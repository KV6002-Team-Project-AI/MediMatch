# %%
# !pip install transformers torch
# !pip install transformers[torch]
# !pip install accelerate -U

# %% [markdown]
# # Data

# %%
data = [
    ("I'm allergic to cats.", {"entities": [(14, 18, "ALLERGY")]}),
    ("Peanuts cause an allergic reaction.", {"entities": [(0, 7, "ALLERGY")]}),
    ("He has a severe nut allergy.", {"entities": [(18, 22, "ALLERGY")]}),
    ("She suffers from hay fever.", {"entities": [(15, 23, "ALLERGY")]}),
    ("I'm allergic to pollen.", {"entities": [(14, 19, "ALLERGY")]}),
    ("He developed a shellfish allergy.", {"entities": [(22, 29, "ALLERGY")]}),
    ("She's allergic to gluten.", {"entities": [(14, 20, "ALLERGY")]}),
    ("I have a dairy allergy.", {"entities": [(10, 16, "ALLERGY")]}),
    ("He's allergic to bee stings.", {"entities": [(14, 23, "ALLERGY")]}),
    ("Pollen allergies make me sneeze.", {"entities": [(0, 6, "ALLERGY")]}),
    ("I get itchy from pet dander.", {"entities": [(13, 22, "ALLERGY")]}),
    ("She's allergic to latex.", {"entities": [(14, 19, "ALLERGY")]}),
    ("I'm sensitive to dust mites.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to mold.", {"entities": [(14, 18, "ALLERGY")]}),
    ("She's allergic to ragweed.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I'm allergic to seafood.", {"entities": [(14, 20, "ALLERGY")]}),
    ("He has an egg allergy.", {"entities": [(15, 20, "ALLERGY")]}),
    ("She's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I'm allergic to grass.", {"entities": [(14, 18, "ALLERGY")]}),
    ("He has a peanut allergy.", {"entities": [(15, 21, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("I'm allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He has a milk allergy.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to sunflower seeds.", {"entities": [(14, 28, "ALLERGY")]}),
    ("I'm allergic to cats and dogs.", {"entities": [(14, 18, "ALLERGY"), (23, 27, "ALLERGY")]}),
    ("He's allergic to gluten and dairy.", {"entities": [(14, 20, "ALLERGY"), (25, 30, "ALLERGY")]}),
    ("She's allergic to peanuts and soy.", {"entities": [(14, 21, "ALLERGY"), (26, 29, "ALLERGY")]}),
    ("I'm allergic to shellfish and fish.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("He's allergic to pollen and grass.", {"entities": [(14, 19, "ALLERGY"), (24, 28, "ALLERGY")]}),
    ("She's allergic to mold and dust mites.", {"entities": [(14, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("I'm allergic to latex and sunflower seeds.", {"entities": [(14, 19, "ALLERGY"), (24, 38, "ALLERGY")]}),
    ("He's allergic to cats, dogs, and peanuts.", {"entities": [(14, 18, "ALLERGY"), (20, 24, "ALLERGY"), (29, 36, "ALLERGY")]}),
    ("She's allergic to gluten, dairy, and soy.", {"entities": [(14, 20, "ALLERGY"), (22, 27, "ALLERGY"), (32, 35, "ALLERGY")]}),
    ("I'm allergic to shellfish, fish, and eggs.", {"entities": [(14, 23, "ALLERGY"), (25, 29, "ALLERGY"), (34, 38, "ALLERGY")]}),
    ("He's allergic to pollen, grass, and mold.", {"entities": [(14, 19, "ALLERGY"), (21, 25, "ALLERGY"), (30, 34, "ALLERGY")]}),
    ("She's allergic to peanuts, soy, and sunflower seeds.", {"entities": [(14, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 45, "ALLERGY")]}),
    ("I'm allergic to cats, dogs, peanuts, and shellfish.", {"entities": [(14, 18, "ALLERGY"), (20, 24, "ALLERGY"), (29, 36, "ALLERGY"), (41, 50, "ALLERGY")]}),
    ("I have an allergy to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("She's allergic to pine nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to mustard seeds.", {"entities": [(14, 26, "ALLERGY")]}),
    ("I suffer from an almond allergy.", {"entities": [(19, 25, "ALLERGY")]}),
    ("She's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to kiwi fruit.", {"entities": [(19, 28, "ALLERGY")]}),
    ("He's allergic to wheat gluten.", {"entities": [(14, 24, "ALLERGY")]}),
    ("She's allergic to cow's milk.", {"entities": [(14, 22, "ALLERGY")]}),
    ("I have an allergy to pineapples.", {"entities": [(19, 29, "ALLERGY")]}),
    ("He's allergic to bee pollen.", {"entities": [(14, 23, "ALLERGY")]}),
    ("I suffer from a cashew allergy.", {"entities": [(19, 25, "ALLERGY")]}),
    ("She's allergic to hazelnuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sunflower oil.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to pecans.", {"entities": [(19, 24, "ALLERGY")]}),
    ("She's allergic to coconut milk.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I suffer from an eggplant allergy.", {"entities": [(19, 28, "ALLERGY")]}),
    ("He's allergic to pineapple juice.", {"entities": [(14, 25, "ALLERGY")]}),
    ("She's allergic to strawberry jam.", {"entities": [(14, 26, "ALLERGY")]}),
    ("I have an allergy to tomato sauce.", {"entities": [(19, 29, "ALLERGY")]}),
    ("He's allergic to grapefruit.", {"entities": [(14, 23, "ALLERGY")]}),
    ("She's allergic to blueberries.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I suffer from a raspberry allergy.", {"entities": [(19, 28, "ALLERGY")]}),
    ("He's allergic to blackberries.", {"entities": [(14, 25, "ALLERGY")]}),
    ("She's allergic to raspberries.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to strawberries.", {"entities": [(19, 30, "ALLERGY")]}),
    ("He's allergic to watermelon.", {"entities": [(14, 24, "ALLERGY")]}),
    ("She's allergic to cantaloupe.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I suffer from a honeydew allergy.", {"entities": [(19, 28, "ALLERGY")]}),
    ("He's allergic to bananas.", {"entities": [(14, 21, "ALLERGY")]}),
    ("She's allergic to oranges.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to lemons.", {"entities": [(19, 25, "ALLERGY")]}),
    ("He's allergic to limes.", {"entities": [(14, 19, "ALLERGY")]}),
    ("She's allergic to grapefruits.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I suffer from a tangerine allergy.", {"entities": [(19, 29, "ALLERGY")]}),
    ("He's allergic to cherries.", {"entities": [(14, 22, "ALLERGY")]}),
    ("She's allergic to plums.", {"entities": [(14, 19, "ALLERGY")]}),
    ("I have an allergy to peaches.", {"entities": [(19, 26, "ALLERGY")]}),
    ("He's allergic to apricots.", {"entities": [(14, 22, "ALLERGY")]}),
    ("She's allergic to apples.", {"entities": [(14, 20, "ALLERGY")]}),
    ("I suffer from a pear allergy.", {"entities": [(19, 23, "ALLERGY")]}),
    ("He's allergic to mangoes.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have allergies to peanuts and shellfish.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("She's allergic to soy and wheat gluten.", {"entities": [(14, 17, "ALLERGY"), (22, 32, "ALLERGY")]}),
    ("He's allergic to dairy and eggs.", {"entities": [(14, 19, "ALLERGY"), (24, 28, "ALLERGY")]}),
    ("I have allergies to tree nuts and sesame seeds.", {"entities": [(14, 23, "ALLERGY"), (28, 39, "ALLERGY")]}),
    ("She's allergic to fish and shellfish.", {"entities": [(14, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("He's allergic to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I have allergies to wheat gluten and soy.", {"entities": [(14, 24, "ALLERGY"), (29, 32, "ALLERGY")]}),
    ("She's allergic to dairy and soy.", {"entities": [(14, 19, "ALLERGY"), (24, 27, "ALLERGY")]}),
    ("He's allergic to peanuts and eggs.", {"entities": [(14, 21, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("I have allergies to shellfish and fish.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("She's allergic to dairy and wheat gluten.", {"entities": [(14, 19, "ALLERGY"), (24, 34, "ALLERGY")]}),
    ("He's allergic to tree nuts and peanuts.", {"entities": [(14, 23, "ALLERGY"), (28, 35, "ALLERGY")]}),
    ("I have allergies to soy and dairy.", {"entities": [(14, 17, "ALLERGY"), (22, 27, "ALLERGY")]}),
    ("She's allergic to shellfish and wheat gluten.", {"entities": [(14, 23, "ALLERGY"), (28, 38, "ALLERGY")]}),
    ("He's allergic to peanuts and soy.", {"entities": [(14, 21, "ALLERGY"), (26, 29, "ALLERGY")]}),
    ("I have allergies to dairy and eggs.", {"entities": [(14, 19, "ALLERGY"), (24, 28, "ALLERGY")]}),
    ("She's allergic to fish and shellfish.", {"entities": [(14, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("He's allergic to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I have allergies to wheat gluten and soy.", {"entities": [(14, 24, "ALLERGY"), (29, 32, "ALLERGY")]}),
    ("She's allergic to dairy and soy.", {"entities": [(14, 19, "ALLERGY"), (24, 27, "ALLERGY")]}),
    ("He's allergic to peanuts and eggs.", {"entities": [(14, 21, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("I have allergies to shellfish and fish.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("She's allergic to dairy and wheat gluten.", {"entities": [(14, 19, "ALLERGY"), (24, 34, "ALLERGY")]}),
    ("He's allergic to tree nuts and peanuts.", {"entities": [(14, 23, "ALLERGY"), (28, 35, "ALLERGY")]}),
    ("I have allergies to soy and dairy.", {"entities": [(14, 17, "ALLERGY"), (22, 27, "ALLERGY")]}),
    ("She's allergic to shellfish and wheat gluten.", {"entities": [(14, 23, "ALLERGY"), (28, 38, "ALLERGY")]}),
    ("He's allergic to peanuts and soy.", {"entities": [(14, 21, "ALLERGY"), (26, 29, "ALLERGY")]}),
    ("I have allergies to dairy and eggs.", {"entities": [(14, 19, "ALLERGY"), (24, 28, "ALLERGY")]}),
    ("She's allergic to fish and shellfish.", {"entities": [(14, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("He's allergic to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I have allergies to peanuts and shellfish.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("She's allergic to soy and wheat gluten.", {"entities": [(14, 17, "ALLERGY"), (22, 32, "ALLERGY")]}),
    ("He's allergic to dairy and eggs.", {"entities": [(14, 19, "ALLERGY"), (24, 28, "ALLERGY")]}),
    ("I have allergies to tree nuts and sesame seeds.", {"entities": [(14, 23, "ALLERGY"), (28, 39, "ALLERGY")]}),
    ("She's allergic to fish and shellfish.", {"entities": [(14, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("He's allergic to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I have allergies to wheat gluten and soy.", {"entities": [(14, 24, "ALLERGY"), (29, 32, "ALLERGY")]}),
    ("She's allergic to dairy and fish.", {"entities": [(14, 19, "ALLERGY"), (24, 28, "ALLERGY")]}),
    ("I have allergies to shellfish and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("He's allergic to peanuts and sesame seeds.", {"entities": [(14, 21, "ALLERGY"), (26, 37, "ALLERGY")]}),
    ("I have allergies to soy and tree nuts.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("She's allergic to wheat gluten and shellfish.", {"entities": [(14, 24, "ALLERGY"), (29, 38, "ALLERGY")]}),
    ("He's allergic to dairy and peanuts.", {"entities": [(14, 19, "ALLERGY"), (24, 31, "ALLERGY")]}),
    ("I have allergies to fish and eggs.", {"entities": [(14, 18, "ALLERGY"), (23, 27, "ALLERGY")]}),
    ("She's allergic to soy and sesame seeds.", {"entities": [(14, 17, "ALLERGY"), (22, 33, "ALLERGY")]}),
    ("He's allergic to wheat gluten and tree nuts.", {"entities": [(14, 24, "ALLERGY"), (29, 38, "ALLERGY")]}),
    ("I have allergies to dairy and shellfish.", {"entities": [(14, 19, "ALLERGY"), (24, 33, "ALLERGY")]}),
    ("She's allergic to peanuts and fish.", {"entities": [(14, 21, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's allergic to soy and eggs.", {"entities": [(14, 17, "ALLERGY"), (22, 26, "ALLERGY")]}),
    ("I have allergies to sesame seeds and wheat gluten.", {"entities": [(14, 25, "ALLERGY"), (30, 40, "ALLERGY")]}),
    ("She's allergic to shellfish and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 37, "ALLERGY")]}),
    ("He's allergic to peanuts and dairy.", {"entities": [(14, 21, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I have allergies to fish and soy.", {"entities": [(14, 18, "ALLERGY"), (23, 26, "ALLERGY")]}),
    ("She's allergic to eggs and sesame seeds.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("He's allergic to wheat gluten and peanuts.", {"entities": [(14, 24, "ALLERGY"), (29, 36, "ALLERGY")]}),
    ("I have allergies to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 33, "ALLERGY")]}),
    ("She's allergic to fish and tree nuts.", {"entities": [(14, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("He's allergic to soy and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("I have allergies to peanuts and wheat gluten.", {"entities": [(14, 21, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("She's allergic to sesame seeds and dairy.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("He's allergic to tree nuts and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to soy and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("She's allergic to wheat gluten and peanuts.", {"entities": [(14, 24, "ALLERGY"), (29, 36, "ALLERGY")]}),
    ("He's allergic to dairy and fish.", {"entities": [(14, 19, "ALLERGY"), (24, 28, "ALLERGY")]}),
    ("I have allergies to sesame seeds and tree nuts.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY")]}),
    ("She's allergic to shellfish and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("He's allergic to peanuts and soy.", {"entities": [(14, 21, "ALLERGY"), (26, 29, "ALLERGY")]}),
    ("I have allergies to dairy and wheat gluten.", {"entities": [(14, 19, "ALLERGY"), (24, 34, "ALLERGY")]}),
    ("She's allergic to fish and sesame seeds.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("He's allergic to eggs and shellfish.", {"entities": [(14, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("I have allergies to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("She's allergic to soy and dairy.", {"entities": [(14, 17, "ALLERGY"), (22, 26, "ALLERGY")]}),
    ("He's allergic to wheat gluten and fish.", {"entities": [(14, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("I have allergies to shellfish and sesame seeds.", {"entities": [(14, 23, "ALLERGY"), (28, 39, "ALLERGY")]}),
    ("She's allergic to peanuts and eggs.", {"entities": [(14, 21, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's allergic to soy and tree nuts.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("I have allergies to dairy and wheat gluten.", {"entities": [(14, 19, "ALLERGY"), (24, 34, "ALLERGY")]}),
    ("She's allergic to fish and shellfish.", {"entities": [(14, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("He's allergic to peanuts and sesame seeds.", {"entities": [(14, 21, "ALLERGY"), (26, 37, "ALLERGY")]}),
    ("I have allergies to soy and dairy.", {"entities": [(14, 17, "ALLERGY"), (22, 26, "ALLERGY")]}),
    ("She's allergic to wheat gluten and tree nuts.", {"entities": [(14, 24, "ALLERGY"), (29, 38, "ALLERGY")]}),
    ("He's allergic to eggs and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY")]}),
    ("I have allergies to shellfish and fish.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("She's allergic to sesame seeds and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 33, "ALLERGY")]}),
    ("He's allergic to tree nuts and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 33, "ALLERGY")]}),
    ("I have allergies to peanuts and wheat gluten.", {"entities": [(14, 21, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("She's allergic to sesame seeds and shellfish.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY")]}),
    ("He's allergic to eggs and soy.", {"entities": [(14, 18, "ALLERGY"), (23, 26, "ALLERGY")]}),
    ("I have allergies to tree nuts and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 33, "ALLERGY")]}),
    ("She's allergic to wheat gluten and fish.", {"entities": [(14, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("He's allergic to shellfish and peanuts.", {"entities": [(14, 23, "ALLERGY"), (28, 35, "ALLERGY")]}),
    ("I have allergies to sesame seeds and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 33, "ALLERGY")]}),
    ("She's allergic to tree nuts and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("He's allergic to wheat gluten and dairy.", {"entities": [(14, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("I have allergies to peanuts and shellfish.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("She's allergic to soy and wheat gluten.", {"entities": [(14, 17, "ALLERGY"), (22, 32, "ALLERGY")]}),
    ("He's allergic to dairy and eggs.", {"entities": [(14, 19, "ALLERGY"), (24, 28, "ALLERGY")]}),
    ("I have allergies to tree nuts and sesame seeds.", {"entities": [(14, 23, "ALLERGY"), (28, 39, "ALLERGY")]}),
    ("She's allergic to fish and shellfish.", {"entities": [(14, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("He's allergic to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I have allergies to wheat gluten and soy.", {"entities": [(14, 24, "ALLERGY"), (29, 32, "ALLERGY")]}),
    ("She's allergic to dairy and fish.", {"entities": [(14, 19, "ALLERGY"), (24, 28, "ALLERGY")]}),
    ("I have allergies to shellfish and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("He's allergic to peanuts and sesame seeds.", {"entities": [(14, 21, "ALLERGY"), (26, 37, "ALLERGY")]}),
    ("I have allergies to soy and tree nuts.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("She's allergic to wheat gluten and shellfish.", {"entities": [(14, 24, "ALLERGY"), (29, 38, "ALLERGY")]}),
    ("He's allergic to dairy and peanuts.", {"entities": [(14, 19, "ALLERGY"), (24, 31, "ALLERGY")]}),
    ("I have allergies to fish and eggs.", {"entities": [(14, 18, "ALLERGY"), (23, 27, "ALLERGY")]}),
    ("She's allergic to soy and sesame seeds.", {"entities": [(14, 17, "ALLERGY"), (22, 33, "ALLERGY")]}),
    ("He's allergic to wheat gluten and tree nuts.", {"entities": [(14, 24, "ALLERGY"), (29, 38, "ALLERGY")]}),
    ("I have allergies to dairy and shellfish.", {"entities": [(14, 19, "ALLERGY"), (24, 33, "ALLERGY")]}),
    ("She's allergic to peanuts and fish.", {"entities": [(14, 21, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's allergic to soy and eggs.", {"entities": [(14, 17, "ALLERGY"), (22, 26, "ALLERGY")]}),
    ("I have allergies to sesame seeds and wheat gluten.", {"entities": [(14, 25, "ALLERGY"), (30, 40, "ALLERGY")]}),
    ("She's allergic to shellfish and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 37, "ALLERGY")]}),

    ("I am allergic to peanuts.", {"entities": [(12, 20, "ALLERGY")]}),
    ("She's allergic to dairy.", {"entities": [(14, 18, "ALLERGY")]}),
    ("He's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("I have an allergy to soy.", {"entities": [(17, 20, "ALLERGY")]}),
    ("She has a wheat gluten allergy.", {"entities": [(10, 21, "ALLERGY")]}),
    ("I'm allergic to peanuts and dairy.", {"entities": [(12, 20, "ALLERGY"), (25, 30, "ALLERGY")]}),
    ("She has allergies to soy and shellfish.", {"entities": [(20, 23, "ALLERGY"), (28, 37, "ALLERGY")]}),
    ("He's allergic to wheat gluten and eggs.", {"entities": [(20, 31, "ALLERGY"), (36, 40, "ALLERGY")]}),
    ("I have allergies to tree nuts and fish.", {"entities": [(21, 30, "ALLERGY"), (35, 39, "ALLERGY")]}),
    ("She's allergic to sesame seeds and peanuts.", {"entities": [(21, 32, "ALLERGY"), (37, 45, "ALLERGY")]}),
    ("I am allergic to peanuts, dairy, and shellfish.",
     {"entities": [(12, 20, "ALLERGY"), (22, 27, "ALLERGY"), (32, 41, "ALLERGY")]}),
    ("She has allergies to soy, wheat gluten, and eggs.",
     {"entities": [(20, 23, "ALLERGY"), (28, 39, "ALLERGY"), (44, 48, "ALLERGY")]}),
    ("He's allergic to tree nuts, sesame seeds, and fish.",
     {"entities": [(20, 29, "ALLERGY"), (34, 45, "ALLERGY"), (50, 54, "ALLERGY")]}),
    ("I have allergies to peanuts, tree nuts, and dairy.",
     {"entities": [(21, 30, "ALLERGY"), (32, 41, "ALLERGY"), (46, 51, "ALLERGY")]}),
    ("She's allergic to wheat gluten, soy, and shellfish.",
     {"entities": [(21, 32, "ALLERGY"), (34, 37, "ALLERGY"), (42, 51, "ALLERGY")]}),
    ("I have allergies to peanuts, dairy, soy, and shellfish.",
     {"entities": [(21, 30, "ALLERGY"), (32, 36, "ALLERGY"), (38, 41, "ALLERGY"), (46, 55, "ALLERGY")]}),
    ("She's allergic to wheat gluten, eggs, tree nuts, and fish.",
     {"entities": [(21, 32, "ALLERGY"), (34, 38, "ALLERGY"), (40, 49, "ALLERGY"), (54, 58, "ALLERGY")]}),
    ("He's allergic to peanuts, sesame seeds, dairy, and wheat gluten.",
     {"entities": [(21, 30, "ALLERGY"), (32, 45, "ALLERGY"), (46, 51, "ALLERGY"), (56, 67, "ALLERGY")]}),
    ("I have allergies to soy, shellfish, peanuts, and sesame seeds.",
     {"entities": [(21, 24, "ALLERGY"), (25, 34, "ALLERGY"), (39, 47, "ALLERGY"), (52, 63, "ALLERGY")]}),
    ("She's allergic to dairy, wheat gluten, eggs, and tree nuts.",
     {"entities": [(21, 26, "ALLERGY"), (27, 38, "ALLERGY"), (43, 47, "ALLERGY"), (52, 61, "ALLERGY")]}),
    ("He's allergic to fish, soy, sesame seeds, and shellfish.",
     {"entities": [(21, 25, "ALLERGY"), (26, 29, "ALLERGY"), (34, 45, "ALLERGY"), (50, 59, "ALLERGY")]}),
    ("I have allergies to peanuts, dairy, wheat gluten, soy, and shellfish.", {
        "entities": [(21, 30, "ALLERGY"), (32, 36, "ALLERGY"), (38, 49, "ALLERGY"), (54, 57, "ALLERGY"),
                     (62, 71, "ALLERGY")]}),
    ("She's allergic to sesame seeds, tree nuts, eggs, soy, and fish.", {
        "entities": [(21, 32, "ALLERGY"), (34, 43, "ALLERGY"), (45, 49, "ALLERGY"), (54, 57, "ALLERGY"),
                     (62, 66, "ALLERGY")]}),
    ("He's allergic to wheat gluten, peanuts, dairy, shellfish, and soy.", {
        "entities": [(21, 32, "ALLERGY"), (34, 41, "ALLERGY"), (43, 48, "ALLERGY"), (53, 62, "ALLERGY"),
                     (67, 70, "ALLERGY")]}),
    ("I have allergies to soy, sesame seeds, tree nuts, shellfish, and wheat gluten.", {
        "entities": [(21, 24, "ALLERGY"), (25, 36, "ALLERGY"), (38, 47, "ALLERGY"), (52, 61, "ALLERGY"),
                     (66, 77, "ALLERGY")]}),
    ("She's allergic to dairy, peanuts, soy, fish, and eggs.", {
        "entities": [(21, 26, "ALLERGY"), (27, 34, "ALLERGY"), (36, 39, "ALLERGY"), (44, 48, "ALLERGY"),
                     (53, 57, "ALLERGY")]}),
    ("He's allergic to shellfish, wheat gluten, sesame seeds, dairy, and tree nuts.", {
        "entities": [(21, 30, "ALLERGY"), (32, 43, "ALLERGY"), (45, 56, "ALLERGY"), (61, 66, "ALLERGY"),
                     (71, 80, "ALLERGY")]}),
    ("I have allergies to peanuts, tree nuts, soy, wheat gluten, eggs, and fish.", {
        "entities": [(21, 30, "ALLERGY"), (32, 41, "ALLERGY"), (43, 46, "ALLERGY"), (51, 62, "ALLERGY"),
                     (67, 71, "ALLERGY"), (76, 80, "ALLERGY")]}),
    ("She's allergic to soy, dairy, shellfish, sesame seeds, wheat gluten, and peanuts.", {
        "entities": [(21, 24, "ALLERGY"), (26, 31, "ALLERGY"), (33, 42, "ALLERGY"), (47, 58, "ALLERGY"),
                     (63, 74, "ALLERGY"), (79, 86, "ALLERGY")]}),
    ("He's allergic to peanuts, eggs, tree nuts, wheat gluten, soy, and fish.", {
        "entities": [(21, 30, "ALLERGY"), (32, 36, "ALLERGY"), (38, 47, "ALLERGY"), (52, 63, "ALLERGY"),
                     (68, 71, "ALLERGY"), (76, 80, "ALLERGY")]}),
    ("I have allergies to shellfish, soy, sesame seeds, dairy, peanuts, and wheat gluten.", {
        "entities": [(21, 30, "ALLERGY"), (32, 35, "ALLERGY"), (37, 48, "ALLERGY"), (53, 58, "ALLERGY"),
                     (63, 71, "ALLERGY"), (76, 87, "ALLERGY")]}),
    ("She's allergic to fish, wheat gluten, tree nuts, soy, peanuts, and eggs.", {
        "entities": [(21, 25, "ALLERGY"), (27, 38, "ALLERGY"), (43, 52, "ALLERGY"), (57, 60, "ALLERGY"),
                     (65, 73, "ALLERGY"), (78, 82, "ALLERGY")]}),
    ("He's allergic to dairy, shellfish, wheat gluten, peanuts, soy, sesame seeds, and eggs.", {
        "entities": [(21, 26, "ALLERGY"), (28, 37, "ALLERGY"), (42, 53, "ALLERGY"), (58, 65, "ALLERGY"),
                     (70, 73, "ALLERGY"), (78, 89, "ALLERGY"), (94, 98, "ALLERGY")]}),
    ("I have allergies to soy, dairy, wheat gluten, peanuts, shellfish, eggs, and sesame seeds.", {
        "entities": [(21, 24, "ALLERGY"), (26, 31, "ALLERGY"), (33, 44, "ALLERGY"), (49, 58, "ALLERGY"),
                     (63, 71, "ALLERGY"), (76, 80, "ALLERGY"), (85, 96, "ALLERGY")]}),
    ("She's allergic to tree nuts, peanuts, soy, dairy, eggs, sesame seeds, and wheat gluten.", {
        "entities": [(21, 30, "ALLERGY"), (32, 39, "ALLERGY"), (44, 47, "ALLERGY"), (52, 57, "ALLERGY"),
                     (62, 66, "ALLERGY"), (71, 82, "ALLERGY"), (87, 98, "ALLERGY")]}),
    ("He's allergic to peanuts, wheat gluten, soy, sesame seeds, shellfish, eggs, and dairy.", {
        "entities": [(21, 30, "ALLERGY"), (32, 43, "ALLERGY"), (48, 51, "ALLERGY"), (56, 67, "ALLERGY"),
                     (72, 81, "ALLERGY"), (86, 90, "ALLERGY"), (95, 100, "ALLERGY")]}),
    ("I have allergies to dairy, soy, peanuts, wheat gluten, shellfish, eggs, tree nuts, and sesame seeds.", {
        "entities": [(21, 26, "ALLERGY"), (28, 31, "ALLERGY"), (36, 45, "ALLERGY"), (50, 61, "ALLERGY"),
                     (66, 75, "ALLERGY"), (80, 84, "ALLERGY"), (89, 98, "ALLERGY"), (103, 114, "ALLERGY")]}),
    ("She's allergic to eggs, soy, dairy, peanuts, wheat gluten, tree nuts, sesame seeds, and fish.", {
        "entities": [(21, 25, "ALLERGY"), (27, 30, "ALLERGY"), (35, 40, "ALLERGY"), (45, 54, "ALLERGY"),
                     (59, 68, "ALLERGY"), (73, 82, "ALLERGY"), (87, 98, "ALLERGY"), (103, 107, "ALLERGY")]}),
    ("He's allergic to shellfish, peanuts, wheat gluten, soy, dairy, sesame seeds, eggs, and tree nuts.", {
        "entities": [(21, 30, "ALLERGY"), (32, 39, "ALLERGY"), (44, 55, "ALLERGY"), (60, 63, "ALLERGY"),
                     (68, 73, "ALLERGY"), (78, 89, "ALLERGY"), (94, 98, "ALLERGY"), (103, 112, "ALLERGY")]}),
    ("I have allergies to peanuts, tree nuts, wheat gluten, soy, dairy, fish, shellfish, sesame seeds, and eggs.", {
        "entities": [(21, 30, "ALLERGY"), (32, 41, "ALLERGY"), (46, 57, "ALLERGY"), (62, 65, "ALLERGY"),
                     (70, 75, "ALLERGY"), (80, 84, "ALLERGY"), (89, 98, "ALLERGY"), (103, 114, "ALLERGY"),
                     (119, 123, "ALLERGY")]}),
    ("She's allergic to soy, dairy, peanuts, wheat gluten, fish, shellfish, tree nuts, eggs, and sesame seeds.", {
        "entities": [(21, 24, "ALLERGY"), (26, 31, "ALLERGY"), (36, 45, "ALLERGY"), (50, 61, "ALLERGY"),
                     (66, 70, "ALLERGY"), (75, 84, "ALLERGY"), (89, 98, "ALLERGY"), (103, 107, "ALLERGY"),
                     (112, 123, "ALLERGY")]}),
    ("He's allergic to wheat gluten, peanuts, soy, shellfish, sesame seeds, dairy, eggs, tree nuts, and fish.", {
        "entities": [(21, 32, "ALLERGY"), (34, 41, "ALLERGY"), (46, 49, "ALLERGY"), (54, 63, "ALLERGY"),
                     (68, 79, "ALLERGY"), (84, 89, "ALLERGY"), (94, 98, "ALLERGY"), (103, 112, "ALLERGY"),
                     (117, 121, "ALLERGY")]}),
    ("I have allergies to peanuts, soy, dairy, eggs, shellfish, tree nuts, wheat gluten, sesame seeds, and fish.", {
        "entities": [(21, 30, "ALLERGY"), (32, 35, "ALLERGY"), (40, 45, "ALLERGY"), (50, 54, "ALLERGY"),
                     (59, 68, "ALLERGY"), (73, 82, "ALLERGY"), (87, 98, "ALLERGY"), (103, 114, "ALLERGY"),
                     (119, 123, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I'm allergic to dairy.", {"entities": [(14, 18, "ALLERGY")]}),
    ("She's allergic to eggs.", {"entities": [(14, 18, "ALLERGY")]}),
    ("I have an allergy to soy.", {"entities": [(18, 21, "ALLERGY")]}),
    ("He has allergies to tree nuts.", {"entities": [(17, 26, "ALLERGY")]}),
    ("I'm allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("She's allergic to fish.", {"entities": [(14, 18, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have allergies to peanuts and soy.", {"entities": [(14, 21, "ALLERGY"), (26, 29, "ALLERGY")]}),
    ("She's allergic to dairy and shellfish.", {"entities": [(14, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("He's allergic to wheat gluten and eggs.", {"entities": [(14, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("I have allergies to tree nuts and sesame seeds.", {"entities": [(14, 23, "ALLERGY"), (28, 39, "ALLERGY")]}),
    ("She's allergic to fish and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY")]}),
    ("He's allergic to shellfish and soy.", {"entities": [(14, 23, "ALLERGY"), (28, 31, "ALLERGY")]}),
    ("I have allergies to sesame seeds and dairy.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("She's allergic to wheat gluten and tree nuts.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY")]}),
    ("He's allergic to peanuts, soy, and eggs.", {"entities": [(14, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("I have allergies to dairy, shellfish, and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 32, "ALLERGY"), (37, 48, "ALLERGY")]}),
    ("She's allergic to fish, peanuts, and sesame seeds.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY"), (35, 46, "ALLERGY")]}),
    ("He's allergic to soy, dairy, and tree nuts.", {"entities": [(14, 17, "ALLERGY"), (22, 27, "ALLERGY"), (32, 41, "ALLERGY")]}),
    ("I have allergies to wheat gluten, fish, and shellfish.", {"entities": [(14, 24, "ALLERGY"), (29, 33, "ALLERGY"), (38, 47, "ALLERGY")]}),
    ("She's allergic to peanuts, tree nuts, and dairy.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 42, "ALLERGY")]}),
    ("He's allergic to sesame seeds, soy, and eggs.", {"entities": [(14, 25, "ALLERGY"), (30, 33, "ALLERGY"), (38, 42, "ALLERGY")]}),
    ("I have allergies to shellfish, wheat gluten, and fish.", {"entities": [(14, 23, "ALLERGY"), (28, 39, "ALLERGY"), (44, 48, "ALLERGY")]}),
    ("She's allergic to peanuts, dairy, and soy.", {"entities": [(14, 21, "ALLERGY"), (23, 28, "ALLERGY"), (33, 36, "ALLERGY")]}),
    ("He's allergic to fish, eggs, and shellfish.", {"entities": [(14, 18, "ALLERGY"), (23, 27, "ALLERGY"), (32, 41, "ALLERGY")]}),
    ("I have allergies to tree nuts, wheat gluten, and peanuts.", {"entities": [(14, 23, "ALLERGY"), (28, 39, "ALLERGY"), (44, 51, "ALLERGY")]}),
    ("She's allergic to soy, sesame seeds, and dairy.", {"entities": [(14, 17, "ALLERGY"), (22, 33, "ALLERGY"), (38, 43, "ALLERGY")]}),
    ("He's allergic to peanuts, fish, and eggs.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 36, "ALLERGY")]}),
    ("I have allergies to shellfish, tree nuts, and wheat gluten.", {"entities": [(14, 23, "ALLERGY"), (28, 37, "ALLERGY"), (42, 53, "ALLERGY")]}),
    ("She's allergic to dairy, sesame seeds, and soy.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY"), (39, 42, "ALLERGY")]}),
    ("He's allergic to wheat gluten, peanuts, and shellfish.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 53, "ALLERGY")]}),
    ("I have allergies to soy, eggs, and dairy.", {"entities": [(14, 17, "ALLERGY"), (22, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("She's allergic to peanuts, wheat gluten, and fish.", {"entities": [(14, 21, "ALLERGY"), (23, 34, "ALLERGY"), (39, 43, "ALLERGY")]}),
    ("He's allergic to dairy, sesame seeds, and soy.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY"), (39, 42, "ALLERGY")]}),
    ("I have allergies to shellfish, tree nuts, and peanuts.", {"entities": [(14, 23, "ALLERGY"), (28, 37, "ALLERGY"), (42, 51, "ALLERGY")]}),
    ("She's allergic to soy, eggs, and fish.", {"entities": [(14, 17, "ALLERGY"), (22, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("He's allergic to peanuts, shellfish, and dairy.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 42, "ALLERGY")]}),
    ("I have allergies to wheat gluten, soy, and tree nuts.", {"entities": [(14, 25, "ALLERGY"), (30, 33, "ALLERGY"), (38, 47, "ALLERGY")]}),
    ("She's allergic to dairy, fish, and eggs.", {"entities": [(14, 18, "ALLERGY"), (23, 27, "ALLERGY"), (32, 36, "ALLERGY")]}),
    ("He's allergic to peanuts, wheat gluten, and sesame seeds.", {"entities": [(14, 21, "ALLERGY"), (23, 34, "ALLERGY"), (39, 50, "ALLERGY")]}),
    ("I have allergies to shellfish, soy, and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 31, "ALLERGY"), (36, 41, "ALLERGY")]}),
    ("She's allergic to tree nuts, eggs, and soy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY"), (37, 40, "ALLERGY")]}),
    ("He's allergic to peanuts, fish, and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 41, "ALLERGY")]}),
    ("I have allergies to sesame seeds, dairy, and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY"), (40, 43, "ALLERGY")]}),
    ("She's allergic to wheat gluten, shellfish, and eggs.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 48, "ALLERGY")]}),
    ("He's allergic to peanuts, sesame seeds, and soy.", {"entities": [(14, 21, "ALLERGY"), (23, 34, "ALLERGY"), (39, 42, "ALLERGY")]}),
    ("I have allergies to dairy, tree nuts, and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 32, "ALLERGY"), (37, 48, "ALLERGY")]}),
    ("She's allergic to fish, peanuts, and eggs.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY"), (35, 39, "ALLERGY")]}),
    ("He's allergic to soy, wheat gluten, and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 33, "ALLERGY"), (38, 47, "ALLERGY")]}),
    ("I have allergies to sesame seeds, dairy, and tree nuts.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY"), (40, 49, "ALLERGY")]}),
    ("She's allergic to peanuts, fish, and soy.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 35, "ALLERGY")]}),
    ("He's allergic to wheat gluten, eggs, and dairy.", {"entities": [(14, 25, "ALLERGY"), (30, 34, "ALLERGY"), (39, 43, "ALLERGY")]}),
    ("I have allergies to tree nuts, shellfish, and wheat gluten.", {"entities": [(14, 23, "ALLERGY"), (28, 37, "ALLERGY"), (42, 53, "ALLERGY")]}),
    ("She's allergic to soy, peanuts, and fish.", {"entities": [(14, 17, "ALLERGY"), (22, 29, "ALLERGY"), (34, 38, "ALLERGY")]}),
    ("He's allergic to dairy, wheat gluten, and tree nuts.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY"), (39, 48, "ALLERGY")]}),
    ("I have allergies to shellfish, sesame seeds, and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 39, "ALLERGY"), (44, 49, "ALLERGY")]}),
    ("She's allergic to fish, soy, and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 26, "ALLERGY"), (31, 38, "ALLERGY")]}),
    ("He's allergic to peanuts, tree nuts, and wheat gluten.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 48, "ALLERGY")]}),
    ("I have allergies to dairy, eggs, and soy.", {"entities": [(14, 18, "ALLERGY"), (23, 27, "ALLERGY"), (32, 35, "ALLERGY")]}),
    ("She's allergic to wheat gluten, shellfish, and sesame seeds.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 55, "ALLERGY")]}),
    ("He's allergic to peanuts, fish, and dairy.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 36, "ALLERGY")]}),
    ("I have allergies to soy, tree nuts, and eggs.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY"), (36, 40, "ALLERGY")]}),
    ("She's allergic to dairy, peanuts, and shellfish.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY"), (35, 44, "ALLERGY")]}),
    ("He's allergic to wheat gluten, sesame seeds, and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 41, "ALLERGY"), (46, 50, "ALLERGY")]}),
    ("I have allergies to soy, dairy, and tree nuts.", {"entities": [(14, 17, "ALLERGY"), (22, 27, "ALLERGY"), (32, 41, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and eggs.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He's allergic to wheat gluten, soy, and shellfish.", {"entities": [(14, 25, "ALLERGY"), (30, 33, "ALLERGY"), (38, 47, "ALLERGY")]}),
    ("I have allergies to sesame seeds, dairy, and eggs.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY"), (40, 44, "ALLERGY")]}),
    ("She's allergic to peanuts, fish, and wheat gluten.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 43, "ALLERGY")]}),
    ("He's allergic to soy, tree nuts, and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY"), (36, 45, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and soy.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("She's allergic to wheat gluten, sesame seeds, and tree nuts.", {"entities": [(14, 25, "ALLERGY"), (30, 41, "ALLERGY"), (46, 55, "ALLERGY")]}),
    ("He's allergic to peanuts, fish, and soy.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 35, "ALLERGY")]}),
    ("I have allergies to shellfish, dairy, and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("She's allergic to soy, peanuts, and fish.", {"entities": [(14, 17, "ALLERGY"), (22, 29, "ALLERGY"), (34, 38, "ALLERGY")]}),
    ("He's allergic to wheat gluten, shellfish, and dairy.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 49, "ALLERGY")]}),
    ("I have allergies to sesame seeds, tree nuts, and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 47, "ALLERGY")]}),
    ("She's allergic to peanuts, dairy, and fish.", {"entities": [(14, 21, "ALLERGY"), (23, 28, "ALLERGY"), (33, 37, "ALLERGY")]}),
    ("He's allergic to wheat gluten, soy, and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 33, "ALLERGY"), (38, 45, "ALLERGY")]}),
    ("I have allergies to shellfish, sesame seeds, and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 39, "ALLERGY"), (44, 53, "ALLERGY")]}),
    ("She's allergic to fish, peanuts, and soy.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("He's allergic to dairy, wheat gluten, and eggs.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY"), (39, 43, "ALLERGY")]}),
    ("I have allergies to tree nuts, peanuts, and shellfish.", {"entities": [(14, 23, "ALLERGY"), (28, 35, "ALLERGY"), (40, 49, "ALLERGY")]}),
    ("She's allergic to soy, dairy, and fish.", {"entities": [(14, 17, "ALLERGY"), (22, 27, "ALLERGY"), (32, 36, "ALLERGY")]}),
    ("He's allergic to peanuts, wheat gluten, and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (23, 34, "ALLERGY"), (39, 48, "ALLERGY")]}),
    ("I have allergies to sesame seeds, shellfish, and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 47, "ALLERGY")]}),
    ("She's allergic to dairy, eggs, and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 27, "ALLERGY"), (32, 39, "ALLERGY")]}),
    ("He's allergic to wheat gluten, soy, and sesame seeds.", {"entities": [(14, 25, "ALLERGY"), (30, 33, "ALLERGY"), (38, 49, "ALLERGY")]}),
    ("I have allergies to tree nuts, shellfish, and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 37, "ALLERGY"), (42, 46, "ALLERGY")]}),
    ("She's allergic to fish, soy, and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 26, "ALLERGY"), (31, 42, "ALLERGY")]}),
    ("He's allergic to peanuts, eggs, and sesame seeds.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 43, "ALLERGY")]}),
    ("I have allergies to shellfish, dairy, and soy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY"), (37, 40, "ALLERGY")]}),
    ("She's allergic to wheat gluten, tree nuts, and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 48, "ALLERGY")]}),
    ("He's allergic to peanuts, sesame seeds, and eggs.", {"entities": [(14, 21, "ALLERGY"), (23, 34, "ALLERGY"), (39, 43, "ALLERGY")]}),
    ("I have allergies to soy, dairy, and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 27, "ALLERGY"), (32, 41, "ALLERGY")]}),
    ("She's allergic to fish, peanuts, and dairy.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY"), (35, 39, "ALLERGY")]}),
    ("He's allergic to wheat gluten, soy, and tree nuts.", {"entities": [(14, 25, "ALLERGY"), (30, 33, "ALLERGY"), (38, 47, "ALLERGY")]}),
    ("I have allergies to sesame seeds, dairy, and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY"), (40, 43, "ALLERGY")]}),
    ("She's allergic to peanuts, fish, and wheat gluten.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 43, "ALLERGY")]}),
    ("He's allergic to soy, tree nuts, and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY"), (36, 45, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and soy.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("She's allergic to wheat gluten, sesame seeds, and tree nuts.", {"entities": [(14, 25, "ALLERGY"), (30, 41, "ALLERGY"), (46, 55, "ALLERGY")]}),
    ("He's allergic to peanuts, fish, and soy.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 35, "ALLERGY")]}),
    ("I have allergies to shellfish, dairy, and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("She's allergic to soy, peanuts, and fish.", {"entities": [(14, 17, "ALLERGY"), (22, 29, "ALLERGY"), (34, 38, "ALLERGY")]}),
    ("He's allergic to wheat gluten, shellfish, and dairy.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 49, "ALLERGY")]}),
    ("I have allergies to sesame seeds, tree nuts, and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 47, "ALLERGY")]}),
    ("She's allergic to peanuts, dairy, and fish.", {"entities": [(14, 21, "ALLERGY"), (23, 28, "ALLERGY"), (33, 37, "ALLERGY")]}),
    ("He's allergic to wheat gluten, soy, and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 33, "ALLERGY"), (38, 45, "ALLERGY")]}),
    ("I have allergies to shellfish, sesame seeds, and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 39, "ALLERGY"), (44, 53, "ALLERGY")]}),
    ("She's allergic to fish, soy, and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 26, "ALLERGY"), (31, 42, "ALLERGY")]}),
    ("He's allergic to peanuts, eggs, and sesame seeds.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 43, "ALLERGY")]}),
    ("I have allergies to shellfish, dairy, and soy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY"), (37, 40, "ALLERGY")]}),
    ("She's allergic to wheat gluten, tree nuts, and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 48, "ALLERGY")]}),
    ("He's allergic to peanuts, sesame seeds, and eggs.", {"entities": [(14, 21, "ALLERGY"), (23, 34, "ALLERGY"), (39, 43, "ALLERGY")]}),
    ("I have allergies to soy, dairy, and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 27, "ALLERGY"), (32, 41, "ALLERGY")]}),
    ("She's allergic to fish, peanuts, and dairy.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY"), (35, 39, "ALLERGY")]}),
    ("He's allergic to wheat gluten, soy, and tree nuts.", {"entities": [(14, 25, "ALLERGY"), (30, 33, "ALLERGY"), (38, 47, "ALLERGY")]}),
    ("I have allergies to sesame seeds, dairy, and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY"), (40, 43, "ALLERGY")]}),
    ("She's allergic to peanuts, fish, and wheat gluten.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 43, "ALLERGY")]}),
    ("He's allergic to soy, tree nuts, and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY"), (36, 45, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and soy.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("She's allergic to wheat gluten, sesame seeds, and tree nuts.", {"entities": [(14, 25, "ALLERGY"), (30, 41, "ALLERGY"), (46, 55, "ALLERGY")]}),
    ("He's allergic to peanuts, fish, and soy.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 35, "ALLERGY")]}),
    ("I have allergies to shellfish, dairy, and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("She's allergic to soy, peanuts, and fish.", {"entities": [(14, 17, "ALLERGY"), (22, 29, "ALLERGY"), (34, 38, "ALLERGY")]}),
    ("He's allergic to wheat gluten, shellfish, and dairy.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 49, "ALLERGY")]}),
    ("I have allergies to sesame seeds, tree nuts, and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 47, "ALLERGY")]}),
    ("She's allergic to peanuts, dairy, and fish.", {"entities": [(14, 21, "ALLERGY"), (23, 28, "ALLERGY"), (33, 37, "ALLERGY")]}),
    ("He's allergic to wheat gluten, soy, and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 33, "ALLERGY"), (38, 45, "ALLERGY")]}),
    ("I have allergies to shellfish, sesame seeds, and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 39, "ALLERGY"), (44, 53, "ALLERGY")]}),
    ("She's allergic to fish, soy, and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 26, "ALLERGY"), (31, 42, "ALLERGY")]}),
    ("He's allergic to peanuts, eggs, and sesame seeds.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 43, "ALLERGY")]}),
    ("I have allergies to shellfish, dairy, and soy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY"), (37, 40, "ALLERGY")]}),
    ("She's allergic to wheat gluten, tree nuts, and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 48, "ALLERGY")]}),
    ("He's allergic to peanuts, sesame seeds, and eggs.", {"entities": [(14, 21, "ALLERGY"), (23, 34, "ALLERGY"), (39, 43, "ALLERGY")]}),
    ("I have allergies to soy, dairy, and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 27, "ALLERGY"), (32, 41, "ALLERGY")]}),
    ("She's allergic to fish, peanuts, and dairy.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY"), (35, 39, "ALLERGY")]}),
    ("He's allergic to wheat gluten, soy, and tree nuts.", {"entities": [(14, 25, "ALLERGY"), (30, 33, "ALLERGY"), (38, 47, "ALLERGY")]}),
    ("I have allergies to sesame seeds, dairy, and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY"), (40, 43, "ALLERGY")]}),
    ("She's allergic to peanuts, fish, and wheat gluten.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 43, "ALLERGY")]}),
    ("He's allergic to soy, tree nuts, and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY"), (36, 45, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and soy.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("She's allergic to wheat gluten, sesame seeds, and tree nuts.", {"entities": [(14, 25, "ALLERGY"), (30, 41, "ALLERGY"), (46, 55, "ALLERGY")]}),
    ("He's allergic to peanuts, fish, and soy.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 35, "ALLERGY")]}),
    ("I have allergies to shellfish, dairy, and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("She's allergic to soy, peanuts, and fish.", {"entities": [(14, 17, "ALLERGY"), (22, 29, "ALLERGY"), (34, 38, "ALLERGY")]}),
    ("He's allergic to wheat gluten, shellfish, and dairy.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 49, "ALLERGY")]}),
    ("I have allergies to sesame seeds, tree nuts, and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 47, "ALLERGY")]}),
    ("She's allergic to peanuts, dairy, and fish.", {"entities": [(14, 21, "ALLERGY"), (23, 28, "ALLERGY"), (33, 37, "ALLERGY")]}),
    ("He's allergic to wheat gluten, soy, and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 33, "ALLERGY"), (38, 45, "ALLERGY")]}),
    ("I have allergies to shellfish, sesame seeds, and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 39, "ALLERGY"), (44, 53, "ALLERGY")]}),
    ("She's allergic to fish, soy, and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 26, "ALLERGY"), (31, 42, "ALLERGY")]}),
    ("He's allergic to peanuts, eggs, and sesame seeds.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 43, "ALLERGY")]}),
    ("I have allergies to shellfish, dairy, and soy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY"), (37, 40, "ALLERGY")]}),
    ("She's allergic to wheat gluten, tree nuts, and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 48, "ALLERGY")]}),
    ("He's allergic to peanuts, sesame seeds, and eggs.", {"entities": [(14, 21, "ALLERGY"), (23, 34, "ALLERGY"), (39, 43, "ALLERGY")]}),
    ("I have allergies to soy, dairy, and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 27, "ALLERGY"), (32, 41, "ALLERGY")]}),
    ("She's allergic to fish, peanuts, and dairy.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY"), (35, 39, "ALLERGY")]}),
    ("He's allergic to wheat gluten, soy, and tree nuts.", {"entities": [(14, 25, "ALLERGY"), (30, 33, "ALLERGY"), (38, 47, "ALLERGY")]}),
    ("I have allergies to sesame seeds, dairy, and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY"), (40, 43, "ALLERGY")]}),
    ("She's allergic to peanuts, fish, and wheat gluten.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 43, "ALLERGY")]}),
    ("He's allergic to soy, tree nuts, and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY"), (36, 45, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and soy.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("She's allergic to wheat gluten, sesame seeds, and tree nuts.", {"entities": [(14, 25, "ALLERGY"), (30, 41, "ALLERGY"), (46, 55, "ALLERGY")]}),
    ("He's allergic to peanuts, fish, and soy.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 35, "ALLERGY")]}),
    ("I have allergies to shellfish, dairy, and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("She's allergic to soy, peanuts, and fish.", {"entities": [(14, 17, "ALLERGY"), (22, 29, "ALLERGY"), (34, 38, "ALLERGY")]}),
    ("He's allergic to wheat gluten, shellfish, and dairy.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 49, "ALLERGY")]}),
    ("I have allergies to sesame seeds, tree nuts, and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 47, "ALLERGY")]}),
    ("She's allergic to peanuts, dairy, and fish.", {"entities": [(14, 21, "ALLERGY"), (23, 28, "ALLERGY"), (33, 37, "ALLERGY")]}),
    ("He's allergic to wheat gluten, soy, and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 33, "ALLERGY"), (38, 45, "ALLERGY")]}),
    ("I have allergies to shellfish, sesame seeds, and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 39, "ALLERGY"), (44, 53, "ALLERGY")]}),
    ("She's allergic to fish, soy, and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 26, "ALLERGY"), (31, 42, "ALLERGY")]}),
    ("He's allergic to peanuts, eggs, and sesame seeds.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 43, "ALLERGY")]}),
    ("I have allergies to shellfish, dairy, and soy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY"), (37, 40, "ALLERGY")]}),
    ("She's allergic to wheat gluten, tree nuts, and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 48, "ALLERGY")]}),
    ("He's allergic to peanuts, sesame seeds, and eggs.", {"entities": [(14, 21, "ALLERGY"), (23, 34, "ALLERGY"), (39, 43, "ALLERGY")]}),
    ("I have allergies to soy, dairy, and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 27, "ALLERGY"), (32, 41, "ALLERGY")]}),
    ("She's allergic to fish, peanuts, and dairy.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY"), (35, 39, "ALLERGY")]}),
    ("He's allergic to wheat gluten, soy, and tree nuts.", {"entities": [(14, 25, "ALLERGY"), (30, 33, "ALLERGY"), (38, 47, "ALLERGY")]}),
    ("I have allergies to sesame seeds, dairy, and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY"), (40, 43, "ALLERGY")]}),
    ("She's allergic to peanuts, fish, and wheat gluten.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 43, "ALLERGY")]}),
    ("He's allergic to soy, tree nuts, and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY"), (36, 45, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and soy.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("She's allergic to wheat gluten, sesame seeds, and tree nuts.", {"entities": [(14, 25, "ALLERGY"), (30, 41, "ALLERGY"), (46, 55, "ALLERGY")]}),
    ("He's allergic to peanuts, fish, and soy.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 35, "ALLERGY")]}),
    ("I have allergies to shellfish, dairy, and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("She's allergic to soy, peanuts, and fish.", {"entities": [(14, 17, "ALLERGY"), (22, 29, "ALLERGY"), (34, 38, "ALLERGY")]}),
    ("He's allergic to wheat gluten, shellfish, and dairy.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 49, "ALLERGY")]}),
    ("I have allergies to sesame seeds, tree nuts, and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 47, "ALLERGY")]}),
    ("She's allergic to peanuts, dairy, and fish.", {"entities": [(14, 21, "ALLERGY"), (23, 28, "ALLERGY"), (33, 37, "ALLERGY")]}),
    ("He's allergic to wheat gluten, soy, and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 33, "ALLERGY"), (38, 45, "ALLERGY")]}),
    ("I have allergies to shellfish, sesame seeds, and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 39, "ALLERGY"), (44, 53, "ALLERGY")]}),
    ("She's allergic to fish, soy, and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 26, "ALLERGY"), (31, 42, "ALLERGY")]}),
    ("He's allergic to peanuts, eggs, and sesame seeds.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 43, "ALLERGY")]}),
    ("I have allergies to shellfish, dairy, and soy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY"), (37, 40, "ALLERGY")]}),
    ("She's allergic to wheat gluten, tree nuts, and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 48, "ALLERGY")]}),
    ("He's allergic to peanuts, sesame seeds, and eggs.", {"entities": [(14, 21, "ALLERGY"), (23, 34, "ALLERGY"), (39, 43, "ALLERGY")]}),
    ("I have allergies to soy, dairy, and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 27, "ALLERGY"), (32, 41, "ALLERGY")]}),
    ("She's allergic to fish, peanuts, and dairy.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY"), (35, 39, "ALLERGY")]}),
    ("He's allergic to wheat gluten, soy, and tree nuts.", {"entities": [(14, 25, "ALLERGY"), (30, 33, "ALLERGY"), (38, 47, "ALLERGY")]}),
    ("I have allergies to sesame seeds, dairy, and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY"), (40, 43, "ALLERGY")]}),
    ("She's allergic to peanuts, fish, and wheat gluten.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 43, "ALLERGY")]}),
    ("He's allergic to soy, tree nuts, and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY"), (36, 45, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and soy.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("She's allergic to wheat gluten, sesame seeds, and tree nuts.", {"entities": [(14, 25, "ALLERGY"), (30, 41, "ALLERGY"), (46, 55, "ALLERGY")]}),
    ("He's allergic to peanuts, fish, and soy.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 35, "ALLERGY")]}),
    ("I have allergies to shellfish, dairy, and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("She's allergic to soy, peanuts, and fish.", {"entities": [(14, 17, "ALLERGY"), (22, 29, "ALLERGY"), (34, 38, "ALLERGY")]}),
    ("He's allergic to wheat gluten, shellfish, and dairy.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 49, "ALLERGY")]}),
    ("I have allergies to sesame seeds, tree nuts, and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 47, "ALLERGY")]}),
    ("She's allergic to peanuts, dairy, and fish.", {"entities": [(14, 21, "ALLERGY"), (23, 28, "ALLERGY"), (33, 37, "ALLERGY")]}),
    ("He's allergic to wheat gluten, soy, and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 33, "ALLERGY"), (38, 45, "ALLERGY")]}),
    ("I have allergies to shellfish, sesame seeds, and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 39, "ALLERGY"), (44, 53, "ALLERGY")]}),
    ("She's allergic to fish, soy, and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 26, "ALLERGY"), (31, 42, "ALLERGY")]}),
    ("He's allergic to peanuts, eggs, and sesame seeds.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 43, "ALLERGY")]}),
    ("I have allergies to shellfish, dairy, and soy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY"), (37, 40, "ALLERGY")]}),
    ("She's allergic to wheat gluten, tree nuts, and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 48, "ALLERGY")]}),
    ("He's allergic to peanuts, sesame seeds, and eggs.", {"entities": [(14, 21, "ALLERGY"), (23, 34, "ALLERGY"), (39, 43, "ALLERGY")]}),
    ("I have allergies to soy, dairy, and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 27, "ALLERGY"), (32, 41, "ALLERGY")]}),
    ("She's allergic to fish, peanuts, and dairy.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY"), (35, 39, "ALLERGY")]}),
    ("He's allergic to wheat gluten, soy, and tree nuts.", {"entities": [(14, 25, "ALLERGY"), (30, 33, "ALLERGY"), (38, 47, "ALLERGY")]}),
    ("I have allergies to sesame seeds, dairy, and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY"), (40, 43, "ALLERGY")]}),
    ("She's allergic to peanuts, fish, and wheat gluten.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 43, "ALLERGY")]}),
    ("He's allergic to soy, tree nuts, and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY"), (36, 45, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and soy.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("She's allergic to wheat gluten, sesame seeds, and tree nuts.", {"entities": [(14, 25, "ALLERGY"), (30, 41, "ALLERGY"), (46, 55, "ALLERGY")]}),
    ("He's allergic to peanuts, fish, and soy.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 35, "ALLERGY")]}),
    ("I have allergies to shellfish, dairy, and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("She's allergic to soy, peanuts, and fish.", {"entities": [(14, 17, "ALLERGY"), (22, 29, "ALLERGY"), (34, 38, "ALLERGY")]}),
    ("He's allergic to wheat gluten, shellfish, and dairy.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 49, "ALLERGY")]}),
    ("I have allergies to sesame seeds, tree nuts, and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 47, "ALLERGY")]}),
    ("She's allergic to peanuts, dairy, and fish.", {"entities": [(14, 21, "ALLERGY"), (23, 28, "ALLERGY"), (33, 37, "ALLERGY")]}),
    ("He's allergic to wheat gluten, soy, and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 33, "ALLERGY"), (38, 45, "ALLERGY")]}),
    ("I have allergies to shellfish, sesame seeds, and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 39, "ALLERGY"), (44, 53, "ALLERGY")]}),
    ("She's allergic to fish, soy, and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 26, "ALLERGY"), (31, 42, "ALLERGY")]}),
    ("He's allergic to peanuts, eggs, and sesame seeds.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 43, "ALLERGY")]}),
    ("I have allergies to shellfish, dairy, and soy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY"), (37, 40, "ALLERGY")]}),
    ("She's allergic to wheat gluten, tree nuts, and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 48, "ALLERGY")]}),
    ("He's allergic to peanuts, sesame seeds, and eggs.", {"entities": [(14, 21, "ALLERGY"), (23, 34, "ALLERGY"), (39, 43, "ALLERGY")]}),
    ("I have allergies to soy, dairy, and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 27, "ALLERGY"), (32, 41, "ALLERGY")]}),
    ("She's allergic to fish, peanuts, and dairy.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY"), (35, 39, "ALLERGY")]}),
    ("He's allergic to wheat gluten, soy, and tree nuts.", {"entities": [(14, 25, "ALLERGY"), (30, 33, "ALLERGY"), (38, 47, "ALLERGY")]}),
    ("I have allergies to sesame seeds, dairy, and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY"), (40, 43, "ALLERGY")]}),
    ("She's allergic to peanuts, fish, and wheat gluten.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 43, "ALLERGY")]}),
    ("He's allergic to soy, tree nuts, and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY"), (36, 45, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and soy.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("She's allergic to wheat gluten, sesame seeds, and tree nuts.", {"entities": [(14, 25, "ALLERGY"), (30, 41, "ALLERGY"), (46, 55, "ALLERGY")]}),
    ("He's allergic to peanuts, fish, and soy.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 35, "ALLERGY")]}),
    ("I have allergies to shellfish, dairy, and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("She's allergic to soy, peanuts, and fish.", {"entities": [(14, 17, "ALLERGY"), (22, 29, "ALLERGY"), (34, 38, "ALLERGY")]}),
    ("He's allergic to wheat gluten, shellfish, and dairy.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 49, "ALLERGY")]}),
    ("I have allergies to sesame seeds, tree nuts, and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 47, "ALLERGY")]}),
    ("She's allergic to peanuts, dairy, and fish.", {"entities": [(14, 21, "ALLERGY"), (23, 28, "ALLERGY"), (33, 37, "ALLERGY")]}),
    ("He's allergic to wheat gluten, soy, and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 33, "ALLERGY"), (38, 45, "ALLERGY")]}),
    ("I have allergies to shellfish, sesame seeds, and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 39, "ALLERGY"), (44, 53, "ALLERGY")]}),
    ("She's allergic to fish, soy, and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 26, "ALLERGY"), (31, 42, "ALLERGY")]}),
    ("He's allergic to peanuts, eggs, and sesame seeds.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 43, "ALLERGY")]}),
    ("I have allergies to shellfish, dairy, and soy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY"), (37, 40, "ALLERGY")]}),
    ("She's allergic to wheat gluten, tree nuts, and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 48, "ALLERGY")]}),
    ("He's allergic to peanuts, sesame seeds, and eggs.", {"entities": [(14, 21, "ALLERGY"), (23, 34, "ALLERGY"), (39, 43, "ALLERGY")]}),
    ("I have allergies to soy, dairy, and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 27, "ALLERGY"), (32, 41, "ALLERGY")]}),
    ("She's allergic to fish, peanuts, and dairy.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY"), (35, 39, "ALLERGY")]}),
    ("He's allergic to wheat gluten, soy, and tree nuts.", {"entities": [(14, 25, "ALLERGY"), (30, 33, "ALLERGY"), (38, 47, "ALLERGY")]}),
    ("I have allergies to sesame seeds, dairy, and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY"), (40, 43, "ALLERGY")]}),
    ("She's allergic to peanuts, fish, and wheat gluten.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 43, "ALLERGY")]}),
    ("He's allergic to soy, tree nuts, and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY"), (36, 45, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and soy.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("She's allergic to wheat gluten, sesame seeds, and tree nuts.", {"entities": [(14, 25, "ALLERGY"), (30, 41, "ALLERGY"), (46, 55, "ALLERGY")]}),
    ("He's allergic to peanuts, fish, and soy.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 35, "ALLERGY")]}),
    ("I have allergies to shellfish, dairy, and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("She's allergic to soy, peanuts, and fish.", {"entities": [(14, 17, "ALLERGY"), (22, 29, "ALLERGY"), (34, 38, "ALLERGY")]}),
    ("He's allergic to wheat gluten, shellfish, and dairy.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 49, "ALLERGY")]}),
    ("I have allergies to sesame seeds, tree nuts, and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 47, "ALLERGY")]}),
    ("She's allergic to peanuts, dairy, and fish.", {"entities": [(14, 21, "ALLERGY"), (23, 28, "ALLERGY"), (33, 37, "ALLERGY")]}),
    ("He's allergic to wheat gluten, soy, and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 33, "ALLERGY"), (38, 45, "ALLERGY")]}),
    ("I have allergies to shellfish, sesame seeds, and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 39, "ALLERGY"), (44, 53, "ALLERGY")]}),
    ("She's allergic to fish, soy, and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 26, "ALLERGY"), (31, 42, "ALLERGY")]}),
    ("He's allergic to peanuts, eggs, and sesame seeds.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 43, "ALLERGY")]}),
    ("I have allergies to shellfish, dairy, and soy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY"), (37, 40, "ALLERGY")]}),
    ("She's allergic to wheat gluten, tree nuts, and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 48, "ALLERGY")]}),
    ("He's allergic to peanuts, sesame seeds, and eggs.", {"entities": [(14, 21, "ALLERGY"), (23, 34, "ALLERGY"), (39, 43, "ALLERGY")]}),
    ("I have allergies to soy, dairy, and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 27, "ALLERGY"), (32, 41, "ALLERGY")]}),
    ("She's allergic to fish, peanuts, and dairy.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY"), (35, 39, "ALLERGY")]}),
    ("He's allergic to wheat gluten, soy, and tree nuts.", {"entities": [(14, 25, "ALLERGY"), (30, 33, "ALLERGY"), (38, 47, "ALLERGY")]}),
    ("I have allergies to sesame seeds, dairy, and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY"), (40, 43, "ALLERGY")]}),
    ("She's allergic to peanuts, fish, and wheat gluten.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 43, "ALLERGY")]}),
    ("He's allergic to soy, tree nuts, and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY"), (36, 45, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and soy.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("She's allergic to wheat gluten, sesame seeds, and tree nuts.", {"entities": [(14, 25, "ALLERGY"), (30, 41, "ALLERGY"), (46, 55, "ALLERGY")]}),
    ("He's allergic to peanuts, fish, and soy.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 35, "ALLERGY")]}),
    ("I have allergies to shellfish, dairy, and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("She's allergic to soy, peanuts, and fish.", {"entities": [(14, 17, "ALLERGY"), (22, 29, "ALLERGY"), (34, 38, "ALLERGY")]}),
    ("He's allergic to wheat gluten, shellfish, and dairy.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 49, "ALLERGY")]}),
    ("I have allergies to sesame seeds, tree nuts, and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 47, "ALLERGY")]}),
    ("She's allergic to peanuts, dairy, and fish.", {"entities": [(14, 21, "ALLERGY"), (23, 28, "ALLERGY"), (33, 37, "ALLERGY")]}),
    ("He's allergic to wheat gluten, soy, and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 33, "ALLERGY"), (38, 45, "ALLERGY")]}),
    ("I have allergies to shellfish, sesame seeds, and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 39, "ALLERGY"), (44, 53, "ALLERGY")]}),
    ("She's allergic to fish, soy, and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 26, "ALLERGY"), (31, 42, "ALLERGY")]}),
    ("He's allergic to peanuts, eggs, and sesame seeds.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 43, "ALLERGY")]}),
    ("I have allergies to shellfish, dairy, and soy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY"), (37, 40, "ALLERGY")]}),
    ("She's allergic to wheat gluten, tree nuts, and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 48, "ALLERGY")]}),
    ("He's allergic to peanuts, sesame seeds, and eggs.", {"entities": [(14, 21, "ALLERGY"), (23, 34, "ALLERGY"), (39, 43, "ALLERGY")]}),
    ("I have allergies to soy, dairy, and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 27, "ALLERGY"), (32, 41, "ALLERGY")]}),
    ("She's allergic to fish, peanuts, and dairy.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY"), (35, 39, "ALLERGY")]}),
    ("He's allergic to wheat gluten, soy, and tree nuts.", {"entities": [(14, 25, "ALLERGY"), (30, 33, "ALLERGY"), (38, 47, "ALLERGY")]}),
    ("I have allergies to sesame seeds, dairy, and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY"), (40, 43, "ALLERGY")]}),
    ("She's allergic to peanuts, fish, and wheat gluten.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 43, "ALLERGY")]}),
    ("He's allergic to soy, tree nuts, and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY"), (36, 45, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and soy.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("She's allergic to wheat gluten, sesame seeds, and tree nuts.", {"entities": [(14, 25, "ALLERGY"), (30, 41, "ALLERGY"), (46, 55, "ALLERGY")]}),
    ("He's allergic to peanuts, fish, and soy.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 35, "ALLERGY")]}),
    ("I have allergies to shellfish, dairy, and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("She's allergic to soy, peanuts, and fish.", {"entities": [(14, 17, "ALLERGY"), (22, 29, "ALLERGY"), (34, 38, "ALLERGY")]}),
    ("He's allergic to wheat gluten, shellfish, and dairy.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 49, "ALLERGY")]}),
    ("I have allergies to sesame seeds, tree nuts, and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 47, "ALLERGY")]}),
    ("She's allergic to peanuts, dairy, and fish.", {"entities": [(14, 21, "ALLERGY"), (23, 28, "ALLERGY"), (33, 37, "ALLERGY")]}),
    ("He's allergic to wheat gluten, soy, and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 33, "ALLERGY"), (38, 45, "ALLERGY")]}),
    ("I have allergies to shellfish, sesame seeds, and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 39, "ALLERGY"), (44, 53, "ALLERGY")]}),
    ("She's allergic to fish, soy, and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 26, "ALLERGY"), (31, 42, "ALLERGY")]}),
    ("He's allergic to peanuts, eggs, and sesame seeds.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 43, "ALLERGY")]}),
    ("I have allergies to shellfish, dairy, and soy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY"), (37, 40, "ALLERGY")]}),
    ("She's allergic to wheat gluten, tree nuts, and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 48, "ALLERGY")]}),
    ("He's allergic to peanuts, sesame seeds, and eggs.", {"entities": [(14, 21, "ALLERGY"), (23, 34, "ALLERGY"), (39, 43, "ALLERGY")]}),
    ("I have allergies to soy, dairy, and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 27, "ALLERGY"), (32, 41, "ALLERGY")]}),
    ("She's allergic to fish, peanuts, and dairy.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY"), (35, 39, "ALLERGY")]}),
    ("He's allergic to wheat gluten, soy, and tree nuts.", {"entities": [(14, 25, "ALLERGY"), (30, 33, "ALLERGY"), (38, 47, "ALLERGY")]}),
    ("I have allergies to sesame seeds, dairy, and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY"), (40, 43, "ALLERGY")]}),
    ("She's allergic to peanuts, fish, and wheat gluten.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 43, "ALLERGY")]}),
    ("He's allergic to soy, tree nuts, and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY"), (36, 45, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and soy.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("She's allergic to wheat gluten, sesame seeds, and tree nuts.", {"entities": [(14, 25, "ALLERGY"), (30, 41, "ALLERGY"), (46, 55, "ALLERGY")]}),
    ("He's allergic to peanuts, fish, and soy.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 35, "ALLERGY")]}),
    ("I have allergies to shellfish, dairy, and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("She's allergic to soy, peanuts, and fish.", {"entities": [(14, 17, "ALLERGY"), (22, 29, "ALLERGY"), (34, 38, "ALLERGY")]}),
    ("He's allergic to wheat gluten, shellfish, and dairy.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 49, "ALLERGY")]}),
    ("I have allergies to sesame seeds, tree nuts, and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 47, "ALLERGY")]}),
    ("She's allergic to peanuts, dairy, and fish.", {"entities": [(14, 21, "ALLERGY"), (23, 28, "ALLERGY"), (33, 37, "ALLERGY")]}),
    ("He's allergic to wheat gluten, soy, and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 33, "ALLERGY"), (38, 45, "ALLERGY")]}),
    ("I have allergies to shellfish, sesame seeds, and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 39, "ALLERGY"), (44, 53, "ALLERGY")]}),
    ("She's allergic to fish, soy, and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 26, "ALLERGY"), (31, 42, "ALLERGY")]}),
    ("He's allergic to peanuts, eggs, and sesame seeds.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 43, "ALLERGY")]}),
    ("I have allergies to shellfish, dairy, and soy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY"), (37, 40, "ALLERGY")]}),
    ("She's allergic to wheat gluten, tree nuts, and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 48, "ALLERGY")]}),
    ("He's allergic to peanuts, sesame seeds, and eggs.", {"entities": [(14, 21, "ALLERGY"), (23, 34, "ALLERGY"), (39, 43, "ALLERGY")]}),
    ("I have allergies to soy, dairy, and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 27, "ALLERGY"), (32, 41, "ALLERGY")]}),
    ("She's allergic to fish, peanuts, and dairy.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY"), (35, 39, "ALLERGY")]}),
    ("He's allergic to wheat gluten, soy, and tree nuts.", {"entities": [(14, 25, "ALLERGY"), (30, 33, "ALLERGY"), (38, 47, "ALLERGY")]}),
    ("I have allergies to sesame seeds, dairy, and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY"), (40, 43, "ALLERGY")]}),
    ("She's allergic to peanuts, fish, and wheat gluten.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 43, "ALLERGY")]}),
    ("He's allergic to soy, tree nuts, and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY"), (36, 45, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and soy.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("She's allergic to wheat gluten, sesame seeds, and tree nuts.", {"entities": [(14, 25, "ALLERGY"), (30, 41, "ALLERGY"), (46, 55, "ALLERGY")]}),
    ("He's allergic to peanuts, fish, and soy.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 35, "ALLERGY")]}),
    ("I have allergies to shellfish, dairy, and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("She's allergic to soy, peanuts, and fish.", {"entities": [(14, 17, "ALLERGY"), (22, 29, "ALLERGY"), (34, 38, "ALLERGY")]}),
    ("He's allergic to wheat gluten, shellfish, and dairy.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 49, "ALLERGY")]}),
    ("I have allergies to sesame seeds, tree nuts, and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 47, "ALLERGY")]}),
    ("She's allergic to peanuts, dairy, and fish.", {"entities": [(14, 21, "ALLERGY"), (23, 28, "ALLERGY"), (33, 37, "ALLERGY")]}),
    ("He's allergic to wheat gluten, soy, and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 33, "ALLERGY"), (38, 45, "ALLERGY")]}),
    ("I have allergies to shellfish, sesame seeds, and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 39, "ALLERGY"), (44, 53, "ALLERGY")]}),
    ("She's allergic to fish, soy, and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 26, "ALLERGY"), (31, 42, "ALLERGY")]}),
    ("He's allergic to peanuts, eggs, and sesame seeds.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 43, "ALLERGY")]}),
    ("I have allergies to shellfish, dairy, and soy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY"), (37, 40, "ALLERGY")]}),
    ("She's allergic to wheat gluten, tree nuts, and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 48, "ALLERGY")]}),
    ("He's allergic to peanuts, sesame seeds, and eggs.", {"entities": [(14, 21, "ALLERGY"), (23, 34, "ALLERGY"), (39, 43, "ALLERGY")]}),
    ("I have allergies to soy, dairy, and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 27, "ALLERGY"), (32, 41, "ALLERGY")]}),
    ("She's allergic to fish, peanuts, and dairy.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY"), (35, 39, "ALLERGY")]}),
    ("He's allergic to wheat gluten, soy, and tree nuts.", {"entities": [(14, 25, "ALLERGY"), (30, 33, "ALLERGY"), (38, 47, "ALLERGY")]}),
    ("I have allergies to sesame seeds, dairy, and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY"), (40, 43, "ALLERGY")]}),
    ("She's allergic to peanuts, fish, and wheat gluten.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 43, "ALLERGY")]}),
    ("He's allergic to soy, tree nuts, and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY"), (36, 45, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and soy.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("She's allergic to wheat gluten, sesame seeds, and tree nuts.", {"entities": [(14, 25, "ALLERGY"), (30, 41, "ALLERGY"), (46, 55, "ALLERGY")]}),
    ("He's allergic to peanuts, fish, and soy.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 35, "ALLERGY")]}),
    ("I have allergies to shellfish, dairy, and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("She's allergic to soy, peanuts, and fish.", {"entities": [(14, 17, "ALLERGY"), (22, 29, "ALLERGY"), (34, 38, "ALLERGY")]}),
    ("He's allergic to wheat gluten, shellfish, and dairy.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 49, "ALLERGY")]}),
    ("I have allergies to sesame seeds, tree nuts, and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 47, "ALLERGY")]}),
    ("She's allergic to peanuts, dairy, and fish.", {"entities": [(14, 21, "ALLERGY"), (23, 28, "ALLERGY"), (33, 37, "ALLERGY")]}),
    ("He's allergic to wheat gluten, soy, and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 33, "ALLERGY"), (38, 45, "ALLERGY")]}),
    ("I have allergies to shellfish, sesame seeds, and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 39, "ALLERGY"), (44, 53, "ALLERGY")]}),
    ("She's allergic to fish, soy, and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 26, "ALLERGY"), (31, 42, "ALLERGY")]}),
    ("He's allergic to peanuts, eggs, and sesame seeds.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 43, "ALLERGY")]}),
    ("I have allergies to shellfish, dairy, and soy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY"), (37, 40, "ALLERGY")]}),
    ("She's allergic to wheat gluten, tree nuts, and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 48, "ALLERGY")]}),
    ("He's allergic to peanuts, sesame seeds, and eggs.", {"entities": [(14, 21, "ALLERGY"), (23, 34, "ALLERGY"), (39, 43, "ALLERGY")]}),
    ("I have allergies to soy, dairy, and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 27, "ALLERGY"), (32, 41, "ALLERGY")]}),
    ("She's allergic to fish, peanuts, and dairy.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY"), (35, 39, "ALLERGY")]}),
    ("He's allergic to wheat gluten, soy, and tree nuts.", {"entities": [(14, 25, "ALLERGY"), (30, 33, "ALLERGY"), (38, 47, "ALLERGY")]}),
    ("I have allergies to sesame seeds, dairy, and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY"), (40, 43, "ALLERGY")]}),
    ("She's allergic to peanuts, fish, and wheat gluten.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 43, "ALLERGY")]}),
    ("He's allergic to soy, tree nuts, and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY"), (36, 45, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and soy.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("She's allergic to wheat gluten, sesame seeds, and tree nuts.", {"entities": [(14, 25, "ALLERGY"), (30, 41, "ALLERGY"), (46, 55, "ALLERGY")]}),
    ("He's allergic to peanuts, fish, and soy.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 35, "ALLERGY")]}),
    ("I have allergies to shellfish, dairy, and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("She's allergic to soy, peanuts, and fish.", {"entities": [(14, 17, "ALLERGY"), (22, 29, "ALLERGY"), (34, 38, "ALLERGY")]}),
    ("He's allergic to wheat gluten, shellfish, and dairy.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY"), (44, 49, "ALLERGY")]}),
    ("She's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("He's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("I have allergies to dairy.", {"entities": [(14, 18, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I'm allergic to wheat gluten.", {"entities": [(16, 27, "ALLERGY")]}),
    ("She's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("I have allergies to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("I have allergies to dairy.", {"entities": [(14, 18, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I'm allergic to wheat gluten.", {"entities": [(16, 27, "ALLERGY")]}),
    ("She's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("I have allergies to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("I have allergies to dairy.", {"entities": [(14, 18, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I'm allergic to wheat gluten.", {"entities": [(16, 27, "ALLERGY")]}),
    ("She's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("I have allergies to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("I have allergies to dairy.", {"entities": [(14, 18, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I'm allergic to wheat gluten.", {"entities": [(16, 27, "ALLERGY")]}),
    ("She's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("I have allergies to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("I have allergies to dairy.", {"entities": [(14, 18, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I'm allergic to wheat gluten.", {"entities": [(16, 27, "ALLERGY")]}),
    ("She's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("I have allergies to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("I have allergies to dairy.", {"entities": [(14, 18, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I'm allergic to wheat gluten.", {"entities": [(16, 27, "ALLERGY")]}),
    ("She's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("I have allergies to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("I have allergies to dairy.", {"entities": [(14, 18, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I'm allergic to wheat gluten.", {"entities": [(16, 27, "ALLERGY")]}),
    ("She's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("I have allergies to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("I have allergies to dairy.", {"entities": [(14, 18, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I'm allergic to wheat gluten.", {"entities": [(16, 27, "ALLERGY")]}),
    ("She's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("I have allergies to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("I have allergies to dairy.", {"entities": [(14, 18, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I'm allergic to wheat gluten.", {"entities": [(16, 27, "ALLERGY")]}),
    ("She's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("I have allergies to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("I have allergies to dairy.", {"entities": [(14, 18, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I'm allergic to wheat gluten.", {"entities": [(16, 27, "ALLERGY")]}),
    ("She's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("I have allergies to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("I have allergies to dairy.", {"entities": [(14, 18, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I'm allergic to wheat gluten.", {"entities": [(16, 27, "ALLERGY")]}),
    ("She's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("I have allergies to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("I have allergies to dairy.", {"entities": [(14, 18, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I'm allergic to wheat gluten.", {"entities": [(16, 27, "ALLERGY")]}),
    ("She's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("I have allergies to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("I have allergies to dairy.", {"entities": [(14, 18, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I'm allergic to wheat gluten.", {"entities": [(16, 27, "ALLERGY")]}),
    ("She's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts and shellfish.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("She's allergic to soy and wheat gluten.", {"entities": [(14, 17, "ALLERGY"), (22, 32, "ALLERGY")]}),
    ("He's allergic to dairy and eggs.", {"entities": [(14, 19, "ALLERGY"), (24, 28, "ALLERGY")]}),
    ("I have allergies to tree nuts and sesame seeds.", {"entities": [(14, 23, "ALLERGY"), (28, 39, "ALLERGY")]}),
    ("She's allergic to fish and shellfish.", {"entities": [(14, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("He's allergic to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I have allergies to wheat gluten and soy.", {"entities": [(14, 24, "ALLERGY"), (29, 32, "ALLERGY")]}),
    ("She's allergic to eggs and dairy.", {"entities": [(14, 18, "ALLERGY"), (23, 27, "ALLERGY")]}),
    ("He's allergic to sesame seeds and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 36, "ALLERGY")]}),
    ("I have allergies to shellfish and wheat gluten.", {"entities": [(14, 23, "ALLERGY"), (28, 39, "ALLERGY")]}),
    ("She's allergic to tree nuts and fish.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("He's allergic to soy and dairy.", {"entities": [(14, 17, "ALLERGY"), (22, 26, "ALLERGY")]}),
    ("I have allergies to peanuts and eggs.", {"entities": [(14, 21, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("She's allergic to wheat gluten and shellfish.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY")]}),
    ("He's allergic to sesame seeds and tree nuts.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY")]}),
    ("I have allergies to soy and fish.", {"entities": [(14, 17, "ALLERGY"), (22, 26, "ALLERGY")]}),
    ("She's allergic to dairy and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY")]}),
    ("He's allergic to shellfish and wheat gluten.", {"entities": [(14, 23, "ALLERGY"), (28, 39, "ALLERGY")]}),
    ("I have allergies to eggs and sesame seeds.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to tree nuts and soy.", {"entities": [(14, 23, "ALLERGY"), (28, 31, "ALLERGY")]}),
    ("He's allergic to fish and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 29, "ALLERGY")]}),
    ("I have allergies to wheat gluten and dairy.", {"entities": [(14, 25, "ALLERGY"), (30, 34, "ALLERGY")]}),
    ("She's allergic to shellfish and sesame seeds.", {"entities": [(14, 23, "ALLERGY"), (28, 39, "ALLERGY")]}),
    ("He's allergic to soy and tree nuts.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("I have allergies to peanuts and fish.", {"entities": [(14, 21, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("She's allergic to dairy and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("He's allergic to sesame seeds and shellfish.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY")]}),
    ("I have allergies to tree nuts and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("She's allergic to soy and peanuts.", {"entities": [(14, 17, "ALLERGY"), (22, 29, "ALLERGY")]}),
    ("He's allergic to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("I have allergies to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("She's allergic to sesame seeds and tree nuts.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY")]}),
    ("He's allergic to soy and eggs.", {"entities": [(14, 17, "ALLERGY"), (22, 26, "ALLERGY")]}),
    ("I have allergies to peanuts and shellfish.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("She's allergic to wheat gluten and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 32, "ALLERGY")]}),
    ("He's allergic to dairy and tree nuts.", {"entities": [(14, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("I have allergies to eggs and fish.", {"entities": [(14, 18, "ALLERGY"), (23, 27, "ALLERGY")]}),
    ("She's allergic to shellfish and peanuts.", {"entities": [(14, 23, "ALLERGY"), (28, 35, "ALLERGY")]}),
    ("He's allergic to wheat gluten and sesame seeds.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY")]}),
    ("I have allergies to soy and dairy.", {"entities": [(14, 17, "ALLERGY"), (22, 26, "ALLERGY")]}),
    ("She's allergic to tree nuts and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("He's allergic to peanuts and fish.", {"entities": [(14, 21, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("I have allergies to sesame seeds and wheat gluten.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY")]}),
    ("She's allergic to soy and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("He's allergic to dairy and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY")]}),
    ("I have allergies to eggs and tree nuts.", {"entities": [(14, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("She's allergic to wheat gluten and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 34, "ALLERGY")]}),
    ("He's allergic to sesame seeds and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 32, "ALLERGY")]}),
    ("I have allergies to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("She's allergic to tree nuts and peanuts.", {"entities": [(14, 23, "ALLERGY"), (28, 35, "ALLERGY")]}),
    ("He's allergic to soy and wheat gluten.", {"entities": [(14, 17, "ALLERGY"), (22, 32, "ALLERGY")]}),
    ("I have allergies to dairy and shellfish.", {"entities": [(14, 18, "ALLERGY"), (23, 31, "ALLERGY")]}),
    ("She's allergic to eggs and sesame seeds.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("He's allergic to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and dairy.", {"entities": [(14, 17, "ALLERGY"), (22, 26, "ALLERGY")]}),
    ("He's allergic to shellfish and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 30, "ALLERGY")]}),
    ("I have allergies to sesame seeds and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 36, "ALLERGY")]}),
    ("She's allergic to wheat gluten and shellfish.", {"entities": [(14, 25, "ALLERGY"), (30, 31, "ALLERGY")]}),
    ("He's allergic to soy and tree nuts.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("I have allergies to dairy and fish.", {"entities": [(14, 18, "ALLERGY"), (23, 27, "ALLERGY")]}),
    ("She's allergic to eggs and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 29, "ALLERGY")]}),
    ("He's allergic to wheat gluten and sesame seeds.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY")]}),
    ("I have allergies to soy and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("She's allergic to dairy and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY")]}),
    ("He's allergic to tree nuts and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and sesame seeds.", {"entities": [(14, 17, "ALLERGY"), (22, 25, "ALLERGY")]}),
    ("He's allergic to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("She's allergic to wheat gluten and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 34, "ALLERGY")]}),
    ("He's allergic to sesame seeds and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 32, "ALLERGY")]}),
    ("I have allergies to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("She's allergic to tree nuts and peanuts.", {"entities": [(14, 23, "ALLERGY"), (28, 35, "ALLERGY")]}),
    ("He's allergic to soy and wheat gluten.", {"entities": [(14, 17, "ALLERGY"), (22, 32, "ALLERGY")]}),
    ("I have allergies to dairy and shellfish.", {"entities": [(14, 18, "ALLERGY"), (23, 31, "ALLERGY")]}),
    ("She's allergic to eggs and sesame seeds.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("He's allergic to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and dairy.", {"entities": [(14, 17, "ALLERGY"), (22, 26, "ALLERGY")]}),
    ("He's allergic to shellfish and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 30, "ALLERGY")]}),
    ("I have allergies to sesame seeds and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 36, "ALLERGY")]}),
    ("She's allergic to wheat gluten and shellfish.", {"entities": [(14, 25, "ALLERGY"), (30, 31, "ALLERGY")]}),
    ("He's allergic to soy and tree nuts.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("I have allergies to dairy and fish.", {"entities": [(14, 18, "ALLERGY"), (23, 27, "ALLERGY")]}),
    ("She's allergic to eggs and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 29, "ALLERGY")]}),
    ("He's allergic to wheat gluten and sesame seeds.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY")]}),
    ("I have allergies to soy and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("She's allergic to dairy and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY")]}),
    ("He's allergic to tree nuts and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and sesame seeds.", {"entities": [(14, 17, "ALLERGY"), (22, 25, "ALLERGY")]}),
    ("He's allergic to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("She's allergic to wheat gluten and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 34, "ALLERGY")]}),
    ("He's allergic to sesame seeds and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 32, "ALLERGY")]}),
    ("I have allergies to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("She's allergic to tree nuts and peanuts.", {"entities": [(14, 23, "ALLERGY"), (28, 35, "ALLERGY")]}),
    ("He's allergic to soy and wheat gluten.", {"entities": [(14, 17, "ALLERGY"), (22, 32, "ALLERGY")]}),
    ("I have allergies to dairy and shellfish.", {"entities": [(14, 18, "ALLERGY"), (23, 31, "ALLERGY")]}),
    ("She's allergic to eggs and sesame seeds.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("He's allergic to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and dairy.", {"entities": [(14, 17, "ALLERGY"), (22, 26, "ALLERGY")]}),
    ("He's allergic to shellfish and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 30, "ALLERGY")]}),
    ("I have allergies to sesame seeds and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 36, "ALLERGY")]}),
    ("She's allergic to wheat gluten and shellfish.", {"entities": [(14, 25, "ALLERGY"), (30, 31, "ALLERGY")]}),
    ("He's allergic to soy and tree nuts.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("I have allergies to dairy and fish.", {"entities": [(14, 18, "ALLERGY"), (23, 27, "ALLERGY")]}),
    ("She's allergic to eggs and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 29, "ALLERGY")]}),
    ("He's allergic to wheat gluten and sesame seeds.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY")]}),
    ("I have allergies to soy and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("She's allergic to dairy and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY")]}),
    ("He's allergic to tree nuts and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and sesame seeds.", {"entities": [(14, 17, "ALLERGY"), (22, 25, "ALLERGY")]}),
    ("He's allergic to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("She's allergic to wheat gluten and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 34, "ALLERGY")]}),
    ("He's allergic to sesame seeds and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 32, "ALLERGY")]}),
    ("I have allergies to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("She's allergic to tree nuts and peanuts.", {"entities": [(14, 23, "ALLERGY"), (28, 35, "ALLERGY")]}),
    ("He's allergic to soy and wheat gluten.", {"entities": [(14, 17, "ALLERGY"), (22, 32, "ALLERGY")]}),
    ("I have allergies to dairy and shellfish.", {"entities": [(14, 18, "ALLERGY"), (23, 31, "ALLERGY")]}),
    ("She's allergic to eggs and sesame seeds.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("He's allergic to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and dairy.", {"entities": [(14, 17, "ALLERGY"), (22, 26, "ALLERGY")]}),
    ("He's allergic to shellfish and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 30, "ALLERGY")]}),
    ("I have allergies to sesame seeds and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 36, "ALLERGY")]}),
    ("She's allergic to wheat gluten and shellfish.", {"entities": [(14, 25, "ALLERGY"), (30, 31, "ALLERGY")]}),
    ("He's allergic to soy and tree nuts.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("I have allergies to dairy and fish.", {"entities": [(14, 18, "ALLERGY"), (23, 27, "ALLERGY")]}),
    ("She's allergic to eggs and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 29, "ALLERGY")]}),
    ("He's allergic to wheat gluten and sesame seeds.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY")]}),
    ("I have allergies to soy and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("She's allergic to dairy and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY")]}),
    ("He's allergic to tree nuts and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and sesame seeds.", {"entities": [(14, 17, "ALLERGY"), (22, 25, "ALLERGY")]}),
    ("He's allergic to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("She's allergic to wheat gluten and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 34, "ALLERGY")]}),
    ("He's allergic to sesame seeds and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 32, "ALLERGY")]}),
    ("I have allergies to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("She's allergic to tree nuts and peanuts.", {"entities": [(14, 23, "ALLERGY"), (28, 35, "ALLERGY")]}),
    ("He's allergic to soy and wheat gluten.", {"entities": [(14, 17, "ALLERGY"), (22, 32, "ALLERGY")]}),
    ("I have allergies to dairy and shellfish.", {"entities": [(14, 18, "ALLERGY"), (23, 31, "ALLERGY")]}),
    ("She's allergic to eggs and sesame seeds.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("He's allergic to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and dairy.", {"entities": [(14, 17, "ALLERGY"), (22, 26, "ALLERGY")]}),
    ("He's allergic to shellfish and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 30, "ALLERGY")]}),
    ("I have allergies to sesame seeds and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 36, "ALLERGY")]}),
    ("She's allergic to wheat gluten and shellfish.", {"entities": [(14, 25, "ALLERGY"), (30, 31, "ALLERGY")]}),
    ("He's allergic to soy and tree nuts.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("I have allergies to dairy and fish.", {"entities": [(14, 18, "ALLERGY"), (23, 27, "ALLERGY")]}),
    ("She's allergic to eggs and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 29, "ALLERGY")]}),
    ("He's allergic to wheat gluten and sesame seeds.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY")]}),
    ("I have allergies to soy and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("She's allergic to dairy and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY")]}),
    ("He's allergic to tree nuts and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and sesame seeds.", {"entities": [(14, 17, "ALLERGY"), (22, 25, "ALLERGY")]}),
    ("He's allergic to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("She's allergic to wheat gluten and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 34, "ALLERGY")]}),
    ("He's allergic to sesame seeds and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 32, "ALLERGY")]}),
    ("I have allergies to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("She's allergic to tree nuts and peanuts.", {"entities": [(14, 23, "ALLERGY"), (28, 35, "ALLERGY")]}),
    ("He's allergic to soy and wheat gluten.", {"entities": [(14, 17, "ALLERGY"), (22, 32, "ALLERGY")]}),
    ("I have allergies to dairy and shellfish.", {"entities": [(14, 18, "ALLERGY"), (23, 31, "ALLERGY")]}),
    ("She's allergic to eggs and sesame seeds.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("He's allergic to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and dairy.", {"entities": [(14, 17, "ALLERGY"), (22, 26, "ALLERGY")]}),
    ("He's allergic to shellfish and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 30, "ALLERGY")]}),
    ("I have allergies to sesame seeds and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 36, "ALLERGY")]}),
    ("She's allergic to wheat gluten and shellfish.", {"entities": [(14, 25, "ALLERGY"), (30, 31, "ALLERGY")]}),
    ("He's allergic to soy and tree nuts.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("I have allergies to dairy and fish.", {"entities": [(14, 18, "ALLERGY"), (23, 27, "ALLERGY")]}),
    ("She's allergic to eggs and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 29, "ALLERGY")]}),
    ("He's allergic to wheat gluten and sesame seeds.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY")]}),
    ("I have allergies to soy and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("She's allergic to dairy and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY")]}),
    ("He's allergic to tree nuts and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and sesame seeds.", {"entities": [(14, 17, "ALLERGY"), (22, 25, "ALLERGY")]}),
    ("He's allergic to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("She's allergic to wheat gluten and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 34, "ALLERGY")]}),
    ("He's allergic to sesame seeds and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 32, "ALLERGY")]}),
    ("I have allergies to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("She's allergic to tree nuts and peanuts.", {"entities": [(14, 23, "ALLERGY"), (28, 35, "ALLERGY")]}),
    ("He's allergic to soy and wheat gluten.", {"entities": [(14, 17, "ALLERGY"), (22, 32, "ALLERGY")]}),
    ("I have allergies to dairy and shellfish.", {"entities": [(14, 18, "ALLERGY"), (23, 31, "ALLERGY")]}),
    ("She's allergic to eggs and sesame seeds.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("He's allergic to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and dairy.", {"entities": [(14, 17, "ALLERGY"), (22, 26, "ALLERGY")]}),
    ("He's allergic to shellfish and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 30, "ALLERGY")]}),
    ("I have allergies to sesame seeds and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 36, "ALLERGY")]}),
    ("She's allergic to wheat gluten and shellfish.", {"entities": [(14, 25, "ALLERGY"), (30, 31, "ALLERGY")]}),
    ("He's allergic to soy and tree nuts.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("I have allergies to dairy and fish.", {"entities": [(14, 18, "ALLERGY"), (23, 27, "ALLERGY")]}),
    ("She's allergic to eggs and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 29, "ALLERGY")]}),
    ("He's allergic to wheat gluten and sesame seeds.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY")]}),
    ("I have allergies to soy and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("She's allergic to dairy and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY")]}),
    ("He's allergic to tree nuts and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and sesame seeds.", {"entities": [(14, 17, "ALLERGY"), (22, 25, "ALLERGY")]}),
    ("He's allergic to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("She's allergic to wheat gluten and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 34, "ALLERGY")]}),
    ("He's allergic to sesame seeds and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 32, "ALLERGY")]}),
    ("I have allergies to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("She's allergic to tree nuts and peanuts.", {"entities": [(14, 23, "ALLERGY"), (28, 35, "ALLERGY")]}),
    ("He's allergic to soy and wheat gluten.", {"entities": [(14, 17, "ALLERGY"), (22, 32, "ALLERGY")]}),
    ("I have allergies to dairy and shellfish.", {"entities": [(14, 18, "ALLERGY"), (23, 31, "ALLERGY")]}),
    ("She's allergic to eggs and sesame seeds.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("He's allergic to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and dairy.", {"entities": [(14, 17, "ALLERGY"), (22, 26, "ALLERGY")]}),
    ("He's allergic to shellfish and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 30, "ALLERGY")]}),
    ("I have allergies to sesame seeds and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 36, "ALLERGY")]}),
    ("She's allergic to wheat gluten and shellfish.", {"entities": [(14, 25, "ALLERGY"), (30, 31, "ALLERGY")]}),
    ("He's allergic to soy and tree nuts.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("I have allergies to dairy and fish.", {"entities": [(14, 18, "ALLERGY"), (23, 27, "ALLERGY")]}),
    ("She's allergic to eggs and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 29, "ALLERGY")]}),
    ("He's allergic to wheat gluten and sesame seeds.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY")]}),
    ("I have allergies to soy and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("She's allergic to dairy and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY")]}),
    ("He's allergic to tree nuts and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and sesame seeds.", {"entities": [(14, 17, "ALLERGY"), (22, 25, "ALLERGY")]}),
    ("He's allergic to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("She's allergic to wheat gluten and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 34, "ALLERGY")]}),
    ("He's allergic to sesame seeds and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 32, "ALLERGY")]}),
    ("I have allergies to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("She's allergic to tree nuts and peanuts.", {"entities": [(14, 23, "ALLERGY"), (28, 35, "ALLERGY")]}),
    ("He's allergic to soy and wheat gluten.", {"entities": [(14, 17, "ALLERGY"), (22, 32, "ALLERGY")]}),
    ("I have allergies to dairy and shellfish.", {"entities": [(14, 18, "ALLERGY"), (23, 31, "ALLERGY")]}),
    ("She's allergic to eggs and sesame seeds.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("He's allergic to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and dairy.", {"entities": [(14, 17, "ALLERGY"), (22, 26, "ALLERGY")]}),
    ("He's allergic to shellfish and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 30, "ALLERGY")]}),
    ("I have allergies to sesame seeds and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 36, "ALLERGY")]}),
    ("She's allergic to wheat gluten and shellfish.", {"entities": [(14, 25, "ALLERGY"), (30, 31, "ALLERGY")]}),
    ("He's allergic to soy and tree nuts.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("I have allergies to dairy and fish.", {"entities": [(14, 18, "ALLERGY"), (23, 27, "ALLERGY")]}),
    ("She's allergic to eggs and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 29, "ALLERGY")]}),
    ("He's allergic to wheat gluten and sesame seeds.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY")]}),
    ("I have allergies to soy and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("She's allergic to dairy and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY")]}),
    ("He's allergic to tree nuts and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and sesame seeds.", {"entities": [(14, 17, "ALLERGY"), (22, 25, "ALLERGY")]}),
    ("He's allergic to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("She's allergic to wheat gluten and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 34, "ALLERGY")]}),
    ("He's allergic to sesame seeds and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 32, "ALLERGY")]}),
    ("I have allergies to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("She's allergic to tree nuts and peanuts.", {"entities": [(14, 23, "ALLERGY"), (28, 35, "ALLERGY")]}),
    ("He's allergic to soy and wheat gluten.", {"entities": [(14, 17, "ALLERGY"), (22, 32, "ALLERGY")]}),
    ("I have allergies to dairy and shellfish.", {"entities": [(14, 18, "ALLERGY"), (23, 31, "ALLERGY")]}),
    ("She's allergic to eggs and sesame seeds.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("He's allergic to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and dairy.", {"entities": [(14, 17, "ALLERGY"), (22, 26, "ALLERGY")]}),
    ("He's allergic to shellfish and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 30, "ALLERGY")]}),
    ("I have allergies to sesame seeds and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 36, "ALLERGY")]}),
    ("She's allergic to wheat gluten and shellfish.", {"entities": [(14, 25, "ALLERGY"), (30, 31, "ALLERGY")]}),
    ("He's allergic to soy and tree nuts.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("I have allergies to dairy and fish.", {"entities": [(14, 18, "ALLERGY"), (23, 27, "ALLERGY")]}),
    ("She's allergic to eggs and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 29, "ALLERGY")]}),
    ("He's allergic to wheat gluten and sesame seeds.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY")]}),
    ("I have allergies to soy and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("She's allergic to dairy and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY")]}),
    ("He's allergic to tree nuts and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and sesame seeds.", {"entities": [(14, 17, "ALLERGY"), (22, 25, "ALLERGY")]}),
    ("He's allergic to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("She's allergic to wheat gluten and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 34, "ALLERGY")]}),
    ("He's allergic to sesame seeds and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 32, "ALLERGY")]}),
    ("I have allergies to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("She's allergic to tree nuts and peanuts.", {"entities": [(14, 23, "ALLERGY"), (28, 35, "ALLERGY")]}),
    ("He's allergic to soy and wheat gluten.", {"entities": [(14, 17, "ALLERGY"), (22, 32, "ALLERGY")]}),
    ("I have allergies to dairy and shellfish.", {"entities": [(14, 18, "ALLERGY"), (23, 31, "ALLERGY")]}),
    ("She's allergic to eggs and sesame seeds.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("He's allergic to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and dairy.", {"entities": [(14, 17, "ALLERGY"), (22, 26, "ALLERGY")]}),
    ("He's allergic to shellfish and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 30, "ALLERGY")]}),
    ("I have allergies to sesame seeds and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 36, "ALLERGY")]}),
    ("She's allergic to wheat gluten and shellfish.", {"entities": [(14, 25, "ALLERGY"), (30, 31, "ALLERGY")]}),
    ("He's allergic to soy and tree nuts.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("I have allergies to dairy and fish.", {"entities": [(14, 18, "ALLERGY"), (23, 27, "ALLERGY")]}),
    ("She's allergic to eggs and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 29, "ALLERGY")]}),
    ("He's allergic to wheat gluten and sesame seeds.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY")]}),
    ("I have allergies to soy and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("She's allergic to dairy and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY")]}),
    ("He's allergic to tree nuts and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and sesame seeds.", {"entities": [(14, 17, "ALLERGY"), (22, 25, "ALLERGY")]}),
    ("He's allergic to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("She's allergic to wheat gluten and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 34, "ALLERGY")]}),
    ("He's allergic to sesame seeds and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 32, "ALLERGY")]}),
    ("I have allergies to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("She's allergic to tree nuts and peanuts.", {"entities": [(14, 23, "ALLERGY"), (28, 35, "ALLERGY")]}),
    ("He's allergic to soy and wheat gluten.", {"entities": [(14, 17, "ALLERGY"), (22, 32, "ALLERGY")]}),
    ("I have allergies to dairy and shellfish.", {"entities": [(14, 18, "ALLERGY"), (23, 31, "ALLERGY")]}),
    ("She's allergic to eggs and sesame seeds.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("He's allergic to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and dairy.", {"entities": [(14, 17, "ALLERGY"), (22, 26, "ALLERGY")]}),
    ("He's allergic to shellfish and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 30, "ALLERGY")]}),
    ("I have allergies to sesame seeds and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 36, "ALLERGY")]}),
    ("She's allergic to wheat gluten and shellfish.", {"entities": [(14, 25, "ALLERGY"), (30, 31, "ALLERGY")]}),
    ("He's allergic to soy and tree nuts.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("I have allergies to dairy and fish.", {"entities": [(14, 18, "ALLERGY"), (23, 27, "ALLERGY")]}),
    ("She's allergic to eggs and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 29, "ALLERGY")]}),
    ("He's allergic to wheat gluten and sesame seeds.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY")]}),
    ("I have allergies to soy and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("She's allergic to dairy and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY")]}),
    ("He's allergic to tree nuts and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and sesame seeds.", {"entities": [(14, 17, "ALLERGY"), (22, 25, "ALLERGY")]}),
    ("He's allergic to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("She's allergic to wheat gluten and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 34, "ALLERGY")]}),
    ("He's allergic to sesame seeds and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 32, "ALLERGY")]}),
    ("I have allergies to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("She's allergic to tree nuts and peanuts.", {"entities": [(14, 23, "ALLERGY"), (28, 35, "ALLERGY")]}),
    ("He's allergic to soy and wheat gluten.", {"entities": [(14, 17, "ALLERGY"), (22, 32, "ALLERGY")]}),
    ("I have allergies to dairy and shellfish.", {"entities": [(14, 18, "ALLERGY"), (23, 31, "ALLERGY")]}),
    ("She's allergic to eggs and sesame seeds.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("He's allergic to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and dairy.", {"entities": [(14, 17, "ALLERGY"), (22, 26, "ALLERGY")]}),
    ("He's allergic to shellfish and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 30, "ALLERGY")]}),
    ("I have allergies to sesame seeds and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 36, "ALLERGY")]}),
    ("She's allergic to wheat gluten and shellfish.", {"entities": [(14, 25, "ALLERGY"), (30, 31, "ALLERGY")]}),
    ("He's allergic to soy and tree nuts.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("I have allergies to dairy and fish.", {"entities": [(14, 18, "ALLERGY"), (23, 27, "ALLERGY")]}),
    ("She's allergic to eggs and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 29, "ALLERGY")]}),
    ("He's allergic to wheat gluten and sesame seeds.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY")]}),
    ("I have allergies to soy and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("She's allergic to dairy and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY")]}),
    ("He's allergic to tree nuts and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and sesame seeds.", {"entities": [(14, 17, "ALLERGY"), (22, 25, "ALLERGY")]}),
    ("He's allergic to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("She's allergic to wheat gluten and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 34, "ALLERGY")]}),
    ("He's allergic to sesame seeds and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 32, "ALLERGY")]}),
    ("I have allergies to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("She's allergic to tree nuts and peanuts.", {"entities": [(14, 23, "ALLERGY"), (28, 35, "ALLERGY")]}),
    ("He's allergic to soy and wheat gluten.", {"entities": [(14, 17, "ALLERGY"), (22, 32, "ALLERGY")]}),
    ("I have allergies to dairy and shellfish.", {"entities": [(14, 18, "ALLERGY"), (23, 31, "ALLERGY")]}),
    ("She's allergic to eggs and sesame seeds.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("He's allergic to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and dairy.", {"entities": [(14, 17, "ALLERGY"), (22, 26, "ALLERGY")]}),
    ("He's allergic to shellfish and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 30, "ALLERGY")]}),
    ("I have allergies to sesame seeds and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 36, "ALLERGY")]}),
    ("She's allergic to wheat gluten and shellfish.", {"entities": [(14, 25, "ALLERGY"), (30, 31, "ALLERGY")]}),
    ("He's allergic to soy and tree nuts.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("I have allergies to dairy and fish.", {"entities": [(14, 18, "ALLERGY"), (23, 27, "ALLERGY")]}),
    ("She's allergic to eggs and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 29, "ALLERGY")]}),
    ("He's allergic to wheat gluten and sesame seeds.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY")]}),
    ("I have allergies to soy and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("She's allergic to dairy and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY")]}),
    ("He's allergic to tree nuts and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and sesame seeds.", {"entities": [(14, 17, "ALLERGY"), (22, 25, "ALLERGY")]}),
    ("He's allergic to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("She's allergic to wheat gluten and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 34, "ALLERGY")]}),
    ("He's allergic to sesame seeds and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 32, "ALLERGY")]}),
    ("I have allergies to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("She's allergic to tree nuts and peanuts.", {"entities": [(14, 23, "ALLERGY"), (28, 35, "ALLERGY")]}),
    ("He's allergic to soy and wheat gluten.", {"entities": [(14, 17, "ALLERGY"), (22, 32, "ALLERGY")]}),
    ("I have allergies to dairy and shellfish.", {"entities": [(14, 18, "ALLERGY"), (23, 31, "ALLERGY")]}),
    ("She's allergic to eggs and sesame seeds.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("He's allergic to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and dairy.", {"entities": [(14, 17, "ALLERGY"), (22, 26, "ALLERGY")]}),
    ("He's allergic to shellfish and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 30, "ALLERGY")]}),
    ("I have allergies to sesame seeds and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 36, "ALLERGY")]}),
    ("She's allergic to wheat gluten and shellfish.", {"entities": [(14, 25, "ALLERGY"), (30, 31, "ALLERGY")]}),
    ("He's allergic to soy and tree nuts.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("I have allergies to dairy and fish.", {"entities": [(14, 18, "ALLERGY"), (23, 27, "ALLERGY")]}),
    ("She's allergic to eggs and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 29, "ALLERGY")]}),
    ("He's allergic to wheat gluten and sesame seeds.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY")]}),
    ("I have allergies to soy and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("She's allergic to dairy and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY")]}),
    ("He's allergic to tree nuts and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and sesame seeds.", {"entities": [(14, 17, "ALLERGY"), (22, 25, "ALLERGY")]}),
    ("He's allergic to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("She's allergic to wheat gluten and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 34, "ALLERGY")]}),
    ("He's allergic to sesame seeds and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 32, "ALLERGY")]}),
    ("I have allergies to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("She's allergic to tree nuts and peanuts.", {"entities": [(14, 23, "ALLERGY"), (28, 35, "ALLERGY")]}),
    ("He's allergic to soy and wheat gluten.", {"entities": [(14, 17, "ALLERGY"), (22, 32, "ALLERGY")]}),
    ("I have allergies to dairy and shellfish.", {"entities": [(14, 18, "ALLERGY"), (23, 31, "ALLERGY")]}),
    ("She's allergic to eggs and sesame seeds.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("He's allergic to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and dairy.", {"entities": [(14, 17, "ALLERGY"), (22, 26, "ALLERGY")]}),
    ("He's allergic to shellfish and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 30, "ALLERGY")]}),
    ("I have allergies to sesame seeds and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 36, "ALLERGY")]}),
    ("She's allergic to wheat gluten and shellfish.", {"entities": [(14, 25, "ALLERGY"), (30, 31, "ALLERGY")]}),
    ("He's allergic to soy and tree nuts.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("I have allergies to dairy and fish.", {"entities": [(14, 18, "ALLERGY"), (23, 27, "ALLERGY")]}),
    ("She's allergic to eggs and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 29, "ALLERGY")]}),
    ("He's allergic to wheat gluten and sesame seeds.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY")]}),
    ("I have allergies to soy and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("She's allergic to dairy and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY")]}),
    ("He's allergic to tree nuts and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and sesame seeds.", {"entities": [(14, 17, "ALLERGY"), (22, 25, "ALLERGY")]}),
    ("He's allergic to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("She's allergic to wheat gluten and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 34, "ALLERGY")]}),
    ("He's allergic to sesame seeds and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 32, "ALLERGY")]}),
    ("I have allergies to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("She's allergic to tree nuts and peanuts.", {"entities": [(14, 23, "ALLERGY"), (28, 35, "ALLERGY")]}),
    ("He's allergic to soy and wheat gluten.", {"entities": [(14, 17, "ALLERGY"), (22, 32, "ALLERGY")]}),
    ("I have allergies to dairy and shellfish.", {"entities": [(14, 18, "ALLERGY"), (23, 31, "ALLERGY")]}),
    ("She's allergic to eggs and sesame seeds.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("He's allergic to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and dairy.", {"entities": [(14, 17, "ALLERGY"), (22, 26, "ALLERGY")]}),
    ("He's allergic to shellfish and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 30, "ALLERGY")]}),
    ("I have allergies to sesame seeds and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 36, "ALLERGY")]}),
    ("She's allergic to wheat gluten and shellfish.", {"entities": [(14, 25, "ALLERGY"), (30, 31, "ALLERGY")]}),
    ("He's allergic to soy and tree nuts.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("I have allergies to dairy and fish.", {"entities": [(14, 18, "ALLERGY"), (23, 27, "ALLERGY")]}),
    ("She's allergic to eggs and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 29, "ALLERGY")]}),
    ("He's allergic to wheat gluten and sesame seeds.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY")]}),
    ("I have allergies to soy and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("She's allergic to dairy and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY")]}),
    ("He's allergic to tree nuts and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and sesame seeds.", {"entities": [(14, 17, "ALLERGY"), (22, 25, "ALLERGY")]}),
    ("He's allergic to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("She's allergic to wheat gluten and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 34, "ALLERGY")]}),
    ("He's allergic to sesame seeds and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 32, "ALLERGY")]}),
    ("I have allergies to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("She's allergic to tree nuts and peanuts.", {"entities": [(14, 23, "ALLERGY"), (28, 35, "ALLERGY")]}),
    ("He's allergic to soy and wheat gluten.", {"entities": [(14, 17, "ALLERGY"), (22, 32, "ALLERGY")]}),
    ("I have allergies to dairy and shellfish.", {"entities": [(14, 18, "ALLERGY"), (23, 31, "ALLERGY")]}),
    ("She's allergic to eggs and sesame seeds.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("He's allergic to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and dairy.", {"entities": [(14, 17, "ALLERGY"), (22, 26, "ALLERGY")]}),
    ("He's allergic to shellfish and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 30, "ALLERGY")]}),
    ("I have allergies to sesame seeds and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 36, "ALLERGY")]}),
    ("She's allergic to wheat gluten and shellfish.", {"entities": [(14, 25, "ALLERGY"), (30, 31, "ALLERGY")]}),
    ("He's allergic to soy and tree nuts.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("I have allergies to dairy and fish.", {"entities": [(14, 18, "ALLERGY"), (23, 27, "ALLERGY")]}),
    ("She's allergic to eggs and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 29, "ALLERGY")]}),
    ("He's allergic to wheat gluten and sesame seeds.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY")]}),
    ("I have allergies to soy and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("She's allergic to dairy and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY")]}),
    ("He's allergic to tree nuts and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and sesame seeds.", {"entities": [(14, 17, "ALLERGY"), (22, 25, "ALLERGY")]}),
    ("He's allergic to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("She's allergic to wheat gluten and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 34, "ALLERGY")]}),
    ("He's allergic to sesame seeds and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 32, "ALLERGY")]}),
    ("I have allergies to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("She's allergic to tree nuts and peanuts.", {"entities": [(14, 23, "ALLERGY"), (28, 35, "ALLERGY")]}),
    ("He's allergic to soy and wheat gluten.", {"entities": [(14, 17, "ALLERGY"), (22, 32, "ALLERGY")]}),
    ("I have allergies to dairy and shellfish.", {"entities": [(14, 18, "ALLERGY"), (23, 31, "ALLERGY")]}),
    ("She's allergic to eggs and sesame seeds.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("He's allergic to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and dairy.", {"entities": [(14, 17, "ALLERGY"), (22, 26, "ALLERGY")]}),
    ("He's allergic to shellfish and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 30, "ALLERGY")]}),
    ("I have allergies to sesame seeds and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 36, "ALLERGY")]}),
    ("She's allergic to wheat gluten and shellfish.", {"entities": [(14, 25, "ALLERGY"), (30, 31, "ALLERGY")]}),
    ("He's allergic to soy and tree nuts.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("I have allergies to dairy and fish.", {"entities": [(14, 18, "ALLERGY"), (23, 27, "ALLERGY")]}),
    ("She's allergic to eggs and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 29, "ALLERGY")]}),
    ("He's allergic to wheat gluten and sesame seeds.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY")]}),
    ("I have allergies to soy and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("She's allergic to dairy and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY")]}),
    ("He's allergic to tree nuts and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and sesame seeds.", {"entities": [(14, 17, "ALLERGY"), (22, 25, "ALLERGY")]}),
    ("He's allergic to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("She's allergic to wheat gluten and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 34, "ALLERGY")]}),
    ("He's allergic to sesame seeds and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 32, "ALLERGY")]}),
    ("I have allergies to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("She's allergic to tree nuts and peanuts.", {"entities": [(14, 23, "ALLERGY"), (28, 35, "ALLERGY")]}),
    ("He's allergic to soy and wheat gluten.", {"entities": [(14, 17, "ALLERGY"), (22, 32, "ALLERGY")]}),
    ("I have allergies to dairy and shellfish.", {"entities": [(14, 18, "ALLERGY"), (23, 31, "ALLERGY")]}),
    ("She's allergic to eggs and sesame seeds.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("He's allergic to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and dairy.", {"entities": [(14, 17, "ALLERGY"), (22, 26, "ALLERGY")]}),
    ("He's allergic to shellfish and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 30, "ALLERGY")]}),
    ("I have allergies to sesame seeds and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 36, "ALLERGY")]}),
    ("She's allergic to wheat gluten and shellfish.", {"entities": [(14, 25, "ALLERGY"), (30, 31, "ALLERGY")]}),
    ("He's allergic to soy and tree nuts.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("I have allergies to dairy and fish.", {"entities": [(14, 18, "ALLERGY"), (23, 27, "ALLERGY")]}),
    ("She's allergic to eggs and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 29, "ALLERGY")]}),
    ("He's allergic to wheat gluten and sesame seeds.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY")]}),
    ("I have allergies to soy and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("She's allergic to dairy and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY")]}),
    ("He's allergic to tree nuts and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and sesame seeds.", {"entities": [(14, 17, "ALLERGY"), (22, 25, "ALLERGY")]}),
    ("He's allergic to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("She's allergic to wheat gluten and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 34, "ALLERGY")]}),
    ("He's allergic to sesame seeds and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 32, "ALLERGY")]}),
    ("I have allergies to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("She's allergic to tree nuts and peanuts.", {"entities": [(14, 23, "ALLERGY"), (28, 35, "ALLERGY")]}),
    ("He's allergic to soy and wheat gluten.", {"entities": [(14, 17, "ALLERGY"), (22, 32, "ALLERGY")]}),
    ("I have allergies to dairy and shellfish.", {"entities": [(14, 18, "ALLERGY"), (23, 31, "ALLERGY")]}),
    ("She's allergic to eggs and sesame seeds.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("He's allergic to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and dairy.", {"entities": [(14, 17, "ALLERGY"), (22, 26, "ALLERGY")]}),
    ("He's allergic to shellfish and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 30, "ALLERGY")]}),
    ("I have allergies to sesame seeds and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 36, "ALLERGY")]}),
    ("She's allergic to wheat gluten and shellfish.", {"entities": [(14, 25, "ALLERGY"), (30, 31, "ALLERGY")]}),
    ("He's allergic to soy and tree nuts.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("I have allergies to dairy and fish.", {"entities": [(14, 18, "ALLERGY"), (23, 27, "ALLERGY")]}),
    ("She's allergic to eggs and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 29, "ALLERGY")]}),
    ("He's allergic to wheat gluten and sesame seeds.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY")]}),
    ("I have allergies to soy and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("She's allergic to dairy and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY")]}),
    ("He's allergic to tree nuts and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and sesame seeds.", {"entities": [(14, 17, "ALLERGY"), (22, 25, "ALLERGY")]}),
    ("He's allergic to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("She's allergic to wheat gluten and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 34, "ALLERGY")]}),
    ("He's allergic to sesame seeds and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 32, "ALLERGY")]}),
    ("I have allergies to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("She's allergic to tree nuts and peanuts.", {"entities": [(14, 23, "ALLERGY"), (28, 35, "ALLERGY")]}),
    ("He's allergic to soy and wheat gluten.", {"entities": [(14, 17, "ALLERGY"), (22, 32, "ALLERGY")]}),
    ("I have allergies to dairy and shellfish.", {"entities": [(14, 18, "ALLERGY"), (23, 31, "ALLERGY")]}),
    ("She's allergic to eggs and sesame seeds.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("He's allergic to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and dairy.", {"entities": [(14, 17, "ALLERGY"), (22, 26, "ALLERGY")]}),
    ("He's allergic to shellfish and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 30, "ALLERGY")]}),
    ("I have allergies to sesame seeds and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 36, "ALLERGY")]}),
    ("She's allergic to wheat gluten and shellfish.", {"entities": [(14, 25, "ALLERGY"), (30, 31, "ALLERGY")]}),
    ("He's allergic to soy and tree nuts.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("I have allergies to dairy and fish.", {"entities": [(14, 18, "ALLERGY"), (23, 27, "ALLERGY")]}),
    ("She's allergic to eggs and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 29, "ALLERGY")]}),
    ("He's allergic to wheat gluten and sesame seeds.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY")]}),
    ("I have allergies to soy and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("She's allergic to dairy and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY")]}),
    ("He's allergic to tree nuts and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and sesame seeds.", {"entities": [(14, 17, "ALLERGY"), (22, 25, "ALLERGY")]}),
    ("He's allergic to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("She's allergic to wheat gluten and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 34, "ALLERGY")]}),
    ("He's allergic to sesame seeds and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 32, "ALLERGY")]}),
    ("I have allergies to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("She's allergic to tree nuts and peanuts.", {"entities": [(14, 23, "ALLERGY"), (28, 35, "ALLERGY")]}),
    ("He's allergic to soy and wheat gluten.", {"entities": [(14, 17, "ALLERGY"), (22, 32, "ALLERGY")]}),
    ("I have allergies to dairy and shellfish.", {"entities": [(14, 18, "ALLERGY"), (23, 31, "ALLERGY")]}),
    ("She's allergic to eggs and sesame seeds.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("He's allergic to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and dairy.", {"entities": [(14, 17, "ALLERGY"), (22, 26, "ALLERGY")]}),
    ("He's allergic to shellfish and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 30, "ALLERGY")]}),
    ("I have allergies to sesame seeds and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 36, "ALLERGY")]}),
    ("She's allergic to wheat gluten and shellfish.", {"entities": [(14, 25, "ALLERGY"), (30, 31, "ALLERGY")]}),
    ("He's allergic to soy and tree nuts.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("I have allergies to dairy and fish.", {"entities": [(14, 18, "ALLERGY"), (23, 27, "ALLERGY")]}),
    ("She's allergic to eggs and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 29, "ALLERGY")]}),
    ("He's allergic to wheat gluten and sesame seeds.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY")]}),
    ("I have allergies to soy and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("She's allergic to dairy and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY")]}),
    ("He's allergic to tree nuts and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and sesame seeds.", {"entities": [(14, 17, "ALLERGY"), (22, 25, "ALLERGY")]}),
    ("He's allergic to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("She's allergic to wheat gluten and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 34, "ALLERGY")]}),
    ("He's allergic to sesame seeds and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 32, "ALLERGY")]}),
    ("I have allergies to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("She's allergic to tree nuts and peanuts.", {"entities": [(14, 23, "ALLERGY"), (28, 35, "ALLERGY")]}),
    ("He's allergic to soy and wheat gluten.", {"entities": [(14, 17, "ALLERGY"), (22, 32, "ALLERGY")]}),
    ("I have allergies to dairy and shellfish.", {"entities": [(14, 18, "ALLERGY"), (23, 31, "ALLERGY")]}),
    ("She's allergic to eggs and sesame seeds.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("He's allergic to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and dairy.", {"entities": [(14, 17, "ALLERGY"), (22, 26, "ALLERGY")]}),
    ("He's allergic to shellfish and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 30, "ALLERGY")]}),
    ("I have allergies to sesame seeds and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 36, "ALLERGY")]}),
    ("She's allergic to wheat gluten and shellfish.", {"entities": [(14, 25, "ALLERGY"), (30, 31, "ALLERGY")]}),
    ("He's allergic to soy and tree nuts.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("I have allergies to dairy and fish.", {"entities": [(14, 18, "ALLERGY"), (23, 27, "ALLERGY")]}),
    ("She's allergic to eggs and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 29, "ALLERGY")]}),
    ("He's allergic to wheat gluten and sesame seeds.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY")]}),
    ("I have allergies to soy and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("She's allergic to dairy and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY")]}),
    ("He's allergic to tree nuts and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and sesame seeds.", {"entities": [(14, 17, "ALLERGY"), (22, 25, "ALLERGY")]}),
    ("He's allergic to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("She's allergic to wheat gluten and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 34, "ALLERGY")]}),
    ("He's allergic to sesame seeds and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 32, "ALLERGY")]}),
    ("I have allergies to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("She's allergic to tree nuts and peanuts.", {"entities": [(14, 23, "ALLERGY"), (28, 35, "ALLERGY")]}),
    ("He's allergic to soy and wheat gluten.", {"entities": [(14, 17, "ALLERGY"), (22, 32, "ALLERGY")]}),
    ("I have allergies to dairy and shellfish.", {"entities": [(14, 18, "ALLERGY"), (23, 31, "ALLERGY")]}),
    ("She's allergic to eggs and sesame seeds.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("He's allergic to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and dairy.", {"entities": [(14, 17, "ALLERGY"), (22, 26, "ALLERGY")]}),
    ("He's allergic to shellfish and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 30, "ALLERGY")]}),
    ("I have allergies to sesame seeds and peanuts.", {"entities": [(14, 25, "ALLERGY"), (30, 36, "ALLERGY")]}),
    ("She's allergic to wheat gluten and shellfish.", {"entities": [(14, 25, "ALLERGY"), (30, 31, "ALLERGY")]}),
    ("He's allergic to soy and tree nuts.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("I have allergies to dairy and fish.", {"entities": [(14, 18, "ALLERGY"), (23, 27, "ALLERGY")]}),
    ("She's allergic to eggs and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 29, "ALLERGY")]}),
    ("He's allergic to wheat gluten and sesame seeds.", {"entities": [(14, 25, "ALLERGY"), (30, 39, "ALLERGY")]}),
    ("I have allergies to soy and shellfish.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("She's allergic to dairy and peanuts.", {"entities": [(14, 18, "ALLERGY"), (23, 30, "ALLERGY")]}),
    ("He's allergic to tree nuts and eggs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to fish and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 34, "ALLERGY")]}),
    ("She's allergic to soy and sesame seeds.", {"entities": [(14, 17, "ALLERGY"), (22, 25, "ALLERGY")]}),
    ("He's allergic to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I have allergies to peanuts and tree nuts.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("She's allergic to wheat gluten and fish.", {"entities": [(14, 25, "ALLERGY"), (30, 34, "ALLERGY")]}),
    ("He's allergic to sesame seeds and soy.", {"entities": [(14, 25, "ALLERGY"), (30, 32, "ALLERGY")]}),
    ("I have allergies to shellfish and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("She's allergic to tree nuts and peanuts.", {"entities": [(14, 23, "ALLERGY"), (28, 35, "ALLERGY")]}),
    ("He's allergic to soy and wheat gluten.", {"entities": [(14, 17, "ALLERGY"), (22, 32, "ALLERGY")]}),
    ("I have allergies to dairy and shellfish.", {"entities": [(14, 18, "ALLERGY"), (23, 31, "ALLERGY")]}),
    ("I have an allergy to peanuts.", {"entities": [(15, 22, "ALLERGY")]}),
    ("She's allergic to milk.", {"entities": [(14, 18, "ALLERGY")]}),
    ("He's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("He's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to fish.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to dairy.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to fish.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to dairy.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to fish.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to dairy.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to fish.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to dairy.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to fish.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to dairy.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to fish.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to dairy.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to fish.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to dairy.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to fish.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to dairy.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to fish.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to dairy.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to fish.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to dairy.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to fish.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to dairy.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to fish.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to dairy.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to fish.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to dairy.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to fish.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to dairy.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to fish.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to dairy.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to fish.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to dairy.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to fish.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to dairy.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to fish.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to dairy.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to fish.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to dairy.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to fish.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to dairy.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to fish.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to dairy.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to fish.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to dairy.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to fish.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to dairy.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to fish.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to dairy.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to fish.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to dairy.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to fish.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to dairy.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to fish.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to dairy.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to fish.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to dairy.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to fish.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to dairy.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to fish.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to sesame seeds.", {"entities": [(14, 25, "ALLERGY")]}),
    ("I have an allergy to dairy.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to shellfish.", {"entities": [(14, 23, "ALLERGY")]}),
    ("He's allergic to peanuts.", {"entities": [(14, 21, "ALLERGY")]}),
    ("I have an allergy to milk.", {"entities": [(15, 18, "ALLERGY")]}),
    ("She's allergic to wheat gluten.", {"entities": [(14, 25, "ALLERGY")]}),
    ("He's allergic to soy.", {"entities": [(14, 17, "ALLERGY")]}),
    ("I have an allergy to eggs.", {"entities": [(15, 19, "ALLERGY")]}),
    ("She's allergic to tree nuts.", {"entities": [(14, 23, "ALLERGY")]}),
    ("I'm allergic to peanuts, shellfish, and dairy.", {"entities": [(13, 20, "ALLERGY"), (22, 31, "ALLERGY"), (36, 41, "ALLERGY")]}),
    ("She has allergies to soy, wheat gluten, and sesame seeds.", {"entities": [(20, 23, "ALLERGY"), (25, 36, "ALLERGY"), (41, 52, "ALLERGY")]}),
    ("He's allergic to eggs, tree nuts, and fish.", {"entities": [(14, 18, "ALLERGY"), (20, 29, "ALLERGY"), (34, 38, "ALLERGY")]}),
    ("I suffer from allergies to milk, peanuts, and shellfish.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 50, "ALLERGY")]}),
    ("She's sensitive to wheat gluten, soy, and dairy.", {"entities": [(20, 31, "ALLERGY"), (33, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("He has allergies to eggs, sesame seeds, and peanuts.", {"entities": [(14, 18, "ALLERGY"), (20, 31, "ALLERGY"), (36, 43, "ALLERGY")]}),
    ("I'm allergic to fish, shellfish, and tree nuts.", {"entities": [(13, 17, "ALLERGY"), (19, 28, "ALLERGY"), (33, 42, "ALLERGY")]}),
    ("She's sensitive to peanuts, sesame seeds, and soy.", {"entities": [(20, 27, "ALLERGY"), (29, 40, "ALLERGY"), (45, 48, "ALLERGY")]}),
    ("He's allergic to dairy, wheat gluten, and eggs.", {"entities": [(14, 18, "ALLERGY"), (20, 31, "ALLERGY"), (36, 40, "ALLERGY")]}),
    ("I have allergies to soy, tree nuts, and shellfish.", {"entities": [(23, 26, "ALLERGY"), (28, 37, "ALLERGY"), (42, 51, "ALLERGY")]}),
    ("I'm allergic to milk, fish, and sesame seeds.", {"entities": [(13, 17, "ALLERGY"), (19, 23, "ALLERGY"), (28, 39, "ALLERGY")]}),
    ("She has allergies to peanuts, eggs, and wheat gluten.", {"entities": [(20, 27, "ALLERGY"), (29, 33, "ALLERGY"), (38, 49, "ALLERGY")]}),
    ("He's sensitive to soy, shellfish, and dairy.", {"entities": [(14, 17, "ALLERGY"), (19, 28, "ALLERGY"), (33, 38, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, soy, and fish.", {"entities": [(23, 32, "ALLERGY"), (34, 37, "ALLERGY"), (42, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, sesame seeds, and shellfish.", {"entities": [(14, 21, "ALLERGY"), (23, 34, "ALLERGY"), (39, 48, "ALLERGY")]}),
    ("He has allergies to dairy, soy, and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (20, 23, "ALLERGY"), (28, 39, "ALLERGY")]}),
    ("I'm allergic to eggs, fish, and tree nuts.", {"entities": [(13, 17, "ALLERGY"), (19, 23, "ALLERGY"), (28, 37, "ALLERGY")]}),
    ("She's sensitive to shellfish, peanuts, and dairy.", {"entities": [(20, 29, "ALLERGY"), (31, 38, "ALLERGY"), (43, 48, "ALLERGY")]}),
    ("He has allergies to wheat gluten, soy, and peanuts.", {"entities": [(14, 25, "ALLERGY"), (27, 30, "ALLERGY"), (35, 42, "ALLERGY")]}),
    ("I suffer from allergies to milk, tree nuts, and sesame seeds.", {"entities": [(23, 27, "ALLERGY"), (29, 38, "ALLERGY"), (43, 54, "ALLERGY")]}),
    ("She's allergic to fish, eggs, and dairy.", {"entities": [(14, 18, "ALLERGY"), (20, 24, "ALLERGY"), (29, 34, "ALLERGY")]}),
    ("He's allergic to soy, wheat gluten, and peanuts.", {"entities": [(14, 17, "ALLERGY"), (19, 30, "ALLERGY"), (35, 42, "ALLERGY")]}),
    ("I have allergies to shellfish, sesame seeds, and soy.", {"entities": [(23, 32, "ALLERGY"), (34, 45, "ALLERGY"), (50, 53, "ALLERGY")]}),
    ("I'm allergic to peanuts, dairy, and eggs.", {"entities": [(13, 20, "ALLERGY"), (22, 27, "ALLERGY"), (32, 36, "ALLERGY")]}),
    ("She has allergies to wheat gluten, tree nuts, and fish.", {"entities": [(20, 31, "ALLERGY"), (33, 42, "ALLERGY"), (47, 51, "ALLERGY")]}),
    ("He's sensitive to soy, sesame seeds, and dairy.", {"entities": [(14, 17, "ALLERGY"), (19, 30, "ALLERGY"), (35, 40, "ALLERGY")]}),
    ("I suffer from allergies to shellfish, peanuts, and wheat gluten.", {"entities": [(23, 32, "ALLERGY"), (34, 41, "ALLERGY"), (46, 57, "ALLERGY")]}),
    ("She's allergic to eggs, soy, and fish.", {"entities": [(14, 18, "ALLERGY"), (20, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("He has allergies to milk, tree nuts, and shellfish.", {"entities": [(14, 18, "ALLERGY"), (20, 29, "ALLERGY"), (34, 43, "ALLERGY")]}),
    ("I'm allergic to wheat gluten, sesame seeds, and dairy.", {"entities": [(13, 24, "ALLERGY"), (26, 37, "ALLERGY"), (42, 47, "ALLERGY")]}),
    ("She has allergies to peanuts, shellfish, and eggs.", {"entities": [(20, 27, "ALLERGY"), (29, 38, "ALLERGY"), (43, 47, "ALLERGY")]}),
    ("He's sensitive to soy, dairy, and fish.", {"entities": [(14, 17, "ALLERGY"), (19, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, wheat gluten, and soy.", {"entities": [(23, 32, "ALLERGY"), (34, 45, "ALLERGY"), (50, 53, "ALLERGY")]}),
    ("She's allergic to eggs, peanuts, and sesame seeds.", {"entities": [(14, 18, "ALLERGY"), (20, 27, "ALLERGY"), (32, 43, "ALLERGY")]}),
    ("He has allergies to dairy, shellfish, and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (20, 29, "ALLERGY"), (34, 45, "ALLERGY")]}),
    ("I'm allergic to fish, soy, and dairy.", {"entities": [(13, 17, "ALLERGY"), (19, 22, "ALLERGY"), (27, 32, "ALLERGY")]}),
    ("She's sensitive to tree nuts, sesame seeds, and peanuts.", {"entities": [(20, 29, "ALLERGY"), (31, 42, "ALLERGY"), (47, 54, "ALLERGY")]}),
    ("He has allergies to wheat gluten, shellfish, and eggs.", {"entities": [(14, 25, "ALLERGY"), (27, 36, "ALLERGY"), (41, 45, "ALLERGY")]}),
    ("I suffer from allergies to dairy, fish, and tree nuts.", {"entities": [(23, 28, "ALLERGY"), (30, 34, "ALLERGY"), (39, 48, "ALLERGY")]}),
    ("She's allergic to soy, wheat gluten, and sesame seeds.", {"entities": [(14, 17, "ALLERGY"), (19, 30, "ALLERGY"), (35, 46, "ALLERGY")]}),
    ("He's allergic to peanuts, shellfish, and dairy.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 42, "ALLERGY")]}),
    ("I have allergies to eggs, tree nuts, and fish.", {"entities": [(23, 27, "ALLERGY"), (29, 38, "ALLERGY"), (43, 47, "ALLERGY")]}),
    ("She's allergic to milk, peanuts, and shellfish.", {"entities": [(14, 18, "ALLERGY"), (20, 27, "ALLERGY"), (32, 41, "ALLERGY")]}),
    ("He's allergic to soy, wheat gluten, and sesame seeds.", {"entities": [(14, 17, "ALLERGY"), (19, 30, "ALLERGY"), (35, 46, "ALLERGY")]}),
    ("I'm allergic to eggs, tree nuts, and dairy.", {"entities": [(13, 17, "ALLERGY"), (19, 28, "ALLERGY"), (33, 38, "ALLERGY")]}),
    ("She has allergies to milk, peanuts, and fish.", {"entities": [(20, 24, "ALLERGY"), (26, 33, "ALLERGY"), (38, 42, "ALLERGY")]}),
    ("He's sensitive to soy, wheat gluten, and shellfish.", {"entities": [(14, 17, "ALLERGY"), (19, 30, "ALLERGY"), (35, 44, "ALLERGY")]}),
    ("I suffer from allergies to eggs, dairy, and soy.", {"entities": [(23, 27, "ALLERGY"), (29, 34, "ALLERGY"), (39, 42, "ALLERGY")]}),
    ("She's allergic to peanuts, tree nuts, and fish.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has allergies to soy, shellfish, and dairy.", {"entities": [(14, 17, "ALLERGY"), (19, 28, "ALLERGY"), (33, 38, "ALLERGY")]}),
    ("I'm allergic to wheat gluten, peanuts, and eggs.", {"entities": [(13, 24, "ALLERGY"), (26, 33, "ALLERGY"), (38, 42, "ALLERGY")]}),
    ("She has allergies to sesame seeds, dairy, and soy.", {"entities": [(20, 31, "ALLERGY"), (33, 38, "ALLERGY"), (43, 46, "ALLERGY")]}),
    ("He's sensitive to fish, wheat gluten, and tree nuts.", {"entities": [(14, 18, "ALLERGY"), (20, 31, "ALLERGY"), (36, 45, "ALLERGY")]}),
    ("I suffer from allergies to peanuts, eggs, and dairy.", {"entities": [(23, 30, "ALLERGY"), (32, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to soy, shellfish, and wheat gluten.", {"entities": [(14, 17, "ALLERGY"), (19, 28, "ALLERGY"), (33, 44, "ALLERGY")]}),
    ("He has allergies to milk, fish, and sesame seeds.", {"entities": [(14, 18, "ALLERGY"), (20, 24, "ALLERGY"), (29, 40, "ALLERGY")]}),
    ("I'm allergic to peanuts, soy, and tree nuts.", {"entities": [(13, 20, "ALLERGY"), (22, 25, "ALLERGY"), (30, 39, "ALLERGY")]}),
    ("She has allergies to dairy, eggs, and wheat gluten.", {"entities": [(20, 24, "ALLERGY"), (26, 30, "ALLERGY"), (35, 46, "ALLERGY")]}),
    ("He's sensitive to shellfish, peanuts, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 32, "ALLERGY"), (37, 40, "ALLERGY")]}),
    ("I suffer from allergies to fish, wheat gluten, and dairy.", {"entities": [(23, 27, "ALLERGY"), (29, 40, "ALLERGY"), (45, 50, "ALLERGY")]}),
    ("She's allergic to eggs, tree nuts, and peanuts.", {"entities": [(14, 18, "ALLERGY"), (20, 29, "ALLERGY"), (34, 41, "ALLERGY")]}),
    ("He has allergies to milk, sesame seeds, and soy.", {"entities": [(14, 18, "ALLERGY"), (20, 31, "ALLERGY"), (36, 39, "ALLERGY")]}),
    ("I'm allergic to wheat gluten, fish, and dairy.", {"entities": [(13, 24, "ALLERGY"), (26, 30, "ALLERGY"), (35, 40, "ALLERGY")]}),
    ("She has allergies to peanuts, shellfish, and tree nuts.", {"entities": [(20, 27, "ALLERGY"), (29, 38, "ALLERGY"), (43, 52, "ALLERGY")]}),
    ("He's sensitive to soy, wheat gluten, and eggs.", {"entities": [(14, 17, "ALLERGY"), (19, 30, "ALLERGY"), (35, 39, "ALLERGY")]}),
    ("I suffer from allergies to sesame seeds, fish, and soy.", {"entities": [(23, 34, "ALLERGY"), (36, 40, "ALLERGY"), (45, 48, "ALLERGY")]}),
    ("She's allergic to dairy, peanuts, and shellfish.", {"entities": [(14, 18, "ALLERGY"), (20, 27, "ALLERGY"), (32, 41, "ALLERGY")]}),
    ("He has allergies to eggs, soy, and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (20, 23, "ALLERGY"), (28, 39, "ALLERGY")]}),
    ("I'm allergic to tree nuts, dairy, and peanuts.", {"entities": [(13, 22, "ALLERGY"), (24, 29, "ALLERGY"), (34, 41, "ALLERGY")]}),
    ("She has allergies to wheat gluten, soy, and fish.", {"entities": [(20, 31, "ALLERGY"), (33, 36, "ALLERGY"), (41, 45, "ALLERGY")]}),
    ("He's sensitive to shellfish, peanuts, and wheat gluten.", {"entities": [(14, 23, "ALLERGY"), (25, 32, "ALLERGY"), (37, 48, "ALLERGY")]}),
    ("I suffer from allergies to sesame seeds, dairy, and shellfish.", {"entities": [(23, 34, "ALLERGY"), (36, 41, "ALLERGY"), (46, 55, "ALLERGY")]}),
    ("She's allergic to eggs, soy, and peanuts.", {"entities": [(14, 18, "ALLERGY"), (20, 23, "ALLERGY"), (28, 35, "ALLERGY")]}),
    ("He has allergies to milk, shellfish, and tree nuts.", {"entities": [(14, 18, "ALLERGY"), (20, 29, "ALLERGY"), (34, 43, "ALLERGY")]}),
    ("I'm allergic to wheat gluten, peanuts, and soy.", {"entities": [(13, 24, "ALLERGY"), (26, 33, "ALLERGY"), (38, 41, "ALLERGY")]}),
    ("She has allergies to sesame seeds, dairy, and tree nuts.", {"entities": [(20, 31, "ALLERGY"), (33, 38, "ALLERGY"), (43, 52, "ALLERGY")]}),
    ("He's sensitive to shellfish, soy, and wheat gluten.", {"entities": [(14, 23, "ALLERGY"), (25, 28, "ALLERGY"), (33, 44, "ALLERGY")]}),
    ("I suffer from allergies to eggs, peanuts, and fish.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 45, "ALLERGY")]}),
    ("She's allergic to dairy, wheat gluten, and sesame seeds.", {"entities": [(14, 18, "ALLERGY"), (20, 31, "ALLERGY"), (36, 47, "ALLERGY")]}),
    ("He has allergies to milk, peanuts, and soy.", {"entities": [(14, 18, "ALLERGY"), (20, 27, "ALLERGY"), (32, 35, "ALLERGY")]}),
    ("I'm allergic to tree nuts, fish, and wheat gluten.", {"entities": [(13, 22, "ALLERGY"), (24, 28, "ALLERGY"), (33, 44, "ALLERGY")]}),
    ("She has allergies to wheat gluten, soy, and peanuts.", {"entities": [(20, 31, "ALLERGY"), (33, 36, "ALLERGY"), (41, 48, "ALLERGY")]}),
    ("He's sensitive to shellfish, dairy, and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (25, 29, "ALLERGY"), (34, 43, "ALLERGY")]}),
    ("I suffer from allergies to sesame seeds, peanuts, and eggs.", {"entities": [(23, 34, "ALLERGY"), (36, 43, "ALLERGY"), (48, 52, "ALLERGY")]}),
    ("She's allergic to dairy, soy, and shellfish.", {"entities": [(14, 18, "ALLERGY"), (20, 23, "ALLERGY"), (28, 37, "ALLERGY")]}),
    ("He has allergies to wheat gluten, peanuts, and sesame seeds.", {"entities": [(14, 25, "ALLERGY"), (27, 34, "ALLERGY"), (39, 50, "ALLERGY")]}),
    ("I'm allergic to tree nuts, dairy, and soy.", {"entities": [(13, 22, "ALLERGY"), (24, 29, "ALLERGY"), (34, 37, "ALLERGY")]}),
    ("She has allergies to fish, wheat gluten, and shellfish.", {"entities": [(20, 24, "ALLERGY"), (26, 37, "ALLERGY"), (42, 51, "ALLERGY")]}),
    ("He's sensitive to peanuts, sesame seeds, and dairy.", {"entities": [(14, 21, "ALLERGY"), (23, 34, "ALLERGY"), (39, 44, "ALLERGY")]}),
    ("I suffer from allergies to eggs, soy, and tree nuts.", {"entities": [(23, 27, "ALLERGY"), (29, 32, "ALLERGY"), (37, 46, "ALLERGY")]}),
    ("She's allergic to dairy, wheat gluten, and peanuts.", {"entities": [(14, 18, "ALLERGY"), (20, 31, "ALLERGY"), (36, 43, "ALLERGY")]}),
    ("He has allergies to milk, sesame seeds, and soy.", {"entities": [(14, 18, "ALLERGY"), (20, 31, "ALLERGY"), (36, 39, "ALLERGY")]}),
    ("I'm allergic to wheat gluten, fish, and sesame seeds.", {"entities": [(13, 24, "ALLERGY"), (26, 30, "ALLERGY"), (35, 46, "ALLERGY")]}),
    ("She has allergies to peanuts, shellfish, and soy.", {"entities": [(20, 27, "ALLERGY"), (29, 38, "ALLERGY"), (43, 46, "ALLERGY")]}),
    ("He's sensitive to dairy, peanuts, and eggs.", {"entities": [(14, 18, "ALLERGY"), (20, 27, "ALLERGY"), (32, 36, "ALLERGY")]}),
    ("I suffer from allergies to wheat gluten, soy, and shellfish.", {"entities": [(23, 34, "ALLERGY"), (36, 39, "ALLERGY"), (44, 53, "ALLERGY")]}),
    ("She's allergic to sesame seeds, peanuts, and dairy.", {"entities": [(14, 25, "ALLERGY"), (27, 34, "ALLERGY"), (39, 44, "ALLERGY")]}),
    ("He has allergies to tree nuts, dairy, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 29, "ALLERGY"), (34, 37, "ALLERGY")]}),
    ("I'm allergic to eggs, shellfish, and tree nuts.", {"entities": [(13, 17, "ALLERGY"), (19, 28, "ALLERGY"), (33, 42, "ALLERGY")]}),
    ("She has allergies to soy, dairy, and wheat gluten.", {"entities": [(20, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 46, "ALLERGY")]}),
    ("He's sensitive to peanuts, wheat gluten, and shellfish.", {"entities": [(14, 21, "ALLERGY"), (23, 34, "ALLERGY"), (39, 48, "ALLERGY")]}),
    ("I suffer from allergies to eggs, peanuts, and dairy.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to fish, tree nuts, and sesame seeds.", {"entities": [(14, 18, "ALLERGY"), (20, 29, "ALLERGY"), (34, 45, "ALLERGY")]}),
    ("He has allergies to wheat gluten, peanuts, and dairy.", {"entities": [(14, 25, "ALLERGY"), (27, 34, "ALLERGY"), (39, 44, "ALLERGY")]}),
    ("I'm allergic to soy, eggs, and shellfish.", {"entities": [(13, 16, "ALLERGY"), (18, 22, "ALLERGY"), (27, 36, "ALLERGY")]}),
    ("She has allergies to milk, tree nuts, and peanuts.", {"entities": [(20, 24, "ALLERGY"), (26, 35, "ALLERGY"), (40, 47, "ALLERGY")]}),
    ("He's sensitive to sesame seeds, dairy, and soy.", {"entities": [(14, 25, "ALLERGY"), (27, 32, "ALLERGY"), (37, 40, "ALLERGY")]}),
    ("I suffer from allergies to fish, eggs, and wheat gluten.", {"entities": [(23, 27, "ALLERGY"), (29, 33, "ALLERGY"), (38, 49, "ALLERGY")]}),
    ("She's allergic to shellfish, soy, and dairy.", {"entities": [(14, 23, "ALLERGY"), (25, 28, "ALLERGY"), (33, 38, "ALLERGY")]}),
    ("He has allergies to peanuts, sesame seeds, and fish.", {"entities": [(14, 21, "ALLERGY"), (23, 34, "ALLERGY"), (39, 43, "ALLERGY")]}),
    ("I'm allergic to tree nuts, wheat gluten, and eggs.", {"entities": [(13, 22, "ALLERGY"), (24, 35, "ALLERGY"), (40, 44, "ALLERGY")]}),
    ("She has allergies to dairy, peanuts, and sesame seeds.", {"entities": [(20, 24, "ALLERGY"), (26, 33, "ALLERGY"), (38, 49, "ALLERGY")]}),
    ("He's sensitive to fish, wheat gluten, and tree nuts.", {"entities": [(14, 18, "ALLERGY"), (20, 31, "ALLERGY"), (36, 45, "ALLERGY")]}),
    ("I suffer from allergies to peanuts, soy, and dairy.", {"entities": [(23, 30, "ALLERGY"), (32, 35, "ALLERGY"), (40, 45, "ALLERGY")]}),
    ("She's allergic to sesame seeds, fish, and shellfish.", {"entities": [(14, 25, "ALLERGY"), (27, 31, "ALLERGY"), (36, 45, "ALLERGY")]}),
    ("He has allergies to wheat gluten, tree nuts, and dairy.", {"entities": [(14, 25, "ALLERGY"), (27, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("I'm allergic to soy, eggs, and peanuts.", {"entities": [(13, 16, "ALLERGY"), (18, 22, "ALLERGY"), (27, 34, "ALLERGY")]}),
    ("She has allergies to milk, shellfish, and wheat gluten.", {"entities": [(20, 24, "ALLERGY"), (26, 35, "ALLERGY"), (40, 51, "ALLERGY")]}),
    ("He's sensitive to tree nuts, dairy, and sesame seeds.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 46, "ALLERGY")]}),
    ("I suffer from allergies to fish, soy, and peanuts.", {"entities": [(23, 27, "ALLERGY"), (29, 32, "ALLERGY"), (37, 44, "ALLERGY")]}),
    ("She's allergic to wheat gluten, dairy, and eggs.", {"entities": [(14, 25, "ALLERGY"), (27, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has allergies to sesame seeds, soy, and tree nuts.", {"entities": [(14, 25, "ALLERGY"), (27, 30, "ALLERGY"), (35, 44, "ALLERGY")]}),
    ("I'm allergic to shellfish, wheat gluten, and soy.", {"entities": [(13, 22, "ALLERGY"), (24, 35, "ALLERGY"), (40, 43, "ALLERGY")]}),
    ("She has allergies to dairy, peanuts, and fish.", {"entities": [(20, 24, "ALLERGY"), (26, 33, "ALLERGY"), (38, 42, "ALLERGY")]}),
    ("He's sensitive to eggs, tree nuts, and sesame seeds.", {"entities": [(14, 18, "ALLERGY"), (20, 29, "ALLERGY"), (34, 45, "ALLERGY")]}),
    ("I suffer from allergies to soy, wheat gluten, and dairy.", {"entities": [(23, 26, "ALLERGY"), (28, 39, "ALLERGY"), (44, 49, "ALLERGY")]}),
    ("She's allergic to fish, eggs, and peanuts.", {"entities": [(14, 18, "ALLERGY"), (20, 24, "ALLERGY"), (29, 36, "ALLERGY")]}),
    ("He has allergies to shellfish, soy, and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (25, 28, "ALLERGY"), (33, 42, "ALLERGY")]}),
    ("I'm allergic to dairy, sesame seeds, and wheat gluten.", {"entities": [(13, 17, "ALLERGY"), (19, 30, "ALLERGY"), (35, 46, "ALLERGY")]}),
    ("She has allergies to peanuts, fish, and dairy.", {"entities": [(20, 27, "ALLERGY"), (29, 33, "ALLERGY"), (38, 43, "ALLERGY")]}),
    ("He's sensitive to eggs, wheat gluten, and soy.", {"entities": [(14, 18, "ALLERGY"), (20, 31, "ALLERGY"), (36, 39, "ALLERGY")]}),
    ("I suffer from allergies to shellfish, tree nuts, and peanuts.", {"entities": [(23, 32, "ALLERGY"), (34, 43, "ALLERGY"), (48, 55, "ALLERGY")]}),
    ("She's allergic to milk, soy, and sesame seeds.", {"entities": [(14, 18, "ALLERGY"), (20, 23, "ALLERGY"), (28, 39, "ALLERGY")]}),
    ("He has allergies to peanuts, shellfish, and wheat gluten.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 48, "ALLERGY")]}),
    ("I'm allergic to eggs, dairy, and soy.", {"entities": [(13, 17, "ALLERGY"), (19, 24, "ALLERGY"), (29, 32, "ALLERGY")]}),
    ("She has allergies to wheat gluten, peanuts, and shellfish.", {"entities": [(20, 31, "ALLERGY"), (33, 40, "ALLERGY"), (45, 54, "ALLERGY")]}),
    ("He's sensitive to fish, dairy, and tree nuts.", {"entities": [(14, 18, "ALLERGY"), (20, 25, "ALLERGY"), (30, 39, "ALLERGY")]}),
    ("I suffer from allergies to soy, sesame seeds, and eggs.", {"entities": [(23, 26, "ALLERGY"), (28, 39, "ALLERGY"), (44, 48, "ALLERGY")]}),
    ("She's allergic to tree nuts, wheat gluten, and dairy.", {"entities": [(14, 23, "ALLERGY"), (25, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("He has allergies to peanuts, eggs, and sesame seeds.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 43, "ALLERGY")]}),
    ("I'm allergic to fish, dairy, and soy.", {"entities": [(13, 17, "ALLERGY"), (19, 24, "ALLERGY"), (29, 32, "ALLERGY")]}),
    ("She has allergies to wheat gluten, peanuts, and tree nuts.", {"entities": [(20, 31, "ALLERGY"), (33, 40, "ALLERGY"), (45, 54, "ALLERGY")]}),
    ("He's sensitive to shellfish, soy, and eggs.", {"entities": [(14, 23, "ALLERGY"), (25, 28, "ALLERGY"), (33, 37, "ALLERGY")]}),
    ("I suffer from allergies to milk, sesame seeds, and fish.", {"entities": [(23, 27, "ALLERGY"), (29, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She's allergic to wheat gluten, dairy, and shellfish.", {"entities": [(14, 25, "ALLERGY"), (27, 32, "ALLERGY"), (37, 46, "ALLERGY")]}),
    ("He has allergies to peanuts, tree nuts, and soy.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 40, "ALLERGY")]}),
    ("I'm allergic to eggs, soy, and wheat gluten.", {"entities": [(13, 17, "ALLERGY"), (19, 22, "ALLERGY"), (27, 38, "ALLERGY")]}),
    ("She has allergies to dairy, shellfish, and tree nuts.", {"entities": [(20, 24, "ALLERGY"), (26, 35, "ALLERGY"), (40, 49, "ALLERGY")]}),
    ("He's sensitive to sesame seeds, fish, and dairy.", {"entities": [(14, 25, "ALLERGY"), (27, 31, "ALLERGY"), (36, 41, "ALLERGY")]}),
    ("I suffer from allergies to wheat gluten, peanuts, and eggs.", {"entities": [(23, 34, "ALLERGY"), (36, 43, "ALLERGY"), (48, 52, "ALLERGY")]}),
    ("She's allergic to soy, dairy, and peanuts.", {"entities": [(14, 17, "ALLERGY"), (19, 24, "ALLERGY"), (29, 36, "ALLERGY")]}),
    ("He has allergies to fish, sesame seeds, and wheat gluten.", {"entities": [(14, 18, "ALLERGY"), (20, 31, "ALLERGY"), (36, 47, "ALLERGY")]}),
    ("I'm allergic to shellfish, dairy, and eggs.", {"entities": [(13, 22, "ALLERGY"), (24, 29, "ALLERGY"), (34, 38, "ALLERGY")]}),
    ("She has allergies to wheat gluten, tree nuts, and soy.", {"entities": [(20, 31, "ALLERGY"), (33, 42, "ALLERGY"), (47, 50, "ALLERGY")]}),
    ("He's sensitive to peanuts, soy, and shellfish.", {"entities": [(14, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 40, "ALLERGY")]}),
    ("I suffer from allergies to dairy, wheat gluten, and eggs.", {"entities": [(23, 28, "ALLERGY"), (30, 41, "ALLERGY"), (46, 50, "ALLERGY")]}),
    ("She's allergic to fish, tree nuts, and dairy.", {"entities": [(14, 18, "ALLERGY"), (20, 29, "ALLERGY"), (34, 39, "ALLERGY")]}),
    ("He has allergies to sesame seeds, dairy, and peanuts.", {"entities": [(14, 25, "ALLERGY"), (27, 32, "ALLERGY"), (37, 44, "ALLERGY")]}),
    ("I'm allergic to wheat gluten, peanuts, and soy.", {"entities": [(13, 24, "ALLERGY"), (26, 33, "ALLERGY"), (38, 41, "ALLERGY")]}),
    ("She has allergies to shellfish, tree nuts, and sesame seeds.", {"entities": [(20, 29, "ALLERGY"), (31, 40, "ALLERGY"), (45, 56, "ALLERGY")]}),
    ("He's sensitive to dairy, peanuts, and eggs.", {"entities": [(14, 18, "ALLERGY"), (20, 27, "ALLERGY"), (32, 36, "ALLERGY")]}),
    ("I suffer from allergies to wheat gluten, soy, and shellfish.", {"entities": [(23, 34, "ALLERGY"), (36, 39, "ALLERGY"), (44, 53, "ALLERGY")]}),
    ("She's allergic to sesame seeds, fish, and dairy.", {"entities": [(14, 25, "ALLERGY"), (27, 31, "ALLERGY"), (36, 41, "ALLERGY")]}),
    ("He has allergies to tree nuts, dairy, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 29, "ALLERGY"), (34, 37, "ALLERGY")]}),
    ("I'm allergic to eggs, shellfish, and tree nuts.", {"entities": [(13, 17, "ALLERGY"), (19, 28, "ALLERGY"), (33, 42, "ALLERGY")]}),
    ("She has allergies to soy, wheat gluten, and dairy.", {"entities": [(20, 23, "ALLERGY"), (25, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("He's sensitive to shellfish, peanuts, and wheat gluten.", {"entities": [(14, 23, "ALLERGY"), (25, 32, "ALLERGY"), (37, 48, "ALLERGY")]}),
    ("I suffer from allergies to sesame seeds, dairy, and shellfish.", {"entities": [(23, 34, "ALLERGY"), (36, 41, "ALLERGY"), (46, 55, "ALLERGY")]}),
    ("She's allergic to eggs, soy, and peanuts.", {"entities": [(14, 18, "ALLERGY"), (20, 23, "ALLERGY"), (28, 35, "ALLERGY")]}),
    ("He has allergies to milk, shellfish, and tree nuts.", {"entities": [(14, 18, "ALLERGY"), (20, 29, "ALLERGY"), (34, 43, "ALLERGY")]}),
    ("I'm allergic to wheat gluten, peanuts, and soy.", {"entities": [(13, 24, "ALLERGY"), (26, 33, "ALLERGY"), (38, 41, "ALLERGY")]}),
    ("She has allergies to sesame seeds, dairy, and tree nuts.", {"entities": [(20, 31, "ALLERGY"), (33, 38, "ALLERGY"), (43, 52, "ALLERGY")]}),
    ("He's sensitive to shellfish, soy, and wheat gluten.", {"entities": [(14, 23, "ALLERGY"), (25, 28, "ALLERGY"), (33, 44, "ALLERGY")]}),
    ("I suffer from allergies to eggs, peanuts, and fish.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 45, "ALLERGY")]}),
    ("She's allergic to dairy, wheat gluten, and sesame seeds.", {"entities": [(14, 18, "ALLERGY"), (20, 31, "ALLERGY"), (36, 47, "ALLERGY")]}),
    ("He has allergies to milk, peanuts, and soy.", {"entities": [(14, 18, "ALLERGY"), (20, 27, "ALLERGY"), (32, 35, "ALLERGY")]}),
    ("I'm allergic to tree nuts, fish, and wheat gluten.", {"entities": [(13, 22, "ALLERGY"), (24, 28, "ALLERGY"), (33, 44, "ALLERGY")]}),
    ("She has allergies to wheat gluten, soy, and peanuts.", {"entities": [(20, 31, "ALLERGY"), (33, 36, "ALLERGY"), (41, 48, "ALLERGY")]}),
    ("He's sensitive to shellfish, dairy, and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (25, 29, "ALLERGY"), (34, 43, "ALLERGY")]}),
    ("I suffer from allergies to sesame seeds, peanuts, and eggs.", {"entities": [(23, 34, "ALLERGY"), (36, 43, "ALLERGY"), (48, 52, "ALLERGY")]}),
    ("She's allergic to dairy, soy, and shellfish.", {"entities": [(14, 18, "ALLERGY"), (20, 23, "ALLERGY"), (28, 37, "ALLERGY")]}),
    ("He has allergies to wheat gluten, peanuts, and sesame seeds.", {"entities": [(14, 25, "ALLERGY"), (27, 34, "ALLERGY"), (39, 50, "ALLERGY")]}),
    ("I'm allergic to tree nuts, dairy, and soy.", {"entities": [(13, 22, "ALLERGY"), (24, 29, "ALLERGY"), (34, 37, "ALLERGY")]}),
    ("She has allergies to fish, wheat gluten, and shellfish.", {"entities": [(20, 24, "ALLERGY"), (26, 37, "ALLERGY"), (42, 51, "ALLERGY")]}),
    ("He's sensitive to peanuts, sesame seeds, and dairy.", {"entities": [(14, 21, "ALLERGY"), (23, 34, "ALLERGY"), (39, 44, "ALLERGY")]}),
    ("I suffer from allergies to eggs, soy, and tree nuts.", {"entities": [(23, 27, "ALLERGY"), (29, 32, "ALLERGY"), (37, 46, "ALLERGY")]}),
    ("She's allergic to dairy, wheat gluten, and peanuts.", {"entities": [(14, 18, "ALLERGY"), (20, 31, "ALLERGY"), (36, 43, "ALLERGY")]}),
    ("He has allergies to milk, sesame seeds, and soy.", {"entities": [(14, 18, "ALLERGY"), (20, 31, "ALLERGY"), (36, 39, "ALLERGY")]}),
    ("I'm allergic to wheat gluten, fish, and sesame seeds.", {"entities": [(13, 24, "ALLERGY"), (26, 30, "ALLERGY"), (35, 46, "ALLERGY")]}),
    ("She has allergies to peanuts, shellfish, and soy.", {"entities": [(20, 27, "ALLERGY"), (29, 38, "ALLERGY"), (43, 46, "ALLERGY")]}),
    ("He's sensitive to dairy, peanuts, and eggs.", {"entities": [(14, 18, "ALLERGY"), (20, 27, "ALLERGY"), (32, 36, "ALLERGY")]}),
    ("I suffer from allergies to wheat gluten, soy, and shellfish.", {"entities": [(23, 34, "ALLERGY"), (36, 39, "ALLERGY"), (44, 53, "ALLERGY")]}),
    ("She's allergic to sesame seeds, peanuts, and dairy.", {"entities": [(14, 25, "ALLERGY"), (27, 34, "ALLERGY"), (39, 44, "ALLERGY")]}),
    ("He has allergies to tree nuts, dairy, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 29, "ALLERGY"), (34, 37, "ALLERGY")]}),
    ("I'm allergic to eggs, shellfish, and tree nuts.", {"entities": [(13, 17, "ALLERGY"), (19, 28, "ALLERGY"), (33, 42, "ALLERGY")]}),
    ("She has allergies to soy, dairy, and wheat gluten.", {"entities": [(20, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 46, "ALLERGY")]}),
    ("He's sensitive to peanuts, wheat gluten, and shellfish.", {"entities": [(14, 21, "ALLERGY"), (23, 34, "ALLERGY"), (39, 48, "ALLERGY")]}),
    ("I suffer from allergies to eggs, peanuts, and dairy.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to fish, tree nuts, and sesame seeds.", {"entities": [(14, 18, "ALLERGY"), (20, 29, "ALLERGY"), (34, 45, "ALLERGY")]}),
    ("He has allergies to wheat gluten, peanuts, and dairy.", {"entities": [(14, 25, "ALLERGY"), (27, 34, "ALLERGY"), (39, 44, "ALLERGY")]}),
    ("I'm allergic to soy, eggs, and peanuts.", {"entities": [(13, 16, "ALLERGY"), (18, 22, "ALLERGY"), (27, 36, "ALLERGY")]}),
    ("She has allergies to milk, tree nuts, and peanuts.", {"entities": [(20, 24, "ALLERGY"), (26, 35, "ALLERGY"), (40, 47, "ALLERGY")]}),
    ("He's sensitive to sesame seeds, dairy, and soy.", {"entities": [(14, 25, "ALLERGY"), (27, 32, "ALLERGY"), (37, 40, "ALLERGY")]}),
    ("I suffer from allergies to fish, eggs, and wheat gluten.", {"entities": [(23, 27, "ALLERGY"), (29, 33, "ALLERGY"), (38, 49, "ALLERGY")]}),
    ("She's allergic to shellfish, soy, and dairy.", {"entities": [(14, 23, "ALLERGY"), (25, 28, "ALLERGY"), (33, 38, "ALLERGY")]}),
    ("He has allergies to peanuts, sesame seeds, and fish.", {"entities": [(14, 21, "ALLERGY"), (23, 34, "ALLERGY"), (39, 43, "ALLERGY")]}),
    ("I'm allergic to tree nuts, wheat gluten, and eggs.", {"entities": [(13, 22, "ALLERGY"), (24, 35, "ALLERGY"), (40, 44, "ALLERGY")]}),
    ("She has allergies to dairy, peanuts, and sesame seeds.", {"entities": [(20, 24, "ALLERGY"), (26, 33, "ALLERGY"), (38, 49, "ALLERGY")]}),
    ("He's sensitive to fish, wheat gluten, and tree nuts.", {"entities": [(14, 18, "ALLERGY"), (20, 31, "ALLERGY"), (36, 45, "ALLERGY")]}),
    ("I suffer from allergies to peanuts, soy, and dairy.", {"entities": [(23, 30, "ALLERGY"), (32, 35, "ALLERGY"), (40, 45, "ALLERGY")]}),
    ("She's allergic to sesame seeds, fish, and shellfish.", {"entities": [(14, 25, "ALLERGY"), (27, 31, "ALLERGY"), (36, 45, "ALLERGY")]}),
    ("He has allergies to wheat gluten, tree nuts, and dairy.", {"entities": [(14, 25, "ALLERGY"), (27, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("I'm allergic to soy, eggs, and peanuts.", {"entities": [(13, 16, "ALLERGY"), (18, 22, "ALLERGY"), (27, 34, "ALLERGY")]}),
    ("She has allergies to milk, shellfish, and wheat gluten.", {"entities": [(20, 24, "ALLERGY"), (26, 35, "ALLERGY"), (40, 51, "ALLERGY")]}),
    ("He's sensitive to tree nuts, dairy, and sesame seeds.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 46, "ALLERGY")]}),
    ("I suffer from allergies to fish, soy, and peanuts.", {"entities": [(23, 27, "ALLERGY"), (29, 32, "ALLERGY"), (37, 44, "ALLERGY")]}),
    ("She's allergic to wheat gluten, dairy, and eggs.", {"entities": [(14, 25, "ALLERGY"), (27, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has allergies to sesame seeds, soy, and tree nuts.", {"entities": [(14, 25, "ALLERGY"), (27, 30, "ALLERGY"), (35, 44, "ALLERGY")]}),
    ("I'm allergic to shellfish, wheat gluten, and soy.", {"entities": [(13, 22, "ALLERGY"), (24, 35, "ALLERGY"), (40, 43, "ALLERGY")]}),
    ("She has allergies to dairy, peanuts, and fish.", {"entities": [(20, 24, "ALLERGY"), (26, 33, "ALLERGY"), (38, 42, "ALLERGY")]}),
    ("He's sensitive to eggs, tree nuts, and sesame seeds.", {"entities": [(14, 18, "ALLERGY"), (20, 29, "ALLERGY"), (34, 45, "ALLERGY")]}),
    ("I suffer from allergies to soy, wheat gluten, and dairy.", {"entities": [(23, 26, "ALLERGY"), (28, 39, "ALLERGY"), (44, 49, "ALLERGY")]}),
    ("She's allergic to fish, eggs, and peanuts.", {"entities": [(14, 18, "ALLERGY"), (20, 24, "ALLERGY"), (29, 36, "ALLERGY")]}),
    ("He has allergies to shellfish, soy, and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (25, 28, "ALLERGY"), (33, 42, "ALLERGY")]}),
    ("I'm allergic to dairy, sesame seeds, and wheat gluten.", {"entities": [(13, 17, "ALLERGY"), (19, 30, "ALLERGY"), (35, 46, "ALLERGY")]}),
    ("She has allergies to peanuts, fish, and dairy.", {"entities": [(20, 27, "ALLERGY"), (29, 33, "ALLERGY"), (38, 43, "ALLERGY")]}),
    ("He's sensitive to eggs, wheat gluten, and soy.", {"entities": [(14, 18, "ALLERGY"), (20, 31, "ALLERGY"), (36, 39, "ALLERGY")]}),
    ("I suffer from allergies to shellfish, tree nuts, and peanuts.", {"entities": [(23, 32, "ALLERGY"), (34, 43, "ALLERGY"), (48, 55, "ALLERGY")]}),
    ("She's allergic to milk, soy, and sesame seeds.", {"entities": [(14, 18, "ALLERGY"), (20, 23, "ALLERGY"), (28, 39, "ALLERGY")]}),
    ("He has allergies to peanuts, shellfish, and wheat gluten.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 48, "ALLERGY")]}),
    ("I'm allergic to eggs, dairy, and soy.", {"entities": [(13, 17, "ALLERGY"), (19, 24, "ALLERGY"), (29, 32, "ALLERGY")]}),
    ("She has allergies to wheat gluten, peanuts, and shellfish.", {"entities": [(20, 31, "ALLERGY"), (33, 40, "ALLERGY"), (45, 54, "ALLERGY")]}),
    ("He's sensitive to fish, dairy, and tree nuts.", {"entities": [(14, 18, "ALLERGY"), (20, 25, "ALLERGY"), (30, 39, "ALLERGY")]}),
    ("I suffer from allergies to soy, sesame seeds, and eggs.", {"entities": [(23, 26, "ALLERGY"), (28, 39, "ALLERGY"), (44, 48, "ALLERGY")]}),
    ("She's allergic to tree nuts, wheat gluten, and dairy.", {"entities": [(14, 23, "ALLERGY"), (25, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("He has allergies to peanuts, eggs, and sesame seeds.", {"entities": [(14, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 43, "ALLERGY")]}),
    ("I'm allergic to fish, dairy, and soy.", {"entities": [(13, 17, "ALLERGY"), (19, 24, "ALLERGY"), (29, 32, "ALLERGY")]}),
    ("She has allergies to wheat gluten, peanuts, and tree nuts.", {"entities": [(20, 31, "ALLERGY"), (33, 40, "ALLERGY"), (45, 54, "ALLERGY")]}),
    ("He's sensitive to shellfish, soy, and eggs.", {"entities": [(14, 23, "ALLERGY"), (25, 28, "ALLERGY"), (33, 37, "ALLERGY")]}),
    ("I suffer from allergies to milk, sesame seeds, and fish.", {"entities": [(23, 27, "ALLERGY"), (29, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("I suffer from allergies to milk, sesame seeds, and fish.", {"entities": [(23, 27, "ALLERGY"), (29, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to peanuts, shellfish, and soy.", {"entities": [(20, 27, "ALLERGY"), (29, 38, "ALLERGY"), (43, 46, "ALLERGY")]}),
    ("He's sensitive to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to peanuts and pollen.", {"entities": [(23, 30, "ALLERGY"), (35, 41, "ALLERGY")]}),
    ("She's allergic to cat dander.", {"entities": [(14, 22, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("He's sensitive to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("I'm allergic to penicillin.", {"entities": [(13, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("She has allergies to dairy and dust mites.", {"entities": [(20, 25, "ALLERGY"), (30, 40, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to wheat.", {"entities": [(13, 21, "ALLERGY"), (25, 30, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts and cats.", {"entities": [(23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("She has allergies to dust mites and dairy.", {"entities": [(20, 30, "ALLERGY"), (35, 40, "ALLERGY")]}),
    ("He's sensitive to dog saliva.", {"entities": [(14, 23, "ALLERGY"), (27, 36, "ALLERGY")]}),
    ("I suffer from allergies to pollen and fish.", {"entities": [(23, 29, "ALLERGY"), (34, 38, "ALLERGY")]}),
    ("She's allergic to peanuts and shellfish.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I suffer from allergies to fish, ragweed, and latex.", {"entities": [(23, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("She's allergic to peanuts, shellfish, and cats.", {"entities": [(14, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 41, "ALLERGY")]}),
    ("He has an allergy to pollen.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 21, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("She's allergic to bee stings.", {"entities": [(14, 22, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has an allergy to shellfish.", {"entities": [(14, 21, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to gluten.", {"entities": [(13, 21, "ALLERGY"), (25, 31, "ALLERGY")]}),
    ("She's allergic to mold.", {"entities": [(14, 22, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's sensitive to grass.", {"entities": [(14, 22, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts, pollen, and cats.", {"entities": [(23, 32, "ALLERGY"), (34, 40, "ALLERGY"), (45, 49, "ALLERGY")]}),
    ("She has allergies to dust mites, dairy products, and peanuts.", {"entities": [(20, 30, "ALLERGY"), (32, 46, "ALLERGY"), (51, 58, "ALLERGY")]}),
    ("He's sensitive to dog saliva, wheat, and soy.", {"entities": [(14, 23, "ALLERGY"), (25, 30, "ALLERGY"), (35, 38, "ALLERGY")]}),
    ("I have allergies to peanuts and pollen.", {"entities": [(16, 23, "ALLERGY"), (28, 34, "ALLERGY")]}),
    ("She's allergic to cats and dust mites.", {"entities": [(14, 17, "ALLERGY"), (22, 32, "ALLERGY")]}),
    ("He's sensitive to shellfish and grass pollen.", {"entities": [(14, 23, "ALLERGY"), (28, 39, "ALLERGY")]}),
    ("I suffer from allergies to dairy and ragweed.", {"entities": [(23, 28, "ALLERGY"), (33, 40, "ALLERGY")]}),
    ("She has an allergy to dogs and tree nuts.", {"entities": [(19, 23, "ALLERGY"), (28, 37, "ALLERGY")]}),
    ("He's allergic to soy and bee stings.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("I'm allergic to gluten and penicillin.", {"entities": [(13, 19, "ALLERGY"), (24, 35, "ALLERGY")]}),
    ("She's allergic to fish and mold.", {"entities": [(14, 18, "ALLERGY"), (23, 27, "ALLERGY")]}),
    ("He's sensitive to peanuts and pollen.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("I suffer from allergies to shellfish and pet dander.", {"entities": [(23, 32, "ALLERGY"), (37, 47, "ALLERGY")]}),
    ("She has allergies to dairy and grass.", {"entities": [(20, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("He's allergic to cats and pollen.", {"entities": [(14, 17, "ALLERGY"), (22, 28, "ALLERGY")]}),
    ("I have allergies to soy and bee stings.", {"entities": [(16, 19, "ALLERGY"), (24, 33, "ALLERGY")]}),
    ("She's sensitive to peanuts and mold.", {"entities": [(14, 21, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's allergic to shellfish and grass.", {"entities": [(14, 23, "ALLERGY"), (28, 33, "ALLERGY")]}),
    ("I'm allergic to dairy and ragweed.", {"entities": [(13, 18, "ALLERGY"), (23, 30, "ALLERGY")]}),
    ("She's allergic to fish and tree nuts.", {"entities": [(14, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("He has an allergy to gluten and pollen.", {"entities": [(19, 25, "ALLERGY"), (30, 36, "ALLERGY")]}),
    ("I suffer from allergies to peanuts and mold.", {"entities": [(23, 30, "ALLERGY"), (35, 39, "ALLERGY")]}),
    ("She's allergic to soy and grass pollen.", {"entities": [(14, 17, "ALLERGY"), (22, 32, "ALLERGY")]}),
    ("He's sensitive to cat dander and bee stings.", {"entities": [(14, 24, "ALLERGY"), (29, 38, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts and pollen.", {"entities": [(23, 32, "ALLERGY"), (37, 43, "ALLERGY")]}),
    ("She has an allergy to dust mites and shellfish.", {"entities": [(20, 30, "ALLERGY"), (35, 44, "ALLERGY")]}),
    ("He's allergic to wheat and ragweed.", {"entities": [(14, 19, "ALLERGY"), (24, 31, "ALLERGY")]}),
    ("I'm allergic to sesame seeds and cats.", {"entities": [(13, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("She's allergic to peanuts and latex.", {"entities": [(14, 21, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("He has an allergy to shellfish and dogs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I suffer from allergies to pollen and chocolate.", {"entities": [(23, 29, "ALLERGY"), (34, 43, "ALLERGY")]}),
    ("She's allergic to strawberries and dust mites.", {"entities": [(14, 25, "ALLERGY"), (30, 40, "ALLERGY")]}),
    ("He's sensitive to fish and grass pollen.", {"entities": [(14, 18, "ALLERGY"), (23, 33, "ALLERGY")]}),
    ("I'm allergic to dairy and dog saliva.", {"entities": [(13, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("She's allergic to shellfish and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 37, "ALLERGY")]}),
    ("He has an allergy to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to soy and cats.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has allergies to wheat and dust mites.", {"entities": [(20, 25, "ALLERGY"), (30, 40, "ALLERGY")]}),
    ("He's allergic to pollen and tree nuts.", {"entities": [(14, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to peanuts and fish.", {"entities": [(13, 20, "ALLERGY"), (25, 29, "ALLERGY")]}),
    ("She's allergic to sesame seeds and latex.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("He has an allergy to dairy and dogs.", {"entities": [(14, 19, "ALLERGY"), (24, 28, "ALLERGY")]}),
    ("I suffer from allergies to shellfish and grass.", {"entities": [(23, 32, "ALLERGY"), (37, 42, "ALLERGY")]}),
    ("She's allergic to pollen and cat dander.", {"entities": [(14, 20, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("I suffer from allergies to peanuts and pollen.", {"entities": [(23, 30, "ALLERGY"), (35, 41, "ALLERGY")]}),
    ("She's allergic to cats and dust mites.", {"entities": [(14, 17, "ALLERGY"), (22, 32, "ALLERGY")]}),
    ("He's sensitive to shellfish and grass pollen.", {"entities": [(14, 23, "ALLERGY"), (28, 39, "ALLERGY")]}),
    ("I have allergies to dairy and ragweed.", {"entities": [(23, 28, "ALLERGY"), (33, 40, "ALLERGY")]}),
    ("She has an allergy to dogs and tree nuts.", {"entities": [(19, 23, "ALLERGY"), (28, 37, "ALLERGY")]}),
    ("He's allergic to soy and bee stings.", {"entities": [(14, 17, "ALLERGY"), (22, 31, "ALLERGY")]}),
    ("I'm allergic to gluten and penicillin.", {"entities": [(13, 19, "ALLERGY"), (24, 35, "ALLERGY")]}),
    ("She's allergic to fish and mold.", {"entities": [(14, 18, "ALLERGY"), (23, 27, "ALLERGY")]}),
    ("He's sensitive to peanuts and pollen.", {"entities": [(14, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("I suffer from allergies to shellfish and pet dander.", {"entities": [(23, 32, "ALLERGY"), (37, 47, "ALLERGY")]}),
    ("She has allergies to dairy and grass.", {"entities": [(20, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("He's allergic to cats and pollen.", {"entities": [(14, 17, "ALLERGY"), (22, 28, "ALLERGY")]}),
    ("I have allergies to soy and bee stings.", {"entities": [(16, 19, "ALLERGY"), (24, 33, "ALLERGY")]}),
    ("She's sensitive to peanuts and mold.", {"entities": [(14, 21, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("He's allergic to shellfish and grass.", {"entities": [(14, 23, "ALLERGY"), (28, 33, "ALLERGY")]}),
    ("I'm allergic to dairy and ragweed.", {"entities": [(13, 18, "ALLERGY"), (23, 30, "ALLERGY")]}),
    ("She's allergic to fish and tree nuts.", {"entities": [(14, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("He has an allergy to gluten and pollen.", {"entities": [(19, 25, "ALLERGY"), (30, 36, "ALLERGY")]}),
    ("I suffer from allergies to peanuts and mold.", {"entities": [(23, 30, "ALLERGY"), (35, 39, "ALLERGY")]}),
    ("She's allergic to soy and grass pollen.", {"entities": [(14, 17, "ALLERGY"), (22, 32, "ALLERGY")]}),
    ("He's sensitive to cat dander and bee stings.", {"entities": [(14, 24, "ALLERGY"), (29, 38, "ALLERGY")]}),
    ("I suffer from allergies to tree nuts and pollen.", {"entities": [(23, 32, "ALLERGY"), (37, 43, "ALLERGY")]}),
    ("She has an allergy to dust mites and shellfish.", {"entities": [(20, 30, "ALLERGY"), (35, 44, "ALLERGY")]}),
    ("He's allergic to wheat and ragweed.", {"entities": [(14, 19, "ALLERGY"), (24, 31, "ALLERGY")]}),
    ("I'm allergic to sesame seeds and cats.", {"entities": [(13, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("She's allergic to peanuts and latex.", {"entities": [(14, 21, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("He has an allergy to shellfish and dogs.", {"entities": [(14, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("I suffer from allergies to pollen and chocolate.", {"entities": [(23, 29, "ALLERGY"), (34, 43, "ALLERGY")]}),
    ("She's allergic to strawberries and dust mites.", {"entities": [(14, 25, "ALLERGY"), (30, 40, "ALLERGY")]}),
    ("He's sensitive to fish and grass pollen.", {"entities": [(14, 18, "ALLERGY"), (23, 33, "ALLERGY")]}),
    ("I'm allergic to dairy and dog saliva.", {"entities": [(13, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("She's allergic to shellfish and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 37, "ALLERGY")]}),
    ("He has an allergy to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to soy and cats.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has allergies to wheat and dust mites.", {"entities": [(20, 25, "ALLERGY"), (30, 40, "ALLERGY")]}),
    ("He's allergic to pollen and tree nuts.", {"entities": [(14, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to peanuts and fish.", {"entities": [(13, 20, "ALLERGY"), (25, 29, "ALLERGY")]}),
    ("She's allergic to sesame seeds and latex.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("He has an allergy to dairy and dogs.", {"entities": [(14, 19, "ALLERGY"), (24, 28, "ALLERGY")]}),
    ("I suffer from allergies to shellfish and grass.", {"entities": [(23, 32, "ALLERGY"), (37, 42, "ALLERGY")]}),
    ("She's allergic to pollen and cat dander.", {"entities": [(14, 20, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("He's sensitive to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to cats and mold.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has an allergy to tree nuts and latex.", {"entities": [(20, 29, "ALLERGY"), (34, 39, "ALLERGY")]}),
    ("He's allergic to fish and grass pollen.", {"entities": [(14, 18, "ALLERGY"), (23, 33, "ALLERGY")]}),
    ("I'm allergic to dairy and dog saliva.", {"entities": [(13, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("She's allergic to shellfish and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 37, "ALLERGY")]}),
    ("He has an allergy to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to soy and cats.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has allergies to wheat and dust mites.", {"entities": [(20, 25, "ALLERGY"), (30, 40, "ALLERGY")]}),
    ("He's allergic to pollen and tree nuts.", {"entities": [(14, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to peanuts and fish.", {"entities": [(13, 20, "ALLERGY"), (25, 29, "ALLERGY")]}),
    ("She's allergic to sesame seeds and latex.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("He has an allergy to dairy and dogs.", {"entities": [(14, 19, "ALLERGY"), (24, 28, "ALLERGY")]}),
    ("I suffer from allergies to shellfish and grass.", {"entities": [(23, 32, "ALLERGY"), (37, 42, "ALLERGY")]}),
    ("She's allergic to pollen and cat dander.", {"entities": [(14, 20, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("He's sensitive to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to cats and mold.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has an allergy to tree nuts and latex.", {"entities": [(20, 29, "ALLERGY"), (34, 39, "ALLERGY")]}),
    ("He's allergic to fish and grass pollen.", {"entities": [(14, 18, "ALLERGY"), (23, 33, "ALLERGY")]}),
    ("I'm allergic to dairy and dog saliva.", {"entities": [(13, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("She's allergic to shellfish and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 37, "ALLERGY")]}),
    ("He has an allergy to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to soy and cats.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has allergies to wheat and dust mites.", {"entities": [(20, 25, "ALLERGY"), (30, 40, "ALLERGY")]}),
    ("He's allergic to pollen and tree nuts.", {"entities": [(14, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to peanuts and fish.", {"entities": [(13, 20, "ALLERGY"), (25, 29, "ALLERGY")]}),
    ("She's allergic to sesame seeds and latex.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("He has an allergy to dairy and dogs.", {"entities": [(14, 19, "ALLERGY"), (24, 28, "ALLERGY")]}),
    ("I suffer from allergies to shellfish and grass.", {"entities": [(23, 32, "ALLERGY"), (37, 42, "ALLERGY")]}),
    ("She's allergic to pollen and cat dander.", {"entities": [(14, 20, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("He's sensitive to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to cats and mold.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has an allergy to tree nuts and latex.", {"entities": [(20, 29, "ALLERGY"), (34, 39, "ALLERGY")]}),
    ("He's allergic to fish and grass pollen.", {"entities": [(14, 18, "ALLERGY"), (23, 33, "ALLERGY")]}),
    ("I'm allergic to dairy and dog saliva.", {"entities": [(13, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("She's allergic to shellfish and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 37, "ALLERGY")]}),
    ("He has an allergy to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to soy and cats.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has allergies to wheat and dust mites.", {"entities": [(20, 25, "ALLERGY"), (30, 40, "ALLERGY")]}),
    ("He's allergic to pollen and tree nuts.", {"entities": [(14, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to peanuts and fish.", {"entities": [(13, 20, "ALLERGY"), (25, 29, "ALLERGY")]}),
    ("She's allergic to sesame seeds and latex.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("He has an allergy to dairy and dogs.", {"entities": [(14, 19, "ALLERGY"), (24, 28, "ALLERGY")]}),
    ("I suffer from allergies to shellfish and grass.", {"entities": [(23, 32, "ALLERGY"), (37, 42, "ALLERGY")]}),
    ("She's allergic to pollen and cat dander.", {"entities": [(14, 20, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("He's sensitive to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to cats and mold.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has an allergy to tree nuts and latex.", {"entities": [(20, 29, "ALLERGY"), (34, 39, "ALLERGY")]}),
    ("He's allergic to fish and grass pollen.", {"entities": [(14, 18, "ALLERGY"), (23, 33, "ALLERGY")]}),
    ("I'm allergic to dairy and dog saliva.", {"entities": [(13, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("She's allergic to shellfish and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 37, "ALLERGY")]}),
    ("He has an allergy to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to soy and cats.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has allergies to wheat and dust mites.", {"entities": [(20, 25, "ALLERGY"), (30, 40, "ALLERGY")]}),
    ("He's allergic to pollen and tree nuts.", {"entities": [(14, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to peanuts and fish.", {"entities": [(13, 20, "ALLERGY"), (25, 29, "ALLERGY")]}),
    ("She's allergic to sesame seeds and latex.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("He has an allergy to dairy and dogs.", {"entities": [(14, 19, "ALLERGY"), (24, 28, "ALLERGY")]}),
    ("I suffer from allergies to shellfish and grass.", {"entities": [(23, 32, "ALLERGY"), (37, 42, "ALLERGY")]}),
    ("She's allergic to pollen and cat dander.", {"entities": [(14, 20, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("He's sensitive to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to cats and mold.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has an allergy to tree nuts and latex.", {"entities": [(20, 29, "ALLERGY"), (34, 39, "ALLERGY")]}),
    ("He's allergic to fish and grass pollen.", {"entities": [(14, 18, "ALLERGY"), (23, 33, "ALLERGY")]}),
    ("I'm allergic to dairy and dog saliva.", {"entities": [(13, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("She's allergic to shellfish and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 37, "ALLERGY")]}),
    ("He has an allergy to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to soy and cats.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has allergies to wheat and dust mites.", {"entities": [(20, 25, "ALLERGY"), (30, 40, "ALLERGY")]}),
    ("He's allergic to pollen and tree nuts.", {"entities": [(14, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to peanuts and fish.", {"entities": [(13, 20, "ALLERGY"), (25, 29, "ALLERGY")]}),
    ("She's allergic to sesame seeds and latex.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("He has an allergy to dairy and dogs.", {"entities": [(14, 19, "ALLERGY"), (24, 28, "ALLERGY")]}),
    ("I suffer from allergies to shellfish and grass.", {"entities": [(23, 32, "ALLERGY"), (37, 42, "ALLERGY")]}),
    ("She's allergic to pollen and cat dander.", {"entities": [(14, 20, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("He's sensitive to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to cats and mold.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has an allergy to tree nuts and latex.", {"entities": [(20, 29, "ALLERGY"), (34, 39, "ALLERGY")]}),
    ("He's allergic to fish and grass pollen.", {"entities": [(14, 18, "ALLERGY"), (23, 33, "ALLERGY")]}),
    ("I'm allergic to dairy and dog saliva.", {"entities": [(13, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("She's allergic to shellfish and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 37, "ALLERGY")]}),
    ("He has an allergy to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to soy and cats.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has allergies to wheat and dust mites.", {"entities": [(20, 25, "ALLERGY"), (30, 40, "ALLERGY")]}),
    ("He's allergic to pollen and tree nuts.", {"entities": [(14, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to peanuts and fish.", {"entities": [(13, 20, "ALLERGY"), (25, 29, "ALLERGY")]}),
    ("She's allergic to sesame seeds and latex.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("He has an allergy to dairy and dogs.", {"entities": [(14, 19, "ALLERGY"), (24, 28, "ALLERGY")]}),
    ("I suffer from allergies to shellfish and grass.", {"entities": [(23, 32, "ALLERGY"), (37, 42, "ALLERGY")]}),
    ("She's allergic to pollen and cat dander.", {"entities": [(14, 20, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("He's sensitive to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to cats and mold.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has an allergy to tree nuts and latex.", {"entities": [(20, 29, "ALLERGY"), (34, 39, "ALLERGY")]}),
    ("He's allergic to fish and grass pollen.", {"entities": [(14, 18, "ALLERGY"), (23, 33, "ALLERGY")]}),
    ("I'm allergic to dairy and dog saliva.", {"entities": [(13, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("She's allergic to shellfish and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 37, "ALLERGY")]}),
    ("He has an allergy to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to soy and cats.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has allergies to wheat and dust mites.", {"entities": [(20, 25, "ALLERGY"), (30, 40, "ALLERGY")]}),
    ("He's allergic to pollen and tree nuts.", {"entities": [(14, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to peanuts and fish.", {"entities": [(13, 20, "ALLERGY"), (25, 29, "ALLERGY")]}),
    ("She's allergic to sesame seeds and latex.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("He has an allergy to dairy and dogs.", {"entities": [(14, 19, "ALLERGY"), (24, 28, "ALLERGY")]}),
    ("I suffer from allergies to shellfish and grass.", {"entities": [(23, 32, "ALLERGY"), (37, 42, "ALLERGY")]}),
    ("She's allergic to pollen and cat dander.", {"entities": [(14, 20, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("He's sensitive to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to cats and mold.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has an allergy to tree nuts and latex.", {"entities": [(20, 29, "ALLERGY"), (34, 39, "ALLERGY")]}),
    ("He's allergic to fish and grass pollen.", {"entities": [(14, 18, "ALLERGY"), (23, 33, "ALLERGY")]}),
    ("I'm allergic to dairy and dog saliva.", {"entities": [(13, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("She's allergic to shellfish and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 37, "ALLERGY")]}),
    ("He has an allergy to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to soy and cats.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has allergies to wheat and dust mites.", {"entities": [(20, 25, "ALLERGY"), (30, 40, "ALLERGY")]}),
    ("He's allergic to pollen and tree nuts.", {"entities": [(14, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to peanuts and fish.", {"entities": [(13, 20, "ALLERGY"), (25, 29, "ALLERGY")]}),
    ("She's allergic to sesame seeds and latex.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("He has an allergy to dairy and dogs.", {"entities": [(14, 19, "ALLERGY"), (24, 28, "ALLERGY")]}),
    ("I suffer from allergies to shellfish and grass.", {"entities": [(23, 32, "ALLERGY"), (37, 42, "ALLERGY")]}),
    ("She's allergic to pollen and cat dander.", {"entities": [(14, 20, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("He's sensitive to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to cats and mold.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has an allergy to tree nuts and latex.", {"entities": [(20, 29, "ALLERGY"), (34, 39, "ALLERGY")]}),
    ("He's allergic to fish and grass pollen.", {"entities": [(14, 18, "ALLERGY"), (23, 33, "ALLERGY")]}),
    ("I'm allergic to dairy and dog saliva.", {"entities": [(13, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("She's allergic to shellfish and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 37, "ALLERGY")]}),
    ("He has an allergy to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to soy and cats.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has allergies to wheat and dust mites.", {"entities": [(20, 25, "ALLERGY"), (30, 40, "ALLERGY")]}),
    ("He's allergic to pollen and tree nuts.", {"entities": [(14, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to peanuts and fish.", {"entities": [(13, 20, "ALLERGY"), (25, 29, "ALLERGY")]}),
    ("She's allergic to sesame seeds and latex.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("He has an allergy to dairy and dogs.", {"entities": [(14, 19, "ALLERGY"), (24, 28, "ALLERGY")]}),
    ("I suffer from allergies to shellfish and grass.", {"entities": [(23, 32, "ALLERGY"), (37, 42, "ALLERGY")]}),
    ("She's allergic to pollen and cat dander.", {"entities": [(14, 20, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("He's sensitive to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to cats and mold.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has an allergy to tree nuts and latex.", {"entities": [(20, 29, "ALLERGY"), (34, 39, "ALLERGY")]}),
    ("He's allergic to fish and grass pollen.", {"entities": [(14, 18, "ALLERGY"), (23, 33, "ALLERGY")]}),
    ("I'm allergic to dairy and dog saliva.", {"entities": [(13, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("She's allergic to shellfish and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 37, "ALLERGY")]}),
    ("He has an allergy to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to soy and cats.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has allergies to wheat and dust mites.", {"entities": [(20, 25, "ALLERGY"), (30, 40, "ALLERGY")]}),
    ("He's allergic to pollen and tree nuts.", {"entities": [(14, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to peanuts and fish.", {"entities": [(13, 20, "ALLERGY"), (25, 29, "ALLERGY")]}),
    ("She's allergic to sesame seeds and latex.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("He has an allergy to dairy and dogs.", {"entities": [(14, 19, "ALLERGY"), (24, 28, "ALLERGY")]}),
    ("I suffer from allergies to shellfish and grass.", {"entities": [(23, 32, "ALLERGY"), (37, 42, "ALLERGY")]}),
    ("She's allergic to pollen and cat dander.", {"entities": [(14, 20, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("He's sensitive to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to cats and mold.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has an allergy to tree nuts and latex.", {"entities": [(20, 29, "ALLERGY"), (34, 39, "ALLERGY")]}),
    ("He's allergic to fish and grass pollen.", {"entities": [(14, 18, "ALLERGY"), (23, 33, "ALLERGY")]}),
    ("I'm allergic to dairy and dog saliva.", {"entities": [(13, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("She's allergic to shellfish and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 37, "ALLERGY")]}),
    ("He has an allergy to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to soy and cats.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has allergies to wheat and dust mites.", {"entities": [(20, 25, "ALLERGY"), (30, 40, "ALLERGY")]}),
    ("He's allergic to pollen and tree nuts.", {"entities": [(14, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to peanuts and fish.", {"entities": [(13, 20, "ALLERGY"), (25, 29, "ALLERGY")]}),
    ("She's allergic to sesame seeds and latex.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("He has an allergy to dairy and dogs.", {"entities": [(14, 19, "ALLERGY"), (24, 28, "ALLERGY")]}),
    ("I suffer from allergies to shellfish and grass.", {"entities": [(23, 32, "ALLERGY"), (37, 42, "ALLERGY")]}),
    ("She's allergic to pollen and cat dander.", {"entities": [(14, 20, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("He's sensitive to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to cats and mold.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has an allergy to tree nuts and latex.", {"entities": [(20, 29, "ALLERGY"), (34, 39, "ALLERGY")]}),
    ("He's allergic to fish and grass pollen.", {"entities": [(14, 18, "ALLERGY"), (23, 33, "ALLERGY")]}),
    ("I'm allergic to dairy and dog saliva.", {"entities": [(13, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("She's allergic to shellfish and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 37, "ALLERGY")]}),
    ("He has an allergy to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to soy and cats.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has allergies to wheat and dust mites.", {"entities": [(20, 25, "ALLERGY"), (30, 40, "ALLERGY")]}),
    ("He's allergic to pollen and tree nuts.", {"entities": [(14, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to peanuts and fish.", {"entities": [(13, 20, "ALLERGY"), (25, 29, "ALLERGY")]}),
    ("She's allergic to sesame seeds and latex.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("He has an allergy to dairy and dogs.", {"entities": [(14, 19, "ALLERGY"), (24, 28, "ALLERGY")]}),
    ("I suffer from allergies to shellfish and grass.", {"entities": [(23, 32, "ALLERGY"), (37, 42, "ALLERGY")]}),
    ("She's allergic to pollen and cat dander.", {"entities": [(14, 20, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("He's sensitive to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to cats and mold.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has an allergy to tree nuts and latex.", {"entities": [(20, 29, "ALLERGY"), (34, 39, "ALLERGY")]}),
    ("He's allergic to fish and grass pollen.", {"entities": [(14, 18, "ALLERGY"), (23, 33, "ALLERGY")]}),
    ("I'm allergic to dairy and dog saliva.", {"entities": [(13, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("She's allergic to shellfish and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 37, "ALLERGY")]}),
    ("He has an allergy to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to soy and cats.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has allergies to wheat and dust mites.", {"entities": [(20, 25, "ALLERGY"), (30, 40, "ALLERGY")]}),
    ("He's allergic to pollen and tree nuts.", {"entities": [(14, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to peanuts and fish.", {"entities": [(13, 20, "ALLERGY"), (25, 29, "ALLERGY")]}),
    ("She's allergic to sesame seeds and latex.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("He has an allergy to dairy and dogs.", {"entities": [(14, 19, "ALLERGY"), (24, 28, "ALLERGY")]}),
    ("I suffer from allergies to shellfish and grass.", {"entities": [(23, 32, "ALLERGY"), (37, 42, "ALLERGY")]}),
    ("She's allergic to pollen and cat dander.", {"entities": [(14, 20, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("He's sensitive to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to cats and mold.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has an allergy to tree nuts and latex.", {"entities": [(20, 29, "ALLERGY"), (34, 39, "ALLERGY")]}),
    ("He's allergic to fish and grass pollen.", {"entities": [(14, 18, "ALLERGY"), (23, 33, "ALLERGY")]}),
    ("I'm allergic to dairy and dog saliva.", {"entities": [(13, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("She's allergic to shellfish and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 37, "ALLERGY")]}),
    ("He has an allergy to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to soy and cats.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has allergies to wheat and dust mites.", {"entities": [(20, 25, "ALLERGY"), (30, 40, "ALLERGY")]}),
    ("He's allergic to pollen and tree nuts.", {"entities": [(14, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to peanuts and fish.", {"entities": [(13, 20, "ALLERGY"), (25, 29, "ALLERGY")]}),
    ("She's allergic to sesame seeds and latex.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("He has an allergy to dairy and dogs.", {"entities": [(14, 19, "ALLERGY"), (24, 28, "ALLERGY")]}),
    ("I suffer from allergies to shellfish and grass.", {"entities": [(23, 32, "ALLERGY"), (37, 42, "ALLERGY")]}),
    ("She's allergic to pollen and cat dander.", {"entities": [(14, 20, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("He's sensitive to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to cats and mold.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has an allergy to tree nuts and latex.", {"entities": [(20, 29, "ALLERGY"), (34, 39, "ALLERGY")]}),
    ("He's allergic to fish and grass pollen.", {"entities": [(14, 18, "ALLERGY"), (23, 33, "ALLERGY")]}),
    ("I'm allergic to dairy and dog saliva.", {"entities": [(13, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("She's allergic to shellfish and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 37, "ALLERGY")]}),
    ("He has an allergy to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to soy and cats.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has allergies to wheat and dust mites.", {"entities": [(20, 25, "ALLERGY"), (30, 40, "ALLERGY")]}),
    ("He's allergic to pollen and tree nuts.", {"entities": [(14, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to peanuts and fish.", {"entities": [(13, 20, "ALLERGY"), (25, 29, "ALLERGY")]}),
    ("She's allergic to sesame seeds and latex.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("He has an allergy to dairy and dogs.", {"entities": [(14, 19, "ALLERGY"), (24, 28, "ALLERGY")]}),
    ("I suffer from allergies to shellfish and grass.", {"entities": [(23, 32, "ALLERGY"), (37, 42, "ALLERGY")]}),
    ("She's allergic to pollen and cat dander.", {"entities": [(14, 20, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("He's sensitive to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to cats and mold.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has an allergy to tree nuts and latex.", {"entities": [(20, 29, "ALLERGY"), (34, 39, "ALLERGY")]}),
    ("He's allergic to fish and grass pollen.", {"entities": [(14, 18, "ALLERGY"), (23, 33, "ALLERGY")]}),
    ("I'm allergic to dairy and dog saliva.", {"entities": [(13, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("She's allergic to shellfish and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 37, "ALLERGY")]}),
    ("He has an allergy to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to soy and cats.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has allergies to wheat and dust mites.", {"entities": [(20, 25, "ALLERGY"), (30, 40, "ALLERGY")]}),
    ("He's allergic to pollen and tree nuts.", {"entities": [(14, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to peanuts and fish.", {"entities": [(13, 20, "ALLERGY"), (25, 29, "ALLERGY")]}),
    ("She's allergic to sesame seeds and latex.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("He has an allergy to dairy and dogs.", {"entities": [(14, 19, "ALLERGY"), (24, 28, "ALLERGY")]}),
    ("I suffer from allergies to shellfish and grass.", {"entities": [(23, 32, "ALLERGY"), (37, 42, "ALLERGY")]}),
    ("She's allergic to pollen and cat dander.", {"entities": [(14, 20, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("He's sensitive to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to cats and mold.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has an allergy to tree nuts and latex.", {"entities": [(20, 29, "ALLERGY"), (34, 39, "ALLERGY")]}),
    ("He's allergic to fish and grass pollen.", {"entities": [(14, 18, "ALLERGY"), (23, 33, "ALLERGY")]}),
    ("I'm allergic to dairy and dog saliva.", {"entities": [(13, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("She's allergic to shellfish and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 37, "ALLERGY")]}),
    ("He has an allergy to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to soy and cats.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has allergies to wheat and dust mites.", {"entities": [(20, 25, "ALLERGY"), (30, 40, "ALLERGY")]}),
    ("He's allergic to pollen and tree nuts.", {"entities": [(14, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to peanuts and fish.", {"entities": [(13, 20, "ALLERGY"), (25, 29, "ALLERGY")]}),
    ("She's allergic to sesame seeds and latex.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("He has an allergy to dairy and dogs.", {"entities": [(14, 19, "ALLERGY"), (24, 28, "ALLERGY")]}),
    ("I suffer from allergies to shellfish and grass.", {"entities": [(23, 32, "ALLERGY"), (37, 42, "ALLERGY")]}),
    ("She's allergic to pollen and cat dander.", {"entities": [(14, 20, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("He's sensitive to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to cats and mold.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has an allergy to tree nuts and latex.", {"entities": [(20, 29, "ALLERGY"), (34, 39, "ALLERGY")]}),
    ("He's allergic to fish and grass pollen.", {"entities": [(14, 18, "ALLERGY"), (23, 33, "ALLERGY")]}),
    ("I'm allergic to dairy and dog saliva.", {"entities": [(13, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("She's allergic to shellfish and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 37, "ALLERGY")]}),
    ("He has an allergy to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to soy and cats.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has allergies to wheat and dust mites.", {"entities": [(20, 25, "ALLERGY"), (30, 40, "ALLERGY")]}),
    ("He's allergic to pollen and tree nuts.", {"entities": [(14, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to peanuts and fish.", {"entities": [(13, 20, "ALLERGY"), (25, 29, "ALLERGY")]}),
    ("She's allergic to sesame seeds and latex.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("He has an allergy to dairy and dogs.", {"entities": [(14, 19, "ALLERGY"), (24, 28, "ALLERGY")]}),
    ("I suffer from allergies to shellfish and grass.", {"entities": [(23, 32, "ALLERGY"), (37, 42, "ALLERGY")]}),
    ("She's allergic to pollen and cat dander.", {"entities": [(14, 20, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("He's sensitive to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to cats and mold.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has an allergy to tree nuts and latex.", {"entities": [(20, 29, "ALLERGY"), (34, 39, "ALLERGY")]}),
    ("He's allergic to fish and grass pollen.", {"entities": [(14, 18, "ALLERGY"), (23, 33, "ALLERGY")]}),
    ("I'm allergic to dairy and dog saliva.", {"entities": [(13, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("She's allergic to shellfish and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 37, "ALLERGY")]}),
    ("He has an allergy to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to soy and cats.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has allergies to wheat and dust mites.", {"entities": [(20, 25, "ALLERGY"), (30, 40, "ALLERGY")]}),
    ("He's allergic to pollen and tree nuts.", {"entities": [(14, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to peanuts and fish.", {"entities": [(13, 20, "ALLERGY"), (25, 29, "ALLERGY")]}),
    ("She's allergic to sesame seeds and latex.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("He has an allergy to dairy and dogs.", {"entities": [(14, 19, "ALLERGY"), (24, 28, "ALLERGY")]}),
    ("I suffer from allergies to shellfish and grass.", {"entities": [(23, 32, "ALLERGY"), (37, 42, "ALLERGY")]}),
    ("She's allergic to pollen and cat dander.", {"entities": [(14, 20, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("He's sensitive to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to cats and mold.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has an allergy to tree nuts and latex.", {"entities": [(20, 29, "ALLERGY"), (34, 39, "ALLERGY")]}),
    ("He's allergic to fish and grass pollen.", {"entities": [(14, 18, "ALLERGY"), (23, 33, "ALLERGY")]}),
    ("I'm allergic to dairy and dog saliva.", {"entities": [(13, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("She's allergic to shellfish and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 37, "ALLERGY")]}),
    ("He has an allergy to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to soy and cats.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has allergies to wheat and dust mites.", {"entities": [(20, 25, "ALLERGY"), (30, 40, "ALLERGY")]}),
    ("He's allergic to pollen and tree nuts.", {"entities": [(14, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to peanuts and fish.", {"entities": [(13, 20, "ALLERGY"), (25, 29, "ALLERGY")]}),
    ("She's allergic to sesame seeds and latex.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("He has an allergy to dairy and dogs.", {"entities": [(14, 19, "ALLERGY"), (24, 28, "ALLERGY")]}),
    ("I suffer from allergies to shellfish and grass.", {"entities": [(23, 32, "ALLERGY"), (37, 42, "ALLERGY")]}),
    ("She's allergic to pollen and cat dander.", {"entities": [(14, 20, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("He's sensitive to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to cats and mold.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has an allergy to tree nuts and latex.", {"entities": [(20, 29, "ALLERGY"), (34, 39, "ALLERGY")]}),
    ("He's allergic to fish and grass pollen.", {"entities": [(14, 18, "ALLERGY"), (23, 33, "ALLERGY")]}),
    ("I'm allergic to dairy and dog saliva.", {"entities": [(13, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("She's allergic to shellfish and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 37, "ALLERGY")]}),
    ("He has an allergy to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to soy and cats.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has allergies to wheat and dust mites.", {"entities": [(20, 25, "ALLERGY"), (30, 40, "ALLERGY")]}),
    ("He's allergic to pollen and tree nuts.", {"entities": [(14, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to peanuts and fish.", {"entities": [(13, 20, "ALLERGY"), (25, 29, "ALLERGY")]}),
    ("She's allergic to sesame seeds and latex.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("He has an allergy to dairy and dogs.", {"entities": [(14, 19, "ALLERGY"), (24, 28, "ALLERGY")]}),
    ("I suffer from allergies to shellfish and grass.", {"entities": [(23, 32, "ALLERGY"), (37, 42, "ALLERGY")]}),
    ("She's allergic to pollen and cat dander.", {"entities": [(14, 20, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("He's sensitive to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to cats and mold.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has an allergy to tree nuts and latex.", {"entities": [(20, 29, "ALLERGY"), (34, 39, "ALLERGY")]}),
    ("He's allergic to fish and grass pollen.", {"entities": [(14, 18, "ALLERGY"), (23, 33, "ALLERGY")]}),
    ("I'm allergic to dairy and dog saliva.", {"entities": [(13, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("She's allergic to shellfish and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 37, "ALLERGY")]}),
    ("He has an allergy to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to soy and cats.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has allergies to wheat and dust mites.", {"entities": [(20, 25, "ALLERGY"), (30, 40, "ALLERGY")]}),
    ("He's allergic to pollen and tree nuts.", {"entities": [(14, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to peanuts and fish.", {"entities": [(13, 20, "ALLERGY"), (25, 29, "ALLERGY")]}),
    ("She's allergic to sesame seeds and latex.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("He has an allergy to dairy and dogs.", {"entities": [(14, 19, "ALLERGY"), (24, 28, "ALLERGY")]}),
    ("I suffer from allergies to shellfish and grass.", {"entities": [(23, 32, "ALLERGY"), (37, 42, "ALLERGY")]}),
    ("She's allergic to pollen and cat dander.", {"entities": [(14, 20, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("He's sensitive to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to cats and mold.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has an allergy to tree nuts and latex.", {"entities": [(20, 29, "ALLERGY"), (34, 39, "ALLERGY")]}),
    ("He's allergic to fish and grass pollen.", {"entities": [(14, 18, "ALLERGY"), (23, 33, "ALLERGY")]}),
    ("I'm allergic to dairy and dog saliva.", {"entities": [(13, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("She's allergic to shellfish and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 37, "ALLERGY")]}),
    ("He has an allergy to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to soy and cats.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has allergies to wheat and dust mites.", {"entities": [(20, 25, "ALLERGY"), (30, 40, "ALLERGY")]}),
    ("He's allergic to pollen and tree nuts.", {"entities": [(14, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to peanuts and fish.", {"entities": [(13, 20, "ALLERGY"), (25, 29, "ALLERGY")]}),
    ("She's allergic to sesame seeds and latex.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("He has an allergy to dairy and dogs.", {"entities": [(14, 19, "ALLERGY"), (24, 28, "ALLERGY")]}),
    ("I suffer from allergies to shellfish and grass.", {"entities": [(23, 32, "ALLERGY"), (37, 42, "ALLERGY")]}),
    ("She's allergic to pollen and cat dander.", {"entities": [(14, 20, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("He's sensitive to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to cats and mold.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has an allergy to tree nuts and latex.", {"entities": [(20, 29, "ALLERGY"), (34, 39, "ALLERGY")]}),
    ("He's allergic to fish and grass pollen.", {"entities": [(14, 18, "ALLERGY"), (23, 33, "ALLERGY")]}),
    ("I'm allergic to dairy and dog saliva.", {"entities": [(13, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("She's allergic to shellfish and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 37, "ALLERGY")]}),
    ("He has an allergy to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to soy and cats.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has allergies to wheat and dust mites.", {"entities": [(20, 25, "ALLERGY"), (30, 40, "ALLERGY")]}),
    ("He's allergic to pollen and tree nuts.", {"entities": [(14, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to peanuts and fish.", {"entities": [(13, 20, "ALLERGY"), (25, 29, "ALLERGY")]}),
    ("She's allergic to sesame seeds and latex.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("He has an allergy to dairy and dogs.", {"entities": [(14, 19, "ALLERGY"), (24, 28, "ALLERGY")]}),
    ("I suffer from allergies to shellfish and grass.", {"entities": [(23, 32, "ALLERGY"), (37, 42, "ALLERGY")]}),
    ("She's allergic to pollen and cat dander.", {"entities": [(14, 20, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("He's sensitive to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to cats and mold.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has an allergy to tree nuts and latex.", {"entities": [(20, 29, "ALLERGY"), (34, 39, "ALLERGY")]}),
    ("He's allergic to fish and grass pollen.", {"entities": [(14, 18, "ALLERGY"), (23, 33, "ALLERGY")]}),
    ("I'm allergic to dairy and dog saliva.", {"entities": [(13, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("She's allergic to shellfish and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 37, "ALLERGY")]}),
    ("He has an allergy to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to soy and cats.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has allergies to wheat and dust mites.", {"entities": [(20, 25, "ALLERGY"), (30, 40, "ALLERGY")]}),
    ("He's allergic to pollen and tree nuts.", {"entities": [(14, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to peanuts and fish.", {"entities": [(13, 20, "ALLERGY"), (25, 29, "ALLERGY")]}),
    ("She's allergic to sesame seeds and latex.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("He has an allergy to dairy and dogs.", {"entities": [(14, 19, "ALLERGY"), (24, 28, "ALLERGY")]}),
    ("I suffer from allergies to shellfish and grass.", {"entities": [(23, 32, "ALLERGY"), (37, 42, "ALLERGY")]}),
    ("She's allergic to pollen and cat dander.", {"entities": [(14, 20, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("He's sensitive to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to cats and mold.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has an allergy to tree nuts and latex.", {"entities": [(20, 29, "ALLERGY"), (34, 39, "ALLERGY")]}),
    ("He's allergic to fish and grass pollen.", {"entities": [(14, 18, "ALLERGY"), (23, 33, "ALLERGY")]}),
    ("I'm allergic to dairy and dog saliva.", {"entities": [(13, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("She's allergic to shellfish and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 37, "ALLERGY")]}),
    ("He has an allergy to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to soy and cats.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has allergies to wheat and dust mites.", {"entities": [(20, 25, "ALLERGY"), (30, 40, "ALLERGY")]}),
    ("He's allergic to pollen and tree nuts.", {"entities": [(14, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to peanuts and fish.", {"entities": [(13, 20, "ALLERGY"), (25, 29, "ALLERGY")]}),
    ("She's allergic to sesame seeds and latex.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("He has an allergy to dairy and dogs.", {"entities": [(14, 19, "ALLERGY"), (24, 28, "ALLERGY")]}),
    ("I suffer from allergies to shellfish and grass.", {"entities": [(23, 32, "ALLERGY"), (37, 42, "ALLERGY")]}),
    ("She's allergic to pollen and cat dander.", {"entities": [(14, 20, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("He's sensitive to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to cats and mold.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has an allergy to tree nuts and latex.", {"entities": [(20, 29, "ALLERGY"), (34, 39, "ALLERGY")]}),
    ("He's allergic to fish and grass pollen.", {"entities": [(14, 18, "ALLERGY"), (23, 33, "ALLERGY")]}),
    ("I'm allergic to dairy and dog saliva.", {"entities": [(13, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("She's allergic to shellfish and tree nuts.", {"entities": [(14, 23, "ALLERGY"), (28, 37, "ALLERGY")]}),
    ("He has an allergy to peanuts and bee stings.", {"entities": [(14, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I suffer from allergies to soy and cats.", {"entities": [(23, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("She has allergies to wheat and dust mites.", {"entities": [(20, 25, "ALLERGY"), (30, 40, "ALLERGY")]}),
    ("He's allergic to pollen and tree nuts.", {"entities": [(14, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to peanuts and fish.", {"entities": [(13, 20, "ALLERGY"), (25, 29, "ALLERGY")]}),
    ("She's allergic to sesame seeds and latex.", {"entities": [(14, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("He has an allergy to dairy and dogs.", {"entities": [(14, 19, "ALLERGY"), (24, 28, "ALLERGY")]}),
    ("I suffer from allergies to shellfish and grass.", {"entities": [(23, 32, "ALLERGY"), (37, 42, "ALLERGY")]}),
    ("She's allergic to pollen and cat dander.", {"entities": [(14, 20, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("I have allergies to peanuts and cat dander.", {"entities": [(13, 21, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("I'm allergic to soy and pollen.", {"entities": [(13, 16, "ALLERGY"), (21, 27, "ALLERGY")]}),
    ("I suffer from allergies to shellfish and ragweed.", {"entities": [(23, 32, "ALLERGY"), (37, 44, "ALLERGY")]}),
    ("I'm sensitive to dairy and dust mites.", {"entities": [(14, 19, "ALLERGY"), (24, 34, "ALLERGY")]}),
    ("I have allergies to tree nuts and grass.", {"entities": [(13, 22, "ALLERGY"), (27, 32, "ALLERGY")]}),
    ("I'm allergic to fish and mold.", {"entities": [(13, 17, "ALLERGY"), (22, 26, "ALLERGY")]}),
    ("I suffer from allergies to wheat and dog saliva.", {"entities": [(23, 28, "ALLERGY"), (33, 44, "ALLERGY")]}),
    ("I have allergies to shellfish and bee stings.", {"entities": [(13, 22, "ALLERGY"), (27, 37, "ALLERGY")]}),
    ("I'm sensitive to dairy and latex.", {"entities": [(14, 19, "ALLERGY"), (24, 29, "ALLERGY")]}),
    ("I'm allergic to soy and cat saliva.", {"entities": [(13, 16, "ALLERGY"), (21, 31, "ALLERGY")]}),
    ("I have allergies to tree nuts and pollen.", {"entities": [(13, 22, "ALLERGY"), (27, 33, "ALLERGY")]}),
    ("I'm sensitive to peanuts and grass.", {"entities": [(14, 21, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to wheat and dust mites.", {"entities": [(23, 28, "ALLERGY"), (33, 43, "ALLERGY")]}),
    ("I have allergies to shellfish and bee stings.", {"entities": [(13, 22, "ALLERGY"), (27, 37, "ALLERGY")]}),
    ("I'm sensitive to dairy and latex.", {"entities": [(14, 19, "ALLERGY"), (24, 29, "ALLERGY")]}),
    ("I'm allergic to soy and cat saliva.", {"entities": [(13, 16, "ALLERGY"), (21, 31, "ALLERGY")]}),
    ("I have allergies to tree nuts and pollen.", {"entities": [(13, 22, "ALLERGY"), (27, 33, "ALLERGY")]}),
    ("I'm sensitive to peanuts and grass.", {"entities": [(14, 21, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to wheat and dust mites.", {"entities": [(23, 28, "ALLERGY"), (33, 43, "ALLERGY")]}),
    ("I have allergies to shellfish and bee stings.", {"entities": [(13, 22, "ALLERGY"), (27, 37, "ALLERGY")]}),
    ("I'm sensitive to dairy and latex.", {"entities": [(14, 19, "ALLERGY"), (24, 29, "ALLERGY")]}),
    ("I'm allergic to soy and cat saliva.", {"entities": [(13, 16, "ALLERGY"), (21, 31, "ALLERGY")]}),
    ("I have allergies to tree nuts and pollen.", {"entities": [(13, 22, "ALLERGY"), (27, 33, "ALLERGY")]}),
    ("I'm sensitive to peanuts and grass.", {"entities": [(14, 21, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to wheat and dust mites.", {"entities": [(23, 28, "ALLERGY"), (33, 43, "ALLERGY")]}),
    ("I have allergies to shellfish and bee stings.", {"entities": [(13, 22, "ALLERGY"), (27, 37, "ALLERGY")]}),
    ("I'm sensitive to dairy and latex.", {"entities": [(14, 19, "ALLERGY"), (24, 29, "ALLERGY")]}),
    ("I'm allergic to soy and cat saliva.", {"entities": [(13, 16, "ALLERGY"), (21, 31, "ALLERGY")]}),
    ("I have allergies to tree nuts and pollen.", {"entities": [(13, 22, "ALLERGY"), (27, 33, "ALLERGY")]}),
    ("I'm sensitive to peanuts and grass.", {"entities": [(14, 21, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to wheat and dust mites.", {"entities": [(23, 28, "ALLERGY"), (33, 43, "ALLERGY")]}),
    ("I have allergies to shellfish and bee stings.", {"entities": [(13, 22, "ALLERGY"), (27, 37, "ALLERGY")]}),
    ("I'm sensitive to dairy and latex.", {"entities": [(14, 19, "ALLERGY"), (24, 29, "ALLERGY")]}),
    ("I'm allergic to soy and cat saliva.", {"entities": [(13, 16, "ALLERGY"), (21, 31, "ALLERGY")]}),
    ("I have allergies to tree nuts and pollen.", {"entities": [(13, 22, "ALLERGY"), (27, 33, "ALLERGY")]}),
    ("I'm sensitive to peanuts and grass.", {"entities": [(14, 21, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to wheat and dust mites.", {"entities": [(23, 28, "ALLERGY"), (33, 43, "ALLERGY")]}),
    ("I have allergies to shellfish and bee stings.", {"entities": [(13, 22, "ALLERGY"), (27, 37, "ALLERGY")]}),
    ("I'm sensitive to dairy and latex.", {"entities": [(14, 19, "ALLERGY"), (24, 29, "ALLERGY")]}),
    ("I'm allergic to soy and cat saliva.", {"entities": [(13, 16, "ALLERGY"), (21, 31, "ALLERGY")]}),
    ("I have allergies to tree nuts and pollen.", {"entities": [(13, 22, "ALLERGY"), (27, 33, "ALLERGY")]}),
    ("I'm sensitive to peanuts and grass.", {"entities": [(14, 21, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to wheat and dust mites.", {"entities": [(23, 28, "ALLERGY"), (33, 43, "ALLERGY")]}),
    ("I have allergies to shellfish and bee stings.", {"entities": [(13, 22, "ALLERGY"), (27, 37, "ALLERGY")]}),
    ("I'm sensitive to dairy and latex.", {"entities": [(14, 19, "ALLERGY"), (24, 29, "ALLERGY")]}),
    ("I'm allergic to soy and cat saliva.", {"entities": [(13, 16, "ALLERGY"), (21, 31, "ALLERGY")]}),
    ("I have allergies to tree nuts and pollen.", {"entities": [(13, 22, "ALLERGY"), (27, 33, "ALLERGY")]}),
    ("I'm sensitive to peanuts and grass.", {"entities": [(14, 21, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to wheat and dust mites.", {"entities": [(23, 28, "ALLERGY"), (33, 43, "ALLERGY")]}),
    ("I have allergies to shellfish and bee stings.", {"entities": [(13, 22, "ALLERGY"), (27, 37, "ALLERGY")]}),
    ("I'm sensitive to dairy and latex.", {"entities": [(14, 19, "ALLERGY"), (24, 29, "ALLERGY")]}),
    ("I'm allergic to soy and cat saliva.", {"entities": [(13, 16, "ALLERGY"), (21, 31, "ALLERGY")]}),
    ("I have allergies to tree nuts and pollen.", {"entities": [(13, 22, "ALLERGY"), (27, 33, "ALLERGY")]}),
    ("I'm sensitive to peanuts and grass.", {"entities": [(14, 21, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to wheat and dust mites.", {"entities": [(23, 28, "ALLERGY"), (33, 43, "ALLERGY")]}),
    ("I have allergies to shellfish and bee stings.", {"entities": [(13, 22, "ALLERGY"), (27, 37, "ALLERGY")]}),
    ("I'm sensitive to dairy and latex.", {"entities": [(14, 19, "ALLERGY"), (24, 29, "ALLERGY")]}),
    ("I'm allergic to soy and cat saliva.", {"entities": [(13, 16, "ALLERGY"), (21, 31, "ALLERGY")]}),
    ("I have allergies to tree nuts and pollen.", {"entities": [(13, 22, "ALLERGY"), (27, 33, "ALLERGY")]}),
    ("I'm sensitive to peanuts and grass.", {"entities": [(14, 21, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to wheat and dust mites.", {"entities": [(23, 28, "ALLERGY"), (33, 43, "ALLERGY")]}),
    ("I have allergies to shellfish and bee stings.", {"entities": [(13, 22, "ALLERGY"), (27, 37, "ALLERGY")]}),
    ("I'm sensitive to dairy and latex.", {"entities": [(14, 19, "ALLERGY"), (24, 29, "ALLERGY")]}),
    ("I'm allergic to soy and cat saliva.", {"entities": [(13, 16, "ALLERGY"), (21, 31, "ALLERGY")]}),
    ("I have allergies to tree nuts and pollen.", {"entities": [(13, 22, "ALLERGY"), (27, 33, "ALLERGY")]}),
    ("I'm sensitive to peanuts and grass.", {"entities": [(14, 21, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to wheat and dust mites.", {"entities": [(23, 28, "ALLERGY"), (33, 43, "ALLERGY")]}),
    ("I have allergies to shellfish and bee stings.", {"entities": [(13, 22, "ALLERGY"), (27, 37, "ALLERGY")]}),
    ("I'm sensitive to dairy and latex.", {"entities": [(14, 19, "ALLERGY"), (24, 29, "ALLERGY")]}),
    ("I'm allergic to soy and cat saliva.", {"entities": [(13, 16, "ALLERGY"), (21, 31, "ALLERGY")]}),
    ("I have allergies to tree nuts and pollen.", {"entities": [(13, 22, "ALLERGY"), (27, 33, "ALLERGY")]}),
    ("I'm sensitive to peanuts and grass.", {"entities": [(14, 21, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to wheat and dust mites.", {"entities": [(23, 28, "ALLERGY"), (33, 43, "ALLERGY")]}),
    ("I have allergies to shellfish and bee stings.", {"entities": [(13, 22, "ALLERGY"), (27, 37, "ALLERGY")]}),
    ("I'm sensitive to dairy and latex.", {"entities": [(14, 19, "ALLERGY"), (24, 29, "ALLERGY")]}),
    ("I'm allergic to soy and cat saliva.", {"entities": [(13, 16, "ALLERGY"), (21, 31, "ALLERGY")]}),
    ("I have allergies to tree nuts and pollen.", {"entities": [(13, 22, "ALLERGY"), (27, 33, "ALLERGY")]}),
    ("I'm sensitive to peanuts and grass.", {"entities": [(14, 21, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I suffer from allergies to wheat and dust mites.", {"entities": [(23, 28, "ALLERGY"), (33, 43, "ALLERGY")]}),
    ("I have allergies to shellfish and bee stings.", {"entities": [(13, 22, "ALLERGY"), (27, 37, "ALLERGY")]}),
    ("I'm sensitive to dairy and latex.", {"entities": [(14, 19, "ALLERGY"), (24, 29, "ALLERGY")]}),
    ("I'm allergic to soy and cat saliva.", {"entities": [(13, 16, "ALLERGY"), (21, 31, "ALLERGY")]}),
    ("I have allergies to tree nuts and pollen.", {"entities": [(13, 22, "ALLERGY"), (27, 33, "ALLERGY")]}),
    ("I'm sensitive to peanuts and grass.", {"entities": [(14, 21, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I have a peanut allergy.", {"entities": [(10, 17, "ALLERGY")]}),
    ("I'm allergic to shellfish.", {"entities": [(13, 22, "ALLERGY")]}),
    ("I suffer from hay fever.", {"entities": [(17, 26, "ALLERGY")]}),
    ("I have a dairy allergy.", {"entities": [(10, 15, "ALLERGY")]}),
    ("I'm allergic to cats.", {"entities": [(13, 17, "ALLERGY")]}),
    ("I have a pollen allergy.", {"entities": [(10, 16, "ALLERGY")]}),
    ("I'm allergic to tree nuts.", {"entities": [(13, 22, "ALLERGY")]}),
    ("I suffer from dust mite allergies.", {"entities": [(17, 26, "ALLERGY")]}),
    ("I have a soy allergy.", {"entities": [(10, 13, "ALLERGY")]}),
    ("I'm allergic to fish.", {"entities": [(13, 17, "ALLERGY")]}),
    ("I have an egg allergy.", {"entities": [(10, 13, "ALLERGY")]}),
    ("I'm allergic to wheat.", {"entities": [(13, 18, "ALLERGY")]}),
    ("I suffer from mold allergies.", {"entities": [(17, 21, "ALLERGY")]}),
    ("I have a sesame allergy.", {"entities": [(10, 17, "ALLERGY")]}),
    ("I'm allergic to latex.", {"entities": [(13, 18, "ALLERGY")]}),
    ("I have a dog allergy.", {"entities": [(10, 13, "ALLERGY")]}),
    ("I suffer from bee sting allergies.", {"entities": [(17, 26, "ALLERGY")]}),
    ("I have a shrimp allergy.", {"entities": [(10, 16, "ALLERGY")]}),
    ("I'm allergic to grass.", {"entities": [(13, 18, "ALLERGY")]}),
    ("I have a milk allergy.", {"entities": [(10, 14, "ALLERGY")]}),
    ("I'm allergic to ragweed.", {"entities": [(13, 20, "ALLERGY")]}),
    ("I suffer from chicken egg allergies.", {"entities": [(17, 20, "ALLERGY")]}),
    ("I have a penicillin allergy.", {"entities": [(10, 20, "ALLERGY")]}),
    ("I'm allergic to peanuts.", {"entities": [(13, 20, "ALLERGY")]}),
    ("I have a gluten allergy.", {"entities": [(10, 15, "ALLERGY")]}),
    ("I'm allergic to shrimp.", {"entities": [(13, 19, "ALLERGY")]}),
    ("I have a tree pollen allergy.", {"entities": [(10, 21, "ALLERGY")]}),
    ("I suffer from dust allergies.", {"entities": [(17, 25, "ALLERGY")]}),
    ("I have a kiwi allergy.", {"entities": [(10, 14, "ALLERGY")]}),
    ("I'm allergic to almonds.", {"entities": [(13, 20, "ALLERGY")]}),
    ("I have a sulfite allergy.", {"entities": [(10, 17, "ALLERGY")]}),
    ("I'm allergic to mold.", {"entities": [(13, 17, "ALLERGY")]}),
    ("I have a cat allergy.", {"entities": [(10, 13, "ALLERGY")]}),
    ("I'm allergic to cockroaches.", {"entities": [(13, 24, "ALLERGY")]}),
    ("I have a strawberry allergy.", {"entities": [(10, 19, "ALLERGY")]}),
    ("I'm allergic to latex gloves.", {"entities": [(13, 22, "ALLERGY")]}),
    ("I have a sunflower seed allergy.", {"entities": [(10, 24, "ALLERGY")]}),
    ("I'm allergic to pecans.", {"entities": [(13, 19, "ALLERGY")]}),
    ("I have a carrot allergy.", {"entities": [(10, 15, "ALLERGY")]}),
    ("I'm allergic to lobster.", {"entities": [(13, 19, "ALLERGY")]}),
    ("I have a bee venom allergy.", {"entities": [(10, 19, "ALLERGY")]}),
    ("I'm allergic to melons.", {"entities": [(13, 19, "ALLERGY")]}),
    ("I have a latex allergy.", {"entities": [(10, 14, "ALLERGY")]}),
    ("I'm allergic to hazelnuts.", {"entities": [(13, 22, "ALLERGY")]}),
    ("I have a grass allergy.", {"entities": [(10, 15, "ALLERGY")]}),
    ("I'm allergic to dust mites.", {"entities": [(13, 22, "ALLERGY")]}),
    ("I have a peach allergy.", {"entities": [(10, 15, "ALLERGY")]}),
    ("I'm allergic to aspirin.", {"entities": [(13, 19, "ALLERGY")]}),
    ("I have a latex rubber allergy.", {"entities": [(10, 21, "ALLERGY")]}),
    ("I'm allergic to tomatoes.", {"entities": [(13, 21, "ALLERGY")]}),
    ("I have a latex fruit syndrome.", {"entities": [(10, 26, "ALLERGY")]}),
    ("I'm allergic to walnuts.", {"entities": [(13, 20, "ALLERGY")]}),
    ("I'm allergic to arugula.", {"entities": [(13, 20, "ALLERGY")]}),
    ("I have a romaine lettuce allergy.", {"entities": [(10, 24, "ALLERGY")]}),
    ("I suffer from spinach allergies.", {"entities": [(17, 24, "ALLERGY")]}),
    ("I'm allergic to watercress.", {"entities": [(13, 23, "ALLERGY")]}),
    ("I have a chard allergy.", {"entities": [(10, 14, "ALLERGY")]}),
    ("I suffer from mesclun allergies.", {"entities": [(17, 24, "ALLERGY")]}),
    ("I'm allergic to iceberg lettuce.", {"entities": [(13, 27, "ALLERGY")]}),
    ("I have a beet greens allergy.", {"entities": [(10, 22, "ALLERGY")]}),
    ("I suffer from mustard greens allergies.", {"entities": [(17, 31, "ALLERGY")]}),
    ("I'm allergic to turnip greens.", {"entities": [(13, 26, "ALLERGY")]}),
    ("I have a dandelion greens allergy.", {"entities": [(10, 27, "ALLERGY")]}),
    ("I suffer from collard greens allergies.", {"entities": [(17, 31, "ALLERGY")]}),
    ("I'm allergic to kale.", {"entities": [(13, 16, "ALLERGY")]}),
    ("I have a cilantro allergy.", {"entities": [(10, 18, "ALLERGY")]}),
    ("I suffer from parsley allergies.", {"entities": [(17, 24, "ALLERGY")]}),
    ("I'm allergic to basil.", {"entities": [(13, 17, "ALLERGY")]}),
    ("I have a mint allergy.", {"entities": [(10, 14, "ALLERGY")]}),
    ("I suffer from rosemary allergies.", {"entities": [(17, 25, "ALLERGY")]}),
    ("I'm allergic to oregano.", {"entities": [(13, 19, "ALLERGY")]}),
    ("I have a thyme allergy.", {"entities": [(10, 15, "ALLERGY")]}),
    ("I suffer from sage allergies.", {"entities": [(17, 20, "ALLERGY")]}),
    ("I'm allergic to tarragon.", {"entities": [(13, 20, "ALLERGY")]}),
    ("I have a marjoram allergy.", {"entities": [(10, 18, "ALLERGY")]}),
    ("I suffer from chives allergies.", {"entities": [(17, 23, "ALLERGY")]}),
    ("I'm allergic to scallions.", {"entities": [(13, 21, "ALLERGY")]}),
    ("I have a lemongrass allergy.", {"entities": [(10, 21, "ALLERGY")]}),
    ("I suffer from garlic chive allergies.", {"entities": [(17, 28, "ALLERGY")]}),
    ("I'm allergic to ramps.", {"entities": [(13, 18, "ALLERGY")]}),
    ("I have a fennel allergy.", {"entities": [(10, 16, "ALLERGY")]}),
    ("I suffer from kaffir lime leaf allergies.", {"entities": [(17, 35, "ALLERGY")]}),
    ("I'm allergic to lemon balm.", {"entities": [(13, 23, "ALLERGY")]}),
    ("I have a lovage allergy.", {"entities": [(10, 16, "ALLERGY")]}),
    ("I suffer from sorrel allergies.", {"entities": [(17, 23, "ALLERGY")]}),
    ("I'm allergic to epazote.", {"entities": [(13, 19, "ALLERGY")]}),
    ("I have a chickweed allergy.", {"entities": [(10, 20, "ALLERGY")]}),
    ("I suffer from hyssop allergies.", {"entities": [(17, 23, "ALLERGY")]}),
    ("I'm allergic to borage.", {"entities": [(13, 18, "ALLERGY")]}),
    ("I have a chamomile allergy.", {"entities": [(10, 20, "ALLERGY")]}),
    ("I suffer from chicory allergies.", {"entities": [(17, 24, "ALLERGY")]}),
    ("I'm allergic to chervil.", {"entities": [(13, 20, "ALLERGY")]}),
    ("I have a cicely allergy.", {"entities": [(10, 16, "ALLERGY")]}),
    ("I suffer from clary sage allergies.", {"entities": [(17, 27, "ALLERGY")]}),
    ("I'm allergic to coriander.", {"entities": [(13, 22, "ALLERGY")]}),
    ("I have a culantro allergy.", {"entities": [(10, 17, "ALLERGY")]}),
    ("I suffer from burnet allergies.", {"entities": [(17, 23, "ALLERGY")]}),
    ("I'm allergic to dill.", {"entities": [(13, 16, "ALLERGY")]}),
    ("I have a fenugreek allergy.", {"entities": [(10, 19, "ALLERGY")]}),
    ("I suffer from hoja santa allergies.", {"entities": [(17, 27, "ALLERGY")]}),
    ("I'm allergic to horehound.", {"entities": [(13, 21, "ALLERGY")]}),
    ("I have a lemon verbena allergy.", {"entities": [(10, 24, "ALLERGY")]}),
    ("I suffer from liquorice allergies.", {"entities": [(17, 25, "ALLERGY")]}),
    ("I'm allergic to maggioreggio.", {"entities": [(13, 24, "ALLERGY")]}),
    ("I have a mugwort allergy.", {"entities": [(10, 17, "ALLERGY")]}),
    ("I suffer from myrtle allergies.", {"entities": [(17, 23, "ALLERGY")]}),
    ("I'm allergic to nigella.", {"entities": [(13, 19, "ALLERGY")]}),
    ("I have a peppergrass allergy.", {"entities": [(10, 21, "ALLERGY")]}),
    ("I suffer from perilla allergies.", {"entities": [(17, 24, "ALLERGY")]}),
    ("I'm allergic to radish sprouts.", {"entities": [(13, 25, "ALLERGY")]}),
    ("I have a rose geranium allergy.", {"entities": [(10, 23, "ALLERGY")]}),
    ("I suffer from salad burnet allergies.", {"entities": [(17, 31, "ALLERGY")]}),
    ("I'm allergic to sculpit.", {"entities": [(13, 19, "ALLERGY")]}),
    ("I have a sea buckthorn allergy.", {"entities": [(10, 23, "ALLERGY")]}),
    ("I suffer from woodruff allergies.", {"entities": [(17, 25, "ALLERGY")]}),
    ("I have a carrot allergy.", {"entities": [(10, 16, "ALLERGY")]}),
    ("I'm allergic to citrus fruits.", {"entities": [(13, 25, "ALLERGY")]}),
    ("I have a coconut allergy.", {"entities": [(10, 17, "ALLERGY")]}),
    ("I suffer from corn allergies.", {"entities": [(17, 21, "ALLERGY")]}),
    ("I'm allergic to crustaceans.", {"entities": [(13, 24, "ALLERGY")]}),
    ("I have a garlic allergy.", {"entities": [(10, 15, "ALLERGY")]}),
    ("I suffer from kiwi allergies.", {"entities": [(17, 20, "ALLERGY")]}),
    ("I'm allergic to lentils.", {"entities": [(13, 20, "ALLERGY")]}),
    ("I have a mushroom allergy.", {"entities": [(10, 17, "ALLERGY")]}),
    ("I suffer from mustard allergies.", {"entities": [(17, 24, "ALLERGY")]}),
    ("I'm allergic to oats.", {"entities": [(13, 16, "ALLERGY")]}),
    ("I have a peach allergy.", {"entities": [(10, 15, "ALLERGY")]}),
    ("I suffer from pear allergies.", {"entities": [(17, 20, "ALLERGY")]}),
    ("I'm allergic to peppers.", {"entities": [(13, 20, "ALLERGY")]}),
    ("I have a pork allergy.", {"entities": [(10, 13, "ALLERGY")]}),
    ("I suffer from red meat allergies.", {"entities": [(17, 24, "ALLERGY")]}),
    ("I'm allergic to rice.", {"entities": [(13, 16, "ALLERGY")]}),
    ("I have a rye allergy.", {"entities": [(10, 12, "ALLERGY")]}),
    ("I suffer from salmon allergies.", {"entities": [(17, 23, "ALLERGY")]}),
    ("I'm allergic to scallops.", {"entities": [(13, 20, "ALLERGY")]}),
    ("I have a shellfish allergy.", {"entities": [(10, 19, "ALLERGY")]}),
    ("I suffer from soybean allergies.", {"entities": [(17, 24, "ALLERGY")]}),
    ("I'm allergic to spinach.", {"entities": [(13, 20, "ALLERGY")]}),
    ("I have a strawberry allergy.", {"entities": [(10, 21, "ALLERGY")]}),
    ("I suffer from sunflower seed allergies.", {"entities": [(17, 31, "ALLERGY")]}),
    ("I'm allergic to tuna fish.", {"entities": [(13, 21, "ALLERGY")]}),
    ("I have a wheat allergy.", {"entities": [(10, 15, "ALLERGY")]}),
    ("I suffer from yeast allergies.", {"entities": [(17, 22, "ALLERGY")]}),
    ("I'm allergic to almonds.", {"entities": [(13, 20, "ALLERGY")]}),
    ("I have an apple allergy.", {"entities": [(10, 15, "ALLERGY")]}),
    ("I suffer from apricot allergies.", {"entities": [(17, 24, "ALLERGY")]}),
    ("I'm allergic to avocados.", {"entities": [(13, 21, "ALLERGY")]}),
    ("I have a banana allergy.", {"entities": [(10, 16, "ALLERGY")]}),
    ("I suffer from barley allergies.", {"entities": [(17, 22, "ALLERGY")]}),
    ("I'm allergic to bell peppers.", {"entities": [(13, 24, "ALLERGY")]}),
    ("I have a blackberry allergy.", {"entities": [(10, 21, "ALLERGY")]}),
    ("I suffer from blueberry allergies.", {"entities": [(17, 26, "ALLERGY")]}),
    ("I'm allergic to broccoli.", {"entities": [(13, 21, "ALLERGY")]}),
    ("I have a cabbage allergy.", {"entities": [(10, 17, "ALLERGY")]}),
    ("I suffer from cantaloupe allergies.", {"entities": [(17, 27, "ALLERGY")]}),
    ("I'm allergic to cherries.", {"entities": [(13, 21, "ALLERGY")]}),
    ("I have a chocolate allergy.", {"entities": [(10, 18, "ALLERGY")]}),
    ("I suffer from cinnamon allergies.", {"entities": [(17, 26, "ALLERGY")]}),
    ("I'm allergic to coffee.", {"entities": [(13, 18, "ALLERGY")]}),
    ("I have a cranberry allergy.", {"entities": [(10, 19, "ALLERGY")]}),
    ("I suffer from cucumber allergies.", {"entities": [(17, 26, "ALLERGY")]}),
    ("I'm allergic to dates.", {"entities": [(13, 18, "ALLERGY")]}),
    ("I have an eggplant allergy.", {"entities": [(10, 19, "ALLERGY")]}),
    ("I suffer from fig allergies.", {"entities": [(17, 20, "ALLERGY")]}),
    ("I'm allergic to grapefruit.", {"entities": [(13, 23, "ALLERGY")]}),
    ("I have a green bean allergy.", {"entities": [(10, 20, "ALLERGY")]}),
    ("I suffer from honeydew melon allergies.", {"entities": [(17, 31, "ALLERGY")]}),
    ("I'm allergic to kale.", {"entities": [(13, 16, "ALLERGY")]}),
    ("I have a kiwifruit allergy.", {"entities": [(10, 20, "ALLERGY")]}),
    ("I suffer from leek allergies.", {"entities": [(17, 21, "ALLERGY")]}),
    ("I'm allergic to mangoes.", {"entities": [(13, 20, "ALLERGY")]}),
    ("I have a nectarine allergy.", {"entities": [(10, 19, "ALLERGY")]}),
    ("I suffer from okra allergies.", {"entities": [(17, 22, "ALLERGY")]}),
    ("I'm allergic to olives.", {"entities": [(13, 19, "ALLERGY")]}),
    ("I have an onion allergy.", {"entities": [(10, 15, "ALLERGY")]}),
    ("I suffer from papaya allergies.", {"entities": [(17, 23, "ALLERGY")]}),
    ("I'm allergic to passion fruit.", {"entities": [(13, 24, "ALLERGY")]}),
    ("I have a peach allergy.", {"entities": [(10, 15, "ALLERGY")]}),
    ("I suffer from pear allergies.", {"entities": [(17, 20, "ALLERGY")]}),
    ("I'm allergic to peas.", {"entities": [(13, 16, "ALLERGY")]}),
    ("I have a pineapple allergy.", {"entities": [(10, 19, "ALLERGY")]}),
    ("I suffer from pluot allergies.", {"entities": [(17, 22, "ALLERGY")]}),
    ("I'm allergic to pomegranates.", {"entities": [(13, 25, "ALLERGY")]}),
    ("I have a potato allergy.", {"entities": [(10, 16, "ALLERGY")]}),
    ("I suffer from pumpkin allergies.", {"entities": [(17, 23, "ALLERGY")]}),
    ("I'm allergic to radishes.", {"entities": [(13, 21, "ALLERGY")]}),
    ("I have a raspberry allergy.", {"entities": [(10, 20, "ALLERGY")]}),
    ("I suffer from rhubarb allergies.", {"entities": [(17, 24, "ALLERGY")]}),
    ("I'm allergic to rutabaga.", {"entities": [(13, 21, "ALLERGY")]}),
    ("I have a tangerine allergy.", {"entities": [(10, 20, "ALLERGY")]}),
    ("I suffer from turnip allergies.", {"entities": [(17, 22, "ALLERGY")]}),
    ("I'm allergic to watermelon.", {"entities": [(13, 23, "ALLERGY")]}),
    ("I have a zucchini allergy.", {"entities": [(10, 19, "ALLERGY")]}),
    ("I suffer from radicchio allergies.", {"entities": [(17, 25, "ALLERGY")]}),
    ("I'm allergic to endives.", {"entities": [(13, 19, "ALLERGY")]}),
    ("I have a bok choy allergy.", {"entities": [(10, 18, "ALLERGY")]}),
    ("I suffer from shallot allergies.", {"entities": [(17, 23, "ALLERGY")]}),
    ("I'm allergic to escarole.", {"entities": [(13, 21, "ALLERGY")]}),
    ("I have a jicama allergy.", {"entities": [(10, 16, "ALLERGY")]}),
    ("I suffer from fiddlehead fern allergies.", {"entities": [(17, 38, "ALLERGY")]}),
    ("I'm allergic to kohlrabi.", {"entities": [(13, 21, "ALLERGY")]}),
    ("I have a rapini allergy.", {"entities": [(10, 16, "ALLERGY")]}),
    ("I suffer from arugula allergies.", {"entities": [(17, 24, "ALLERGY")]}),
    ("I'm allergic to romaine lettuce.", {"entities": [(13, 27, "ALLERGY")]}),
    ("I have a spinach allergy.", {"entities": [(10, 17, "ALLERGY")]}),
    ("I suffer from watercress allergies.", {"entities": [(17, 24, "ALLERGY")]}),
    ("I'm allergic to chard.", {"entities": [(13, 17, "ALLERGY")]}),
    ("I have a mesclun allergy.", {"entities": [(10, 16, "ALLERGY")]}),
    ("I suffer from iceberg lettuce allergies.", {"entities": [(17, 31, "ALLERGY")]}),
    ("I'm allergic to beet greens.", {"entities": [(13, 22, "ALLERGY")]}),
    ("I have a mustard greens allergy.", {"entities": [(10, 31, "ALLERGY")]}),
    ("I suffer from turnip greens allergies.", {"entities": [(17, 31, "ALLERGY")]}),
    ("I'm allergic to dandelion greens.", {"entities": [(13, 28, "ALLERGY")]}),
    ("I have a collard greens allergy.", {"entities": [(10, 31, "ALLERGY")]}),
    ("I suffer from kale allergies.", {"entities": [(17, 20, "ALLERGY")]}),
    ("I'm allergic to cilantro.", {"entities": [(13, 21, "ALLERGY")]}),
    ("I have a parsley allergy.", {"entities": [(10, 17, "ALLERGY")]}),
    ("I suffer from basil allergies.", {"entities": [(17, 21, "ALLERGY")]}),
    ("I'm allergic to mint.", {"entities": [(13, 16, "ALLERGY")]}),
    ("I have a rosemary allergy.", {"entities": [(10, 18, "ALLERGY")]}),
    ("I suffer from oregano allergies.", {"entities": [(17, 25, "ALLERGY")]}),
    ("I'm allergic to thyme.", {"entities": [(13, 18, "ALLERGY")]}),
    ("I have a sage allergy.", {"entities": [(10, 14, "ALLERGY")]}),
    ("I suffer from tarragon allergies.", {"entities": [(17, 24, "ALLERGY")]}),
    ("I'm allergic to marjoram.", {"entities": [(13, 20, "ALLERGY")]}),
    ("I have a chives allergy.", {"entities": [(10, 16, "ALLERGY")]}),
    ("I suffer from scallions allergies.", {"entities": [(17, 25, "ALLERGY")]}),
    ("I'm allergic to lemongrass.", {"entities": [(13, 21, "ALLERGY")]}),
    ("I have a garlic chive allergy.", {"entities": [(10, 21, "ALLERGY")]}),
    ("I suffer from ramps allergies.", {"entities": [(17, 22, "ALLERGY")]}),
    ("I'm allergic to fennel.", {"entities": [(13, 19, "ALLERGY")]}),
    ("I have a kaffir lime leaf allergy.", {"entities": [(10, 29, "ALLERGY")]}),
    ("I suffer from lemon balm allergies.", {"entities": [(17, 27, "ALLERGY")]}),
    ("I'm allergic to lovage.", {"entities": [(13, 16, "ALLERGY")]}),
    ("I have a sorrel allergy.", {"entities": [(10, 16, "ALLERGY")]}),
    ("I suffer from epazote allergies.", {"entities": [(17, 23, "ALLERGY")]}),
    ("I'm allergic to chickweed.", {"entities": [(13, 21, "ALLERGY")]}),
    ("I have a hyssop allergy.", {"entities": [(10, 16, "ALLERGY")]}),
    ("I suffer from borage allergies.", {"entities": [(17, 22, "ALLERGY")]}),
    ("I'm allergic to chamomile.", {"entities": [(13, 22, "ALLERGY")]}),
    ("I have a chicory allergy.", {"entities": [(10, 16, "ALLERGY")]}),
    ("I suffer from chervil allergies.", {"entities": [(17, 24, "ALLERGY")]}),
    ("I'm allergic to cicely.", {"entities": [(13, 19, "ALLERGY")]}),
    ("I suffer from coriander allergies.", {"entities": [(17, 26, "ALLERGY")]}),
    ("I'm allergic to culantro.", {"entities": [(13, 20, "ALLERGY")]}),
    ("I have a burnet allergy.", {"entities": [(10, 16, "ALLERGY")]}),
    ("I suffer from dill allergies.", {"entities": [(17, 20, "ALLERGY")]}),
    ("I'm allergic to fenugreek.", {"entities": [(13, 22, "ALLERGY")]}),
    ("I have a hoja santa allergy.", {"entities": [(10, 21, "ALLERGY")]}),
    ("I suffer from horehound allergies.", {"entities": [(17, 23, "ALLERGY")]}),
    ("I'm allergic to lemon verbena.", {"entities": [(13, 24, "ALLERGY")]}),
    ("I have a liquorice allergy.", {"entities": [(10, 25, "ALLERGY")]}),
    ("I suffer from maggioreggio allergies.", {"entities": [(17, 28, "ALLERGY")]}),
    ("I'm allergic to mugwort.", {"entities": [(13, 20, "ALLERGY")]}),
    ("I have a myrtle allergy.", {"entities": [(10, 16, "ALLERGY")]}),
    ("I suffer from nigella allergies.", {"entities": [(17, 23, "ALLERGY")]}),
    ("I'm allergic to peppergrass.", {"entities": [(13, 21, "ALLERGY")]}),
    ("I have a perilla allergy.", {"entities": [(10, 17, "ALLERGY")]}),
    ("I suffer from radish sprouts allergies.", {"entities": [(17, 29, "ALLERGY")]}),
    ("I'm allergic to rose geranium.", {"entities": [(13, 24, "ALLERGY")]}),
    ("I have a salad burnet allergy.", {"entities": [(10, 24, "ALLERGY")]}),
    ("I suffer from sculpit allergies.", {"entities": [(17, 23, "ALLERGY")]}),
    ("I'm allergic to sea buckthorn.", {"entities": [(13, 24, "ALLERGY")]}),
    ("I have a woodruff allergy.", {"entities": [(10, 17, "ALLERGY")]}),
    ("I suffer from yarrow allergies.", {"entities": [(17, 23, "ALLERGY")]}),
    ("I'm allergic to arachis oil.", {"entities": [(13, 23, "ALLERGY")]}),
    ("I have a sunflower oil allergy.", {"entities": [(10, 23, "ALLERGY")]}),
    ("I suffer from soybean oil allergies.", {"entities": [(17, 27, "ALLERGY")]}),
    ("I'm allergic to safflower oil.", {"entities": [(13, 26, "ALLERGY")]}),
    ("I have a sesame oil allergy.", {"entities": [(10, 21, "ALLERGY")]}),
    ("I suffer from walnut oil allergies.", {"entities": [(17, 27, "ALLERGY")]}),
    ("I'm allergic to grapeseed oil.", {"entities": [(13, 24, "ALLERGY")]}),
    ("I have a coconut oil allergy.", {"entities": [(10, 22, "ALLERGY")]}),
    ("I suffer from canola oil allergies.", {"entities": [(17, 26, "ALLERGY")]}),
    ("I'm allergic to almond oil.", {"entities": [(13, 22, "ALLERGY")]}),
    ("I have a peanut oil allergy.", {"entities": [(10, 20, "ALLERGY")]}),
    ("I suffer from corn oil allergies.", {"entities": [(17, 25, "ALLERGY")]}),
    ("I'm allergic to soy sauce.", {"entities": [(13, 21, "ALLERGY")]}),
    ("I have a tamari allergy.", {"entities": [(10, 15, "ALLERGY")]}),
    ("I suffer from fish sauce allergies.", {"entities": [(17, 28, "ALLERGY")]}),
    ("I'm allergic to oyster sauce.", {"entities": [(13, 24, "ALLERGY")]}),
    ("I have a hoisin sauce allergy.", {"entities": [(10, 22, "ALLERGY")]}),
    ("I suffer from shrimp paste allergies.", {"entities": [(17, 29, "ALLERGY")]}),
    ("I'm allergic to worcestershire sauce.", {"entities": [(13, 31, "ALLERGY")]}),
    ("I have a barbecue sauce allergy.", {"entities": [(10, 23, "ALLERGY")]}),
    ("I suffer from ketchup allergies.", {"entities": [(17, 23, "ALLERGY")]}),
    ("I'm allergic to mustard sauce.", {"entities": [(13, 25, "ALLERGY")]}),
    ("I have a relish allergy.", {"entities": [(10, 16, "ALLERGY")]}),
    ("I suffer from salad dressing allergies.", {"entities": [(17, 30, "ALLERGY")]}),
    ("I'm allergic to salsa.", {"entities": [(13, 18, "ALLERGY")]}),
    ("I have a soybean paste allergy.", {"entities": [(10, 23, "ALLERGY")]}),
    ("I suffer from tahini allergies.", {"entities": [(17, 23, "ALLERGY")]}),
    ("I'm allergic to miso.", {"entities": [(13, 16, "ALLERGY")]}),
    ("I have a tempeh allergy.", {"entities": [(10, 16, "ALLERGY")]}),
    ("I suffer from tofu allergies.", {"entities": [(17, 21, "ALLERGY")]}),
    ("I'm allergic to natto.", {"entities": [(13, 17, "ALLERGY")]}),
    ("I have a yuba allergy.", {"entities": [(10, 14, "ALLERGY")]}),
    ("I suffer from spirulina allergies.", {"entities": [(17, 26, "ALLERGY")]}),
    ("I'm allergic to chlorella.", {"entities": [(13, 21, "ALLERGY")]}),
    ("I have a bee pollen allergy.", {"entities": [(10, 20, "ALLERGY")]}),
    ("I suffer from propolis allergies.", {"entities": [(17, 25, "ALLERGY")]}),
    ("I'm allergic to royal jelly.", {"entities": [(13, 23, "ALLERGY")]}),
    ("I have a venom allergy.", {"entities": [(10, 15, "ALLERGY")]}),
    ("I suffer from penicillin allergies.", {"entities": [(17, 27, "ALLERGY")]}),
    ("I'm allergic to sulfa drugs.", {"entities": [(13, 23, "ALLERGY")]}),
    ("I have a tetracycline allergy.", {"entities": [(10, 21, "ALLERGY")]}),
    ("The sky is blue.", {"entities": []}),
    ("I enjoy playing the guitar.", {"entities": []}),
    ("She runs every morning.", {"entities": []}),
    ("Cooking is an art form.", {"entities": []}),
    ("He likes to read science fiction novels.", {"entities": []}),
    ("The flowers bloom in spring.", {"entities": []}),
    ("Hiking in the mountains is exhilarating.", {"entities": []}),
    ("Music brings people together.", {"entities": []}),
    ("They celebrate birthdays with cake.", {"entities": []}),
    ("Learning new skills is challenging.", {"entities": []}),
    ("The train arrives at 9 AM.", {"entities": []}),
    ("I prefer tea over coffee.", {"entities": []}),
    ("The cat purrs when petted.", {"entities": []}),
    ("Driving in traffic can be stressful.", {"entities": []}),
    ("I like to watch documentaries.", {"entities": []}),
    ("The smell of freshly cut grass is pleasant.", {"entities": []}),
    ("She practices yoga for relaxation.", {"entities": []}),
    ("Artists express themselves through their work.", {"entities": []}),
    ("Reading under a cozy blanket is comforting.", {"entities": []}),
    ("He enjoys fishing by the lake.", {"entities": []}),
    ("Rainbows appear after a rainstorm.", {"entities": []}),
    ("The sound of laughter fills the room.", {"entities": []}),
    ("She bakes cookies for her friends.", {"entities": []}),
    ("The city lights shine brightly at night.", {"entities": []}),
    ("He takes photographs as a hobby.", {"entities": []}),
    ("Writing poetry is a creative outlet.", {"entities": []}),
    ("They take walks in the park.", {"entities": []}),
    ("Exploring new places is exciting.", {"entities": []}),
    ("The clock ticks rhythmically on the wall.", {"entities": []}),
    ("She practices meditation for inner peace.", {"entities": []}),
    ("Gardens are filled with colorful flowers.", {"entities": []}),
    ("The smell of coffee fills the kitchen.", {"entities": []}),
    ("They go swimming at the beach.", {"entities": []}),
    ("Drawing is a form of self-expression.", {"entities": []}),
    ("He enjoys watching sports on TV.", {"entities": []}),
    ("Birds chirp in the trees.", {"entities": []}),
    ("She volunteers at the local shelter.", {"entities": []}),
    ("The sun sets in the evening sky.", {"entities": []}),
    ("He practices martial arts for discipline.", {"entities": []}),
    ("Candles flicker in the dark room.", {"entities": []}),
    ("She enjoys picnics in the park.", {"entities": []}),
    ("The smell of rain is refreshing.", {"entities": []}),
    ("They go for bike rides on weekends.", {"entities": []}),
    ("Cooking with fresh herbs enhances flavor.", {"entities": []}),
    ("He plays the piano for relaxation.", {"entities": []}),
    ("The stars twinkle in the night sky.", {"entities": []}),
    ("She collects seashells on the beach.", {"entities": []}),
    ("The smell of cinnamon fills the air.", {"entities": []}),
    ("They watch the sunrise together.", {"entities": []}),
    ("Painting landscapes is a hobby.", {"entities": []}),
    ("He enjoys stargazing on clear nights.", {"entities": []}),
    ("The smell of roses is intoxicating.", {"entities": []}),
    ("She enjoys gardening in her spare time.", {"entities": []}),
    ("He listens to music while studying.", {"entities": []}),
    ("Watching the sunset is a peaceful experience.", {"entities": []}),
    ("They go camping in the mountains.", {"entities": []}),
    ("The sound of waves crashing is relaxing.", {"entities": []}),
    ("She practices mindfulness for mental clarity.", {"entities": []}),
    ("He enjoys building model airplanes.", {"entities": []}),
    ("The smell of pine trees fills the forest.", {"entities": []}),
    ("They go for long walks in nature.", {"entities": []}),
    ("She enjoys knitting as a hobby.", {"entities": []}),
    ("The sound of crickets fills the night.", {"entities": []}),
    ("He takes photographs of nature.", {"entities": []}),
    ("She enjoys collecting vintage records.", {"entities": []}),
    ("The smell of fresh laundry is comforting.", {"entities": []}),
    ("They enjoy picnics by the lake.", {"entities": []}),
    ("He practices calligraphy for relaxation.", {"entities": []}),
    ("Watching thunderstorms is exciting.", {"entities": []}),
    ("She enjoys birdwatching in the park.", {"entities": []}),
    ("The smell of barbecue fills the backyard.", {"entities": []}),
    ("They go on road trips to explore new places.", {"entities": []}),
    ("He enjoys sculpting as a creative outlet.", {"entities": []}),
    ("The sound of birdsong fills the morning.", {"entities": []}),
    ("She practices tai chi for balance.", {"entities": []}),
    ("They go for hikes in the wilderness.", {"entities": []}),
    ("He enjoys playing board games with friends.", {"entities": []}),
    ("The smell of fresh bread is irresistible.", {"entities": []}),
    ("They watch movies together on weekends.", {"entities": []}),
    ("She enjoys embroidery as a hobby.", {"entities": []}),
    ("The sound of rain tapping on the roof is calming.", {"entities": []}),
    ("He collects stamps as a hobby.", {"entities": []}),
    ("She enjoys horseback riding in the countryside.", {"entities": []}),
    ("The smell of chocolate chip cookies baking is heavenly.", {"entities": []}),
    ("They go kayaking on the river.", {"entities": []}),
    ("He practices photography as a hobby.", {"entities": []}),
    ("The sound of wind rustling through the trees is soothing.", {"entities": []}),
    ("She enjoys pottery as a creative outlet.", {"entities": []}),
    ("They go for walks in the snow.", {"entities": []}),
    ("He enjoys reading comic books in his free time.", {"entities": []}),
    ("The smell of freshly brewed coffee is invigorating.", {"entities": []}),
    ("They go ice skating at the rink.", {"entities": []}),
    ("She practices mindfulness for stress relief.", {"entities": []}),
    ("The sound of a crackling fire is comforting.", {"entities": []}),
    ("He enjoys playing video games as a hobby.", {"entities": []}),
    ("She enjoys knitting as a creative outlet.", {"entities": []}),
    ("They go for picnics in the countryside.", {"entities": []}),
    ("I love exploring new places and discovering.", {"entities": []}),
    ("I enjoy nature, trees, and fresh air.", {"entities": []}),
    ("I find joy in watching the sunset.", {"entities": []}),
    ("I'm passionate about photography and capturing moments.", {"entities": []}),
    ("I find solace in reading books.", {"entities": []}),
    ("I love cooking delicious meals.", {"entities": []}),
    ("I'm fascinated by stars and stargazing.", {"entities": []}),
    ("I'm drawn to the ocean and waves.", {"entities": []}),
    ("I'm a believer in mindfulness and meditation.", {"entities": []}),
    ("I find inspiration in art galleries.", {"entities": []}),
    ("I'm always curious and love learning.", {"entities": []}),
    ("I enjoy solving puzzles and brain teasers.", {"entities": []}),
    ("I find peace in nature's beauty.", {"entities": []}),
    ("I'm passionate about music and guitar.", {"entities": []}),
    ("I'm a keen observer and birdwatching.", {"entities": []}),
    ("I'm a collector and enjoy finding treasures.", {"entities": []}),
    ("I'm happiest when surrounded by loved ones.", {"entities": []}),
    ("I believe in self-care and relaxation.", {"entities": []}),
    ("I'm an adventurer and love exploring.", {"entities": []}),
    ("I'm passionate about conservation and sustainability.", {"entities": []}),
    ("I find joy in helping others.", {"entities": []}),
    ("I'm fascinated by history and museums.", {"entities": []}),
    ("I'm a dreamer and love creativity.", {"entities": []}),
    ("I'm a believer in positivity and kindness.", {"entities": []}),
    ("I find peace in life's simplicity.", {"entities": []}),
    ("I'm passionate about fitness and challenges.", {"entities": []}),
    ("I'm a lifelong learner and seek growth.", {"entities": []}),
    ("I find inspiration in nature and photography.", {"entities": []}),
    ("I'm an advocate for mental health awareness.", {"entities": []}),
    ("I'm an explorer and love adventures.", {"entities": []}),
    ("I find joy in the little things.", {"entities": []}),
    ("I'm passionate about creativity and expression.", {"entities": []}),
    ("I'm an animal lover and enjoy companionship.", {"entities": []}),
    ("I'm a believer in gratitude and thankfulness.", {"entities": []}),
    ("I'm a dreamer and imagine endless possibilities.", {"entities": []}),
    ("I'm a seeker of knowledge and understanding.", {"entities": []}),
    ("I enjoy painting and expressing my emotions.", {"entities": []}),
    ("I'm an early riser and love mornings.", {"entities": []}),
    ("I find comfort in a warm cup.", {"entities": []}),
    ("I'm passionate about helping others succeed.", {"entities": []}),
    ("I'm fascinated by science and discovery.", {"entities": []}),
    ("I find joy in spending time outdoors.", {"entities": []}),
    ("I'm a believer in lifelong learning.", {"entities": []}),
    ("I'm an explorer and crave new experiences.", {"entities": []}),
    ("I love the smell of fresh flowers.", {"entities": []}),
    ("I find solace in the sound of rain.", {"entities": []}),
    ("I'm a believer in the power of positivity.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about protecting the environment.", {"entities": []}),
    ("I find inspiration in the beauty of nature.", {"entities": []}),
    ("I'm a dreamer and love to imagine.", {"entities": []}),
    ("I'm an optimist and see the good.", {"entities": []}),
    ("I enjoy the taste of freshly brewed coffee.", {"entities": []}),
    ("I'm a believer in the importance of kindness.", {"entities": []}),
    ("I love the feeling of accomplishment after exercise.", {"entities": []}),
    ("I find happiness in the little things.", {"entities": []}),
    ("I'm passionate about making a difference.", {"entities": []}),
    ("I find peace in the sound of birdsong.", {"entities": []}),
    ("I'm a believer in the power of dreams.", {"entities": []}),
    ("I'm an adventurer and seek new horizons.", {"entities": []}),
    ("I enjoy the feeling of sunshine on my face.", {"entities": []}),
    ("I'm passionate about living life to the fullest.", {"entities": []}),
    ("I find comfort in the company of loved ones.", {"entities": []}),
    ("I'm fascinated by the wonders of the universe.", {"entities": []}),
    ("I find joy in the simple pleasures of life.", {"entities": []}),
    ("I'm a believer in the value of friendship.", {"entities": []}),
    ("I enjoy the feeling of grass beneath my feet.", {"entities": []}),
    ("I'm passionate about learning from others.", {"entities": []}),
    ("I find inspiration in the power of imagination.", {"entities": []}),
    ("I'm a dreamer and chase my aspirations.", {"entities": []}),
    ("I'm an explorer and seek adventure.", {"entities": []}),
    ("I enjoy the feeling of accomplishment after a workout.", {"entities": []}),
    ("I'm a believer in the beauty of simplicity.", {"entities": []}),
    ("I find happiness in the beauty of nature.", {"entities": []}),
    ("I'm passionate about making a positive impact.", {"entities": []}),
    ("I find comfort in the warmth of the sun.", {"entities": []}),
    ("I'm fascinated by the mysteries of the mind.", {"entities": []}),
    ("I find joy in the laughter of loved ones.", {"entities": []}),
    ("I'm a believer in the power of love.", {"entities": []}),
    ("I enjoy the feeling of rain on my skin.", {"entities": []}),
    ("I'm passionate about pursuing my dreams.", {"entities": []}),
    ("I find inspiration in the beauty of art.", {"entities": []}),
    ("I'm a dreamer and believe in possibilities.", {"entities": []}),
    ("I'm an adventurer and embrace uncertainty.", {"entities": []}),
    ("I enjoy the feeling of wind in my hair.", {"entities": []}),
    ("I'm a believer in the importance of gratitude.", {"entities": []}),
    ("I find happiness in the simplicity of life.", {"entities": []}),
    ("I'm passionate about spreading kindness.", {"entities": []}),
    ("I find comfort in the sound of waves.", {"entities": []}),
    ("I'm fascinated by the diversity of cultures.", {"entities": []}),
    ("I find joy in the beauty of a sunrise.", {"entities": []}),
    ("I'm a believer in the power of perseverance.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about living with purpose.", {"entities": []}),
    ("I find inspiration in the magic of storytelling.", {"entities": []}),
    ("I'm a dreamer and believe in magic.", {"entities": []}),
    ("I'm an explorer and seek new adventures.", {"entities": []}),
    ("I enjoy the feeling of a warm embrace.", {"entities": []}),
    ("I'm a believer in the beauty of diversity.", {"entities": []}),
    ("I find happiness in the company of friends.", {"entities": []}),
    ("I'm passionate about preserving natural habitats.", {"entities": []}),
    ("I find comfort in the sound of gentle rain.", {"entities": []}),
    ("I'm fascinated by the wonders of the natural world.", {"entities": []}),
    ("I find joy in the sound of children's laughter.", {"entities": []}),
    ("I'm a believer in the power of resilience.", {"entities": []}),
    ("I enjoy the feeling of accomplishment after a run.", {"entities": []}),
    ("I'm passionate about creating meaningful connections.", {"entities": []}),
    ("I find inspiration in the beauty of the night sky.", {"entities": []}),
    ("I'm a dreamer and chase after my dreams.", {"entities": []}),
    ("I'm an adventurer and seek new challenges.", {"entities": []}),
    ("I enjoy the feeling of a warm cup of tea.", {"entities": []}),
    ("I'm a believer in the importance of empathy.", {"entities": []}),
    ("I find happiness in the sound of music.", {"entities": []}),
    ("I'm passionate about fostering a sense of belonging.", {"entities": []}),
    ("I find comfort in the serenity of a quiet moment.", {"entities": []}),
    ("I'm fascinated by the mysteries of the human heart.", {"entities": []}),
    ("I find joy in the colors of a sunset.", {"entities": []}),
    ("I'm a believer in the power of positive thinking.", {"entities": []}),
    ("I enjoy the feeling of a cool breeze.", {"entities": []}),
    ("I'm passionate about making a positive difference.", {"entities": []}),
    ("I find inspiration in the resilience of nature.", {"entities": []}),
    ("I'm a dreamer and believe in infinite possibilities.", {"entities": []}),
    ("I'm an explorer and seek new opportunities.", {"entities": []}),
    ("I enjoy the feeling of laughter bubbling up.", {"entities": []}),
    ("I'm a believer in the importance of compassion.", {"entities": []}),
    ("I find happiness in the simple joys of life.", {"entities": []}),
    ("I'm passionate about protecting endangered species.", {"entities": []}),
    ("I find comfort in the sound of birds chirping.", {"entities": []}),
    ("I'm fascinated by the wonders of the cosmos.", {"entities": []}),
    ("I find joy in the beauty of a blooming flower.", {"entities": []}),
    ("I'm a believer in the power of self-discovery.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about creating a more sustainable future.", {"entities": []}),
    ("I find inspiration in the power of human potential.", {"entities": []}),
    ("I'm a dreamer and believe in following my heart.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm hug.", {"entities": []}),
    ("I'm a believer in the importance of diversity.", {"entities": []}),
    ("I find happiness in the beauty of a rainbow.", {"entities": []}),
    ("I'm passionate about promoting social justice.", {"entities": []}),
    ("I find comfort in the warmth of a cozy fire.", {"entities": []}),
    ("I'm fascinated by the intricacies of the human mind.", {"entities": []}),
    ("I find joy in the sound of waves crashing.", {"entities": []}),
    ("I'm a believer in the power of resilience and perseverance.", {"entities": []}),
    ("I enjoy the feeling of a gentle breeze.", {"entities": []}),
    ("I'm passionate about spreading love and kindness.", {"entities": []}),
    ("I find inspiration in the beauty of the natural world.", {"entities": []}),
    ("I'm a dreamer and believe in the beauty of dreams.", {"entities": []}),
    ("I'm an explorer and seek adventure wherever I go.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm a believer in the importance of mindfulness.", {"entities": []}),
    ("I find happiness in the company of good friends.", {"entities": []}),
    ("I'm passionate about making the world a better place.", {"entities": []}),
    ("I find comfort in the sound of rain falling softly.", {"entities": []}),
    ("I'm fascinated by the wonders of the natural world.", {"entities": []}),
    ("I find joy in the laughter of children at play.", {"entities": []}),
    ("I'm a believer in the power of resilience and strength.", {"entities": []}),
    ("I enjoy the feeling of accomplishment after a workout.", {"entities": []}),
    ("I'm passionate about fostering a sense of community.", {"entities": []}),
    ("I find inspiration in the beauty of the night sky.", {"entities": []}),
    ("I'm a dreamer and believe in the power of imagination.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm cup of tea.", {"entities": []}),
    ("I'm a believer in the importance of empathy and understanding.", {"entities": []}),
    ("I find happiness in the sound of music.", {"entities": []}),
    ("I'm passionate about fostering a sense of belonging.", {"entities": []}),
    ("I find comfort in the serenity of a quiet moment.", {"entities": []}),
    ("I'm fascinated by the mysteries of the human heart.", {"entities": []}),
    ("I find joy in the colors of a sunset.", {"entities": []}),
    ("I'm a believer in the power of positive thinking.", {"entities": []}),
    ("I enjoy the feeling of a cool breeze.", {"entities": []}),
    ("I'm passionate about making a positive difference.", {"entities": []}),
    ("I find inspiration in the resilience of nature.", {"entities": []}),
    ("I'm a dreamer and believe in infinite possibilities.", {"entities": []}),
    ("I'm an explorer and seek new opportunities.", {"entities": []}),
    ("I enjoy the feeling of laughter bubbling up.", {"entities": []}),
    ("I'm a believer in the importance of compassion.", {"entities": []}),
    ("I find happiness in the simple joys of life.", {"entities": []}),
    ("I'm passionate about protecting endangered species.", {"entities": []}),
    ("I find comfort in the sound of birds chirping.", {"entities": []}),
    ("I'm fascinated by the wonders of the cosmos.", {"entities": []}),
    ("I find joy in the beauty of a blooming flower.", {"entities": []}),
    ("I'm a believer in the power of self-discovery.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about creating a more sustainable future.", {"entities": []}),
    ("I find inspiration in the power of human potential.", {"entities": []}),
    ("I'm a dreamer and believe in following my heart.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm hug.", {"entities": []}),
    ("I'm a believer in the importance of diversity.", {"entities": []}),
    ("I find happiness in the beauty of a rainbow.", {"entities": []}),
    ("I'm passionate about promoting social justice.", {"entities": []}),
    ("I find comfort in the warmth of a cozy fire.", {"entities": []}),
    ("I'm fascinated by the intricacies of the human mind.", {"entities": []}),
    ("I find joy in the sound of waves crashing.", {"entities": []}),
    ("I'm a believer in the power of resilience and perseverance.", {"entities": []}),
    ("I enjoy the feeling of a gentle breeze.", {"entities": []}),
    ("I'm passionate about spreading love and kindness.", {"entities": []}),
    ("I find inspiration in the beauty of the natural world.", {"entities": []}),
    ("I'm a dreamer and believe in the beauty of dreams.", {"entities": []}),
    ("I'm an explorer and seek adventure wherever I go.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm a believer in the importance of mindfulness.", {"entities": []}),
    ("I find happiness in the company of good friends.", {"entities": []}),
    ("I'm passionate about making the world a better place.", {"entities": []}),
    ("I find comfort in the sound of rain falling softly.", {"entities": []}),
    ("I'm fascinated by the wonders of the natural world.", {"entities": []}),
    ("I find joy in the laughter of children at play.", {"entities": []}),
    ("I'm a believer in the power of resilience and strength.", {"entities": []}),
    ("I enjoy the feeling of accomplishment after a workout.", {"entities": []}),
    ("I'm passionate about fostering a sense of community.", {"entities": []}),
    ("I find inspiration in the beauty of the night sky.", {"entities": []}),
    ("I'm a dreamer and believe in the power of imagination.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm cup of tea.", {"entities": []}),
    ("I'm a believer in the importance of empathy and understanding.", {"entities": []}),
    ("I find happiness in the sound of music.", {"entities": []}),
    ("I'm passionate about fostering a sense of belonging.", {"entities": []}),
    ("I find comfort in the serenity of a quiet moment.", {"entities": []}),
    ("I'm fascinated by the mysteries of the human heart.", {"entities": []}),
    ("I find joy in the colors of a sunset.", {"entities": []}),
    ("I'm a believer in the power of positive thinking.", {"entities": []}),
    ("I enjoy the feeling of a cool breeze.", {"entities": []}),
    ("I'm passionate about making a positive difference.", {"entities": []}),
    ("I find inspiration in the resilience of nature.", {"entities": []}),
    ("I'm a dreamer and believe in infinite possibilities.", {"entities": []}),
    ("I'm an explorer and seek new opportunities.", {"entities": []}),
    ("I enjoy the feeling of laughter bubbling up.", {"entities": []}),
    ("I'm a believer in the importance of compassion.", {"entities": []}),
    ("I find happiness in the simple joys of life.", {"entities": []}),
    ("I'm passionate about protecting endangered species.", {"entities": []}),
    ("I find comfort in the sound of birds chirping.", {"entities": []}),
    ("I'm fascinated by the wonders of the cosmos.", {"entities": []}),
    ("I find joy in the beauty of a blooming flower.", {"entities": []}),
    ("I'm a believer in the power of self-discovery.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about creating a more sustainable future.", {"entities": []}),
    ("I find inspiration in the power of human potential.", {"entities": []}),
    ("I'm a dreamer and believe in following my heart.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm hug.", {"entities": []}),
    ("I'm a believer in the importance of diversity.", {"entities": []}),
    ("I find happiness in the beauty of a rainbow.", {"entities": []}),
    ("I'm passionate about promoting social justice.", {"entities": []}),
    ("I find comfort in the warmth of a cozy fire.", {"entities": []}),
    ("I'm fascinated by the intricacies of the human mind.", {"entities": []}),
    ("I find joy in the sound of waves crashing.", {"entities": []}),
    ("I'm a believer in the power of resilience and perseverance.", {"entities": []}),
    ("I enjoy the feeling of a gentle breeze.", {"entities": []}),
    ("I'm passionate about spreading love and kindness.", {"entities": []}),
    ("I find inspiration in the beauty of the natural world.", {"entities": []}),
    ("I'm a dreamer and believe in the beauty of dreams.", {"entities": []}),
    ("I'm an explorer and seek adventure wherever I go.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm a believer in the importance of mindfulness.", {"entities": []}),
    ("I find happiness in the company of good friends.", {"entities": []}),
    ("I'm passionate about making the world a better place.", {"entities": []}),
    ("I find comfort in the sound of rain falling softly.", {"entities": []}),
    ("I'm fascinated by the wonders of the natural world.", {"entities": []}),
    ("I find joy in the laughter of children at play.", {"entities": []}),
    ("I'm a believer in the power of resilience and strength.", {"entities": []}),
    ("I enjoy the feeling of accomplishment after a workout.", {"entities": []}),
    ("I'm passionate about fostering a sense of community.", {"entities": []}),
    ("I find inspiration in the beauty of the night sky.", {"entities": []}),
    ("I'm a dreamer and believe in the power of imagination.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm cup of tea.", {"entities": []}),
    ("I'm a believer in the importance of empathy and understanding.", {"entities": []}),
    ("I find happiness in the sound of music.", {"entities": []}),
    ("I'm passionate about fostering a sense of belonging.", {"entities": []}),
    ("I find comfort in the serenity of a quiet moment.", {"entities": []}),
    ("I'm fascinated by the mysteries of the human heart.", {"entities": []}),
    ("I find joy in the colors of a sunset.", {"entities": []}),
    ("I'm a believer in the power of positive thinking.", {"entities": []}),
    ("I enjoy the feeling of a cool breeze.", {"entities": []}),
    ("I'm passionate about making a positive difference.", {"entities": []}),
    ("I find inspiration in the resilience of nature.", {"entities": []}),
    ("I'm a dreamer and believe in infinite possibilities.", {"entities": []}),
    ("I'm an explorer and seek new opportunities.", {"entities": []}),
    ("I enjoy the feeling of laughter bubbling up.", {"entities": []}),
    ("I'm a believer in the importance of compassion.", {"entities": []}),
    ("I find happiness in the simple joys of life.", {"entities": []}),
    ("I'm passionate about protecting endangered species.", {"entities": []}),
    ("I find comfort in the sound of birds chirping.", {"entities": []}),
    ("I'm fascinated by the wonders of the cosmos.", {"entities": []}),
    ("I find joy in the beauty of a blooming flower.", {"entities": []}),
    ("I'm a believer in the power of self-discovery.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about creating a more sustainable future.", {"entities": []}),
    ("I find inspiration in the power of human potential.", {"entities": []}),
    ("I'm a dreamer and believe in following my heart.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm hug.", {"entities": []}),
    ("I'm a believer in the importance of diversity.", {"entities": []}),
    ("I find happiness in the beauty of a rainbow.", {"entities": []}),
    ("I'm passionate about promoting social justice.", {"entities": []}),
    ("I find comfort in the warmth of a cozy fire.", {"entities": []}),
    ("I'm fascinated by the intricacies of the human mind.", {"entities": []}),
    ("I find joy in the sound of waves crashing.", {"entities": []}),
    ("I'm a believer in the power of resilience and perseverance.", {"entities": []}),
    ("I enjoy the feeling of a gentle breeze.", {"entities": []}),
    ("I'm passionate about spreading love and kindness.", {"entities": []}),
    ("I find inspiration in the beauty of the natural world.", {"entities": []}),
    ("I'm a dreamer and believe in the beauty of dreams.", {"entities": []}),
    ("I'm an explorer and seek adventure wherever I go.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm a believer in the importance of mindfulness.", {"entities": []}),
    ("I find happiness in the company of good friends.", {"entities": []}),
    ("I'm passionate about making the world a better place.", {"entities": []}),
    ("I find comfort in the sound of rain falling softly.", {"entities": []}),
    ("I'm fascinated by the wonders of the natural world.", {"entities": []}),
    ("I find joy in the laughter of children at play.", {"entities": []}),
    ("I'm a believer in the power of resilience and strength.", {"entities": []}),
    ("I enjoy the feeling of accomplishment after a workout.", {"entities": []}),
    ("I'm passionate about fostering a sense of community.", {"entities": []}),
    ("I find inspiration in the beauty of the night sky.", {"entities": []}),
    ("I'm a dreamer and believe in the power of imagination.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm cup of tea.", {"entities": []}),
    ("I'm a believer in the importance of empathy and understanding.", {"entities": []}),
    ("I find happiness in the sound of music.", {"entities": []}),
    ("I'm passionate about fostering a sense of belonging.", {"entities": []}),
    ("I find comfort in the serenity of a quiet moment.", {"entities": []}),
    ("I'm fascinated by the mysteries of the human heart.", {"entities": []}),
    ("I find joy in the colors of a sunset.", {"entities": []}),
    ("I'm a believer in the power of positive thinking.", {"entities": []}),
    ("I enjoy the feeling of a cool breeze.", {"entities": []}),
    ("I'm passionate about making a positive difference.", {"entities": []}),
    ("I find inspiration in the resilience of nature.", {"entities": []}),
    ("I'm a dreamer and believe in infinite possibilities.", {"entities": []}),
    ("I'm an explorer and seek new opportunities.", {"entities": []}),
    ("I enjoy the feeling of laughter bubbling up.", {"entities": []}),
    ("I'm a believer in the importance of compassion.", {"entities": []}),
    ("I find happiness in the simple joys of life.", {"entities": []}),
    ("I'm passionate about protecting endangered species.", {"entities": []}),
    ("I find comfort in the sound of birds chirping.", {"entities": []}),
    ("I'm fascinated by the wonders of the cosmos.", {"entities": []}),
    ("I find joy in the beauty of a blooming flower.", {"entities": []}),
    ("I'm a believer in the power of self-discovery.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about creating a more sustainable future.", {"entities": []}),
    ("I find inspiration in the power of human potential.", {"entities": []}),
    ("I'm a dreamer and believe in following my heart.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm hug.", {"entities": []}),
    ("I'm a believer in the importance of diversity.", {"entities": []}),
    ("I find happiness in the beauty of a rainbow.", {"entities": []}),
    ("I'm passionate about promoting social justice.", {"entities": []}),
    ("I find comfort in the warmth of a cozy fire.", {"entities": []}),
    ("I'm fascinated by the intricacies of the human mind.", {"entities": []}),
    ("I find joy in the sound of waves crashing.", {"entities": []}),
    ("I'm a believer in the power of resilience and perseverance.", {"entities": []}),
    ("I enjoy the feeling of a gentle breeze.", {"entities": []}),
    ("I'm passionate about spreading love and kindness.", {"entities": []}),
    ("I find inspiration in the beauty of the natural world.", {"entities": []}),
    ("I'm a dreamer and believe in the beauty of dreams.", {"entities": []}),
    ("I'm an explorer and seek adventure wherever I go.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm a believer in the importance of mindfulness.", {"entities": []}),
    ("I find happiness in the company of good friends.", {"entities": []}),
    ("I'm passionate about making the world a better place.", {"entities": []}),
    ("I find comfort in the sound of rain falling softly.", {"entities": []}),
    ("I'm fascinated by the wonders of the natural world.", {"entities": []}),
    ("I find joy in the laughter of children at play.", {"entities": []}),
    ("I'm a believer in the power of resilience and strength.", {"entities": []}),
    ("I enjoy the feeling of accomplishment after a workout.", {"entities": []}),
    ("I'm passionate about fostering a sense of community.", {"entities": []}),
    ("I find inspiration in the beauty of the night sky.", {"entities": []}),
    ("I'm a dreamer and believe in the power of imagination.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm cup of tea.", {"entities": []}),
    ("I'm a believer in the importance of empathy and understanding.", {"entities": []}),
    ("I find happiness in the sound of music.", {"entities": []}),
    ("I'm passionate about fostering a sense of belonging.", {"entities": []}),
    ("I find comfort in the serenity of a quiet moment.", {"entities": []}),
    ("I'm fascinated by the mysteries of the human heart.", {"entities": []}),
    ("I find joy in the colors of a sunset.", {"entities": []}),
    ("I'm a believer in the power of positive thinking.", {"entities": []}),
    ("I enjoy the feeling of a cool breeze.", {"entities": []}),
    ("I'm passionate about making a positive difference.", {"entities": []}),
    ("I find inspiration in the resilience of nature.", {"entities": []}),
    ("I'm a dreamer and believe in infinite possibilities.", {"entities": []}),
    ("I'm an explorer and seek new opportunities.", {"entities": []}),
    ("I enjoy the feeling of laughter bubbling up.", {"entities": []}),
    ("I'm a believer in the importance of compassion.", {"entities": []}),
    ("I find happiness in the simple joys of life.", {"entities": []}),
    ("I'm passionate about protecting endangered species.", {"entities": []}),
    ("I find comfort in the sound of birds chirping.", {"entities": []}),
    ("I'm fascinated by the wonders of the cosmos.", {"entities": []}),
    ("I find joy in the beauty of a blooming flower.", {"entities": []}),
    ("I'm a believer in the power of self-discovery.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about creating a more sustainable future.", {"entities": []}),
    ("I find inspiration in the power of human potential.", {"entities": []}),
    ("I'm a dreamer and believe in following my heart.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm hug.", {"entities": []}),
    ("I'm a believer in the importance of diversity.", {"entities": []}),
    ("I find happiness in the beauty of a rainbow.", {"entities": []}),
    ("I'm passionate about promoting social justice.", {"entities": []}),
    ("I find comfort in the warmth of a cozy fire.", {"entities": []}),
    ("I'm fascinated by the intricacies of the human mind.", {"entities": []}),
    ("I find joy in the sound of waves crashing.", {"entities": []}),
    ("I'm a believer in the power of resilience and perseverance.", {"entities": []}),
    ("I enjoy the feeling of a gentle breeze.", {"entities": []}),
    ("I'm passionate about spreading love and kindness.", {"entities": []}),
    ("I find inspiration in the beauty of the natural world.", {"entities": []}),
    ("I'm a dreamer and believe in the beauty of dreams.", {"entities": []}),
    ("I'm an explorer and seek adventure wherever I go.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm a believer in the importance of mindfulness.", {"entities": []}),
    ("I find happiness in the company of good friends.", {"entities": []}),
    ("I'm passionate about making the world a better place.", {"entities": []}),
    ("I find comfort in the sound of rain falling softly.", {"entities": []}),
    ("I'm fascinated by the wonders of the natural world.", {"entities": []}),
    ("I find joy in the laughter of children at play.", {"entities": []}),
    ("I'm a believer in the power of resilience and strength.", {"entities": []}),
    ("I enjoy the feeling of accomplishment after a workout.", {"entities": []}),
    ("I'm passionate about fostering a sense of community.", {"entities": []}),
    ("I find inspiration in the beauty of the night sky.", {"entities": []}),
    ("I'm a dreamer and believe in the power of imagination.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm cup of tea.", {"entities": []}),
    ("I'm a believer in the importance of empathy and understanding.", {"entities": []}),
    ("I find happiness in the sound of music.", {"entities": []}),
    ("I'm passionate about fostering a sense of belonging.", {"entities": []}),
    ("I find comfort in the serenity of a quiet moment.", {"entities": []}),
    ("I'm fascinated by the mysteries of the human heart.", {"entities": []}),
    ("I find joy in the colors of a sunset.", {"entities": []}),
    ("I'm a believer in the power of positive thinking.", {"entities": []}),
    ("I enjoy the feeling of a cool breeze.", {"entities": []}),
    ("I'm passionate about making a positive difference.", {"entities": []}),
    ("I find inspiration in the resilience of nature.", {"entities": []}),
    ("I'm a dreamer and believe in infinite possibilities.", {"entities": []}),
    ("I'm an explorer and seek new opportunities.", {"entities": []}),
    ("I enjoy the feeling of laughter bubbling up.", {"entities": []}),
    ("I'm a believer in the importance of compassion.", {"entities": []}),
    ("I find happiness in the simple joys of life.", {"entities": []}),
    ("I'm passionate about protecting endangered species.", {"entities": []}),
    ("I find comfort in the sound of birds chirping.", {"entities": []}),
    ("I'm fascinated by the wonders of the cosmos.", {"entities": []}),
    ("I find joy in the beauty of a blooming flower.", {"entities": []}),
    ("I'm a believer in the power of self-discovery.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about creating a more sustainable future.", {"entities": []}),
    ("I find inspiration in the power of human potential.", {"entities": []}),
    ("I'm a dreamer and believe in following my heart.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm hug.", {"entities": []}),
    ("I'm a believer in the importance of diversity.", {"entities": []}),
    ("I find happiness in the beauty of a rainbow.", {"entities": []}),
    ("I'm passionate about promoting social justice.", {"entities": []}),
    ("I find comfort in the warmth of a cozy fire.", {"entities": []}),
    ("I'm fascinated by the intricacies of the human mind.", {"entities": []}),
    ("I find joy in the sound of waves crashing.", {"entities": []}),
    ("I'm a believer in the power of resilience and perseverance.", {"entities": []}),
    ("I enjoy the feeling of a gentle breeze.", {"entities": []}),
    ("I'm passionate about spreading love and kindness.", {"entities": []}),
    ("I find inspiration in the beauty of the natural world.", {"entities": []}),
    ("I'm a dreamer and believe in the beauty of dreams.", {"entities": []}),
    ("I'm an explorer and seek adventure wherever I go.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm a believer in the importance of mindfulness.", {"entities": []}),
    ("I find happiness in the company of good friends.", {"entities": []}),
    ("I'm passionate about making the world a better place.", {"entities": []}),
    ("I find comfort in the sound of rain falling softly.", {"entities": []}),
    ("I'm fascinated by the wonders of the natural world.", {"entities": []}),
    ("I find joy in the laughter of children at play.", {"entities": []}),
    ("I'm a believer in the power of resilience and strength.", {"entities": []}),
    ("I enjoy the feeling of accomplishment after a workout.", {"entities": []}),
    ("I'm passionate about fostering a sense of community.", {"entities": []}),
    ("I find inspiration in the beauty of the night sky.", {"entities": []}),
    ("I'm a dreamer and believe in the power of imagination.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm cup of tea.", {"entities": []}),
    ("I'm a believer in the importance of empathy and understanding.", {"entities": []}),
    ("I find happiness in the sound of music.", {"entities": []}),
    ("I'm passionate about fostering a sense of belonging.", {"entities": []}),
    ("I find comfort in the serenity of a quiet moment.", {"entities": []}),
    ("I'm fascinated by the mysteries of the human heart.", {"entities": []}),
    ("I find joy in the colors of a sunset.", {"entities": []}),
    ("I'm a believer in the power of positive thinking.", {"entities": []}),
    ("I enjoy the feeling of a cool breeze.", {"entities": []}),
    ("I'm passionate about making a positive difference.", {"entities": []}),
    ("I find inspiration in the resilience of nature.", {"entities": []}),
    ("I'm a dreamer and believe in infinite possibilities.", {"entities": []}),
    ("I'm an explorer and seek new opportunities.", {"entities": []}),
    ("I enjoy the feeling of laughter bubbling up.", {"entities": []}),
    ("I'm a believer in the importance of compassion.", {"entities": []}),
    ("I find happiness in the simple joys of life.", {"entities": []}),
    ("I'm passionate about protecting endangered species.", {"entities": []}),
    ("I find comfort in the sound of birds chirping.", {"entities": []}),
    ("I'm fascinated by the wonders of the cosmos.", {"entities": []}),
    ("I find joy in the beauty of a blooming flower.", {"entities": []}),
    ("I'm a believer in the power of self-discovery.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about creating a more sustainable future.", {"entities": []}),
    ("I find inspiration in the power of human potential.", {"entities": []}),
    ("I'm a dreamer and believe in following my heart.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm hug.", {"entities": []}),
    ("I'm a believer in the importance of diversity.", {"entities": []}),
    ("I find happiness in the beauty of a rainbow.", {"entities": []}),
    ("I'm passionate about promoting social justice.", {"entities": []}),
    ("I find comfort in the warmth of a cozy fire.", {"entities": []}),
    ("I'm fascinated by the intricacies of the human mind.", {"entities": []}),
    ("I find joy in the sound of waves crashing.", {"entities": []}),
    ("I'm a believer in the power of resilience and perseverance.", {"entities": []}),
    ("I enjoy the feeling of a gentle breeze.", {"entities": []}),
    ("I'm passionate about spreading love and kindness.", {"entities": []}),
    ("I find inspiration in the beauty of the natural world.", {"entities": []}),
    ("I'm a dreamer and believe in the beauty of dreams.", {"entities": []}),
    ("I'm an explorer and seek adventure wherever I go.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm a believer in the importance of mindfulness.", {"entities": []}),
    ("I find happiness in the company of good friends.", {"entities": []}),
    ("I'm passionate about making the world a better place.", {"entities": []}),
    ("I find comfort in the sound of rain falling softly.", {"entities": []}),
    ("I'm fascinated by the wonders of the natural world.", {"entities": []}),
    ("I find joy in the laughter of children at play.", {"entities": []}),
    ("I'm a believer in the power of resilience and strength.", {"entities": []}),
    ("I enjoy the feeling of accomplishment after a workout.", {"entities": []}),
    ("I'm passionate about fostering a sense of community.", {"entities": []}),
    ("I find inspiration in the beauty of the night sky.", {"entities": []}),
    ("I'm a dreamer and believe in the power of imagination.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm cup of tea.", {"entities": []}),
    ("I'm a believer in the importance of empathy and understanding.", {"entities": []}),
    ("I find happiness in the sound of music.", {"entities": []}),
    ("I'm passionate about fostering a sense of belonging.", {"entities": []}),
    ("I find comfort in the serenity of a quiet moment.", {"entities": []}),
    ("I'm fascinated by the mysteries of the human heart.", {"entities": []}),
    ("I find joy in the colors of a sunset.", {"entities": []}),
    ("I'm a believer in the power of positive thinking.", {"entities": []}),
    ("I enjoy the feeling of a cool breeze.", {"entities": []}),
    ("I'm passionate about making a positive difference.", {"entities": []}),
    ("I find inspiration in the resilience of nature.", {"entities": []}),
    ("I'm a dreamer and believe in infinite possibilities.", {"entities": []}),
    ("I'm an explorer and seek new opportunities.", {"entities": []}),
    ("I enjoy the feeling of laughter bubbling up.", {"entities": []}),
    ("I'm a believer in the importance of compassion.", {"entities": []}),
    ("I find happiness in the simple joys of life.", {"entities": []}),
    ("I'm passionate about protecting endangered species.", {"entities": []}),
    ("I find comfort in the sound of birds chirping.", {"entities": []}),
    ("I'm fascinated by the wonders of the cosmos.", {"entities": []}),
    ("I find joy in the beauty of a blooming flower.", {"entities": []}),
    ("I'm a believer in the power of self-discovery.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about creating a more sustainable future.", {"entities": []}),
    ("I find inspiration in the power of human potential.", {"entities": []}),
    ("I'm a dreamer and believe in following my heart.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm hug.", {"entities": []}),
    ("I'm a believer in the importance of diversity.", {"entities": []}),
    ("I find happiness in the beauty of a rainbow.", {"entities": []}),
    ("I'm passionate about promoting social justice.", {"entities": []}),
    ("I find comfort in the warmth of a cozy fire.", {"entities": []}),
    ("I'm fascinated by the intricacies of the human mind.", {"entities": []}),
    ("I find joy in the sound of waves crashing.", {"entities": []}),
    ("I'm a believer in the power of resilience and perseverance.", {"entities": []}),
    ("I enjoy the feeling of a gentle breeze.", {"entities": []}),
    ("I'm passionate about spreading love and kindness.", {"entities": []}),
    ("I find inspiration in the beauty of the natural world.", {"entities": []}),
    ("I'm a dreamer and believe in the beauty of dreams.", {"entities": []}),
    ("I'm an explorer and seek adventure wherever I go.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm a believer in the importance of mindfulness.", {"entities": []}),
    ("I find happiness in the company of good friends.", {"entities": []}),
    ("I'm passionate about making the world a better place.", {"entities": []}),
    ("I find comfort in the sound of rain falling softly.", {"entities": []}),
    ("I'm fascinated by the wonders of the natural world.", {"entities": []}),
    ("I find joy in the laughter of children at play.", {"entities": []}),
    ("I'm a believer in the power of resilience and strength.", {"entities": []}),
    ("I enjoy the feeling of accomplishment after a workout.", {"entities": []}),
    ("I'm passionate about fostering a sense of community.", {"entities": []}),
    ("I find inspiration in the beauty of the night sky.", {"entities": []}),
    ("I'm a dreamer and believe in the power of imagination.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm cup of tea.", {"entities": []}),
    ("I'm a believer in the importance of empathy and understanding.", {"entities": []}),
    ("I find happiness in the sound of music.", {"entities": []}),
    ("I'm passionate about fostering a sense of belonging.", {"entities": []}),
    ("I find comfort in the serenity of a quiet moment.", {"entities": []}),
    ("I'm fascinated by the mysteries of the human heart.", {"entities": []}),
    ("I find joy in the colors of a sunset.", {"entities": []}),
    ("I'm a believer in the power of positive thinking.", {"entities": []}),
    ("I enjoy the feeling of a cool breeze.", {"entities": []}),
    ("I'm passionate about making a positive difference.", {"entities": []}),
    ("I find inspiration in the resilience of nature.", {"entities": []}),
    ("I'm a dreamer and believe in infinite possibilities.", {"entities": []}),
    ("I'm an explorer and seek new opportunities.", {"entities": []}),
    ("I enjoy the feeling of laughter bubbling up.", {"entities": []}),
    ("I'm a believer in the importance of compassion.", {"entities": []}),
    ("I find happiness in the simple joys of life.", {"entities": []}),
    ("I'm passionate about protecting endangered species.", {"entities": []}),
    ("I find comfort in the sound of birds chirping.", {"entities": []}),
    ("I'm fascinated by the wonders of the cosmos.", {"entities": []}),
    ("I find joy in the beauty of a blooming flower.", {"entities": []}),
    ("I'm a believer in the power of self-discovery.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about creating a more sustainable future.", {"entities": []}),
    ("I find inspiration in the power of human potential.", {"entities": []}),
    ("I'm a dreamer and believe in following my heart.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm hug.", {"entities": []}),
    ("I'm a believer in the importance of diversity.", {"entities": []}),
    ("I find happiness in the beauty of a rainbow.", {"entities": []}),
    ("I'm passionate about promoting social justice.", {"entities": []}),
    ("I find comfort in the warmth of a cozy fire.", {"entities": []}),
    ("I'm fascinated by the intricacies of the human mind.", {"entities": []}),
    ("I find joy in the sound of waves crashing.", {"entities": []}),
    ("I'm a believer in the power of resilience and perseverance.", {"entities": []}),
    ("I enjoy the feeling of a gentle breeze.", {"entities": []}),
    ("I'm passionate about spreading love and kindness.", {"entities": []}),
    ("I find inspiration in the beauty of the natural world.", {"entities": []}),
    ("I'm a dreamer and believe in the beauty of dreams.", {"entities": []}),
    ("I'm an explorer and seek adventure wherever I go.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm a believer in the importance of mindfulness.", {"entities": []}),
    ("I find happiness in the company of good friends.", {"entities": []}),
    ("I'm passionate about making the world a better place.", {"entities": []}),
    ("I find comfort in the sound of rain falling softly.", {"entities": []}),
    ("I'm fascinated by the wonders of the natural world.", {"entities": []}),
    ("I find joy in the laughter of children at play.", {"entities": []}),
    ("I'm a believer in the power of resilience and strength.", {"entities": []}),
    ("I enjoy the feeling of accomplishment after a workout.", {"entities": []}),
    ("I'm passionate about fostering a sense of community.", {"entities": []}),
    ("I find inspiration in the beauty of the night sky.", {"entities": []}),
    ("I'm a dreamer and believe in the power of imagination.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm cup of tea.", {"entities": []}),
    ("I'm a believer in the importance of empathy and understanding.", {"entities": []}),
    ("I find happiness in the sound of music.", {"entities": []}),
    ("I'm passionate about fostering a sense of belonging.", {"entities": []}),
    ("I find comfort in the serenity of a quiet moment.", {"entities": []}),
    ("I'm fascinated by the mysteries of the human heart.", {"entities": []}),
    ("I find joy in the colors of a sunset.", {"entities": []}),
    ("I'm a believer in the power of positive thinking.", {"entities": []}),
    ("I enjoy the feeling of a cool breeze.", {"entities": []}),
    ("I'm passionate about making a positive difference.", {"entities": []}),
    ("I find inspiration in the resilience of nature.", {"entities": []}),
    ("I'm a dreamer and believe in infinite possibilities.", {"entities": []}),
    ("I'm an explorer and seek new opportunities.", {"entities": []}),
    ("I enjoy the feeling of laughter bubbling up.", {"entities": []}),
    ("I'm a believer in the importance of compassion.", {"entities": []}),
    ("I find happiness in the simple joys of life.", {"entities": []}),
    ("I'm passionate about protecting endangered species.", {"entities": []}),
    ("I find comfort in the sound of birds chirping.", {"entities": []}),
    ("I'm fascinated by the wonders of the cosmos.", {"entities": []}),
    ("I find joy in the beauty of a blooming flower.", {"entities": []}),
    ("I'm a believer in the power of self-discovery.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about creating a more sustainable future.", {"entities": []}),
    ("I find inspiration in the power of human potential.", {"entities": []}),
    ("I'm a dreamer and believe in following my heart.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm hug.", {"entities": []}),
    ("I'm a believer in the importance of diversity.", {"entities": []}),
    ("I find happiness in the beauty of a rainbow.", {"entities": []}),
    ("I'm passionate about promoting social justice.", {"entities": []}),
    ("I find comfort in the warmth of a cozy fire.", {"entities": []}),
    ("I'm fascinated by the intricacies of the human mind.", {"entities": []}),
    ("I find joy in the sound of waves crashing.", {"entities": []}),
    ("I'm a believer in the power of resilience and perseverance.", {"entities": []}),
    ("I enjoy the feeling of a gentle breeze.", {"entities": []}),
    ("I'm passionate about spreading love and kindness.", {"entities": []}),
    ("I find inspiration in the beauty of the natural world.", {"entities": []}),
    ("I'm a dreamer and believe in the beauty of dreams.", {"entities": []}),
    ("I'm an explorer and seek adventure wherever I go.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm a believer in the importance of mindfulness.", {"entities": []}),
    ("I find happiness in the company of good friends.", {"entities": []}),
    ("I'm passionate about making the world a better place.", {"entities": []}),
    ("I find comfort in the sound of rain falling softly.", {"entities": []}),
    ("I'm fascinated by the wonders of the natural world.", {"entities": []}),
    ("I find joy in the laughter of children at play.", {"entities": []}),
    ("I'm a believer in the power of resilience and strength.", {"entities": []}),
    ("I enjoy the feeling of accomplishment after a workout.", {"entities": []}),
    ("I'm passionate about fostering a sense of community.", {"entities": []}),
    ("I find inspiration in the beauty of the night sky.", {"entities": []}),
    ("I'm a dreamer and believe in the power of imagination.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm cup of tea.", {"entities": []}),
    ("I'm a believer in the importance of empathy and understanding.", {"entities": []}),
    ("I find happiness in the sound of music.", {"entities": []}),
    ("I'm passionate about fostering a sense of belonging.", {"entities": []}),
    ("I find comfort in the serenity of a quiet moment.", {"entities": []}),
    ("I'm fascinated by the mysteries of the human heart.", {"entities": []}),
    ("I find joy in the colors of a sunset.", {"entities": []}),
    ("I'm a believer in the power of positive thinking.", {"entities": []}),
    ("I enjoy the feeling of a cool breeze.", {"entities": []}),
    ("I'm passionate about making a positive difference.", {"entities": []}),
    ("I find inspiration in the resilience of nature.", {"entities": []}),
    ("I'm a dreamer and believe in infinite possibilities.", {"entities": []}),
    ("I'm an explorer and seek new opportunities.", {"entities": []}),
    ("I enjoy the feeling of laughter bubbling up.", {"entities": []}),
    ("I'm a believer in the importance of compassion.", {"entities": []}),
    ("I find happiness in the simple joys of life.", {"entities": []}),
    ("I'm passionate about protecting endangered species.", {"entities": []}),
    ("I find comfort in the sound of birds chirping.", {"entities": []}),
    ("I'm fascinated by the wonders of the cosmos.", {"entities": []}),
    ("I find joy in the beauty of a blooming flower.", {"entities": []}),
    ("I'm a believer in the power of self-discovery.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about creating a more sustainable future.", {"entities": []}),
    ("I find inspiration in the power of human potential.", {"entities": []}),
    ("I'm a dreamer and believe in following my heart.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm hug.", {"entities": []}),
    ("I'm a believer in the importance of diversity.", {"entities": []}),
    ("I find happiness in the beauty of a rainbow.", {"entities": []}),
    ("I'm passionate about promoting social justice.", {"entities": []}),
    ("I find comfort in the warmth of a cozy fire.", {"entities": []}),
    ("I'm fascinated by the intricacies of the human mind.", {"entities": []}),
    ("I find joy in the sound of waves crashing.", {"entities": []}),
    ("I'm a believer in the power of resilience and perseverance.", {"entities": []}),
    ("I enjoy the feeling of a gentle breeze.", {"entities": []}),
    ("I'm passionate about spreading love and kindness.", {"entities": []}),
    ("I find inspiration in the beauty of the natural world.", {"entities": []}),
    ("I'm a dreamer and believe in the beauty of dreams.", {"entities": []}),
    ("I'm an explorer and seek adventure wherever I go.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm a believer in the importance of mindfulness.", {"entities": []}),
    ("I find happiness in the company of good friends.", {"entities": []}),
    ("I'm passionate about making the world a better place.", {"entities": []}),
    ("I find comfort in the sound of rain falling softly.", {"entities": []}),
    ("I'm fascinated by the wonders of the natural world.", {"entities": []}),
    ("I find joy in the laughter of children at play.", {"entities": []}),
    ("I'm a believer in the power of resilience and strength.", {"entities": []}),
    ("I enjoy the feeling of accomplishment after a workout.", {"entities": []}),
    ("I'm passionate about fostering a sense of community.", {"entities": []}),
    ("I find inspiration in the beauty of the night sky.", {"entities": []}),
    ("I'm a dreamer and believe in the power of imagination.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm cup of tea.", {"entities": []}),
    ("I'm a believer in the importance of empathy and understanding.", {"entities": []}),
    ("I find happiness in the sound of music.", {"entities": []}),
    ("I'm passionate about fostering a sense of belonging.", {"entities": []}),
    ("I find comfort in the serenity of a quiet moment.", {"entities": []}),
    ("I'm fascinated by the mysteries of the human heart.", {"entities": []}),
    ("I find joy in the colors of a sunset.", {"entities": []}),
    ("I'm a believer in the power of positive thinking.", {"entities": []}),
    ("I enjoy the feeling of a cool breeze.", {"entities": []}),
    ("I'm passionate about making a positive difference.", {"entities": []}),
    ("I find inspiration in the resilience of nature.", {"entities": []}),
    ("I'm a dreamer and believe in infinite possibilities.", {"entities": []}),
    ("I'm an explorer and seek new opportunities.", {"entities": []}),
    ("I enjoy the feeling of laughter bubbling up.", {"entities": []}),
    ("I'm a believer in the importance of compassion.", {"entities": []}),
    ("I find happiness in the simple joys of life.", {"entities": []}),
    ("I'm passionate about protecting endangered species.", {"entities": []}),
    ("I find comfort in the sound of birds chirping.", {"entities": []}),
    ("I'm fascinated by the wonders of the cosmos.", {"entities": []}),
    ("I find joy in the beauty of a blooming flower.", {"entities": []}),
    ("I'm a believer in the power of self-discovery.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about creating a more sustainable future.", {"entities": []}),
    ("I find inspiration in the power of human potential.", {"entities": []}),
    ("I'm a dreamer and believe in following my heart.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm hug.", {"entities": []}),
    ("I'm a believer in the importance of diversity.", {"entities": []}),
    ("I find happiness in the beauty of a rainbow.", {"entities": []}),
    ("I'm passionate about promoting social justice.", {"entities": []}),
    ("I find comfort in the warmth of a cozy fire.", {"entities": []}),
    ("I'm fascinated by the intricacies of the human mind.", {"entities": []}),
    ("I find joy in the sound of waves crashing.", {"entities": []}),
    ("I'm a believer in the power of resilience and perseverance.", {"entities": []}),
    ("I enjoy the feeling of a gentle breeze.", {"entities": []}),
    ("I'm passionate about spreading love and kindness.", {"entities": []}),
    ("I find inspiration in the beauty of the natural world.", {"entities": []}),
    ("I'm a dreamer and believe in the beauty of dreams.", {"entities": []}),
    ("I'm an explorer and seek adventure wherever I go.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm a believer in the importance of mindfulness.", {"entities": []}),
    ("I find happiness in the company of good friends.", {"entities": []}),
    ("I'm passionate about making the world a better place.", {"entities": []}),
    ("I find comfort in the sound of rain falling softly.", {"entities": []}),
    ("I'm fascinated by the wonders of the natural world.", {"entities": []}),
    ("I find joy in the laughter of children at play.", {"entities": []}),
    ("I'm a believer in the power of resilience and strength.", {"entities": []}),
    ("I enjoy the feeling of accomplishment after a workout.", {"entities": []}),
    ("I'm passionate about fostering a sense of community.", {"entities": []}),
    ("I find inspiration in the beauty of the night sky.", {"entities": []}),
    ("I'm a dreamer and believe in the power of imagination.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm cup of tea.", {"entities": []}),
    ("I'm a believer in the importance of empathy and understanding.", {"entities": []}),
    ("I find happiness in the sound of music.", {"entities": []}),
    ("I'm passionate about fostering a sense of belonging.", {"entities": []}),
    ("I find comfort in the serenity of a quiet moment.", {"entities": []}),
    ("I'm fascinated by the mysteries of the human heart.", {"entities": []}),
    ("I find joy in the colors of a sunset.", {"entities": []}),
    ("I'm a believer in the power of positive thinking.", {"entities": []}),
    ("I enjoy the feeling of a cool breeze.", {"entities": []}),
    ("I'm passionate about making a positive difference.", {"entities": []}),
    ("I find inspiration in the resilience of nature.", {"entities": []}),
    ("I'm a dreamer and believe in infinite possibilities.", {"entities": []}),
    ("I'm an explorer and seek new opportunities.", {"entities": []}),
    ("I enjoy the feeling of laughter bubbling up.", {"entities": []}),
    ("I'm a believer in the importance of compassion.", {"entities": []}),
    ("I find happiness in the simple joys of life.", {"entities": []}),
    ("I'm passionate about protecting endangered species.", {"entities": []}),
    ("I find comfort in the sound of birds chirping.", {"entities": []}),
    ("I'm fascinated by the wonders of the cosmos.", {"entities": []}),
    ("I find joy in the beauty of a blooming flower.", {"entities": []}),
    ("I'm a believer in the power of self-discovery.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about creating a more sustainable future.", {"entities": []}),
    ("I find inspiration in the power of human potential.", {"entities": []}),
    ("I'm a dreamer and believe in following my heart.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm hug.", {"entities": []}),
    ("I'm a believer in the importance of diversity.", {"entities": []}),
    ("I find happiness in the beauty of a rainbow.", {"entities": []}),
    ("I'm passionate about promoting social justice.", {"entities": []}),
    ("I find comfort in the warmth of a cozy fire.", {"entities": []}),
    ("I'm fascinated by the intricacies of the human mind.", {"entities": []}),
    ("I find joy in the sound of waves crashing.", {"entities": []}),
    ("I'm a believer in the power of resilience and perseverance.", {"entities": []}),
    ("I enjoy the feeling of a gentle breeze.", {"entities": []}),
    ("I'm passionate about spreading love and kindness.", {"entities": []}),
    ("I find inspiration in the beauty of the natural world.", {"entities": []}),
    ("I'm a dreamer and believe in the beauty of dreams.", {"entities": []}),
    ("I'm an explorer and seek adventure wherever I go.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm a believer in the importance of mindfulness.", {"entities": []}),
    ("I find happiness in the company of good friends.", {"entities": []}),
    ("I'm passionate about making the world a better place.", {"entities": []}),
    ("I find comfort in the sound of rain falling softly.", {"entities": []}),
    ("I'm fascinated by the wonders of the natural world.", {"entities": []}),
    ("I find joy in the laughter of children at play.", {"entities": []}),
    ("I'm a believer in the power of resilience and strength.", {"entities": []}),
    ("I enjoy the feeling of accomplishment after a workout.", {"entities": []}),
    ("I'm passionate about fostering a sense of community.", {"entities": []}),
    ("I find inspiration in the beauty of the night sky.", {"entities": []}),
    ("I'm a dreamer and believe in the power of imagination.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm cup of tea.", {"entities": []}),
    ("I'm a believer in the importance of empathy and understanding.", {"entities": []}),
    ("I find happiness in the sound of music.", {"entities": []}),
    ("I'm passionate about fostering a sense of belonging.", {"entities": []}),
    ("I find comfort in the serenity of a quiet moment.", {"entities": []}),
    ("I'm fascinated by the mysteries of the human heart.", {"entities": []}),
    ("I find joy in the colors of a sunset.", {"entities": []}),
    ("I'm a believer in the power of positive thinking.", {"entities": []}),
    ("I enjoy the feeling of a cool breeze.", {"entities": []}),
    ("I'm passionate about making a positive difference.", {"entities": []}),
    ("I find inspiration in the resilience of nature.", {"entities": []}),
    ("I'm a dreamer and believe in infinite possibilities.", {"entities": []}),
    ("I'm an explorer and seek new opportunities.", {"entities": []}),
    ("I enjoy the feeling of laughter bubbling up.", {"entities": []}),
    ("I'm a believer in the importance of compassion.", {"entities": []}),
    ("I find happiness in the simple joys of life.", {"entities": []}),
    ("I'm passionate about protecting endangered species.", {"entities": []}),
    ("I find comfort in the sound of birds chirping.", {"entities": []}),
    ("I'm fascinated by the wonders of the cosmos.", {"entities": []}),
    ("I find joy in the beauty of a blooming flower.", {"entities": []}),
    ("I'm a believer in the power of self-discovery.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about creating a more sustainable future.", {"entities": []}),
    ("I find inspiration in the power of human potential.", {"entities": []}),
    ("I'm a dreamer and believe in following my heart.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm hug.", {"entities": []}),
    ("I'm a believer in the importance of diversity.", {"entities": []}),
    ("I find happiness in the beauty of a rainbow.", {"entities": []}),
    ("I'm passionate about promoting social justice.", {"entities": []}),
    ("I find comfort in the warmth of a cozy fire.", {"entities": []}),
    ("I'm fascinated by the intricacies of the human mind.", {"entities": []}),
    ("I find joy in the sound of waves crashing.", {"entities": []}),
    ("I'm a believer in the power of resilience and perseverance.", {"entities": []}),
    ("I enjoy the feeling of a gentle breeze.", {"entities": []}),
    ("I'm passionate about spreading love and kindness.", {"entities": []}),
    ("I find inspiration in the beauty of the natural world.", {"entities": []}),
    ("I'm a dreamer and believe in the beauty of dreams.", {"entities": []}),
    ("I'm an explorer and seek adventure wherever I go.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm a believer in the importance of mindfulness.", {"entities": []}),
    ("I find happiness in the company of good friends.", {"entities": []}),
    ("I'm passionate about making the world a better place.", {"entities": []}),
    ("I find comfort in the sound of rain falling softly.", {"entities": []}),
    ("I'm fascinated by the wonders of the natural world.", {"entities": []}),
    ("I find joy in the laughter of children at play.", {"entities": []}),
    ("I'm a believer in the power of resilience and strength.", {"entities": []}),
    ("I enjoy the feeling of accomplishment after a workout.", {"entities": []}),
    ("I'm passionate about fostering a sense of community.", {"entities": []}),
    ("I find inspiration in the beauty of the night sky.", {"entities": []}),
    ("I'm a dreamer and believe in the power of imagination.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm cup of tea.", {"entities": []}),
    ("I'm a believer in the importance of empathy and understanding.", {"entities": []}),
    ("I find happiness in the sound of music.", {"entities": []}),
    ("I'm passionate about fostering a sense of belonging.", {"entities": []}),
    ("I find comfort in the serenity of a quiet moment.", {"entities": []}),
    ("I'm fascinated by the mysteries of the human heart.", {"entities": []}),
    ("I find joy in the colors of a sunset.", {"entities": []}),
    ("I'm a believer in the power of positive thinking.", {"entities": []}),
    ("I enjoy the feeling of a cool breeze.", {"entities": []}),
    ("I'm passionate about making a positive difference.", {"entities": []}),
    ("I find inspiration in the resilience of nature.", {"entities": []}),
    ("I'm a dreamer and believe in infinite possibilities.", {"entities": []}),
    ("I'm an explorer and seek new opportunities.", {"entities": []}),
    ("I enjoy the feeling of laughter bubbling up.", {"entities": []}),
    ("I'm a believer in the importance of compassion.", {"entities": []}),
    ("I find happiness in the simple joys of life.", {"entities": []}),
    ("I'm passionate about protecting endangered species.", {"entities": []}),
    ("I find comfort in the sound of birds chirping.", {"entities": []}),
    ("I'm fascinated by the wonders of the cosmos.", {"entities": []}),
    ("I find joy in the beauty of a blooming flower.", {"entities": []}),
    ("I'm a believer in the power of self-discovery.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about creating a more sustainable future.", {"entities": []}),
    ("I find inspiration in the power of human potential.", {"entities": []}),
    ("I'm a dreamer and believe in following my heart.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm hug.", {"entities": []}),
    ("I'm a believer in the importance of diversity.", {"entities": []}),
    ("I find happiness in the beauty of a rainbow.", {"entities": []}),
    ("I'm passionate about promoting social justice.", {"entities": []}),
    ("I find comfort in the warmth of a cozy fire.", {"entities": []}),
    ("I'm fascinated by the intricacies of the human mind.", {"entities": []}),
    ("I find joy in the sound of waves crashing.", {"entities": []}),
    ("I'm a believer in the power of resilience and perseverance.", {"entities": []}),
    ("I enjoy the feeling of a gentle breeze.", {"entities": []}),
    ("I'm passionate about spreading love and kindness.", {"entities": []}),
    ("I find inspiration in the beauty of the natural world.", {"entities": []}),
    ("I'm a dreamer and believe in the beauty of dreams.", {"entities": []}),
    ("I'm an explorer and seek adventure wherever I go.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm a believer in the importance of mindfulness.", {"entities": []}),
    ("I find happiness in the company of good friends.", {"entities": []}),
    ("I'm passionate about making the world a better place.", {"entities": []}),
    ("I find comfort in the sound of rain falling softly.", {"entities": []}),
    ("I'm fascinated by the wonders of the natural world.", {"entities": []}),
    ("I find joy in the laughter of children at play.", {"entities": []}),
    ("I'm a believer in the power of resilience and strength.", {"entities": []}),
    ("I enjoy the feeling of accomplishment after a workout.", {"entities": []}),
    ("I'm passionate about fostering a sense of community.", {"entities": []}),
    ("I find inspiration in the beauty of the night sky.", {"entities": []}),
    ("I'm a dreamer and believe in the power of imagination.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm cup of tea.", {"entities": []}),
    ("I'm a believer in the importance of empathy and understanding.", {"entities": []}),
    ("I find happiness in the sound of music.", {"entities": []}),
    ("I'm passionate about fostering a sense of belonging.", {"entities": []}),
    ("I find comfort in the serenity of a quiet moment.", {"entities": []}),
    ("I'm fascinated by the mysteries of the human heart.", {"entities": []}),
    ("I find joy in the colors of a sunset.", {"entities": []}),
    ("I'm a believer in the power of positive thinking.", {"entities": []}),
    ("I enjoy the feeling of a cool breeze.", {"entities": []}),
    ("I'm passionate about making a positive difference.", {"entities": []}),
    ("I find inspiration in the resilience of nature.", {"entities": []}),
    ("I'm a dreamer and believe in infinite possibilities.", {"entities": []}),
    ("I'm an explorer and seek new opportunities.", {"entities": []}),
    ("I enjoy the feeling of laughter bubbling up.", {"entities": []}),
    ("I'm a believer in the importance of compassion.", {"entities": []}),
    ("I find happiness in the simple joys of life.", {"entities": []}),
    ("I'm passionate about protecting endangered species.", {"entities": []}),
    ("I find comfort in the sound of birds chirping.", {"entities": []}),
    ("I'm fascinated by the wonders of the cosmos.", {"entities": []}),
    ("I find joy in the beauty of a blooming flower.", {"entities": []}),
    ("I'm a believer in the power of self-discovery.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about creating a more sustainable future.", {"entities": []}),
    ("I find inspiration in the power of human potential.", {"entities": []}),
    ("I'm a dreamer and believe in following my heart.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm hug.", {"entities": []}),
    ("I'm a believer in the importance of diversity.", {"entities": []}),
    ("I find happiness in the beauty of a rainbow.", {"entities": []}),
    ("I'm passionate about promoting social justice.", {"entities": []}),
    ("I find comfort in the warmth of a cozy fire.", {"entities": []}),
    ("I'm fascinated by the intricacies of the human mind.", {"entities": []}),
    ("I find joy in the sound of waves crashing.", {"entities": []}),
    ("I'm a believer in the power of resilience and perseverance.", {"entities": []}),
    ("I enjoy the feeling of a gentle breeze.", {"entities": []}),
    ("I'm passionate about spreading love and kindness.", {"entities": []}),
    ("I find inspiration in the beauty of the natural world.", {"entities": []}),
    ("I'm a dreamer and believe in the beauty of dreams.", {"entities": []}),
    ("I'm an explorer and seek adventure wherever I go.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm a believer in the importance of mindfulness.", {"entities": []}),
    ("I find happiness in the company of good friends.", {"entities": []}),
    ("I'm passionate about making the world a better place.", {"entities": []}),
    ("I find comfort in the sound of rain falling softly.", {"entities": []}),
    ("I'm fascinated by the wonders of the natural world.", {"entities": []}),
    ("I find joy in the laughter of children at play.", {"entities": []}),
    ("I'm a believer in the power of resilience and strength.", {"entities": []}),
    ("I enjoy the feeling of accomplishment after a workout.", {"entities": []}),
    ("I'm passionate about fostering a sense of community.", {"entities": []}),
    ("I find inspiration in the beauty of the night sky.", {"entities": []}),
    ("I'm a dreamer and believe in the power of imagination.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm cup of tea.", {"entities": []}),
    ("I'm a believer in the importance of empathy and understanding.", {"entities": []}),
    ("I find happiness in the sound of music.", {"entities": []}),
    ("I'm passionate about fostering a sense of belonging.", {"entities": []}),
    ("I find comfort in the serenity of a quiet moment.", {"entities": []}),
    ("I'm fascinated by the mysteries of the human heart.", {"entities": []}),
    ("I find joy in the colors of a sunset.", {"entities": []}),
    ("I'm a believer in the power of positive thinking.", {"entities": []}),
    ("I enjoy the feeling of a cool breeze.", {"entities": []}),
    ("I'm passionate about making a positive difference.", {"entities": []}),
    ("I find inspiration in the resilience of nature.", {"entities": []}),
    ("I'm a dreamer and believe in infinite possibilities.", {"entities": []}),
    ("I'm an explorer and seek new opportunities.", {"entities": []}),
    ("I enjoy the feeling of laughter bubbling up.", {"entities": []}),
    ("I'm a believer in the importance of compassion.", {"entities": []}),
    ("I find happiness in the simple joys of life.", {"entities": []}),
    ("I'm passionate about protecting endangered species.", {"entities": []}),
    ("I find comfort in the sound of birds chirping.", {"entities": []}),
    ("I'm fascinated by the wonders of the cosmos.", {"entities": []}),
    ("I find joy in the beauty of a blooming flower.", {"entities": []}),
    ("I'm a believer in the power of self-discovery.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about creating a more sustainable future.", {"entities": []}),
    ("I find inspiration in the power of human potential.", {"entities": []}),
    ("I'm a dreamer and believe in following my heart.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm hug.", {"entities": []}),
    ("I'm a believer in the importance of diversity.", {"entities": []}),
    ("I find happiness in the beauty of a rainbow.", {"entities": []}),
    ("I'm passionate about promoting social justice.", {"entities": []}),
    ("I find comfort in the warmth of a cozy fire.", {"entities": []}),
    ("I'm fascinated by the intricacies of the human mind.", {"entities": []}),
    ("I find joy in the sound of waves crashing.", {"entities": []}),
    ("I'm a believer in the power of resilience and perseverance.", {"entities": []}),
    ("I enjoy the feeling of a gentle breeze.", {"entities": []}),
    ("I'm passionate about spreading love and kindness.", {"entities": []}),
    ("I find inspiration in the beauty of the natural world.", {"entities": []}),
    ("I'm a dreamer and believe in the beauty of dreams.", {"entities": []}),
    ("I'm an explorer and seek adventure wherever I go.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm a believer in the importance of mindfulness.", {"entities": []}),
    ("I find happiness in the company of good friends.", {"entities": []}),
    ("I'm passionate about making the world a better place.", {"entities": []}),
    ("I find comfort in the sound of rain falling softly.", {"entities": []}),
    ("I'm fascinated by the wonders of the natural world.", {"entities": []}),
    ("I find joy in the laughter of children at play.", {"entities": []}),
    ("I'm a believer in the power of resilience and strength.", {"entities": []}),
    ("I enjoy the feeling of accomplishment after a workout.", {"entities": []}),
    ("I'm passionate about fostering a sense of community.", {"entities": []}),
    ("I find inspiration in the beauty of the night sky.", {"entities": []}),
    ("I'm a dreamer and believe in the power of imagination.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm cup of tea.", {"entities": []}),
    ("I'm a believer in the importance of empathy and understanding.", {"entities": []}),
    ("I find happiness in the sound of music.", {"entities": []}),
    ("I'm passionate about fostering a sense of belonging.", {"entities": []}),
    ("I find comfort in the serenity of a quiet moment.", {"entities": []}),
    ("I'm fascinated by the mysteries of the human heart.", {"entities": []}),
    ("I find joy in the colors of a sunset.", {"entities": []}),
    ("I'm a believer in the power of positive thinking.", {"entities": []}),
    ("I enjoy the feeling of a cool breeze.", {"entities": []}),
    ("I'm passionate about making a positive difference.", {"entities": []}),
    ("I find inspiration in the resilience of nature.", {"entities": []}),
    ("I'm a dreamer and believe in infinite possibilities.", {"entities": []}),
    ("I'm an explorer and seek new opportunities.", {"entities": []}),
    ("I enjoy the feeling of laughter bubbling up.", {"entities": []}),
    ("I'm a believer in the importance of compassion.", {"entities": []}),
    ("I find happiness in the simple joys of life.", {"entities": []}),
    ("I'm passionate about protecting endangered species.", {"entities": []}),
    ("I find comfort in the sound of birds chirping.", {"entities": []}),
    ("I'm fascinated by the wonders of the cosmos.", {"entities": []}),
    ("I find joy in the beauty of a blooming flower.", {"entities": []}),
    ("I'm a believer in the power of self-discovery.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about creating a more sustainable future.", {"entities": []}),
    ("I find inspiration in the power of human potential.", {"entities": []}),
    ("I'm a dreamer and believe in following my heart.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm hug.", {"entities": []}),
    ("I'm a believer in the importance of diversity.", {"entities": []}),
    ("I find happiness in the beauty of a rainbow.", {"entities": []}),
    ("I'm passionate about promoting social justice.", {"entities": []}),
    ("I find comfort in the warmth of a cozy fire.", {"entities": []}),
    ("I'm allergic to cats, dogs, and cheese.",
     {"entities": [(5, 11, "ALLERGY"), (13, 17, "ALLERGY"), (22, 28, "ALLERGY")]}),
    ("I have allergies to pollen, peanuts, and seafood.",
     {"entities": [(10, 17, "ALLERGY"), (19, 26, "ALLERGY"), (31, 38, "ALLERGY")]}),
    ("My allergies include dust mites, soy, and strawberries.",
     {"entities": [(16, 25, "ALLERGY"), (27, 30, "ALLERGY"), (35, 47, "ALLERGY")]}),
    ("I discovered I'm allergic to latex, shellfish, and dairy.",
     {"entities": [(15, 21, "ALLERGY"), (23, 32, "ALLERGY"), (37, 42, "ALLERGY")]}),
    ("I'm allergic to tree nuts, eggs, and certain medications.",
     {"entities": [(5, 14, "ALLERGY"), (16, 20, "ALLERGY"), (25, 46, "ALLERGY")]}),
    ("I have allergies to wheat, mold spores, and bee stings.",
     {"entities": [(10, 15, "ALLERGY"), (17, 27, "ALLERGY"), (32, 41, "ALLERGY")]}),
    ("My allergies include fish, shellfish, and grass pollen.",
     {"entities": [(16, 20, "ALLERGY"), (22, 31, "ALLERGY"), (36, 47, "ALLERGY")]}),
    ("I'm allergic to strawberries, tomatoes, and latex.",
     {"entities": [(5, 16, "ALLERGY"), (18, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("I have allergies to dairy, soy, and dust mites.",
     {"entities": [(10, 15, "ALLERGY"), (17, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("My allergies include peanuts, gluten, and certain perfumes.",
     {"entities": [(16, 23, "ALLERGY"), (25, 31, "ALLERGY"), (36, 52, "ALLERGY")]}),
    ("I'm allergic to strawberries, pollen, and shellfish.", {"entities": [(5, 16, "ALLERGY"), (18, 24, "ALLERGY"), (29, 38, "ALLERGY")]}),
    ("I have allergies to peanuts, dairy, and certain medications.", {"entities": [(10, 17, "ALLERGY"), (19, 24, "ALLERGY"), (29, 50, "ALLERGY")]}),
    ("My allergies include tree nuts, wheat, and pet dander.", {"entities": [(16, 25, "ALLERGY"), (27, 32, "ALLERGY"), (37, 47, "ALLERGY")]}),
    ("I'm allergic to latex, soy, and mold spores.", {"entities": [(5, 10, "ALLERGY"), (12, 15, "ALLERGY"), (20, 30, "ALLERGY")]}),
    ("I have allergies to shellfish, grass pollen, and dust mites.", {"entities": [(10, 19, "ALLERGY"), (21, 32, "ALLERGY"), (37, 46, "ALLERGY")]}),
    ("My allergies include eggs, peanuts, and seafood.", {"entities": [(16, 20, "ALLERGY"), (22, 29, "ALLERGY"), (34, 41, "ALLERGY")]}),
    ("I'm allergic to dairy, gluten, and bee stings.", {"entities": [(5, 10, "ALLERGY"), (12, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("I have allergies to certain fruits, latex, and tree pollen.", {"entities": [(10, 25, "ALLERGY"), (27, 32, "ALLERGY"), (37, 47, "ALLERGY")]}),
    ("My allergies include shellfish, cat hair, and grass.", {"entities": [(16, 25, "ALLERGY"), (27, 35, "ALLERGY"), (40, 45, "ALLERGY")]}),
    ("I'm allergic to peanuts, soy, and ragweed.", {"entities": [(5, 12, "ALLERGY"), (14, 17, "ALLERGY"), (22, 29, "ALLERGY")]}),
    ("I have allergies to dust mites, certain fruits, and latex.", {"entities": [(10, 19, "ALLERGY"), (21, 36, "ALLERGY"), (41, 46, "ALLERGY")]}),
    ("My allergies include dairy, pollen, and shellfish.", {"entities": [(16, 21, "ALLERGY"), (23, 29, "ALLERGY"), (34, 43, "ALLERGY")]}),
    ("I'm allergic to tree nuts, dairy, and certain medications.", {"entities": [(5, 14, "ALLERGY"), (16, 21, "ALLERGY"), (26, 47, "ALLERGY")]}),
    ("I have allergies to pollen, wheat, and seafood.", {"entities": [(10, 16, "ALLERGY"), (18, 23, "ALLERGY"), (28, 35, "ALLERGY")]}),
    ("My allergies include peanuts, eggs, and latex.", {"entities": [(16, 23, "ALLERGY"), (25, 29, "ALLERGY"), (34, 39, "ALLERGY")]}),
    ("I'm allergic to soy, shellfish, and grass pollen.", {"entities": [(5, 8, "ALLERGY"), (10, 19, "ALLERGY"), (24, 34, "ALLERGY")]}),
    ("I have allergies to dairy, gluten, and certain fruits.", {"entities": [(10, 15, "ALLERGY"), (17, 23, "ALLERGY"), (28, 43, "ALLERGY")]}),
    ("My allergies include peanuts, pollen, and latex.", {"entities": [(16, 23, "ALLERGY"), (25, 31, "ALLERGY"), (36, 41, "ALLERGY")]}),
    ("I'm allergic to shellfish, dairy, and dust mites.", {"entities": [(5, 14, "ALLERGY"), (16, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I have allergies to peanuts, wheat, and pet dander.", {"entities": [(10, 17, "ALLERGY"), (19, 24, "ALLERGY"), (29, 39, "ALLERGY")]}),
    ("My allergies include soy, tree nuts, and certain medications.", {"entities": [(16, 19, "ALLERGY"), (21, 30, "ALLERGY"), (35, 56, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and grass pollen.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 37, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and latex.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 34, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain fruits.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 46, "ALLERGY")]}),
    ("I'm allergic to tree nuts, shellfish, and dust mites.", {"entities": [(5, 14, "ALLERGY"), (16, 25, "ALLERGY"), (30, 39, "ALLERGY")]}),
    ("I have allergies to peanuts, dairy, and wheat.", {"entities": [(10, 17, "ALLERGY"), (19, 24, "ALLERGY"), (29, 34, "ALLERGY")]}),
    ("My allergies include pollen, soy, and latex.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and certain fruits.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 42, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and tree nuts.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 38, "ALLERGY")]}),
    ("My allergies include pollen, soy, and wheat.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("I'm allergic to latex, shellfish, and certain medications.", {"entities": [(5, 10, "ALLERGY"), (12, 21, "ALLERGY"), (26, 47, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and eggs.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain fruits.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 46, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and certain medications.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 48, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and latex.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 34, "ALLERGY")]}),
    ("My allergies include pollen, soy, and wheat.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("I'm allergic to latex, shellfish, and certain fruits.", {"entities": [(5, 10, "ALLERGY"), (12, 21, "ALLERGY"), (26, 41, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and tree nuts.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 38, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain medications.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 52, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and eggs.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 31, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and wheat.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 34, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain fruits.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 46, "ALLERGY")]}),
    ("I'm allergic to latex, shellfish, and tree nuts.", {"entities": [(5, 10, "ALLERGY"), (12, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and certain medications.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 50, "ALLERGY")]}),
    ("My allergies include pollen, soy, and wheat.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and eggs.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 31, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and tree nuts.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 38, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain medications.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 52, "ALLERGY")]}),
    ("I'm allergic to latex, shellfish, and wheat.", {"entities": [(5, 10, "ALLERGY"), (12, 21, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and certain fruits.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 44, "ALLERGY")]}),
    ("My allergies include pollen, soy, and tree nuts.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 40, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and certain medications.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 48, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and eggs.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("My allergies include pollen, soy, and wheat.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("I'm allergic to latex, shellfish, and certain fruits.", {"entities": [(5, 10, "ALLERGY"), (12, 21, "ALLERGY"), (26, 41, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and tree nuts.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 38, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain medications.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 52, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and eggs.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 31, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and wheat.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 34, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain fruits.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 46, "ALLERGY")]}),
    ("I'm allergic to latex, shellfish, and tree nuts.", {"entities": [(5, 10, "ALLERGY"), (12, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and certain medications.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 50, "ALLERGY")]}),
    ("My allergies include pollen, soy, and wheat.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and eggs.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 31, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and tree nuts.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 38, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain medications.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 52, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and wheat.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 32, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and eggs.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain fruits.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 46, "ALLERGY")]}),
    ("I'm allergic to latex, shellfish, and tree nuts.", {"entities": [(5, 10, "ALLERGY"), (12, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and certain medications.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 50, "ALLERGY")]}),
    ("My allergies include pollen, soy, and wheat.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and eggs.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 31, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and tree nuts.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 38, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain medications.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 52, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and wheat.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 32, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and eggs.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain fruits.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 46, "ALLERGY")]}),
    ("I'm allergic to latex, shellfish, and tree nuts.", {"entities": [(5, 10, "ALLERGY"), (12, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and certain medications.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 50, "ALLERGY")]}),
    ("My allergies include pollen, soy, and wheat.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and eggs.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 31, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and tree nuts.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 38, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain medications.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 52, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and wheat.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 32, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and eggs.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain fruits.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 46, "ALLERGY")]}),
    ("I'm allergic to latex, shellfish, and tree nuts.", {"entities": [(5, 10, "ALLERGY"), (12, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and certain medications.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 50, "ALLERGY")]}),
    ("My allergies include pollen, soy, and wheat.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and eggs.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 31, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and tree nuts.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 38, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain medications.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 52, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and wheat.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 32, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and eggs.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain fruits.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 46, "ALLERGY")]}),
    ("I'm allergic to latex, shellfish, and tree nuts.", {"entities": [(5, 10, "ALLERGY"), (12, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and certain medications.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 50, "ALLERGY")]}),
    ("My allergies include pollen, soy, and wheat.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and eggs.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 31, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and tree nuts.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 38, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain medications.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 52, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and wheat.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 32, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and eggs.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain fruits.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 46, "ALLERGY")]}),
    ("I'm allergic to latex, shellfish, and tree nuts.", {"entities": [(5, 10, "ALLERGY"), (12, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and certain medications.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 50, "ALLERGY")]}),
    ("My allergies include pollen, soy, and wheat.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and eggs.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 31, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and tree nuts.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 38, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain medications.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 52, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and wheat.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 32, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and eggs.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain fruits.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 46, "ALLERGY")]}),
    ("I'm allergic to latex, shellfish, and tree nuts.", {"entities": [(5, 10, "ALLERGY"), (12, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and certain medications.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 50, "ALLERGY")]}),
    ("My allergies include pollen, soy, and wheat.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and eggs.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 31, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and tree nuts.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 38, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain medications.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 52, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and wheat.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 32, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and eggs.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain fruits.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 46, "ALLERGY")]}),
    ("I'm allergic to latex, shellfish, and tree nuts.", {"entities": [(5, 10, "ALLERGY"), (12, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and certain medications.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 50, "ALLERGY")]}),
    ("My allergies include pollen, soy, and wheat.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and eggs.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 31, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and tree nuts.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 38, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain medications.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 52, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and wheat.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 32, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and eggs.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain fruits.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 46, "ALLERGY")]}),
    ("I'm allergic to latex, shellfish, and tree nuts.", {"entities": [(5, 10, "ALLERGY"), (12, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and certain medications.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 50, "ALLERGY")]}),
    ("My allergies include pollen, soy, and wheat.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and eggs.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 31, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and tree nuts.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 38, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain medications.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 52, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and wheat.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 32, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and eggs.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain fruits.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 46, "ALLERGY")]}),
    ("I'm allergic to latex, shellfish, and tree nuts.", {"entities": [(5, 10, "ALLERGY"), (12, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and certain medications.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 50, "ALLERGY")]}),
    ("My allergies include pollen, soy, and wheat.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and eggs.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 31, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and tree nuts.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 38, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain medications.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 52, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and wheat.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 32, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and eggs.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain fruits.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 46, "ALLERGY")]}),
    ("I'm allergic to latex, shellfish, and tree nuts.", {"entities": [(5, 10, "ALLERGY"), (12, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and certain medications.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 50, "ALLERGY")]}),
    ("My allergies include pollen, soy, and wheat.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and eggs.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 31, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and tree nuts.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 38, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain medications.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 52, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and wheat.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 32, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and eggs.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain fruits.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 46, "ALLERGY")]}),
    ("I'm allergic to latex, shellfish, and tree nuts.", {"entities": [(5, 10, "ALLERGY"), (12, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and certain medications.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 50, "ALLERGY")]}),
    ("My allergies include pollen, soy, and wheat.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and eggs.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 31, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and tree nuts.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 38, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain medications.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 52, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and wheat.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 32, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and eggs.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain fruits.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 46, "ALLERGY")]}),
    ("I'm allergic to latex, shellfish, and tree nuts.", {"entities": [(5, 10, "ALLERGY"), (12, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and certain medications.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 50, "ALLERGY")]}),
    ("My allergies include pollen, soy, and wheat.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and eggs.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 31, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and tree nuts.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 38, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain medications.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 52, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and wheat.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 32, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and eggs.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain fruits.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 46, "ALLERGY")]}),
    ("I'm allergic to latex, shellfish, and tree nuts.", {"entities": [(5, 10, "ALLERGY"), (12, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and certain medications.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 50, "ALLERGY")]}),
    ("My allergies include pollen, soy, and wheat.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and eggs.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 31, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and tree nuts.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 38, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain medications.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 52, "ALLERGY")]}),
    ("I'm allergic to strawberries, shellfish, and penicillin.", {"entities": [(13, 24, "ALLERGY"), (26, 34, "ALLERGY"), (39, 49, "ALLERGY")]}),
    ("My allergies include grass pollen, soy, and dust mites.", {"entities": [(16, 27, "ALLERGY"), (29, 32, "ALLERGY"), (37, 47, "ALLERGY")]}),
    ("I have allergies to milk, peanuts, and sesame seeds.", {"entities": [(18, 22, "ALLERGY"), (24, 31, "ALLERGY"), (36, 48, "ALLERGY")]}),
    ("My allergies include cat dander, eggs, and certain antibiotics.", {"entities": [(16, 26, "ALLERGY"), (28, 32, "ALLERGY"), (37, 59, "ALLERGY")]}),
    ("I'm allergic to ragweed, tree nuts, and latex.", {"entities": [(13, 20, "ALLERGY"), (22, 30, "ALLERGY"), (35, 40, "ALLERGY")]}),
    ("I have allergies to tomatoes, shrimp, and bee stings.", {"entities": [(18, 26, "ALLERGY"), (28, 34, "ALLERGY"), (39, 49, "ALLERGY")]}),
    ("My allergies include mold spores, wheat, and certain painkillers.", {"entities": [(16, 26, "ALLERGY"), (28, 33, "ALLERGY"), (38, 59, "ALLERGY")]}),
    ("I'm allergic to cherries, crab, and sulfa drugs.", {"entities": [(13, 21, "ALLERGY"), (23, 27, "ALLERGY"), (32, 42, "ALLERGY")]}),
    ("My allergies include pine pollen, soybeans, and aspirin.", {"entities": [(16, 27, "ALLERGY"), (29, 37, "ALLERGY"), (42, 49, "ALLERGY")]}),
    ("I have allergies to kiwi, lobster, and iodine.", {"entities": [(18, 22, "ALLERGY"), (24, 31, "ALLERGY"), (36, 42, "ALLERGY")]}),
    ("My allergies include pet hair, almonds, and antihistamines.", {"entities": [(16, 25, "ALLERGY"), (27, 34, "ALLERGY"), (39, 53, "ALLERGY")]}),
    ("I'm allergic to oranges, scallops, and morphine.", {"entities": [(13, 20, "ALLERGY"), (22, 29, "ALLERGY"), (34, 42, "ALLERGY")]}),
    ("My allergies include sunflower pollen, lentils, and codeine.", {"entities": [(16, 30, "ALLERGY"), (32, 39, "ALLERGY"), (44, 51, "ALLERGY")]}),
    ("I have allergies to bell peppers, clams, and corticosteroids.", {"entities": [(18, 29, "ALLERGY"), (31, 36, "ALLERGY"), (41, 56, "ALLERGY")]}),
    ("My allergies include juniper pollen, chickpeas, and morphine.", {"entities": [(16, 30, "ALLERGY"), (32, 41, "ALLERGY"), (46, 54, "ALLERGY")]}),
    ("I'm allergic to peaches, oysters, and ibuprofen.", {"entities": [(13, 20, "ALLERGY"), (22, 29, "ALLERGY"), (34, 43, "ALLERGY")]}),
    ("My allergies include birch pollen, lentils, and benzodiazepines.", {"entities": [(16, 27, "ALLERGY"), (29, 36, "ALLERGY"), (41, 57, "ALLERGY")]}),
    ("I have allergies to avocados, mussels, and sulfa drugs.", {"entities": [(18, 26, "ALLERGY"), (28, 35, "ALLERGY"), (40, 50, "ALLERGY")]}),
    ("My allergies include grass pollen, peas, and antihistamines.", {"entities": [(16, 27, "ALLERGY"), (29, 33, "ALLERGY"), (38, 52, "ALLERGY")]}),
    ("I'm allergic to pineapple, lobster, and codeine.", {"entities": [(13, 22, "ALLERGY"), (24, 31, "ALLERGY"), (36, 43, "ALLERGY")]}),
    ("My allergies include tree pollen, lentils, and aspirin.", {"entities": [(16, 26, "ALLERGY"), (28, 35, "ALLERGY"), (40, 47, "ALLERGY")]}),
    ("I have allergies to bananas, clams, and corticosteroids.", {"entities": [(18, 25, "ALLERGY"), (27, 32, "ALLERGY"), (37, 52, "ALLERGY")]}),
    ("My allergies include ragweed pollen, chickpeas, and ibuprofen.", {"entities": [(16, 29, "ALLERGY"), (31, 40, "ALLERGY"), (45, 54, "ALLERGY")]}),
    ("I'm allergic to melons, oysters, and morphine.", {"entities": [(13, 19, "ALLERGY"), (21, 28, "ALLERGY"), (33, 41, "ALLERGY")]}),
    ("My allergies include olive pollen, mung beans, and benzodiazepines.", {"entities": [(16, 27, "ALLERGY"), (29, 39, "ALLERGY"), (44, 60, "ALLERGY")]}),
    ("I have allergies to grapefruit, shrimp, and sulfa drugs.", {"entities": [(18, 27, "ALLERGY"), (29, 35, "ALLERGY"), (40, 50, "ALLERGY")]}),
    ("My allergies include weed pollen, kidney beans, and antihistamines.", {"entities": [(16, 27, "ALLERGY"), (29, 41, "ALLERGY"), (46, 60, "ALLERGY")]}),
    ("I'm allergic to mangoes, scallops, and codeine.", {"entities": [(13, 20, "ALLERGY"), (22, 29, "ALLERGY"), (34, 41, "ALLERGY")]}),
    ("My allergies include cedar pollen, lentils, and aspirin.", {"entities": [(16, 28, "ALLERGY"), (30, 37, "ALLERGY"), (42, 49, "ALLERGY")]}),
    ("I have allergies to papayas, clams, and corticosteroids.", {"entities": [(18, 25, "ALLERGY"), (27, 32, "ALLERGY"), (37, 52, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain fruits.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 46, "ALLERGY")]}),
    ("I'm allergic to latex, shellfish, and tree nuts.", {"entities": [(5, 10, "ALLERGY"), (12, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and certain medications.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 50, "ALLERGY")]}),
    ("My allergies include pollen, soy, and wheat.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and eggs.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 31, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and tree nuts.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 38, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain medications.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 52, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and wheat.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 32, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and eggs.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain fruits.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 46, "ALLERGY")]}),
    ("I'm allergic to latex, shellfish, and tree nuts.", {"entities": [(5, 10, "ALLERGY"), (12, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and certain medications.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 50, "ALLERGY")]}),
    ("My allergies include pollen, soy, and wheat.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and eggs.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 31, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and tree nuts.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 38, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain medications.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 52, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and wheat.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 32, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and eggs.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain fruits.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 46, "ALLERGY")]}),
    ("I'm allergic to latex, shellfish, and tree nuts.", {"entities": [(5, 10, "ALLERGY"), (12, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and certain medications.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 50, "ALLERGY")]}),
    ("My allergies include pollen, soy, and wheat.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and eggs.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 31, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and tree nuts.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 38, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain medications.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 52, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and wheat.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 32, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and eggs.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain fruits.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 46, "ALLERGY")]}),
    ("I'm allergic to latex, shellfish, and tree nuts.", {"entities": [(5, 10, "ALLERGY"), (12, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and certain medications.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 50, "ALLERGY")]}),
    ("My allergies include pollen, soy, and wheat.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and eggs.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 31, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and tree nuts.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 38, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain medications.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 52, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and wheat.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 32, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and eggs.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain fruits.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 46, "ALLERGY")]}),
    ("I'm allergic to latex, shellfish, and tree nuts.", {"entities": [(5, 10, "ALLERGY"), (12, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and certain medications.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 50, "ALLERGY")]}),
    ("My allergies include pollen, soy, and wheat.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and eggs.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 31, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and tree nuts.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 38, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain medications.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 52, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and wheat.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 32, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and eggs.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain fruits.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 46, "ALLERGY")]}),
    ("I'm allergic to latex, shellfish, and tree nuts.", {"entities": [(5, 10, "ALLERGY"), (12, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and certain medications.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 50, "ALLERGY")]}),
    ("My allergies include pollen, soy, and wheat.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and eggs.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 31, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and tree nuts.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 38, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain medications.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 52, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and wheat.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 32, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and eggs.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain fruits.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 46, "ALLERGY")]}),
    ("I'm allergic to latex, shellfish, and tree nuts.", {"entities": [(5, 10, "ALLERGY"), (12, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and certain medications.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 50, "ALLERGY")]}),
    ("My allergies include pollen, soy, and wheat.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and eggs.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 31, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and tree nuts.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 38, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain medications.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 52, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and wheat.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 32, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and eggs.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain fruits.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 46, "ALLERGY")]}),
    ("I'm allergic to latex, shellfish, and tree nuts.", {"entities": [(5, 10, "ALLERGY"), (12, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and certain medications.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 50, "ALLERGY")]}),
    ("My allergies include pollen, soy, and wheat.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and eggs.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 31, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and tree nuts.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 38, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain medications.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 52, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and wheat.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 32, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and eggs.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain fruits.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 46, "ALLERGY")]}),
    ("I'm allergic to latex, shellfish, and tree nuts.", {"entities": [(5, 10, "ALLERGY"), (12, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and certain medications.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 50, "ALLERGY")]}),
    ("My allergies include pollen, soy, and wheat.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and eggs.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 31, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and tree nuts.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 38, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain medications.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 52, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and wheat.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 32, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and eggs.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain fruits.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 46, "ALLERGY")]}),
    ("I'm allergic to latex, shellfish, and tree nuts.", {"entities": [(5, 10, "ALLERGY"), (12, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and certain medications.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 50, "ALLERGY")]}),
    ("My allergies include pollen, soy, and wheat.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and eggs.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 31, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and tree nuts.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 38, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain medications.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 52, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and wheat.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 32, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and eggs.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain fruits.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 46, "ALLERGY")]}),
    ("I'm allergic to latex, shellfish, and tree nuts.", {"entities": [(5, 10, "ALLERGY"), (12, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and certain medications.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 50, "ALLERGY")]}),
    ("My allergies include pollen, soy, and wheat.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and eggs.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 31, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and tree nuts.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 38, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain medications.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 52, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and wheat.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 32, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and eggs.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain fruits.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 46, "ALLERGY")]}),
    ("I'm allergic to latex, shellfish, and tree nuts.", {"entities": [(5, 10, "ALLERGY"), (12, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and certain medications.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 50, "ALLERGY")]}),
    ("My allergies include pollen, soy, and wheat.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and eggs.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 31, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and tree nuts.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 38, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain medications.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 52, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and wheat.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 32, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and eggs.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain fruits.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 46, "ALLERGY")]}),
    ("I'm allergic to latex, shellfish, and tree nuts.", {"entities": [(5, 10, "ALLERGY"), (12, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and certain medications.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 50, "ALLERGY")]}),
    ("My allergies include pollen, soy, and wheat.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and eggs.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 31, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and tree nuts.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 38, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain medications.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 52, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and wheat.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 32, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and eggs.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("My allergies include pollen, soy, and certain fruits.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 46, "ALLERGY")]}),
    ("I'm allergic to latex, shellfish, and tree nuts.", {"entities": [(5, 10, "ALLERGY"), (12, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and certain medications.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 50, "ALLERGY")]}),
    ("My allergies include pollen, soy, and wheat.", {"entities": [(16, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("I'm allergic to gluten, shellfish, and eggs.", {"entities": [(5, 11, "ALLERGY"), (13, 22, "ALLERGY"), (27, 31, "ALLERGY")]}),
    ("I have allergies to dairy, peanuts, and tree nuts.", {"entities": [(10, 15, "ALLERGY"), (17, 24, "ALLERGY"), (29, 38, "ALLERGY")]}),
    ("I'm allergic to peanuts and shellfish.", {"entities": [(14, 21, "ALLERGY"), (26, 34, "ALLERGY")]}),
    ("My allergies include dairy and gluten.", {"entities": [(16, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("I'm allergic to pollen and dust mites.", {"entities": [(14, 20, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("My allergies are to soy and tree nuts.", {"entities": [(15, 18, "ALLERGY"), (23, 32, "ALLERGY")]}),
    ("I have allergies to latex and eggs.", {"entities": [(17, 22, "ALLERGY"), (27, 31, "ALLERGY")]}),
    ("My allergies include shellfish and wheat.", {"entities": [(16, 24, "ALLERGY"), (29, 34, "ALLERGY")]}),
    ("I'm allergic to peanuts and dairy.", {"entities": [(14, 21, "ALLERGY"), (26, 31, "ALLERGY")]}),
    ("My allergies are to gluten and soy.", {"entities": [(15, 21, "ALLERGY"), (26, 29, "ALLERGY")]}),
    ("I have allergies to dust mites and pollen.", {"entities": [(17, 27, "ALLERGY"), (32, 38, "ALLERGY")]}),
    ("My allergies include tree nuts and shellfish.", {"entities": [(16, 25, "ALLERGY"), (30, 38, "ALLERGY")]}),
    ("I'm allergic to eggs and latex.", {"entities": [(14, 18, "ALLERGY"), (23, 28, "ALLERGY")]}),
    ("My allergies are to wheat and peanuts.", {"entities": [(15, 20, "ALLERGY"), (25, 32, "ALLERGY")]}),
    ("I have allergies to dairy and gluten.", {"entities": [(17, 22, "ALLERGY"), (27, 33, "ALLERGY")]}),
    ("My allergies include soy and tree nuts.", {"entities": [(17, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to shellfish and dust mites.", {"entities": [(14, 22, "ALLERGY"), (27, 37, "ALLERGY")]}),
    ("My allergies are to pollen and eggs.", {"entities": [(15, 21, "ALLERGY"), (26, 30, "ALLERGY")]}),
    ("I have allergies to latex and peanuts.", {"entities": [(17, 22, "ALLERGY"), (27, 34, "ALLERGY")]}),
    ("My allergies include gluten and soy.", {"entities": [(16, 22, "ALLERGY"), (27, 30, "ALLERGY")]}),
    ("I'm allergic to tree nuts and wheat.", {"entities": [(14, 23, "ALLERGY"), (28, 33, "ALLERGY")]}),
    ("My allergies are to eggs and dairy.", {"entities": [(15, 19, "ALLERGY"), (24, 29, "ALLERGY")]}),
    ("I have allergies to dust mites and shellfish.", {"entities": [(17, 27, "ALLERGY"), (32, 40, "ALLERGY")]}),
    ("My allergies include peanuts and latex.", {"entities": [(16, 23, "ALLERGY"), (28, 33, "ALLERGY")]}),
    ("I'm allergic to gluten and soy.", {"entities": [(14, 20, "ALLERGY"), (25, 28, "ALLERGY")]}),
    ("My allergies are to dairy and tree nuts.", {"entities": [(15, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I have allergies to wheat and pollen.", {"entities": [(17, 22, "ALLERGY"), (27, 33, "ALLERGY")]}),
    ("My allergies include shellfish and eggs.", {"entities": [(16, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("I'm allergic to soy and peanuts.", {"entities": [(14, 17, "ALLERGY"), (22, 29, "ALLERGY")]}),
    ("My allergies are to latex and dust mites.", {"entities": [(15, 20, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("I have allergies to tree nuts and dairy.", {"entities": [(17, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("My allergies include wheat and shellfish.", {"entities": [(16, 21, "ALLERGY"), (26, 34, "ALLERGY")]}),
    ("I'm allergic to eggs and gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 29, "ALLERGY")]}),
    ("My allergies are to peanuts and soy.", {"entities": [(15, 22, "ALLERGY"), (27, 30, "ALLERGY")]}),
    ("I have allergies to dairy and dust mites.", {"entities": [(17, 22, "ALLERGY"), (27, 37, "ALLERGY")]}),
    ("My allergies include tree nuts and latex.", {"entities": [(16, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("I'm allergic to shellfish and wheat.", {"entities": [(14, 22, "ALLERGY"), (27, 32, "ALLERGY")]}),
    ("My allergies are to eggs and peanuts.", {"entities": [(15, 19, "ALLERGY"), (24, 31, "ALLERGY")]}),
    ("I have allergies to gluten and soy.", {"entities": [(17, 23, "ALLERGY"), (28, 31, "ALLERGY")]}),
    ("My allergies include dairy and tree nuts.", {"entities": [(16, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I'm allergic to wheat and pollen.", {"entities": [(14, 19, "ALLERGY"), (24, 30, "ALLERGY")]}),
    ("My allergies are to shellfish and latex.", {"entities": [(15, 23, "ALLERGY"), (28, 33, "ALLERGY")]}),
    ("I have allergies to peanuts and eggs.", {"entities": [(17, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("My allergies include soy and dust mites.", {"entities": [(16, 19, "ALLERGY"), (24, 34, "ALLERGY")]}),
    ("I'm allergic to tree nuts and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 33, "ALLERGY")]}),
    ("My allergies are to wheat and shellfish.", {"entities": [(15, 20, "ALLERGY"), (25, 33, "ALLERGY")]}),
    ("I have allergies to eggs and gluten.", {"entities": [(17, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("My allergies include peanuts and soy.", {"entities": [(16, 23, "ALLERGY"), (28, 31, "ALLERGY")]}),
    ("I'm allergic to dairy and dust mites.", {"entities": [(14, 19, "ALLERGY"), (24, 34, "ALLERGY")]}),
    ("My allergies are to tree nuts and latex.", {"entities": [(15, 24, "ALLERGY"), (29, 34, "ALLERGY")]}),
    ("I have allergies to shellfish and wheat.", {"entities": [(17, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("My allergies include eggs and peanuts.", {"entities": [(16, 20, "ALLERGY"), (25, 32, "ALLERGY")]}),
    ("I'm allergic to gluten and soy.", {"entities": [(14, 20, "ALLERGY"), (25, 28, "ALLERGY")]}),
    ("My allergies are to dairy and tree nuts.", {"entities": [(15, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I have allergies to wheat and pollen.", {"entities": [(17, 22, "ALLERGY"), (27, 33, "ALLERGY")]}),
    ("My allergies include shellfish and eggs.", {"entities": [(16, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("I'm allergic to soy and peanuts.", {"entities": [(14, 17, "ALLERGY"), (22, 29, "ALLERGY")]}),
    ("My allergies are to latex and dust mites.", {"entities": [(15, 20, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("I have allergies to tree nuts and dairy.", {"entities": [(17, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("My allergies include wheat and shellfish.", {"entities": [(16, 21, "ALLERGY"), (26, 34, "ALLERGY")]}),
    ("I'm allergic to eggs and gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 29, "ALLERGY")]}),
    ("My allergies are to peanuts and soy.", {"entities": [(15, 22, "ALLERGY"), (27, 30, "ALLERGY")]}),
    ("I have allergies to dairy and dust mites.", {"entities": [(17, 22, "ALLERGY"), (27, 37, "ALLERGY")]}),
    ("My allergies include tree nuts and latex.", {"entities": [(16, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("I'm allergic to shellfish and wheat.", {"entities": [(14, 22, "ALLERGY"), (27, 32, "ALLERGY")]}),
    ("My allergies are to eggs and peanuts.", {"entities": [(15, 19, "ALLERGY"), (24, 31, "ALLERGY")]}),
    ("I have allergies to gluten and soy.", {"entities": [(17, 23, "ALLERGY"), (28, 31, "ALLERGY")]}),
    ("My allergies include dairy and tree nuts.", {"entities": [(16, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I'm allergic to wheat and pollen.", {"entities": [(14, 19, "ALLERGY"), (24, 30, "ALLERGY")]}),
    ("My allergies are to shellfish and latex.", {"entities": [(15, 23, "ALLERGY"), (28, 33, "ALLERGY")]}),
    ("I have allergies to peanuts and eggs.", {"entities": [(17, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("My allergies include soy and dust mites.", {"entities": [(16, 19, "ALLERGY"), (24, 34, "ALLERGY")]}),
    ("I'm allergic to tree nuts and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 33, "ALLERGY")]}),
    ("My allergies are to wheat and shellfish.", {"entities": [(15, 20, "ALLERGY"), (25, 33, "ALLERGY")]}),
    ("I have allergies to eggs and gluten.", {"entities": [(17, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("My allergies include peanuts and soy.", {"entities": [(16, 23, "ALLERGY"), (28, 31, "ALLERGY")]}),
    ("I'm allergic to dairy and dust mites.", {"entities": [(14, 19, "ALLERGY"), (24, 34, "ALLERGY")]}),
    ("My allergies are to tree nuts and latex.", {"entities": [(15, 24, "ALLERGY"), (29, 34, "ALLERGY")]}),
    ("I have allergies to shellfish and wheat.", {"entities": [(17, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("My allergies include eggs and peanuts.", {"entities": [(16, 20, "ALLERGY"), (25, 32, "ALLERGY")]}),
    ("I'm allergic to gluten and soy.", {"entities": [(14, 20, "ALLERGY"), (25, 28, "ALLERGY")]}),
    ("My allergies are to dairy and tree nuts.", {"entities": [(15, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I have allergies to wheat and pollen.", {"entities": [(17, 22, "ALLERGY"), (27, 33, "ALLERGY")]}),
    ("My allergies include shellfish and eggs.", {"entities": [(16, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("I'm allergic to soy and peanuts.", {"entities": [(14, 17, "ALLERGY"), (22, 29, "ALLERGY")]}),
    ("My allergies are to latex and dust mites.", {"entities": [(15, 20, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("I have allergies to tree nuts and dairy.", {"entities": [(17, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("My allergies include wheat and shellfish.", {"entities": [(16, 21, "ALLERGY"), (26, 34, "ALLERGY")]}),
    ("I'm allergic to eggs and gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 29, "ALLERGY")]}),
    ("My allergies are to peanuts and soy.", {"entities": [(15, 22, "ALLERGY"), (27, 30, "ALLERGY")]}),
    ("I have allergies to dairy and dust mites.", {"entities": [(17, 22, "ALLERGY"), (27, 37, "ALLERGY")]}),
    ("My allergies include tree nuts and latex.", {"entities": [(16, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("I'm allergic to shellfish and wheat.", {"entities": [(14, 22, "ALLERGY"), (27, 32, "ALLERGY")]}),
    ("My allergies are to eggs and peanuts.", {"entities": [(15, 19, "ALLERGY"), (24, 31, "ALLERGY")]}),
    ("I have allergies to gluten and soy.", {"entities": [(17, 23, "ALLERGY"), (28, 31, "ALLERGY")]}),
    ("My allergies include dairy and tree nuts.", {"entities": [(16, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I'm allergic to wheat and pollen.", {"entities": [(14, 19, "ALLERGY"), (24, 30, "ALLERGY")]}),
    ("My allergies are to shellfish and latex.", {"entities": [(15, 23, "ALLERGY"), (28, 33, "ALLERGY")]}),
    ("I have allergies to peanuts and eggs.", {"entities": [(17, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("My allergies include soy and dust mites.", {"entities": [(16, 19, "ALLERGY"), (24, 34, "ALLERGY")]}),
    ("I'm allergic to tree nuts and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 33, "ALLERGY")]}),
    ("My allergies are to wheat and shellfish.", {"entities": [(15, 20, "ALLERGY"), (25, 33, "ALLERGY")]}),
    ("I have allergies to eggs and gluten.", {"entities": [(17, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("My allergies include peanuts and soy.", {"entities": [(16, 23, "ALLERGY"), (28, 31, "ALLERGY")]}),
    ("I'm allergic to dairy and dust mites.", {"entities": [(14, 19, "ALLERGY"), (24, 34, "ALLERGY")]}),
    ("My allergies are to tree nuts and latex.", {"entities": [(15, 24, "ALLERGY"), (29, 34, "ALLERGY")]}),
    ("I have allergies to shellfish and wheat.", {"entities": [(17, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("My allergies include eggs and peanuts.", {"entities": [(16, 20, "ALLERGY"), (25, 32, "ALLERGY")]}),
    ("I'm allergic to gluten and soy.", {"entities": [(14, 20, "ALLERGY"), (25, 28, "ALLERGY")]}),
    ("My allergies are to dairy and tree nuts.", {"entities": [(15, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I have allergies to wheat and pollen.", {"entities": [(17, 22, "ALLERGY"), (27, 33, "ALLERGY")]}),
    ("My allergies include shellfish and eggs.", {"entities": [(16, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("I'm allergic to soy and peanuts.", {"entities": [(14, 17, "ALLERGY"), (22, 29, "ALLERGY")]}),
    ("My allergies are to latex and dust mites.", {"entities": [(15, 20, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("I have allergies to tree nuts and dairy.", {"entities": [(17, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("My allergies include wheat and shellfish.", {"entities": [(16, 21, "ALLERGY"), (26, 34, "ALLERGY")]}),
    ("I'm allergic to eggs and gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 29, "ALLERGY")]}),
    ("My allergies are to peanuts and soy.", {"entities": [(15, 22, "ALLERGY"), (27, 30, "ALLERGY")]}),
    ("I have allergies to dairy and dust mites.", {"entities": [(17, 22, "ALLERGY"), (27, 37, "ALLERGY")]}),
    ("My allergies include tree nuts and latex.", {"entities": [(16, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("I'm allergic to shellfish and wheat.", {"entities": [(14, 22, "ALLERGY"), (27, 32, "ALLERGY")]}),
    ("My allergies are to eggs and peanuts.", {"entities": [(15, 19, "ALLERGY"), (24, 31, "ALLERGY")]}),
    ("I have allergies to gluten and soy.", {"entities": [(17, 23, "ALLERGY"), (28, 31, "ALLERGY")]}),
    ("My allergies include dairy and tree nuts.", {"entities": [(16, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I'm allergic to wheat and pollen.", {"entities": [(14, 19, "ALLERGY"), (24, 30, "ALLERGY")]}),
    ("My allergies are to shellfish and latex.", {"entities": [(15, 23, "ALLERGY"), (28, 33, "ALLERGY")]}),
    ("I have allergies to peanuts and eggs.", {"entities": [(17, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("My allergies include soy and dust mites.", {"entities": [(16, 19, "ALLERGY"), (24, 34, "ALLERGY")]}),
    ("I'm allergic to tree nuts and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 33, "ALLERGY")]}),
    ("My allergies are to wheat and shellfish.", {"entities": [(15, 20, "ALLERGY"), (25, 33, "ALLERGY")]}),
    ("I have allergies to eggs and gluten.", {"entities": [(17, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("My allergies include peanuts and soy.", {"entities": [(16, 23, "ALLERGY"), (28, 31, "ALLERGY")]}),
    ("I'm allergic to dairy and dust mites.", {"entities": [(14, 19, "ALLERGY"), (24, 34, "ALLERGY")]}),
    ("My allergies are to tree nuts and latex.", {"entities": [(15, 24, "ALLERGY"), (29, 34, "ALLERGY")]}),
    ("I have allergies to shellfish and wheat.", {"entities": [(17, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("My allergies include eggs and peanuts.", {"entities": [(16, 20, "ALLERGY"), (25, 32, "ALLERGY")]}),
    ("I'm allergic to gluten and soy.", {"entities": [(14, 20, "ALLERGY"), (25, 28, "ALLERGY")]}),
    ("My allergies are to dairy and tree nuts.", {"entities": [(15, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I have allergies to wheat and pollen.", {"entities": [(17, 22, "ALLERGY"), (27, 33, "ALLERGY")]}),
    ("My allergies include shellfish and eggs.", {"entities": [(16, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("I'm allergic to soy and peanuts.", {"entities": [(14, 17, "ALLERGY"), (22, 29, "ALLERGY")]}),
    ("My allergies are to latex and dust mites.", {"entities": [(15, 20, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("I have allergies to tree nuts and dairy.", {"entities": [(17, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("My allergies include wheat and shellfish.", {"entities": [(16, 21, "ALLERGY"), (26, 34, "ALLERGY")]}),
    ("I'm allergic to eggs and gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 29, "ALLERGY")]}),
    ("My allergies are to peanuts and soy.", {"entities": [(15, 22, "ALLERGY"), (27, 30, "ALLERGY")]}),
    ("I have allergies to dairy and dust mites.", {"entities": [(17, 22, "ALLERGY"), (27, 37, "ALLERGY")]}),
    ("My allergies include tree nuts and latex.", {"entities": [(16, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("I'm allergic to shellfish and wheat.", {"entities": [(14, 22, "ALLERGY"), (27, 32, "ALLERGY")]}),
    ("My allergies are to eggs and peanuts.", {"entities": [(15, 19, "ALLERGY"), (24, 31, "ALLERGY")]}),
    ("I have allergies to gluten and soy.", {"entities": [(17, 23, "ALLERGY"), (28, 31, "ALLERGY")]}),
    ("My allergies include dairy and tree nuts.", {"entities": [(16, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I'm allergic to wheat and pollen.", {"entities": [(14, 19, "ALLERGY"), (24, 30, "ALLERGY")]}),
    ("My allergies are to shellfish and latex.", {"entities": [(15, 23, "ALLERGY"), (28, 33, "ALLERGY")]}),
    ("I have allergies to peanuts and eggs.", {"entities": [(17, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("My allergies include soy and dust mites.", {"entities": [(16, 19, "ALLERGY"), (24, 34, "ALLERGY")]}),
    ("I'm allergic to tree nuts and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 33, "ALLERGY")]}),
    ("My allergies are to wheat and shellfish.", {"entities": [(15, 20, "ALLERGY"), (25, 33, "ALLERGY")]}),
    ("I have allergies to eggs and gluten.", {"entities": [(17, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("My allergies include peanuts and soy.", {"entities": [(16, 23, "ALLERGY"), (28, 31, "ALLERGY")]}),
    ("I'm allergic to dairy and dust mites.", {"entities": [(14, 19, "ALLERGY"), (24, 34, "ALLERGY")]}),
    ("My allergies are to tree nuts and latex.", {"entities": [(15, 24, "ALLERGY"), (29, 34, "ALLERGY")]}),
    ("I have allergies to shellfish and wheat.", {"entities": [(17, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("My allergies include eggs and peanuts.", {"entities": [(16, 20, "ALLERGY"), (25, 32, "ALLERGY")]}),
    ("I'm allergic to gluten and soy.", {"entities": [(14, 20, "ALLERGY"), (25, 28, "ALLERGY")]}),
    ("My allergies are to dairy and tree nuts.", {"entities": [(15, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I have allergies to wheat and pollen.", {"entities": [(17, 22, "ALLERGY"), (27, 33, "ALLERGY")]}),
    ("My allergies include shellfish and eggs.", {"entities": [(16, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("I'm allergic to soy and peanuts.", {"entities": [(14, 17, "ALLERGY"), (22, 29, "ALLERGY")]}),
    ("My allergies are to latex and dust mites.", {"entities": [(15, 20, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("I have allergies to tree nuts and dairy.", {"entities": [(17, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("My allergies include wheat and shellfish.", {"entities": [(16, 21, "ALLERGY"), (26, 34, "ALLERGY")]}),
    ("I'm allergic to eggs and gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 29, "ALLERGY")]}),
    ("My allergies are to peanuts and soy.", {"entities": [(15, 22, "ALLERGY"), (27, 30, "ALLERGY")]}),
    ("I have allergies to dairy and dust mites.", {"entities": [(17, 22, "ALLERGY"), (27, 37, "ALLERGY")]}),
    ("My allergies include tree nuts and latex.", {"entities": [(16, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("I'm allergic to shellfish and wheat.", {"entities": [(14, 22, "ALLERGY"), (27, 32, "ALLERGY")]}),
    ("My allergies are to eggs and peanuts.", {"entities": [(15, 19, "ALLERGY"), (24, 31, "ALLERGY")]}),
    ("I have allergies to gluten and soy.", {"entities": [(17, 23, "ALLERGY"), (28, 31, "ALLERGY")]}),
    ("My allergies include dairy and tree nuts.", {"entities": [(16, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I'm allergic to wheat and pollen.", {"entities": [(14, 19, "ALLERGY"), (24, 30, "ALLERGY")]}),
    ("My allergies are to shellfish and latex.", {"entities": [(15, 23, "ALLERGY"), (28, 33, "ALLERGY")]}),
    ("I have allergies to peanuts and eggs.", {"entities": [(17, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("My allergies include soy and dust mites.", {"entities": [(16, 19, "ALLERGY"), (24, 34, "ALLERGY")]}),
    ("I'm allergic to tree nuts and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 33, "ALLERGY")]}),
    ("My allergies are to wheat and shellfish.", {"entities": [(15, 20, "ALLERGY"), (25, 33, "ALLERGY")]}),
    ("I have allergies to eggs and gluten.", {"entities": [(17, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("My allergies include peanuts and soy.", {"entities": [(16, 23, "ALLERGY"), (28, 31, "ALLERGY")]}),
    ("I'm allergic to dairy and dust mites.", {"entities": [(14, 19, "ALLERGY"), (24, 34, "ALLERGY")]}),
    ("My allergies are to tree nuts and latex.", {"entities": [(15, 24, "ALLERGY"), (29, 34, "ALLERGY")]}),
    ("I have allergies to shellfish and wheat.", {"entities": [(17, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("My allergies include eggs and peanuts.", {"entities": [(16, 20, "ALLERGY"), (25, 32, "ALLERGY")]}),
    ("I'm allergic to gluten and soy.", {"entities": [(14, 20, "ALLERGY"), (25, 28, "ALLERGY")]}),
    ("My allergies are to dairy and tree nuts.", {"entities": [(15, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I have allergies to wheat and pollen.", {"entities": [(17, 22, "ALLERGY"), (27, 33, "ALLERGY")]}),
    ("My allergies include shellfish and eggs.", {"entities": [(16, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("I'm allergic to soy and peanuts.", {"entities": [(14, 17, "ALLERGY"), (22, 29, "ALLERGY")]}),
    ("My allergies are to latex and dust mites.", {"entities": [(15, 20, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("I have allergies to tree nuts and dairy.", {"entities": [(17, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("My allergies include wheat and shellfish.", {"entities": [(16, 21, "ALLERGY"), (26, 34, "ALLERGY")]}),
    ("I'm allergic to eggs and gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 29, "ALLERGY")]}),
    ("My allergies are to peanuts and soy.", {"entities": [(15, 22, "ALLERGY"), (27, 30, "ALLERGY")]}),
    ("I have allergies to dairy and dust mites.", {"entities": [(17, 22, "ALLERGY"), (27, 37, "ALLERGY")]}),
    ("My allergies include tree nuts and latex.", {"entities": [(16, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("I'm allergic to shellfish and wheat.", {"entities": [(14, 22, "ALLERGY"), (27, 32, "ALLERGY")]}),
    ("My allergies are to eggs and peanuts.", {"entities": [(15, 19, "ALLERGY"), (24, 31, "ALLERGY")]}),
    ("I have allergies to gluten and soy.", {"entities": [(17, 23, "ALLERGY"), (28, 31, "ALLERGY")]}),
    ("My allergies include dairy and tree nuts.", {"entities": [(16, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I'm allergic to wheat and pollen.", {"entities": [(14, 19, "ALLERGY"), (24, 30, "ALLERGY")]}),
    ("My allergies are to shellfish and latex.", {"entities": [(15, 23, "ALLERGY"), (28, 33, "ALLERGY")]}),
    ("I have allergies to peanuts and eggs.", {"entities": [(17, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("My allergies include soy and dust mites.", {"entities": [(16, 19, "ALLERGY"), (24, 34, "ALLERGY")]}),
    ("I'm allergic to tree nuts and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 33, "ALLERGY")]}),
    ("My allergies are to wheat and shellfish.", {"entities": [(15, 20, "ALLERGY"), (25, 33, "ALLERGY")]}),
    ("I have allergies to eggs and gluten.", {"entities": [(17, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("My allergies include peanuts and soy.", {"entities": [(16, 23, "ALLERGY"), (28, 31, "ALLERGY")]}),
    ("I'm allergic to dairy and dust mites.", {"entities": [(14, 19, "ALLERGY"), (24, 34, "ALLERGY")]}),
    ("My allergies are to tree nuts and latex.", {"entities": [(15, 24, "ALLERGY"), (29, 34, "ALLERGY")]}),
    ("I have allergies to shellfish and wheat.", {"entities": [(17, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("My allergies include eggs and peanuts.", {"entities": [(16, 20, "ALLERGY"), (25, 32, "ALLERGY")]}),
    ("I'm allergic to gluten and soy.", {"entities": [(14, 20, "ALLERGY"), (25, 28, "ALLERGY")]}),
    ("My allergies are to dairy and tree nuts.", {"entities": [(15, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I have allergies to wheat and pollen.", {"entities": [(17, 22, "ALLERGY"), (27, 33, "ALLERGY")]}),
    ("My allergies include shellfish and eggs.", {"entities": [(16, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("I'm allergic to soy and peanuts.", {"entities": [(14, 17, "ALLERGY"), (22, 29, "ALLERGY")]}),
    ("My allergies are to latex and dust mites.", {"entities": [(15, 20, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("I have allergies to tree nuts and dairy.", {"entities": [(17, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("My allergies include wheat and shellfish.", {"entities": [(16, 21, "ALLERGY"), (26, 34, "ALLERGY")]}),
    ("I'm allergic to eggs and gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 29, "ALLERGY")]}),
    ("My allergies are to peanuts and soy.", {"entities": [(15, 22, "ALLERGY"), (27, 30, "ALLERGY")]}),
    ("I have allergies to dairy and dust mites.", {"entities": [(17, 22, "ALLERGY"), (27, 37, "ALLERGY")]}),
    ("My allergies include tree nuts and latex.", {"entities": [(16, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("I'm allergic to shellfish and wheat.", {"entities": [(14, 22, "ALLERGY"), (27, 32, "ALLERGY")]}),
    ("My allergies are to eggs and peanuts.", {"entities": [(15, 19, "ALLERGY"), (24, 31, "ALLERGY")]}),
    ("I have allergies to gluten and soy.", {"entities": [(17, 23, "ALLERGY"), (28, 31, "ALLERGY")]}),
    ("My allergies include dairy and tree nuts.", {"entities": [(16, 21, "ALLERGY"), (26, 35, "ALLERGY")]}),
    ("I'm allergic to wheat and pollen.", {"entities": [(14, 19, "ALLERGY"), (24, 30, "ALLERGY")]}),
    ("My allergies are to shellfish and latex.", {"entities": [(15, 23, "ALLERGY"), (28, 33, "ALLERGY")]}),
    ("I have allergies to peanuts and eggs.", {"entities": [(17, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("My allergies include soy and dust mites.", {"entities": [(16, 19, "ALLERGY"), (24, 34, "ALLERGY")]}),
    ("I'm allergic to tree nuts and dairy.", {"entities": [(14, 23, "ALLERGY"), (28, 33, "ALLERGY")]}),
    ("My allergies are to wheat and shellfish.", {"entities": [(15, 20, "ALLERGY"), (25, 33, "ALLERGY")]}),
    ("I have allergies to eggs and gluten.", {"entities": [(17, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("My allergies include peanuts and soy.", {"entities": [(16, 23, "ALLERGY"), (28, 31, "ALLERGY")]}),
    ("I'm allergic to dairy and dust mites.", {"entities": [(14, 19, "ALLERGY"), (24, 34, "ALLERGY")]}),
    ("My allergies are to tree nuts and latex.", {"entities": [(15, 24, "ALLERGY"), (29, 34, "ALLERGY")]}),
    ("I have allergies to shellfish and wheat.", {"entities": [(17, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("My allergies include eggs and peanuts.", {"entities": [(16, 20, "ALLERGY"), (25, 32, "ALLERGY")]}),
    ("I'm allergic to gluten and soy.", {"entities": [(14, 20, "ALLERGY"), (25, 28, "ALLERGY")]}),
    ("My allergies are to dairy and tree nuts.", {"entities": [(15, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I have allergies to wheat and pollen.", {"entities": [(17, 22, "ALLERGY"), (27, 33, "ALLERGY")]}),
    ("My allergies include shellfish and eggs.", {"entities": [(16, 24, "ALLERGY"), (29, 33, "ALLERGY")]}),
    ("I'm allergic to soy and peanuts.", {"entities": [(14, 17, "ALLERGY"), (22, 29, "ALLERGY")]}),
    ("My allergies are to latex and dust mites.", {"entities": [(15, 20, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("I have allergies to tree nuts and dairy.", {"entities": [(17, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("My allergies include wheat and shellfish.", {"entities": [(16, 21, "ALLERGY"), (26, 34, "ALLERGY")]}),
    ("I'm allergic to eggs and gluten.", {"entities": [(14, 18, "ALLERGY"), (23, 29, "ALLERGY")]}),
    ("My allergies are to peanuts and soy.", {"entities": [(15, 22, "ALLERGY"), (27, 30, "ALLERGY")]}),
    ("I have allergies to dairy and dust mites.", {"entities": [(17, 22, "ALLERGY"), (27, 37, "ALLERGY")]}),
    ("My allergies include tree nuts and latex.", {"entities": [(16, 25, "ALLERGY"), (30, 35, "ALLERGY")]}),
    ("I'm allergic to shellfish and wheat.", {"entities": [(14, 22, "ALLERGY"), (27, 32, "ALLERGY")]}),
    ("I've never experienced any allergies.", {"entities": []}),
    ("There's nothing I'm allergic to.", {"entities": []}),
    ("No allergies have ever affected me.", {"entities": []}),
    ("I'm grateful for my lack of allergies.", {"entities": []}),
    ("No allergy-related issues for me.", {"entities": []}),
    ("I've been lucky to avoid allergies so far.", {"entities": []}),
    ("Allergies aren't a concern in my life.", {"entities": []}),
    ("I don't have any allergies to disclose.", {"entities": []}),
    ("Allergies don't bother me.", {"entities": []}),
    ("I'm not prone to allergies.", {"entities": []}),
    ("No allergic reactions for me.", {"entities": []}),
    ("I'm allergy-resistant.", {"entities": []}),
    ("I've never had an allergic reaction.", {"entities": []}),
    ("I don't suffer from allergies.", {"entities": []}),
    ("I'm fortunate not to have allergies.", {"entities": []}),
    ("No allergies are troubling me.", {"entities": []}),
    ("Allergies aren't part of my health concerns.", {"entities": []}),
    ("I'm unaffected by allergies.", {"entities": []}),
    ("I'm allergy-proof.", {"entities": []}),
    ("I don't have to deal with allergies.", {"entities": []}),
    ("Allergies aren't on my radar.", {"entities": []}),
    ("I've never had to worry about allergies.", {"entities": []}),
    ("No allergic tendencies for me.", {"entities": []}),
    ("I've never shown signs of allergies.", {"entities": []}),
    ("Allergies aren't an issue for me.", {"entities": []}),
    ("I've never had any allergic symptoms.", {"entities": []}),
    ("Allergies have never been a problem for me.", {"entities": []}),
    ("I don't have any allergy-related complications.", {"entities": []}),
    ("I'm allergy-free and proud of it.", {"entities": []}),
    ("I've been blessed with no allergies.", {"entities": []}),
    ("Allergies don't bother me one bit.", {"entities": []}),
    ("I'm not allergic to anything whatsoever.", {"entities": []}),
    ("I've dodged the allergy bullet so far.", {"entities": []}),
    ("Allergies aren't something I have to contend with.", {"entities": []}),
    ("I'm not susceptible to allergies.", {"entities": []}),
    ("Allergies haven't been a concern in my life.", {"entities": []}),
    ("I'm allergy-resistant and proud.", {"entities": []}),
    ("I've never experienced an allergic reaction.", {"entities": []}),
    ("Allergies aren't part of my health landscape.", {"entities": []}),
    ("I'm not bothered by allergies at all.", {"entities": []}),
    ("Allergies haven't been an issue for me.", {"entities": []}),
    ("I'm not affected by allergies in any way.", {"entities": []}),
    ("I've never had to deal with allergies.", {"entities": []}),
    ("Allergies aren't something I've had to deal with.", {"entities": []}),
    ("I'm free from the burden of allergies.", {"entities": []}),
    ("Allergies aren't a concern for me at all.", {"entities": []}),
    ("I don't have any allergies to speak of.", {"entities": []}),
    ("Allergies haven't been a factor in my life.", {"entities": []}),
    ("I've never had any issues with allergies.", {"entities": []}),
    ("Allergies aren't a part of my health profile.", {"entities": []}),
    ("I've never had any allergy-related complications.", {"entities": []}),
    ("Allergies don't affect me in any way.", {"entities": []}),
    ("I've never had to worry about allergies.", {"entities": []}),
    ("Allergies haven't been a concern for me.", {"entities": []}),
    ("I'm allergy-free and happy about it.", {"entities": []}),
    ("Allergies aren't something I've ever dealt with.", {"entities": []}),
    ("I've been fortunate enough to avoid allergies.", {"entities": []}),
    ("Allergies aren't something I've had to face.", {"entities": []}),
    ("I'm grateful not to have any allergies.", {"entities": []}),
    ("Allergies haven't been an issue for me at all.", {"entities": []}),
    ("I've never had any allergic reactions.", {"entities": []}),
    ("Allergies aren't a part of my health concerns.", {"entities": []}),
    ("I've never had to worry about allergies.", {"entities": []}),
    ("Allergies haven't been on my radar.", {"entities": []}),
    ("I've never had to deal with allergies in my life.", {"entities": []}),
    ("Allergies don't affect me in any way.", {"entities": []}),
    ("I've never experienced any allergy symptoms.", {"entities": []}),
    ("Allergies haven't been a problem for me.", {"entities": []}),
    ("I've never been affected by allergies.", {"entities": []}),
    ("Allergies aren't something I've ever had to think about.", {"entities": []}),
    ("I'm not allergic to anything and I'm grateful.", {"entities": []}),
    ("Allergies have never been a concern for me.", {"entities": []}),
    ("I've never had to worry about allergies.", {"entities": []}),
    ("Allergies haven't been an issue for me.", {"entities": []}),
    ("I've never experienced any allergic reactions.", {"entities": []}),
    ("Allergies haven't been part of my health journey.", {"entities": []}),
    ("I've never had to deal with allergies.", {"entities": []}),
    ("Allergies aren't a concern for me at all.", {"entities": []}),
    ("I've never had any allergic symptoms.", {"entities": []}),
    ("Allergies haven't been a problem for me.", {"entities": []}),
    ("I've never had to worry about allergies.", {"entities": []}),
    ("Allergies haven't been on my radar.", {"entities": []}),
    ("I've never had to think about allergies.", {"entities": []}),
    ("Allergies haven't been something I've had to deal with.", {"entities": []}),
    ("I've never experienced any allergy-related issues.", {"entities": []}),
    ("Allergies haven't been a concern for me.", {"entities": []}),
    ("I've never been affected by allergies.", {"entities": []}),
    ("Allergies haven't been part of my health journey.", {"entities": []}),
    ("I've never had to worry about allergies.", {"entities": []}),
    ("Allergies haven't been a concern for me.", {"entities": []}),
    ("I've never had to deal with allergies.", {"entities": []}),
    ("Allergies haven't been something I've had to face.", {"entities": []}),
    ("I've never had to think about allergies.", {"entities": []}),
    ("Allergies haven't been a problem for me.", {"entities": []}),
    ("I've never experienced any allergy-related issues.", {"entities": []}),
    ("Allergies haven't been a concern for me.", {"entities": []}),
    ("I've never been affected by allergies.", {"entities": []}),
    ("Allergies haven't been part of my health journey.", {"entities": []}),
    ("I've never had to worry about allergies.", {"entities": []}),
    ("Allergies haven't been a concern for me.", {"entities": []}),
    ("I've never had to deal with allergies.", {"entities": []}),
    ("Allergies haven't been something I've had to face.", {"entities": []}),
    ("I've never had to think about allergies.", {"entities": []}),
    ("Allergies haven't been a problem for me.", {"entities": []}),
    ("I've never experienced any allergy-related issues.", {"entities": []}),
    ("Allergies haven't been a concern for me.", {"entities": []}),
    ("I've never been affected by allergies.", {"entities": []}),
    ("Allergies haven't been part of my health journey.", {"entities": []}),
    ("I've never had to worry about allergies.", {"entities": []}),
    ("Allergies haven't been a concern for me.", {"entities": []}),
    ("I've never had to deal with allergies.", {"entities": []}),
    ("Allergies haven't been something I've had to face.", {"entities": []}),
    ("I've never had to think about allergies.", {"entities": []}),
    ("Allergies haven't been a problem for me.", {"entities": []}),
    ("I've never experienced any allergy-related issues.", {"entities": []}),
    ("Allergies haven't been a concern for me.", {"entities": []}),
    ("I've never been affected by allergies.", {"entities": []}),
    ("Allergies haven't been part of my health journey.", {"entities": []}),
    ("I've never had to worry about allergies.", {"entities": []}),
    ("Allergies haven't been a concern for me.", {"entities": []}),
    ("I've never had to deal with allergies.", {"entities": []}),
    ("Allergies haven't been something I've had to face.", {"entities": []}),
    ("I've never had to think about allergies.", {"entities": []}),
    ("Allergies haven't been a problem for me.", {"entities": []}),
    ("I've never experienced any allergy-related issues.", {"entities": []}),
    ("I've never had any allergy-related symptoms.", {"entities": []}),
    ("Allergies aren't something I've ever dealt with.", {"entities": []}),
    ("I've never experienced any allergic reactions.", {"entities": []}),
    ("Allergies haven't been a concern for me.", {"entities": []}),
    ("I've never been allergic to anything.", {"entities": []}),
    ("Allergies haven't been a problem in my life.", {"entities": []}),
    ("I've never had to deal with allergies.", {"entities": []}),
    ("Allergies haven't been part of my health history.", {"entities": []}),
    ("I've never suffered from allergies.", {"entities": []}),
    ("Allergies haven't been an issue for me.", {"entities": []}),
    ("I've never had any allergic reactions.", {"entities": []}),
    ("Allergies haven't been a concern for me.", {"entities": []}),
    ("I've never had to deal with allergies.", {"entities": []}),
    ("Allergies haven't been something I've had to think about.", {"entities": []}),
    ("I've never had any allergy-related symptoms.", {"entities": []}),
    ("Allergies haven't been part of my health journey.", {"entities": []}),
    ("I've never experienced any allergic reactions.", {"entities": []}),
    ("Allergies haven't been a problem for me.", {"entities": []}),
    ("I've never been allergic to anything.", {"entities": []}),
    ("Allergies haven't been a concern in my life.", {"entities": []}),
    ("I've never had to deal with allergies.", {"entities": []}),
    ("Allergies haven't been part of my health profile.", {"entities": []}),
    ("I've never suffered from allergies.", {"entities": []}),
    ("Allergies haven't been an issue for me.", {"entities": []}),
    ("I've never had any allergic reactions.", {"entities": []}),
    ("Allergies haven't been a concern for me.", {"entities": []}),
    ("I've never had to deal with allergies.", {"entities": []}),
    ("Allergies haven't been something I've had to think about.", {"entities": []}),
    ("I've never had any allergy-related symptoms.", {"entities": []}),
    ("Allergies haven't been part of my health journey.", {"entities": []}),
    ("I've never experienced any allergic reactions.", {"entities": []}),
    ("Allergies haven't been a problem for me.", {"entities": []}),
    ("I've never been allergic to anything.", {"entities": []}),
    ("Allergies haven't been a concern in my life.", {"entities": []}),
    ("I've never had to deal with allergies.", {"entities": []}),
    ("Allergies haven't been part of my health profile.", {"entities": []}),
    ("I've never suffered from allergies.", {"entities": []}),
    ("Allergies haven't been an issue for me.", {"entities": []}),
    ("I've never had any allergic reactions.", {"entities": []}),
    ("Allergies haven't been a concern for me.", {"entities": []}),
    ("I've never had to deal with allergies.", {"entities": []}),
    ("Allergies haven't been something I've had to think about.", {"entities": []}),
    ("I've never had any allergy-related symptoms.", {"entities": []}),
    ("Allergies haven't been part of my health journey.", {"entities": []}),
    ("I've never experienced any allergic reactions.", {"entities": []}),
    ("Allergies haven't been a problem for me.", {"entities": []}),
    ("I've never been allergic to anything.", {"entities": []}),
    ("Allergies haven't been a concern in my life.", {"entities": []}),
    ("I've never had to deal with allergies.", {"entities": []}),
    ("Allergies haven't been part of my health profile.", {"entities": []}),
    ("I've never suffered from allergies.", {"entities": []}),
    ("Allergies haven't been an issue for me.", {"entities": []}),
    ("I've never had any allergic reactions.", {"entities": []}),
    ("Allergies haven't been a concern for me.", {"entities": []}),
    ("I've never had to deal with allergies.", {"entities": []}),
    ("Allergies haven't been something I've had to think about.", {"entities": []}),
    ("I've never had any allergy-related symptoms.", {"entities": []}),
    ("Allergies haven't been part of my health journey.", {"entities": []}),
    ("I've never experienced any allergic reactions.", {"entities": []}),
    ("Allergies haven't been a problem for me.", {"entities": []}),
    ("I've never been allergic to anything.", {"entities": []}),
    ("Allergies haven't been a concern in my life.", {"entities": []}),
    ("I've never had to deal with allergies.", {"entities": []}),
    ("Allergies haven't been part of my health profile.", {"entities": []}),
    ("I've never suffered from allergies.", {"entities": []}),
    ("Allergies haven't been an issue for me.", {"entities": []}),
    ("I've never had any allergic reactions.", {"entities": []}),
    ("Allergies haven't been a concern for me.", {"entities": []}),
    ("I've never had to deal with allergies.", {"entities": []}),
    ("Allergies haven't been something I've had to think about.", {"entities": []}),
    ("I've never had any allergy-related symptoms.", {"entities": []}),
    ("Allergies haven't been part of my health journey.", {"entities": []}),
    ("I've never experienced any allergic reactions.", {"entities": []}),
    ("Allergies haven't been a problem for me.", {"entities": []}),
    ("I've never been allergic to anything.", {"entities": []}),
    ("Allergies haven't been a concern in my life.", {"entities": []}),
    ("I've never had to deal with allergies.", {"entities": []}),
    ("Allergies haven't been part of my health profile.", {"entities": []}),
    ("I've never suffered from allergies.", {"entities": []}),
    ("Allergies haven't been an issue for me.", {"entities": []}),
    ("I've never had any allergic reactions.", {"entities": []}),
    ("Allergies haven't been a concern for me.", {"entities": []}),
    ("I've never had to deal with allergies.", {"entities": []}),
    ("Allergies haven't been something I've had to think about.", {"entities": []}),
    ("I've never had any allergy-related symptoms.", {"entities": []}),
    ("Allergies haven't been part of my health journey.", {"entities": []}),
    ("I've never experienced any allergic reactions.", {"entities": []}),
    ("Allergies haven't been a problem for me.", {"entities": []}),
    ("I've never been allergic to anything.", {"entities": []}),
    ("Allergies haven't been a concern in my life.", {"entities": []}),
    ("I've never had to deal with allergies.", {"entities": []}),
    ("Allergies haven't been part of my health profile.", {"entities": []}),
    ("I've never suffered from allergies.", {"entities": []}),
    ("Allergies haven't been an issue for me.", {"entities": []}),
    ("I've never had any allergic reactions.", {"entities": []}),
    ("Allergies haven't been a concern for me.", {"entities": []}),
    ("I've never had to deal with allergies.", {"entities": []}),
    ("Allergies haven't been something I've had to think about.", {"entities": []}),
    ("I've never had any allergy-related symptoms.", {"entities": []}),
    ("Allergies haven't been part of my health journey.", {"entities": []}),
    ("I've never experienced any allergic reactions.", {"entities": []}),
    ("Allergies haven't been a problem for me.", {"entities": []}),
    ("I've never been allergic to anything.", {"entities": []}),
    ("Allergies haven't been a concern in my life.", {"entities": []}),
    ("I've never had to deal with allergies.", {"entities": []}),
    ("Allergies haven't been part of my health profile.", {"entities": []}),
    ("I've never suffered from allergies.", {"entities": []}),
    ("Allergies haven't been an issue for me.", {"entities": []}),
    ("I've never had any allergic reactions.", {"entities": []}),
    ("Allergies haven't been a concern for me.", {"entities": []}),
    ("I've never had to deal with allergies.", {"entities": []}),
    ("Allergies haven't been something I've had to think about.", {"entities": []}),
    ("I've never had any allergy-related symptoms.", {"entities": []}),
    ("Allergies haven't been part of my health journey.", {"entities": []}),
    ("I've never experienced any allergic reactions.", {"entities": []}),
    ("Allergies haven't been a problem for me.", {"entities": []}),
    ("I've never been allergic to anything.", {"entities": []}),
    ("Allergies haven't been a concern in my life.", {"entities": []}),
    ("I've never had to deal with allergies.", {"entities": []}),
    ("Allergies haven't been part of my health profile.", {"entities": []}),
    ("I've never suffered from allergies.", {"entities": []}),
    ("Allergies haven't been an issue for me.", {"entities": []}),
    ("I've never had any allergic reactions.", {"entities": []}),
    ("Allergies haven't been a concern for me.", {"entities": []}),
    ("I've never had to deal with allergies.", {"entities": []}),
    ("Allergies haven't been something I've had to think about.", {"entities": []}),
    ("I've never had any allergy-related symptoms.", {"entities": []}),
    ("Allergies haven't been part of my health journey.", {"entities": []}),
    ("I've never experienced any allergic reactions.", {"entities": []}),
    ("Allergies haven't been a problem for me.", {"entities": []}),
    ("I've never been allergic to anything.", {"entities": []}),
    ("Allergies haven't been a concern in my life.", {"entities": []}),
    ("I've never had to deal with allergies.", {"entities": []}),
    ("Allergies haven't been part of my health profile.", {"entities": []}),
    ("I've never suffered from allergies.", {"entities": []}),
    ("Allergies haven't been an issue for me.", {"entities": []}),
    ("I've never had any allergic reactions.", {"entities": []}),
    ("Allergies haven't been a concern for me.", {"entities": []}),
    ("I've never had to deal with allergies.", {"entities": []}),
    ("Allergies haven't been something I've had to think about.", {"entities": []}),
]

# %%
EVAL_DATA = [
    ("I'm allergic to peanuts.", {"entities": [(13, 20, "ALLERGY")]}),
    ("I'm allergic to cats and dust mites.", {"entities": [(13, 16, "ALLERGY"), (21, 31, "ALLERGY")]}),
    ("I have hay fever.", {"entities": [(9, 17, "ALLERGY")]}),
    ("I'm allergic to shellfish.", {"entities": [(13, 22, "ALLERGY")]}),
    ("I'm allergic to pollen and grass.", {"entities": [(13, 19, "ALLERGY"), (24, 29, "ALLERGY")]}),
    ("I have a gluten intolerance.", {"entities": [(10, 17, "ALLERGY")]}),
    ("I'm allergic to milk.", {"entities": [(13, 17, "ALLERGY")]}),
    ("I'm allergic to latex and bananas.", {"entities": [(13, 18, "ALLERGY"), (23, 30, "ALLERGY")]}),
    ("I have a seafood allergy.", {"entities": [(10, 17, "ALLERGY")]}),
    ("I'm allergic to dogs.", {"entities": [(13, 16, "ALLERGY")]}),
    ("I'm allergic to ragweed pollen.", {"entities": [(13, 20, "ALLERGY"), (21, 26, "ALLERGY")]}),
    ("I have lactose intolerance.", {"entities": [(10, 26, "ALLERGY")]}),
    ("I'm allergic to peanuts, tree nuts, and soy.", {"entities": [(13, 20, "ALLERGY"), (22, 31, "ALLERGY"), (36, 39, "ALLERGY")]}),
    ("I'm allergic to bee stings.", {"entities": [(13, 22, "ALLERGY")]}),
    ("I'm allergic to shellfish and peanuts.", {"entities": [(13, 22, "ALLERGY"), (27, 34, "ALLERGY")]}),
    ("I have asthma triggered by dust mites.", {"entities": [(10, 16, "ALLERGY"), (28, 38, "ALLERGY")]}),
    ("I'm allergic to mold and pollen.", {"entities": [(13, 17, "ALLERGY"), (22, 28, "ALLERGY")]}),
    ("I'm allergic to dairy products.", {"entities": [(13, 18, "ALLERGY")]}),
    ("I have a sesame allergy.", {"entities": [(10, 16, "ALLERGY")]}),
    ("I'm allergic to eggs and soy.", {"entities": [(13, 17, "ALLERGY"), (22, 25, "ALLERGY")]}),
    ("I'm allergic to shellfish and fish.", {"entities": [(13, 22, "ALLERGY"), (27, 31, "ALLERGY")]}),
    ("I'm allergic to peanuts and milk.", {"entities": [(13, 20, "ALLERGY"), (25, 29, "ALLERGY")]}),
    ("I'm allergic to pollen, grass, and mold.", {"entities": [(13, 19, "ALLERGY"), (21, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("I have hay fever and asthma.", {"entities": [(9, 17, "ALLERGY"), (22, 28, "ALLERGY")]}),
    ("I'm allergic to peanuts, tree nuts, and shellfish.", {"entities": [(13, 20, "ALLERGY"), (22, 31, "ALLERGY"), (36, 45, "ALLERGY")]}),
    ("I have a wheat allergy.", {"entities": [(10, 15, "ALLERGY")]}),
    ("I'm allergic to penicillin.", {"entities": [(13, 23, "ALLERGY")]}),
    ("I'm allergic to bee stings and peanuts.", {"entities": [(13, 22, "ALLERGY"), (27, 34, "ALLERGY")]}),
    ("I'm allergic to pollen, dust, and mold.", {"entities": [(13, 19, "ALLERGY"), (21, 25, "ALLERGY"), (30, 34, "ALLERGY")]}),
    ("I'm allergic to tree nuts and peanuts.", {"entities": [(13, 22, "ALLERGY"), (27, 34, "ALLERGY")]}),
    ("I have hay fever, asthma, and eczema.", {"entities": [(9, 17, "ALLERGY"), (19, 25, "ALLERGY"), (30, 36, "ALLERGY")]}),
    ("I'm allergic to cats, dogs, and dust mites.", {"entities": [(13, 16, "ALLERGY"), (18, 21, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("I have a gluten allergy and lactose intolerance.", {"entities": [(10, 15, "ALLERGY"), (20, 36, "ALLERGY")]}),
    ("I'm allergic to shellfish and fish.", {"entities": [(13, 22, "ALLERGY"), (27, 31, "ALLERGY")]}),
    ("I'm allergic to pollen, grass, and mold.", {"entities": [(13, 19, "ALLERGY"), (21, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("I'm allergic to latex and bananas.", {"entities": [(13, 18, "ALLERGY"), (23, 30, "ALLERGY")]}),
    ("I have hay fever and asthma.", {"entities": [(9, 17, "ALLERGY"), (22, 28, "ALLERGY")]}),
    ("I'm allergic to peanuts, tree nuts, and shellfish.", {"entities": [(13, 20, "ALLERGY"), (22, 31, "ALLERGY"), (36, 45, "ALLERGY")]}),
    ("I have a wheat allergy.", {"entities": [(10, 15, "ALLERGY")]}),
    ("I'm allergic to penicillin.", {"entities": [(13, 23, "ALLERGY")]}),
    ("I'm allergic to bee stings and peanuts.", {"entities": [(13, 22, "ALLERGY"), (27, 34, "ALLERGY")]}),
    ("I'm allergic to pollen, dust, and mold.", {"entities": [(13, 19, "ALLERGY"), (21, 25, "ALLERGY"), (30, 34, "ALLERGY")]}),
    ("I'm allergic to tree nuts and peanuts.", {"entities": [(13, 22, "ALLERGY"), (27, 34, "ALLERGY")]}),
    ("I have hay fever, asthma, and eczema.", {"entities": [(9, 17, "ALLERGY"), (19, 25, "ALLERGY"), (30, 36, "ALLERGY")]}),
    ("I have a soy allergy.", {"entities": [(10, 13, "ALLERGY")]}),
    ("I'm allergic to pollen and peanuts.", {"entities": [(13, 19, "ALLERGY"), (24, 31, "ALLERGY")]}),
    ("I'm allergic to dairy and gluten.", {"entities": [(13, 18, "ALLERGY"), (23, 29, "ALLERGY")]}),
    ("I have hay fever and pet allergies.", {"entities": [(9, 17, "ALLERGY"), (22, 34, "ALLERGY")]}),
    ("I'm allergic to shellfish and eggs.", {"entities": [(13, 22, "ALLERGY"), (27, 31, "ALLERGY")]}),
    ("I'm allergic to peanuts and tree nuts.", {"entities": [(13, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to milk and soy.", {"entities": [(13, 17, "ALLERGY"), (22, 25, "ALLERGY")]}),
    ("I have a wheat allergy and lactose intolerance.", {"entities": [(10, 15, "ALLERGY"), (20, 36, "ALLERGY")]}),
    ("I'm allergic to bee stings and shellfish.", {"entities": [(13, 22, "ALLERGY"), (27, 36, "ALLERGY")]}),
    ("I'm allergic to latex and kiwi.", {"entities": [(13, 18, "ALLERGY"), (23, 27, "ALLERGY")]}),
    ("I'm allergic to grass pollen and dust mites.", {"entities": [(13, 24, "ALLERGY"), (29, 39, "ALLERGY")]}),
    ("I'm allergic to peanuts, eggs, and dairy.", {"entities": [(13, 20, "ALLERGY"), (22, 26, "ALLERGY"), (31, 36, "ALLERGY")]}),
    ("I have hay fever and ragweed allergy.", {"entities": [(9, 17, "ALLERGY"), (22, 35, "ALLERGY")]}),
    ("I'm allergic to shellfish, tree nuts, and dairy.", {"entities": [(13, 22, "ALLERGY"), (24, 33, "ALLERGY"), (38, 43, "ALLERGY")]}),
    ("I'm allergic to cats, dogs, and pollen.", {"entities": [(13, 16, "ALLERGY"), (18, 21, "ALLERGY"), (26, 32, "ALLERGY")]}),
    ("I'm allergic to gluten and soy.", {"entities": [(13, 18, "ALLERGY"), (23, 26, "ALLERGY")]}),
    ("I have asthma and a dust mite allergy.", {"entities": [(10, 16, "ALLERGY"), (25, 36, "ALLERGY")]}),
    ("I'm allergic to peanuts, milk, and eggs.", {"entities": [(13, 20, "ALLERGY"), (22, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("I'm allergic to latex, bananas, and avocados.", {"entities": [(13, 18, "ALLERGY"), (23, 30, "ALLERGY"), (35, 43, "ALLERGY")]}),
    ("I'm allergic to shellfish and fish.", {"entities": [(13, 22, "ALLERGY"), (27, 31, "ALLERGY")]}),
    ("I'm allergic to pollen, grass, and mold.", {"entities": [(13, 19, "ALLERGY"), (21, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("I'm allergic to tree nuts and peanuts.", {"entities": [(13, 22, "ALLERGY"), (27, 34, "ALLERGY")]}),
    ("I have hay fever, asthma, and eczema.", {"entities": [(9, 17, "ALLERGY"), (19, 25, "ALLERGY"), (30, 36, "ALLERGY")]}),
    ("I'm allergic to cats, dogs, and dust mites.", {"entities": [(13, 16, "ALLERGY"), (18, 21, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("I have a gluten allergy and lactose intolerance.", {"entities": [(10, 15, "ALLERGY"), (20, 36, "ALLERGY")]}),
    ("I'm allergic to shellfish and fish.", {"entities": [(13, 22, "ALLERGY"), (27, 31, "ALLERGY")]}),
    ("I'm allergic to pollen, dust, and mold.", {"entities": [(13, 19, "ALLERGY"), (21, 25, "ALLERGY"), (30, 34, "ALLERGY")]}),
    ("I'm allergic to tree nuts and peanuts.", {"entities": [(13, 22, "ALLERGY"), (27, 34, "ALLERGY")]}),
    ("I have hay fever, asthma, and eczema.", {"entities": [(9, 17, "ALLERGY"), (19, 25, "ALLERGY"), (30, 36, "ALLERGY")]}),
    ("I'm allergic to cats, dogs, and dust mites.", {"entities": [(13, 16, "ALLERGY"), (18, 21, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("I have a gluten allergy and lactose intolerance.", {"entities": [(10, 15, "ALLERGY"), (20, 36, "ALLERGY")]}),
    ("I'm allergic to shellfish and fish.", {"entities": [(13, 22, "ALLERGY"), (27, 31, "ALLERGY")]}),
    ("I'm allergic to pollen, dust, and mold.", {"entities": [(13, 19, "ALLERGY"), (21, 25, "ALLERGY"), (30, 34, "ALLERGY")]}),
    ("I'm allergic to tree nuts and peanuts.", {"entities": [(13, 22, "ALLERGY"), (27, 34, "ALLERGY")]}),
    ("I have hay fever, asthma, and eczema.", {"entities": [(9, 17, "ALLERGY"), (19, 25, "ALLERGY"), (30, 36, "ALLERGY")]}),
    ("I'm allergic to cats, dogs, and dust mites.", {"entities": [(13, 16, "ALLERGY"), (18, 21, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("I have a gluten allergy and lactose intolerance.", {"entities": [(10, 15, "ALLERGY"), (20, 36, "ALLERGY")]}),
    ("I'm allergic to shellfish and fish.", {"entities": [(13, 22, "ALLERGY"), (27, 31, "ALLERGY")]}),
    ("He suffers from a peanut allergy.", {"entities": [(18, 25, "ALLERGY")]}),
    ("She is allergic to cats and dust mites.", {"entities": [(18, 21, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has hay fever.", {"entities": [(7, 15, "ALLERGY")]}),
    ("She is allergic to shellfish.", {"entities": [(18, 27, "ALLERGY")]}),
    ("He is allergic to pollen and grass.", {"entities": [(18, 24, "ALLERGY"), (29, 34, "ALLERGY")]}),
    ("She has a gluten intolerance.", {"entities": [(7, 14, "ALLERGY")]}),
    ("He is allergic to milk.", {"entities": [(18, 22, "ALLERGY")]}),
    ("She is allergic to latex and bananas.", {"entities": [(18, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("He has a seafood allergy.", {"entities": [(7, 14, "ALLERGY")]}),
    ("She is allergic to dogs.", {"entities": [(18, 21, "ALLERGY")]}),
    ("He is allergic to ragweed pollen.", {"entities": [(18, 25, "ALLERGY")]}),
    ("She has lactose intolerance.", {"entities": [(7, 23, "ALLERGY")]}),
    ("He is allergic to peanuts, tree nuts, and soy.", {"entities": [(18, 25, "ALLERGY"), (27, 36, "ALLERGY"), (41, 44, "ALLERGY")]}),
    ("She is allergic to bee stings.", {"entities": [(18, 27, "ALLERGY")]}),
    ("He is allergic to shellfish and peanuts.", {"entities": [(18, 27, "ALLERGY"), (32, 39, "ALLERGY")]}),
    ("She has asthma triggered by dust mites.", {"entities": [(7, 13, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("He is allergic to mold and pollen.", {"entities": [(18, 22, "ALLERGY"), (27, 33, "ALLERGY")]}),
    ("She is allergic to dairy products.", {"entities": [(18, 23, "ALLERGY")]}),
    ("He has a sesame allergy.", {"entities": [(7, 13, "ALLERGY")]}),
    ("She is allergic to eggs and soy.", {"entities": [(18, 22, "ALLERGY"), (27, 30, "ALLERGY")]}),
    ("He is allergic to shellfish and fish.", {"entities": [(18, 27, "ALLERGY"), (32, 36, "ALLERGY")]}),
    ("She is allergic to peanuts and milk.", {"entities": [(18, 25, "ALLERGY"), (30, 34, "ALLERGY")]}),
    ("He is allergic to pollen, grass, and mold.", {"entities": [(18, 24, "ALLERGY"), (26, 31, "ALLERGY"), (36, 40, "ALLERGY")]}),
    ("She has hay fever and asthma.", {"entities": [(7, 15, "ALLERGY"), (20, 26, "ALLERGY")]}),
    ("He is allergic to peanuts, tree nuts, and shellfish.", {"entities": [(18, 25, "ALLERGY"), (27, 36, "ALLERGY"), (41, 50, "ALLERGY")]}),
    ("She has a wheat allergy.", {"entities": [(7, 12, "ALLERGY")]}),
    ("He is allergic to penicillin.", {"entities": [(18, 28, "ALLERGY")]}),
    ("She is allergic to bee stings and peanuts.", {"entities": [(18, 27, "ALLERGY"), (32, 39, "ALLERGY")]}),
    ("He is allergic to pollen, dust, and mold.", {"entities": [(18, 24, "ALLERGY"), (26, 30, "ALLERGY"), (35, 39, "ALLERGY")]}),
    ("She is allergic to tree nuts and peanuts.", {"entities": [(18, 27, "ALLERGY"), (32, 39, "ALLERGY")]}),
    ("He has hay fever, asthma, and eczema.", {"entities": [(7, 15, "ALLERGY"), (17, 23, "ALLERGY"), (28, 34, "ALLERGY")]}),
    ("She is allergic to cats, dogs, and dust mites.", {"entities": [(18, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 41, "ALLERGY")]}),
    ("He has a gluten allergy and lactose intolerance.", {"entities": [(7, 12, "ALLERGY"), (17, 33, "ALLERGY")]}),
    ("She is allergic to shellfish and fish.", {"entities": [(18, 27, "ALLERGY"), (32, 36, "ALLERGY")]}),
    ("He is allergic to pollen, dust, and mold.", {"entities": [(18, 24, "ALLERGY"), (26, 30, "ALLERGY"), (35, 39, "ALLERGY")]}),
    ("She is allergic to tree nuts and peanuts.", {"entities": [(18, 27, "ALLERGY"), (32, 39, "ALLERGY")]}),
    ("He has hay fever, asthma, and eczema.", {"entities": [(7, 15, "ALLERGY"), (17, 23, "ALLERGY"), (28, 34, "ALLERGY")]}),
    ("She is allergic to cats, dogs, and dust mites.", {"entities": [(18, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 41, "ALLERGY")]}),
    ("He has a gluten allergy and lactose intolerance.", {"entities": [(7, 12, "ALLERGY"), (17, 33, "ALLERGY")]}),
    ("She is allergic to shellfish and fish.", {"entities": [(18, 27, "ALLERGY"), (32, 36, "ALLERGY")]}),
    ("He is allergic to pollen, dust, and mold.", {"entities": [(18, 24, "ALLERGY"), (26, 30, "ALLERGY"), (35, 39, "ALLERGY")]}),
    ("She is allergic to tree nuts and peanuts.", {"entities": [(18, 27, "ALLERGY"), (32, 39, "ALLERGY")]}),
    ("He has hay fever, asthma, and eczema.", {"entities": [(7, 15, "ALLERGY"), (17, 23, "ALLERGY"), (28, 34, "ALLERGY")]}),
    ("He suffers from a peanut allergy.", {"entities": [(18, 25, "ALLERGY")]}),
    ("She is allergic to cats and dust mites.", {"entities": [(18, 21, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("He has hay fever.", {"entities": [(7, 15, "ALLERGY")]}),
    ("She is allergic to shellfish.", {"entities": [(18, 27, "ALLERGY")]}),
    ("He is allergic to pollen and grass.", {"entities": [(18, 24, "ALLERGY"), (29, 34, "ALLERGY")]}),
    ("She has a gluten intolerance.", {"entities": [(7, 14, "ALLERGY")]}),
    ("He is allergic to milk.", {"entities": [(18, 22, "ALLERGY")]}),
    ("She is allergic to latex and bananas.", {"entities": [(18, 23, "ALLERGY"), (28, 32, "ALLERGY")]}),
    ("He has a seafood allergy.", {"entities": [(7, 14, "ALLERGY")]}),
    ("She is allergic to dogs.", {"entities": [(18, 21, "ALLERGY")]}),
    ("He is allergic to ragweed pollen.", {"entities": [(18, 25, "ALLERGY")]}),
    ("She has lactose intolerance.", {"entities": [(7, 23, "ALLERGY")]}),
    ("He is allergic to peanuts, tree nuts, and soy.", {"entities": [(18, 25, "ALLERGY"), (27, 36, "ALLERGY"), (41, 44, "ALLERGY")]}),
    ("She is allergic to bee stings.", {"entities": [(18, 27, "ALLERGY")]}),
    ("He is allergic to shellfish and peanuts.", {"entities": [(18, 27, "ALLERGY"), (32, 39, "ALLERGY")]}),
    ("She has asthma triggered by dust mites.", {"entities": [(7, 13, "ALLERGY"), (25, 35, "ALLERGY")]}),
    ("He is allergic to mold and pollen.", {"entities": [(18, 22, "ALLERGY"), (27, 33, "ALLERGY")]}),
    ("She is allergic to dairy products.", {"entities": [(18, 23, "ALLERGY")]}),
    ("He has a sesame allergy.", {"entities": [(7, 13, "ALLERGY")]}),
    ("She is allergic to eggs and soy.", {"entities": [(18, 22, "ALLERGY"), (27, 30, "ALLERGY")]}),
    ("He is allergic to shellfish and fish.", {"entities": [(18, 27, "ALLERGY"), (32, 36, "ALLERGY")]}),
    ("She is allergic to peanuts and milk.", {"entities": [(18, 25, "ALLERGY"), (30, 34, "ALLERGY")]}),
    ("He is allergic to pollen, grass, and mold.", {"entities": [(18, 24, "ALLERGY"), (26, 31, "ALLERGY"), (36, 40, "ALLERGY")]}),
    ("She has hay fever and asthma.", {"entities": [(7, 15, "ALLERGY"), (20, 26, "ALLERGY")]}),
    ("He is allergic to peanuts, tree nuts, and shellfish.", {"entities": [(18, 25, "ALLERGY"), (27, 36, "ALLERGY"), (41, 50, "ALLERGY")]}),
    ("She has a wheat allergy.", {"entities": [(7, 12, "ALLERGY")]}),
    ("He is allergic to penicillin.", {"entities": [(18, 28, "ALLERGY")]}),
    ("She is allergic to bee stings and peanuts.", {"entities": [(18, 27, "ALLERGY"), (32, 39, "ALLERGY")]}),
    ("He is allergic to pollen, dust, and mold.", {"entities": [(18, 24, "ALLERGY"), (26, 30, "ALLERGY"), (35, 39, "ALLERGY")]}),
    ("She is allergic to tree nuts and peanuts.", {"entities": [(18, 27, "ALLERGY"), (32, 39, "ALLERGY")]}),
    ("He has hay fever, asthma, and eczema.", {"entities": [(7, 15, "ALLERGY"), (17, 23, "ALLERGY"), (28, 34, "ALLERGY")]}),
    ("She is allergic to cats, dogs, and dust mites.", {"entities": [(18, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 41, "ALLERGY")]}),
    ("He has a gluten allergy and lactose intolerance.", {"entities": [(7, 12, "ALLERGY"), (17, 33, "ALLERGY")]}),
    ("She is allergic to shellfish and fish.", {"entities": [(18, 27, "ALLERGY"), (32, 36, "ALLERGY")]}),
    ("He is allergic to pollen, dust, and mold.", {"entities": [(18, 24, "ALLERGY"), (26, 30, "ALLERGY"), (35, 39, "ALLERGY")]}),
    ("She is allergic to tree nuts and peanuts.", {"entities": [(18, 27, "ALLERGY"), (32, 39, "ALLERGY")]}),
    ("He has hay fever, asthma, and eczema.", {"entities": [(7, 15, "ALLERGY"), (17, 23, "ALLERGY"), (28, 34, "ALLERGY")]}),
    ("She is allergic to cats, dogs, and dust mites.", {"entities": [(18, 21, "ALLERGY"), (23, 26, "ALLERGY"), (31, 41, "ALLERGY")]}),
    ("He has a gluten allergy and lactose intolerance.", {"entities": [(7, 12, "ALLERGY"), (17, 33, "ALLERGY")]}),
    ("She is allergic to shellfish and fish.", {"entities": [(18, 27, "ALLERGY"), (32, 36, "ALLERGY")]}),
    ("He is allergic to pollen, dust, and mold.", {"entities": [(18, 24, "ALLERGY"), (26, 30, "ALLERGY"), (35, 39, "ALLERGY")]}),
    ("She is allergic to tree nuts and peanuts.", {"entities": [(18, 27, "ALLERGY"), (32, 39, "ALLERGY")]}),
    ("He has hay fever, asthma, and eczema.", {"entities": [(7, 15, "ALLERGY"), (17, 23, "ALLERGY"), (28, 34, "ALLERGY")]}),
    ("I'm allergic to strawberries.", {"entities": [(13, 24, "ALLERGY")]}),
    ("I have a peanut allergy.", {"entities": [(10, 16, "ALLERGY")]}),
    ("I suffer from cat allergies.", {"entities": [(17, 28, "ALLERGY")]}),
    ("I'm allergic to shellfish.", {"entities": [(13, 22, "ALLERGY")]}),
    ("I'm allergic to pollen.", {"entities": [(13, 19, "ALLERGY")]}),
    ("I have a dairy intolerance.", {"entities": [(10, 26, "ALLERGY")]}),
    ("I'm allergic to soy.", {"entities": [(13, 16, "ALLERGY")]}),
    ("I'm allergic to latex.", {"entities": [(13, 17, "ALLERGY")]}),
    ("I suffer from dust mite allergies.", {"entities": [(17, 28, "ALLERGY")]}),
    ("I'm allergic to tree nuts.", {"entities": [(13, 22, "ALLERGY")]}),
    ("I'm allergic to ragweed pollen.", {"entities": [(13, 20, "ALLERGY")]}),
    ("I have a seafood allergy.", {"entities": [(10, 17, "ALLERGY")]}),
    ("I'm allergic to eggs.", {"entities": [(13, 17, "ALLERGY")]}),
    ("I'm allergic to bananas.", {"entities": [(13, 20, "ALLERGY")]}),
    ("I'm allergic to bee stings.", {"entities": [(13, 22, "ALLERGY")]}),
    ("I have a wheat allergy.", {"entities": [(10, 15, "ALLERGY")]}),
    ("I'm allergic to penicillin.", {"entities": [(13, 23, "ALLERGY")]}),
    ("I'm allergic to kiwi.", {"entities": [(13, 17, "ALLERGY")]}),
    ("I'm allergic to grass.", {"entities": [(13, 18, "ALLERGY")]}),
    ("I have a sesame allergy.", {"entities": [(10, 16, "ALLERGY")]}),
    ("I'm allergic to shellfish.", {"entities": [(13, 22, "ALLERGY")]}),
    ("I'm allergic to fish.", {"entities": [(13, 17, "ALLERGY")]}),
    ("I'm allergic to mold.", {"entities": [(13, 17, "ALLERGY")]}),
    ("I'm allergic to peanuts and soy.", {"entities": [(13, 20, "ALLERGY"), (25, 28, "ALLERGY")]}),
    ("I have a dust allergy.", {"entities": [(10, 20, "ALLERGY")]}),
    ("I'm allergic to strawberries and bananas.", {"entities": [(13, 24, "ALLERGY"), (29, 36, "ALLERGY")]}),
    ("I'm allergic to milk and eggs.", {"entities": [(13, 17, "ALLERGY"), (22, 26, "ALLERGY")]}),
    ("I'm allergic to seafood and shellfish.", {"entities": [(13, 20, "ALLERGY"), (25, 34, "ALLERGY")]}),
    ("I'm allergic to pollen and grass.", {"entities": [(13, 19, "ALLERGY"), (24, 29, "ALLERGY")]}),
    ("I have a gluten allergy.", {"entities": [(10, 15, "ALLERGY")]}),
    ("I'm allergic to cats and dogs.", {"entities": [(13, 16, "ALLERGY"), (21, 25, "ALLERGY")]}),
    ("I'm allergic to tree nuts and peanuts.", {"entities": [(13, 22, "ALLERGY"), (27, 34, "ALLERGY")]}),
    ("I'm allergic to ragweed pollen and mold.", {"entities": [(13, 20, "ALLERGY"), (25, 29, "ALLERGY")]}),
    ("I have hay fever and asthma.", {"entities": [(10, 18, "ALLERGY"), (23, 29, "ALLERGY")]}),
    ("I'm allergic to shellfish and fish.", {"entities": [(13, 22, "ALLERGY"), (27, 31, "ALLERGY")]}),
    ("I'm allergic to peanuts and milk.", {"entities": [(13, 20, "ALLERGY"), (25, 29, "ALLERGY")]}),
    ("I'm allergic to pollen, grass, and mold.", {"entities": [(13, 19, "ALLERGY"), (21, 26, "ALLERGY"), (31, 35, "ALLERGY")]}),
    ("I'm allergic to latex and bananas.", {"entities": [(13, 18, "ALLERGY"), (23, 30, "ALLERGY")]}),
    ("I have hay fever and asthma.", {"entities": [(10, 18, "ALLERGY"), (23, 29, "ALLERGY")]}),
    ("I'm allergic to peanuts, tree nuts, and shellfish.", {"entities": [(13, 20, "ALLERGY"), (22, 31, "ALLERGY"), (36, 45, "ALLERGY")]}),
    ("I have a wheat allergy.", {"entities": [(10, 15, "ALLERGY")]}),
    ("I'm allergic to penicillin.", {"entities": [(13, 23, "ALLERGY")]}),
    ("I'm allergic to bee stings and peanuts.", {"entities": [(13, 22, "ALLERGY"), (27, 34, "ALLERGY")]}),
    ("I'm allergic to pollen, dust, and mold.", {"entities": [(13, 19, "ALLERGY"), (21, 25, "ALLERGY"), (30, 34, "ALLERGY")]}),
    ("I'm allergic to tree nuts and peanuts.", {"entities": [(13, 22, "ALLERGY"), (27, 34, "ALLERGY")]}),
    ("I have hay fever, asthma, and eczema.", {"entities": [(10, 18, "ALLERGY"), (23, 29, "ALLERGY"), (34, 40, "ALLERGY")]}),
    ("I'm allergic to cats, dogs, and dust mites.", {"entities": [(13, 16, "ALLERGY"), (18, 21, "ALLERGY"), (26, 36, "ALLERGY")]}),
    ("I have a gluten allergy and lactose intolerance.", {"entities": [(10, 15, "ALLERGY"), (20, 36, "ALLERGY")]}),
    ("I'm allergic to shellfish and fish.", {"entities": [(13, 22, "ALLERGY"), (27, 31, "ALLERGY")]})
]

# %% [markdown]
# # Preprocessing Data

# %%
# !pip install transformers torch
from transformers import AutoTokenizer, AutoModelForTokenClassification, TrainingArguments, Trainer
import torch
import numpy as np

model_name = "dmis-lab/biobert-v1.1"
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
# Define the label to id and id to label mappings
label2id = {"O": 0, "B-ALLERGY": 1, "I-ALLERGY": 2}
id2label = {0: "O", 1: "B-ALLERGY", 2: "I-ALLERGY"}

# %%
def tokenize_and_align_labels(tokenizer, data, label2id):
    tokenized_inputs = tokenizer([text for text, _ in data], padding=True, truncation=True, return_tensors="pt")
    labels = []

    for i, (_, annotations) in enumerate(data):
        word_ids = tokenized_inputs.word_ids(batch_index=i)
        label_array = np.ones(len(word_ids), dtype=int) * label2id["O"]  # Initialize all labels to "O"

        entities = annotations['entities']
        for start_char, end_char, label in entities:
            entity_tokens_range = (tokenized_inputs.char_to_token(i, start_char), tokenized_inputs.char_to_token(i, end_char - 1))
            if None not in entity_tokens_range:
                start_token, end_token = entity_tokens_range
                label_array[start_token] = label2id[f"B-{label}"]  # Begin label
                for token_index in range(start_token + 1, end_token + 1):
                    label_array[token_index] = label2id[f"I-{label}"]  # Inside label

        labels.append(label_array.tolist())

    tokenized_inputs["labels"] = torch.tensor(labels)
    return tokenized_inputs

# %%
# Tokenize and align labels
tokenized_and_aligned_data = tokenize_and_align_labels(tokenizer, TRAIN_DATA, label2id)

# %%
from torch.utils.data import Dataset

class NERDataset(Dataset):
    def __init__(self, tokenized_data):
        self.input_ids = tokenized_data["input_ids"]
        self.attention_mask = tokenized_data["attention_mask"]
        self.labels = tokenized_data["labels"]

    def __len__(self):
        return self.labels.size(0)

    def __getitem__(self, idx):
        return {
            "input_ids": self.input_ids[idx],
            "attention_mask": self.attention_mask[idx],
            "labels": self.labels[idx]
        }

dataset = NERDataset(tokenized_and_aligned_data)

# %%
model = AutoModelForTokenClassification.from_pretrained(model_name, num_labels=len(label2id))
# Out:
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at dmis-lab/biobert-v1.1 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from transformers import get_linear_schedule_with_warmup
from transformers import TrainingArguments
from transformers import EarlyStoppingCallback

from transformers import TrainingArguments
from transformers import EarlyStoppingCallback

# Define early stopping callback
early_stopping = EarlyStoppingCallback(early_stopping_patience=2)

# Training arguments with early stopping
training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=12,
    per_device_train_batch_size=16,
    warmup_steps=500,
    weight_decay=0.01,
    logging_dir='./logs',
    logging_steps=10,
)

# Trainer initialization with early stopping callback
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=TRAIN_DATA,
    callbacks=[early_stopping],
)

# %%
from transformers import Trainer

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset,
    #eval_dataset=validation_dataset,  # Add this line if you have a validation dataset
)

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='3636' max='3636' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3636/3636 2:02:30, Epoch 12/12]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>1.120100</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.025800</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.834600</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.554900</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.293900</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.185000</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.155700</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.147400</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.124000</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# # Setting up evaluation etc

# %%
eval_tokenized_and_aligned = tokenize_and_align_labels(tokenizer, EVAL_DATA, label2id)

# %%
eval_dataset = NERDataset(eval_tokenized_and_aligned)

# %%
evaluation_results = trainer.evaluate(eval_dataset)
print(evaluation_results)
# Out:
#     <div>
#
#       <progress value='28' max='28' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [28/28 00:04]
#     </div>
# {'eval_loss': 0.7576732039451599, 'eval_runtime': 5.001, 'eval_samples_per_second': 43.391, 'eval_steps_per_second': 5.599, 'epoch': 12.0}

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
model_path = r"/content/drive/My Drive/Team_Project_Allergies"

# Save the model
model.save_pretrained(model_path)

# Save the tokenizer
tokenizer.save_pretrained(model_path)
# Out:
# ('/content/drive/My Drive/Team_Project_Allergies/tokenizer_config.json',
#  '/content/drive/My Drive/Team_Project_Allergies/special_tokens_map.json',
#  '/content/drive/My Drive/Team_Project_Allergies/vocab.txt',
#  '/content/drive/My Drive/Team_Project_Allergies/added_tokens.json',
#  '/content/drive/My Drive/Team_Project_Allergies/tokenizer.json')

# %%
# To reload later
#from transformers import AutoModelForTokenClassification, AutoTokenizer

#model_path = "/content/drive/My Drive/Team Project"
#model = AutoModelForTokenClassification.from_pretrained(model_path)
#tokenizer = AutoTokenizer.from_pretrained(model_path)

# %%
# Example text
text = "I have an allergy of ibuprofen"

# Tokenize text and convert to torch tensor
inputs = tokenizer(text, return_tensors="pt")

# Perform inference
with torch.no_grad():
    outputs = model(**inputs)

# Process the model output to get predicted entities
logits = outputs.logits
predictions = logits.argmax(-1).squeeze().tolist()

# Mapping predictions to entity labels
predicted_labels = [id2label[label] for label in predictions]

# Combine tokens with their labels
tokens = tokenizer.convert_ids_to_tokens(inputs["input_ids"].squeeze().tolist())
labeled_tokens = list(zip(tokens, predicted_labels))

def aggregate_entities(tokens, predicted_labels):
    entities = []
    current_entity = []
    current_label = None

    for token, label in zip(tokens, predicted_labels):
        # Skip special tokens
        if token in ["[CLS]", "[SEP]"]:
            continue

        # Handle subword tokens
        if token.startswith("##"):
            if current_entity:
                current_entity[-1] += token[2:]  # Merge with the previous token
            continue

        # Process BIO tags
        if label.startswith("B-"):
            if current_entity:  # Save the previous entity
                entities.append((current_label, " ".join(current_entity)))
            current_entity = [token]
            current_label = label[2:]  # Remove the BIO prefix
        elif label.startswith("I-") and current_label == label[2:]:
            current_entity.append(token)
        else:  # O or different entity
            if current_entity:  # Save the previous entity
                entities.append((current_label, " ".join(current_entity)))
                current_entity = []
                current_label = None

    # Catch any remaining entity
    if current_entity:
        entities.append((current_label, " ".join(current_entity)))

    return entities

# Assuming tokens and predicted_labels are defined
entities = aggregate_entities(tokens, predicted_labels)
for label, entity in entities:
    print(f"{label}: {entity}")


#im allergic to cats and dogs
# Out:
# ALLERGY: of ibuprofen

# %%
print(predicted_labels)
# Out:
# ['O', 'O', 'O', 'O', 'B-ALLERGY', 'I-ALLERGY', 'I-ALLERGY', 'I-ALLERGY', 'I-ALLERGY', 'O', 'O', 'O', 'O', 'B-ALLERGY', 'B-ALLERGY', 'I-ALLERGY', 'O', 'O', 'O', 'B-ALLERGY', 'I-ALLERGY', 'I-ALLERGY', 'O']

# %%
for token, label in zip(tokens, predicted_labels):
    print(f"{token}: {label}")
# Out:
# [CLS]: O
# I: O
# ##M: O
# all: O
# ##ergic: O
# to: B-ALLERGY
# wheat: I-ALLERGY
# [SEP]: O
