# %%
# !pip install transformers torch
# !pip install transformers[torch]
# !pip install accelerate -U

# %% [markdown]
# # Data

# %%
TRAIN_DATA = [
    ("I smoke and drink occasionally, but I exercise regularly.", {"entities": [(2, 7, "LIFESTYLE"), (12, 18, "LIFESTYLE"), (25, 42, "LIFESTYLE")]}),
    ("I'm vegan and exercise daily, but I occasionally drink alcohol.", {"entities": [(4, 9, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (32, 42, "LIFESTYLE")]}),
    ("I used to engage in drug use, but now I focus on exercising and following a vegetarian diet.", {"entities": [(19, 28, "LIFESTYLE"), (39, 52, "LIFESTYLE"), (65, 75, "LIFESTYLE")]}),
    ("I enjoy moderate drinking and exercise regularly, but I'm also vegetarian.", {"entities": [(7, 24, "LIFESTYLE"), (31, 46, "LIFESTYLE"), (57, 68, "LIFESTYLE")]}),
    ("I'm vegan, but I occasionally smoke and drink. I also make sure to exercise regularly.", {"entities": [(4, 9, "LIFESTYLE"), (32, 38, "LIFESTYLE"), (44, 50, "LIFESTYLE"), (69, 86, "LIFESTYLE")]}),
    ("I exercise daily and follow a halal diet, but I'm also a social drinker.", {"entities": [(2, 10, "LIFESTYLE"), (29, 39, "LIFESTYLE"), (46, 60, "LIFESTYLE")]}),
    ("I'm vegetarian and exercise regularly, but I occasionally drink alcohol.", {"entities": [(4, 15, "LIFESTYLE"), (22, 34, "LIFESTYLE"), (48, 54, "LIFESTYLE")]}),
    ("I'm vegan and exercise daily, but I used to smoke and drink heavily.", {"entities": [(4, 9, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (36, 41, "LIFESTYLE"), (46, 52, "LIFESTYLE")]}),
    ("I'm vegan and exercise regularly, but I occasionally drink and smoke.", {"entities": [(4, 9, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (32, 38, "LIFESTYLE"), (44, 49, "LIFESTYLE")]}),
    ("I used to smoke and drink, but now I focus on exercise and follow a pescatarian diet.", {"entities": [(10, 15, "LIFESTYLE"), (22, 29, "LIFESTYLE"), (44, 51, "LIFESTYLE"), (67, 77, "LIFESTYLE")]}),
    ("I'm vegan, but I occasionally indulge in drinking. I also exercise regularly.", {"entities": [(4, 9, "LIFESTYLE"), (32, 40, "LIFESTYLE"), (46, 61, "LIFESTYLE")]}),
    ("I'm vegetarian and exercise daily, but I used to have a history of drug use.", {"entities": [(4, 15, "LIFESTYLE"), (22, 30, "LIFESTYLE"), (51, 60, "LIFESTYLE")]}),
    ("I'm vegan and exercise regularly, but I also enjoy occasional drinking.", {"entities": [(4, 9, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (39, 46, "LIFESTYLE")]}),
    ("I used to smoke and drink, but now I'm focused on exercise and following a vegan diet.", {"entities": [(10, 15, "LIFESTYLE"), (22, 29, "LIFESTYLE"), (45, 54, "LIFESTYLE"), (69, 79, "LIFESTYLE")]}),
    ("I'm vegan, but I occasionally indulge in smoking and drinking. I prioritize exercise.", {"entities": [(4, 9, "LIFESTYLE"), (34, 41, "LIFESTYLE"), (47, 54, "LIFESTYLE"), (68, 76, "LIFESTYLE")]}),
    ("I exercise daily and follow a vegetarian diet, but I occasionally indulge in drinking.", {"entities": [(2, 10, "LIFESTYLE"), (27, 38, "LIFESTYLE"), (51, 59, "LIFESTYLE")]}),
    ("I'm vegan and exercise regularly, but I occasionally smoke and drink.", {"entities": [(4, 9, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (31, 37, "LIFESTYLE"), (43, 49, "LIFESTYLE")]}),
    ("I'm vegetarian and exercise regularly, but I also enjoy occasional smoking and drinking.", {"entities": [(4, 15, "LIFESTYLE"), (22, 34, "LIFESTYLE"), (40, 48, "LIFESTYLE"), (54, 61, "LIFESTYLE")]}),
    ("I used to smoke and drink, but now I'm focused on exercise and following a vegan diet.", {"entities": [(10, 15, "LIFESTYLE"), (22, 29, "LIFESTYLE"), (45, 54, "LIFESTYLE"), (68, 78, "LIFESTYLE")]}),
    ("I'm vegan and exercise regularly, but I also enjoy occasional drinking and smoking.", {"entities": [(4, 9, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (39, 46, "LIFESTYLE"), (52, 59, "LIFESTYLE")]}),
    ("I used to smoke and drink, but now I prioritize exercise and follow a vegetarian diet.", {"entities": [(10, 15, "LIFESTYLE"), (22, 29, "LIFESTYLE"), (44, 54, "LIFESTYLE"), (67, 78, "LIFESTYLE")]}),
    ("I'm vegan, but I occasionally indulge in smoking and drinking. I also prioritize exercise.", {"entities": [(4, 9, "LIFESTYLE"), (34, 41, "LIFESTYLE"), (47, 54, "LIFESTYLE"), (68, 76, "LIFESTYLE")]}),
    ("I exercise daily and follow a vegetarian diet, but I occasionally indulge in drinking.", {"entities": [(2, 10, "LIFESTYLE"), (27, 38, "LIFESTYLE"), (51, 59, "LIFESTYLE")]}),
    ("I'm vegan and exercise regularly, but I occasionally smoke and drink.", {"entities": [(4, 9, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (31, 37, "LIFESTYLE"), (43, 49, "LIFESTYLE")]}),
    ("I'm vegetarian and exercise regularly, but I also enjoy occasional smoking and drinking.", {"entities": [(4, 15, "LIFESTYLE"), (22, 34, "LIFESTYLE"), (40, 48, "LIFESTYLE"), (54, 61, "LIFESTYLE")]}),
    ("I used to smoke and drink, but now I'm focused on exercise and following a vegan diet.", {"entities": [(10, 15, "LIFESTYLE"), (22, 29, "LIFESTYLE"), (45, 54, "LIFESTYLE"), (68, 78, "LIFESTYLE")]}),
    ("I'm vegan and exercise regularly, but I also enjoy occasional drinking and smoking.", {"entities": [(4, 9, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (39, 46, "LIFESTYLE"), (52, 59, "LIFESTYLE")]}),
    ("I used to smoke and drink, but now I prioritize exercise and follow a vegetarian diet.", {"entities": [(10, 15, "LIFESTYLE"), (22, 29, "LIFESTYLE"), (44, 54, "LIFESTYLE"), (67, 78, "LIFESTYLE")]}),
    ("I'm vegan, but I occasionally indulge in smoking and drinking. I also prioritize exercise.", {"entities": [(4, 9, "LIFESTYLE"), (34, 41, "LIFESTYLE"), (47, 54, "LIFESTYLE"), (68, 76, "LIFESTYLE")]}),
    ("I exercise daily and follow a vegetarian diet, but I occasionally indulge in drinking.", {"entities": [(2, 10, "LIFESTYLE"), (27, 38, "LIFESTYLE"), (51, 59, "LIFESTYLE")]}),
    ("I'm vegan and exercise regularly, but I occasionally smoke and drink.", {"entities": [(4, 9, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (31, 37, "LIFESTYLE"), (43, 49, "LIFESTYLE")]}),
    ("I'm vegetarian and exercise regularly, but I also enjoy occasional smoking and drinking.", {"entities": [(4, 15, "LIFESTYLE"), (22, 34, "LIFESTYLE"), (40, 48, "LIFESTYLE"), (54, 61, "LIFESTYLE")]}),
    ("I used to smoke and drink, but now I'm focused on exercise and following a vegan diet.", {"entities": [(10, 15, "LIFESTYLE"), (22, 29, "LIFESTYLE"), (45, 54, "LIFESTYLE"), (68, 78, "LIFESTYLE")]}),
    ("I'm vegan and exercise regularly, but I also enjoy occasional drinking and smoking.", {"entities": [(4, 9, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (39, 46, "LIFESTYLE"), (52, 59, "LIFESTYLE")]}),
    ("I used to smoke and drink, but now I prioritize exercise and follow a vegetarian diet.", {"entities": [(10, 15, "LIFESTYLE"), (22, 29, "LIFESTYLE"), (44, 54, "LIFESTYLE"), (67, 78, "LIFESTYLE")]}),
    ("I'm vegan, but I occasionally indulge in smoking and drinking. I also prioritize exercise.", {"entities": [(4, 9, "LIFESTYLE"), (34, 41, "LIFESTYLE"), (47, 54, "LIFESTYLE"), (68, 76, "LIFESTYLE")]}),
    ("I exercise daily and follow a vegetarian diet, but I occasionally indulge in drinking.", {"entities": [(2, 10, "LIFESTYLE"), (27, 38, "LIFESTYLE"), (51, 59, "LIFESTYLE")]}),
    ("I'm vegan and exercise regularly, but I occasionally smoke and drink.", {"entities": [(4, 9, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (31, 37, "LIFESTYLE"), (43, 49, "LIFESTYLE")]}),
    ("I'm vegetarian and exercise regularly, but I also enjoy occasional smoking and drinking.", {"entities": [(4, 15, "LIFESTYLE"), (22, 34, "LIFESTYLE"), (40, 48, "LIFESTYLE"), (54, 61, "LIFESTYLE")]}),
    ("I used to smoke and drink, but now I'm focused on exercise and following a vegan diet.", {"entities": [(10, 15, "LIFESTYLE"), (22, 29, "LIFESTYLE"), (45, 54, "LIFESTYLE"), (68, 78, "LIFESTYLE")]}),
    ("I'm vegan and exercise regularly, but I also enjoy occasional drinking and smoking.", {"entities": [(4, 9, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (39, 46, "LIFESTYLE"), (52, 59, "LIFESTYLE")]}),
    ("I used to smoke and drink, but now I prioritize exercise and follow a vegetarian diet.", {"entities": [(10, 15, "LIFESTYLE"), (22, 29, "LIFESTYLE"), (44, 54, "LIFESTYLE"), (67, 78, "LIFESTYLE")]}),
    ("I'm vegan, but I occasionally indulge in smoking and drinking. I also prioritize exercise.", {"entities": [(4, 9, "LIFESTYLE"), (34, 41, "LIFESTYLE"), (47, 54, "LIFESTYLE"), (68, 76, "LIFESTYLE")]}),
    ("I exercise daily and follow a vegetarian diet, but I occasionally indulge in drinking.", {"entities": [(2, 10, "LIFESTYLE"), (27, 38, "LIFESTYLE"), (51, 59, "LIFESTYLE")]}),
    ("I'm vegan and exercise regularly, but I occasionally smoke and drink.", {"entities": [(4, 9, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (31, 37, "LIFESTYLE"), (43, 49, "LIFESTYLE")]}),
    ("I'm vegetarian and exercise regularly, but I also enjoy occasional smoking and drinking.", {"entities": [(4, 15, "LIFESTYLE"), (22, 34, "LIFESTYLE"), (40, 48, "LIFESTYLE"), (54, 61, "LIFESTYLE")]}),
    ("I used to smoke and drink, but now I'm focused on exercise and following a vegan diet.", {"entities": [(10, 15, "LIFESTYLE"), (22, 29, "LIFESTYLE"), (45, 54, "LIFESTYLE"), (68, 78, "LIFESTYLE")]}),
    ("I'm vegan and exercise regularly, but I also enjoy occasional drinking and smoking.", {"entities": [(4, 9, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (39, 46, "LIFESTYLE"), (52, 59, "LIFESTYLE")]}),
    ("I used to smoke and drink, but now I prioritize exercise and follow a vegetarian diet.", {"entities": [(10, 15, "LIFESTYLE"), (22, 29, "LIFESTYLE"), (44, 54, "LIFESTYLE"), (67, 78, "LIFESTYLE")]}),
    ("I'm vegan, but I occasionally indulge in smoking and drinking. I also prioritize exercise.", {"entities": [(4, 9, "LIFESTYLE"), (34, 41, "LIFESTYLE"), (47, 54, "LIFESTYLE"), (68, 76, "LIFESTYLE")]}),
    ("I exercise daily and follow a vegetarian diet, but I occasionally indulge in drinking.", {"entities": [(2, 10, "LIFESTYLE"), (27, 38, "LIFESTYLE"), (51, 59, "LIFESTYLE")]}),
    ("I'm vegan and exercise regularly, but I occasionally smoke and drink.", {"entities": [(4, 9, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (31, 37, "LIFESTYLE"), (43, 49, "LIFESTYLE")]}),
    ("I'm vegetarian and exercise regularly, but I also enjoy occasional smoking and drinking.", {"entities": [(4, 15, "LIFESTYLE"), (22, 34, "LIFESTYLE"), (40, 48, "LIFESTYLE"), (54, 61, "LIFESTYLE")]}),
    ("I used to smoke and drink, but now I'm focused on exercise and following a vegan diet.", {"entities": [(10, 15, "LIFESTYLE"), (22, 29, "LIFESTYLE"), (45, 54, "LIFESTYLE"), (68, 78, "LIFESTYLE")]}),
    ("I'm vegan and exercise regularly, but I also enjoy occasional drinking and smoking.", {"entities": [(4, 9, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (39, 46, "LIFESTYLE"), (52, 59, "LIFESTYLE")]}),
    ("I used to smoke and drink, but now I prioritize exercise and follow a vegetarian diet.", {"entities": [(10, 15, "LIFESTYLE"), (22, 29, "LIFESTYLE"), (44, 54, "LIFESTYLE"), (67, 78, "LIFESTYLE")]}),
    ("I'm vegan, but I occasionally indulge in smoking and drinking. I also prioritize exercise.", {"entities": [(4, 9, "LIFESTYLE"), (34, 41, "LIFESTYLE"), (47, 54, "LIFESTYLE"), (68, 76, "LIFESTYLE")]}),
    ("I exercise daily and follow a vegetarian diet, but I occasionally indulge in drinking.", {"entities": [(2, 10, "LIFESTYLE"), (27, 38, "LIFESTYLE"), (51, 59, "LIFESTYLE")]}),
    ("I'm vegan and exercise regularly, but I occasionally smoke and drink.", {"entities": [(4, 9, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (31, 37, "LIFESTYLE"), (43, 49, "LIFESTYLE")]}),
    ("I'm vegetarian and exercise regularly, but I also enjoy occasional smoking and drinking.", {"entities": [(4, 15, "LIFESTYLE"), (22, 34, "LIFESTYLE"), (40, 48, "LIFESTYLE"), (54, 61, "LIFESTYLE")]}),
    ("I used to smoke and drink, but now I'm focused on exercise and following a vegan diet.", {"entities": [(10, 15, "LIFESTYLE"), (22, 29, "LIFESTYLE"), (45, 54, "LIFESTYLE"), (68, 78, "LIFESTYLE")]}),
    ("I'm vegan and exercise regularly, but I also enjoy occasional drinking and smoking.", {"entities": [(4, 9, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (39, 46, "LIFESTYLE"), (52, 59, "LIFESTYLE")]}),
    ("I used to smoke and drink, but now I prioritize exercise and follow a vegetarian diet.", {"entities": [(10, 15, "LIFESTYLE"), (22, 29, "LIFESTYLE"), (44, 54, "LIFESTYLE"), (67, 78, "LIFESTYLE")]}),
    ("I'm vegan, but I occasionally indulge in smoking and drinking. I also prioritize exercise.", {"entities": [(4, 9, "LIFESTYLE"), (34, 41, "LIFESTYLE"), (47, 54, "LIFESTYLE"), (68, 76, "LIFESTYLE")]}),
    ("I exercise daily and follow a vegetarian diet, but I occasionally indulge in drinking.", {"entities": [(2, 10, "LIFESTYLE"), (27, 38, "LIFESTYLE"), (51, 59, "LIFESTYLE")]}),
    ("I'm vegan and exercise regularly, but I occasionally smoke and drink.", {"entities": [(4, 9, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (31, 37, "LIFESTYLE"), (43, 49, "LIFESTYLE")]}),
    ("I'm vegetarian and exercise regularly, but I also enjoy occasional smoking and drinking.", {"entities": [(4, 15, "LIFESTYLE"), (22, 34, "LIFESTYLE"), (40, 48, "LIFESTYLE"), (54, 61, "LIFESTYLE")]}),
    ("I used to smoke and drink, but now I'm focused on exercise and following a vegan diet.", {"entities": [(10, 15, "LIFESTYLE"), (22, 29, "LIFESTYLE"), (45, 54, "LIFESTYLE"), (68, 78, "LIFESTYLE")]}),
    ("I'm vegan and exercise regularly, but I also enjoy occasional drinking and smoking.", {"entities": [(4, 9, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (39, 46, "LIFESTYLE"), (52, 59, "LIFESTYLE")]}),
    ("I used to smoke and drink, but now I prioritize exercise and follow a vegetarian diet.", {"entities": [(10, 15, "LIFESTYLE"), (22, 29, "LIFESTYLE"), (44, 54, "LIFESTYLE"), (67, 78, "LIFESTYLE")]}),
    ("I'm vegan, but I occasionally indulge in smoking and drinking. I also prioritize exercise.", {"entities": [(4, 9, "LIFESTYLE"), (34, 41, "LIFESTYLE"), (47, 54, "LIFESTYLE"), (68, 76, "LIFESTYLE")]}),
    ("I exercise daily and follow a vegetarian diet, but I occasionally indulge in drinking.", {"entities": [(2, 10, "LIFESTYLE"), (27, 38, "LIFESTYLE"), (51, 59, "LIFESTYLE")]}),
    ("I'm vegan and exercise regularly, but I occasionally smoke and drink.", {"entities": [(4, 9, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (31, 37, "LIFESTYLE"), (43, 49, "LIFESTYLE")]}),
    ("I'm vegetarian and exercise regularly, but I also enjoy occasional smoking and drinking.", {"entities": [(4, 15, "LIFESTYLE"), (22, 34, "LIFESTYLE"), (40, 48, "LIFESTYLE"), (54, 61, "LIFESTYLE")]}),
    ("I used to smoke and drink, but now I'm focused on exercise and following a vegan diet.", {"entities": [(10, 15, "LIFESTYLE"), (22, 29, "LIFESTYLE"), (45, 54, "LIFESTYLE"), (68, 78, "LIFESTYLE")]}),
    ("I'm vegan and exercise regularly, but I also enjoy occasional drinking and smoking.", {"entities": [(4, 9, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (39, 46, "LIFESTYLE"), (52, 59, "LIFESTYLE")]}),
    ("I used to smoke and drink, but now I prioritize exercise and follow a vegetarian diet.", {"entities": [(10, 15, "LIFESTYLE"), (22, 29, "LIFESTYLE"), (44, 54, "LIFESTYLE"), (67, 78, "LIFESTYLE")]}),
    ("I'm vegan, but I occasionally indulge in smoking and drinking. I also prioritize exercise.", {"entities": [(4, 9, "LIFESTYLE"), (34, 41, "LIFESTYLE"), (47, 54, "LIFESTYLE"), (68, 76, "LIFESTYLE")]}),
    ("I exercise daily and follow a vegetarian diet, but I occasionally indulge in drinking.", {"entities": [(2, 10, "LIFESTYLE"), (27, 38, "LIFESTYLE"), (51, 59, "LIFESTYLE")]}),
    ("I'm vegan and exercise regularly, but I occasionally smoke and drink.", {"entities": [(4, 9, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (31, 37, "LIFESTYLE"), (43, 49, "LIFESTYLE")]}),
    ("I'm vegetarian and exercise regularly, but I also enjoy occasional smoking and drinking.", {"entities": [(4, 15, "LIFESTYLE"), (22, 34, "LIFESTYLE"), (40, 48, "LIFESTYLE"), (54, 61, "LIFESTYLE")]}),
    ("I used to smoke and drink, but now I'm focused on exercise and following a vegan diet.", {"entities": [(10, 15, "LIFESTYLE"), (22, 29, "LIFESTYLE"), (45, 54, "LIFESTYLE"), (68, 78, "LIFESTYLE")]}),
    ("I'm vegan and exercise regularly, but I also enjoy occasional drinking and smoking.", {"entities": [(4, 9, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (39, 46, "LIFESTYLE"), (52, 59, "LIFESTYLE")]}),
    ("I used to smoke and drink, but now I prioritize exercise and follow a vegetarian diet.", {"entities": [(10, 15, "LIFESTYLE"), (22, 29, "LIFESTYLE"), (44, 54, "LIFESTYLE"), (67, 78, "LIFESTYLE")]}),
    ("I'm vegan, but I occasionally indulge in smoking and drinking. I also prioritize exercise.", {"entities": [(4, 9, "LIFESTYLE"), (34, 41, "LIFESTYLE"), (47, 54, "LIFESTYLE"), (68, 76, "LIFESTYLE")]}),
    ("I exercise daily and follow a vegetarian diet, but I occasionally indulge in drinking.", {"entities": [(2, 10, "LIFESTYLE"), (27, 38, "LIFESTYLE"), (51, 59, "LIFESTYLE")]}),
    ("I'm vegan and exercise regularly, but I occasionally smoke and drink.", {"entities": [(4, 9, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (31, 37, "LIFESTYLE"), (43, 49, "LIFESTYLE")]}),
    ("I'm vegetarian and exercise regularly, but I also enjoy occasional smoking and drinking.", {"entities": [(4, 15, "LIFESTYLE"), (22, 34, "LIFESTYLE"), (40, 48, "LIFESTYLE"), (54, 61, "LIFESTYLE")]}),
    ("I used to smoke and drink, but now I'm focused on exercise and following a vegan diet.", {"entities": [(10, 15, "LIFESTYLE"), (22, 29, "LIFESTYLE"), (45, 54, "LIFESTYLE"), (68, 78, "LIFESTYLE")]}),
    ("I'm vegan and exercise regularly, but I also enjoy occasional drinking and smoking.", {"entities": [(4, 9, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (39, 46, "LIFESTYLE"), (52, 59, "LIFESTYLE")]}),
    ("I used to smoke and drink, but now I prioritize exercise and follow a vegetarian diet.", {"entities": [(10, 15, "LIFESTYLE"), (22, 29, "LIFESTYLE"), (44, 54, "LIFESTYLE"), (67, 78, "LIFESTYLE")]}),
    ("I'm vegan, but I occasionally indulge in smoking and drinking. I also prioritize exercise.", {"entities": [(4, 9, "LIFESTYLE"), (34, 41, "LIFESTYLE"), (47, 54, "LIFESTYLE"), (68, 76, "LIFESTYLE")]}),
    ("I exercise daily and follow a vegetarian diet, but I occasionally indulge in drinking.", {"entities": [(2, 10, "LIFESTYLE"), (27, 38, "LIFESTYLE"), (51, 59, "LIFESTYLE")]}),
    ("I'm vegan and exercise regularly, but I occasionally smoke and drink.", {"entities": [(4, 9, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (31, 37, "LIFESTYLE"), (43, 49, "LIFESTYLE")]}),
    ("I'm vegetarian and exercise regularly, but I also enjoy occasional smoking and drinking.", {"entities": [(4, 15, "LIFESTYLE"), (22, 34, "LIFESTYLE"), (40, 48, "LIFESTYLE"), (54, 61, "LIFESTYLE")]}),
    ("I used to smoke and drink, but now I'm focused on exercise and following a vegan diet.", {"entities": [(10, 15, "LIFESTYLE"), (22, 29, "LIFESTYLE"), (45, 54, "LIFESTYLE"), (68, 78, "LIFESTYLE")]}),
    ("I'm vegan and exercise regularly, but I also enjoy occasional drinking and smoking.", {"entities": [(4, 9, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (39, 46, "LIFESTYLE"), (52, 59, "LIFESTYLE")]}),
    ("I used to smoke and drink, but now I prioritize exercise and follow a vegetarian diet.", {"entities": [(10, 15, "LIFESTYLE"), (22, 29, "LIFESTYLE"), (44, 54, "LIFESTYLE"), (67, 78, "LIFESTYLE")]}),
    ("I'm vegan, but I occasionally indulge in smoking and drinking. I also prioritize exercise.", {"entities": [(4, 9, "LIFESTYLE"), (34, 41, "LIFESTYLE"), (47, 54, "LIFESTYLE"), (68, 76, "LIFESTYLE")]}),
    ("I exercise daily and follow a vegetarian diet, but I occasionally indulge in drinking.", {"entities": [(2, 10, "LIFESTYLE"), (27, 38, "LIFESTYLE"), (51, 59, "LIFESTYLE")]}),
    ("I'm vegan and exercise regularly, but I occasionally smoke and drink.", {"entities": [(4, 9, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (31, 37, "LIFESTYLE"), (43, 49, "LIFESTYLE")]}),
    ("I'm vegetarian and exercise regularly, but I also enjoy occasional smoking and drinking.", {"entities": [(4, 15, "LIFESTYLE"), (22, 34, "LIFESTYLE"), (40, 48, "LIFESTYLE"), (54, 61, "LIFESTYLE")]}),
    ("I used to smoke and drink, but now I'm focused on exercise and following a vegan diet.", {"entities": [(10, 15, "LIFESTYLE"), (22, 29, "LIFESTYLE"), (45, 54, "LIFESTYLE"), (68, 78, "LIFESTYLE")]}),
    ("I'm vegan and exercise regularly, but I also enjoy occasional drinking and smoking.", {"entities": [(4, 9, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (39, 46, "LIFESTYLE"), (52, 59, "LIFESTYLE")]}),
    ("I used to smoke and drink, but now I prioritize exercise and follow a vegetarian diet.", {"entities": [(10, 15, "LIFESTYLE"), (22, 29, "LIFESTYLE"), (44, 54, "LIFESTYLE"), (67, 78, "LIFESTYLE")]}),
    ("I'm vegan, but I occasionally indulge in smoking and drinking. I also prioritize exercise.", {"entities": [(4, 9, "LIFESTYLE"), (34, 41, "LIFESTYLE"), (47, 54, "LIFESTYLE"), (68, 76, "LIFESTYLE")]}),
    ("I exercise daily and follow a vegetarian diet, but I occasionally indulge in drinking.", {"entities": [(2, 10, "LIFESTYLE"), (27, 38, "LIFESTYLE"), (51, 59, "LIFESTYLE")]}),
    ("I'm vegan and exercise regularly, but I occasionally smoke and drink.", {"entities": [(4, 9, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (31, 37, "LIFESTYLE"), (43, 49, "LIFESTYLE")]}),
    ("I'm vegetarian and exercise regularly, but I also enjoy occasional smoking and drinking.", {"entities": [(4, 15, "LIFESTYLE"), (22, 34, "LIFESTYLE"), (40, 48, "LIFESTYLE"), (54, 61, "LIFESTYLE")]}),
    ("I used to smoke and drink, but now I'm focused on exercise and following a vegan diet.", {"entities": [(10, 15, "LIFESTYLE"), (22, 29, "LIFESTYLE"), (45, 54, "LIFESTYLE"), (68, 78, "LIFESTYLE")]}),
    ("I'm vegan and exercise regularly, but I also enjoy occasional drinking and smoking.", {"entities": [(4, 9, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (39, 46, "LIFESTYLE"), (52, 59, "LIFESTYLE")]}),
    ("I used to smoke and drink, but now I prioritize exercise and follow a vegetarian diet.", {"entities": [(10, 15, "LIFESTYLE"), (22, 29, "LIFESTYLE"), (44, 54, "LIFESTYLE"), (67, 78, "LIFESTYLE")]}),
    ("I'm vegan, but I occasionally indulge in smoking and drinking. I also prioritize exercise.", {"entities": [(4, 9, "LIFESTYLE"), (34, 41, "LIFESTYLE"), (47, 54, "LIFESTYLE"), (68, 76, "LIFESTYLE")]}),
    ("I exercise daily and follow a vegetarian diet, but I occasionally indulge in drinking.", {"entities": [(2, 10, "LIFESTYLE"), (27, 38, "LIFESTYLE"), (51, 59, "LIFESTYLE")]}),
    ("I'm vegan and exercise regularly, but I occasionally smoke and drink.", {"entities": [(4, 9, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (31, 37, "LIFESTYLE"), (43, 49, "LIFESTYLE")]}),
    ("I'm vegetarian and exercise regularly, but I also enjoy occasional smoking and drinking.", {"entities": [(4, 15, "LIFESTYLE"), (22, 34, "LIFESTYLE"), (40, 48, "LIFESTYLE"), (54, 61, "LIFESTYLE")]}),
    ("I used to smoke and drink, but now I'm focused on exercise and following a vegan diet.", {"entities": [(10, 15, "LIFESTYLE"), (22, 29, "LIFESTYLE"), (45, 54, "LIFESTYLE"), (68, 78, "LIFESTYLE")]}),
    ("I smoke, drink, and exercise regularly.", {"entities": [(2, 6, "LIFESTYLE"), (8, 13, "LIFESTYLE"), (19, 27, "LIFESTYLE")]}),
    ("I exercise and follow a vegan diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I smoke and follow a vegetarian diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 27, "LIFESTYLE")]}),
    ("I drink alcohol and exercise.", {"entities": [(2, 6, "LIFESTYLE"), (17, 25, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 27, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegetarian diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I follow a vegetarian diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 27, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegetarian diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I follow a vegetarian diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 27, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegetarian diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I follow a vegetarian diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 27, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegetarian diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I follow a vegetarian diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 27, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegetarian diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I follow a vegetarian diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 27, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegetarian diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I follow a vegetarian diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 27, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegetarian diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I follow a vegetarian diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 27, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegetarian diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I follow a vegetarian diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 27, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegetarian diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I follow a vegetarian diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 27, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegetarian diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I follow a vegetarian diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 27, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegetarian diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I follow a vegetarian diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 27, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegetarian diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I follow a vegetarian diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 27, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegetarian diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I follow a vegetarian diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 27, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegetarian diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I smoke and follow a gluten-free diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 28, "LIFESTYLE")]}),
    ("I drink alcohol and follow a keto diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise and follow a pescatarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I smoke and follow a low-carb diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 26, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a Mediterranean diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke and follow a ketogenic diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 25, "LIFESTYLE")]}),
    ("I drink alcohol and follow a paleo diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 28, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I follow a vegetarian diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 27, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegetarian diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I follow a vegetarian diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 27, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegetarian diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I follow a vegetarian diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 27, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegetarian diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I follow a vegetarian diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 27, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegetarian diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I follow a vegetarian diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 27, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegetarian diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I follow a vegetarian diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 27, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegetarian diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I follow a vegetarian diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 27, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegetarian diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I follow a vegetarian diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 27, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegetarian diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I follow a vegetarian diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 27, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegetarian diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I follow a vegetarian diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 27, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegetarian diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I follow a vegetarian diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 27, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegetarian diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I follow a vegetarian diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 27, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegetarian diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I follow a vegetarian diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 27, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegetarian diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I follow a vegetarian diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 27, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegetarian diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I follow a vegetarian diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 27, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegetarian diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I follow a vegetarian diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 27, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegetarian diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I follow a vegetarian diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 27, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegetarian diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I follow a vegetarian diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 27, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegetarian diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I follow a vegetarian diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 27, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegetarian diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I follow a vegetarian diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 27, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegetarian diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I follow a vegetarian diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 27, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegetarian diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I follow a vegetarian diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke and follow a vegan diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 27, "LIFESTYLE")]}),
    ("I drink alcohol and follow a vegetarian diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),

    ("I smoke, drink alcohol, and use drugs.", {
        "entities": [(2, 6, "LIFESTYLE"), (12, 26, "LIFESTYLE"), (32, 36, "LIFESTYLE"), (41, 45, "LIFESTYLE"),
                     (20, 24, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke and use drugs.", {"entities": [(2, 6, "LIFESTYLE"), (11, 15, "LIFESTYLE"), (20, 24, "LIFESTYLE")]}),
    ("I exercise and follow a vegan diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I drink alcohol and follow a halal diet.",
     {"entities": [(2, 6, "LIFESTYLE"), (17, 29, "LIFESTYLE"), (35, 39, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke, exercise, and follow a vegan diet.",
     {"entities": [(2, 6, "LIFESTYLE"), (8, 16, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I use drugs.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol and follow a paleo diet.",
     {"entities": [(2, 6, "LIFESTYLE"), (17, 28, "LIFESTYLE"), (34, 39, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke, exercise, and follow a halal diet.",
     {"entities": [(2, 6, "LIFESTYLE"), (8, 16, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I use drugs.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke, exercise, and follow a vegan diet.",
     {"entities": [(2, 6, "LIFESTYLE"), (8, 16, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I use drugs.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol and follow a paleo diet.",
     {"entities": [(2, 6, "LIFESTYLE"), (17, 28, "LIFESTYLE"), (34, 39, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke, exercise, and follow a halal diet.",
     {"entities": [(2, 6, "LIFESTYLE"), (8, 16, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I use drugs.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke, exercise, and follow a vegan diet.",
     {"entities": [(2, 6, "LIFESTYLE"), (8, 16, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I use drugs.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol and follow a paleo diet.",
     {"entities": [(2, 6, "LIFESTYLE"), (17, 28, "LIFESTYLE"), (34, 39, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke, exercise, and follow a halal diet.",
     {"entities": [(2, 6, "LIFESTYLE"), (8, 16, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I use drugs.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke, exercise, and follow a vegan diet.",
     {"entities": [(2, 6, "LIFESTYLE"), (8, 16, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I use drugs.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol and follow a paleo diet.",
     {"entities": [(2, 6, "LIFESTYLE"), (17, 28, "LIFESTYLE"), (34, 39, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke, exercise, and follow a halal diet.",
     {"entities": [(2, 6, "LIFESTYLE"), (8, 16, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I use drugs.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke, exercise, and follow a vegan diet.",
     {"entities": [(2, 6, "LIFESTYLE"), (8, 16, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I use drugs.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol and follow a paleo diet.",
     {"entities": [(2, 6, "LIFESTYLE"), (17, 28, "LIFESTYLE"), (34, 39, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke, exercise, and follow a halal diet.",
     {"entities": [(2, 6, "LIFESTYLE"), (8, 16, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I use drugs.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke, exercise, and follow a vegan diet.",
     {"entities": [(2, 6, "LIFESTYLE"), (8, 16, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I use drugs.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol and follow a paleo diet.",
     {"entities": [(2, 6, "LIFESTYLE"), (17, 28, "LIFESTYLE"), (34, 39, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke, exercise, and follow a halal diet.",
     {"entities": [(2, 6, "LIFESTYLE"), (8, 16, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I use drugs.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke, exercise, and follow a vegan diet.",
     {"entities": [(2, 6, "LIFESTYLE"), (8, 16, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I use drugs.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol and follow a paleo diet.",
     {"entities": [(2, 6, "LIFESTYLE"), (17, 28, "LIFESTYLE"), (34, 39, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke, exercise, and follow a halal diet.",
     {"entities": [(2, 6, "LIFESTYLE"), (8, 16, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I use drugs.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke, exercise, and follow a vegan diet.",
     {"entities": [(2, 6, "LIFESTYLE"), (8, 16, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I use drugs.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol and follow a paleo diet.",
     {"entities": [(2, 6, "LIFESTYLE"), (17, 28, "LIFESTYLE"), (34, 39, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke, exercise, and follow a halal diet.",
     {"entities": [(2, 6, "LIFESTYLE"), (8, 16, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I use drugs.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke, exercise, and follow a vegan diet.",
     {"entities": [(2, 6, "LIFESTYLE"), (8, 16, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I use drugs.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol and follow a paleo diet.",
     {"entities": [(2, 6, "LIFESTYLE"), (17, 28, "LIFESTYLE"), (34, 39, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke, exercise, and follow a halal diet.",
     {"entities": [(2, 6, "LIFESTYLE"), (8, 16, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I use drugs.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke, exercise, and follow a vegan diet.",
     {"entities": [(2, 6, "LIFESTYLE"), (8, 16, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I use drugs.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol and follow a paleo diet.",
     {"entities": [(2, 6, "LIFESTYLE"), (17, 28, "LIFESTYLE"), (34, 39, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke, exercise, and follow a halal diet.",
     {"entities": [(2, 6, "LIFESTYLE"), (8, 16, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I use drugs.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke, exercise, and follow a vegan diet.",
     {"entities": [(2, 6, "LIFESTYLE"), (8, 16, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I use drugs.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol and follow a paleo diet.",
     {"entities": [(2, 6, "LIFESTYLE"), (17, 28, "LIFESTYLE"), (34, 39, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke, exercise, and follow a halal diet.",
     {"entities": [(2, 6, "LIFESTYLE"), (8, 16, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I use drugs.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke, exercise, and follow a vegan diet.",
     {"entities": [(2, 6, "LIFESTYLE"), (8, 16, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I use drugs.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol and follow a paleo diet.",
     {"entities": [(2, 6, "LIFESTYLE"), (17, 28, "LIFESTYLE"), (34, 39, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke, exercise, and follow a halal diet.",
     {"entities": [(2, 6, "LIFESTYLE"), (8, 16, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I use drugs.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a paleo diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 33, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke, exercise, and follow a vegan diet.",
     {"entities": [(2, 6, "LIFESTYLE"), (8, 16, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I use drugs.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol and follow a paleo diet.",
     {"entities": [(2, 6, "LIFESTYLE"), (17, 28, "LIFESTYLE"), (34, 39, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I drink alcohol.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke, exercise, and follow a halal diet.",
     {"entities": [(2, 6, "LIFESTYLE"), (8, 16, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I use drugs.", {"entities": [(2, 6, "LIFESTYLE")]}),
("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol and follow a paleo diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 28, "LIFESTYLE"), (34, 39, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol and follow a paleo diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 28, "LIFESTYLE"), (34, 39, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol and follow a paleo diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 28, "LIFESTYLE"), (34, 39, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol and follow a paleo diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 28, "LIFESTYLE"), (34, 39, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol and follow a paleo diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 28, "LIFESTYLE"), (34, 39, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol and follow a paleo diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 28, "LIFESTYLE"), (34, 39, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol and follow a paleo diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 28, "LIFESTYLE"), (34, 39, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol and follow a paleo diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 28, "LIFESTYLE"), (34, 39, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol and follow a paleo diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 28, "LIFESTYLE"), (34, 39, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I exercise and follow a vegetarian diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 34, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(13, 25, "LIFESTYLE")]}),
    ("I smoke and drink alcohol.", {"entities": [(2, 6, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("I exercise and follow a halal diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 31, "LIFESTYLE")]}),
    ("I smoke and follow a halal diet.", {"entities": [(2, 6, "LIFESTYLE"), (15, 24, "LIFESTYLE")]}),
    ("I drink alcohol and follow a paleo diet.", {"entities": [(2, 6, "LIFESTYLE"), (17, 28, "LIFESTYLE"), (34, 39, "LIFESTYLE")]}),
    ("I exercise and follow a gluten-free diet.", {"entities": [(2, 10, "LIFESTYLE"), (22, 35, "LIFESTYLE")]}),
    ("I smoke cigarettes and drink alcohol, but I exercise regularly.", {"entities": [(2, 8, "LIFESTYLE"), (25, 32, "LIFESTYLE"), (46, 55, "LIFESTYLE")]}),
    ("I don't smoke or drink, and I follow a vegan diet.", {"entities": [(10, 15, "LIFESTYLE"), (20, 25, "LIFESTYLE"), (35, 45, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally indulge in drinking.", {"entities": [(2, 10, "LIFESTYLE"), (35, 41, "LIFESTYLE"), (50, 59, "LIFESTYLE")]}),
    ("I'm on a halal diet, and I don't smoke or drink.", {"entities": [(14, 18, "LIFESTYLE"), (30, 36, "LIFESTYLE"), (41, 48, "LIFESTYLE")]}),
    ("I smoke but I'm dedicated to exercise.", {"entities": [(2, 8, "LIFESTYLE"), (24, 32, "LIFESTYLE")]}),
    ("I enjoy drinking alcohol, but I'm committed to a balanced diet.", {"entities": [(12, 18, "LIFESTYLE"), (35, 42, "LIFESTYLE"), (53, 63, "LIFESTYLE")]}),
    ("I'm a non-smoker and a social drinker, but I prioritize exercise.", {"entities": [(7, 16, "LIFESTYLE"), (27, 33, "LIFESTYLE"), (49, 58, "LIFESTYLE")]}),
    ("I'm on a strict diet, and I avoid both smoking and drinking.", {"entities": [(13, 18, "LIFESTYLE"), (30, 36, "LIFESTYLE"), (41, 48, "LIFESTYLE")]}),
    ("I exercise regularly, but I occasionally smoke cigars.", {"entities": [(2, 10, "LIFESTYLE"), (41, 47, "LIFESTYLE"), (52, 58, "LIFESTYLE")]}),
    ("I'm not into drugs, and I follow a vegetarian diet.", {"entities": [(12, 16, "LIFESTYLE"), (31, 41, "LIFESTYLE"), (46, 56, "LIFESTYLE")]}),
    ("I smoke occasionally and enjoy drinking, but I prioritize exercise.", {"entities": [(2, 7, "LIFESTYLE"), (25, 32, "LIFESTYLE"), (52, 61, "LIFESTYLE")]}),
    ("I follow a strict diet, but I occasionally drink alcohol.", {"entities": [(18, 23, "LIFESTYLE"), (35, 41, "LIFESTYLE"), (52, 59, "LIFESTYLE")]}),
    ("I'm a smoker, but I'm committed to regular exercise.", {"entities": [(5, 11, "LIFESTYLE"), (27, 36, "LIFESTYLE")]}),
    ("I prefer not to smoke or drink, and I focus on healthy eating.", {"entities": [(17, 22, "LIFESTYLE"), (33, 38, "LIFESTYLE"), (50, 60, "LIFESTYLE")]}),
    ("I exercise religiously, but I enjoy a glass of wine occasionally.", {"entities": [(2, 10, "LIFESTYLE"), (45, 54, "LIFESTYLE"), (65, 74, "LIFESTYLE")]}),
    ("I'm on a vegan diet, but I do smoke and drink on occasion.", {"entities": [(11, 16, "LIFESTYLE"), (31, 36, "LIFESTYLE"), (44, 49, "LIFESTYLE")]}),
    ("I'm not into drugs, and I prioritize both diet and exercise.", {"entities": [(12, 16, "LIFESTYLE"), (34, 38, "LIFESTYLE"), (47, 56, "LIFESTYLE")]}),
    ("I occasionally smoke, but I'm diligent about exercising.", {"entities": [(2, 13, "LIFESTYLE"), (35, 45, "LIFESTYLE")]}),
    ("I drink alcohol socially, but I'm committed to a healthy diet.", {"entities": [(10, 15, "LIFESTYLE"), (34, 40, "LIFESTYLE"), (56, 65, "LIFESTYLE")]}),
    ("I'm on a halal diet, and I don't engage in smoking or drinking.", {"entities": [(14, 18, "LIFESTYLE"), (32, 39, "LIFESTYLE"), (44, 51, "LIFESTYLE")]}),
    ("I'm not a smoker or a drinker, and I'm dedicated to exercising.", {"entities": [(9, 15, "LIFESTYLE"), (25, 31, "LIFESTYLE"), (50, 60, "LIFESTYLE")]}),
    ("I enjoy the occasional drink, but I'm disciplined about exercise.", {"entities": [(21, 27, "LIFESTYLE"), (47, 56, "LIFESTYLE")]}),
    ("I smoke cigarettes, but I compensate with a healthy diet and exercise routine.", {"entities": [(2, 8, "LIFESTYLE"), (38, 47, "LIFESTYLE"), (57, 66, "LIFESTYLE")]}),
    ("I don't smoke or drink, and I maintain a vegetarian diet.", {"entities": [(7, 12, "LIFESTYLE"), (20, 25, "LIFESTYLE"), (41, 51, "LIFESTYLE")]}),
    ("I'm a social drinker, but I'm strict about following my exercise regimen.", {"entities": [(7, 13, "LIFESTYLE"), (38, 44, "LIFESTYLE"), (58, 67, "LIFESTYLE")]}),
    ("I occasionally indulge in smoking, but I'm consistent with exercise.", {"entities": [(2, 13, "LIFESTYLE"), (46, 55, "LIFESTYLE")]}),
    ("I drink alcohol occasionally, but I prioritize my healthy diet.", {"entities": [(2, 8, "LIFESTYLE"), (35, 44, "LIFESTYLE"), (55, 64, "LIFESTYLE")]}),
    ("I'm on a halal diet, and I don't smoke or drink.", {"entities": [(14, 18, "LIFESTYLE"), (30, 36, "LIFESTYLE"), (41, 48, "LIFESTYLE")]}),
    ("I'm not into drugs, and I follow a vegetarian diet.", {"entities": [(12, 16, "LIFESTYLE"), (31, 41, "LIFESTYLE"), (46, 56, "LIFESTYLE")]}),
    ("I occasionally smoke cigars, but I exercise regularly.", {"entities": [(2, 13, "LIFESTYLE"), (33, 39, "LIFESTYLE")]}),
    ("I drink alcohol occasionally, but I'm dedicated to exercise.", {"entities": [(2, 8, "LIFESTYLE"), (35, 44, "LIFESTYLE"), (50, 59, "LIFESTYLE")]}),
    ("I smoke cigarettes, but I prioritize a healthy diet and exercise.", {"entities": [(2, 8, "LIFESTYLE"), (39, 47, "LIFESTYLE"), (53, 62, "LIFESTYLE")]}),
    ("I don't smoke or drink, and I follow a gluten-free diet.", {"entities": [(10, 15, "LIFESTYLE"), (20, 25, "LIFESTYLE"), (35, 46, "LIFESTYLE")]}),
    ("I'm on a vegan diet, but I occasionally drink alcohol.", {"entities": [(11, 16, "LIFESTYLE"), (28, 33, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I smoke occasionally, but I'm committed to exercise.", {"entities": [(2, 13, "LIFESTYLE"), (28, 37, "LIFESTYLE")]}),
    ("I'm on a strict diet, and I don't smoke or drink.", {"entities": [(13, 18, "LIFESTYLE"), (30, 36, "LIFESTYLE"), (41, 48, "LIFESTYLE")]}),
    ("I exercise regularly, but I occasionally enjoy a drink.", {"entities": [(2, 10, "LIFESTYLE"), (41, 50, "LIFESTYLE"), (59, 64, "LIFESTYLE")]}),
    ("I'm a non-smoker, but I occasionally drink alcohol.", {"entities": [(7, 16, "LIFESTYLE"), (31, 37, "LIFESTYLE"), (46, 55, "LIFESTYLE")]}),
    ("I'm on a halal diet, but I occasionally smoke.", {"entities": [(14, 18, "LIFESTYLE"), (32, 36, "LIFESTYLE"), (41, 47, "LIFESTYLE")]}),
    ("I'm not into drugs, and I'm dedicated to a vegetarian diet.", {"entities": [(12, 16, "LIFESTYLE"), (33, 43, "LIFESTYLE"), (48, 58, "LIFESTYLE")]}),
    ("I exercise regularly, but I occasionally smoke.", {"entities": [(2, 10, "LIFESTYLE"), (35, 41, "LIFESTYLE"), (46, 52, "LIFESTYLE")]}),
    ("I occasionally drink alcohol, but I'm committed to exercise.", {"entities": [(2, 13, "LIFESTYLE"), (35, 44, "LIFESTYLE"), (49, 58, "LIFESTYLE")]}),
    ("I'm on a vegan diet, but I occasionally smoke.", {"entities": [(11, 16, "LIFESTYLE"), (32, 36, "LIFESTYLE"), (41, 47, "LIFESTYLE")]}),
    ("I smoke occasionally, but I prioritize exercise.", {"entities": [(2, 13, "LIFESTYLE"), (29, 38, "LIFESTYLE")]}),
    ("I enjoy drinking occasionally, but I'm dedicated to exercise.", {"entities": [(7, 22, "LIFESTYLE"), (35, 44, "LIFESTYLE"), (49, 58, "LIFESTYLE")]}),
    ("I'm on a gluten-free diet, but I occasionally smoke.", {"entities": [(11, 22, "LIFESTYLE"), (32, 36, "LIFESTYLE"), (41, 47, "LIFESTYLE")]}),
    ("I'm not into drugs, and I prioritize exercise.", {"entities": [(12, 16, "LIFESTYLE"), (31, 41, "LIFESTYLE")]}),
    ("I exercise regularly, but I occasionally drink alcohol.", {"entities": [(2, 10, "LIFESTYLE"), (35, 41, "LIFESTYLE"), (50, 59, "LIFESTYLE")]}),
    ("I'm on a halal diet, but I enjoy drinking occasionally.", {"entities": [(14, 18, "LIFESTYLE"), (31, 36, "LIFESTYLE"), (51, 60, "LIFESTYLE")]}),
    ("I'm not into drugs, but I enjoy drinking occasionally.", {"entities": [(12, 16, "LIFESTYLE"), (28, 33, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I'm on a vegan diet, but I occasionally smoke.", {"entities": [(11, 16, "LIFESTYLE"), (31, 35, "LIFESTYLE"), (40, 46, "LIFESTYLE")]}),
    ("I smoke occasionally, but I'm committed to exercise.", {"entities": [(2, 13, "LIFESTYLE"), (30, 39, "LIFESTYLE")]}),
    ("I'm on a strict diet, but I occasionally enjoy a drink.", {"entities": [(13, 18, "LIFESTYLE"), (32, 41, "LIFESTYLE"), (50, 55, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally drink alcohol.", {"entities": [(2, 10, "LIFESTYLE"), (35, 41, "LIFESTYLE"), (52, 61, "LIFESTYLE")]}),
    ("I'm on a gluten-free diet, but I occasionally smoke.", {"entities": [(11, 22, "LIFESTYLE"), (32, 36, "LIFESTYLE"), (41, 47, "LIFESTYLE")]}),
    ("I'm not into drugs, and I prioritize a healthy diet.", {"entities": [(12, 16, "LIFESTYLE"), (31, 41, "LIFESTYLE"), (46, 56, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally enjoy a drink.", {"entities": [(2, 10, "LIFESTYLE"), (35, 44, "LIFESTYLE"), (49, 54, "LIFESTYLE")]}),
    ("I'm on a halal diet, but I occasionally drink alcohol.", {"entities": [(14, 18, "LIFESTYLE"), (31, 36, "LIFESTYLE"), (51, 60, "LIFESTYLE")]}),
    ("I'm not into drugs, but I enjoy drinking occasionally.", {"entities": [(12, 16, "LIFESTYLE"), (28, 33, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I'm on a vegan diet, but I occasionally smoke.", {"entities": [(11, 16, "LIFESTYLE"), (31, 35, "LIFESTYLE"), (40, 46, "LIFESTYLE")]}),
    ("I smoke occasionally, but I'm committed to exercise.", {"entities": [(2, 13, "LIFESTYLE"), (30, 39, "LIFESTYLE")]}),
    ("I'm on a strict diet, but I occasionally enjoy a drink.", {"entities": [(13, 18, "LIFESTYLE"), (32, 41, "LIFESTYLE"), (50, 55, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally drink alcohol.", {"entities": [(2, 10, "LIFESTYLE"), (35, 41, "LIFESTYLE"), (52, 61, "LIFESTYLE")]}),
    ("I'm on a gluten-free diet, but I occasionally smoke.", {"entities": [(11, 22, "LIFESTYLE"), (32, 36, "LIFESTYLE"), (41, 47, "LIFESTYLE")]}),
    ("I'm not into drugs, and I prioritize a healthy diet.", {"entities": [(12, 16, "LIFESTYLE"), (31, 41, "LIFESTYLE"), (46, 56, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally enjoy a drink.", {"entities": [(2, 10, "LIFESTYLE"), (35, 44, "LIFESTYLE"), (49, 54, "LIFESTYLE")]}),
    ("I'm on a halal diet, but I occasionally drink alcohol.", {"entities": [(14, 18, "LIFESTYLE"), (31, 36, "LIFESTYLE"), (51, 60, "LIFESTYLE")]}),
    ("I'm not into drugs, but I enjoy drinking occasionally.", {"entities": [(12, 16, "LIFESTYLE"), (28, 33, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I'm on a vegan diet, but I occasionally smoke.", {"entities": [(11, 16, "LIFESTYLE"), (31, 35, "LIFESTYLE"), (40, 46, "LIFESTYLE")]}),
    ("I smoke occasionally, but I'm committed to exercise.", {"entities": [(2, 13, "LIFESTYLE"), (30, 39, "LIFESTYLE")]}),
    ("I'm on a strict diet, but I occasionally enjoy a drink.", {"entities": [(13, 18, "LIFESTYLE"), (32, 41, "LIFESTYLE"), (50, 55, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally drink alcohol.", {"entities": [(2, 10, "LIFESTYLE"), (35, 41, "LIFESTYLE"), (52, 61, "LIFESTYLE")]}),
    ("I'm on a gluten-free diet, but I occasionally smoke.", {"entities": [(11, 22, "LIFESTYLE"), (32, 36, "LIFESTYLE"), (41, 47, "LIFESTYLE")]}),
    ("I'm not into drugs, and I prioritize a healthy diet.", {"entities": [(12, 16, "LIFESTYLE"), (31, 41, "LIFESTYLE"), (46, 56, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally enjoy a drink.", {"entities": [(2, 10, "LIFESTYLE"), (35, 44, "LIFESTYLE"), (49, 54, "LIFESTYLE")]}),
    ("I'm on a halal diet, but I occasionally drink alcohol.", {"entities": [(14, 18, "LIFESTYLE"), (31, 36, "LIFESTYLE"), (51, 60, "LIFESTYLE")]}),
    ("I'm not into drugs, but I enjoy drinking occasionally.", {"entities": [(12, 16, "LIFESTYLE"), (28, 33, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I'm on a vegan diet, but I occasionally smoke.", {"entities": [(11, 16, "LIFESTYLE"), (31, 35, "LIFESTYLE"), (40, 46, "LIFESTYLE")]}),
    ("I smoke occasionally, but I'm committed to exercise.", {"entities": [(2, 13, "LIFESTYLE"), (30, 39, "LIFESTYLE")]}),
    ("I'm on a strict diet, but I occasionally enjoy a drink.", {"entities": [(13, 18, "LIFESTYLE"), (32, 41, "LIFESTYLE"), (50, 55, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally drink alcohol.", {"entities": [(2, 10, "LIFESTYLE"), (35, 41, "LIFESTYLE"), (52, 61, "LIFESTYLE")]}),
    ("I'm on a gluten-free diet, but I occasionally smoke.", {"entities": [(11, 22, "LIFESTYLE"), (32, 36, "LIFESTYLE"), (41, 47, "LIFESTYLE")]}),
    ("I'm not into drugs, and I prioritize a healthy diet.", {"entities": [(12, 16, "LIFESTYLE"), (31, 41, "LIFESTYLE"), (46, 56, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally enjoy a drink.", {"entities": [(2, 10, "LIFESTYLE"), (35, 44, "LIFESTYLE"), (49, 54, "LIFESTYLE")]}),
    ("I'm on a halal diet, but I occasionally drink alcohol.", {"entities": [(14, 18, "LIFESTYLE"), (31, 36, "LIFESTYLE"), (51, 60, "LIFESTYLE")]}),
    ("I'm not into drugs, but I enjoy drinking occasionally.", {"entities": [(12, 16, "LIFESTYLE"), (28, 33, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I'm on a vegan diet, but I occasionally smoke.", {"entities": [(11, 16, "LIFESTYLE"), (31, 35, "LIFESTYLE"), (40, 46, "LIFESTYLE")]}),
    ("I smoke occasionally, but I'm committed to exercise.", {"entities": [(2, 13, "LIFESTYLE"), (30, 39, "LIFESTYLE")]}),
    ("I'm on a strict diet, but I occasionally enjoy a drink.", {"entities": [(13, 18, "LIFESTYLE"), (32, 41, "LIFESTYLE"), (50, 55, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally drink alcohol.", {"entities": [(2, 10, "LIFESTYLE"), (35, 41, "LIFESTYLE"), (52, 61, "LIFESTYLE")]}),
    ("I'm on a gluten-free diet, but I occasionally smoke.", {"entities": [(11, 22, "LIFESTYLE"), (32, 36, "LIFESTYLE"), (41, 47, "LIFESTYLE")]}),
    ("I'm not into drugs, and I prioritize a healthy diet.", {"entities": [(12, 16, "LIFESTYLE"), (31, 41, "LIFESTYLE"), (46, 56, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally enjoy a drink.", {"entities": [(2, 10, "LIFESTYLE"), (35, 44, "LIFESTYLE"), (49, 54, "LIFESTYLE")]}),
    ("I'm on a halal diet, but I occasionally drink alcohol.", {"entities": [(14, 18, "LIFESTYLE"), (31, 36, "LIFESTYLE"), (51, 60, "LIFESTYLE")]}),
    ("I'm not into drugs, but I enjoy drinking occasionally.", {"entities": [(12, 16, "LIFESTYLE"), (28, 33, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I'm on a vegan diet, but I occasionally smoke.", {"entities": [(11, 16, "LIFESTYLE"), (31, 35, "LIFESTYLE"), (40, 46, "LIFESTYLE")]}),
    ("I smoke occasionally, but I'm committed to exercise.", {"entities": [(2, 13, "LIFESTYLE"), (30, 39, "LIFESTYLE")]}),
    ("I'm on a strict diet, but I occasionally enjoy a drink.", {"entities": [(13, 18, "LIFESTYLE"), (32, 41, "LIFESTYLE"), (50, 55, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally drink alcohol.", {"entities": [(2, 10, "LIFESTYLE"), (35, 41, "LIFESTYLE"), (52, 61, "LIFESTYLE")]}),
    ("I'm on a gluten-free diet, but I occasionally smoke.", {"entities": [(11, 22, "LIFESTYLE"), (32, 36, "LIFESTYLE"), (41, 47, "LIFESTYLE")]}),
    ("I'm not into drugs, and I prioritize a healthy diet.", {"entities": [(12, 16, "LIFESTYLE"), (31, 41, "LIFESTYLE"), (46, 56, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally enjoy a drink.", {"entities": [(2, 10, "LIFESTYLE"), (35, 44, "LIFESTYLE"), (49, 54, "LIFESTYLE")]}),
    ("I'm on a halal diet, but I occasionally drink alcohol.", {"entities": [(14, 18, "LIFESTYLE"), (31, 36, "LIFESTYLE"), (51, 60, "LIFESTYLE")]}),
    ("I'm not into drugs, but I enjoy drinking occasionally.", {"entities": [(12, 16, "LIFESTYLE"), (28, 33, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I'm on a vegan diet, but I occasionally smoke.", {"entities": [(11, 16, "LIFESTYLE"), (31, 35, "LIFESTYLE"), (40, 46, "LIFESTYLE")]}),
    ("I smoke occasionally, but I'm committed to exercise.", {"entities": [(2, 13, "LIFESTYLE"), (30, 39, "LIFESTYLE")]}),
    ("I'm on a strict diet, but I occasionally enjoy a drink.", {"entities": [(13, 18, "LIFESTYLE"), (32, 41, "LIFESTYLE"), (50, 55, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally drink alcohol.", {"entities": [(2, 10, "LIFESTYLE"), (35, 41, "LIFESTYLE"), (52, 61, "LIFESTYLE")]}),
    ("I'm on a gluten-free diet, but I occasionally smoke.", {"entities": [(11, 22, "LIFESTYLE"), (32, 36, "LIFESTYLE"), (41, 47, "LIFESTYLE")]}),
    ("I'm not into drugs, and I prioritize a healthy diet.", {"entities": [(12, 16, "LIFESTYLE"), (31, 41, "LIFESTYLE"), (46, 56, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally enjoy a drink.", {"entities": [(2, 10, "LIFESTYLE"), (35, 44, "LIFESTYLE"), (49, 54, "LIFESTYLE")]}),
    ("I'm on a halal diet, but I occasionally drink alcohol.", {"entities": [(14, 18, "LIFESTYLE"), (31, 36, "LIFESTYLE"), (51, 60, "LIFESTYLE")]}),
    ("I'm not into drugs, but I enjoy drinking occasionally.", {"entities": [(12, 16, "LIFESTYLE"), (28, 33, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I'm on a vegan diet, but I occasionally smoke.", {"entities": [(11, 16, "LIFESTYLE"), (31, 35, "LIFESTYLE"), (40, 46, "LIFESTYLE")]}),
    ("I smoke occasionally, but I'm committed to exercise.", {"entities": [(2, 13, "LIFESTYLE"), (30, 39, "LIFESTYLE")]}),
    ("I'm on a strict diet, but I occasionally enjoy a drink.", {"entities": [(13, 18, "LIFESTYLE"), (32, 41, "LIFESTYLE"), (50, 55, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally drink alcohol.", {"entities": [(2, 10, "LIFESTYLE"), (35, 41, "LIFESTYLE"), (52, 61, "LIFESTYLE")]}),
    ("I'm on a gluten-free diet, but I occasionally smoke.", {"entities": [(11, 22, "LIFESTYLE"), (32, 36, "LIFESTYLE"), (41, 47, "LIFESTYLE")]}),
    ("I'm not into drugs, and I prioritize a healthy diet.", {"entities": [(12, 16, "LIFESTYLE"), (31, 41, "LIFESTYLE"), (46, 56, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally enjoy a drink.", {"entities": [(2, 10, "LIFESTYLE"), (35, 44, "LIFESTYLE"), (49, 54, "LIFESTYLE")]}),
    ("I'm on a halal diet, but I occasionally drink alcohol.", {"entities": [(14, 18, "LIFESTYLE"), (31, 36, "LIFESTYLE"), (51, 60, "LIFESTYLE")]}),
    ("I'm not into drugs, but I enjoy drinking occasionally.", {"entities": [(12, 16, "LIFESTYLE"), (28, 33, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I'm on a vegan diet, but I occasionally smoke.", {"entities": [(11, 16, "LIFESTYLE"), (31, 35, "LIFESTYLE"), (40, 46, "LIFESTYLE")]}),
    ("I smoke occasionally, but I'm committed to exercise.", {"entities": [(2, 13, "LIFESTYLE"), (30, 39, "LIFESTYLE")]}),
    ("I'm on a strict diet, but I occasionally enjoy a drink.", {"entities": [(13, 18, "LIFESTYLE"), (32, 41, "LIFESTYLE"), (50, 55, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally drink alcohol.", {"entities": [(2, 10, "LIFESTYLE"), (35, 41, "LIFESTYLE"), (52, 61, "LIFESTYLE")]}),
    ("I'm on a gluten-free diet, but I occasionally smoke.", {"entities": [(11, 22, "LIFESTYLE"), (32, 36, "LIFESTYLE"), (41, 47, "LIFESTYLE")]}),
    ("I'm not into drugs, and I prioritize a healthy diet.", {"entities": [(12, 16, "LIFESTYLE"), (31, 41, "LIFESTYLE"), (46, 56, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally enjoy a drink.", {"entities": [(2, 10, "LIFESTYLE"), (35, 44, "LIFESTYLE"), (49, 54, "LIFESTYLE")]}),
    ("I'm on a halal diet, but I occasionally drink alcohol.", {"entities": [(14, 18, "LIFESTYLE"), (31, 36, "LIFESTYLE"), (51, 60, "LIFESTYLE")]}),
    ("I'm not into drugs, but I enjoy drinking occasionally.", {"entities": [(12, 16, "LIFESTYLE"), (28, 33, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I'm on a vegan diet, but I occasionally smoke.", {"entities": [(11, 16, "LIFESTYLE"), (31, 35, "LIFESTYLE"), (40, 46, "LIFESTYLE")]}),
    ("I smoke occasionally, but I'm committed to exercise.", {"entities": [(2, 13, "LIFESTYLE"), (30, 39, "LIFESTYLE")]}),
    ("I'm on a strict diet, but I occasionally enjoy a drink.", {"entities": [(13, 18, "LIFESTYLE"), (32, 41, "LIFESTYLE"), (50, 55, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally drink alcohol.", {"entities": [(2, 10, "LIFESTYLE"), (35, 41, "LIFESTYLE"), (52, 61, "LIFESTYLE")]}),
    ("I'm on a gluten-free diet, but I occasionally smoke.", {"entities": [(11, 22, "LIFESTYLE"), (32, 36, "LIFESTYLE"), (41, 47, "LIFESTYLE")]}),
    ("I'm not into drugs, and I prioritize a healthy diet.", {"entities": [(12, 16, "LIFESTYLE"), (31, 41, "LIFESTYLE"), (46, 56, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally enjoy a drink.", {"entities": [(2, 10, "LIFESTYLE"), (35, 44, "LIFESTYLE"), (49, 54, "LIFESTYLE")]}),
    ("I'm on a halal diet, but I occasionally drink alcohol.", {"entities": [(14, 18, "LIFESTYLE"), (31, 36, "LIFESTYLE"), (51, 60, "LIFESTYLE")]}),
    ("I'm not into drugs, but I enjoy drinking occasionally.", {"entities": [(12, 16, "LIFESTYLE"), (28, 33, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I'm on a vegan diet, but I occasionally smoke.", {"entities": [(11, 16, "LIFESTYLE"), (31, 35, "LIFESTYLE"), (40, 46, "LIFESTYLE")]}),
    ("I smoke occasionally, but I'm committed to exercise.", {"entities": [(2, 13, "LIFESTYLE"), (30, 39, "LIFESTYLE")]}),
    ("I'm on a strict diet, but I occasionally enjoy a drink.", {"entities": [(13, 18, "LIFESTYLE"), (32, 41, "LIFESTYLE"), (50, 55, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally drink alcohol.", {"entities": [(2, 10, "LIFESTYLE"), (35, 41, "LIFESTYLE"), (52, 61, "LIFESTYLE")]}),
    ("I'm on a gluten-free diet, but I occasionally smoke.", {"entities": [(11, 22, "LIFESTYLE"), (32, 36, "LIFESTYLE"), (41, 47, "LIFESTYLE")]}),
    ("I'm not into drugs, and I prioritize a healthy diet.", {"entities": [(12, 16, "LIFESTYLE"), (31, 41, "LIFESTYLE"), (46, 56, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally enjoy a drink.", {"entities": [(2, 10, "LIFESTYLE"), (35, 44, "LIFESTYLE"), (49, 54, "LIFESTYLE")]}),
    ("I'm on a halal diet, but I occasionally drink alcohol.", {"entities": [(14, 18, "LIFESTYLE"), (31, 36, "LIFESTYLE"), (51, 60, "LIFESTYLE")]}),
    ("I'm not into drugs, but I enjoy drinking occasionally.", {"entities": [(12, 16, "LIFESTYLE"), (28, 33, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I'm on a vegan diet, but I occasionally smoke.", {"entities": [(11, 16, "LIFESTYLE"), (31, 35, "LIFESTYLE"), (40, 46, "LIFESTYLE")]}),
    ("I smoke occasionally, but I'm committed to exercise.", {"entities": [(2, 13, "LIFESTYLE"), (30, 39, "LIFESTYLE")]}),
    ("I'm on a strict diet, but I occasionally enjoy a drink.", {"entities": [(13, 18, "LIFESTYLE"), (32, 41, "LIFESTYLE"), (50, 55, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally drink alcohol.", {"entities": [(2, 10, "LIFESTYLE"), (35, 41, "LIFESTYLE"), (52, 61, "LIFESTYLE")]}),
    ("I'm on a gluten-free diet, but I occasionally smoke.", {"entities": [(11, 22, "LIFESTYLE"), (32, 36, "LIFESTYLE"), (41, 47, "LIFESTYLE")]}),
    ("I'm not into drugs, and I prioritize a healthy diet.", {"entities": [(12, 16, "LIFESTYLE"), (31, 41, "LIFESTYLE"), (46, 56, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally enjoy a drink.", {"entities": [(2, 10, "LIFESTYLE"), (35, 44, "LIFESTYLE"), (49, 54, "LIFESTYLE")]}),
    ("I'm on a halal diet, but I occasionally drink alcohol.", {"entities": [(14, 18, "LIFESTYLE"), (31, 36, "LIFESTYLE"), (51, 60, "LIFESTYLE")]}),
    ("I'm not into drugs, but I enjoy drinking occasionally.", {"entities": [(12, 16, "LIFESTYLE"), (28, 33, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I'm on a vegan diet, but I occasionally smoke.", {"entities": [(11, 16, "LIFESTYLE"), (31, 35, "LIFESTYLE"), (40, 46, "LIFESTYLE")]}),
    ("I smoke occasionally, but I'm committed to exercise.", {"entities": [(2, 13, "LIFESTYLE"), (30, 39, "LIFESTYLE")]}),
    ("I'm on a strict diet, but I occasionally enjoy a drink.", {"entities": [(13, 18, "LIFESTYLE"), (32, 41, "LIFESTYLE"), (50, 55, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally drink alcohol.", {"entities": [(2, 10, "LIFESTYLE"), (35, 41, "LIFESTYLE"), (52, 61, "LIFESTYLE")]}),
    ("I'm on a gluten-free diet, but I occasionally smoke.", {"entities": [(11, 22, "LIFESTYLE"), (32, 36, "LIFESTYLE"), (41, 47, "LIFESTYLE")]}),
    ("I'm not into drugs, and I prioritize a healthy diet.", {"entities": [(12, 16, "LIFESTYLE"), (31, 41, "LIFESTYLE"), (46, 56, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally enjoy a drink.", {"entities": [(2, 10, "LIFESTYLE"), (35, 44, "LIFESTYLE"), (49, 54, "LIFESTYLE")]}),
    ("I'm on a halal diet, but I occasionally drink alcohol.", {"entities": [(14, 18, "LIFESTYLE"), (31, 36, "LIFESTYLE"), (51, 60, "LIFESTYLE")]}),
    ("I'm not into drugs, but I enjoy drinking occasionally.", {"entities": [(12, 16, "LIFESTYLE"), (28, 33, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I'm on a vegan diet, but I occasionally smoke.", {"entities": [(11, 16, "LIFESTYLE"), (31, 35, "LIFESTYLE"), (40, 46, "LIFESTYLE")]}),
    ("I smoke occasionally, but I'm committed to exercise.", {"entities": [(2, 13, "LIFESTYLE"), (30, 39, "LIFESTYLE")]}),
    ("I'm on a strict diet, but I occasionally enjoy a drink.", {"entities": [(13, 18, "LIFESTYLE"), (32, 41, "LIFESTYLE"), (50, 55, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally drink alcohol.", {"entities": [(2, 10, "LIFESTYLE"), (35, 41, "LIFESTYLE"), (52, 61, "LIFESTYLE")]}),
    ("I'm on a gluten-free diet, but I occasionally smoke.", {"entities": [(11, 22, "LIFESTYLE"), (32, 36, "LIFESTYLE"), (41, 47, "LIFESTYLE")]}),
    ("I'm not into drugs, and I prioritize a healthy diet.", {"entities": [(12, 16, "LIFESTYLE"), (31, 41, "LIFESTYLE"), (46, 56, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally enjoy a drink.", {"entities": [(2, 10, "LIFESTYLE"), (35, 44, "LIFESTYLE"), (49, 54, "LIFESTYLE")]}),
    ("I'm on a halal diet, but I occasionally drink alcohol.", {"entities": [(14, 18, "LIFESTYLE"), (31, 36, "LIFESTYLE"), (51, 60, "LIFESTYLE")]}),
    ("I'm not into drugs, but I enjoy drinking occasionally.", {"entities": [(12, 16, "LIFESTYLE"), (28, 33, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I'm on a vegan diet, but I occasionally smoke.", {"entities": [(11, 16, "LIFESTYLE"), (31, 35, "LIFESTYLE"), (40, 46, "LIFESTYLE")]}),
    ("I smoke occasionally, but I'm committed to exercise.", {"entities": [(2, 13, "LIFESTYLE"), (30, 39, "LIFESTYLE")]}),
    ("I'm on a strict diet, but I occasionally enjoy a drink.", {"entities": [(13, 18, "LIFESTYLE"), (32, 41, "LIFESTYLE"), (50, 55, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally drink alcohol.", {"entities": [(2, 10, "LIFESTYLE"), (35, 41, "LIFESTYLE"), (52, 61, "LIFESTYLE")]}),
    ("I'm on a gluten-free diet, but I occasionally smoke.", {"entities": [(11, 22, "LIFESTYLE"), (32, 36, "LIFESTYLE"), (41, 47, "LIFESTYLE")]}),
    ("I'm not into drugs, and I prioritize a healthy diet.", {"entities": [(12, 16, "LIFESTYLE"), (31, 41, "LIFESTYLE"), (46, 56, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally enjoy a drink.", {"entities": [(2, 10, "LIFESTYLE"), (35, 44, "LIFESTYLE"), (49, 54, "LIFESTYLE")]}),
    ("I'm on a halal diet, but I occasionally drink alcohol.", {"entities": [(14, 18, "LIFESTYLE"), (31, 36, "LIFESTYLE"), (51, 60, "LIFESTYLE")]}),
    ("I'm not into drugs, but I enjoy drinking occasionally.", {"entities": [(12, 16, "LIFESTYLE"), (28, 33, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I'm on a vegan diet, but I occasionally smoke.", {"entities": [(11, 16, "LIFESTYLE"), (31, 35, "LIFESTYLE"), (40, 46, "LIFESTYLE")]}),
    ("I smoke occasionally, but I'm committed to exercise.", {"entities": [(2, 13, "LIFESTYLE"), (30, 39, "LIFESTYLE")]}),
    ("I'm on a strict diet, but I occasionally enjoy a drink.", {"entities": [(13, 18, "LIFESTYLE"), (32, 41, "LIFESTYLE"), (50, 55, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally drink alcohol.", {"entities": [(2, 10, "LIFESTYLE"), (35, 41, "LIFESTYLE"), (52, 61, "LIFESTYLE")]}),
    ("I'm on a gluten-free diet, but I occasionally smoke.", {"entities": [(11, 22, "LIFESTYLE"), (32, 36, "LIFESTYLE"), (41, 47, "LIFESTYLE")]}),
    ("I'm not into drugs, and I prioritize a healthy diet.", {"entities": [(12, 16, "LIFESTYLE"), (31, 41, "LIFESTYLE"), (46, 56, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally enjoy a drink.", {"entities": [(2, 10, "LIFESTYLE"), (35, 44, "LIFESTYLE"), (49, 54, "LIFESTYLE")]}),
    ("I'm on a halal diet, but I occasionally drink alcohol.", {"entities": [(14, 18, "LIFESTYLE"), (31, 36, "LIFESTYLE"), (51, 60, "LIFESTYLE")]}),
    ("I'm not into drugs, but I enjoy drinking occasionally.", {"entities": [(12, 16, "LIFESTYLE"), (28, 33, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I'm on a vegan diet, but I occasionally smoke.", {"entities": [(11, 16, "LIFESTYLE"), (31, 35, "LIFESTYLE"), (40, 46, "LIFESTYLE")]}),
    ("I smoke occasionally, but I'm committed to exercise.", {"entities": [(2, 13, "LIFESTYLE"), (30, 39, "LIFESTYLE")]}),
    ("I'm on a strict diet, but I occasionally enjoy a drink.", {"entities": [(13, 18, "LIFESTYLE"), (32, 41, "LIFESTYLE"), (50, 55, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally drink alcohol.", {"entities": [(2, 10, "LIFESTYLE"), (35, 41, "LIFESTYLE"), (52, 61, "LIFESTYLE")]}),
    ("I'm on a gluten-free diet, but I occasionally smoke.", {"entities": [(11, 22, "LIFESTYLE"), (32, 36, "LIFESTYLE"), (41, 47, "LIFESTYLE")]}),
    ("I'm not into drugs, and I prioritize a healthy diet.", {"entities": [(12, 16, "LIFESTYLE"), (31, 41, "LIFESTYLE"), (46, 56, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally enjoy a drink.", {"entities": [(2, 10, "LIFESTYLE"), (35, 44, "LIFESTYLE"), (49, 54, "LIFESTYLE")]}),
    ("I'm on a halal diet, but I occasionally drink alcohol.", {"entities": [(14, 18, "LIFESTYLE"), (31, 36, "LIFESTYLE"), (51, 60, "LIFESTYLE")]}),
    ("I'm not into drugs, but I enjoy drinking occasionally.", {"entities": [(12, 16, "LIFESTYLE"), (28, 33, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I'm on a vegan diet, but I occasionally smoke.", {"entities": [(11, 16, "LIFESTYLE"), (31, 35, "LIFESTYLE"), (40, 46, "LIFESTYLE")]}),
    ("I smoke occasionally, but I'm committed to exercise.", {"entities": [(2, 13, "LIFESTYLE"), (30, 39, "LIFESTYLE")]}),
    ("I'm on a strict diet, but I occasionally enjoy a drink.", {"entities": [(13, 18, "LIFESTYLE"), (32, 41, "LIFESTYLE"), (50, 55, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally drink alcohol.", {"entities": [(2, 10, "LIFESTYLE"), (35, 41, "LIFESTYLE"), (52, 61, "LIFESTYLE")]}),
    ("I'm on a gluten-free diet, but I occasionally smoke.", {"entities": [(11, 22, "LIFESTYLE"), (32, 36, "LIFESTYLE"), (41, 47, "LIFESTYLE")]}),
    ("I'm not into drugs, and I prioritize a healthy diet.", {"entities": [(12, 16, "LIFESTYLE"), (31, 41, "LIFESTYLE"), (46, 56, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally enjoy a drink.", {"entities": [(2, 10, "LIFESTYLE"), (35, 44, "LIFESTYLE"), (49, 54, "LIFESTYLE")]}),
    ("I'm on a halal diet, but I occasionally drink alcohol.", {"entities": [(14, 18, "LIFESTYLE"), (31, 36, "LIFESTYLE"), (51, 60, "LIFESTYLE")]}),
    ("I'm not into drugs, but I enjoy drinking occasionally.", {"entities": [(12, 16, "LIFESTYLE"), (28, 33, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I'm on a vegan diet, but I occasionally smoke.", {"entities": [(11, 16, "LIFESTYLE"), (31, 35, "LIFESTYLE"), (40, 46, "LIFESTYLE")]}),
    ("I smoke occasionally, but I'm committed to exercise.", {"entities": [(2, 13, "LIFESTYLE"), (30, 39, "LIFESTYLE")]}),
    ("I'm on a strict diet, but I occasionally enjoy a drink.", {"entities": [(13, 18, "LIFESTYLE"), (32, 41, "LIFESTYLE"), (50, 55, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally drink alcohol.", {"entities": [(2, 10, "LIFESTYLE"), (35, 41, "LIFESTYLE"), (52, 61, "LIFESTYLE")]}),
    ("I'm on a gluten-free diet, but I occasionally smoke.", {"entities": [(11, 22, "LIFESTYLE"), (32, 36, "LIFESTYLE"), (41, 47, "LIFESTYLE")]}),
    ("I'm not into drugs, and I prioritize a healthy diet.", {"entities": [(12, 16, "LIFESTYLE"), (31, 41, "LIFESTYLE"), (46, 56, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally enjoy a drink.", {"entities": [(2, 10, "LIFESTYLE"), (35, 44, "LIFESTYLE"), (49, 54, "LIFESTYLE")]}),
    ("I'm on a halal diet, but I occasionally drink alcohol.", {"entities": [(14, 18, "LIFESTYLE"), (31, 36, "LIFESTYLE"), (51, 60, "LIFESTYLE")]}),
    ("I'm not into drugs, but I enjoy drinking occasionally.", {"entities": [(12, 16, "LIFESTYLE"), (28, 33, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I'm on a vegan diet, but I occasionally smoke.", {"entities": [(11, 16, "LIFESTYLE"), (31, 35, "LIFESTYLE"), (40, 46, "LIFESTYLE")]}),
    ("I smoke occasionally, but I'm committed to exercise.", {"entities": [(2, 13, "LIFESTYLE"), (30, 39, "LIFESTYLE")]}),
    ("I'm on a strict diet, but I occasionally enjoy a drink.", {"entities": [(13, 18, "LIFESTYLE"), (32, 41, "LIFESTYLE"), (50, 55, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally drink alcohol.", {"entities": [(2, 10, "LIFESTYLE"), (35, 41, "LIFESTYLE"), (52, 61, "LIFESTYLE")]}),
    ("I'm on a gluten-free diet, but I occasionally smoke.", {"entities": [(11, 22, "LIFESTYLE"), (32, 36, "LIFESTYLE"), (41, 47, "LIFESTYLE")]}),
    ("I'm not into drugs, and I prioritize a healthy diet.", {"entities": [(12, 16, "LIFESTYLE"), (31, 41, "LIFESTYLE"), (46, 56, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally enjoy a drink.", {"entities": [(2, 10, "LIFESTYLE"), (35, 44, "LIFESTYLE"), (49, 54, "LIFESTYLE")]}),
    ("I'm on a halal diet, but I occasionally drink alcohol.", {"entities": [(14, 18, "LIFESTYLE"), (31, 36, "LIFESTYLE"), (51, 60, "LIFESTYLE")]}),
    ("I'm not into drugs, but I enjoy drinking occasionally.", {"entities": [(12, 16, "LIFESTYLE"), (28, 33, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I'm on a vegan diet, but I occasionally smoke.", {"entities": [(11, 16, "LIFESTYLE"), (31, 35, "LIFESTYLE"), (40, 46, "LIFESTYLE")]}),
    ("I smoke occasionally, but I'm committed to exercise.", {"entities": [(2, 13, "LIFESTYLE"), (30, 39, "LIFESTYLE")]}),
    ("I'm on a strict diet, but I occasionally enjoy a drink.", {"entities": [(13, 18, "LIFESTYLE"), (32, 41, "LIFESTYLE"), (50, 55, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally drink alcohol.", {"entities": [(2, 10, "LIFESTYLE"), (35, 41, "LIFESTYLE"), (52, 61, "LIFESTYLE")]}),
    ("I'm on a gluten-free diet, but I occasionally smoke.", {"entities": [(11, 22, "LIFESTYLE"), (32, 36, "LIFESTYLE"), (41, 47, "LIFESTYLE")]}),
    ("I'm not into drugs, and I prioritize a healthy diet.", {"entities": [(12, 16, "LIFESTYLE"), (31, 41, "LIFESTYLE"), (46, 56, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally enjoy a drink.", {"entities": [(2, 10, "LIFESTYLE"), (35, 44, "LIFESTYLE"), (49, 54, "LIFESTYLE")]}),
    ("I'm on a halal diet, but I occasionally drink alcohol.", {"entities": [(14, 18, "LIFESTYLE"), (31, 36, "LIFESTYLE"), (51, 60, "LIFESTYLE")]}),
    ("I'm not into drugs, but I enjoy drinking occasionally.", {"entities": [(12, 16, "LIFESTYLE"), (28, 33, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I'm on a vegan diet, but I occasionally smoke.", {"entities": [(11, 16, "LIFESTYLE"), (31, 35, "LIFESTYLE"), (40, 46, "LIFESTYLE")]}),
    ("I smoke occasionally, but I'm committed to exercise.", {"entities": [(2, 13, "LIFESTYLE"), (30, 39, "LIFESTYLE")]}),
    ("I'm on a strict diet, but I occasionally enjoy a drink.", {"entities": [(13, 18, "LIFESTYLE"), (32, 41, "LIFESTYLE"), (50, 55, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally drink alcohol.", {"entities": [(2, 10, "LIFESTYLE"), (35, 41, "LIFESTYLE"), (52, 61, "LIFESTYLE")]}),
    ("I'm on a gluten-free diet, but I occasionally smoke.", {"entities": [(11, 22, "LIFESTYLE"), (32, 36, "LIFESTYLE"), (41, 47, "LIFESTYLE")]}),
    ("I'm not into drugs, and I prioritize a healthy diet.", {"entities": [(12, 16, "LIFESTYLE"), (31, 41, "LIFESTYLE"), (46, 56, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally enjoy a drink.", {"entities": [(2, 10, "LIFESTYLE"), (35, 44, "LIFESTYLE"), (49, 54, "LIFESTYLE")]}),
    ("I'm on a halal diet, but I occasionally drink alcohol.", {"entities": [(14, 18, "LIFESTYLE"), (31, 36, "LIFESTYLE"), (51, 60, "LIFESTYLE")]}),
    ("I'm not into drugs, but I enjoy drinking occasionally.", {"entities": [(12, 16, "LIFESTYLE"), (28, 33, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I'm on a vegan diet, but I occasionally smoke.", {"entities": [(11, 16, "LIFESTYLE"), (31, 35, "LIFESTYLE"), (40, 46, "LIFESTYLE")]}),
    ("I smoke occasionally, but I'm committed to exercise.", {"entities": [(2, 13, "LIFESTYLE"), (30, 39, "LIFESTYLE")]}),
    ("I'm on a strict diet, but I occasionally enjoy a drink.", {"entities": [(13, 18, "LIFESTYLE"), (32, 41, "LIFESTYLE"), (50, 55, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally drink alcohol.", {"entities": [(2, 10, "LIFESTYLE"), (35, 41, "LIFESTYLE"), (52, 61, "LIFESTYLE")]}),
    ("I'm on a gluten-free diet, but I occasionally smoke.", {"entities": [(11, 22, "LIFESTYLE"), (32, 36, "LIFESTYLE"), (41, 47, "LIFESTYLE")]}),
    ("I'm not into drugs, and I prioritize a healthy diet.", {"entities": [(12, 16, "LIFESTYLE"), (31, 41, "LIFESTYLE"), (46, 56, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally enjoy a drink.", {"entities": [(2, 10, "LIFESTYLE"), (35, 44, "LIFESTYLE"), (49, 54, "LIFESTYLE")]}),
    ("I'm on a halal diet, but I occasionally drink alcohol.", {"entities": [(14, 18, "LIFESTYLE"), (31, 36, "LIFESTYLE"), (51, 60, "LIFESTYLE")]}),
    ("I'm not into drugs, but I enjoy drinking occasionally.", {"entities": [(12, 16, "LIFESTYLE"), (28, 33, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I'm on a vegan diet, but I occasionally smoke.", {"entities": [(11, 16, "LIFESTYLE"), (31, 35, "LIFESTYLE"), (40, 46, "LIFESTYLE")]}),
    ("I smoke occasionally, but I'm committed to exercise.", {"entities": [(2, 13, "LIFESTYLE"), (30, 39, "LIFESTYLE")]}),
    ("I'm on a strict diet, but I occasionally enjoy a drink.", {"entities": [(13, 18, "LIFESTYLE"), (32, 41, "LIFESTYLE"), (50, 55, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally drink alcohol.", {"entities": [(2, 10, "LIFESTYLE"), (35, 41, "LIFESTYLE"), (52, 61, "LIFESTYLE")]}),
    ("I'm on a gluten-free diet, but I occasionally smoke.", {"entities": [(11, 22, "LIFESTYLE"), (32, 36, "LIFESTYLE"), (41, 47, "LIFESTYLE")]}),
    ("I'm not into drugs, and I prioritize a healthy diet.", {"entities": [(12, 16, "LIFESTYLE"), (31, 41, "LIFESTYLE"), (46, 56, "LIFESTYLE")]}),
    ("I exercise daily, but I occasionally enjoy a drink.", {"entities": [(2, 10, "LIFESTYLE"), (35, 44, "LIFESTYLE"), (49, 54, "LIFESTYLE")]}),
    ("I'm on a halal diet, but I occasionally drink alcohol.", {"entities": [(14, 18, "LIFESTYLE"), (31, 36, "LIFESTYLE"), (51, 60, "LIFESTYLE")]}),
    ("I exercise daily.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise every day.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise often.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise consistently.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise religiously.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise without fail.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I make sure to exercise.", {"entities": [(15, 23, "LIFESTYLE")]}),
    ("I always exercise.", {"entities": [(7, 15, "LIFESTYLE")]}),
    ("I exercise regularly without fail.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise as part of my routine.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise religiously every morning.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise consistently every week.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise daily without exception.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I make exercise a priority.", {"entities": [(6, 14, "LIFESTYLE")]}),
    ("I ensure to exercise regularly.", {"entities": [(12, 20, "LIFESTYLE")]}),
    ("I always make time to exercise.", {"entities": [(20, 28, "LIFESTYLE")]}),
    ("I never skip my exercise routine.", {"entities": [(10, 18, "LIFESTYLE")]}),
    ("I'm committed to exercise.", {"entities": [(15, 23, "LIFESTYLE")]}),
    ("I am dedicated to exercise.", {"entities": [(11, 19, "LIFESTYLE")]}),
    ("I am devoted to exercise.", {"entities": [(7, 15, "LIFESTYLE")]}),
    ("I am serious about exercise.", {"entities": [(10, 18, "LIFESTYLE")]}),
    ("I am passionate about exercise.", {"entities": [(10, 18, "LIFESTYLE")]}),
    ("I am enthusiastic about exercise.", {"entities": [(10, 18, "LIFESTYLE")]}),
    ("I never miss my exercise sessions.", {"entities": [(12, 20, "LIFESTYLE")]}),
    ("I engage in regular exercise.", {"entities": [(12, 20, "LIFESTYLE")]}),
    ("I incorporate exercise into my daily routine.", {"entities": [(14, 22, "LIFESTYLE")]}),
    ("I am consistent with exercise.", {"entities": [(16, 24, "LIFESTYLE")]}),
    ("I prioritize exercise.", {"entities": [(12, 20, "LIFESTYLE")]}),
    ("I am disciplined with exercise.", {"entities": [(14, 22, "LIFESTYLE")]}),
    ("I adhere to my exercise regimen.", {"entities": [(10, 18, "LIFESTYLE")]}),
    ("I stick to my exercise plan.", {"entities": [(9, 17, "LIFESTYLE")]}),
    ("I follow through with exercise.", {"entities": [(15, 23, "LIFESTYLE")]}),
    ("I'm dedicated to daily exercise.", {"entities": [(14, 22, "LIFESTYLE")]}),
    ("I'm consistent with exercise.", {"entities": [(14, 22, "LIFESTYLE")]}),
    ("I'm committed to regular exercise.", {"entities": [(14, 22, "LIFESTYLE")]}),
    ("I'm serious about exercise.", {"entities": [(7, 15, "LIFESTYLE")]}),
    ("I'm passionate about exercise.", {"entities": [(7, 15, "LIFESTYLE")]}),
    ("I'm enthusiastic about exercise.", {"entities": [(7, 15, "LIFESTYLE")]}),
    ("I never miss my daily exercise.", {"entities": [(14, 22, "LIFESTYLE")]}),
    ("I never skip exercise.", {"entities": [(12, 20, "LIFESTYLE")]}),
    ("I engage in exercise regularly.", {"entities": [(12, 20, "LIFESTYLE")]}),
    ("I incorporate regular exercise into my routine.", {"entities": [(14, 22, "LIFESTYLE")]}),
    ("I'm consistent with my exercise routine.", {"entities": [(15, 23, "LIFESTYLE")]}),
    ("I prioritize daily exercise.", {"entities": [(12, 20, "LIFESTYLE")]}),
    ("I'm disciplined with my exercise routine.", {"entities": [(15, 23, "LIFESTYLE")]}),
    ("I adhere to my daily exercise plan.", {"entities": [(10, 18, "LIFESTYLE")]}),
    ("I stick to my exercise schedule.", {"entities": [(9, 17, "LIFESTYLE")]}),
    ("I follow through with my exercise routine.", {"entities": [(15, 23, "LIFESTYLE")]}),
    ("I'm dedicated to exercising regularly.", {"entities": [(14, 24, "LIFESTYLE")]}),
    ("I'm consistent with my workout routine.", {"entities": [(15, 25, "LIFESTYLE")]}),
    ("I'm committed to regular physical activity.", {"entities": [(14, 29, "LIFESTYLE")]}),
    ("I'm serious about my fitness regimen.", {"entities": [(12, 26, "LIFESTYLE")]}),
    ("I'm passionate about staying fit.", {"entities": [(7, 18, "LIFESTYLE")]}),
    ("I'm enthusiastic about my daily workouts.", {"entities": [(7, 24, "LIFESTYLE")]}),
    ("I never miss my daily workout.", {"entities": [(14, 24, "LIFESTYLE")]}),
    ("I never skip my workout.", {"entities": [(12, 19, "LIFESTYLE")]}),
    ("I engage in my workout regularly.", {"entities": [(12, 24, "LIFESTYLE")]}),
    ("I incorporate my workout into my routine.", {"entities": [(14, 24, "LIFESTYLE")]}),
    ("I'm consistent with my fitness routine.", {"entities": [(15, 26, "LIFESTYLE")]}),
    ("I prioritize my daily workout.", {"entities": [(12, 19, "LIFESTYLE")]}),
    ("I'm disciplined with my fitness routine.", {"entities": [(15, 26, "LIFESTYLE")]}),
    ("I adhere to my daily workout plan.", {"entities": [(10, 17, "LIFESTYLE")]}),
    ("I stick to my workout schedule.", {"entities": [(9, 16, "LIFESTYLE")]}),
    ("I exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise every day.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise often.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise consistently.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise religiously.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise without fail.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I make sure to exercise.", {"entities": [(15, 23, "LIFESTYLE")]}),
    ("I always exercise.", {"entities": [(7, 15, "LIFESTYLE")]}),
    ("I exercise regularly without fail.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise as part of my routine.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise religiously every morning.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise consistently every week.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise daily without exception.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I make exercise a priority.", {"entities": [(6, 14, "LIFESTYLE")]}),
    ("I ensure to exercise regularly.", {"entities": [(12, 20, "LIFESTYLE")]}),
    ("I always make time to exercise.", {"entities": [(20, 28, "LIFESTYLE")]}),
    ("I never skip my exercise routine.", {"entities": [(10, 18, "LIFESTYLE")]}),
    ("I'm committed to exercise.", {"entities": [(15, 23, "LIFESTYLE")]}),
    ("I am dedicated to exercise.", {"entities": [(11, 19, "LIFESTYLE")]}),
    ("I am devoted to exercise.", {"entities": [(7, 15, "LIFESTYLE")]}),
    ("I am serious about exercise.", {"entities": [(10, 18, "LIFESTYLE")]}),
    ("I am passionate about exercise.", {"entities": [(10, 18, "LIFESTYLE")]}),
    ("I am enthusiastic about exercise.", {"entities": [(10, 18, "LIFESTYLE")]}),
    ("I never miss my exercise sessions.", {"entities": [(12, 20, "LIFESTYLE")]}),
    ("I engage in regular exercise.", {"entities": [(12, 20, "LIFESTYLE")]}),
    ("I incorporate exercise into my daily routine.", {"entities": [(14, 22, "LIFESTYLE")]}),
    ("I am consistent with exercise.", {"entities": [(16, 24, "LIFESTYLE")]}),
    ("I prioritize exercise.", {"entities": [(12, 20, "LIFESTYLE")]}),
    ("I am disciplined with exercise.", {"entities": [(14, 22, "LIFESTYLE")]}),
    ("I adhere to my exercise regimen.", {"entities": [(10, 18, "LIFESTYLE")]}),
    ("I stick to my exercise plan.", {"entities": [(9, 17, "LIFESTYLE")]}),
    ("I follow through with exercise.", {"entities": [(15, 23, "LIFESTYLE")]}),
    ("I'm dedicated to daily exercise.", {"entities": [(14, 22, "LIFESTYLE")]}),
    ("I'm consistent with exercise.", {"entities": [(14, 22, "LIFESTYLE")]}),
    ("I'm committed to regular exercise.", {"entities": [(14, 22, "LIFESTYLE")]}),
    ("I'm serious about exercise.", {"entities": [(7, 15, "LIFESTYLE")]}),
    ("I'm passionate about exercise.", {"entities": [(7, 15, "LIFESTYLE")]}),
    ("I'm enthusiastic about exercise.", {"entities": [(7, 15, "LIFESTYLE")]}),
    ("I never miss my daily exercise.", {"entities": [(14, 22, "LIFESTYLE")]}),
    ("I never skip exercise.", {"entities": [(12, 20, "LIFESTYLE")]}),
    ("I engage in exercise regularly.", {"entities": [(12, 20, "LIFESTYLE")]}),
    ("I incorporate regular exercise into my routine.", {"entities": [(14, 22, "LIFESTYLE")]}),
    ("I'm consistent with my exercise routine.", {"entities": [(15, 23, "LIFESTYLE")]}),
    ("I prioritize daily exercise.", {"entities": [(12, 20, "LIFESTYLE")]}),
    ("I'm disciplined with my exercise routine.", {"entities": [(15, 23, "LIFESTYLE")]}),
    ("I adhere to my daily exercise plan.", {"entities": [(10, 18, "LIFESTYLE")]}),
    ("I stick to my exercise schedule.", {"entities": [(9, 16, "LIFESTYLE")]}),
    ("I follow through with my exercise routine.", {"entities": [(15, 23, "LIFESTYLE")]}),
    ("I'm dedicated to exercising regularly.", {"entities": [(14, 24, "LIFESTYLE")]}),
    ("I'm consistent with my workout routine.", {"entities": [(15, 25, "LIFESTYLE")]}),
    ("I'm committed to regular physical activity.", {"entities": [(14, 29, "LIFESTYLE")]}),
    ("I'm serious about my fitness regimen.", {"entities": [(12, 26, "LIFESTYLE")]}),
    ("I'm passionate about staying fit.", {"entities": [(7, 18, "LIFESTYLE")]}),
    ("I'm enthusiastic about my daily workouts.", {"entities": [(7, 24, "LIFESTYLE")]}),
    ("I never miss my daily workout.", {"entities": [(14, 24, "LIFESTYLE")]}),
    ("I never skip my workout.", {"entities": [(12, 19, "LIFESTYLE")]}),
    ("I engage in my workout regularly.", {"entities": [(12, 24, "LIFESTYLE")]}),
    ("I incorporate my workout into my routine.", {"entities": [(14, 24, "LIFESTYLE")]}),
    ("I'm consistent with my fitness routine.", {"entities": [(15, 26, "LIFESTYLE")]}),
    ("I prioritize my daily workout.", {"entities": [(12, 19, "LIFESTYLE")]}),
    ("I'm disciplined with my fitness routine.", {"entities": [(15, 26, "LIFESTYLE")]}),
    ("I adhere to my daily workout plan.", {"entities": [(10, 17, "LIFESTYLE")]}),
    ("I stick to my workout schedule.", {"entities": [(9, 16, "LIFESTYLE")]}),
    ("I follow through with my fitness routine.", {"entities": [(15, 26, "LIFESTYLE")]}),
    ("I'm vegan.", {"entities": [(3, 8, "LIFESTYLE")]}),
    ("I'm a vegan.", {"entities": [(3, 8, "LIFESTYLE")]}),
    ("I'm vegetarian.", {"entities": [(3, 12, "LIFESTYLE")]}),
    ("I'm a vegetarian.", {"entities": [(3, 12, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("I follow a vegetarian diet.", {"entities": [(10, 19, "LIFESTYLE")]}),
    ("I stick to veganism.", {"entities": [(10, 17, "LIFESTYLE")]}),
    ("I adhere to veganism.", {"entities": [(10, 17, "LIFESTYLE")]}),
    ("I'm strictly vegan.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I'm strictly vegetarian.", {"entities": [(11, 20, "LIFESTYLE")]}),
    ("I'm committed to veganism.", {"entities": [(16, 23, "LIFESTYLE")]}),
    ("I'm committed to vegetarianism.", {"entities": [(16, 25, "LIFESTYLE")]}),
    ("I strictly adhere to veganism.", {"entities": [(22, 29, "LIFESTYLE")]}),
    ("I strictly adhere to vegetarianism.", {"entities": [(22, 31, "LIFESTYLE")]}),
    ("I'm vegan by choice.", {"entities": [(3, 8, "LIFESTYLE")]}),
    ("I'm vegetarian by choice.", {"entities": [(3, 12, "LIFESTYLE")]}),
    ("I maintain a vegan lifestyle.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I maintain a vegetarian lifestyle.", {"entities": [(11, 20, "LIFESTYLE")]}),
    ("I'm dedicated to veganism.", {"entities": [(16, 23, "LIFESTYLE")]}),
    ("I'm dedicated to vegetarianism.", {"entities": [(16, 25, "LIFESTYLE")]}),
    ("I'm fully vegan.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("I'm fully vegetarian.", {"entities": [(10, 19, "LIFESTYLE")]}),
    ("I strictly follow veganism.", {"entities": [(20, 27, "LIFESTYLE")]}),
    ("I strictly follow vegetarianism.", {"entities": [(20, 29, "LIFESTYLE")]}),
    ("I'm committed to being vegan.", {"entities": [(16, 21, "LIFESTYLE")]}),
    ("I'm committed to being vegetarian.", {"entities": [(16, 25, "LIFESTYLE")]}),
    ("I adhere strictly to veganism.", {"entities": [(20, 27, "LIFESTYLE")]}),
    ("I adhere strictly to vegetarianism.", {"entities": [(20, 29, "LIFESTYLE")]}),
    ("I'm vegan for ethical reasons.", {"entities": [(3, 8, "LIFESTYLE")]}),
    ("I'm vegetarian for ethical reasons.", {"entities": [(3, 12, "LIFESTYLE")]}),
    ("I'm vegan for environmental reasons.", {"entities": [(3, 8, "LIFESTYLE")]}),
    ("I'm vegetarian for environmental reasons.", {"entities": [(3, 12, "LIFESTYLE")]}),
    ("I'm vegan for health reasons.", {"entities": [(3, 8, "LIFESTYLE")]}),
    ("I'm vegetarian for health reasons.", {"entities": [(3, 12, "LIFESTYLE")]}),
    ("I'm a strict vegan.", {"entities": [(3, 8, "LIFESTYLE")]}),
    ("I'm a strict vegetarian.", {"entities": [(3, 12, "LIFESTYLE")]}),
    ("I'm a vegan by choice.", {"entities": [(3, 8, "LIFESTYLE")]}),
    ("I'm a vegetarian by choice.", {"entities": [(3, 12, "LIFESTYLE")]}),
    ("I'm a committed vegan.", {"entities": [(3, 8, "LIFESTYLE")]}),
    ("I'm a committed vegetarian.", {"entities": [(3, 12, "LIFESTYLE")]}),
    ("I'm a vegan for ethical reasons.", {"entities": [(3, 8, "LIFESTYLE")]}),
    ("I'm a vegetarian for ethical reasons.", {"entities": [(3, 12, "LIFESTYLE")]}),
    ("I'm a vegan for environmental reasons.", {"entities": [(3, 8, "LIFESTYLE")]}),
    ("I'm a vegetarian for environmental reasons.", {"entities": [(3, 12, "LIFESTYLE")]}),
    ("I'm a vegan for health reasons.", {"entities": [(3, 8, "LIFESTYLE")]}),
    ("I'm a vegetarian for health reasons.", {"entities": [(3, 12, "LIFESTYLE")]}),
    ("I've chosen to be vegan.", {"entities": [(16, 21, "LIFESTYLE")]}),
    ("I've chosen to be vegetarian.", {"entities": [(16, 25, "LIFESTYLE")]}),
    ("I've embraced veganism.", {"entities": [(14, 21, "LIFESTYLE")]}),
    ("I've embraced vegetarianism.", {"entities": [(14, 23, "LIFESTYLE")]}),
    ("I've adopted a vegan lifestyle.", {"entities": [(13, 18, "LIFESTYLE")]}),
    ("I've adopted a vegetarian lifestyle.", {"entities": [(13, 22, "LIFESTYLE")]}),
    ("I've committed to veganism.", {"entities": [(19, 26, "LIFESTYLE")]}),
    ("I've committed to vegetarianism.", {"entities": [(19, 28, "LIFESTYLE")]}),
    ("I've chosen a vegan lifestyle.", {"entities": [(13, 18, "LIFESTYLE")]}),
    ("I've chosen a vegetarian lifestyle.", {"entities": [(13, 22, "LIFESTYLE")]}),
    ("I've dedicated myself to veganism.", {"entities": [(15, 22, "LIFESTYLE")]}),
    ("I've dedicated myself to vegetarianism.", {"entities": [(15, 24, "LIFESTYLE")]}),
    ("I've gone vegan.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("I've gone vegetarian.", {"entities": [(9, 18, "LIFESTYLE")]}),
    ("I've transitioned to veganism.", {"entities": [(15, 22, "LIFESTYLE")]}),
    ("I've transitioned to vegetarianism.", {"entities": [(15, 24, "LIFESTYLE")]}),
    ("I've become a vegan.", {"entities": [(12, 17, "LIFESTYLE")]}),
    ("I've become a vegetarian.", {"entities": [(12, 21, "LIFESTYLE")]}),
    ("I've embraced being vegan.", {"entities": [(13, 18, "LIFESTYLE")]}),
    ("I've embraced being vegetarian.", {"entities": [(13, 22, "LIFESTYLE")]}),
    ("I've adopted the vegan lifestyle.", {"entities": [(13, 18, "LIFESTYLE")]}),
    ("I've adopted the vegetarian lifestyle.", {"entities": [(13, 22, "LIFESTYLE")]}),
    ("I've committed to being vegan.", {"entities": [(19, 24, "LIFESTYLE")]}),
    ("I've committed to being vegetarian.", {"entities": [(19, 28, "LIFESTYLE")]}),
    ("I've chosen the vegan lifestyle.", {"entities": [(13, 18, "LIFESTYLE")]}),
    ("I've chosen the vegetarian lifestyle.", {"entities": [(13, 22, "LIFESTYLE")]}),
    ("I've dedicated myself to being vegan.", {"entities": [(15, 24, "LIFESTYLE")]}),
    ("I've dedicated myself to being vegetarian.", {"entities": [(15, 24, "LIFESTYLE")]}),
    ("I've transitioned into veganism.", {"entities": [(15, 22, "LIFESTYLE")]}),
    ("I've transitioned into vegetarianism.", {"entities": [(15, 24, "LIFESTYLE")]}),
    ("I've taken up being vegan.", {"entities": [(12, 17, "LIFESTYLE")]}),
    ("I've taken up being vegetarian.", {"entities": [(12, 21, "LIFESTYLE")]}),
    ("I've embraced veganism.", {"entities": [(13, 20, "LIFESTYLE")]}),
    ("I've embraced vegetarianism.", {"entities": [(13, 22, "LIFESTYLE")]}),
    ("I've adopted a vegan lifestyle.", {"entities": [(13, 18, "LIFESTYLE")]}),
    ("I've adopted a vegetarian lifestyle.", {"entities": [(13, 22, "LIFESTYLE")]}),
    ("I've committed to veganism.", {"entities": [(19, 26, "LIFESTYLE")]}),
    ("I've committed to vegetarianism.", {"entities": [(19, 28, "LIFESTYLE")]}),
    ("I've chosen a vegan lifestyle.", {"entities": [(13, 18, "LIFESTYLE")]}),
    ("I've chosen a vegetarian lifestyle.", {"entities": [(13, 22, "LIFESTYLE")]}),
    ("I've dedicated myself to veganism.", {"entities": [(15, 22, "LIFESTYLE")]}),
    ("I've dedicated myself to vegetarianism.", {"entities": [(15, 24, "LIFESTYLE")]}),
    ("I'm vegan.", {"entities": [(3, 8, "LIFESTYLE")]}),
    ("I'm vegetarian.", {"entities": [(3, 12, "LIFESTYLE")]}),
    ("I follow a vegan diet.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("I follow a vegetarian diet.", {"entities": [(10, 19, "LIFESTYLE")]}),
    ("I'm strictly vegan.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I'm strictly vegetarian.", {"entities": [(11, 20, "LIFESTYLE")]}),
    ("I'm vegan by choice.", {"entities": [(3, 8, "LIFESTYLE")]}),
    ("I'm vegetarian by choice.", {"entities": [(3, 12, "LIFESTYLE")]}),
    ("I maintain a vegan lifestyle.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I maintain a vegetarian lifestyle.", {"entities": [(11, 20, "LIFESTYLE")]}),
    ("I'm dedicated to veganism.", {"entities": [(16, 23, "LIFESTYLE")]}),
    ("I'm dedicated to vegetarianism.", {"entities": [(16, 25, "LIFESTYLE")]}),
    ("I'm fully vegan.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("I'm fully vegetarian.", {"entities": [(10, 19, "LIFESTYLE")]}),
    ("I'm vegan for ethical reasons.", {"entities": [(3, 8, "LIFESTYLE")]}),
    ("I'm vegetarian for ethical reasons.", {"entities": [(3, 12, "LIFESTYLE")]}),
    ("I'm vegan for environmental reasons.", {"entities": [(3, 8, "LIFESTYLE")]}),
    ("I'm vegetarian for environmental reasons.", {"entities": [(3, 12, "LIFESTYLE")]}),
    ("I'm vegan for health reasons.", {"entities": [(3, 8, "LIFESTYLE")]}),
    ("I'm vegetarian for health reasons.", {"entities": [(3, 12, "LIFESTYLE")]}),
    ("I'm a strict vegan.", {"entities": [(3, 8, "LIFESTYLE")]}),
    ("I'm a strict vegetarian.", {"entities": [(3, 12, "LIFESTYLE")]}),
    ("I'm a vegan by choice.", {"entities": [(3, 8, "LIFESTYLE")]}),
    ("I'm a vegetarian by choice.", {"entities": [(3, 12, "LIFESTYLE")]}),
    ("I'm a committed vegan.", {"entities": [(3, 8, "LIFESTYLE")]}),
    ("I'm a committed vegetarian.", {"entities": [(3, 12, "LIFESTYLE")]}),
    ("I'm a vegan for ethical reasons.", {"entities": [(3, 8, "LIFESTYLE")]}),
    ("I'm a vegetarian for ethical reasons.", {"entities": [(3, 12, "LIFESTYLE")]}),
    ("I'm a vegan for environmental reasons.", {"entities": [(3, 8, "LIFESTYLE")]}),
    ("I'm a vegetarian for environmental reasons.", {"entities": [(3, 12, "LIFESTYLE")]}),
    ("I'm a vegan for health reasons.", {"entities": [(3, 8, "LIFESTYLE")]}),
    ("I'm a vegetarian for health reasons.", {"entities": [(3, 12, "LIFESTYLE")]}),
    ("I've chosen to be vegan.", {"entities": [(16, 21, "LIFESTYLE")]}),
    ("I've chosen to be vegetarian.", {"entities": [(16, 25, "LIFESTYLE")]}),
    ("I've embraced veganism.", {"entities": [(14, 21, "LIFESTYLE")]}),
    ("I've embraced vegetarianism.", {"entities": [(14, 23, "LIFESTYLE")]}),
    ("I've adopted a vegan lifestyle.", {"entities": [(13, 18, "LIFESTYLE")]}),
    ("I've adopted a vegetarian lifestyle.", {"entities": [(13, 22, "LIFESTYLE")]}),
    ("I've committed to veganism.", {"entities": [(19, 26, "LIFESTYLE")]}),
    ("I've committed to vegetarianism.", {"entities": [(19, 28, "LIFESTYLE")]}),
    ("I've chosen a vegan lifestyle.", {"entities": [(13, 18, "LIFESTYLE")]}),
    ("I've chosen a vegetarian lifestyle.", {"entities": [(13, 22, "LIFESTYLE")]}),
    ("I've dedicated myself to veganism.", {"entities": [(15, 22, "LIFESTYLE")]}),
    ("I've dedicated myself to vegetarianism.", {"entities": [(15, 24, "LIFESTYLE")]}),
    ("I've gone vegan.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("I've gone vegetarian.", {"entities": [(9, 18, "LIFESTYLE")]}),
    ("I've transitioned to veganism.", {"entities": [(15, 22, "LIFESTYLE")]}),
    ("I've transitioned to vegetarianism.", {"entities": [(15, 24, "LIFESTYLE")]}),
    ("I've become a vegan.", {"entities": [(12, 17, "LIFESTYLE")]}),
    ("I've become a vegetarian.", {"entities": [(12, 21, "LIFESTYLE")]}),
    ("I've embraced being vegan.", {"entities": [(13, 18, "LIFESTYLE")]}),
    ("I've embraced being vegetarian.", {"entities": [(13, 22, "LIFESTYLE")]}),
    ("I've adopted the vegan lifestyle.", {"entities": [(13, 18, "LIFESTYLE")]}),
    ("I've adopted the vegetarian lifestyle.", {"entities": [(13, 22, "LIFESTYLE")]}),
    ("I've committed to being vegan.", {"entities": [(19, 24, "LIFESTYLE")]}),
    ("I've committed to being vegetarian.", {"entities": [(19, 28, "LIFESTYLE")]}),
    ("I've chosen the vegan lifestyle.", {"entities": [(13, 18, "LIFESTYLE")]}),
    ("I've chosen the vegetarian lifestyle.", {"entities": [(13, 22, "LIFESTYLE")]}),
    ("I've dedicated myself to veganism.", {"entities": [(15, 24, "LIFESTYLE")]}),
    ("I've dedicated myself to vegetarianism.", {"entities": [(15, 24, "LIFESTYLE")]}),
    ("I've transitioned into veganism.", {"entities": [(15, 22, "LIFESTYLE")]}),
    ("I've transitioned into vegetarianism.", {"entities": [(15, 24, "LIFESTYLE")]}),
    ("I've taken up being vegan.", {"entities": [(12, 17, "LIFESTYLE")]}),
    ("I've taken up being vegetarian.", {"entities": [(12, 21, "LIFESTYLE")]}),
    ("I've embraced veganism.", {"entities": [(13, 20, "LIFESTYLE")]}),
    ("I've embraced vegetarianism.", {"entities": [(13, 22, "LIFESTYLE")]}),
    ("I've adopted a vegan lifestyle.", {"entities": [(13, 18, "LIFESTYLE")]}),
    ("I've adopted a vegetarian lifestyle.", {"entities": [(13, 22, "LIFESTYLE")]}),
    ("I've committed to veganism.", {"entities": [(19, 26, "LIFESTYLE")]}),
    ("I've committed to vegetarianism.", {"entities": [(19, 28, "LIFESTYLE")]}),
    ("I've chosen a vegan lifestyle.", {"entities": [(13, 18, "LIFESTYLE")]}),
    ("I've chosen a vegetarian lifestyle.", {"entities": [(13, 22, "LIFESTYLE")]}),
    ("I've dedicated myself to veganism.", {"entities": [(15, 22, "LIFESTYLE")]}),
    ("I've dedicated myself to vegetarianism.", {"entities": [(15, 24, "LIFESTYLE")]}),
    ("I follow a halal diet.", {"entities": [(10, 14, "LIFESTYLE")]}),
    ("I stick to halal.", {"entities": [(9, 13, "LIFESTYLE")]}),
    ("I adhere to halal.", {"entities": [(10, 14, "LIFESTYLE")]}),
    ("I'm strictly halal.", {"entities": [(11, 15, "LIFESTYLE")]}),
    ("I'm halal.", {"entities": [(3, 7, "LIFESTYLE")]}),
    ("I only eat halal.", {"entities": [(11, 15, "LIFESTYLE")]}),
    ("I follow a kosher diet.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("I stick to kosher.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("I adhere to kosher.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("I'm strictly kosher.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I'm kosher.", {"entities": [(3, 8, "LIFESTYLE")]}),
    ("I only eat kosher.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I follow a halal diet.", {"entities": [(10, 14, "LIFESTYLE")]}),
    ("I stick to halal.", {"entities": [(9, 13, "LIFESTYLE")]}),
    ("I adhere to halal.", {"entities": [(10, 14, "LIFESTYLE")]}),
    ("I'm strictly halal.", {"entities": [(11, 15, "LIFESTYLE")]}),
    ("I'm halal.", {"entities": [(3, 7, "LIFESTYLE")]}),
    ("I only eat halal.", {"entities": [(11, 15, "LIFESTYLE")]}),
    ("I follow a kosher diet.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("I stick to kosher.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("I adhere to kosher.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("I'm strictly kosher.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I'm kosher.", {"entities": [(3, 8, "LIFESTYLE")]}),
    ("I only eat kosher.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I follow a halal diet.", {"entities": [(10, 14, "LIFESTYLE")]}),
    ("I stick to halal.", {"entities": [(9, 13, "LIFESTYLE")]}),
    ("I adhere to halal.", {"entities": [(10, 14, "LIFESTYLE")]}),
    ("I'm strictly halal.", {"entities": [(11, 15, "LIFESTYLE")]}),
    ("I'm halal.", {"entities": [(3, 7, "LIFESTYLE")]}),
    ("I only eat halal.", {"entities": [(11, 15, "LIFESTYLE")]}),
    ("I follow a kosher diet.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("I stick to kosher.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("I adhere to kosher.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("I'm strictly kosher.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I'm kosher.", {"entities": [(3, 8, "LIFESTYLE")]}),
    ("I only eat kosher.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I follow a halal diet.", {"entities": [(10, 14, "LIFESTYLE")]}),
    ("I stick to halal.", {"entities": [(9, 13, "LIFESTYLE")]}),
    ("I adhere to halal.", {"entities": [(10, 14, "LIFESTYLE")]}),
    ("I'm strictly halal.", {"entities": [(11, 15, "LIFESTYLE")]}),
    ("I'm halal.", {"entities": [(3, 7, "LIFESTYLE")]}),
    ("I only eat halal.", {"entities": [(11, 15, "LIFESTYLE")]}),
    ("I follow a kosher diet.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("I stick to kosher.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("I adhere to kosher.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("I'm strictly kosher.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I'm kosher.", {"entities": [(3, 8, "LIFESTYLE")]}),
    ("I only eat kosher.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I follow a halal diet.", {"entities": [(10, 14, "LIFESTYLE")]}),
    ("I stick to halal.", {"entities": [(9, 13, "LIFESTYLE")]}),
    ("I adhere to halal.", {"entities": [(10, 14, "LIFESTYLE")]}),
    ("I'm strictly halal.", {"entities": [(11, 15, "LIFESTYLE")]}),
    ("I'm halal.", {"entities": [(3, 7, "LIFESTYLE")]}),
    ("I only eat halal.", {"entities": [(11, 15, "LIFESTYLE")]}),
    ("I follow a kosher diet.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("I stick to kosher.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("I adhere to kosher.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("I'm strictly kosher.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I'm kosher.", {"entities": [(3, 8, "LIFESTYLE")]}),
    ("I only eat kosher.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I follow a halal diet.", {"entities": [(10, 14, "LIFESTYLE")]}),
    ("I stick to halal.", {"entities": [(9, 13, "LIFESTYLE")]}),
    ("I adhere to halal.", {"entities": [(10, 14, "LIFESTYLE")]}),
    ("I'm strictly halal.", {"entities": [(11, 15, "LIFESTYLE")]}),
    ("I'm halal.", {"entities": [(3, 7, "LIFESTYLE")]}),
    ("I only eat halal.", {"entities": [(11, 15, "LIFESTYLE")]}),
    ("I follow a kosher diet.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("I stick to kosher.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("I adhere to kosher.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("I'm strictly kosher.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I'm kosher.", {"entities": [(3, 8, "LIFESTYLE")]}),
    ("I only eat kosher.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I follow a halal diet.", {"entities": [(10, 14, "LIFESTYLE")]}),
    ("I stick to halal.", {"entities": [(9, 13, "LIFESTYLE")]}),
    ("I adhere to halal.", {"entities": [(10, 14, "LIFESTYLE")]}),
    ("I'm strictly halal.", {"entities": [(11, 15, "LIFESTYLE")]}),
    ("I'm halal.", {"entities": [(3, 7, "LIFESTYLE")]}),
    ("I only eat halal.", {"entities": [(11, 15, "LIFESTYLE")]}),
    ("I follow a kosher diet.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("I stick to kosher.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("I adhere to kosher.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("I'm strictly kosher.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I'm kosher.", {"entities": [(3, 8, "LIFESTYLE")]}),
    ("I only eat kosher.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I strictly adhere to a halal diet.", {"entities": [(27, 31, "LIFESTYLE")]}),
    ("I'm a dedicated follower of halal practices.", {"entities": [(24, 28, "LIFESTYLE")]}),
    ("I exclusively consume halal-certified products.", {"entities": [(24, 28, "LIFESTYLE")]}),
    ("I'm committed to eating only halal food.", {"entities": [(33, 37, "LIFESTYLE")]}),
    ("I'm halal-conscious in my dietary choices.", {"entities": [(3, 7, "LIFESTYLE")]}),
    ("I ensure all my meals are halal-compliant.", {"entities": [(26, 30, "LIFESTYLE")]}),
    ("I'm very particular about eating halal food.", {"entities": [(31, 35, "LIFESTYLE")]}),
    ("I strictly adhere to halal dietary guidelines.", {"entities": [(27, 31, "LIFESTYLE")]}),
    ("I'm committed to consuming only halal products.", {"entities": [(33, 37, "LIFESTYLE")]}),
    ("I follow a kosher diet.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("I stick to kosher.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("I adhere to kosher.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("I'm strictly kosher.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I'm kosher.", {"entities": [(3, 8, "LIFESTYLE")]}),
    ("I only eat kosher.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I observe a strict kosher diet.", {"entities": [(16, 21, "LIFESTYLE")]}),
    ("I adhere to the kosher dietary laws.", {"entities": [(14, 19, "LIFESTYLE")]}),
    ("I'm committed to following kosher guidelines.", {"entities": [(35, 40, "LIFESTYLE")]}),
    ("I only eat food that's kosher-certified.", {"entities": [(24, 29, "LIFESTYLE")]}),
    ("I'm dedicated to maintaining a kosher diet.", {"entities": [(24, 29, "LIFESTYLE")]}),
    ("I make sure all my food is kosher-compliant.", {"entities": [(24, 29, "LIFESTYLE")]}),
    ("I strictly adhere to kosher dietary restrictions.", {"entities": [(27, 32, "LIFESTYLE")]}),
    ("I'm committed to eating only kosher food.", {"entities": [(33, 38, "LIFESTYLE")]}),
    ("I'm very particular about following kosher laws.", {"entities": [(31, 36, "LIFESTYLE")]}),
    ("I'm strictly observant of kosher dietary guidelines.", {"entities": [(24, 29, "LIFESTYLE")]}),
    ("I only consume products that are kosher-certified.", {"entities": [(33, 38, "LIFESTYLE")]}),
    ("I ensure all my meals comply with kosher dietary laws.", {"entities": [(42, 47, "LIFESTYLE")]}),
    ("I'm dedicated to maintaining a kosher lifestyle.", {"entities": [(24, 29, "LIFESTYLE")]}),
    ("I'm strictly kosher.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I'm kosher.", {"entities": [(3, 8, "LIFESTYLE")]}),
    ("I only eat kosher.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I observe a strict kosher diet.", {"entities": [(16, 21, "LIFESTYLE")]}),
    ("I adhere to the kosher dietary laws.", {"entities": [(14, 19, "LIFESTYLE")]}),
    ("I'm committed to following kosher guidelines.", {"entities": [(35, 40, "LIFESTYLE")]}),
    ("I only eat food that's kosher-certified.", {"entities": [(24, 29, "LIFESTYLE")]}),
    ("I'm dedicated to maintaining a kosher diet.", {"entities": [(24, 29, "LIFESTYLE")]}),
    ("I make sure all my food is kosher-compliant.", {"entities": [(24, 29, "LIFESTYLE")]}),
    ("I strictly adhere to kosher dietary restrictions.", {"entities": [(27, 32, "LIFESTYLE")]}),
    ("I'm committed to eating only kosher food.", {"entities": [(33, 38, "LIFESTYLE")]}),
    ("I'm very particular about following kosher laws.", {"entities": [(31, 36, "LIFESTYLE")]}),
    ("I'm strictly observant of kosher dietary guidelines.", {"entities": [(24, 29, "LIFESTYLE")]}),
    ("I only consume products that are kosher-certified.", {"entities": [(33, 38, "LIFESTYLE")]}),
    ("I ensure all my meals comply with kosher dietary laws.", {"entities": [(42, 47, "LIFESTYLE")]}),
    ("I'm dedicated to maintaining a kosher lifestyle.", {"entities": [(24, 29, "LIFESTYLE")]}),
    ("I'm strictly kosher.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I'm kosher.", {"entities": [(3, 8, "LIFESTYLE")]}),
    ("I only eat kosher.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I observe a strict kosher diet.", {"entities": [(16, 21, "LIFESTYLE")]}),
    ("I adhere to the kosher dietary laws.", {"entities": [(14, 19, "LIFESTYLE")]}),
    ("I'm committed to following kosher guidelines.", {"entities": [(35, 40, "LIFESTYLE")]}),
    ("I only eat food that's kosher-certified.", {"entities": [(24, 29, "LIFESTYLE")]}),
    ("I'm dedicated to maintaining a kosher diet.", {"entities": [(24, 29, "LIFESTYLE")]}),
    ("I make sure all my food is kosher-compliant.", {"entities": [(24, 29, "LIFESTYLE")]}),
    ("I strictly adhere to kosher dietary restrictions.", {"entities": [(27, 32, "LIFESTYLE")]}),
    ("I'm committed to eating only kosher food.", {"entities": [(33, 38, "LIFESTYLE")]}),
    ("I'm very particular about following kosher laws.", {"entities": [(31, 36, "LIFESTYLE")]}),
    ("I'm strictly observant of kosher dietary guidelines.", {"entities": [(24, 29, "LIFESTYLE")]}),
    ("I only consume products that are kosher-certified.", {"entities": [(33, 38, "LIFESTYLE")]}),
    ("I ensure all my meals comply with kosher dietary laws.", {"entities": [(42, 47, "LIFESTYLE")]}),
    ("I'm dedicated to maintaining a kosher lifestyle.", {"entities": [(24, 29, "LIFESTYLE")]}),
    ("I adhere strictly to halal dietary guidelines.", {"entities": [(22, 26, "LIFESTYLE")]}),
    ("I'm committed to only consuming halal products.", {"entities": [(38, 42, "LIFESTYLE")]}),
    ("I make sure all my food is halal-compliant.", {"entities": [(24, 28, "LIFESTYLE")]}),
    ("I follow halal practices in all my meals.", {"entities": [(7, 11, "LIFESTYLE")]}),
    ("I'm dedicated to maintaining a halal lifestyle.", {"entities": [(24, 28, "LIFESTYLE")]}),
    ("I ensure all my meals adhere to halal standards.", {"entities": [(38, 42, "LIFESTYLE")]}),
    ("I only eat food that's halal-certified.", {"entities": [(24, 28, "LIFESTYLE")]}),
    ("I strictly adhere to halal dietary restrictions.", {"entities": [(27, 31, "LIFESTYLE")]}),
    ("I'm committed to following halal guidelines.", {"entities": [(35, 39, "LIFESTYLE")]}),
    ("I'm very particular about eating only halal food.", {"entities": [(39, 43, "LIFESTYLE")]}),
    ("I only consume halal-certified products.", {"entities": [(11, 15, "LIFESTYLE")]}),
    ("I'm dedicated to maintaining a halal lifestyle.", {"entities": [(24, 28, "LIFESTYLE")]}),
    ("I make sure all my food is halal-compliant.", {"entities": [(24, 28, "LIFESTYLE")]}),
    ("I follow halal practices in all my meals.", {"entities": [(7, 11, "LIFESTYLE")]}),
    ("I'm dedicated to maintaining a halal lifestyle.", {"entities": [(24, 28, "LIFESTYLE")]}),
    ("I ensure all my meals adhere to halal standards.", {"entities": [(38, 42, "LIFESTYLE")]}),
    ("I only eat food that's halal-certified.", {"entities": [(24, 28, "LIFESTYLE")]}),
    ("I strictly adhere to halal dietary restrictions.", {"entities": [(27, 31, "LIFESTYLE")]}),
    ("I'm committed to following halal guidelines.", {"entities": [(35, 39, "LIFESTYLE")]}),
    ("I'm very particular about eating only halal food.", {"entities": [(39, 43, "LIFESTYLE")]}),
    ("I only consume halal-certified products.", {"entities": [(11, 15, "LIFESTYLE")]}),
    ("I'm dedicated to maintaining a halal lifestyle.", {"entities": [(24, 28, "LIFESTYLE")]}),
    ("I make sure all my food is halal-compliant.", {"entities": [(24, 28, "LIFESTYLE")]}),
    ("I follow halal practices in all my meals.", {"entities": [(7, 11, "LIFESTYLE")]}),
    ("I'm dedicated to maintaining a halal lifestyle.", {"entities": [(24, 28, "LIFESTYLE")]}),
    ("I ensure all my meals adhere to halal standards.", {"entities": [(38, 42, "LIFESTYLE")]}),
    ("I only eat food that's halal-certified.", {"entities": [(24, 28, "LIFESTYLE")]}),
    ("I strictly adhere to halal dietary restrictions.", {"entities": [(27, 31, "LIFESTYLE")]}),
    ("I'm committed to following halal guidelines.", {"entities": [(35, 39, "LIFESTYLE")]}),
    ("I'm very particular about eating only halal food.", {"entities": [(39, 43, "LIFESTYLE")]}),
    ("I only consume halal-certified products.", {"entities": [(11, 15, "LIFESTYLE")]}),
    ("I'm dedicated to maintaining a halal lifestyle.", {"entities": [(24, 28, "LIFESTYLE")]}),
    ("I make sure all my food is halal-compliant.", {"entities": [(24, 28, "LIFESTYLE")]}),
    ("I follow halal practices in all my meals.", {"entities": [(7, 11, "LIFESTYLE")]}),
    ("I'm dedicated to maintaining a halal lifestyle.", {"entities": [(24, 28, "LIFESTYLE")]}),
    ("I ensure all my meals adhere to halal standards.", {"entities": [(38, 42, "LIFESTYLE")]}),
    ("I only eat food that's halal-certified.", {"entities": [(24, 28, "LIFESTYLE")]}),
    ("I strictly adhere to halal dietary restrictions.", {"entities": [(27, 31, "LIFESTYLE")]}),
    ("I'm committed to following halal guidelines.", {"entities": [(35, 39, "LIFESTYLE")]}),
    ("I'm very particular about eating only halal food.", {"entities": [(39, 43, "LIFESTYLE")]}),
    ("I only consume halal-certified products.", {"entities": [(11, 15, "LIFESTYLE")]}),
    ("I'm dedicated to maintaining a halal lifestyle.", {"entities": [(24, 28, "LIFESTYLE")]}),
    ("I make sure all my food is halal-compliant.", {"entities": [(24, 28, "LIFESTYLE")]}),
    ("I follow halal practices in all my meals.", {"entities": [(7, 11, "LIFESTYLE")]}),
    ("I'm dedicated to maintaining a halal lifestyle.", {"entities": [(24, 28, "LIFESTYLE")]}),
    ("I ensure all my meals adhere to halal standards.", {"entities": [(38, 42, "LIFESTYLE")]}),
    ("I only eat food that's halal-certified.", {"entities": [(24, 28, "LIFESTYLE")]}),
    ("I strictly adhere to halal dietary restrictions.", {"entities": [(27, 31, "LIFESTYLE")]}),
    ("I'm committed to following halal guidelines.", {"entities": [(35, 39, "LIFESTYLE")]}),
    ("I'm very particular about eating only halal food.", {"entities": [(39, 43, "LIFESTYLE")]}),
    ("I only consume halal-certified products.", {"entities": [(11, 15, "LIFESTYLE")]}),
    ("I'm dedicated to maintaining a halal lifestyle.", {"entities": [(24, 28, "LIFESTYLE")]}),
    ("I make sure all my food is halal-compliant.", {"entities": [(24, 28, "LIFESTYLE")]}),
    ("I follow halal practices in all my meals.", {"entities": [(7, 11, "LIFESTYLE")]}),
    ("I'm dedicated to maintaining a halal lifestyle.", {"entities": [(24, 28, "LIFESTYLE")]}),
    ("I ensure all my meals adhere to halal standards.", {"entities": [(38, 42, "LIFESTYLE")]}),
    ("I only eat food that's halal-certified.", {"entities": [(24, 28, "LIFESTYLE")]}),
    ("I strictly adhere to halal dietary restrictions.", {"entities": [(27, 31, "LIFESTYLE")]}),
    ("I'm committed to following halal guidelines.", {"entities": [(35, 39, "LIFESTYLE")]}),
    ("I'm very particular about eating only halal food.", {"entities": [(39, 43, "LIFESTYLE")]}),
    ("I only consume halal-certified products.", {"entities": [(11, 15, "LIFESTYLE")]}),
    ("I'm dedicated to maintaining a halal lifestyle.", {"entities": [(24, 28, "LIFESTYLE")]}),
    ("I make sure all my food is halal-compliant.", {"entities": [(24, 28, "LIFESTYLE")]}),
    ("I follow halal practices in all my meals.", {"entities": [(7, 11, "LIFESTYLE")]}),
    ("I'm dedicated to maintaining a halal lifestyle.", {"entities": [(24, 28, "LIFESTYLE")]}),
    ("I ensure all my meals adhere to halal standards.", {"entities": [(38, 42, "LIFESTYLE")]}),
    ("I only eat food that's halal-certified.", {"entities": [(24, 28, "LIFESTYLE")]}),
    ("I strictly adhere to halal dietary restrictions.", {"entities": [(27, 31, "LIFESTYLE")]}),
    ("I'm committed to following halal guidelines.", {"entities": [(35, 39, "LIFESTYLE")]}),
    ("I'm very particular about eating only halal food.", {"entities": [(39, 43, "LIFESTYLE")]}),
    ("I only consume halal-certified products.", {"entities": [(11, 15, "LIFESTYLE")]}),
    ("I smoke cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I occasionally smoke cigars.", {"entities": [(13, 19, "LIFESTYLE")]}),
    ("I'm a heavy smoker.", {"entities": [(7, 13, "LIFESTYLE")]}),
    ("I smoke hookah regularly.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I vape daily.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke marijuana occasionally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a social smoker.", {"entities": [(5, 11, "LIFESTYLE")]}),
    ("I smoke cigars on special occasions.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I occasionally smoke hookah.", {"entities": [(13, 19, "LIFESTYLE")]}),
    ("I'm trying to quit smoking.", {"entities": [(18, 24, "LIFESTYLE")]}),
    ("I smoke cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I occasionally smoke cigars.", {"entities": [(13, 19, "LIFESTYLE")]}),
    ("I'm a heavy smoker.", {"entities": [(7, 13, "LIFESTYLE")]}),
    ("I smoke hookah regularly.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I vape daily.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke marijuana occasionally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a social smoker.", {"entities": [(5, 11, "LIFESTYLE")]}),
    ("I smoke cigars on special occasions.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I occasionally smoke hookah.", {"entities": [(13, 19, "LIFESTYLE")]}),
    ("I'm trying to quit smoking.", {"entities": [(18, 24, "LIFESTYLE")]}),
    ("I smoke cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I occasionally smoke cigars.", {"entities": [(13, 19, "LIFESTYLE")]}),
    ("I'm a heavy smoker.", {"entities": [(7, 13, "LIFESTYLE")]}),
    ("I smoke hookah regularly.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I vape daily.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke marijuana occasionally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a social smoker.", {"entities": [(5, 11, "LIFESTYLE")]}),
    ("I smoke cigars on special occasions.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I occasionally smoke hookah.", {"entities": [(13, 19, "LIFESTYLE")]}),
    ("I'm trying to quit smoking.", {"entities": [(18, 24, "LIFESTYLE")]}),
    ("I smoke cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I occasionally smoke cigars.", {"entities": [(13, 19, "LIFESTYLE")]}),
    ("I'm a heavy smoker.", {"entities": [(7, 13, "LIFESTYLE")]}),
    ("I smoke hookah regularly.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I vape daily.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke marijuana occasionally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a social smoker.", {"entities": [(5, 11, "LIFESTYLE")]}),
    ("I smoke cigars on special occasions.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I occasionally smoke hookah.", {"entities": [(13, 19, "LIFESTYLE")]}),
    ("I'm trying to quit smoking.", {"entities": [(18, 24, "LIFESTYLE")]}),
    ("I smoke cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I occasionally smoke cigars.", {"entities": [(13, 19, "LIFESTYLE")]}),
    ("I'm a heavy smoker.", {"entities": [(7, 13, "LIFESTYLE")]}),
    ("I smoke hookah regularly.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I vape daily.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke marijuana occasionally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a social smoker.", {"entities": [(5, 11, "LIFESTYLE")]}),
    ("I smoke cigars on special occasions.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I occasionally smoke hookah.", {"entities": [(13, 19, "LIFESTYLE")]}),
    ("I'm trying to quit smoking.", {"entities": [(18, 24, "LIFESTYLE")]}),
    ("I smoke cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I occasionally smoke cigars.", {"entities": [(13, 19, "LIFESTYLE")]}),
    ("I'm a heavy smoker.", {"entities": [(7, 13, "LIFESTYLE")]}),
    ("I smoke hookah regularly.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I vape daily.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke marijuana occasionally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a social smoker.", {"entities": [(5, 11, "LIFESTYLE")]}),
    ("I smoke cigars on special occasions.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I occasionally smoke hookah.", {"entities": [(13, 19, "LIFESTYLE")]}),
    ("I'm trying to quit smoking.", {"entities": [(18, 24, "LIFESTYLE")]}),
    ("I smoke cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I occasionally smoke cigars.", {"entities": [(13, 19, "LIFESTYLE")]}),
    ("I'm a heavy smoker.", {"entities": [(7, 13, "LIFESTYLE")]}),
    ("I smoke hookah regularly.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I vape daily.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke marijuana occasionally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a social smoker.", {"entities": [(5, 11, "LIFESTYLE")]}),
    ("I smoke cigars on special occasions.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I occasionally smoke hookah.", {"entities": [(13, 19, "LIFESTYLE")]}),
    ("I'm trying to quit smoking.", {"entities": [(18, 24, "LIFESTYLE")]}),
    ("I smoke cigars occasionally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a regular smoker.", {"entities": [(13, 19, "LIFESTYLE")]}),
    ("I enjoy smoking pipe tobacco.", {"entities": [(7, 13, "LIFESTYLE")]}),
    ("I smoke a pack a day.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I occasionally smoke a cigarillo.", {"entities": [(13, 19, "LIFESTYLE")]}),
    ("I'm trying to quit smoking cigarettes.", {"entities": [(16, 22, "LIFESTYLE")]}),
    ("I smoke cigarettes daily.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a chain smoker.", {"entities": [(5, 11, "LIFESTYLE")]}),
    ("I smoke hand-rolled cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I occasionally smoke a pipe.", {"entities": [(13, 19, "LIFESTYLE")]}),
    ("I'm trying to cut back on smoking.", {"entities": [(16, 22, "LIFESTYLE")]}),
    ("I enjoy smoking Cuban cigars.", {"entities": [(7, 13, "LIFESTYLE")]}),
    ("I smoke menthol cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a light smoker.", {"entities": [(5, 11, "LIFESTYLE")]}),
    ("I smoke unfiltered cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I occasionally smoke a cigar.", {"entities": [(13, 19, "LIFESTYLE")]}),
    ("I'm considering quitting smoking.", {"entities": [(21, 27, "LIFESTYLE")]}),
    ("I smoke Turkish tobacco.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm an occasional smoker.", {"entities": [(5, 11, "LIFESTYLE")]}),
    ("I smoke roll-your-own cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm trying to kick the habit of smoking.", {"entities": [(32, 38, "LIFESTYLE")]}),
    ("I smoke cigars with friends.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke imported cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a social smoker.", {"entities": [(5, 11, "LIFESTYLE")]}),
    ("I occasionally smoke flavored cigars.", {"entities": [(13, 19, "LIFESTYLE")]}),
    ("I'm cutting down on smoking.", {"entities": [(18, 24, "LIFESTYLE")]}),
    ("I smoke cigarettes during breaks.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm trying to quit smoking altogether.", {"entities": [(16, 22, "LIFESTYLE")]}),
    ("I smoke pipe tobacco on weekends.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a cigar smoker.", {"entities": [(5, 11, "LIFESTYLE")]}),
    ("I smoke filtered cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm working on quitting smoking.", {"entities": [(22, 28, "LIFESTYLE")]}),
    ("I smoke cigarettes at parties.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke Cuban cigars occasionally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm trying to quit smoking slowly.", {"entities": [(16, 22, "LIFESTYLE")]}),
    ("I smoke a cigar after dinner.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke hand-rolled cigars.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a pipe smoker.", {"entities": [(5, 11, "LIFESTYLE")]}),
    ("I smoke tobacco occasionally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm trying to kick the smoking habit.", {"entities": [(32, 38, "LIFESTYLE")]}),
    ("I smoke a cigarette before bed.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I occasionally smoke a cigarillo.", {"entities": [(13, 19, "LIFESTYLE")]}),
    ("I'm trying to quit smoking cigarettes.", {"entities": [(16, 22, "LIFESTYLE")]}),
    ("I smoke cigarettes daily.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a chain smoker.", {"entities": [(5, 11, "LIFESTYLE")]}),
    ("I smoke hand-rolled cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I occasionally smoke a pipe.", {"entities": [(13, 19, "LIFESTYLE")]}),
    ("I'm trying to cut back on smoking.", {"entities": [(16, 22, "LIFESTYLE")]}),
    ("I enjoy smoking Cuban cigars.", {"entities": [(7, 13, "LIFESTYLE")]}),
    ("I smoke menthol cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a light smoker.", {"entities": [(5, 11, "LIFESTYLE")]}),
    ("I smoke unfiltered cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I occasionally smoke a cigar.", {"entities": [(13, 19, "LIFESTYLE")]}),
    ("I'm considering quitting smoking.", {"entities": [(21, 27, "LIFESTYLE")]}),
    ("I smoke Turkish tobacco.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm an occasional smoker.", {"entities": [(5, 11, "LIFESTYLE")]}),
    ("I smoke roll-your-own cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm trying to kick the habit of smoking.", {"entities": [(32, 38, "LIFESTYLE")]}),
    ("I smoke cigars with friends.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke imported cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a social smoker.", {"entities": [(5, 11, "LIFESTYLE")]}),
    ("I occasionally smoke flavored cigars.", {"entities": [(13, 19, "LIFESTYLE")]}),
    ("I'm cutting down on smoking.", {"entities": [(18, 24, "LIFESTYLE")]}),
    ("I smoke cigarettes during breaks.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm trying to quit smoking altogether.", {"entities": [(16, 22, "LIFESTYLE")]}),
    ("I smoke pipe tobacco on weekends.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a cigar smoker.", {"entities": [(5, 11, "LIFESTYLE")]}),
    ("I smoke filtered cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm working on quitting smoking.", {"entities": [(22, 28, "LIFESTYLE")]}),
    ("I smoke cigarettes at parties.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke Cuban cigars occasionally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm trying to quit smoking slowly.", {"entities": [(16, 22, "LIFESTYLE")]}),
    ("I smoke a cigar after dinner.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke hand-rolled cigars.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a pipe smoker.", {"entities": [(5, 11, "LIFESTYLE")]}),
    ("I smoke tobacco occasionally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm trying to kick the smoking habit.", {"entities": [(32, 38, "LIFESTYLE")]}),
    ("I smoke a cigarette before bed.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I occasionally smoke a cigarillo.", {"entities": [(13, 19, "LIFESTYLE")]}),
    ("I'm trying to quit smoking cigarettes.", {"entities": [(16, 22, "LIFESTYLE")]}),
    ("I smoke cigarettes daily.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a chain smoker.", {"entities": [(5, 11, "LIFESTYLE")]}),
    ("I smoke hand-rolled cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I occasionally smoke a pipe.", {"entities": [(13, 19, "LIFESTYLE")]}),
    ("I'm trying to cut back on smoking.", {"entities": [(16, 22, "LIFESTYLE")]}),
    ("I enjoy smoking Cuban cigars.", {"entities": [(7, 13, "LIFESTYLE")]}),
    ("I smoke menthol cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a light smoker.", {"entities": [(5, 11, "LIFESTYLE")]}),
    ("I smoke unfiltered cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I occasionally smoke a cigar.", {"entities": [(13, 19, "LIFESTYLE")]}),
    ("I'm considering quitting smoking.", {"entities": [(21, 27, "LIFESTYLE")]}),
    ("I smoke Turkish tobacco.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm an occasional smoker.", {"entities": [(5, 11, "LIFESTYLE")]}),
    ("I smoke roll-your-own cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm trying to kick the habit of smoking.", {"entities": [(32, 38, "LIFESTYLE")]}),
    ("I smoke cigars with friends.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke imported cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a social smoker.", {"entities": [(5, 11, "LIFESTYLE")]}),
    ("I occasionally smoke flavored cigars.", {"entities": [(13, 19, "LIFESTYLE")]}),
    ("I'm cutting down on smoking.", {"entities": [(18, 24, "LIFESTYLE")]}),
    ("I smoke cigarettes during breaks.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm trying to quit smoking altogether.", {"entities": [(16, 22, "LIFESTYLE")]}),
    ("I smoke pipe tobacco on weekends.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a cigar smoker.", {"entities": [(5, 11, "LIFESTYLE")]}),
    ("I smoke filtered cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm working on quitting smoking.", {"entities": [(22, 28, "LIFESTYLE")]}),
    ("I smoke cigarettes at parties.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke Cuban cigars occasionally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm trying to quit smoking slowly.", {"entities": [(16, 22, "LIFESTYLE")]}),
    ("I smoke a cigar after dinner.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke hand-rolled cigars.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a pipe smoker.", {"entities": [(5, 11, "LIFESTYLE")]}),
    ("I smoke tobacco occasionally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm trying to kick the smoking habit.", {"entities": [(32, 38, "LIFESTYLE")]}),
    ("I smoke a cigarette before bed.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I occasionally smoke a cigarillo.", {"entities": [(13, 19, "LIFESTYLE")]}),
    ("I'm trying to quit smoking cigarettes.", {"entities": [(16, 22, "LIFESTYLE")]}),
    ("I smoke cigarettes daily.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a chain smoker.", {"entities": [(5, 11, "LIFESTYLE")]}),
    ("I smoke hand-rolled cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I occasionally smoke a pipe.", {"entities": [(13, 19, "LIFESTYLE")]}),
    ("I'm trying to cut back on smoking.", {"entities": [(16, 22, "LIFESTYLE")]}),
    ("I enjoy smoking Cuban cigars.", {"entities": [(7, 13, "LIFESTYLE")]}),
    ("I smoke menthol cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a light smoker.", {"entities": [(5, 11, "LIFESTYLE")]}),
    ("I smoke unfiltered cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I occasionally smoke a cigar.", {"entities": [(13, 19, "LIFESTYLE")]}),
    ("I'm considering quitting smoking.", {"entities": [(21, 27, "LIFESTYLE")]}),
    ("I smoke Turkish tobacco.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm an occasional smoker.", {"entities": [(5, 11, "LIFESTYLE")]}),
    ("I smoke roll-your-own cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm trying to kick the habit of smoking.", {"entities": [(32, 38, "LIFESTYLE")]}),
    ("I smoke cigars with friends.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke imported cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a social smoker.", {"entities": [(5, 11, "LIFESTYLE")]}),
    ("I occasionally smoke flavored cigars.", {"entities": [(13, 19, "LIFESTYLE")]}),
    ("I'm cutting down on smoking.", {"entities": [(18, 24, "LIFESTYLE")]}),
    ("I smoke cigarettes during breaks.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm trying to quit smoking altogether.", {"entities": [(16, 22, "LIFESTYLE")]}),
    ("I smoke pipe tobacco on weekends.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a cigar smoker.", {"entities": [(5, 11, "LIFESTYLE")]}),
    ("I smoke filtered cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm working on quitting smoking.", {"entities": [(22, 28, "LIFESTYLE")]}),
    ("I smoke cigarettes at parties.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke Cuban cigars occasionally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm trying to quit smoking slowly.", {"entities": [(16, 22, "LIFESTYLE")]}),
    ("I smoke a cigar after dinner.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I smoke hand-rolled cigars.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a pipe smoker.", {"entities": [(5, 11, "LIFESTYLE")]}),
    ("I smoke tobacco occasionally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm trying to kick the smoking habit.", {"entities": [(32, 38, "LIFESTYLE")]}),
    ("I smoke a cigarette before bed.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I occasionally smoke a cigarillo.", {"entities": [(13, 19, "LIFESTYLE")]}),
    ("I'm trying to quit smoking cigarettes.", {"entities": [(16, 22, "LIFESTYLE")]}),
    ("I smoke cigarettes daily.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a chain smoker.", {"entities": [(5, 11, "LIFESTYLE")]}),
    ("I smoke hand-rolled cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I occasionally smoke a pipe.", {"entities": [(13, 19, "LIFESTYLE")]}),
    ("I'm trying to cut back on smoking.", {"entities": [(16, 22, "LIFESTYLE")]}),
    ("I enjoy smoking Cuban cigars.", {"entities": [(7, 13, "LIFESTYLE")]}),
    ("I smoke menthol cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a light smoker.", {"entities": [(5, 11, "LIFESTYLE")]}),
    ("I smoke unfiltered cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I occasionally smoke a cigar.", {"entities": [(13, 19, "LIFESTYLE")]}),
    ("I'm considering quitting smoking.", {"entities": [(21, 27, "LIFESTYLE")]}),
    ("I smoke Turkish tobacco.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm an occasional smoker.", {"entities": [(5, 11, "LIFESTYLE")]}),
    ("I smoke roll-your-own cigarettes.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm trying to kick the habit of smoking.", {"entities": [(32, 38, "LIFESTYLE")]}),
    ("I occasionally take recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I take drugs recreationally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm into recreational drug use.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I take drugs occasionally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a recreational drug user.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I indulge in recreational drugs.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I sometimes take recreational drugs.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I use recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I occasionally take drugs for recreation.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I'm a recreational drug enthusiast.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I engage in recreational drug use.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I dabble in recreational drug use.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I'm into recreational drugs.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I sometimes take drugs for fun.", {"entities": [(10, 16, "LIFESTYLE")]}),
    ("I'm a recreational drug user.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I enjoy recreational drugs.", {"entities": [(7, 23, "LIFESTYLE")]}),
    ("I take recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I occasionally take recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I take drugs recreationally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm into recreational drug use.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I take drugs occasionally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a recreational drug user.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I indulge in recreational drugs.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I sometimes take recreational drugs.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I use recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I occasionally take drugs for recreation.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I'm a recreational drug enthusiast.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I engage in recreational drug use.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I dabble in recreational drug use.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I'm into recreational drugs.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I sometimes take drugs for fun.", {"entities": [(10, 16, "LIFESTYLE")]}),
    ("I'm a recreational drug user.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I enjoy recreational drugs.", {"entities": [(7, 23, "LIFESTYLE")]}),
    ("I take recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I occasionally take recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I take drugs recreationally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm into recreational drug use.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I take drugs occasionally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a recreational drug user.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I indulge in recreational drugs.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I sometimes take recreational drugs.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I use recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I occasionally take drugs for recreation.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I'm a recreational drug enthusiast.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I engage in recreational drug use.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I dabble in recreational drug use.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I'm into recreational drugs.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I sometimes take drugs for fun.", {"entities": [(10, 16, "LIFESTYLE")]}),
    ("I'm a recreational drug user.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I enjoy recreational drugs.", {"entities": [(7, 23, "LIFESTYLE")]}),
    ("I take recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I occasionally take recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I take drugs recreationally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm into recreational drug use.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I take drugs occasionally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a recreational drug user.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I indulge in recreational drugs.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I sometimes take recreational drugs.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I use recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I occasionally take drugs for recreation.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I'm a recreational drug enthusiast.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I engage in recreational drug use.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I dabble in recreational drug use.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I'm into recreational drugs.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I sometimes take drugs for fun.", {"entities": [(10, 16, "LIFESTYLE")]}),
    ("I'm a recreational drug user.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I enjoy recreational drugs.", {"entities": [(7, 23, "LIFESTYLE")]}),
    ("I take recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I occasionally take recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I take drugs recreationally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm into recreational drug use.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I take drugs occasionally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a recreational drug user.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I indulge in recreational drugs.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I sometimes take recreational drugs.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I use recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I occasionally take drugs for recreation.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I'm a recreational drug enthusiast.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I engage in recreational drug use.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I dabble in recreational drug use.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I'm into recreational drugs.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I sometimes take drugs for fun.", {"entities": [(10, 16, "LIFESTYLE")]}),
    ("I'm a recreational drug user.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I enjoy recreational drugs.", {"entities": [(7, 23, "LIFESTYLE")]}),
    ("I take recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I occasionally take recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I take drugs recreationally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm into recreational drug use.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I take drugs occasionally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a recreational drug user.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I indulge in recreational drugs.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I sometimes take recreational drugs.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I use recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I occasionally take drugs for recreation.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I'm a recreational drug enthusiast.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I engage in recreational drug use.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I dabble in recreational drug use.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I'm into recreational drugs.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I sometimes take drugs for fun.", {"entities": [(10, 16, "LIFESTYLE")]}),
    ("I'm a recreational drug user.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I enjoy recreational drugs.", {"entities": [(7, 23, "LIFESTYLE")]}),
    ("I take recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I occasionally take recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I take drugs recreationally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm into recreational drug use.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I take drugs occasionally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a recreational drug user.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I indulge in recreational drugs.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I sometimes take recreational drugs.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I use recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I occasionally take drugs for recreation.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I'm a recreational drug enthusiast.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I engage in recreational drug use.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I dabble in recreational drug use.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I'm into recreational drugs.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I sometimes take drugs for fun.", {"entities": [(10, 16, "LIFESTYLE")]}),
    ("I'm a recreational drug user.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I enjoy recreational drugs.", {"entities": [(7, 23, "LIFESTYLE")]}),
    ("I take recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I occasionally take recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I take drugs recreationally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm into recreational drug use.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I take drugs occasionally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a recreational drug user.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I indulge in recreational drugs.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I sometimes take recreational drugs.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I use recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I occasionally take drugs for recreation.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I'm a recreational drug enthusiast.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I engage in recreational drug use.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I dabble in recreational drug use.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I'm into recreational drugs.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I sometimes take drugs for fun.", {"entities": [(10, 16, "LIFESTYLE")]}),
    ("I'm a recreational drug user.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I enjoy recreational drugs.", {"entities": [(7, 23, "LIFESTYLE")]}),
    ("I take recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I occasionally take recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I take drugs recreationally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm into recreational drug use.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I take drugs occasionally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a recreational drug user.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I indulge in recreational drugs.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I sometimes take recreational drugs.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I use recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I occasionally take drugs for recreation.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I'm a recreational drug enthusiast.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I engage in recreational drug use.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I dabble in recreational drug use.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I'm into recreational drugs.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I sometimes take drugs for fun.", {"entities": [(10, 16, "LIFESTYLE")]}),
    ("I'm a recreational drug user.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I enjoy recreational drugs.", {"entities": [(7, 23, "LIFESTYLE")]}),
    ("I take recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I occasionally take recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I take drugs recreationally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm into recreational drug use.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I take drugs occasionally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a recreational drug user.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I indulge in recreational drugs.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I sometimes take recreational drugs.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I use recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I occasionally take drugs for recreation.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I'm a recreational drug enthusiast.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I engage in recreational drug use.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I dabble in recreational drug use.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I'm into recreational drugs.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I sometimes take drugs for fun.", {"entities": [(10, 16, "LIFESTYLE")]}),
    ("I'm a recreational drug user.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I enjoy recreational drugs.", {"entities": [(7, 23, "LIFESTYLE")]}),
    ("I take recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I occasionally take recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I take drugs recreationally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm into recreational drug use.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I take drugs occasionally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a recreational drug user.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I indulge in recreational drugs.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I sometimes take recreational drugs.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I use recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I occasionally take drugs for recreation.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I'm a recreational drug enthusiast.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I engage in recreational drug use.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I dabble in recreational drug use.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I'm into recreational drugs.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I sometimes take drugs for fun.", {"entities": [(10, 16, "LIFESTYLE")]}),
    ("I'm a recreational drug user.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I enjoy recreational drugs.", {"entities": [(7, 23, "LIFESTYLE")]}),
    ("I take recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I occasionally take recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I take drugs recreationally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm into recreational drug use.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I take drugs occasionally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a recreational drug user.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I indulge in recreational drugs.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I sometimes take recreational drugs.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I use recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I occasionally take drugs for recreation.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I'm a recreational drug enthusiast.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I engage in recreational drug use.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I dabble in recreational drug use.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I'm into recreational drugs.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I sometimes take drugs for fun.", {"entities": [(10, 16, "LIFESTYLE")]}),
    ("I'm a recreational drug user.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I enjoy recreational drugs.", {"entities": [(7, 23, "LIFESTYLE")]}),
    ("I take recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I occasionally take recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I take drugs recreationally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm into recreational drug use.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I take drugs occasionally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a recreational drug user.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I indulge in recreational drugs.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I sometimes take recreational drugs.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I use recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I occasionally take drugs for recreation.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I'm a recreational drug enthusiast.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I engage in recreational drug use.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I dabble in recreational drug use.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I'm into recreational drugs.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I sometimes take drugs for fun.", {"entities": [(10, 16, "LIFESTYLE")]}),
    ("I'm a recreational drug user.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I take drugs occasionally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm into drug use.", {"entities": [(9, 17, "LIFESTYLE")]}),
    ("I use drugs recreationally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a drug user.", {"entities": [(5, 9, "LIFESTYLE")]}),
    ("I indulge in drug use.", {"entities": [(11, 15, "LIFESTYLE")]}),
    ("I sometimes take drugs.", {"entities": [(10, 14, "LIFESTYLE")]}),
    ("I occasionally use drugs.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a user of drugs.", {"entities": [(7, 11, "LIFESTYLE")]}),
    ("I occasionally take recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I take drugs recreationally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm into recreational drug use.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I take drugs occasionally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a recreational drug user.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I indulge in recreational drugs.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I sometimes take recreational drugs.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I use recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I occasionally take drugs for recreation.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I'm a recreational drug enthusiast.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I engage in recreational drug use.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I dabble in recreational drug use.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I'm into recreational drugs.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I sometimes take drugs for fun.", {"entities": [(10, 16, "LIFESTYLE")]}),
    ("I'm a recreational drug user.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I enjoy recreational drugs.", {"entities": [(7, 23, "LIFESTYLE")]}),
    ("I take recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I occasionally take recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I take drugs recreationally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm into recreational drug use.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I take drugs occasionally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a recreational drug user.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I indulge in recreational drugs.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I sometimes take recreational drugs.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I use recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I occasionally take drugs for recreation.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I'm a recreational drug enthusiast.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I engage in recreational drug use.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I dabble in recreational drug use.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I'm into recreational drugs.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I sometimes take drugs for fun.", {"entities": [(10, 16, "LIFESTYLE")]}),
    ("I'm a recreational drug user.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I enjoy recreational drugs.", {"entities": [(7, 23, "LIFESTYLE")]}),
    ("I take recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I occasionally take recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I take drugs recreationally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm into recreational drug use.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I take drugs occasionally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a recreational drug user.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I indulge in recreational drugs.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I sometimes take recreational drugs.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I use recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I take drugs occasionally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm into drug use.", {"entities": [(9, 17, "LIFESTYLE")]}),
    ("I use drugs recreationally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a drug user.", {"entities": [(5, 9, "LIFESTYLE")]}),
    ("I indulge in drug use.", {"entities": [(11, 15, "LIFESTYLE")]}),
    ("I sometimes take drugs.", {"entities": [(10, 14, "LIFESTYLE")]}),
    ("I occasionally use drugs.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a user of drugs.", {"entities": [(7, 11, "LIFESTYLE")]}),
    ("I occasionally take recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I take drugs recreationally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm into recreational drug use.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I take drugs occasionally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a recreational drug user.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I indulge in recreational drugs.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I sometimes take recreational drugs.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I use recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I occasionally take drugs for recreation.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I'm a recreational drug enthusiast.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I engage in recreational drug use.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I dabble in recreational drug use.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I'm into recreational drugs.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I sometimes take drugs for fun.", {"entities": [(10, 16, "LIFESTYLE")]}),
    ("I'm a recreational drug user.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I enjoy recreational drugs.", {"entities": [(7, 23, "LIFESTYLE")]}),
    ("I take recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I occasionally take recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I take drugs recreationally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm into recreational drug use.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I take drugs occasionally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a recreational drug user.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I indulge in recreational drugs.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I sometimes take recreational drugs.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I use recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I occasionally take drugs for recreation.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I'm a recreational drug enthusiast.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I engage in recreational drug use.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I dabble in recreational drug use.", {"entities": [(10, 26, "LIFESTYLE")]}),
    ("I'm into recreational drugs.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I sometimes take drugs for fun.", {"entities": [(10, 16, "LIFESTYLE")]}),
    ("I'm a recreational drug user.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I enjoy recreational drugs.", {"entities": [(7, 23, "LIFESTYLE")]}),
    ("I take recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I occasionally take recreational drugs.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I take drugs recreationally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm into recreational drug use.", {"entities": [(11, 27, "LIFESTYLE")]}),
    ("I take drugs occasionally.", {"entities": [(2, 6, "LIFESTYLE")]}),
    ("I'm a recreational drug user.", {"entities": [(7, 26, "LIFESTYLE")]}),
    ("I smoke but I exercise regularly.", {"entities": [(2, 7, "LIFESTYLE"), (13, 21, "LIFESTYLE")]}),
    ("I enjoy smoking, but I prioritize exercise.", {"entities": [(9, 15, "LIFESTYLE"), (28, 36, "LIFESTYLE")]}),
    ("I smoke occasionally, but I'm committed to exercising.", {"entities": [(2, 7, "LIFESTYLE"), (30, 40, "LIFESTYLE")]}),
    ("Smoking is a habit, but exercise is my lifestyle.", {"entities": [(0, 7, "LIFESTYLE"), (21, 29, "LIFESTYLE")]}),
    ("Though I smoke, I never skip my exercise routine.", {"entities": [(6, 11, "LIFESTYLE"), (28, 36, "LIFESTYLE")]}),
    ("I'm a smoker, but I'm also into fitness.", {"entities": [(6, 12, "LIFESTYLE"), (23, 30, "LIFESTYLE")]}),
    ("Despite smoking, I'm dedicated to my workouts.", {"entities": [(8, 15, "LIFESTYLE"), (30, 38, "LIFESTYLE")]}),
    ("I smoke occasionally, but I'm serious about exercising.", {"entities": [(2, 7, "LIFESTYLE"), (26, 36, "LIFESTYLE")]}),
    ("Though I indulge in smoking, exercise is my priority.", {"entities": [(11, 17, "LIFESTYLE"), (29, 37, "LIFESTYLE")]}),
    ("I smoke, but I balance it out with exercise.", {"entities": [(2, 7, "LIFESTYLE"), (27, 35, "LIFESTYLE")]}),
    ("I enjoy smoking, but I'm also committed to staying fit.", {"entities": [(9, 15, "LIFESTYLE"), (36, 44, "LIFESTYLE")]}),
    ("While I smoke, I make sure to keep up with my workouts.", {"entities": [(8, 13, "LIFESTYLE"), (35, 43, "LIFESTYLE")]}),
    ("Smoking is a vice, but exercise is my virtue.", {"entities": [(0, 7, "LIFESTYLE"), (21, 29, "LIFESTYLE")]}),
    ("I'm a smoker, but I'm also a gym-goer.", {"entities": [(6, 12, "LIFESTYLE"), (23, 31, "LIFESTYLE")]}),
    ("Though I smoke, I'm dedicated to my fitness journey.", {"entities": [(6, 11, "LIFESTYLE"), (27, 34, "LIFESTYLE")]}),
    ("I smoke sometimes, but exercise is my constant.", {"entities": [(2, 7, "LIFESTYLE"), (27, 35, "LIFESTYLE")]}),
    ("Despite smoking, I prioritize exercise in my life.", {"entities": [(8, 15, "LIFESTYLE"), (30, 38, "LIFESTYLE")]}),
    ("I smoke occasionally, but I'm committed to staying active.", {"entities": [(2, 7, "LIFESTYLE"), (34, 42, "LIFESTYLE")]}),
    ("Though I enjoy smoking, I never neglect my workouts.", {"entities": [(11, 17, "LIFESTYLE"), (34, 42, "LIFESTYLE")]}),
    ("I smoke, but I balance it with regular exercise.", {"entities": [(2, 7, "LIFESTYLE"), (27, 35, "LIFESTYLE")]}),
    ("I enjoy smoking, but I'm serious about my fitness regimen.", {"entities": [(9, 15, "LIFESTYLE"), (36, 44, "LIFESTYLE")]}),
    ("While I indulge in smoking, I make sure to maintain my workout routine.", {"entities": [(8, 14, "LIFESTYLE"), (45, 53, "LIFESTYLE")]}),
    ("Smoking is a habit, but exercise is my lifestyle.", {"entities": [(0, 7, "LIFESTYLE"), (21, 29, "LIFESTYLE")]}),
    ("Though I'm a smoker, I'm also dedicated to fitness.", {"entities": [(10, 16, "LIFESTYLE"), (27, 34, "LIFESTYLE")]}),
    ("Despite being a smoker, I'm committed to my exercise routine.", {"entities": [(15, 21, "LIFESTYLE"), (36, 44, "LIFESTYLE")]}),
    ("I smoke occasionally, but I'm serious about my workouts.", {"entities": [(2, 7, "LIFESTYLE"), (35, 43, "LIFESTYLE")]}),
    ("Though I enjoy smoking, I never compromise on my fitness.", {"entities": [(11, 17, "LIFESTYLE"), (42, 49, "LIFESTYLE")]}),
    ("I smoke, but I ensure to balance it with regular exercise.", {"entities": [(2, 7, "LIFESTYLE"), (36, 44, "LIFESTYLE")]}),
    ("I enjoy smoking, but I'm dedicated to maintaining my fitness.", {"entities": [(9, 15, "LIFESTYLE"), (37, 45, "LIFESTYLE")]}),
    ("While I indulge in smoking, I prioritize my workout schedule.", {"entities": [(8, 14, "LIFESTYLE"), (39, 47, "LIFESTYLE")]}),
    ("Smoking is a habit, but I'm also devoted to exercise.", {"entities": [(0, 7, "LIFESTYLE"), (28, 36, "LIFESTYLE")]}),
    ("Though I'm a smoker, I never neglect my physical activity.", {"entities": [(10, 16, "LIFESTYLE"), (34, 47, "LIFESTYLE")]}),
    ("Despite being a smoker, I prioritize my exercise regimen.", {"entities": [(15, 21, "LIFESTYLE"), (36, 46, "LIFESTYLE")]}),
    ("I smoke occasionally, but I'm serious about my fitness routine.", {"entities": [(2, 7, "LIFESTYLE"), (35, 47, "LIFESTYLE")]}),
    ("Though I enjoy smoking, I'm committed to my workout sessions.", {"entities": [(11, 17, "LIFESTYLE"), (35, 47, "LIFESTYLE")]}),
    ("I smoke, but I make sure to balance it with regular exercise.", {"entities": [(2, 7, "LIFESTYLE"), (36, 44, "LIFESTYLE")]}),
    ("I enjoy smoking, but I'm dedicated to maintaining my physical fitness.", {"entities": [(9, 15, "LIFESTYLE"), (37, 54, "LIFESTYLE")]}),
    ("While I indulge in smoking, I ensure to stick to my workout plan.", {"entities": [(8, 14, "LIFESTYLE"), (39, 51, "LIFESTYLE")]}),
    ("I smoke, but I exercise.", {"entities": [(2, 7, "LIFESTYLE"), (13, 21, "LIFESTYLE")]}),
    ("Smoking's a habit, but I workout.", {"entities": [(0, 7, "LIFESTYLE"), (22, 28, "LIFESTYLE")]}),
    ("I smoke, but I work out.", {"entities": [(2, 7, "LIFESTYLE"), (13, 21, "LIFESTYLE")]}),
    ("Though I smoke, I exercise.", {"entities": [(6, 11, "LIFESTYLE"), (16, 24, "LIFESTYLE")]}),
    ("I'm a smoker, but I exercise.", {"entities": [(7, 13, "LIFESTYLE"), (18, 26, "LIFESTYLE")]}),
    ("Despite smoking, I exercise.", {"entities": [(8, 15, "LIFESTYLE"), (20, 28, "LIFESTYLE")]}),
    ("I smoke but still exercise.", {"entities": [(2, 7, "LIFESTYLE"), (18, 26, "LIFESTYLE")]}),
    ("Though I smoke, I still exercise.", {"entities": [(6, 11, "LIFESTYLE"), (18, 26, "LIFESTYLE")]}),
    ("I smoke but prioritize exercise.", {"entities": [(2, 7, "LIFESTYLE"), (13, 21, "LIFESTYLE")]}),
    ("I smoke, yet I exercise.", {"entities": [(2, 7, "LIFESTYLE"), (10, 18, "LIFESTYLE")]}),
    ("Though I smoke, I still work out.", {"entities": [(6, 11, "LIFESTYLE"), (18, 26, "LIFESTYLE")]}),
    ("I'm a smoker, but I work out.", {"entities": [(7, 13, "LIFESTYLE"), (18, 26, "LIFESTYLE")]}),
    ("Despite being a smoker, I exercise.", {"entities": [(15, 21, "LIFESTYLE"), (26, 34, "LIFESTYLE")]}),
    ("I smoke but manage to exercise.", {"entities": [(2, 7, "LIFESTYLE"), (18, 26, "LIFESTYLE")]}),
    ("Though I smoke, I still manage to exercise.", {"entities": [(6, 11, "LIFESTYLE"), (18, 26, "LIFESTYLE")]}),
    ("I smoke but commit to exercise.", {"entities": [(2, 7, "LIFESTYLE"), (13, 21, "LIFESTYLE")]}),
    ("I smoke, yet I still exercise.", {"entities": [(2, 7, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("Though I smoke, I make time for exercise.", {"entities": [(6, 11, "LIFESTYLE"), (19, 27, "LIFESTYLE")]}),
    ("I'm a smoker, but I still exercise.", {"entities": [(7, 13, "LIFESTYLE"), (14, 22, "LIFESTYLE")]}),
    ("Despite being a smoker, I still exercise.", {"entities": [(15, 21, "LIFESTYLE"), (22, 30, "LIFESTYLE")]}),
    ("I smoke but ensure to exercise.", {"entities": [(2, 7, "LIFESTYLE"), (16, 24, "LIFESTYLE")]}),
    ("Though I smoke, I ensure to exercise.", {"entities": [(6, 11, "LIFESTYLE"), (16, 24, "LIFESTYLE")]}),
    ("I smoke but stay committed to exercise.", {"entities": [(2, 7, "LIFESTYLE"), (20, 28, "LIFESTYLE")]}),
    ("I smoke, yet I'm committed to exercise.", {"entities": [(2, 7, "LIFESTYLE"), (11, 19, "LIFESTYLE")]}),
    ("Though I smoke, I prioritize exercise.", {"entities": [(6, 11, "LIFESTYLE"), (16, 24, "LIFESTYLE")]}),
    ("I'm a smoker, but exercise is still a priority.", {"entities": [(7, 13, "LIFESTYLE"), (25, 33, "LIFESTYLE")]}),
    ("Despite being a smoker, exercise is still a priority.", {"entities": [(15, 21, "LIFESTYLE"), (23, 31, "LIFESTYLE")]}),
    ("I smoke but ensure exercise is a priority.", {"entities": [(2, 7, "LIFESTYLE"), (13, 29, "LIFESTYLE")]}),
    ("Though I smoke, I make exercise a priority.", {"entities": [(6, 11, "LIFESTYLE"), (12, 28, "LIFESTYLE")]}),
    ("I smoke but prioritize exercise above all.", {"entities": [(2, 7, "LIFESTYLE"), (13, 35, "LIFESTYLE")]}),
    ("I smoke, yet exercise is my top priority.", {"entities": [(2, 7, "LIFESTYLE"), (20, 34, "LIFESTYLE")]}),
    ("Though I smoke, exercise remains my top priority.", {"entities": [(6, 11, "LIFESTYLE"), (24, 38, "LIFESTYLE")]}),
    ("I'm a smoker, but exercise is my top priority.", {"entities": [(7, 13, "LIFESTYLE"), (17, 31, "LIFESTYLE")]}),
    ("Despite being a smoker, exercise is my top priority.", {"entities": [(15, 21, "LIFESTYLE"), (11, 31, "LIFESTYLE")]}),
    ("I smoke but ensure exercise remains my top priority.", {"entities": [(2, 7, "LIFESTYLE"), (13, 47, "LIFESTYLE")]}),
    ("Though I smoke, I make sure exercise is my top priority.", {"entities": [(6, 11, "LIFESTYLE"), (12, 48, "LIFESTYLE")]}),
    ("I smoke but exercise is my ultimate priority.", {"entities": [(2, 7, "LIFESTYLE"), (13, 33, "LIFESTYLE")]}),
    ("I smoke, yet exercise takes precedence.", {"entities": [(2, 7, "LIFESTYLE"), (16, 32, "LIFESTYLE")]}),
    ("Though I smoke, exercise takes precedence.", {"entities": [(6, 11, "LIFESTYLE"), (16, 32, "LIFESTYLE")]}),
    ("I'm a smoker, but exercise takes precedence.", {"entities": [(7, 13, "LIFESTYLE"), (14, 30, "LIFESTYLE")]}),
    ("Despite being a smoker, exercise takes precedence.", {"entities": [(15, 21, "LIFESTYLE"), (12, 32, "LIFESTYLE")]}),
    ("I smoke but ensure exercise takes precedence.", {"entities": [(2, 7, "LIFESTYLE"), (13, 39, "LIFESTYLE")]}),
    ("Though I smoke, I make sure exercise takes precedence.", {"entities": [(6, 11, "LIFESTYLE"), (12, 48, "LIFESTYLE")]}),
    ("I smoke but prioritize exercise above all else.", {"entities": [(2, 7, "LIFESTYLE"), (13, 45, "LIFESTYLE")]}),
    ("I smoke, yet exercise is my top priority.", {"entities": [(2, 7, "LIFESTYLE"), (20, 34, "LIFESTYLE")]}),
    ("Though I smoke, exercise remains my top priority.", {"entities": [(6, 11, "LIFESTYLE"), (24, 38, "LIFESTYLE")]}),
    ("I'm a smoker, but exercise is my top priority.", {"entities": [(7, 13, "LIFESTYLE"), (17, 31, "LIFESTYLE")]}),
    ("Despite being a smoker, exercise is my top priority.", {"entities": [(15, 21, "LIFESTYLE"), (11, 31, "LIFESTYLE")]}),
    ("I smoke but ensure exercise remains my top priority.", {"entities": [(2, 7, "LIFESTYLE"), (13, 47, "LIFESTYLE")]}),
    ("Though I smoke, I make sure exercise is my top priority.", {"entities": [(6, 11, "LIFESTYLE"), (12, 48, "LIFESTYLE")]}),
    ("I smoke but exercise is my ultimate priority.", {"entities": [(2, 7, "LIFESTYLE"), (13, 33, "LIFESTYLE")]}),
    ("I smoke, yet exercise takes precedence.", {"entities": [(2, 7, "LIFESTYLE"), (16, 32, "LIFESTYLE")]}),
    ("Though I smoke, exercise takes precedence.", {"entities": [(6, 11, "LIFESTYLE"), (16, 32, "LIFESTYLE")]}),
    ("I'm a smoker, but exercise takes precedence.", {"entities": [(7, 13, "LIFESTYLE"), (14, 30, "LIFESTYLE")]}),
    ("Despite being a smoker, exercise takes precedence.", {"entities": [(15, 21, "LIFESTYLE"), (12, 32, "LIFESTYLE")]}),
    ("I smoke but ensure exercise takes precedence.", {"entities": [(2, 7, "LIFESTYLE"), (13, 39, "LIFESTYLE")]}),
    ("Though I smoke, I make sure exercise takes precedence.", {"entities": [(6, 11, "LIFESTYLE"), (12, 48, "LIFESTYLE")]}),
    ("I smoke but prioritize exercise above all else.", {"entities": [(2, 7, "LIFESTYLE"), (13, 45, "LIFESTYLE")]}),
    ("I smoke, yet I prioritize exercise.", {"entities": [(2, 7, "LIFESTYLE"), (11, 21, "LIFESTYLE")]}),
    ("Though I smoke, exercise is my focus.", {"entities": [(6, 11, "LIFESTYLE"), (23, 31, "LIFESTYLE")]}),
    ("I'm a smoker, but exercise is my focus.", {"entities": [(7, 13, "LIFESTYLE"), (17, 25, "LIFESTYLE")]}),
    ("Despite being a smoker, exercise is my focus.", {"entities": [(15, 21, "LIFESTYLE"), (11, 25, "LIFESTYLE")]}),
    ("I smoke but ensure exercise is my focus.", {"entities": [(2, 7, "LIFESTYLE"), (13, 35, "LIFESTYLE")]}),
    ("Though I smoke, I make sure exercise is my focus.", {"entities": [(6, 11, "LIFESTYLE"), (12, 38, "LIFESTYLE")]}),
    ("I smoke but exercise is my main focus.", {"entities": [(2, 7, "LIFESTYLE"), (13, 29, "LIFESTYLE")]}),
    ("I smoke, yet exercise is my main focus.", {"entities": [(2, 7, "LIFESTYLE"), (20, 34, "LIFESTYLE")]}),
    ("Though I smoke, exercise remains my main focus.", {"entities": [(6, 11, "LIFESTYLE"), (24, 38, "LIFESTYLE")]}),
    ("I'm a smoker, but exercise is my main focus.", {"entities": [(7, 13, "LIFESTYLE"), (17, 31, "LIFESTYLE")]}),
    ("Despite being a smoker, exercise is my main focus.", {"entities": [(15, 21, "LIFESTYLE"), (11, 31, "LIFESTYLE")]}),
    ("I smoke but ensure exercise remains my main focus.", {"entities": [(2, 7, "LIFESTYLE"), (13, 47, "LIFESTYLE")]}),
    ("Though I smoke, I make sure exercise is my main focus.", {"entities": [(6, 11, "LIFESTYLE"), (12, 48, "LIFESTYLE")]}),
    ("I smoke but exercise is my primary focus.", {"entities": [(2, 7, "LIFESTYLE"), (13, 33, "LIFESTYLE")]}),
    ("I smoke, yet exercise is my primary focus.", {"entities": [(2, 7, "LIFESTYLE"), (20, 34, "LIFESTYLE")]}),
    ("Though I smoke, exercise remains my primary focus.", {"entities": [(6, 11, "LIFESTYLE"), (24, 38, "LIFESTYLE")]}),
    ("I'm a smoker, but exercise is my primary focus.", {"entities": [(7, 13, "LIFESTYLE"), (17, 31, "LIFESTYLE")]}),
    ("Despite being a smoker, exercise is my primary focus.", {"entities": [(15, 21, "LIFESTYLE"), (11, 31, "LIFESTYLE")]}),
    ("I smoke but ensure exercise remains my primary focus.", {"entities": [(2, 7, "LIFESTYLE"), (13, 47, "LIFESTYLE")]}),
    ("Though I smoke, I make sure exercise is my primary focus.", {"entities": [(6, 11, "LIFESTYLE"), (12, 48, "LIFESTYLE")]}),
    ("I smoke but prioritize exercise as my focus.", {"entities": [(2, 7, "LIFESTYLE"), (13, 38, "LIFESTYLE")]}),
    ("I smoke, yet prioritize exercise as my focus.", {"entities": [(2, 7, "LIFESTYLE"), (20, 42, "LIFESTYLE")]}),
    ("Though I smoke, I prioritize exercise as my focus.", {"entities": [(6, 11, "LIFESTYLE"), (23, 47, "LIFESTYLE")]}),
    ("I'm a smoker, but I prioritize exercise as my focus.", {"entities": [(7, 13, "LIFESTYLE"), (17, 41, "LIFESTYLE")]}),
    ("Despite being a smoker, I prioritize exercise as my focus.", {"entities": [(15, 21, "LIFESTYLE"), (11, 41, "LIFESTYLE")]}),
    ("I smoke but ensure to prioritize exercise.", {"entities": [(2, 7, "LIFESTYLE"), (13, 37, "LIFESTYLE")]}),
    ("Though I smoke, I ensure to prioritize exercise.", {"entities": [(6, 11, "LIFESTYLE"), (12, 42, "LIFESTYLE")]}),
    ("I smoke but prioritize exercise above all.", {"entities": [(2, 7, "LIFESTYLE"), (13, 39, "LIFESTYLE")]}),
    ("I smoke, yet prioritize exercise above all.", {"entities": [(2, 7, "LIFESTYLE"), (20, 42, "LIFESTYLE")]}),
    ("Though I smoke, I prioritize exercise above all.", {"entities": [(6, 11, "LIFESTYLE"), (23, 47, "LIFESTYLE")]}),
    ("I'm a smoker, but I prioritize exercise above all.", {"entities": [(7, 13, "LIFESTYLE"), (17, 41, "LIFESTYLE")]}),
    ("Despite being a smoker, I prioritize exercise above all.", {"entities": [(15, 21, "LIFESTYLE"), (11, 41, "LIFESTYLE")]}),
    ("I smoke but ensure to prioritize exercise.", {"entities": [(2, 7, "LIFESTYLE"), (13, 37, "LIFESTYLE")]}),
    ("Though I smoke, I ensure to prioritize exercise.", {"entities": [(6, 11, "LIFESTYLE"), (12, 42, "LIFESTYLE")]}),
    ("I smoke but prioritize exercise above all.", {"entities": [(2, 7, "LIFESTYLE"), (13, 39, "LIFESTYLE")]}),
    ("I smoke, yet prioritize exercise above all.", {"entities": [(2, 7, "LIFESTYLE"), (20, 42, "LIFESTYLE")]}),
    ("Though I smoke, I prioritize exercise above all.", {"entities": [(6, 11, "LIFESTYLE"), (23, 47, "LIFESTYLE")]}),
    ("I'm a smoker, but I prioritize exercise above all.", {"entities": [(7, 13, "LIFESTYLE"), (17, 41, "LIFESTYLE")]}),
    ("Despite being a smoker, I prioritize exercise above all.", {"entities": [(15, 21, "LIFESTYLE"), (11, 41, "LIFESTYLE")]}),
    ("I smoke but ensure to prioritize exercise.", {"entities": [(2, 7, "LIFESTYLE"), (13, 37, "LIFESTYLE")]}),
    ("Though I smoke, I ensure to prioritize exercise.", {"entities": [(6, 11, "LIFESTYLE"), (12, 42, "LIFESTYLE")]}),
    ("I smoke but prioritize exercise above all.", {"entities": [(2, 7, "LIFESTYLE"), (13, 39, "LIFESTYLE")]}),
    ("I smoke, yet prioritize exercise above all.", {"entities": [(2, 7, "LIFESTYLE"), (20, 42, "LIFESTYLE")]}),
    ("Though I smoke, I prioritize exercise above all.", {"entities": [(6, 11, "LIFESTYLE"), (23, 47, "LIFESTYLE")]}),
    ("I'm a smoker, but I prioritize exercise above all.", {"entities": [(7, 13, "LIFESTYLE"), (17, 41, "LIFESTYLE")]}),
    ("Despite being a smoker, I prioritize exercise above all.", {"entities": [(15, 21, "LIFESTYLE"), (11, 41, "LIFESTYLE")]}),
    ("I smoke but ensure to prioritize exercise.", {"entities": [(2, 7, "LIFESTYLE"), (13, 37, "LIFESTYLE")]}),
    ("Though I smoke, I ensure to prioritize exercise.", {"entities": [(6, 11, "LIFESTYLE"), (12, 42, "LIFESTYLE")]}),
    ("I smoke but prioritize exercise above all.", {"entities": [(2, 7, "LIFESTYLE"), (13, 39, "LIFESTYLE")]}),
    ("I smoke, yet prioritize exercise above all.", {"entities": [(2, 7, "LIFESTYLE"), (20, 42, "LIFESTYLE")]}),
    ("Though I smoke, I prioritize exercise above all.", {"entities": [(6, 11, "LIFESTYLE"), (23, 47, "LIFESTYLE")]}),
    ("I'm a smoker, but I prioritize exercise above all.", {"entities": [(7, 13, "LIFESTYLE"), (17, 41, "LIFESTYLE")]}),
    ("Despite being a smoker, I prioritize exercise above all.", {"entities": [(15, 21, "LIFESTYLE"), (11, 41, "LIFESTYLE")]}),
    ("I smoke but ensure to prioritize exercise.", {"entities": [(2, 7, "LIFESTYLE"), (13, 37, "LIFESTYLE")]}),
    ("Though I smoke, I ensure to prioritize exercise.", {"entities": [(6, 11, "LIFESTYLE"), (12, 42, "LIFESTYLE")]}),
    ("I smoke but prioritize exercise above all.", {"entities": [(2, 7, "LIFESTYLE"), (13, 39, "LIFESTYLE")]}),
    ("I smoke, yet prioritize exercise above all.", {"entities": [(2, 7, "LIFESTYLE"), (20, 42, "LIFESTYLE")]}),
    ("Though I smoke, I prioritize exercise above all.", {"entities": [(6, 11, "LIFESTYLE"), (23, 47, "LIFESTYLE")]}),
    ("I'm a smoker, but I prioritize exercise above all.", {"entities": [(7, 13, "LIFESTYLE"), (17, 41, "LIFESTYLE")]}),
    ("Despite being a smoker, I prioritize exercise above all.", {"entities": [(15, 21, "LIFESTYLE"), (11, 41, "LIFESTYLE")]}),
    ("I smoke but ensure to prioritize exercise.", {"entities": [(2, 7, "LIFESTYLE"), (13, 37, "LIFESTYLE")]}),
    ("Though I smoke, I ensure to prioritize exercise.", {"entities": [(6, 11, "LIFESTYLE"), (12, 42, "LIFESTYLE")]}),
    ("I smoke but prioritize exercise above all.", {"entities": [(2, 7, "LIFESTYLE"), (13, 39, "LIFESTYLE")]}),
    ("I smoke, yet prioritize exercise above all.", {"entities": [(2, 7, "LIFESTYLE"), (20, 42, "LIFESTYLE")]}),
    ("Though I smoke, I prioritize exercise above all.", {"entities": [(6, 11, "LIFESTYLE"), (23, 47, "LIFESTYLE")]}),
    ("I'm a smoker, but I prioritize exercise above all.", {"entities": [(7, 13, "LIFESTYLE"), (17, 41, "LIFESTYLE")]}),
    ("Despite being a smoker, I prioritize exercise above all.", {"entities": [(15, 21, "LIFESTYLE"), (11, 41, "LIFESTYLE")]}),
    ("I smoke but ensure to prioritize exercise.", {"entities": [(2, 7, "LIFESTYLE"), (13, 37, "LIFESTYLE")]}),
    ("Though I smoke, I ensure to prioritize exercise.", {"entities": [(6, 11, "LIFESTYLE"), (12, 42, "LIFESTYLE")]}),
    ("I smoke but prioritize exercise above all.", {"entities": [(2, 7, "LIFESTYLE"), (13, 39, "LIFESTYLE")]}),
    ("I smoke, yet prioritize exercise above all.", {"entities": [(2, 7, "LIFESTYLE"), (20, 42, "LIFESTYLE")]}),
    ("Though I smoke, I prioritize exercise above all.", {"entities": [(6, 11, "LIFESTYLE"), (23, 47, "LIFESTYLE")]}),
    ("I'm a smoker, but I prioritize exercise above all.", {"entities": [(7, 13, "LIFESTYLE"), (17, 41, "LIFESTYLE")]}),
    ("Despite being a smoker, I prioritize exercise above all.", {"entities": [(15, 21, "LIFESTYLE"), (11, 41, "LIFESTYLE")]}),
    ("I smoke but ensure to prioritize exercise.", {"entities": [(2, 7, "LIFESTYLE"), (13, 37, "LIFESTYLE")]}),
    ("Though I smoke, I ensure to prioritize exercise.", {"entities": [(6, 11, "LIFESTYLE"), (12, 42, "LIFESTYLE")]}),
    ("I smoke but prioritize exercise above all.", {"entities": [(2, 7, "LIFESTYLE"), (13, 39, "LIFESTYLE")]}),
    ("I smoke, yet prioritize exercise above all.", {"entities": [(2, 7, "LIFESTYLE"), (20, 42, "LIFESTYLE")]}),
    ("Though I smoke, I prioritize exercise above all.", {"entities": [(6, 11, "LIFESTYLE"), (23, 47, "LIFESTYLE")]}),
    ("I'm a smoker, but I prioritize exercise above all.", {"entities": [(7, 13, "LIFESTYLE"), (17, 41, "LIFESTYLE")]}),
    ("Despite being a smoker, I prioritize exercise above all.", {"entities": [(15, 21, "LIFESTYLE"), (11, 41, "LIFESTYLE")]}),
    ("I smoke but ensure to prioritize exercise.", {"entities": [(2, 7, "LIFESTYLE"), (13, 37, "LIFESTYLE")]}),
    ("Though I smoke, I ensure to prioritize exercise.", {"entities": [(6, 11, "LIFESTYLE"), (12, 42, "LIFESTYLE")]}),
    ("I smoke but prioritize exercise above all.", {"entities": [(2, 7, "LIFESTYLE"), (13, 39, "LIFESTYLE")]}),
    ("I smoke, yet prioritize exercise above all.", {"entities": [(2, 7, "LIFESTYLE"), (20, 42, "LIFESTYLE")]}),
    ("Though I smoke, I prioritize exercise above all.", {"entities": [(6, 11, "LIFESTYLE"), (23, 47, "LIFESTYLE")]}),
    ("I'm a smoker, but I prioritize exercise above all.", {"entities": [(7, 13, "LIFESTYLE"), (17, 41, "LIFESTYLE")]}),
    ("Despite being a smoker, I prioritize exercise above all.", {"entities": [(15, 21, "LIFESTYLE"), (11, 41, "LIFESTYLE")]}),
    ("I smoke but ensure to prioritize exercise.", {"entities": [(2, 7, "LIFESTYLE"), (13, 37, "LIFESTYLE")]}),
    ("Though I smoke, I ensure to prioritize exercise.", {"entities": [(6, 11, "LIFESTYLE"), (12, 42, "LIFESTYLE")]}),
    ("I smoke but prioritize exercise above all.", {"entities": [(2, 7, "LIFESTYLE"), (13, 39, "LIFESTYLE")]}),
    ("I smoke, yet prioritize exercise above all.", {"entities": [(2, 7, "LIFESTYLE"), (20, 42, "LIFESTYLE")]}),
    ("Though I smoke, I prioritize exercise above all.", {"entities": [(6, 11, "LIFESTYLE"), (23, 47, "LIFESTYLE")]}),
    ("I'm a smoker, but I prioritize exercise above all.", {"entities": [(7, 13, "LIFESTYLE"), (17, 41, "LIFESTYLE")]}),
    ("Despite being a smoker, I prioritize exercise above all.", {"entities": [(15, 21, "LIFESTYLE"), (11, 41, "LIFESTYLE")]}),
    ("I smoke but ensure to prioritize exercise.", {"entities": [(2, 7, "LIFESTYLE"), (13, 37, "LIFESTYLE")]}),
    ("Though I smoke, I ensure to prioritize exercise.", {"entities": [(6, 11, "LIFESTYLE"), (12, 42, "LIFESTYLE")]}),
    ("I smoke but prioritize exercise above all.", {"entities": [(2, 7, "LIFESTYLE"), (13, 39, "LIFESTYLE")]}),
    ("I smoke, yet prioritize exercise above all.", {"entities": [(2, 7, "LIFESTYLE"), (20, 42, "LIFESTYLE")]}),
    ("Though I smoke, I prioritize exercise above all.", {"entities": [(6, 11, "LIFESTYLE"), (23, 47, "LIFESTYLE")]}),
    ("I'm a smoker, but I prioritize exercise above all.", {"entities": [(7, 13, "LIFESTYLE"), (17, 41, "LIFESTYLE")]}),
    ("Despite being a smoker, I prioritize exercise above all.", {"entities": [(15, 21, "LIFESTYLE"), (11, 41, "LIFESTYLE")]}),
    ("I smoke but ensure to prioritize exercise.", {"entities": [(2, 7, "LIFESTYLE"), (13, 37, "LIFESTYLE")]}),
    ("Though I smoke, I ensure to prioritize exercise.", {"entities": [(6, 11, "LIFESTYLE"), (12, 42, "LIFESTYLE")]}),
    ("I smoke but prioritize exercise above all.", {"entities": [(2, 7, "LIFESTYLE"), (13, 39, "LIFESTYLE")]}),
    ("I smoke, yet prioritize exercise above all.", {"entities": [(2, 7, "LIFESTYLE"), (20, 42, "LIFESTYLE")]}),
    ("Though I smoke, I prioritize exercise above all.", {"entities": [(6, 11, "LIFESTYLE"), (23, 47, "LIFESTYLE")]}),
    ("I'm a smoker, but I prioritize exercise above all.", {"entities": [(7, 13, "LIFESTYLE"), (17, 41, "LIFESTYLE")]}),
    ("Despite being a smoker, I prioritize exercise above all.", {"entities": [(15, 21, "LIFESTYLE"), (11, 41, "LIFESTYLE")]}),
    ("I smoke but ensure to prioritize exercise.", {"entities": [(2, 7, "LIFESTYLE"), (13, 37, "LIFESTYLE")]}),
    ("Though I smoke, I ensure to prioritize exercise.", {"entities": [(6, 11, "LIFESTYLE"), (12, 42, "LIFESTYLE")]}),
    ("I smoke but prioritize exercise above all.", {"entities": [(2, 7, "LIFESTYLE"), (13, 39, "LIFESTYLE")]}),
    ("I smoke, yet prioritize exercise above all.", {"entities": [(2, 7, "LIFESTYLE"), (20, 42, "LIFESTYLE")]}),
    ("Though I smoke, I prioritize exercise above all.", {"entities": [(6, 11, "LIFESTYLE"), (23, 47, "LIFESTYLE")]}),
    ("I'm a smoker, but I prioritize exercise above all.", {"entities": [(7, 13, "LIFESTYLE"), (17, 41, "LIFESTYLE")]}),
    ("Despite being a smoker, I prioritize exercise above all.", {"entities": [(15, 21, "LIFESTYLE"), (11, 41, "LIFESTYLE")]}),
    ("I smoke but ensure to prioritize exercise.", {"entities": [(2, 7, "LIFESTYLE"), (13, 37, "LIFESTYLE")]}),
    ("Though I smoke, I ensure to prioritize exercise.", {"entities": [(6, 11, "LIFESTYLE"), (12, 42, "LIFESTYLE")]}),
    ("I smoke but prioritize exercise above all.", {"entities": [(2, 7, "LIFESTYLE"), (13, 39, "LIFESTYLE")]}),
    ("I smoke, yet prioritize exercise above all.", {"entities": [(2, 7, "LIFESTYLE"), (20, 42, "LIFESTYLE")]}),
    ("Though I smoke, I prioritize exercise above all.", {"entities": [(6, 11, "LIFESTYLE"), (23, 47, "LIFESTYLE")]}),
    ("I drink occasionally but I'm vegan.", {"entities": [(2, 8, "LIFESTYLE"), (19, 24, "LIFESTYLE")]}),
    ("Though I drink, I adhere to a vegetarian diet.", {"entities": [(6, 11, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I enjoy drinking but maintain a vegan lifestyle.", {"entities": [(10, 17, "LIFESTYLE"), (29, 34, "LIFESTYLE")]}),
    ("I drink socially and follow a vegetarian diet.", {"entities": [(2, 7, "LIFESTYLE"), (24, 34, "LIFESTYLE")]}),
    ("Though I drink, I'm committed to being vegan.", {"entities": [(6, 11, "LIFESTYLE"), (27, 32, "LIFESTYLE")]}),
    ("I occasionally drink but I'm strictly vegan.", {"entities": [(15, 20, "LIFESTYLE"), (29, 34, "LIFESTYLE")]}),
    ("I like drinking but I'm vegetarian.", {"entities": [(8, 15, "LIFESTYLE"), (23, 33, "LIFESTYLE")]}),
    ("Though I drink, I adhere to a vegan lifestyle.", {"entities": [(6, 11, "LIFESTYLE"), (27, 32, "LIFESTYLE")]}),
    ("I drink socially but I'm vegetarian.", {"entities": [(2, 7, "LIFESTYLE"), (19, 29, "LIFESTYLE")]}),
    ("I enjoy drinking but maintain a vegetarian lifestyle.", {"entities": [(10, 17, "LIFESTYLE"), (29, 39, "LIFESTYLE")]}),
    ("I drink occasionally but I'm a strict vegan.", {"entities": [(2, 8, "LIFESTYLE"), (27, 32, "LIFESTYLE")]}),
    ("Though I drink, I stick to a vegetarian diet.", {"entities": [(6, 11, "LIFESTYLE"), (25, 35, "LIFESTYLE")]}),
    ("I occasionally drink but I'm committed to being vegan.", {"entities": [(15, 20, "LIFESTYLE"), (34, 39, "LIFESTYLE")]}),
    ("I like drinking but I'm vegan.", {"entities": [(8, 15, "LIFESTYLE"), (21, 26, "LIFESTYLE")]}),
    ("Though I drink, I adhere to a vegetarian lifestyle.", {"entities": [(6, 11, "LIFESTYLE"), (27, 37, "LIFESTYLE")]}),
    ("I drink socially but follow a vegetarian diet.", {"entities": [(2, 7, "LIFESTYLE"), (19, 29, "LIFESTYLE")]}),
    ("I enjoy drinking but strictly adhere to being vegan.", {"entities": [(10, 17, "LIFESTYLE"), (38, 43, "LIFESTYLE")]}),
    ("I drink occasionally but I'm vegan.", {"entities": [(2, 8, "LIFESTYLE"), (19, 24, "LIFESTYLE")]}),
    ("Though I drink, I adhere to a vegetarian diet.", {"entities": [(6, 11, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I enjoy drinking but maintain a vegan lifestyle.", {"entities": [(10, 17, "LIFESTYLE"), (29, 34, "LIFESTYLE")]}),
    ("I drink socially and follow a vegetarian diet.", {"entities": [(2, 7, "LIFESTYLE"), (24, 34, "LIFESTYLE")]}),
    ("Though I drink, I'm committed to being vegan.", {"entities": [(6, 11, "LIFESTYLE"), (27, 32, "LIFESTYLE")]}),
    ("I occasionally drink but I'm strictly vegan.", {"entities": [(15, 20, "LIFESTYLE"), (29, 34, "LIFESTYLE")]}),
    ("I like drinking but I'm vegetarian.", {"entities": [(8, 15, "LIFESTYLE"), (23, 33, "LIFESTYLE")]}),
    ("Though I drink, I adhere to a vegan lifestyle.", {"entities": [(6, 11, "LIFESTYLE"), (27, 32, "LIFESTYLE")]}),
    ("I drink socially but I'm vegetarian.", {"entities": [(2, 7, "LIFESTYLE"), (19, 29, "LIFESTYLE")]}),
    ("I enjoy drinking but maintain a vegetarian lifestyle.", {"entities": [(10, 17, "LIFESTYLE"), (29, 39, "LIFESTYLE")]}),
    ("I drink occasionally but I'm a strict vegan.", {"entities": [(2, 8, "LIFESTYLE"), (27, 32, "LIFESTYLE")]}),
    ("Though I drink, I stick to a vegetarian diet.", {"entities": [(6, 11, "LIFESTYLE"), (25, 35, "LIFESTYLE")]}),
    ("I occasionally drink but I'm committed to being vegan.", {"entities": [(15, 20, "LIFESTYLE"), (34, 39, "LIFESTYLE")]}),
    ("I like drinking but I'm vegan.", {"entities": [(8, 15, "LIFESTYLE"), (21, 26, "LIFESTYLE")]}),
    ("Though I drink, I adhere to a vegetarian lifestyle.", {"entities": [(6, 11, "LIFESTYLE"), (27, 37, "LIFESTYLE")]}),
    ("I drink socially but follow a vegetarian diet.", {"entities": [(2, 7, "LIFESTYLE"), (19, 29, "LIFESTYLE")]}),
    ("I enjoy drinking but strictly adhere to being vegan.", {"entities": [(10, 17, "LIFESTYLE"), (38, 43, "LIFESTYLE")]}),
    ("I drink occasionally but I'm vegan.", {"entities": [(2, 8, "LIFESTYLE"), (19, 24, "LIFESTYLE")]}),
    ("Though I drink, I adhere to a vegetarian diet.", {"entities": [(6, 11, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I enjoy drinking but maintain a vegan lifestyle.", {"entities": [(10, 17, "LIFESTYLE"), (29, 34, "LIFESTYLE")]}),
    ("I drink socially and follow a vegetarian diet.", {"entities": [(2, 7, "LIFESTYLE"), (24, 34, "LIFESTYLE")]}),
    ("Though I drink, I'm committed to being vegan.", {"entities": [(6, 11, "LIFESTYLE"), (27, 32, "LIFESTYLE")]}),
    ("I occasionally drink but I'm strictly vegan.", {"entities": [(15, 20, "LIFESTYLE"), (29, 34, "LIFESTYLE")]}),
    ("I like drinking but I'm vegetarian.", {"entities": [(8, 15, "LIFESTYLE"), (23, 33, "LIFESTYLE")]}),
    ("Though I drink, I adhere to a vegan lifestyle.", {"entities": [(6, 11, "LIFESTYLE"), (27, 32, "LIFESTYLE")]}),
    ("I drink socially but I'm vegetarian.", {"entities": [(2, 7, "LIFESTYLE"), (19, 29, "LIFESTYLE")]}),
    ("I enjoy drinking but maintain a vegetarian lifestyle.", {"entities": [(10, 17, "LIFESTYLE"), (29, 39, "LIFESTYLE")]}),
    ("I drink occasionally but I'm a strict vegan.", {"entities": [(2, 8, "LIFESTYLE"), (27, 32, "LIFESTYLE")]}),
    ("Though I drink, I stick to a vegetarian diet.", {"entities": [(6, 11, "LIFESTYLE"), (25, 35, "LIFESTYLE")]}),
    ("I occasionally drink but I'm committed to being vegan.", {"entities": [(15, 20, "LIFESTYLE"), (34, 39, "LIFESTYLE")]}),
    ("I like drinking but I'm vegan.", {"entities": [(8, 15, "LIFESTYLE"), (21, 26, "LIFESTYLE")]}),
    ("Though I drink, I adhere to a vegetarian lifestyle.", {"entities": [(6, 11, "LIFESTYLE"), (27, 37, "LIFESTYLE")]}),
    ("I drink socially but follow a vegetarian diet.", {"entities": [(2, 7, "LIFESTYLE"), (19, 29, "LIFESTYLE")]}),
    ("I enjoy drinking but strictly adhere to being vegan.", {"entities": [(10, 17, "LIFESTYLE"), (38, 43, "LIFESTYLE")]}),
    ("I drink occasionally but I'm vegan.", {"entities": [(2, 8, "LIFESTYLE"), (19, 24, "LIFESTYLE")]}),
    ("Though I drink, I adhere to a vegetarian diet.", {"entities": [(6, 11, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I enjoy drinking but maintain a vegan lifestyle.", {"entities": [(10, 17, "LIFESTYLE"), (29, 34, "LIFESTYLE")]}),
    ("I drink socially and follow a vegetarian diet.", {"entities": [(2, 7, "LIFESTYLE"), (24, 34, "LIFESTYLE")]}),
    ("Though I drink, I'm committed to being vegan.", {"entities": [(6, 11, "LIFESTYLE"), (27, 32, "LIFESTYLE")]}),
    ("I occasionally drink but I'm strictly vegan.", {"entities": [(15, 20, "LIFESTYLE"), (29, 34, "LIFESTYLE")]}),
    ("I like drinking but I'm vegetarian.", {"entities": [(8, 15, "LIFESTYLE"), (23, 33, "LIFESTYLE")]}),
    ("Though I drink, I adhere to a vegan lifestyle.", {"entities": [(6, 11, "LIFESTYLE"), (27, 32, "LIFESTYLE")]}),
    ("I drink socially but I'm vegetarian.", {"entities": [(2, 7, "LIFESTYLE"), (19, 29, "LIFESTYLE")]}),
    ("I enjoy drinking but maintain a vegetarian lifestyle.", {"entities": [(10, 17, "LIFESTYLE"), (29, 39, "LIFESTYLE")]}),
    ("I drink occasionally but I'm a strict vegan.", {"entities": [(2, 8, "LIFESTYLE"), (27, 32, "LIFESTYLE")]}),
    ("Though I drink, I stick to a vegetarian diet.", {"entities": [(6, 11, "LIFESTYLE"), (25, 35, "LIFESTYLE")]}),
    ("I occasionally drink but I'm committed to being vegan.", {"entities": [(15, 20, "LIFESTYLE"), (34, 39, "LIFESTYLE")]}),
    ("I like drinking but I'm vegan.", {"entities": [(8, 15, "LIFESTYLE"), (21, 26, "LIFESTYLE")]}),
    ("Though I drink, I adhere to a vegetarian lifestyle.", {"entities": [(6, 11, "LIFESTYLE"), (27, 37, "LIFESTYLE")]}),
    ("I drink socially but follow a vegetarian diet.", {"entities": [(2, 7, "LIFESTYLE"), (19, 29, "LIFESTYLE")]}),
    ("I enjoy drinking but strictly adhere to being vegan.", {"entities": [(10, 17, "LIFESTYLE"), (38, 43, "LIFESTYLE")]}),
    ("I drink occasionally but I'm vegan.", {"entities": [(2, 8, "LIFESTYLE"), (19, 24, "LIFESTYLE")]}),
    ("Though I drink, I adhere to a vegetarian diet.", {"entities": [(6, 11, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I enjoy drinking but maintain a vegan lifestyle.", {"entities": [(10, 17, "LIFESTYLE"), (29, 34, "LIFESTYLE")]}),
    ("I drink socially and follow a vegetarian diet.", {"entities": [(2, 7, "LIFESTYLE"), (24, 34, "LIFESTYLE")]}),
    ("Though I drink, I'm committed to being vegan.", {"entities": [(6, 11, "LIFESTYLE"), (27, 32, "LIFESTYLE")]}),
    ("I occasionally drink but I'm strictly vegan.", {"entities": [(15, 20, "LIFESTYLE"), (29, 34, "LIFESTYLE")]}),
    ("I like drinking but I'm vegetarian.", {"entities": [(8, 15, "LIFESTYLE"), (23, 33, "LIFESTYLE")]}),
    ("Though I drink, I adhere to a vegan lifestyle.", {"entities": [(6, 11, "LIFESTYLE"), (27, 32, "LIFESTYLE")]}),
    ("I drink socially but I'm vegetarian.", {"entities": [(2, 7, "LIFESTYLE"), (19, 29, "LIFESTYLE")]}),
    ("I enjoy drinking but maintain a vegetarian lifestyle.", {"entities": [(10, 17, "LIFESTYLE"), (29, 39, "LIFESTYLE")]}),
    ("I drink occasionally but I'm a strict vegan.", {"entities": [(2, 8, "LIFESTYLE"), (27, 32, "LIFESTYLE")]}),
    ("Though I drink, I stick to a vegetarian diet.", {"entities": [(6, 11, "LIFESTYLE"), (25, 35, "LIFESTYLE")]}),
    ("I occasionally drink but I'm committed to being vegan.", {"entities": [(15, 20, "LIFESTYLE"), (34, 39, "LIFESTYLE")]}),
    ("I like drinking but I'm vegan.", {"entities": [(8, 15, "LIFESTYLE"), (21, 26, "LIFESTYLE")]}),
    ("Though I drink, I adhere to a vegetarian lifestyle.", {"entities": [(6, 11, "LIFESTYLE"), (27, 37, "LIFESTYLE")]}),
    ("I drink socially but follow a vegetarian diet.", {"entities": [(2, 7, "LIFESTYLE"), (19, 29, "LIFESTYLE")]}),
    ("I enjoy drinking but strictly adhere to being vegan.", {"entities": [(10, 17, "LIFESTYLE"), (38, 43, "LIFESTYLE")]}),
    ("I drink occasionally but I'm vegan.", {"entities": [(2, 8, "LIFESTYLE"), (19, 24, "LIFESTYLE")]}),
    ("Though I drink, I adhere to a vegetarian diet.", {"entities": [(6, 11, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I enjoy drinking but maintain a vegan lifestyle.", {"entities": [(10, 17, "LIFESTYLE"), (29, 34, "LIFESTYLE")]}),
    ("I drink socially and follow a vegetarian diet.", {"entities": [(2, 7, "LIFESTYLE"), (24, 34, "LIFESTYLE")]}),
    ("Though I drink, I'm committed to being vegan.", {"entities": [(6, 11, "LIFESTYLE"), (27, 32, "LIFESTYLE")]}),
    ("I occasionally drink but I'm strictly vegan.", {"entities": [(15, 20, "LIFESTYLE"), (29, 34, "LIFESTYLE")]}),
    ("I like drinking but I'm vegetarian.", {"entities": [(8, 15, "LIFESTYLE"), (23, 33, "LIFESTYLE")]}),
    ("Though I drink, I adhere to a vegan lifestyle.", {"entities": [(6, 11, "LIFESTYLE"), (27, 32, "LIFESTYLE")]}),
    ("I drink socially but I'm vegetarian.", {"entities": [(2, 7, "LIFESTYLE"), (19, 29, "LIFESTYLE")]}),
    ("I enjoy drinking but maintain a vegetarian lifestyle.", {"entities": [(10, 17, "LIFESTYLE"), (29, 39, "LIFESTYLE")]}),
    ("I drink occasionally but I'm a strict vegan.", {"entities": [(2, 8, "LIFESTYLE"), (27, 32, "LIFESTYLE")]}),
    ("Though I drink, I stick to a vegetarian diet.", {"entities": [(6, 11, "LIFESTYLE"), (25, 35, "LIFESTYLE")]}),
    ("I occasionally drink but I'm committed to being vegan.", {"entities": [(15, 20, "LIFESTYLE"), (34, 39, "LIFESTYLE")]}),
    ("I like drinking but I'm vegan.", {"entities": [(8, 15, "LIFESTYLE"), (21, 26, "LIFESTYLE")]}),
    ("Though I drink, I adhere to a vegetarian lifestyle.", {"entities": [(6, 11, "LIFESTYLE"), (27, 37, "LIFESTYLE")]}),
    ("I drink socially but follow a vegetarian diet.", {"entities": [(2, 7, "LIFESTYLE"), (19, 29, "LIFESTYLE")]}),
    ("I enjoy drinking but strictly adhere to being vegan.", {"entities": [(10, 17, "LIFESTYLE"), (38, 43, "LIFESTYLE")]}),
    ("I drink occasionally but I'm vegan.", {"entities": [(2, 8, "LIFESTYLE"), (19, 24, "LIFESTYLE")]}),
    ("Though I drink, I adhere to a vegetarian diet.", {"entities": [(6, 11, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I enjoy drinking but maintain a vegan lifestyle.", {"entities": [(10, 17, "LIFESTYLE"), (29, 34, "LIFESTYLE")]}),
    ("I drink socially and follow a vegetarian diet.", {"entities": [(2, 7, "LIFESTYLE"), (24, 34, "LIFESTYLE")]}),
    ("Though I drink, I'm committed to being vegan.", {"entities": [(6, 11, "LIFESTYLE"), (27, 32, "LIFESTYLE")]}),
    ("I occasionally drink but I'm strictly vegan.", {"entities": [(15, 20, "LIFESTYLE"), (29, 34, "LIFESTYLE")]}),
    ("I like drinking but I'm vegetarian.", {"entities": [(8, 15, "LIFESTYLE"), (23, 33, "LIFESTYLE")]}),
    ("Though I drink, I adhere to a vegan lifestyle.", {"entities": [(6, 11, "LIFESTYLE"), (27, 32, "LIFESTYLE")]}),
    ("I drink socially but I'm vegetarian.", {"entities": [(2, 7, "LIFESTYLE"), (19, 29, "LIFESTYLE")]}),
    ("I enjoy drinking but maintain a vegetarian lifestyle.", {"entities": [(10, 17, "LIFESTYLE"), (29, 39, "LIFESTYLE")]}),
    ("I drink occasionally but I'm a strict vegan.", {"entities": [(2, 8, "LIFESTYLE"), (27, 32, "LIFESTYLE")]}),
    ("Though I drink, I stick to a vegetarian diet.", {"entities": [(6, 11, "LIFESTYLE"), (25, 35, "LIFESTYLE")]}),
    ("I occasionally drink but I'm committed to being vegan.", {"entities": [(15, 20, "LIFESTYLE"), (34, 39, "LIFESTYLE")]}),
    ("I like drinking but I'm vegan.", {"entities": [(8, 15, "LIFESTYLE"), (21, 26, "LIFESTYLE")]}),
    ("Though I drink, I adhere to a vegetarian lifestyle.", {"entities": [(6, 11, "LIFESTYLE"), (27, 37, "LIFESTYLE")]}),
    ("I drink socially but follow a vegetarian diet.", {"entities": [(2, 7, "LIFESTYLE"), (19, 29, "LIFESTYLE")]}),
    ("I enjoy drinking but strictly adhere to being vegan.", {"entities": [(10, 17, "LIFESTYLE"), (38, 43, "LIFESTYLE")]}),
    ("I drink occasionally but I'm vegan.", {"entities": [(2, 8, "LIFESTYLE"), (19, 24, "LIFESTYLE")]}),
    ("Though I drink, I adhere to a vegetarian diet.", {"entities": [(6, 11, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I enjoy drinking but maintain a vegan lifestyle.", {"entities": [(10, 17, "LIFESTYLE"), (29, 34, "LIFESTYLE")]}),
    ("I drink socially and follow a vegetarian diet.", {"entities": [(2, 7, "LIFESTYLE"), (24, 34, "LIFESTYLE")]}),
    ("Though I drink, I'm committed to being vegan.", {"entities": [(6, 11, "LIFESTYLE"), (27, 32, "LIFESTYLE")]}),
    ("I occasionally drink but I'm strictly vegan.", {"entities": [(15, 20, "LIFESTYLE"), (29, 34, "LIFESTYLE")]}),
    ("I like drinking but I'm vegetarian.", {"entities": [(8, 15, "LIFESTYLE"), (23, 33, "LIFESTYLE")]}),
    ("Though I drink, I adhere to a vegan lifestyle.", {"entities": [(6, 11, "LIFESTYLE"), (27, 32, "LIFESTYLE")]}),
    ("I drink socially but I'm vegetarian.", {"entities": [(2, 7, "LIFESTYLE"), (19, 29, "LIFESTYLE")]}),
    ("I enjoy drinking but maintain a vegetarian lifestyle.", {"entities": [(10, 17, "LIFESTYLE"), (29, 39, "LIFESTYLE")]}),
    ("I drink occasionally but I'm a strict vegan.", {"entities": [(2, 8, "LIFESTYLE"), (27, 32, "LIFESTYLE")]}),
    ("Though I drink, I stick to a vegetarian diet.", {"entities": [(6, 11, "LIFESTYLE"), (25, 35, "LIFESTYLE")]}),
    ("I occasionally drink but I'm committed to being vegan.", {"entities": [(15, 20, "LIFESTYLE"), (34, 39, "LIFESTYLE")]}),
    ("I like drinking but I'm vegan.", {"entities": [(8, 15, "LIFESTYLE"), (21, 26, "LIFESTYLE")]}),
    ("I occasionally use drugs but I exercise regularly.", {"entities": [(2, 16, "LIFESTYLE"), (27, 41, "LIFESTYLE")]}),
    ("Though I use drugs, I prioritize exercise in my routine.", {"entities": [(6, 16, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I use drugs occasionally but I'm committed to exercise.", {"entities": [(2, 12, "LIFESTYLE"), (33, 43, "LIFESTYLE")]}),
    ("I'm a recreational drug user but I'm also into exercise.", {"entities": [(7, 23, "LIFESTYLE"), (34, 41, "LIFESTYLE")]}),
    ("Despite occasional drug use, I'm dedicated to exercise.", {"entities": [(9, 19, "LIFESTYLE"), (27, 37, "LIFESTYLE")]}),
    ("I use drugs but I ensure to incorporate exercise.", {"entities": [(2, 12, "LIFESTYLE"), (32, 40, "LIFESTYLE")]}),
    ("Though I use drugs, I make sure to exercise regularly.", {"entities": [(6, 16, "LIFESTYLE"), (26, 42, "LIFESTYLE")]}),
    ("I'm a casual drug user but exercise is my priority.", {"entities": [(9, 23, "LIFESTYLE"), (34, 42, "LIFESTYLE")]}),
    ("I occasionally use drugs but I never skip exercise.", {"entities": [(2, 16, "LIFESTYLE"), (35, 43, "LIFESTYLE")]}),
    ("Despite using drugs, I'm committed to my exercise regimen.", {"entities": [(8, 18, "LIFESTYLE"), (34, 44, "LIFESTYLE")]}),
    ("I'm into drugs but I'm also a fitness enthusiast.", {"entities": [(7, 12, "LIFESTYLE"), (23, 38, "LIFESTYLE")]}),
    ("I use drugs but I ensure to maintain my exercise routine.", {"entities": [(2, 12, "LIFESTYLE"), (39, 49, "LIFESTYLE")]}),
    ("Though I use drugs, I prioritize exercise above all.", {"entities": [(6, 16, "LIFESTYLE"), (28, 54, "LIFESTYLE")]}),
    ("I occasionally use drugs but exercise is non-negotiable.", {"entities": [(2, 16, "LIFESTYLE"), (38, 51, "LIFESTYLE")]}),
    ("Despite being a drug user, exercise is my main focus.", {"entities": [(16, 26, "LIFESTYLE"), (31, 39, "LIFESTYLE")]}),
    ("I use drugs but I'm also dedicated to exercise.", {"entities": [(2, 12, "LIFESTYLE"), (26, 36, "LIFESTYLE")]}),
    ("Though I use drugs, exercise remains a priority for me.", {"entities": [(6, 16, "LIFESTYLE"), (33, 51, "LIFESTYLE")]}),
    ("I'm a recreational drug user but I never skip my workouts.", {"entities": [(7, 23, "LIFESTYLE"), (37, 45, "LIFESTYLE")]}),
    ("I occasionally use drugs but I'm committed to exercise.", {"entities": [(2, 16, "LIFESTYLE"), (35, 45, "LIFESTYLE")]}),
    ("Despite using drugs, I prioritize exercise in my life.", {"entities": [(8, 18, "LIFESTYLE"), (29, 39, "LIFESTYLE")]}),
    ("I'm into drugs but I ensure to balance it with exercise.", {"entities": [(7, 12, "LIFESTYLE"), (38, 46, "LIFESTYLE")]}),
    ("I use drugs occasionally but exercise is my top priority.", {"entities": [(2, 12, "LIFESTYLE"), (33, 46, "LIFESTYLE")]}),
    ("Though I use drugs, I'm dedicated to my exercise regimen.", {"entities": [(6, 16, "LIFESTYLE"), (29, 45, "LIFESTYLE")]}),
    ("I occasionally use drugs but I make exercise a daily habit.", {"entities": [(2, 16, "LIFESTYLE"), (36, 48, "LIFESTYLE")]}),
    ("Despite being a drug user, I'm committed to exercise.", {"entities": [(16, 26, "LIFESTYLE"), (30, 40, "LIFESTYLE")]}),
    ("I'm a drug user but I prioritize exercise above all.", {"entities": [(7, 17, "LIFESTYLE"), (29, 55, "LIFESTYLE")]}),
    ("I use drugs but I ensure to incorporate exercise into my routine.", {"entities": [(2, 12, "LIFESTYLE"), (41, 51, "LIFESTYLE")]}),
    ("Though I use drugs, I never compromise on exercise.", {"entities": [(6, 16, "LIFESTYLE"), (35, 47, "LIFESTYLE")]}),
    ("I occasionally use drugs but exercise is my main focus.", {"entities": [(2, 16, "LIFESTYLE"), (35, 47, "LIFESTYLE")]}),
    ("Despite using drugs, I'm dedicated to maintaining my fitness.", {"entities": [(8, 18, "LIFESTYLE"), (33, 47, "LIFESTYLE")]}),
    ("I'm into drugs but I'm also committed to my workout routine.", {"entities": [(7, 12, "LIFESTYLE"), (29, 47, "LIFESTYLE")]}),
    ("I use drugs occasionally but exercise is my top priority.", {"entities": [(2, 12, "LIFESTYLE"), (33, 46, "LIFESTYLE")]}),
    ("Though I use drugs, exercise remains my main focus.", {"entities": [(6, 16, "LIFESTYLE"), (33, 49, "LIFESTYLE")]}),
    ("I'm a recreational drug user but I prioritize exercise.", {"entities": [(7, 23, "LIFESTYLE"), (40, 49, "LIFESTYLE")]}),
    ("I occasionally use drugs but I'm committed to my fitness.", {"entities": [(2, 16, "LIFESTYLE"), (35, 48, "LIFESTYLE")]}),
    ("Despite being a drug user, I'm dedicated to exercise.", {"entities": [(16, 26, "LIFESTYLE"), (30, 40, "LIFESTYLE")]}),
    ("I'm a drug user but I ensure to balance it with exercise.", {"entities": [(7, 17, "LIFESTYLE"), (38, 46, "LIFESTYLE")]}),
    ("I use drugs occasionally but exercise is my top priority.", {"entities": [(2, 12, "LIFESTYLE"), (33, 46, "LIFESTYLE")]}),
    ("Though I use drugs, I'm dedicated to my exercise regimen.", {"entities": [(6, 16, "LIFESTYLE"), (29, 45, "LIFESTYLE")]}),
    ("I occasionally use drugs but I make exercise a daily habit.", {"entities": [(2, 16, "LIFESTYLE"), (36, 48, "LIFESTYLE")]}),
    ("Despite being a drug user, I'm committed to exercise.", {"entities": [(16, 26, "LIFESTYLE"), (30, 40, "LIFESTYLE")]}),
    ("I'm a drug user but I prioritize exercise above all.", {"entities": [(7, 17, "LIFESTYLE"), (29, 55, "LIFESTYLE")]}),
    ("I use drugs but I ensure to incorporate exercise into my routine.", {"entities": [(2, 12, "LIFESTYLE"), (41, 51, "LIFESTYLE")]}),
    ("Though I use drugs, I never compromise on exercise.", {"entities": [(6, 16, "LIFESTYLE"), (35, 47, "LIFESTYLE")]}),
    ("I occasionally use drugs but exercise is my main focus.", {"entities": [(2, 16, "LIFESTYLE"), (35, 47, "LIFESTYLE")]}),
    ("Despite using drugs, I'm dedicated to maintaining my fitness.", {"entities": [(8, 18, "LIFESTYLE"), (33, 47, "LIFESTYLE")]}),
    ("I'm into drugs but I'm also committed to my workout routine.", {"entities": [(7, 12, "LIFESTYLE"), (29, 47, "LIFESTYLE")]}),
    ("I use drugs occasionally but exercise is my top priority.", {"entities": [(2, 12, "LIFESTYLE"), (33, 46, "LIFESTYLE")]}),
    ("Though I use drugs, exercise remains my main focus.", {"entities": [(6, 16, "LIFESTYLE"), (33, 49, "LIFESTYLE")]}),
    ("I'm a recreational drug user but I prioritize exercise.", {"entities": [(7, 23, "LIFESTYLE"), (40, 49, "LIFESTYLE")]}),
    ("I occasionally use drugs but I'm committed to my fitness.", {"entities": [(2, 16, "LIFESTYLE"), (35, 48, "LIFESTYLE")]}),
    ("Despite being a drug user, I'm dedicated to exercise.", {"entities": [(16, 26, "LIFESTYLE"), (30, 40, "LIFESTYLE")]}),
    ("I'm a drug user but I ensure to balance it with exercise.", {"entities": [(7, 17, "LIFESTYLE"), (38, 46, "LIFESTYLE")]}),
    ("I use drugs occasionally but exercise is my top priority.", {"entities": [(2, 12, "LIFESTYLE"), (33, 46, "LIFESTYLE")]}),
    ("Though I use drugs, I'm dedicated to my exercise regimen.", {"entities": [(6, 16, "LIFESTYLE"), (29, 45, "LIFESTYLE")]}),
    ("I occasionally use drugs but I make exercise a daily habit.", {"entities": [(2, 16, "LIFESTYLE"), (36, 48, "LIFESTYLE")]}),
    ("Despite being a drug user, I'm committed to exercise.", {"entities": [(16, 26, "LIFESTYLE"), (30, 40, "LIFESTYLE")]}),
    ("I'm a drug user but I prioritize exercise above all.", {"entities": [(7, 17, "LIFESTYLE"), (29, 55, "LIFESTYLE")]}),
    ("I use drugs but I ensure to incorporate exercise into my routine.", {"entities": [(2, 12, "LIFESTYLE"), (41, 51, "LIFESTYLE")]}),
    ("Though I use drugs, I never compromise on exercise.", {"entities": [(6, 16, "LIFESTYLE"), (35, 47, "LIFESTYLE")]}),
    ("I occasionally use drugs but exercise is my main focus.", {"entities": [(2, 16, "LIFESTYLE"), (35, 47, "LIFESTYLE")]}),
    ("Despite using drugs, I'm dedicated to maintaining my fitness.", {"entities": [(8, 18, "LIFESTYLE"), (33, 47, "LIFESTYLE")]}),
    ("I'm into drugs but I'm also committed to my workout routine.", {"entities": [(7, 12, "LIFESTYLE"), (29, 47, "LIFESTYLE")]}),
    ("I use drugs occasionally but exercise is my top priority.", {"entities": [(2, 12, "LIFESTYLE"), (33, 46, "LIFESTYLE")]}),
    ("Though I use drugs, exercise remains my main focus.", {"entities": [(6, 16, "LIFESTYLE"), (33, 49, "LIFESTYLE")]}),
    ("I'm a recreational drug user but I prioritize exercise.", {"entities": [(7, 23, "LIFESTYLE"), (40, 49, "LIFESTYLE")]}),
    ("I occasionally use drugs but I'm committed to my fitness.", {"entities": [(2, 16, "LIFESTYLE"), (35, 48, "LIFESTYLE")]}),
    ("Despite being a drug user, I'm dedicated to exercise.", {"entities": [(16, 26, "LIFESTYLE"), (30, 40, "LIFESTYLE")]}),
    ("I'm a drug user but I ensure to balance it with exercise.", {"entities": [(7, 17, "LIFESTYLE"), (38, 46, "LIFESTYLE")]}),
    ("I use drugs occasionally but exercise is my top priority.", {"entities": [(2, 12, "LIFESTYLE"), (33, 46, "LIFESTYLE")]}),
    ("Though I use drugs, I'm dedicated to my exercise regimen.", {"entities": [(6, 16, "LIFESTYLE"), (29, 45, "LIFESTYLE")]}),
    ("I occasionally use drugs but I make exercise a daily habit.", {"entities": [(2, 16, "LIFESTYLE"), (36, 48, "LIFESTYLE")]}),
    ("Despite being a drug user, I'm committed to exercise.", {"entities": [(16, 26, "LIFESTYLE"), (30, 40, "LIFESTYLE")]}),
    ("I'm a drug user but I prioritize exercise above all.", {"entities": [(7, 17, "LIFESTYLE"), (29, 55, "LIFESTYLE")]}),
    ("I use drugs but I ensure to incorporate exercise into my routine.", {"entities": [(2, 12, "LIFESTYLE"), (41, 51, "LIFESTYLE")]}),
    ("Though I use drugs, I never compromise on exercise.", {"entities": [(6, 16, "LIFESTYLE"), (35, 47, "LIFESTYLE")]}),
    ("I occasionally use drugs but exercise is my main focus.", {"entities": [(2, 16, "LIFESTYLE"), (35, 47, "LIFESTYLE")]}),
    ("Despite using drugs, I'm dedicated to maintaining my fitness.", {"entities": [(8, 18, "LIFESTYLE"), (33, 47, "LIFESTYLE")]}),
    ("I'm into drugs but I'm also committed to my workout routine.", {"entities": [(7, 12, "LIFESTYLE"), (29, 47, "LIFESTYLE")]}),
    ("I use drugs occasionally but exercise is my top priority.", {"entities": [(2, 12, "LIFESTYLE"), (33, 46, "LIFESTYLE")]}),
    ("Though I use drugs, exercise remains my main focus.", {"entities": [(6, 16, "LIFESTYLE"), (33, 49, "LIFESTYLE")]}),
    ("I'm a recreational drug user but I prioritize exercise.", {"entities": [(7, 23, "LIFESTYLE"), (40, 49, "LIFESTYLE")]}),
    ("I occasionally use drugs but I'm committed to my fitness.", {"entities": [(2, 16, "LIFESTYLE"), (35, 48, "LIFESTYLE")]}),
    ("Despite being a drug user, I'm dedicated to exercise.", {"entities": [(16, 26, "LIFESTYLE"), (30, 40, "LIFESTYLE")]}),
    ("I'm a drug user but I ensure to balance it with exercise.", {"entities": [(7, 17, "LIFESTYLE"), (38, 46, "LIFESTYLE")]}),
    ("I use drugs occasionally but exercise is my top priority.", {"entities": [(2, 12, "LIFESTYLE"), (33, 46, "LIFESTYLE")]}),
    ("Though I use drugs, I'm dedicated to my exercise regimen.", {"entities": [(6, 16, "LIFESTYLE"), (29, 45, "LIFESTYLE")]}),
    ("I occasionally use drugs but I make exercise a daily habit.", {"entities": [(2, 16, "LIFESTYLE"), (36, 48, "LIFESTYLE")]}),
    ("Despite being a drug user, I'm committed to exercise.", {"entities": [(16, 26, "LIFESTYLE"), (30, 40, "LIFESTYLE")]}),
    ("I'm a drug user but I prioritize exercise above all.", {"entities": [(7, 17, "LIFESTYLE"), (29, 55, "LIFESTYLE")]}),
    ("I use drugs but I ensure to incorporate exercise into my routine.", {"entities": [(2, 12, "LIFESTYLE"), (41, 51, "LIFESTYLE")]}),
    ("Though I use drugs, I never compromise on exercise.", {"entities": [(6, 16, "LIFESTYLE"), (35, 47, "LIFESTYLE")]}),
    ("I occasionally use drugs but exercise is my main focus.", {"entities": [(2, 16, "LIFESTYLE"), (35, 47, "LIFESTYLE")]}),
    ("Despite using drugs, I'm dedicated to maintaining my fitness.", {"entities": [(8, 18, "LIFESTYLE"), (33, 47, "LIFESTYLE")]}),
    ("I'm into drugs but I'm also committed to my workout routine.", {"entities": [(7, 12, "LIFESTYLE"), (29, 47, "LIFESTYLE")]}),
    ("I use drugs occasionally but exercise is my top priority.", {"entities": [(2, 12, "LIFESTYLE"), (33, 46, "LIFESTYLE")]}),
    ("Though I use drugs, exercise remains my main focus.", {"entities": [(6, 16, "LIFESTYLE"), (33, 49, "LIFESTYLE")]}),
    ("I'm a recreational drug user but I prioritize exercise.", {"entities": [(7, 23, "LIFESTYLE"), (40, 49, "LIFESTYLE")]}),
    ("I occasionally use drugs but I'm committed to my fitness.", {"entities": [(2, 16, "LIFESTYLE"), (35, 48, "LIFESTYLE")]}),
    ("Despite being a drug user, I'm dedicated to exercise.", {"entities": [(16, 26, "LIFESTYLE"), (30, 40, "LIFESTYLE")]}),
    ("I'm a drug user but I ensure to balance it with exercise.", {"entities": [(7, 17, "LIFESTYLE"), (38, 46, "LIFESTYLE")]}),
    ("I use drugs occasionally but exercise is my top priority.", {"entities": [(2, 12, "LIFESTYLE"), (33, 46, "LIFESTYLE")]}),
    ("Though I use drugs, I'm dedicated to my exercise regimen.", {"entities": [(6, 16, "LIFESTYLE"), (29, 45, "LIFESTYLE")]}),
    ("I occasionally use drugs but I make exercise a daily habit.", {"entities": [(2, 16, "LIFESTYLE"), (36, 48, "LIFESTYLE")]}),
    ("Despite being a drug user, I'm committed to exercise.", {"entities": [(16, 26, "LIFESTYLE"), (30, 40, "LIFESTYLE")]}),
    ("I'm a drug user but I prioritize exercise above all.", {"entities": [(7, 17, "LIFESTYLE"), (29, 55, "LIFESTYLE")]}),
    ("I use drugs but I ensure to incorporate exercise into my routine.", {"entities": [(2, 12, "LIFESTYLE"), (41, 51, "LIFESTYLE")]}),
    ("Though I use drugs, I never compromise on exercise.", {"entities": [(6, 16, "LIFESTYLE"), (35, 47, "LIFESTYLE")]}),
    ("I occasionally use drugs but exercise is my main focus.", {"entities": [(2, 16, "LIFESTYLE"), (35, 47, "LIFESTYLE")]}),
    ("Despite using drugs, I'm dedicated to maintaining my fitness.", {"entities": [(8, 18, "LIFESTYLE"), (33, 47, "LIFESTYLE")]}),
    ("I'm into drugs but I'm also committed to my workout routine.", {"entities": [(7, 12, "LIFESTYLE"), (29, 47, "LIFESTYLE")]}),
    ("I use drugs occasionally but exercise is my top priority.", {"entities": [(2, 12, "LIFESTYLE"), (33, 46, "LIFESTYLE")]}),
    ("Though I use drugs, exercise remains my main focus.", {"entities": [(6, 16, "LIFESTYLE"), (33, 49, "LIFESTYLE")]}),
    ("I'm a recreational drug user but I prioritize exercise.", {"entities": [(7, 23, "LIFESTYLE"), (40, 49, "LIFESTYLE")]}),
    ("I occasionally use drugs but I'm committed to my fitness.", {"entities": [(2, 16, "LIFESTYLE"), (35, 48, "LIFESTYLE")]}),
    ("Despite being a drug user, I'm dedicated to exercise.", {"entities": [(16, 26, "LIFESTYLE"), (30, 40, "LIFESTYLE")]}),
    ("I'm a drug user but I ensure to balance it with exercise.", {"entities": [(7, 17, "LIFESTYLE"), (38, 46, "LIFESTYLE")]}),
    ("I use drugs occasionally but exercise is my top priority.", {"entities": [(2, 12, "LIFESTYLE"), (33, 46, "LIFESTYLE")]}),
    ("Though I use drugs, I'm dedicated to my exercise regimen.", {"entities": [(6, 16, "LIFESTYLE"), (29, 45, "LIFESTYLE")]}),
    ("I occasionally use drugs but I make exercise a daily habit.", {"entities": [(2, 16, "LIFESTYLE"), (36, 48, "LIFESTYLE")]}),
    ("Despite being a drug user, I'm committed to exercise.", {"entities": [(16, 26, "LIFESTYLE"), (30, 40, "LIFESTYLE")]}),
    ("I'm a drug user but I prioritize exercise above all.", {"entities": [(7, 17, "LIFESTYLE"), (29, 55, "LIFESTYLE")]}),
    ("I use drugs but I ensure to incorporate exercise into my routine.", {"entities": [(2, 12, "LIFESTYLE"), (41, 51, "LIFESTYLE")]}),
    ("Though I use drugs, I never compromise on exercise.", {"entities": [(6, 16, "LIFESTYLE"), (35, 47, "LIFESTYLE")]}),
    ("I occasionally use drugs but exercise is my main focus.", {"entities": [(2, 16, "LIFESTYLE"), (35, 47, "LIFESTYLE")]}),
    ("Despite using drugs, I'm dedicated to maintaining my fitness.", {"entities": [(8, 18, "LIFESTYLE"), (33, 47, "LIFESTYLE")]}),
    ("I'm into drugs but I'm also committed to my workout routine.", {"entities": [(7, 12, "LIFESTYLE"), (29, 47, "LIFESTYLE")]}),
    ("I use drugs occasionally but exercise is my top priority.", {"entities": [(2, 12, "LIFESTYLE"), (33, 46, "LIFESTYLE")]}),
    ("Though I use drugs, exercise remains my main focus.", {"entities": [(6, 16, "LIFESTYLE"), (33, 49, "LIFESTYLE")]}),
    ("I'm a recreational drug user but I prioritize exercise.", {"entities": [(7, 23, "LIFESTYLE"), (40, 49, "LIFESTYLE")]}),
    ("I occasionally use drugs but I'm committed to my fitness.", {"entities": [(2, 16, "LIFESTYLE"), (35, 48, "LIFESTYLE")]}),
    ("Despite being a drug user, I'm dedicated to exercise.", {"entities": [(16, 26, "LIFESTYLE"), (30, 40, "LIFESTYLE")]}),
    ("I'm a drug user but I ensure to balance it with exercise.", {"entities": [(7, 17, "LIFESTYLE"), (38, 46, "LIFESTYLE")]}),
    ("I use drugs occasionally but exercise is my top priority.", {"entities": [(2, 12, "LIFESTYLE"), (33, 46, "LIFESTYLE")]}),
    ("Though I use drugs, I'm dedicated to my exercise regimen.", {"entities": [(6, 16, "LIFESTYLE"), (29, 45, "LIFESTYLE")]}),
    ("I occasionally use drugs but I make exercise a daily habit.", {"entities": [(2, 16, "LIFESTYLE"), (36, 48, "LIFESTYLE")]}),
    ("Despite being a drug user, I'm committed to exercise.", {"entities": [(16, 26, "LIFESTYLE"), (30, 40, "LIFESTYLE")]}),
    ("I smoke but I follow a vegan diet.", {"entities": [(2, 7, "LIFESTYLE"), (26, 36, "LIFESTYLE")]}),
    ("Though I smoke, I'm committed to a halal diet.", {"entities": [(6, 11, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I'm a smoker but I adhere to a vegetarian diet.", {"entities": [(7, 13, "LIFESTYLE"), (30, 41, "LIFESTYLE")]}),
    ("I smoke occasionally but I'm dedicated to a kosher diet.", {"entities": [(2, 7, "LIFESTYLE"), (33, 44, "LIFESTYLE")]}),
    ("Despite smoking, I maintain a vegan lifestyle.", {"entities": [(9, 16, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I'm a smoker but I prioritize a halal diet.", {"entities": [(7, 13, "LIFESTYLE"), (31, 41, "LIFESTYLE")]}),
    ("I occasionally smoke but I stick to a vegetarian diet.", {"entities": [(2, 12, "LIFESTYLE"), (29, 40, "LIFESTYLE")]}),
    ("Though I smoke, I'm committed to a kosher lifestyle.", {"entities": [(6, 11, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I smoke but I follow a vegan diet.", {"entities": [(2, 7, "LIFESTYLE"), (26, 36, "LIFESTYLE")]}),
    ("Though I smoke, I'm committed to a halal diet.", {"entities": [(6, 11, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I'm a smoker but I adhere to a vegetarian diet.", {"entities": [(7, 13, "LIFESTYLE"), (30, 41, "LIFESTYLE")]}),
    ("I smoke occasionally but I'm dedicated to a kosher diet.", {"entities": [(2, 7, "LIFESTYLE"), (33, 44, "LIFESTYLE")]}),
    ("Despite smoking, I maintain a vegan lifestyle.", {"entities": [(9, 16, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I'm a smoker but I prioritize a halal diet.", {"entities": [(7, 13, "LIFESTYLE"), (31, 41, "LIFESTYLE")]}),
    ("I occasionally smoke but I stick to a vegetarian diet.", {"entities": [(2, 12, "LIFESTYLE"), (29, 40, "LIFESTYLE")]}),
    ("Though I smoke, I'm committed to a kosher lifestyle.", {"entities": [(6, 11, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I smoke but I follow a vegan diet.", {"entities": [(2, 7, "LIFESTYLE"), (26, 36, "LIFESTYLE")]}),
    ("Though I smoke, I'm committed to a halal diet.", {"entities": [(6, 11, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I'm a smoker but I adhere to a vegetarian diet.", {"entities": [(7, 13, "LIFESTYLE"), (30, 41, "LIFESTYLE")]}),
    ("I smoke occasionally but I'm dedicated to a kosher diet.", {"entities": [(2, 7, "LIFESTYLE"), (33, 44, "LIFESTYLE")]}),
    ("Despite smoking, I maintain a vegan lifestyle.", {"entities": [(9, 16, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I'm a smoker but I prioritize a halal diet.", {"entities": [(7, 13, "LIFESTYLE"), (31, 41, "LIFESTYLE")]}),
    ("I occasionally smoke but I stick to a vegetarian diet.", {"entities": [(2, 12, "LIFESTYLE"), (29, 40, "LIFESTYLE")]}),
    ("Though I smoke, I'm committed to a kosher lifestyle.", {"entities": [(6, 11, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I smoke but I follow a vegan diet.", {"entities": [(2, 7, "LIFESTYLE"), (26, 36, "LIFESTYLE")]}),
    ("Though I smoke, I'm committed to a halal diet.", {"entities": [(6, 11, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I'm a smoker but I adhere to a vegetarian diet.", {"entities": [(7, 13, "LIFESTYLE"), (30, 41, "LIFESTYLE")]}),
    ("I smoke occasionally but I'm dedicated to a kosher diet.", {"entities": [(2, 7, "LIFESTYLE"), (33, 44, "LIFESTYLE")]}),
    ("Despite smoking, I maintain a vegan lifestyle.", {"entities": [(9, 16, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I'm a smoker but I prioritize a halal diet.", {"entities": [(7, 13, "LIFESTYLE"), (31, 41, "LIFESTYLE")]}),
    ("I occasionally smoke but I stick to a vegetarian diet.", {"entities": [(2, 12, "LIFESTYLE"), (29, 40, "LIFESTYLE")]}),
    ("Though I smoke, I'm committed to a kosher lifestyle.", {"entities": [(6, 11, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I smoke but I follow a vegan diet.", {"entities": [(2, 7, "LIFESTYLE"), (26, 36, "LIFESTYLE")]}),
    ("Though I smoke, I'm committed to a halal diet.", {"entities": [(6, 11, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I'm a smoker but I adhere to a vegetarian diet.", {"entities": [(7, 13, "LIFESTYLE"), (30, 41, "LIFESTYLE")]}),
    ("I smoke occasionally but I'm dedicated to a kosher diet.", {"entities": [(2, 7, "LIFESTYLE"), (33, 44, "LIFESTYLE")]}),
    ("Despite smoking, I maintain a vegan lifestyle.", {"entities": [(9, 16, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I'm a smoker but I prioritize a halal diet.", {"entities": [(7, 13, "LIFESTYLE"), (31, 41, "LIFESTYLE")]}),
    ("I occasionally smoke but I stick to a vegetarian diet.", {"entities": [(2, 12, "LIFESTYLE"), (29, 40, "LIFESTYLE")]}),
    ("Though I smoke, I'm committed to a kosher lifestyle.", {"entities": [(6, 11, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I smoke but I follow a vegan diet.", {"entities": [(2, 7, "LIFESTYLE"), (26, 36, "LIFESTYLE")]}),
    ("Though I smoke, I'm committed to a halal diet.", {"entities": [(6, 11, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I'm a smoker but I adhere to a vegetarian diet.", {"entities": [(7, 13, "LIFESTYLE"), (30, 41, "LIFESTYLE")]}),
    ("I smoke occasionally but I'm dedicated to a kosher diet.", {"entities": [(2, 7, "LIFESTYLE"), (33, 44, "LIFESTYLE")]}),
    ("Despite smoking, I maintain a vegan lifestyle.", {"entities": [(9, 16, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I'm a smoker but I prioritize a halal diet.", {"entities": [(7, 13, "LIFESTYLE"), (31, 41, "LIFESTYLE")]}),
    ("I occasionally smoke but I stick to a vegetarian diet.", {"entities": [(2, 12, "LIFESTYLE"), (29, 40, "LIFESTYLE")]}),
    ("Though I smoke, I'm committed to a kosher lifestyle.", {"entities": [(6, 11, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I smoke but I follow a vegan diet.", {"entities": [(2, 7, "LIFESTYLE"), (26, 36, "LIFESTYLE")]}),
    ("Though I smoke, I'm committed to a halal diet.", {"entities": [(6, 11, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I'm a smoker but I adhere to a vegetarian diet.", {"entities": [(7, 13, "LIFESTYLE"), (30, 41, "LIFESTYLE")]}),
    ("I smoke occasionally but I'm dedicated to a kosher diet.", {"entities": [(2, 7, "LIFESTYLE"), (33, 44, "LIFESTYLE")]}),
    ("Despite smoking, I maintain a vegan lifestyle.", {"entities": [(9, 16, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I'm a smoker but I prioritize a halal diet.", {"entities": [(7, 13, "LIFESTYLE"), (31, 41, "LIFESTYLE")]}),
    ("I occasionally smoke but I stick to a vegetarian diet.", {"entities": [(2, 12, "LIFESTYLE"), (29, 40, "LIFESTYLE")]}),
    ("Though I smoke, I'm committed to a kosher lifestyle.", {"entities": [(6, 11, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I smoke but I follow a vegan diet.", {"entities": [(2, 7, "LIFESTYLE"), (26, 36, "LIFESTYLE")]}),
    ("Though I smoke, I'm committed to a halal diet.", {"entities": [(6, 11, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I'm a smoker but I adhere to a vegetarian diet.", {"entities": [(7, 13, "LIFESTYLE"), (30, 41, "LIFESTYLE")]}),
    ("I smoke occasionally but I'm dedicated to a kosher diet.", {"entities": [(2, 7, "LIFESTYLE"), (33, 44, "LIFESTYLE")]}),
    ("Despite smoking, I maintain a vegan lifestyle.", {"entities": [(9, 16, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I'm a smoker but I prioritize a halal diet.", {"entities": [(7, 13, "LIFESTYLE"), (31, 41, "LIFESTYLE")]}),
    ("I occasionally smoke but I stick to a vegetarian diet.", {"entities": [(2, 12, "LIFESTYLE"), (29, 40, "LIFESTYLE")]}),
    ("Though I smoke, I'm committed to a kosher lifestyle.", {"entities": [(6, 11, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I smoke but I follow a vegan diet.", {"entities": [(2, 7, "LIFESTYLE"), (26, 36, "LIFESTYLE")]}),
    ("Though I smoke, I'm committed to a halal diet.", {"entities": [(6, 11, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I'm a smoker but I adhere to a vegetarian diet.", {"entities": [(7, 13, "LIFESTYLE"), (30, 41, "LIFESTYLE")]}),
    ("I smoke occasionally but I'm dedicated to a kosher diet.", {"entities": [(2, 7, "LIFESTYLE"), (33, 44, "LIFESTYLE")]}),
    ("Despite smoking, I maintain a vegan lifestyle.", {"entities": [(9, 16, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I'm a smoker but I prioritize a halal diet.", {"entities": [(7, 13, "LIFESTYLE"), (31, 41, "LIFESTYLE")]}),
    ("I occasionally smoke but I stick to a vegetarian diet.", {"entities": [(2, 12, "LIFESTYLE"), (29, 40, "LIFESTYLE")]}),
    ("Though I smoke, I'm committed to a kosher lifestyle.", {"entities": [(6, 11, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I smoke but I follow a vegan diet.", {"entities": [(2, 7, "LIFESTYLE"), (26, 36, "LIFESTYLE")]}),
    ("Though I smoke, I'm committed to a halal diet.", {"entities": [(6, 11, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I'm a smoker but I adhere to a vegetarian diet.", {"entities": [(7, 13, "LIFESTYLE"), (30, 41, "LIFESTYLE")]}),
    ("I smoke occasionally but I'm dedicated to a kosher diet.", {"entities": [(2, 7, "LIFESTYLE"), (33, 44, "LIFESTYLE")]}),
    ("Despite smoking, I maintain a vegan lifestyle.", {"entities": [(9, 16, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I'm a smoker but I prioritize a halal diet.", {"entities": [(7, 13, "LIFESTYLE"), (31, 41, "LIFESTYLE")]}),
    ("I occasionally smoke but I stick to a vegetarian diet.", {"entities": [(2, 12, "LIFESTYLE"), (29, 40, "LIFESTYLE")]}),
    ("Though I smoke, I'm committed to a kosher lifestyle.", {"entities": [(6, 11, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I smoke but I follow a vegan diet.", {"entities": [(2, 7, "LIFESTYLE"), (26, 36, "LIFESTYLE")]}),
    ("Though I smoke, I'm committed to a halal diet.", {"entities": [(6, 11, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I'm a smoker but I adhere to a vegetarian diet.", {"entities": [(7, 13, "LIFESTYLE"), (30, 41, "LIFESTYLE")]}),
    ("I smoke occasionally but I'm dedicated to a kosher diet.", {"entities": [(2, 7, "LIFESTYLE"), (33, 44, "LIFESTYLE")]}),
    ("Despite smoking, I maintain a vegan lifestyle.", {"entities": [(9, 16, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I'm a smoker but I prioritize a halal diet.", {"entities": [(7, 13, "LIFESTYLE"), (31, 41, "LIFESTYLE")]}),
    ("I occasionally smoke but I stick to a vegetarian diet.", {"entities": [(2, 12, "LIFESTYLE"), (29, 40, "LIFESTYLE")]}),
    ("Though I smoke, I'm committed to a kosher lifestyle.", {"entities": [(6, 11, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
("I smoke but I follow a vegan diet.", {"entities": [(2, 7, "LIFESTYLE"), (26, 36, "LIFESTYLE")]}),
    ("Though I smoke, I'm committed to a halal diet.", {"entities": [(6, 11, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I'm a smoker but I adhere to a vegetarian diet.", {"entities": [(7, 13, "LIFESTYLE"), (30, 41, "LIFESTYLE")]}),
    ("I smoke occasionally but I'm dedicated to a kosher diet.", {"entities": [(2, 7, "LIFESTYLE"), (33, 44, "LIFESTYLE")]}),
    ("Despite smoking, I maintain a vegan lifestyle.", {"entities": [(9, 16, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I'm a smoker but I prioritize a halal diet.", {"entities": [(7, 13, "LIFESTYLE"), (31, 41, "LIFESTYLE")]}),
    ("I occasionally smoke but I stick to a vegetarian diet.", {"entities": [(2, 12, "LIFESTYLE"), (29, 40, "LIFESTYLE")]}),
    ("Though I smoke, I'm committed to a kosher lifestyle.", {"entities": [(6, 11, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I smoke but I follow a vegan diet.", {"entities": [(2, 7, "LIFESTYLE"), (26, 36, "LIFESTYLE")]}),
    ("Though I smoke, I'm committed to a halal diet.", {"entities": [(6, 11, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I'm a smoker but I adhere to a vegetarian diet.", {"entities": [(7, 13, "LIFESTYLE"), (30, 41, "LIFESTYLE")]}),
    ("I smoke occasionally but I'm dedicated to a kosher diet.", {"entities": [(2, 7, "LIFESTYLE"), (33, 44, "LIFESTYLE")]}),
    ("Despite smoking, I maintain a vegan lifestyle.", {"entities": [(9, 16, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I'm a smoker but I prioritize a halal diet.", {"entities": [(7, 13, "LIFESTYLE"), (31, 41, "LIFESTYLE")]}),
    ("I occasionally smoke but I stick to a vegetarian diet.", {"entities": [(2, 12, "LIFESTYLE"), (29, 40, "LIFESTYLE")]}),
    ("Though I smoke, I'm committed to a kosher lifestyle.", {"entities": [(6, 11, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I smoke but I follow a vegan diet.", {"entities": [(2, 7, "LIFESTYLE"), (26, 36, "LIFESTYLE")]}),
    ("Though I smoke, I'm committed to a halal diet.", {"entities": [(6, 11, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I'm a smoker but I adhere to a vegetarian diet.", {"entities": [(7, 13, "LIFESTYLE"), (30, 41, "LIFESTYLE")]}),
    ("I smoke occasionally but I'm dedicated to a kosher diet.", {"entities": [(2, 7, "LIFESTYLE"), (33, 44, "LIFESTYLE")]}),
    ("Despite smoking, I maintain a vegan lifestyle.", {"entities": [(9, 16, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I'm a smoker but I prioritize a halal diet.", {"entities": [(7, 13, "LIFESTYLE"), (31, 41, "LIFESTYLE")]}),
    ("I occasionally smoke but I stick to a vegetarian diet.", {"entities": [(2, 12, "LIFESTYLE"), (29, 40, "LIFESTYLE")]}),
    ("Though I smoke, I'm committed to a kosher lifestyle.", {"entities": [(6, 11, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I smoke but I follow a vegan diet.", {"entities": [(2, 7, "LIFESTYLE"), (26, 36, "LIFESTYLE")]}),
    ("Though I smoke, I'm committed to a halal diet.", {"entities": [(6, 11, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I'm a smoker but I adhere to a vegetarian diet.", {"entities": [(7, 13, "LIFESTYLE"), (30, 41, "LIFESTYLE")]}),
    ("I smoke occasionally but I'm dedicated to a kosher diet.", {"entities": [(2, 7, "LIFESTYLE"), (33, 44, "LIFESTYLE")]}),
    ("Despite smoking, I maintain a vegan lifestyle.", {"entities": [(9, 16, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I'm a smoker but I prioritize a halal diet.", {"entities": [(7, 13, "LIFESTYLE"), (31, 41, "LIFESTYLE")]}),
    ("I occasionally smoke but I stick to a vegetarian diet.", {"entities": [(2, 12, "LIFESTYLE"), (29, 40, "LIFESTYLE")]}),
    ("Though I smoke, I'm committed to a kosher lifestyle.", {"entities": [(6, 11, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I smoke but I follow a vegan diet.", {"entities": [(2, 7, "LIFESTYLE"), (26, 36, "LIFESTYLE")]}),
    ("Though I smoke, I'm committed to a halal diet.", {"entities": [(6, 11, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I'm a smoker but I adhere to a vegetarian diet.", {"entities": [(7, 13, "LIFESTYLE"), (30, 41, "LIFESTYLE")]}),
    ("I smoke occasionally but I'm dedicated to a kosher diet.", {"entities": [(2, 7, "LIFESTYLE"), (33, 44, "LIFESTYLE")]}),
    ("Despite smoking, I maintain a vegan lifestyle.", {"entities": [(9, 16, "LIFESTYLE"), (28, 38, "LIFESTYLE")]}),
    ("I smoke but I exercise regularly.", {"entities": [(2, 7, "LIFESTYLE"), (20, 31, "LIFESTYLE")]}),
    ("Though I smoke, I prioritize exercise.", {"entities": [(6, 11, "LIFESTYLE"), (21, 29, "LIFESTYLE")]}),
    ("I'm a smoker but I enjoy exercising.", {"entities": [(7, 13, "LIFESTYLE"), (18, 29, "LIFESTYLE")]}),
    ("I smoke occasionally but I make time for exercise.", {"entities": [(2, 7, "LIFESTYLE"), (28, 37, "LIFESTYLE")]}),
    ("Despite smoking, I maintain my exercise routine.", {"entities": [(9, 16, "LIFESTYLE"), (24, 34, "LIFESTYLE")]}),
    ("I'm a smoker but I'm dedicated to exercise.", {"entities": [(7, 13, "LIFESTYLE"), (20, 29, "LIFESTYLE")]}),
    ("I occasionally smoke but I never skip exercise.", {"entities": [(2, 12, "LIFESTYLE"), (28, 36, "LIFESTYLE")]}),
    ("Though I smoke, I prioritize staying active.", {"entities": [(6, 11, "LIFESTYLE"), (21, 32, "LIFESTYLE")]}),
    ("I smoke but I exercise regularly.", {"entities": [(2, 7, "LIFESTYLE"), (20, 31, "LIFESTYLE")]}),
    ("Though I smoke, I prioritize exercise.", {"entities": [(6, 11, "LIFESTYLE"), (21, 29, "LIFESTYLE")]}),
    ("I'm a smoker but I enjoy exercising.", {"entities": [(7, 13, "LIFESTYLE"), (18, 29, "LIFESTYLE")]}),
    ("I smoke occasionally but I make time for exercise.", {"entities": [(2, 7, "LIFESTYLE"), (28, 37, "LIFESTYLE")]}),
    ("Despite smoking, I maintain my exercise routine.", {"entities": [(9, 16, "LIFESTYLE"), (24, 34, "LIFESTYLE")]}),
    ("I'm a smoker but I'm dedicated to exercise.", {"entities": [(7, 13, "LIFESTYLE"), (20, 29, "LIFESTYLE")]}),
    ("I occasionally smoke but I never skip exercise.", {"entities": [(2, 12, "LIFESTYLE"), (28, 36, "LIFESTYLE")]}),
    ("Though I smoke, I prioritize staying active.", {"entities": [(6, 11, "LIFESTYLE"), (21, 32, "LIFESTYLE")]}),
    ("I smoke but I exercise regularly.", {"entities": [(2, 7, "LIFESTYLE"), (20, 31, "LIFESTYLE")]}),
    ("Though I smoke, I prioritize exercise.", {"entities": [(6, 11, "LIFESTYLE"), (21, 29, "LIFESTYLE")]}),
    ("I'm a smoker but I enjoy exercising.", {"entities": [(7, 13, "LIFESTYLE"), (18, 29, "LIFESTYLE")]}),
    ("I smoke occasionally but I make time for exercise.", {"entities": [(2, 7, "LIFESTYLE"), (28, 37, "LIFESTYLE")]}),
    ("Despite smoking, I maintain my exercise routine.", {"entities": [(9, 16, "LIFESTYLE"), (24, 34, "LIFESTYLE")]}),
    ("I'm a smoker but I'm dedicated to exercise.", {"entities": [(7, 13, "LIFESTYLE"), (20, 29, "LIFESTYLE")]}),
    ("I occasionally smoke but I never skip exercise.", {"entities": [(2, 12, "LIFESTYLE"), (28, 36, "LIFESTYLE")]}),
    ("Though I smoke, I prioritize staying active.", {"entities": [(6, 11, "LIFESTYLE"), (21, 32, "LIFESTYLE")]}),
    ("I smoke but I exercise regularly.", {"entities": [(2, 7, "LIFESTYLE"), (20, 31, "LIFESTYLE")]}),
    ("Though I smoke, I prioritize exercise.", {"entities": [(6, 11, "LIFESTYLE"), (21, 29, "LIFESTYLE")]}),
    ("I'm a smoker but I enjoy exercising.", {"entities": [(7, 13, "LIFESTYLE"), (18, 29, "LIFESTYLE")]}),
    ("I smoke occasionally but I make time for exercise.", {"entities": [(2, 7, "LIFESTYLE"), (28, 37, "LIFESTYLE")]}),
    ("Despite smoking, I maintain my exercise routine.", {"entities": [(9, 16, "LIFESTYLE"), (24, 34, "LIFESTYLE")]}),
    ("I'm a smoker but I'm dedicated to exercise.", {"entities": [(7, 13, "LIFESTYLE"), (20, 29, "LIFESTYLE")]}),
    ("I occasionally smoke but I never skip exercise.", {"entities": [(2, 12, "LIFESTYLE"), (28, 36, "LIFESTYLE")]}),
    ("Though I smoke, I prioritize staying active.", {"entities": [(6, 11, "LIFESTYLE"), (21, 32, "LIFESTYLE")]}),
    ("Despite my smoking habit, I prioritize exercise in my daily routine.", {"entities": [(19, 26, "LIFESTYLE"), (52, 60, "LIFESTYLE")]}),
    ("I enjoy drinking but I ensure to balance it with regular exercise.", {"entities": [(9, 16, "LIFESTYLE"), (53, 63, "LIFESTYLE")]}),
    ("Though I smoke, I make sure to incorporate exercise into my lifestyle.", {"entities": [(6, 11, "LIFESTYLE"), (51, 60, "LIFESTYLE")]}),
    ("Even with my smoking habit, I maintain a consistent exercise regimen.", {"entities": [(20, 27, "LIFESTYLE"), (52, 61, "LIFESTYLE")]}),
    ("I'm a smoker, but I never neglect my exercise routine.", {"entities": [(9, 15, "LIFESTYLE"), (37, 48, "LIFESTYLE")]}),
    ("Though I enjoy drinking, I prioritize exercise for my well-being.", {"entities": [(6, 16, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I occasionally smoke, but I'm dedicated to my fitness journey.", {"entities": [(12, 17, "LIFESTYLE"), (35, 49, "LIFESTYLE")]}),
    ("Despite my smoking habit, I'm committed to staying active.", {"entities": [(19, 26, "LIFESTYLE"), (48, 54, "LIFESTYLE")]}),
    ("I may smoke, but exercise is always a priority for me.", {"entities": [(6, 11, "LIFESTYLE"), (30, 38, "LIFESTYLE")]}),
    ("Though I indulge in drinking, I never skip my exercise routine.", {"entities": [(6, 14, "LIFESTYLE"), (42, 55, "LIFESTYLE")]}),
    ("Even with my smoking habit, I ensure to maintain my exercise routine.", {"entities": [(20, 27, "LIFESTYLE"), (54, 63, "LIFESTYLE")]}),
    ("I'm a smoker, but I make exercise an integral part of my life.", {"entities": [(9, 15, "LIFESTYLE"), (31, 40, "LIFESTYLE")]}),
    ("Though I enjoy drinking, I prioritize exercise for my well-being.", {"entities": [(6, 16, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I occasionally smoke, but I'm committed to my fitness journey.", {"entities": [(12, 17, "LIFESTYLE"), (35, 49, "LIFESTYLE")]}),
    ("Despite my smoking habit, I'm committed to staying active.", {"entities": [(19, 26, "LIFESTYLE"), (48, 54, "LIFESTYLE")]}),
    ("I may smoke, but exercise is always a priority for me.", {"entities": [(6, 11, "LIFESTYLE"), (30, 38, "LIFESTYLE")]}),
    ("Though I indulge in drinking, I never skip my exercise routine.", {"entities": [(6, 14, "LIFESTYLE"), (42, 55, "LIFESTYLE")]}),
    ("Even with my smoking habit, I ensure to maintain my exercise routine.", {"entities": [(20, 27, "LIFESTYLE"), (54, 63, "LIFESTYLE")]}),
    ("I'm a smoker, but I make exercise an integral part of my life.", {"entities": [(9, 15, "LIFESTYLE"), (31, 40, "LIFESTYLE")]}),
    ("Though I enjoy drinking, I prioritize exercise for my well-being.", {"entities": [(6, 16, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I occasionally smoke, but I'm committed to my fitness journey.", {"entities": [(12, 17, "LIFESTYLE"), (35, 49, "LIFESTYLE")]}),
    ("Despite my smoking habit, I'm committed to staying active.", {"entities": [(19, 26, "LIFESTYLE"), (48, 54, "LIFESTYLE")]}),
    ("I may smoke, but exercise is always a priority for me.", {"entities": [(6, 11, "LIFESTYLE"), (30, 38, "LIFESTYLE")]}),
    ("Though I indulge in drinking, I never skip my exercise routine.", {"entities": [(6, 14, "LIFESTYLE"), (42, 55, "LIFESTYLE")]}),
    ("Even with my smoking habit, I ensure to maintain my exercise routine.", {"entities": [(20, 27, "LIFESTYLE"), (54, 63, "LIFESTYLE")]}),
    ("I'm a smoker, but I make exercise an integral part of my life.", {"entities": [(9, 15, "LIFESTYLE"), (31, 40, "LIFESTYLE")]}),
    ("Though I enjoy drinking, I prioritize exercise for my well-being.", {"entities": [(6, 16, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I occasionally smoke, but I'm committed to my fitness journey.", {"entities": [(12, 17, "LIFESTYLE"), (35, 49, "LIFESTYLE")]}),
    ("Despite my smoking habit, I'm committed to staying active.", {"entities": [(19, 26, "LIFESTYLE"), (48, 54, "LIFESTYLE")]}),
    ("I may smoke, but exercise is always a priority for me.", {"entities": [(6, 11, "LIFESTYLE"), (30, 38, "LIFESTYLE")]}),
    ("Though I indulge in drinking, I never skip my exercise routine.", {"entities": [(6, 14, "LIFESTYLE"), (42, 55, "LIFESTYLE")]}),
    ("Even with my smoking habit, I ensure to maintain my exercise routine.", {"entities": [(20, 27, "LIFESTYLE"), (54, 63, "LIFESTYLE")]}),
    ("I'm a smoker, but I make exercise an integral part of my life.", {"entities": [(9, 15, "LIFESTYLE"), (31, 40, "LIFESTYLE")]}),
    ("Though I enjoy drinking, I prioritize exercise for my well-being.", {"entities": [(6, 16, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I occasionally smoke, but I'm committed to my fitness journey.", {"entities": [(12, 17, "LIFESTYLE"), (35, 49, "LIFESTYLE")]}),
    ("Despite my smoking habit, I'm committed to staying active.", {"entities": [(19, 26, "LIFESTYLE"), (48, 54, "LIFESTYLE")]}),
    ("I may smoke, but exercise is always a priority for me.", {"entities": [(6, 11, "LIFESTYLE"), (30, 38, "LIFESTYLE")]}),
    ("Though I indulge in drinking, I never skip my exercise routine.", {"entities": [(6, 14, "LIFESTYLE"), (42, 55, "LIFESTYLE")]}),
    ("Even with my smoking habit, I ensure to maintain my exercise routine.", {"entities": [(20, 27, "LIFESTYLE"), (54, 63, "LIFESTYLE")]}),
    ("I'm a smoker, but I make exercise an integral part of my life.", {"entities": [(9, 15, "LIFESTYLE"), (31, 40, "LIFESTYLE")]}),
    ("Though I enjoy drinking, I prioritize exercise for my well-being.", {"entities": [(6, 16, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I occasionally smoke, but I'm committed to my fitness journey.", {"entities": [(12, 17, "LIFESTYLE"), (35, 49, "LIFESTYLE")]}),
    ("Despite my smoking habit, I'm committed to staying active.", {"entities": [(19, 26, "LIFESTYLE"), (48, 54, "LIFESTYLE")]}),
    ("I may smoke, but exercise is always a priority for me.", {"entities": [(6, 11, "LIFESTYLE"), (30, 38, "LIFESTYLE")]}),
    ("Though I indulge in drinking, I never skip my exercise routine.", {"entities": [(6, 14, "LIFESTYLE"), (42, 55, "LIFESTYLE")]}),
    ("Even with my smoking habit, I ensure to maintain my exercise routine.", {"entities": [(20, 27, "LIFESTYLE"), (54, 63, "LIFESTYLE")]}),
    ("I'm a smoker, but I make exercise an integral part of my life.", {"entities": [(9, 15, "LIFESTYLE"), (31, 40, "LIFESTYLE")]}),
    ("Though I enjoy drinking, I prioritize exercise for my well-being.", {"entities": [(6, 16, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I occasionally smoke, but I'm committed to my fitness journey.", {"entities": [(12, 17, "LIFESTYLE"), (35, 49, "LIFESTYLE")]}),
    ("Despite my smoking habit, I'm committed to staying active.", {"entities": [(19, 26, "LIFESTYLE"), (48, 54, "LIFESTYLE")]}),
    ("I may smoke, but exercise is always a priority for me.", {"entities": [(6, 11, "LIFESTYLE"), (30, 38, "LIFESTYLE")]}),
    ("Though I indulge in drinking, I never skip my exercise routine.", {"entities": [(6, 14, "LIFESTYLE"), (42, 55, "LIFESTYLE")]}),
    ("Even with my smoking habit, I ensure to maintain my exercise routine.", {"entities": [(20, 27, "LIFESTYLE"), (54, 63, "LIFESTYLE")]}),
    ("I'm a smoker, but I make exercise an integral part of my life.", {"entities": [(9, 15, "LIFESTYLE"), (31, 40, "LIFESTYLE")]}),
    ("Though I enjoy drinking, I prioritize exercise for my well-being.", {"entities": [(6, 16, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I occasionally smoke, but I'm committed to my fitness journey.", {"entities": [(12, 17, "LIFESTYLE"), (35, 49, "LIFESTYLE")]}),
    ("Despite my smoking habit, I'm committed to staying active.", {"entities": [(19, 26, "LIFESTYLE"), (48, 54, "LIFESTYLE")]}),
    ("I may smoke, but exercise is always a priority for me.", {"entities": [(6, 11, "LIFESTYLE"), (30, 38, "LIFESTYLE")]}),
    ("Though I indulge in drinking, I never skip my exercise routine.", {"entities": [(6, 14, "LIFESTYLE"), (42, 55, "LIFESTYLE")]}),
    ("Even with my smoking habit, I ensure to maintain my exercise routine.", {"entities": [(20, 27, "LIFESTYLE"), (54, 63, "LIFESTYLE")]}),
    ("I'm a smoker, but I make exercise an integral part of my life.", {"entities": [(9, 15, "LIFESTYLE"), (31, 40, "LIFESTYLE")]}),
    ("Though I enjoy drinking, I prioritize exercise for my well-being.", {"entities": [(6, 16, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I occasionally smoke, but I'm committed to my fitness journey.", {"entities": [(12, 17, "LIFESTYLE"), (35, 49, "LIFESTYLE")]}),
    ("Despite my smoking habit, I'm committed to staying active.", {"entities": [(19, 26, "LIFESTYLE"), (48, 54, "LIFESTYLE")]}),
    ("I may smoke, but exercise is always a priority for me.", {"entities": [(6, 11, "LIFESTYLE"), (30, 38, "LIFESTYLE")]}),
    ("Though I indulge in drinking, I never skip my exercise routine.", {"entities": [(6, 14, "LIFESTYLE"), (42, 55, "LIFESTYLE")]}),
    ("Even with my smoking habit, I ensure to maintain my exercise routine.", {"entities": [(20, 27, "LIFESTYLE"), (54, 63, "LIFESTYLE")]}),
    ("I'm a smoker, but I make exercise an integral part of my life.", {"entities": [(9, 15, "LIFESTYLE"), (31, 40, "LIFESTYLE")]}),
    ("Though I enjoy drinking, I prioritize exercise for my well-being.", {"entities": [(6, 16, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I occasionally smoke, but I'm committed to my fitness journey.", {"entities": [(12, 17, "LIFESTYLE"), (35, 49, "LIFESTYLE")]}),
    ("Despite my smoking habit, I'm committed to staying active.", {"entities": [(19, 26, "LIFESTYLE"), (48, 54, "LIFESTYLE")]}),
    ("I may smoke, but exercise is always a priority for me.", {"entities": [(6, 11, "LIFESTYLE"), (30, 38, "LIFESTYLE")]}),
    ("Though I indulge in drinking, I never skip my exercise routine.", {"entities": [(6, 14, "LIFESTYLE"), (42, 55, "LIFESTYLE")]}),
    ("Even with my smoking habit, I ensure to maintain my exercise routine.", {"entities": [(20, 27, "LIFESTYLE"), (54, 63, "LIFESTYLE")]}),
    ("I'm a smoker, but I make exercise an integral part of my life.", {"entities": [(9, 15, "LIFESTYLE"), (31, 40, "LIFESTYLE")]}),
    ("Though I enjoy drinking, I prioritize exercise for my well-being.", {"entities": [(6, 16, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I occasionally smoke, but I'm committed to my fitness journey.", {"entities": [(12, 17, "LIFESTYLE"), (35, 49, "LIFESTYLE")]}),
    ("Despite my smoking habit, I'm committed to staying active.", {"entities": [(19, 26, "LIFESTYLE"), (48, 54, "LIFESTYLE")]}),
    ("I may smoke, but exercise is always a priority for me.", {"entities": [(6, 11, "LIFESTYLE"), (30, 38, "LIFESTYLE")]}),
    ("Though I indulge in drinking, I never skip my exercise routine.", {"entities": [(6, 14, "LIFESTYLE"), (42, 55, "LIFESTYLE")]}),
    ("Even with my smoking habit, I ensure to maintain my exercise routine.", {"entities": [(20, 27, "LIFESTYLE"), (54, 63, "LIFESTYLE")]}),
    ("I'm a smoker, but I make exercise an integral part of my life.", {"entities": [(9, 15, "LIFESTYLE"), (31, 40, "LIFESTYLE")]}),
    ("Though I enjoy drinking, I prioritize exercise for my well-being.", {"entities": [(6, 16, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I occasionally smoke, but I'm committed to my fitness journey.", {"entities": [(12, 17, "LIFESTYLE"), (35, 49, "LIFESTYLE")]}),
    ("Despite my smoking habit, I'm committed to staying active.", {"entities": [(19, 26, "LIFESTYLE"), (48, 54, "LIFESTYLE")]}),
    ("I may smoke, but exercise is always a priority for me.", {"entities": [(6, 11, "LIFESTYLE"), (30, 38, "LIFESTYLE")]}),
    ("Though I indulge in drinking, I never skip my exercise routine.", {"entities": [(6, 14, "LIFESTYLE"), (42, 55, "LIFESTYLE")]}),
    ("Even with my smoking habit, I ensure to maintain my exercise routine.", {"entities": [(20, 27, "LIFESTYLE"), (54, 63, "LIFESTYLE")]}),
    ("I'm a smoker, but I make exercise an integral part of my life.", {"entities": [(9, 15, "LIFESTYLE"), (31, 40, "LIFESTYLE")]}),
    ("Though I enjoy drinking, I prioritize exercise for my well-being.", {"entities": [(6, 16, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I occasionally smoke, but I'm committed to my fitness journey.", {"entities": [(12, 17, "LIFESTYLE"), (35, 49, "LIFESTYLE")]}),
    ("Despite my smoking habit, I'm committed to staying active.", {"entities": [(19, 26, "LIFESTYLE"), (48, 54, "LIFESTYLE")]}),
    ("I may smoke, but exercise is always a priority for me.", {"entities": [(6, 11, "LIFESTYLE"), (30, 38, "LIFESTYLE")]}),
    ("Though I indulge in drinking, I never skip my exercise routine.", {"entities": [(6, 14, "LIFESTYLE"), (42, 55, "LIFESTYLE")]}),
    ("Even with my smoking habit, I ensure to maintain my exercise routine.", {"entities": [(20, 27, "LIFESTYLE"), (54, 63, "LIFESTYLE")]}),
    ("I'm a smoker, but I make exercise an integral part of my life.", {"entities": [(9, 15, "LIFESTYLE"), (31, 40, "LIFESTYLE")]}),
    ("Though I enjoy drinking, I prioritize exercise for my well-being.", {"entities": [(6, 16, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I occasionally smoke, but I'm committed to my fitness journey.", {"entities": [(12, 17, "LIFESTYLE"), (35, 49, "LIFESTYLE")]}),
    ("Despite my smoking habit, I'm committed to staying active.", {"entities": [(19, 26, "LIFESTYLE"), (48, 54, "LIFESTYLE")]}),
    ("I may smoke, but exercise is always a priority for me.", {"entities": [(6, 11, "LIFESTYLE"), (30, 38, "LIFESTYLE")]}),
    ("Though I indulge in drinking, I never skip my exercise routine.", {"entities": [(6, 14, "LIFESTYLE"), (42, 55, "LIFESTYLE")]}),
    ("Even with my smoking habit, I ensure to maintain my exercise routine.", {"entities": [(20, 27, "LIFESTYLE"), (54, 63, "LIFESTYLE")]}),
    ("I'm a smoker, but I make exercise an integral part of my life.", {"entities": [(9, 15, "LIFESTYLE"), (31, 40, "LIFESTYLE")]}),
    ("Though I enjoy drinking, I prioritize exercise for my well-being.", {"entities": [(6, 16, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I occasionally smoke, but I'm committed to my fitness journey.", {"entities": [(12, 17, "LIFESTYLE"), (35, 49, "LIFESTYLE")]}),
    ("Despite my smoking habit, I'm committed to staying active.", {"entities": [(19, 26, "LIFESTYLE"), (48, 54, "LIFESTYLE")]}),
    ("I may smoke, but exercise is always a priority for me.", {"entities": [(6, 11, "LIFESTYLE"), (30, 38, "LIFESTYLE")]}),
    ("Though I indulge in drinking, I never skip my exercise routine.", {"entities": [(6, 14, "LIFESTYLE"), (42, 55, "LIFESTYLE")]}),
    ("Even with my smoking habit, I ensure to maintain my exercise routine.", {"entities": [(20, 27, "LIFESTYLE"), (54, 63, "LIFESTYLE")]}),
    ("I'm a smoker, but I make exercise an integral part of my life.", {"entities": [(9, 15, "LIFESTYLE"), (31, 40, "LIFESTYLE")]}),
    ("Though I enjoy drinking, I prioritize exercise for my well-being.", {"entities": [(6, 16, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I occasionally smoke, but I'm committed to my fitness journey.", {"entities": [(12, 17, "LIFESTYLE"), (35, 49, "LIFESTYLE")]}),
    ("Despite my smoking habit, I'm committed to staying active.", {"entities": [(19, 26, "LIFESTYLE"), (48, 54, "LIFESTYLE")]}),
    ("I may smoke, but exercise is always a priority for me.", {"entities": [(6, 11, "LIFESTYLE"), (30, 38, "LIFESTYLE")]}),
    ("Though I indulge in drinking, I never skip my exercise routine.", {"entities": [(6, 14, "LIFESTYLE"), (42, 55, "LIFESTYLE")]}),
    ("Even with my smoking habit, I ensure to maintain my exercise routine.", {"entities": [(20, 27, "LIFESTYLE"), (54, 63, "LIFESTYLE")]}),
    ("I'm a smoker, but I make exercise an integral part of my life.", {"entities": [(9, 15, "LIFESTYLE"), (31, 40, "LIFESTYLE")]}),
    ("Though I enjoy drinking, I prioritize exercise for my well-being.", {"entities": [(6, 16, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I occasionally smoke, but I'm committed to my fitness journey.", {"entities": [(12, 17, "LIFESTYLE"), (35, 49, "LIFESTYLE")]}),
    ("Despite my smoking habit, I'm committed to staying active.", {"entities": [(19, 26, "LIFESTYLE"), (48, 54, "LIFESTYLE")]}),
    ("I may smoke, but exercise is always a priority for me.", {"entities": [(6, 11, "LIFESTYLE"), (30, 38, "LIFESTYLE")]}),
    ("Though I indulge in drinking, I never skip my exercise routine.", {"entities": [(6, 14, "LIFESTYLE"), (42, 55, "LIFESTYLE")]}),
    ("Even with my smoking habit, I ensure to maintain my exercise routine.", {"entities": [(20, 27, "LIFESTYLE"), (54, 63, "LIFESTYLE")]}),
    ("I'm a smoker, but I make exercise an integral part of my life.", {"entities": [(9, 15, "LIFESTYLE"), (31, 40, "LIFESTYLE")]}),
    ("Though I enjoy drinking, I prioritize exercise for my well-being.", {"entities": [(6, 16, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I occasionally smoke, but I'm committed to my fitness journey.", {"entities": [(12, 17, "LIFESTYLE"), (35, 49, "LIFESTYLE")]}),
    ("Despite my smoking habit, I'm committed to staying active.", {"entities": [(19, 26, "LIFESTYLE"), (48, 54, "LIFESTYLE")]}),
    ("I may smoke, but exercise is always a priority for me.", {"entities": [(6, 11, "LIFESTYLE"), (30, 38, "LIFESTYLE")]}),
    ("Though I indulge in drinking, I never skip my exercise routine.", {"entities": [(6, 14, "LIFESTYLE"), (42, 55, "LIFESTYLE")]}),
    ("Even with my smoking habit, I ensure to maintain my exercise routine.", {"entities": [(20, 27, "LIFESTYLE"), (54, 63, "LIFESTYLE")]}),
    ("I'm a smoker, but I make exercise an integral part of my life.", {"entities": [(9, 15, "LIFESTYLE"), (31, 40, "LIFESTYLE")]}),
    ("Though I enjoy drinking, I prioritize exercise for my well-being.", {"entities": [(6, 16, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I occasionally smoke, but I'm committed to my fitness journey.", {"entities": [(12, 17, "LIFESTYLE"), (35, 49, "LIFESTYLE")]}),
    ("Despite my smoking habit, I'm committed to staying active.", {"entities": [(19, 26, "LIFESTYLE"), (48, 54, "LIFESTYLE")]}),
    ("I may smoke, but exercise is always a priority for me.", {"entities": [(6, 11, "LIFESTYLE"), (30, 38, "LIFESTYLE")]}),
    ("Though I indulge in drinking, I never skip my exercise routine.", {"entities": [(6, 14, "LIFESTYLE"), (42, 55, "LIFESTYLE")]}),
    ("Even with my smoking habit, I ensure to maintain my exercise routine.", {"entities": [(20, 27, "LIFESTYLE"), (54, 63, "LIFESTYLE")]}),
    ("I'm a smoker, but I make exercise an integral part of my life.", {"entities": [(9, 15, "LIFESTYLE"), (31, 40, "LIFESTYLE")]}),
    ("Though I enjoy drinking, I prioritize exercise for my well-being.", {"entities": [(6, 16, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I occasionally smoke, but I'm committed to my fitness journey.", {"entities": [(12, 17, "LIFESTYLE"), (35, 49, "LIFESTYLE")]}),
    ("Despite my smoking habit, I'm committed to staying active.", {"entities": [(19, 26, "LIFESTYLE"), (48, 54, "LIFESTYLE")]}),
    ("I may smoke, but exercise is always a priority for me.", {"entities": [(6, 11, "LIFESTYLE"), (30, 38, "LIFESTYLE")]}),
    ("Though I indulge in drinking, I never skip my exercise routine.", {"entities": [(6, 14, "LIFESTYLE"), (42, 55, "LIFESTYLE")]}),
    ("Even with my smoking habit, I ensure to maintain my exercise routine.", {"entities": [(20, 27, "LIFESTYLE"), (54, 63, "LIFESTYLE")]}),
    ("I'm a smoker, but I make exercise an integral part of my life.", {"entities": [(9, 15, "LIFESTYLE"), (31, 40, "LIFESTYLE")]}),
    ("Though I enjoy drinking, I prioritize exercise for my well-being.", {"entities": [(6, 16, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I occasionally smoke, but I'm committed to my fitness journey.", {"entities": [(12, 17, "LIFESTYLE"), (35, 49, "LIFESTYLE")]}),
    ("Despite my smoking habit, I'm committed to staying active.", {"entities": [(19, 26, "LIFESTYLE"), (48, 54, "LIFESTYLE")]}),
    ("I may smoke, but exercise is always a priority for me.", {"entities": [(6, 11, "LIFESTYLE"), (30, 38, "LIFESTYLE")]}),
    ("Though I indulge in drinking, I never skip my exercise routine.", {"entities": [(6, 14, "LIFESTYLE"), (42, 55, "LIFESTYLE")]}),
    ("Even with my smoking habit, I ensure to maintain my exercise routine.", {"entities": [(20, 27, "LIFESTYLE"), (54, 63, "LIFESTYLE")]}),
    ("I'm a smoker, but I make exercise an integral part of my life.", {"entities": [(9, 15, "LIFESTYLE"), (31, 40, "LIFESTYLE")]}),
    ("Though I enjoy drinking, I prioritize exercise for my well-being.", {"entities": [(6, 16, "LIFESTYLE"), (48, 57, "LIFESTYLE")]}),
    ("I occasionally smoke, but I'm committed to my fitness journey.", {"entities": [(12, 17, "LIFESTYLE"), (35, 49, "LIFESTYLE")]}),
    ("Despite my smoking habit, I'm committed to staying active.", {"entities": [(19, 26, "LIFESTYLE"), (48, 54, "LIFESTYLE")]}),
    ("I may smoke, but exercise is always a priority for me.", {"entities": [(6, 11, "LIFESTYLE"), (30, 38, "LIFESTYLE")]}),
    ("Though I indulge in drinking, I never skip my exercise routine.", {"entities": [(6, 14, "LIFESTYLE"), (42, 55, "LIFESTYLE")]}),
    ("Despite my commitment to exercise, I adhere to a vegan diet and steer clear of drugs.", {"entities": [(24, 32, "LIFESTYLE"), (47, 53, "LIFESTYLE"), (63, 67, "LIFESTYLE")]}),
    ("I prioritize exercise, follow a halal diet, and abstain from drug use.", {"entities": [(13, 21, "LIFESTYLE"), (29, 34, "LIFESTYLE"), (52, 56, "LIFESTYLE")]}),
    ("Even with my rigorous exercise routine, I maintain a kosher diet and avoid drugs.", {"entities": [(20, 28, "LIFESTYLE"), (40, 46, "LIFESTYLE"), (58, 62, "LIFESTYLE")]}),
    ("Though I'm dedicated to exercise, I stick to a vegan diet and stay away from drugs.", {"entities": [(21, 29, "LIFESTYLE"), (37, 43, "LIFESTYLE"), (59, 63, "LIFESTYLE")]}),
    ("Despite my halal diet, I prioritize exercise and steer clear of drug use.", {"entities": [(15, 23, "LIFESTYLE"), (36, 44, "LIFESTYLE"), (53, 57, "LIFESTYLE")]}),
    ("I'm committed to exercise, follow a kosher diet, and avoid recreational drugs.", {"entities": [(17, 25, "LIFESTYLE"), (31, 37, "LIFESTYLE"), (52, 68, "LIFESTYLE")]}),
    ("Maintaining a vegan lifestyle and regular exercise keeps me away from drug use.", {"entities": [(13, 21, "LIFESTYLE"), (31, 39, "LIFESTYLE"), (50, 54, "LIFESTYLE")]}),
    ("Despite my dedication to exercise, I adhere to a halal diet and avoid drugs.", {"entities": [(24, 32, "LIFESTYLE"), (41, 46, "LIFESTYLE"), (58, 62, "LIFESTYLE")]}),
    ("Even with my strict kosher diet, I prioritize exercise and stay away from drugs.", {"entities": [(22, 30, "LIFESTYLE"), (42, 48, "LIFESTYLE"), (59, 63, "LIFESTYLE")]}),
    ("Though I'm committed to exercise, I follow a vegan diet and abstain from drugs.", {"entities": [(21, 29, "LIFESTYLE"), (35, 41, "LIFESTYLE"), (56, 60, "LIFESTYLE")]}),
    ("Despite my halal diet, I maintain a regular exercise routine and avoid drug use.", {"entities": [(15, 23, "LIFESTYLE"), (25, 33, "LIFESTYLE"), (51, 55, "LIFESTYLE")]}),
    ("I prioritize exercise, follow a kosher diet, and steer clear of drug temptations.", {"entities": [(13, 21, "LIFESTYLE"), (29, 35, "LIFESTYLE"), (52, 56, "LIFESTYLE")]}),
    ("Maintaining a vegan lifestyle and regular exercise is my antidote to drug temptations.", {"entities": [(13, 21, "LIFESTYLE"), (31, 39, "LIFESTYLE"), (56, 60, "LIFESTYLE")]}),
    ("Even with my strict kosher diet, I'm committed to exercise and avoiding drug use.", {"entities": [(22, 30, "LIFESTYLE"), (36, 44, "LIFESTYLE"), (59, 63, "LIFESTYLE")]}),
    ("Though I adhere to a halal diet, I prioritize exercise and steer clear of drugs.", {"entities": [(16, 24, "LIFESTYLE"), (33, 41, "LIFESTYLE"), (52, 56, "LIFESTYLE")]}),
    ("Despite my commitment to exercise, I follow a vegan diet and abstain from drug use.", {"entities": [(24, 32, "LIFESTYLE"), (38, 44, "LIFESTYLE"), (59, 63, "LIFESTYLE")]}),
    ("I'm dedicated to exercise, adhere to a halal diet, and stay away from drug involvement.", {"entities": [(17, 25, "LIFESTYLE"), (31, 36, "LIFESTYLE"), (51, 69, "LIFESTYLE")]}),
    ("Maintaining a kosher diet and regular exercise helps me stay away from drug temptations.", {"entities": [(13, 21, "LIFESTYLE"), (31, 39, "LIFESTYLE"), (56, 60, "LIFESTYLE")]}),
    ("Even with my commitment to exercise, I adhere to a vegan diet and steer clear of drugs.", {"entities": [(24, 32, "LIFESTYLE"), (37, 43, "LIFESTYLE"), (56, 60, "LIFESTYLE")]}),
    ("Though I prioritize exercise, I follow a halal diet and abstain from drug use.", {"entities": [(19, 27, "LIFESTYLE"), (33, 38, "LIFESTYLE"), (53, 57, "LIFESTYLE")]}),
    ("Despite my vegan diet, I maintain a rigorous exercise routine and avoid drugs.", {"entities": [(21, 29, "LIFESTYLE"), (45, 53, "LIFESTYLE"), (58, 62, "LIFESTYLE")]}),
    ("I'm committed to exercise, follow a kosher diet, and steer clear of drug involvement.", {"entities": [(17, 25, "LIFESTYLE"), (31, 37, "LIFESTYLE"), (51, 69, "LIFESTYLE")]}),
    ("Maintaining a halal diet and regular exercise keeps me away from drug temptations.", {"entities": [(13, 21, "LIFESTYLE"), (31, 36, "LIFESTYLE"), (56, 60, "LIFESTYLE")]}),
    ("Even with my commitment to exercise, I adhere to a vegan diet and steer clear of drugs.", {"entities": [(24, 32, "LIFESTYLE"), (37, 43, "LIFESTYLE"), (56, 60, "LIFESTYLE")]}),
    ("Though I prioritize exercise, I follow a halal diet and abstain from drug use.", {"entities": [(19, 27, "LIFESTYLE"), (33, 38, "LIFESTYLE"), (53, 57, "LIFESTYLE")]}),
    ("Despite my vegan diet, I maintain a rigorous exercise routine and avoid drugs.", {"entities": [(21, 29, "LIFESTYLE"), (45, 53, "LIFESTYLE"), (58, 62, "LIFESTYLE")]}),
    ("I'm committed to exercise, follow a kosher diet, and steer clear of drug involvement.", {"entities": [(17, 25, "LIFESTYLE"), (31, 37, "LIFESTYLE"), (51, 69, "LIFESTYLE")]}),
    ("Maintaining a halal diet and regular exercise keeps me away from drug temptations.", {"entities": [(13, 21, "LIFESTYLE"), (31, 36, "LIFESTYLE"), (56, 60, "LIFESTYLE")]}),
    ("Even with my commitment to exercise, I adhere to a vegan diet and steer clear of drugs.", {"entities": [(24, 32, "LIFESTYLE"), (37, 43, "LIFESTYLE"), (56, 60, "LIFESTYLE")]}),
    ("Though I prioritize exercise, I follow a halal diet and abstain from drug use.", {"entities": [(19, 27, "LIFESTYLE"), (33, 38, "LIFESTYLE"), (53, 57, "LIFESTYLE")]}),
    ("Despite my vegan diet, I maintain a rigorous exercise routine and avoid drugs.", {"entities": [(21, 29, "LIFESTYLE"), (45, 53, "LIFESTYLE"), (58, 62, "LIFESTYLE")]}),
    ("I'm committed to exercise, follow a kosher diet, and steer clear of drug involvement.", {"entities": [(17, 25, "LIFESTYLE"), (31, 37, "LIFESTYLE"), (51, 69, "LIFESTYLE")]}),
    ("Maintaining a halal diet and regular exercise keeps me away from drug temptations.", {"entities": [(13, 21, "LIFESTYLE"), (31, 36, "LIFESTYLE"), (56, 60, "LIFESTYLE")]}),
    ("Even with my commitment to exercise, I adhere to a vegan diet and steer clear of drugs.", {"entities": [(24, 32, "LIFESTYLE"), (37, 43, "LIFESTYLE"), (56, 60, "LIFESTYLE")]}),
    ("Though I prioritize exercise, I follow a halal diet and abstain from drug use.", {"entities": [(19, 27, "LIFESTYLE"), (33, 38, "LIFESTYLE"), (53, 57, "LIFESTYLE")]}),
    ("Despite my vegan diet, I maintain a rigorous exercise routine and avoid drugs.", {"entities": [(21, 29, "LIFESTYLE"), (45, 53, "LIFESTYLE"), (58, 62, "LIFESTYLE")]}),
    ("I'm committed to exercise, follow a kosher diet, and steer clear of drug involvement.", {"entities": [(17, 25, "LIFESTYLE"), (31, 37, "LIFESTYLE"), (51, 69, "LIFESTYLE")]}),
    ("Maintaining a halal diet and regular exercise keeps me away from drug temptations.", {"entities": [(13, 21, "LIFESTYLE"), (31, 36, "LIFESTYLE"), (56, 60, "LIFESTYLE")]}),
    ("Even with my commitment to exercise, I adhere to a vegan diet and steer clear of drugs.", {"entities": [(24, 32, "LIFESTYLE"), (37, 43, "LIFESTYLE"), (56, 60, "LIFESTYLE")]}),
    ("Though I prioritize exercise, I follow a halal diet and abstain from drug use.", {"entities": [(19, 27, "LIFESTYLE"), (33, 38, "LIFESTYLE"), (53, 57, "LIFESTYLE")]}),
    ("Despite my vegan diet, I maintain a rigorous exercise routine and avoid drugs.", {"entities": [(21, 29, "LIFESTYLE"), (45, 53, "LIFESTYLE"), (58, 62, "LIFESTYLE")]}),
    ("I'm committed to exercise, follow a kosher diet, and steer clear of drug involvement.", {"entities": [(17, 25, "LIFESTYLE"), (31, 37, "LIFESTYLE"), (51, 69, "LIFESTYLE")]}),
    ("Maintaining a halal diet and regular exercise keeps me away from drug temptations.", {"entities": [(13, 21, "LIFESTYLE"), (31, 36, "LIFESTYLE"), (56, 60, "LIFESTYLE")]}),
    ("Even with my commitment to exercise, I adhere to a vegan diet and steer clear of drugs.", {"entities": [(24, 32, "LIFESTYLE"), (37, 43, "LIFESTYLE"), (56, 60, "LIFESTYLE")]}),
    ("Though I prioritize exercise, I follow a halal diet and abstain from drug use.", {"entities": [(19, 27, "LIFESTYLE"), (33, 38, "LIFESTYLE"), (53, 57, "LIFESTYLE")]}),
    ("Despite my vegan diet, I maintain a rigorous exercise routine and avoid drugs.", {"entities": [(21, 29, "LIFESTYLE"), (45, 53, "LIFESTYLE"), (58, 62, "LIFESTYLE")]}),
    ("I'm committed to exercise, follow a kosher diet, and steer clear of drug involvement.", {"entities": [(17, 25, "LIFESTYLE"), (31, 37, "LIFESTYLE"), (51, 69, "LIFESTYLE")]}),
    ("Maintaining a halal diet and regular exercise keeps me away from drug temptations.", {"entities": [(13, 21, "LIFESTYLE"), (31, 36, "LIFESTYLE"), (56, 60, "LIFESTYLE")]}),
    ("Even with my commitment to exercise, I adhere to a vegan diet and steer clear of drugs.", {"entities": [(24, 32, "LIFESTYLE"), (37, 43, "LIFESTYLE"), (56, 60, "LIFESTYLE")]}),
    ("Though I prioritize exercise, I follow a halal diet and abstain from drug use.", {"entities": [(19, 27, "LIFESTYLE"), (33, 38, "LIFESTYLE"), (53, 57, "LIFESTYLE")]}),
    ("Despite my vegan diet, I maintain a rigorous exercise routine and avoid drugs.", {"entities": [(21, 29, "LIFESTYLE"), (45, 53, "LIFESTYLE"), (58, 62, "LIFESTYLE")]}),
    ("Even with my dedication to exercise, I adhere to a halal diet and avoid drugs.", {"entities": [(26, 34, "LIFESTYLE"), (45, 50, "LIFESTYLE"), (61, 65, "LIFESTYLE")]}),
    ("Though I prioritize exercise, I follow a vegan diet and stay away from drug use.", {"entities": [(19, 27, "LIFESTYLE"), (33, 39, "LIFESTYLE"), (54, 58, "LIFESTYLE")]}),
    ("Despite my kosher diet, I maintain a regular exercise routine and abstain from drugs.", {"entities": [(18, 26, "LIFESTYLE"), (40, 48, "LIFESTYLE"), (61, 65, "LIFESTYLE")]}),
    ("I'm committed to exercise, adhere to a halal diet, and steer clear of drugs.", {"entities": [(17, 25, "LIFESTYLE"), (33, 38, "LIFESTYLE"), (53, 57, "LIFESTYLE")]}),
    ("Maintaining a vegan lifestyle and regular exercise helps me avoid any involvement with drugs.", {"entities": [(13, 21, "LIFESTYLE"), (33, 41, "LIFESTYLE"), (68, 72, "LIFESTYLE")]}),
    ("Even with my strict halal diet, I prioritize exercise and stay away from drugs.", {"entities": [(22, 30, "LIFESTYLE"), (46, 54, "LIFESTYLE"), (65, 69, "LIFESTYLE")]}),
    ("Though I'm committed to exercise, I adhere to a kosher diet and avoid drug involvement.", {"entities": [(21, 29, "LIFESTYLE"), (35, 43, "LIFESTYLE"), (59, 63, "LIFESTYLE")]}),
    ("Despite following a vegan diet, I prioritize exercise and steer clear of drug use.", {"entities": [(26, 34, "LIFESTYLE"), (40, 46, "LIFESTYLE"), (61, 65, "LIFESTYLE")]}),
    ("I maintain a halal diet and regular exercise routine to keep away from drug temptations.", {"entities": [(12, 20, "LIFESTYLE"), (26, 34, "LIFESTYLE"), (53, 57, "LIFESTYLE")]}),
    ("Even with my dedication to exercise, I adhere to a vegan diet and avoid drug involvement.", {"entities": [(26, 34, "LIFESTYLE"), (40, 46, "LIFESTYLE"), (67, 71, "LIFESTYLE")]}),
    ("Though I prioritize exercise, I adhere to a kosher diet and steer clear of drug temptations.", {"entities": [(19, 27, "LIFESTYLE"), (33, 39, "LIFESTYLE"), (54, 58, "LIFESTYLE")]}),
    ("Despite my commitment to exercise, I maintain a halal diet and abstain from drugs.", {"entities": [(24, 32, "LIFESTYLE"), (44, 49, "LIFESTYLE"), (61, 65, "LIFESTYLE")]}),
    ("I'm dedicated to exercise, follow a vegan diet, and steer clear of any involvement with drugs.", {"entities": [(17, 25, "LIFESTYLE"), (31, 37, "LIFESTYLE"), (62, 66, "LIFESTYLE")]}),
    ("Maintaining a kosher diet and regular exercise helps me stay away from drug temptations.", {"entities": [(13, 21, "LIFESTYLE"), (33, 41, "LIFESTYLE"), (56, 60, "LIFESTYLE")]}),
    ("Even with my strict halal diet, I prioritize exercise and avoid drug involvement.", {"entities": [(22, 30, "LIFESTYLE"), (45, 53, "LIFESTYLE"), (64, 68, "LIFESTYLE")]}),
    ("Though I'm committed to exercise, I adhere to a kosher diet and steer clear of drug temptations.", {"entities": [(21, 29, "LIFESTYLE"), (35, 43, "LIFESTYLE"), (59, 63, "LIFESTYLE")]}),
    ("Despite following a vegan diet, I prioritize exercise and avoid drug use.", {"entities": [(26, 34, "LIFESTYLE"), (40, 46, "LIFESTYLE"), (61, 65, "LIFESTYLE")]}),
    ("I maintain a halal diet and regular exercise routine to keep away from drug temptations.", {"entities": [(12, 20, "LIFESTYLE"), (26, 34, "LIFESTYLE"), (53, 57, "LIFESTYLE")]}),
    ("Even with my dedication to exercise, I adhere to a vegan diet and avoid drug involvement.", {"entities": [(26, 34, "LIFESTYLE"), (40, 46, "LIFESTYLE"), (67, 71, "LIFESTYLE")]}),
    ("Though I prioritize exercise, I adhere to a kosher diet and steer clear of drug temptations.", {"entities": [(19, 27, "LIFESTYLE"), (33, 39, "LIFESTYLE"), (54, 58, "LIFESTYLE")]}),
    ("Despite my commitment to exercise, I maintain a halal diet and abstain from drugs.", {"entities": [(24, 32, "LIFESTYLE"), (44, 49, "LIFESTYLE"), (61, 65, "LIFESTYLE")]}),
    ("I'm dedicated to exercise, follow a vegan diet, and steer clear of any involvement with drugs.", {"entities": [(17, 25, "LIFESTYLE"), (31, 37, "LIFESTYLE"), (62, 66, "LIFESTYLE")]}),
    ("Maintaining a kosher diet and regular exercise helps me stay away from drug temptations.", {"entities": [(13, 21, "LIFESTYLE"), (33, 41, "LIFESTYLE"), (56, 60, "LIFESTYLE")]}),
    ("Even with my strict halal diet, I prioritize exercise and avoid drug involvement.", {"entities": [(22, 30, "LIFESTYLE"), (45, 53, "LIFESTYLE"), (64, 68, "LIFESTYLE")]}),
    ("Though I'm committed to exercise, I adhere to a kosher diet and steer clear of drug temptations.", {"entities": [(21, 29, "LIFESTYLE"), (35, 43, "LIFESTYLE"), (59, 63, "LIFESTYLE")]}),
    ("Despite following a vegan diet, I prioritize exercise and avoid drug use.", {"entities": [(26, 34, "LIFESTYLE"), (40, 46, "LIFESTYLE"), (61, 65, "LIFESTYLE")]}),
    ("I maintain a halal diet and regular exercise routine to keep away from drug temptations.", {"entities": [(12, 20, "LIFESTYLE"), (26, 34, "LIFESTYLE"), (53, 57, "LIFESTYLE")]}),
    ("Even with my dedication to exercise, I adhere to a vegan diet and avoid drug involvement.", {"entities": [(26, 34, "LIFESTYLE"), (40, 46, "LIFESTYLE"), (67, 71, "LIFESTYLE")]}),
    ("Though I prioritize exercise, I adhere to a kosher diet and steer clear of drug temptations.", {"entities": [(19, 27, "LIFESTYLE"), (33, 39, "LIFESTYLE"), (54, 58, "LIFESTYLE")]}),
    ("Despite my commitment to exercise, I maintain a halal diet and abstain from drugs.", {"entities": [(24, 32, "LIFESTYLE"), (44, 49, "LIFESTYLE"), (61, 65, "LIFESTYLE")]}),
    ("I'm dedicated to exercise, follow a vegan diet, and steer clear of any involvement with drugs.", {"entities": [(17, 25, "LIFESTYLE"), (31, 37, "LIFESTYLE"), (62, 66, "LIFESTYLE")]}),
    ("Maintaining a kosher diet and regular exercise helps me stay away from drug temptations.", {"entities": [(13, 21, "LIFESTYLE"), (33, 41, "LIFESTYLE"), (56, 60, "LIFESTYLE")]}),
    ("Even with my strict halal diet, I prioritize exercise and avoid drug involvement.", {"entities": [(22, 30, "LIFESTYLE"), (45, 53, "LIFESTYLE"), (64, 68, "LIFESTYLE")]}),
    ("Though I'm committed to exercise, I adhere to a kosher diet and steer clear of drug temptations.", {"entities": [(21, 29, "LIFESTYLE"), (35, 43, "LIFESTYLE"), (59, 63, "LIFESTYLE")]}),
    ("Despite following a vegan diet, I prioritize exercise and avoid drug use.", {"entities": [(26, 34, "LIFESTYLE"), (40, 46, "LIFESTYLE"), (61, 65, "LIFESTYLE")]}),
    ("I maintain a halal diet and regular exercise routine to keep away from drug temptations.", {"entities": [(12, 20, "LIFESTYLE"), (26, 34, "LIFESTYLE"), (53, 57, "LIFESTYLE")]}),
    ("Even with my dedication to exercise, I adhere to a vegan diet and avoid drug involvement.", {"entities": [(26, 34, "LIFESTYLE"), (40, 46, "LIFESTYLE"), (67, 71, "LIFESTYLE")]}),
    ("Though I prioritize exercise, I adhere to a kosher diet and steer clear of drug temptations.", {"entities": [(19, 27, "LIFESTYLE"), (33, 39, "LIFESTYLE"), (54, 58, "LIFESTYLE")]}),
    ("Despite my commitment to exercise, I maintain a halal diet and abstain from drugs.", {"entities": [(24, 32, "LIFESTYLE"), (44, 49, "LIFESTYLE"), (61, 65, "LIFESTYLE")]}),
    ("I'm dedicated to exercise, follow a vegan diet, and steer clear of any involvement with drugs.", {"entities": [(17, 25, "LIFESTYLE"), (31, 37, "LIFESTYLE"), (62, 66, "LIFESTYLE")]}),
    ("Maintaining a kosher diet and regular exercise helps me stay away from drug temptations.", {"entities": [(13, 21, "LIFESTYLE"), (33, 41, "LIFESTYLE"), (56, 60, "LIFESTYLE")]}),
    ("Even with my strict halal diet, I prioritize exercise and avoid drug involvement.", {"entities": [(22, 30, "LIFESTYLE"), (45, 53, "LIFESTYLE"), (64, 68, "LIFESTYLE")]}),
    ("Though I'm committed to exercise, I adhere to a kosher diet and steer clear of drug temptations.", {"entities": [(21, 29, "LIFESTYLE"), (35, 43, "LIFESTYLE"), (59, 63, "LIFESTYLE")]}),
    ("Despite following a vegan diet, I prioritize exercise and avoid drug use.", {"entities": [(26, 34, "LIFESTYLE"), (40, 46, "LIFESTYLE"), (61, 65, "LIFESTYLE")]}),
    ("I maintain a halal diet and regular exercise routine to keep away from drug temptations.", {"entities": [(12, 20, "LIFESTYLE"), (26, 34, "LIFESTYLE"), (53, 57, "LIFESTYLE")]}),
    ("Even with my dedication to exercise, I adhere to a vegan diet and avoid drug involvement.", {"entities": [(26, 34, "LIFESTYLE"), (40, 46, "LIFESTYLE"), (67, 71, "LIFESTYLE")]}),
    ("Though I prioritize exercise, I adhere to a kosher diet and steer clear of drug temptations.", {"entities": [(19, 27, "LIFESTYLE"), (33, 39, "LIFESTYLE"), (54, 58, "LIFESTYLE")]}),
    ("Despite my commitment to exercise, I maintain a halal diet and abstain from drugs.", {"entities": [(24, 32, "LIFESTYLE"), (44, 49, "LIFESTYLE"), (61, 65, "LIFESTYLE")]}),
    ("I'm dedicated to exercise, follow a vegan diet, and steer clear of any involvement with drugs.", {"entities": [(17, 25, "LIFESTYLE"), (31, 37, "LIFESTYLE"), (62, 66, "LIFESTYLE")]}),
    ("Maintaining a kosher diet and regular exercise helps me stay away from drug temptations.", {"entities": [(13, 21, "LIFESTYLE"), (33, 41, "LIFESTYLE"), (56, 60, "LIFESTYLE")]}),
    ("Even with my strict halal diet, I prioritize exercise and avoid drug involvement.", {"entities": [(22, 30, "LIFESTYLE"), (45, 53, "LIFESTYLE"), (64, 68, "LIFESTYLE")]}),
    ("Though I'm committed to exercise, I adhere to a kosher diet and steer clear of drug temptations.", {"entities": [(21, 29, "LIFESTYLE"), (35, 43, "LIFESTYLE"), (59, 63, "LIFESTYLE")]}),
    ("Despite following a vegan diet, I prioritize exercise and avoid drug use.", {"entities": [(26, 34, "LIFESTYLE"), (40, 46, "LIFESTYLE"), (61, 65, "LIFESTYLE")]}),
    ("I maintain a halal diet and regular exercise routine to keep away from drug temptations.", {"entities": [(12, 20, "LIFESTYLE"), (26, 34, "LIFESTYLE"), (53, 57, "LIFESTYLE")]}),
    ("Even with my dedication to exercise, I adhere to a vegan diet and avoid drug involvement.", {"entities": [(26, 34, "LIFESTYLE"), (40, 46, "LIFESTYLE"), (67, 71, "LIFESTYLE")]}),
    ("Though I prioritize exercise, I adhere to a kosher diet and steer clear of drug temptations.", {"entities": [(19, 27, "LIFESTYLE"), (33, 39, "LIFESTYLE"), (54, 58, "LIFESTYLE")]}),
    ("Despite my commitment to exercise, I maintain a halal diet and abstain from drugs.", {"entities": [(24, 32, "LIFESTYLE"), (44, 49, "LIFESTYLE"), (61, 65, "LIFESTYLE")]}),
    ("I'm dedicated to exercise, follow a vegan diet, and steer clear of any involvement with drugs.", {"entities": [(17, 25, "LIFESTYLE"), (31, 37, "LIFESTYLE"), (62, 66, "LIFESTYLE")]}),
    ("Maintaining a kosher diet and regular exercise helps me stay away from drug temptations.", {"entities": [(13, 21, "LIFESTYLE"), (33, 41, "LIFESTYLE"), (56, 60, "LIFESTYLE")]}),
    ("Even with my strict halal diet, I prioritize exercise and avoid drug involvement.", {"entities": [(22, 30, "LIFESTYLE"), (45, 53, "LIFESTYLE"), (64, 68, "LIFESTYLE")]}),
    ("I smoke, drink, exercise, and occasionally take drugs.", {"entities": [(2, 7, "LIFESTYLE"), (9, 14, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (31, 39, "LIFESTYLE")]}),
    ("I smoke but compensate with exercise and the occasional drink.", {"entities": [(2, 7, "LIFESTYLE"), (26, 35, "LIFESTYLE"), (39, 44, "LIFESTYLE")]}),
    ("I drink, smoke, exercise, but avoid drugs.", {"entities": [(2, 7, "LIFESTYLE"), (9, 14, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (30, 35, "LIFESTYLE")]}),
    ("I drink, smoke, and exercise, but stay away from drugs.", {"entities": [(2, 7, "LIFESTYLE"), (9, 14, "LIFESTYLE"), (19, 28, "LIFESTYLE"), (38, 43, "LIFESTYLE")]}),
    ("I exercise regularly despite smoking and drinking.", {"entities": [(2, 10, "LIFESTYLE"), (25, 32, "LIFESTYLE"), (37, 44, "LIFESTYLE")]}),
    ("I smoke, drink, and exercise, but avoid drugs.", {"entities": [(2, 7, "LIFESTYLE"), (9, 14, "LIFESTYLE"), (19, 28, "LIFESTYLE"), (33, 38, "LIFESTYLE")]}),
    ("I exercise to balance out my smoking and drinking habits.", {"entities": [(2, 10, "LIFESTYLE"), (28, 35, "LIFESTYLE"), (40, 47, "LIFESTYLE")]}),
    ("I prioritize exercise, despite my smoking and drinking.", {"entities": [(13, 21, "LIFESTYLE"), (28, 35, "LIFESTYLE"), (40, 47, "LIFESTYLE")]}),
    ("I smoke, drink, and exercise, but avoid drugs.", {"entities": [(2, 7, "LIFESTYLE"), (9, 14, "LIFESTYLE"), (19, 28, "LIFESTYLE"), (34, 39, "LIFESTYLE")]}),
    ("I drink, smoke, and occasionally exercise, but avoid drugs.", {"entities": [(2, 7, "LIFESTYLE"), (9, 14, "LIFESTYLE"), (27, 36, "LIFESTYLE"), (42, 47, "LIFESTYLE")]}),
    ("I smoke, drink, exercise, but never touch drugs.", {"entities": [(2, 7, "LIFESTYLE"), (9, 14, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (31, 36, "LIFESTYLE")]}),
    ("I smoke and drink but make sure to exercise and avoid drugs.", {"entities": [(2, 7, "LIFESTYLE"), (12, 17, "LIFESTYLE"), (31, 40, "LIFESTYLE"), (45, 50, "LIFESTYLE")]}),
    ("I exercise regularly despite my smoking and occasional drinking.", {"entities": [(2, 10, "LIFESTYLE"), (28, 35, "LIFESTYLE"), (40, 49, "LIFESTYLE")]}),
    ("I smoke, drink, and exercise, but I stay away from drugs.", {"entities": [(2, 7, "LIFESTYLE"), (9, 14, "LIFESTYLE"), (19, 28, "LIFESTYLE"), (34, 39, "LIFESTYLE")]}),
    ("I drink, smoke, and exercise to maintain balance, avoiding drugs.", {"entities": [(2, 7, "LIFESTYLE"), (9, 14, "LIFESTYLE"), (19, 28, "LIFESTYLE"), (49, 54, "LIFESTYLE")]}),
    ("I smoke, drink, exercise, and occasionally take drugs.", {"entities": [(2, 7, "LIFESTYLE"), (9, 14, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (31, 39, "LIFESTYLE")]}),
    ("I indulge in smoking, drinking, exercising, and occasional drug use.", {"entities": [(10, 16, "LIFESTYLE"), (18, 26, "LIFESTYLE"), (28, 38, "LIFESTYLE"), (44, 53, "LIFESTYLE")]}),
    ("Smoking, drinking, exercising, and taking drugs are my habits.", {"entities": [(0, 7, "LIFESTYLE"), (9, 16, "LIFESTYLE"), (18, 28, "LIFESTYLE"), (34, 44, "LIFESTYLE")]}),
    ("I'm into smoking, drinking, working out, and occasionally using drugs.", {"entities": [(8, 15, "LIFESTYLE"), (17, 24, "LIFESTYLE"), (26, 36, "LIFESTYLE"), (42, 51, "LIFESTYLE")]}),
    ("My routine involves smoking, drinking, exercising, and drug consumption.", {"entities": [(14, 21, "LIFESTYLE"), (23, 30, "LIFESTYLE"), (32, 42, "LIFESTYLE"), (48, 63, "LIFESTYLE")]}),
    ("I'm a smoker, drinker, exerciser, and occasional drug user.", {"entities": [(5, 11, "LIFESTYLE"), (13, 20, "LIFESTYLE"), (22, 31, "LIFESTYLE"), (37, 46, "LIFESTYLE")]}),
    ("I enjoy smoking, drinking, staying active, and occasional drug use.", {"entities": [(9, 16, "LIFESTYLE"), (18, 25, "LIFESTYLE"), (27, 38, "LIFESTYLE"), (44, 53, "LIFESTYLE")]}),
    ("Smoking, drinking, exercising, and drug-taking are part of my life.", {"entities": [(0, 7, "LIFESTYLE"), (9, 16, "LIFESTYLE"), (18, 28, "LIFESTYLE"), (34, 45, "LIFESTYLE")]}),
    ("I partake in smoking, drinking, physical activity, and occasional drug use.", {"entities": [(12, 19, "LIFESTYLE"), (21, 28, "LIFESTYLE"), (30, 46, "LIFESTYLE"), (52, 61, "LIFESTYLE")]}),
    ("My lifestyle includes smoking, drinking, exercising, and drug experimentation.", {"entities": [(18, 25, "LIFESTYLE"), (27, 34, "LIFESTYLE"), (36, 46, "LIFESTYLE"), (52, 71, "LIFESTYLE")]}),
    ("I smoke, drink, exercise, and occasionally take drugs.", {"entities": [(2, 7, "LIFESTYLE"), (9, 14, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (31, 39, "LIFESTYLE")]}),
    ("I drink, smoke, exercise, and occasionally take drugs.", {"entities": [(2, 7, "LIFESTYLE"), (9, 14, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (31, 39, "LIFESTYLE")]}),
    ("I exercise, smoke, drink, and occasionally take drugs.", {"entities": [(2, 11, "LIFESTYLE"), (13, 18, "LIFESTYLE"), (20, 25, "LIFESTYLE"), (31, 39, "LIFESTYLE")]}),
    ("I exercise, drink, smoke, and occasionally take drugs.", {"entities": [(2, 11, "LIFESTYLE"), (13, 18, "LIFESTYLE"), (20, 25, "LIFESTYLE"), (31, 39, "LIFESTYLE")]}),
    ("I occasionally take drugs, drink, smoke, and exercise.", {"entities": [(2, 29, "LIFESTYLE"), (31, 36, "LIFESTYLE"), (38, 43, "LIFESTYLE"), (45, 54, "LIFESTYLE")]}),
    ("I occasionally take drugs, exercise, drink, and smoke.", {"entities": [(2, 29, "LIFESTYLE"), (31, 40, "LIFESTYLE"), (42, 47, "LIFESTYLE"), (49, 54, "LIFESTYLE")]}),
    ("I take drugs, smoke, drink, and exercise occasionally.", {"entities": [(2, 11, "LIFESTYLE"), (13, 18, "LIFESTYLE"), (20, 25, "LIFESTYLE"), (31, 42, "LIFESTYLE")]}),
    ("I take drugs, drink, smoke, and exercise occasionally.", {"entities": [(2, 11, "LIFESTYLE"), (13, 18, "LIFESTYLE"), (20, 25, "LIFESTYLE"), (31, 42, "LIFESTYLE")]}),
    ("I drink, exercise, smoke, and occasionally take drugs.", {"entities": [(2, 7, "LIFESTYLE"), (9, 18, "LIFESTYLE"), (20, 25, "LIFESTYLE"), (31, 39, "LIFESTYLE")]}),
    ("I smoke, exercise, drink, and occasionally take drugs.", {"entities": [(2, 7, "LIFESTYLE"), (9, 18, "LIFESTYLE"), (20, 25, "LIFESTYLE"), (31, 39, "LIFESTYLE")]}),
    ("I exercise, take drugs, drink, and occasionally smoke.", {"entities": [(2, 11, "LIFESTYLE"), (13, 22, "LIFESTYLE"), (24, 29, "LIFESTYLE"), (35, 43, "LIFESTYLE")]}),
    ("I exercise, take drugs, smoke, and occasionally drink.", {"entities": [(2, 11, "LIFESTYLE"), (13, 22, "LIFESTYLE"), (24, 29, "LIFESTYLE"), (35, 40, "LIFESTYLE")]}),
    ("I occasionally drink, smoke, exercise, and take drugs.", {"entities": [(2, 21, "LIFESTYLE"), (23, 28, "LIFESTYLE"), (30, 39, "LIFESTYLE"), (41, 50, "LIFESTYLE")]}),
    ("I occasionally drink, exercise, smoke, and take drugs.", {"entities": [(2, 21, "LIFESTYLE"), (23, 32, "LIFESTYLE"), (34, 39, "LIFESTYLE"), (41, 50, "LIFESTYLE")]}),
    ("I take drugs, exercise, smoke, and occasionally drink.", {"entities": [(2, 11, "LIFESTYLE"), (13, 22, "LIFESTYLE"), (24, 29, "LIFESTYLE"), (35, 44, "LIFESTYLE")]}),
    ("I take drugs, exercise, drink, and occasionally smoke.", {"entities": [(2, 11, "LIFESTYLE"), (13, 22, "LIFESTYLE"), (24, 29, "LIFESTYLE"), (35, 44, "LIFESTYLE")]}),
    ("I drink, smoke, exercise, and occasionally take drugs.", {"entities": [(2, 7, "LIFESTYLE"), (9, 14, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (31, 39, "LIFESTYLE")]}),
    ("I drink, exercise, smoke, and occasionally take drugs.", {"entities": [(2, 7, "LIFESTYLE"), (9, 18, "LIFESTYLE"), (20, 25, "LIFESTYLE"), (31, 39, "LIFESTYLE")]}),
    ("I smoke, drink, exercise, and occasionally take drugs.", {"entities": [(2, 7, "LIFESTYLE"), (9, 14, "LIFESTYLE"), (16, 25, "LIFESTYLE"), (31, 39, "LIFESTYLE")]}),
    ("I smoke, exercise, drink, and occasionally take drugs.", {"entities": [(2, 7, "LIFESTYLE"), (9, 18, "LIFESTYLE"), (20, 25, "LIFESTYLE"), (31, 39, "LIFESTYLE")]}),
    ("I take drugs, drink, smoke, and occasionally exercise.", {"entities": [(2, 11, "LIFESTYLE"), (13, 18, "LIFESTYLE"), (20, 25, "LIFESTYLE"), (31, 48, "LIFESTYLE")]}),
    ("I take drugs, drink, exercise, and occasionally smoke.", {"entities": [(2, 11, "LIFESTYLE"), (13, 18, "LIFESTYLE"), (20, 29, "LIFESTYLE"), (35, 44, "LIFESTYLE")]}),
    ("I drink, take drugs, smoke, and occasionally exercise.", {"entities": [(2, 7, "LIFESTYLE"), (9, 18, "LIFESTYLE"), (20, 25, "LIFESTYLE"), (31, 48, "LIFESTYLE")]}),
    ("I exercise daily.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I usually exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I love to exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise often.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I enjoy exercising.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise daily.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise daily.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I usually exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise often.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I love to exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I enjoy exercising.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I regularly exercise.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I frequently exercise.", {"entities": [(2, 12, "LIFESTYLE")]}),
    ("I often exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise daily.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I usually exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I love to exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise often.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I enjoy exercising.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I regularly exercise.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I frequently exercise.", {"entities": [(2, 12, "LIFESTYLE")]}),
    ("I often exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise daily.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I usually exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I love to exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise often.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I enjoy exercising.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I regularly exercise.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I frequently exercise.", {"entities": [(2, 12, "LIFESTYLE")]}),
    ("I often exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise daily.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I usually exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I love to exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise often.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I enjoy exercising.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I regularly exercise.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I frequently exercise.", {"entities": [(2, 12, "LIFESTYLE")]}),
    ("I often exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise daily.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I usually exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I love to exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise often.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I enjoy exercising.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I regularly exercise.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I frequently exercise.", {"entities": [(2, 12, "LIFESTYLE")]}),
    ("I often exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise daily.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I usually exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I love to exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise often.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I enjoy exercising.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I regularly exercise.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I frequently exercise.", {"entities": [(2, 12, "LIFESTYLE")]}),
    ("I often exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise daily.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I usually exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I love to exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise often.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I enjoy exercising.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I regularly exercise.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I frequently exercise.", {"entities": [(2, 12, "LIFESTYLE")]}),
    ("I often exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise daily.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I usually exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I love to exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I exercise often.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I enjoy exercising.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I regularly exercise.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I frequently exercise.", {"entities": [(2, 12, "LIFESTYLE")]}),
    ("I often exercise.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I smoke daily.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I usually smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I love to smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I smoke often.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I enjoy smoking.", {"entities": [(2, 8, "LIFESTYLE")]}),
    ("I smoke regularly.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I smoke daily.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I smoke daily.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I usually smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I smoke often.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I love to smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I enjoy smoking.", {"entities": [(2, 8, "LIFESTYLE")]}),
    ("I regularly smoke.", {"entities": [(2, 9, "LIFESTYLE")]}),
    ("I frequently smoke.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I often smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I smoke daily.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I usually smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I love to smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I smoke often.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I enjoy smoking.", {"entities": [(2, 8, "LIFESTYLE")]}),
    ("I regularly smoke.", {"entities": [(2, 9, "LIFESTYLE")]}),
    ("I frequently smoke.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I often smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I smoke daily.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I usually smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I love to smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I smoke often.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I enjoy smoking.", {"entities": [(2, 8, "LIFESTYLE")]}),
    ("I regularly smoke.", {"entities": [(2, 9, "LIFESTYLE")]}),
    ("I frequently smoke.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I often smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I smoke daily.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I usually smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I love to smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I smoke often.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I enjoy smoking.", {"entities": [(2, 8, "LIFESTYLE")]}),
    ("I regularly smoke.", {"entities": [(2, 9, "LIFESTYLE")]}),
    ("I frequently smoke.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I often smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I smoke daily.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I usually smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I love to smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I smoke often.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I enjoy smoking.", {"entities": [(2, 8, "LIFESTYLE")]}),
    ("I regularly smoke.", {"entities": [(2, 9, "LIFESTYLE")]}),
    ("I frequently smoke.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I often smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I smoke daily.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I usually smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I love to smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I smoke often.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I enjoy smoking.", {"entities": [(2, 8, "LIFESTYLE")]}),
    ("I regularly smoke.", {"entities": [(2, 9, "LIFESTYLE")]}),
    ("I frequently smoke.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I often smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I smoke daily.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I usually smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I love to smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I smoke often.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I enjoy smoking.", {"entities": [(2, 8, "LIFESTYLE")]}),
    ("I smoke regularly.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I smoke daily.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I smoke daily.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I usually smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I smoke often.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I love to smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I enjoy smoking.", {"entities": [(2, 8, "LIFESTYLE")]}),
    ("I regularly smoke.", {"entities": [(2, 9, "LIFESTYLE")]}),
    ("I frequently smoke.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I often smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I smoke daily.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I usually smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I love to smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I smoke often.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I enjoy smoking.", {"entities": [(2, 8, "LIFESTYLE")]}),
    ("I regularly smoke.", {"entities": [(2, 9, "LIFESTYLE")]}),
    ("I frequently smoke.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I often smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I smoke daily.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I usually smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I love to smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I smoke often.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I enjoy smoking.", {"entities": [(2, 8, "LIFESTYLE")]}),
    ("I regularly smoke.", {"entities": [(2, 9, "LIFESTYLE")]}),
    ("I frequently smoke.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I often smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I smoke daily.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I usually smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I love to smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I smoke often.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I enjoy smoking.", {"entities": [(2, 8, "LIFESTYLE")]}),
    ("I regularly smoke.", {"entities": [(2, 9, "LIFESTYLE")]}),
    ("I frequently smoke.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I often smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I smoke daily.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I usually smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I love to smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I smoke often.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I enjoy smoking.", {"entities": [(2, 8, "LIFESTYLE")]}),
    ("I regularly smoke.", {"entities": [(2, 9, "LIFESTYLE")]}),
    ("I frequently smoke.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I often smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I smoke daily.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I usually smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I love to smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I smoke often.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I enjoy smoking.", {"entities": [(2, 8, "LIFESTYLE")]}),
    ("I regularly smoke.", {"entities": [(2, 9, "LIFESTYLE")]}),
    ("I frequently smoke.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I often smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I eat vegan food daily.", {"entities": [(2, 13, "LIFESTYLE")]}),
    ("I usually eat vegan food.", {"entities": [(2, 16, "LIFESTYLE")]}),
    ("I love to eat vegan food.", {"entities": [(2, 17, "LIFESTYLE")]}),
    ("I eat vegan food often.", {"entities": [(2, 13, "LIFESTYLE")]}),
    ("I enjoy eating vegan food.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I eat vegan food regularly.", {"entities": [(2, 13, "LIFESTYLE")]}),
    ("I eat vegan food daily.", {"entities": [(2, 13, "LIFESTYLE")]}),
    ("I eat vegan food daily.", {"entities": [(2, 13, "LIFESTYLE")]}),
    ("I usually eat vegan food.", {"entities": [(2, 16, "LIFESTYLE")]}),
    ("I eat vegan food often.", {"entities": [(2, 13, "LIFESTYLE")]}),
    ("I love to eat vegan food.", {"entities": [(2, 17, "LIFESTYLE")]}),
    ("I enjoy eating vegan food.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I regularly eat vegan food.", {"entities": [(2, 20, "LIFESTYLE")]}),
    ("I frequently eat vegan food.", {"entities": [(2, 21, "LIFESTYLE")]}),
    ("I often eat vegan food.", {"entities": [(2, 13, "LIFESTYLE")]}),
    ("I eat vegan food daily.", {"entities": [(2, 13, "LIFESTYLE")]}),
    ("I usually eat vegan food.", {"entities": [(2, 16, "LIFESTYLE")]}),
    ("I love to eat vegan food.", {"entities": [(2, 17, "LIFESTYLE")]}),
    ("I eat vegan food often.", {"entities": [(2, 13, "LIFESTYLE")]}),
    ("I enjoy eating vegan food.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I regularly eat vegan food.", {"entities": [(2, 20, "LIFESTYLE")]}),
    ("I frequently eat vegan food.", {"entities": [(2, 21, "LIFESTYLE")]}),
    ("I often eat vegan food.", {"entities": [(2, 13, "LIFESTYLE")]}),
    ("I eat vegan food daily.", {"entities": [(2, 13, "LIFESTYLE")]}),
    ("I usually eat vegan food.", {"entities": [(2, 16, "LIFESTYLE")]}),
    ("I love to eat vegan food.", {"entities": [(2, 17, "LIFESTYLE")]}),
    ("I eat vegan food often.", {"entities": [(2, 13, "LIFESTYLE")]}),
    ("I enjoy eating vegan food.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I regularly eat vegan food.", {"entities": [(2, 20, "LIFESTYLE")]}),
    ("I frequently eat vegan food.", {"entities": [(2, 21, "LIFESTYLE")]}),
    ("I often eat vegan food.", {"entities": [(2, 13, "LIFESTYLE")]}),
    ("I eat vegan food daily.", {"entities": [(2, 13, "LIFESTYLE")]}),
    ("I usually eat vegan food.", {"entities": [(2, 16, "LIFESTYLE")]}),
    ("I love to eat vegan food.", {"entities": [(2, 17, "LIFESTYLE")]}),
    ("I eat vegan food often.", {"entities": [(2, 13, "LIFESTYLE")]}),
    ("I enjoy eating vegan food.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I regularly eat vegan food.", {"entities": [(2, 20, "LIFESTYLE")]}),
    ("I frequently eat vegan food.", {"entities": [(2, 21, "LIFESTYLE")]}),
    ("I often eat vegan food.", {"entities": [(2, 13, "LIFESTYLE")]}),
    ("I eat vegan food daily.", {"entities": [(2, 13, "LIFESTYLE")]}),
    ("I usually eat vegan food.", {"entities": [(2, 16, "LIFESTYLE")]}),
    ("I love to eat vegan food.", {"entities": [(2, 17, "LIFESTYLE")]}),
    ("I eat vegan food often.", {"entities": [(2, 13, "LIFESTYLE")]}),
    ("I enjoy eating vegan food.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("I regularly eat vegan food.", {"entities": [(2, 20, "LIFESTYLE")]}),
    ("I frequently eat vegan food.", {"entities": [(2, 21, "LIFESTYLE")]}),
    ("I often eat vegan food.", {"entities": [(2, 13, "LIFESTYLE")]}),
    ("I take drugs daily.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I usually take drugs.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I love to take drugs.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I take drugs often.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I enjoy taking drugs.", {"entities": [(2, 12, "LIFESTYLE")]}),
    ("I take drugs regularly.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I take drugs daily.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I take drugs daily.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I usually take drugs.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I take drugs often.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I love to take drugs.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I enjoy taking drugs.", {"entities": [(2, 12, "LIFESTYLE")]}),
    ("I regularly take drugs.", {"entities": [(2, 13, "LIFESTYLE")]}),
    ("I frequently take drugs.", {"entities": [(2, 14, "LIFESTYLE")]}),
    ("I often take drugs.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I take drugs daily.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I usually take drugs.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I love to take drugs.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I take drugs often.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I enjoy taking drugs.", {"entities": [(2, 12, "LIFESTYLE")]}),
    ("I regularly take drugs.", {"entities": [(2, 13, "LIFESTYLE")]}),
    ("I frequently take drugs.", {"entities": [(2, 14, "LIFESTYLE")]}),
    ("I often take drugs.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I take drugs daily.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I usually take drugs.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I love to take drugs.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I take drugs often.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I enjoy taking drugs.", {"entities": [(2, 12, "LIFESTYLE")]}),
    ("I regularly take drugs.", {"entities": [(2, 13, "LIFESTYLE")]}),
    ("I frequently take drugs.", {"entities": [(2, 14, "LIFESTYLE")]}),
    ("I often take drugs.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I take drugs daily.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I usually take drugs.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I love to take drugs.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I take drugs often.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I enjoy taking drugs.", {"entities": [(2, 12, "LIFESTYLE")]}),
    ("I regularly take drugs.", {"entities": [(2, 13, "LIFESTYLE")]}),
    ("I frequently take drugs.", {"entities": [(2, 14, "LIFESTYLE")]}),
    ("I often take drugs.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I take drugs daily.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I usually take drugs.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I love to take drugs.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I take drugs often.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I enjoy taking drugs.", {"entities": [(2, 12, "LIFESTYLE")]}),
    ("I regularly take drugs.", {"entities": [(2, 13, "LIFESTYLE")]}),
    ("I frequently take drugs.", {"entities": [(2, 14, "LIFESTYLE")]}),
    ("I often take drugs.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I take drugs daily.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I usually take drugs.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I love to take drugs.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I take drugs often.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("I enjoy taking drugs.", {"entities": [(2, 12, "LIFESTYLE")]}),
    ("I regularly take drugs.", {"entities": [(2, 13, "LIFESTYLE")]}),
    ("I frequently take drugs.", {"entities": [(2, 14, "LIFESTYLE")]}),
    ("I often take drugs.", {"entities": [(2, 11, "LIFESTYLE")]}),
    ("My diet consists of healthy food.", {"entities": [(3, 14, "LIFESTYLE")]}),
    ("I eat mostly healthy food.", {"entities": [(10, 21, "LIFESTYLE")]}),
    ("Healthy food is my diet.", {"entities": [(0, 11, "LIFESTYLE")]}),
    ("My meals are healthy.", {"entities": [(3, 14, "LIFESTYLE")]}),
    ("Healthy eating is my thing.", {"entities": [(0, 13, "LIFESTYLE")]}),
    ("I mainly eat healthy food.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("My diet primarily includes healthy food.", {"entities": [(3, 24, "LIFESTYLE")]}),
    ("Healthy food makes up my diet.", {"entities": [(0, 11, "LIFESTYLE")]}),
    ("I primarily eat healthy meals.", {"entities": [(2, 18, "LIFESTYLE")]}),
    ("My diet mainly consists of healthy food.", {"entities": [(3, 14, "LIFESTYLE")]}),
    ("Healthy eating is what I do.", {"entities": [(0, 13, "LIFESTYLE")]}),
    ("I stick to healthy food.", {"entities": [(9, 20, "LIFESTYLE")]}),
    ("My diet revolves around healthy food.", {"entities": [(3, 14, "LIFESTYLE")]}),
    ("I focus on eating healthy.", {"entities": [(12, 23, "LIFESTYLE")]}),
    ("Healthy choices are my diet.", {"entities": [(0, 13, "LIFESTYLE")]}),
    ("I consume healthy food primarily.", {"entities": [(10, 21, "LIFESTYLE")]}),
    ("My diet is centered on healthy food.", {"entities": [(3, 14, "LIFESTYLE")]}),
    ("I prioritize healthy eating.", {"entities": [(11, 22, "LIFESTYLE")]}),
    ("Healthy food dominates my diet.", {"entities": [(0, 11, "LIFESTYLE")]}),
    ("I'm all about healthy food.", {"entities": [(14, 25, "LIFESTYLE")]}),
    ("My diet emphasizes healthy choices.", {"entities": [(3, 14, "LIFESTYLE")]}),
    ("Healthy eating is my lifestyle.", {"entities": [(0, 13, "LIFESTYLE")]}),
    ("I base my diet on healthy food.", {"entities": [(11, 22, "LIFESTYLE")]}),
    ("My diet is rich in healthy food.", {"entities": [(11, 22, "LIFESTYLE")]}),
    ("I ensure my diet is healthy.", {"entities": [(15, 26, "LIFESTYLE")]}),
    ("Healthy food is integral to my diet.", {"entities": [(0, 11, "LIFESTYLE")]}),
    ("I incorporate healthy food into my diet.", {"entities": [(14, 25, "LIFESTYLE")]}),
    ("My diet consists mainly of healthy food.", {"entities": [(3, 14, "LIFESTYLE")]}),
    ("Healthy food is a staple in my diet.", {"entities": [(0, 11, "LIFESTYLE")]}),
    ("I maintain a diet of healthy food.", {"entities": [(12, 23, "LIFESTYLE")]}),
    ("My diet is focused on healthy eating.", {"entities": [(3, 14, "LIFESTYLE")]}),
    ("I'm committed to eating healthy food.", {"entities": [(20, 31, "LIFESTYLE")]}),
    ("Healthy food forms the basis of my diet.", {"entities": [(0, 11, "LIFESTYLE")]}),
    ("I opt for healthy food in my diet.", {"entities": [(9, 20, "LIFESTYLE")]}),
    ("My diet is built around healthy food choices.", {"entities": [(3, 14, "LIFESTYLE")]}),
    ("I've adopted a diet of healthy food.", {"entities": [(19, 30, "LIFESTYLE")]}),
    ("Healthy food is fundamental to my diet.", {"entities": [(0, 11, "LIFESTYLE")]}),
    ("I follow a diet focused on healthy food.", {"entities": [(22, 33, "LIFESTYLE")]}),
    ("My diet is centered around healthy choices.", {"entities": [(3, 14, "LIFESTYLE")]}),
    ("I've embraced healthy eating in my diet.", {"entities": [(16, 27, "LIFESTYLE")]}),
    ("Healthy food is at the core of my diet.", {"entities": [(0, 11, "LIFESTYLE")]}),
    ("I prioritize healthy food in my diet.", {"entities": [(11, 22, "LIFESTYLE")]}),
    ("My diet incorporates a lot of healthy food.", {"entities": [(3, 14, "LIFESTYLE")]}),
    ("I've structured my diet around healthy food.", {"entities": [(21, 32, "LIFESTYLE")]}),
    ("Healthy food plays a major role in my diet.", {"entities": [(0, 11, "LIFESTYLE")]}),
    ("I choose healthy food for my diet.", {"entities": [(7, 18, "LIFESTYLE")]}),
    ("My diet includes plenty of healthy food.", {"entities": [(3, 14, "LIFESTYLE")]}),
    ("I've organized my diet around healthy food.", {"entities": [(21, 32, "LIFESTYLE")]}),
    ("Healthy food is a significant part of my diet.", {"entities": [(0, 11, "LIFESTYLE")]}),
    ("I've structured my diet to include healthy food.", {"entities": [(21, 32, "LIFESTYLE")]}),
    ("My diet revolves largely around healthy food choices.", {"entities": [(3, 14, "LIFESTYLE")]}),
    ("Healthy food is essential to my dietary habits.", {"entities": [(0, 11, "LIFESTYLE")]}),
    ("I opt for healthy food options in my diet.", {"entities": [(9, 20, "LIFESTYLE")]}),
    ("My diet is primarily focused on healthy food choices.", {"entities": [(3, 14, "LIFESTYLE")]}),
    ("I aim for a balanced diet with healthy food choices.", {"entities": [(35, 46, "LIFESTYLE")]}),
    ("Healthy eating habits are central to my diet.", {"entities": [(0, 16, "LIFESTYLE")]}),
    ("I ensure that my diet is packed with healthy food choices.", {"entities": [(25, 36, "LIFESTYLE")]}),
    ("I Smoke.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I Drink socially.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("I Exercise regularly.", {"entities": [(2, 10, "LIFESTYLE")]}),
    ("I am Vegetarian.", {"entities": [(5, 15, "LIFESTYLE")]}),
    ("I am Vegan.", {"entities": [(5, 9, "LIFESTYLE")]}),
    ("I stay away from Drugs.", {"entities": [(12, 17, "LIFESTYLE")]}),
    ("Smoking helps me relax.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I enjoy a drink occasionally.", {"entities": [(2, 7, "LIFESTYLE")]}),
    ("Exercising is part of my routine.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I prefer vegetarian meals.", {"entities": [(10, 20, "LIFESTYLE")]}),
    ("Veganism is my lifestyle choice.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I've never tried drugs.", {"entities": [(15, 20, "LIFESTYLE")]}),
    ("I hate the smell of smoke.", {"entities": [(19, 24, "LIFESTYLE")]}),
    ("I don't drink alcohol.", {"entities": [(11, 17, "LIFESTYLE")]}),
    ("Exercising outdoors is refreshing.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm considering going vegetarian.", {"entities": [(14, 24, "LIFESTYLE")]}),
    ("Being vegan is more than just a diet.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("Say no to drugs.", {"entities": [(7, 12, "LIFESTYLE")]}),
    ("Smoking is bad for your health.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I only drink water.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("I can't skip my daily exercise.", {"entities": [(16, 24, "LIFESTYLE")]}),
    ("I enjoy vegetarian cooking.", {"entities": [(9, 19, "LIFESTYLE")]}),
    ("Living vegan brings me joy.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("I've never touched drugs.", {"entities": [(17, 22, "LIFESTYLE")]}),
    ("I quit smoking last year.", {"entities": [(6, 12, "LIFESTYLE")]}),
    ("I rarely drink coffee.", {"entities": [(8, 13, "LIFESTYLE")]}),
    ("Exercising in the morning wakes me up.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm exploring vegetarian recipes.", {"entities": [(12, 22, "LIFESTYLE")]}),
    ("Going vegan is a big commitment.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("Drugs destroy lives.", {"entities": [(0, 5, "LIFESTYLE")]}),
    ("I hate the taste of smoke.", {"entities": [(18, 23, "LIFESTYLE")]}),
    ("I never drink soda.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Regular exercise improves mood.", {"entities": [(8, 16, "LIFESTYLE")]}),
    ("Vegetarianism is gaining popularity.", {"entities": [(0, 12, "LIFESTYLE")]}),
    ("I've been vegan for years.", {"entities": [(10, 14, "LIFESTYLE")]}),
    ("Stay away from drugs.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Cigarette smoke bothers me.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I only drink green tea.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("Exercising with friends is fun.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm trying out vegetarianism.", {"entities": [(14, 25, "LIFESTYLE")]}),
    ("Vegan lifestyle promotes sustainability.", {"entities": [(6, 12, "LIFESTYLE")]}),
    ("Say yes to a drug-free life.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Smoking is a difficult habit to break.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I enjoy a glass of wine occasionally.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("Exercising regularly improves health.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm considering going vegetarian.", {"entities": [(14, 24, "LIFESTYLE")]}),
    ("Veganism is my lifestyle choice.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I've never tried drugs.", {"entities": [(15, 20, "LIFESTYLE")]}),
    ("I hate the smell of smoke.", {"entities": [(19, 24, "LIFESTYLE")]}),
    ("I don't drink alcohol.", {"entities": [(11, 17, "LIFESTYLE")]}),
    ("Exercising outdoors is refreshing.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm considering going vegetarian.", {"entities": [(14, 24, "LIFESTYLE")]}),
    ("Being vegan is more than just a diet.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("Say no to drugs.", {"entities": [(7, 12, "LIFESTYLE")]}),
    ("Smoking is bad for your health.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I only drink water.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("I can't skip my daily exercise.", {"entities": [(16, 24, "LIFESTYLE")]}),
    ("I enjoy vegetarian cooking.", {"entities": [(9, 19, "LIFESTYLE")]}),
    ("Living vegan brings me joy.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("I've never touched drugs.", {"entities": [(17, 22, "LIFESTYLE")]}),
    ("I quit smoking last year.", {"entities": [(6, 12, "LIFESTYLE")]}),
    ("I rarely drink coffee.", {"entities": [(8, 13, "LIFESTYLE")]}),
    ("Exercising in the morning wakes me up.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm exploring vegetarian recipes.", {"entities": [(12, 22, "LIFESTYLE")]}),
    ("Going vegan is a big commitment.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("Drugs destroy lives.", {"entities": [(0, 5, "LIFESTYLE")]}),
    ("I hate the taste of smoke.", {"entities": [(18, 23, "LIFESTYLE")]}),
    ("I never drink soda.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Regular exercise improves mood.", {"entities": [(8, 16, "LIFESTYLE")]}),
    ("Vegetarianism is gaining popularity.", {"entities": [(0, 12, "LIFESTYLE")]}),
    ("I've been vegan for years.", {"entities": [(10, 14, "LIFESTYLE")]}),
    ("Stay away from drugs.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Cigarette smoke bothers me.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I only drink green tea.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("Exercising with friends is fun.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm trying out vegetarianism.", {"entities": [(14, 25, "LIFESTYLE")]}),
    ("Vegan lifestyle promotes sustainability.", {"entities": [(6, 12, "LIFESTYLE")]}),
    ("Say yes to a drug-free life.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Smoking is a difficult habit to break.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I enjoy a glass of wine occasionally.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("Exercising regularly improves health.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm considering going vegetarian.", {"entities": [(14, 24, "LIFESTYLE")]}),
    ("Veganism is my lifestyle choice.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I've never tried drugs.", {"entities": [(15, 20, "LIFESTYLE")]}),
    ("I hate the smell of smoke.", {"entities": [(19, 24, "LIFESTYLE")]}),
    ("I don't drink alcohol.", {"entities": [(11, 17, "LIFESTYLE")]}),
    ("Exercising outdoors is refreshing.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm considering going vegetarian.", {"entities": [(14, 24, "LIFESTYLE")]}),
    ("Being vegan is more than just a diet.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("Say no to drugs.", {"entities": [(7, 12, "LIFESTYLE")]}),
    ("Smoking is bad for your health.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I only drink water.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("I can't skip my daily exercise.", {"entities": [(16, 24, "LIFESTYLE")]}),
    ("I enjoy vegetarian cooking.", {"entities": [(9, 19, "LIFESTYLE")]}),
    ("Living vegan brings me joy.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("I've never touched drugs.", {"entities": [(17, 22, "LIFESTYLE")]}),
    ("I quit smoking last year.", {"entities": [(6, 12, "LIFESTYLE")]}),
    ("I rarely drink coffee.", {"entities": [(8, 13, "LIFESTYLE")]}),
    ("Exercising in the morning wakes me up.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm exploring vegetarian recipes.", {"entities": [(12, 22, "LIFESTYLE")]}),
    ("Going vegan is a big commitment.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("Drugs destroy lives.", {"entities": [(0, 5, "LIFESTYLE")]}),
    ("I hate the taste of smoke.", {"entities": [(18, 23, "LIFESTYLE")]}),
    ("I never drink soda.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Regular exercise improves mood.", {"entities": [(8, 16, "LIFESTYLE")]}),
    ("Vegetarianism is gaining popularity.", {"entities": [(0, 12, "LIFESTYLE")]}),
    ("I've been vegan for years.", {"entities": [(10, 14, "LIFESTYLE")]}),
    ("Stay away from drugs.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Cigarette smoke bothers me.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I only drink green tea.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("Exercising with friends is fun.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm trying out vegetarianism.", {"entities": [(14, 25, "LIFESTYLE")]}),
    ("Vegan lifestyle promotes sustainability.", {"entities": [(6, 12, "LIFESTYLE")]}),
    ("Say yes to a drug-free life.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Smoking is a difficult habit to break.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I enjoy a glass of wine occasionally.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("Exercising regularly improves health.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm considering going vegetarian.", {"entities": [(14, 24, "LIFESTYLE")]}),
    ("Veganism is my lifestyle choice.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I've never tried drugs.", {"entities": [(15, 20, "LIFESTYLE")]}),
    ("I hate the smell of smoke.", {"entities": [(19, 24, "LIFESTYLE")]}),
    ("I don't drink alcohol.", {"entities": [(11, 17, "LIFESTYLE")]}),
    ("Exercising outdoors is refreshing.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm considering going vegetarian.", {"entities": [(14, 24, "LIFESTYLE")]}),
    ("Being vegan is more than just a diet.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("Say no to drugs.", {"entities": [(7, 12, "LIFESTYLE")]}),
    ("Smoking is bad for your health.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I only drink water.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("I can't skip my daily exercise.", {"entities": [(16, 24, "LIFESTYLE")]}),
    ("I enjoy vegetarian cooking.", {"entities": [(9, 19, "LIFESTYLE")]}),
    ("Living vegan brings me joy.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("I've never touched drugs.", {"entities": [(17, 22, "LIFESTYLE")]}),
    ("I quit smoking last year.", {"entities": [(6, 12, "LIFESTYLE")]}),
    ("I rarely drink coffee.", {"entities": [(8, 13, "LIFESTYLE")]}),
    ("Exercising in the morning wakes me up.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm exploring vegetarian recipes.", {"entities": [(12, 22, "LIFESTYLE")]}),
    ("Going vegan is a big commitment.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("Drugs destroy lives.", {"entities": [(0, 5, "LIFESTYLE")]}),
    ("I hate the taste of smoke.", {"entities": [(18, 23, "LIFESTYLE")]}),
    ("I never drink soda.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Regular exercise improves mood.", {"entities": [(8, 16, "LIFESTYLE")]}),
    ("Vegetarianism is gaining popularity.", {"entities": [(0, 12, "LIFESTYLE")]}),
    ("I've been vegan for years.", {"entities": [(10, 14, "LIFESTYLE")]}),
    ("Stay away from drugs.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Cigarette smoke bothers me.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I only drink green tea.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("Exercising with friends is fun.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm trying out vegetarianism.", {"entities": [(14, 25, "LIFESTYLE")]}),
    ("Vegan lifestyle promotes sustainability.", {"entities": [(6, 12, "LIFESTYLE")]}),
    ("Say yes to a drug-free life.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Smoking is a difficult habit to break.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I enjoy a glass of wine occasionally.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("Exercising regularly improves health.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm considering going vegetarian.", {"entities": [(14, 24, "LIFESTYLE")]}),
    ("Veganism is my lifestyle choice.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I've never tried drugs.", {"entities": [(15, 20, "LIFESTYLE")]}),
    ("I hate the smell of smoke.", {"entities": [(19, 24, "LIFESTYLE")]}),
    ("I don't drink alcohol.", {"entities": [(11, 17, "LIFESTYLE")]}),
    ("Exercising outdoors is refreshing.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm considering going vegetarian.", {"entities": [(14, 24, "LIFESTYLE")]}),
    ("Being vegan is more than just a diet.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("Say no to drugs.", {"entities": [(7, 12, "LIFESTYLE")]}),
    ("Smoking is bad for your health.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I only drink water.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("I can't skip my daily exercise.", {"entities": [(16, 24, "LIFESTYLE")]}),
    ("I enjoy vegetarian cooking.", {"entities": [(9, 19, "LIFESTYLE")]}),
    ("Living vegan brings me joy.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("I've never touched drugs.", {"entities": [(17, 22, "LIFESTYLE")]}),
    ("I quit smoking last year.", {"entities": [(6, 12, "LIFESTYLE")]}),
    ("I rarely drink coffee.", {"entities": [(8, 13, "LIFESTYLE")]}),
    ("Exercising in the morning wakes me up.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm exploring vegetarian recipes.", {"entities": [(12, 22, "LIFESTYLE")]}),
    ("Going vegan is a big commitment.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("Drugs destroy lives.", {"entities": [(0, 5, "LIFESTYLE")]}),
    ("I hate the taste of smoke.", {"entities": [(18, 23, "LIFESTYLE")]}),
    ("I never drink soda.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Regular exercise improves mood.", {"entities": [(8, 16, "LIFESTYLE")]}),
    ("Vegetarianism is gaining popularity.", {"entities": [(0, 12, "LIFESTYLE")]}),
    ("I've been vegan for years.", {"entities": [(10, 14, "LIFESTYLE")]}),
    ("Stay away from drugs.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Cigarette smoke bothers me.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I only drink green tea.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("Exercising with friends is fun.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm trying out vegetarianism.", {"entities": [(14, 25, "LIFESTYLE")]}),
    ("Vegan lifestyle promotes sustainability.", {"entities": [(6, 12, "LIFESTYLE")]}),
    ("Say yes to a drug-free life.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Smoking is a difficult habit to break.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I enjoy a glass of wine occasionally.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("Exercising regularly improves health.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm considering going vegetarian.", {"entities": [(14, 24, "LIFESTYLE")]}),
    ("Veganism is my lifestyle choice.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I've never tried drugs.", {"entities": [(15, 20, "LIFESTYLE")]}),
    ("I hate the smell of smoke.", {"entities": [(19, 24, "LIFESTYLE")]}),
    ("I don't drink alcohol.", {"entities": [(11, 17, "LIFESTYLE")]}),
    ("Exercising outdoors is refreshing.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm considering going vegetarian.", {"entities": [(14, 24, "LIFESTYLE")]}),
    ("Being vegan is more than just a diet.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("Say no to drugs.", {"entities": [(7, 12, "LIFESTYLE")]}),
    ("Smoking is bad for your health.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I only drink water.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("I can't skip my daily exercise.", {"entities": [(16, 24, "LIFESTYLE")]}),
    ("I enjoy vegetarian cooking.", {"entities": [(9, 19, "LIFESTYLE")]}),
    ("Living vegan brings me joy.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("I've never touched drugs.", {"entities": [(17, 22, "LIFESTYLE")]}),
    ("I quit smoking last year.", {"entities": [(6, 12, "LIFESTYLE")]}),
    ("I rarely drink coffee.", {"entities": [(8, 13, "LIFESTYLE")]}),
    ("Exercising in the morning wakes me up.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm exploring vegetarian recipes.", {"entities": [(12, 22, "LIFESTYLE")]}),
    ("Going vegan is a big commitment.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("Drugs destroy lives.", {"entities": [(0, 5, "LIFESTYLE")]}),
    ("I hate the taste of smoke.", {"entities": [(18, 23, "LIFESTYLE")]}),
    ("I never drink soda.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Regular exercise improves mood.", {"entities": [(8, 16, "LIFESTYLE")]}),
    ("Vegetarianism is gaining popularity.", {"entities": [(0, 12, "LIFESTYLE")]}),
    ("I've been vegan for years.", {"entities": [(10, 14, "LIFESTYLE")]}),
    ("Stay away from drugs.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Cigarette smoke bothers me.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I only drink green tea.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("Exercising with friends is fun.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm trying out vegetarianism.", {"entities": [(14, 25, "LIFESTYLE")]}),
    ("Vegan lifestyle promotes sustainability.", {"entities": [(6, 12, "LIFESTYLE")]}),
    ("Say yes to a drug-free life.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Smoking is a difficult habit to break.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I enjoy a glass of wine occasionally.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("Exercising regularly improves health.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm considering going vegetarian.", {"entities": [(14, 24, "LIFESTYLE")]}),
    ("Veganism is my lifestyle choice.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I've never tried drugs.", {"entities": [(15, 20, "LIFESTYLE")]}),
    ("I hate the smell of smoke.", {"entities": [(19, 24, "LIFESTYLE")]}),
    ("I don't drink alcohol.", {"entities": [(11, 17, "LIFESTYLE")]}),
    ("Exercising outdoors is refreshing.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm considering going vegetarian.", {"entities": [(14, 24, "LIFESTYLE")]}),
    ("Being vegan is more than just a diet.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("Say no to drugs.", {"entities": [(7, 12, "LIFESTYLE")]}),
    ("Smoking is bad for your health.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I only drink water.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("I can't skip my daily exercise.", {"entities": [(16, 24, "LIFESTYLE")]}),
    ("I enjoy vegetarian cooking.", {"entities": [(9, 19, "LIFESTYLE")]}),
    ("Living vegan brings me joy.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("I've never touched drugs.", {"entities": [(17, 22, "LIFESTYLE")]}),
    ("I quit smoking last year.", {"entities": [(6, 12, "LIFESTYLE")]}),
    ("I rarely drink coffee.", {"entities": [(8, 13, "LIFESTYLE")]}),
    ("Exercising in the morning wakes me up.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm exploring vegetarian recipes.", {"entities": [(12, 22, "LIFESTYLE")]}),
    ("Going vegan is a big commitment.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("Drugs destroy lives.", {"entities": [(0, 5, "LIFESTYLE")]}),
    ("I hate the taste of smoke.", {"entities": [(18, 23, "LIFESTYLE")]}),
    ("I never drink soda.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Regular exercise improves mood.", {"entities": [(8, 16, "LIFESTYLE")]}),
    ("Vegetarianism is gaining popularity.", {"entities": [(0, 12, "LIFESTYLE")]}),
    ("I've been vegan for years.", {"entities": [(10, 14, "LIFESTYLE")]}),
    ("Stay away from drugs.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Cigarette smoke bothers me.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I only drink green tea.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("Exercising with friends is fun.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm trying out vegetarianism.", {"entities": [(14, 25, "LIFESTYLE")]}),
    ("Vegan lifestyle promotes sustainability.", {"entities": [(6, 12, "LIFESTYLE")]}),
    ("Say yes to a drug-free life.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Smoking is a difficult habit to break.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I enjoy a glass of wine occasionally.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("Exercising regularly improves health.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm considering going vegetarian.", {"entities": [(14, 24, "LIFESTYLE")]}),
    ("Veganism is my lifestyle choice.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I've never tried drugs.", {"entities": [(15, 20, "LIFESTYLE")]}),
    ("I hate the smell of smoke.", {"entities": [(19, 24, "LIFESTYLE")]}),
    ("I don't drink alcohol.", {"entities": [(11, 17, "LIFESTYLE")]}),
    ("Exercising outdoors is refreshing.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm considering going vegetarian.", {"entities": [(14, 24, "LIFESTYLE")]}),
    ("Being vegan is more than just a diet.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("Say no to drugs.", {"entities": [(7, 12, "LIFESTYLE")]}),
    ("Smoking is bad for your health.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I only drink water.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("I can't skip my daily exercise.", {"entities": [(16, 24, "LIFESTYLE")]}),
    ("I enjoy vegetarian cooking.", {"entities": [(9, 19, "LIFESTYLE")]}),
    ("Living vegan brings me joy.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("I've never touched drugs.", {"entities": [(17, 22, "LIFESTYLE")]}),
    ("I quit smoking last year.", {"entities": [(6, 12, "LIFESTYLE")]}),
    ("I rarely drink coffee.", {"entities": [(8, 13, "LIFESTYLE")]}),
    ("Exercising in the morning wakes me up.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm exploring vegetarian recipes.", {"entities": [(12, 22, "LIFESTYLE")]}),
    ("Going vegan is a big commitment.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("Drugs destroy lives.", {"entities": [(0, 5, "LIFESTYLE")]}),
    ("I hate the taste of smoke.", {"entities": [(18, 23, "LIFESTYLE")]}),
    ("I never drink soda.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Regular exercise improves mood.", {"entities": [(8, 16, "LIFESTYLE")]}),
    ("Vegetarianism is gaining popularity.", {"entities": [(0, 12, "LIFESTYLE")]}),
    ("I've been vegan for years.", {"entities": [(10, 14, "LIFESTYLE")]}),
    ("Stay away from drugs.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Cigarette smoke bothers me.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I only drink green tea.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("Exercising with friends is fun.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm trying out vegetarianism.", {"entities": [(14, 25, "LIFESTYLE")]}),
    ("Vegan lifestyle promotes sustainability.", {"entities": [(6, 12, "LIFESTYLE")]}),
    ("Say yes to a drug-free life.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Smoking is a difficult habit to break.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I enjoy a glass of wine occasionally.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("Exercising regularly improves health.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm considering going vegetarian.", {"entities": [(14, 24, "LIFESTYLE")]}),
    ("Veganism is my lifestyle choice.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I've never tried drugs.", {"entities": [(15, 20, "LIFESTYLE")]}),
    ("I hate the smell of smoke.", {"entities": [(19, 24, "LIFESTYLE")]}),
    ("I don't drink alcohol.", {"entities": [(11, 17, "LIFESTYLE")]}),
    ("Exercising outdoors is refreshing.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm considering going vegetarian.", {"entities": [(14, 24, "LIFESTYLE")]}),
    ("Being vegan is more than just a diet.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("Say no to drugs.", {"entities": [(7, 12, "LIFESTYLE")]}),
    ("Smoking is bad for your health.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I only drink water.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("I can't skip my daily exercise.", {"entities": [(16, 24, "LIFESTYLE")]}),
    ("I enjoy vegetarian cooking.", {"entities": [(9, 19, "LIFESTYLE")]}),
    ("Living vegan brings me joy.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("I've never touched drugs.", {"entities": [(17, 22, "LIFESTYLE")]}),
    ("I quit smoking last year.", {"entities": [(6, 12, "LIFESTYLE")]}),
    ("I rarely drink coffee.", {"entities": [(8, 13, "LIFESTYLE")]}),
    ("Exercising in the morning wakes me up.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm exploring vegetarian recipes.", {"entities": [(12, 22, "LIFESTYLE")]}),
    ("Going vegan is a big commitment.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("Drugs destroy lives.", {"entities": [(0, 5, "LIFESTYLE")]}),
    ("I hate the taste of smoke.", {"entities": [(18, 23, "LIFESTYLE")]}),
    ("I never drink soda.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Regular exercise improves mood.", {"entities": [(8, 16, "LIFESTYLE")]}),
    ("Vegetarianism is gaining popularity.", {"entities": [(0, 12, "LIFESTYLE")]}),
    ("I've been vegan for years.", {"entities": [(10, 14, "LIFESTYLE")]}),
    ("Stay away from drugs.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Cigarette smoke bothers me.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I only drink green tea.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("Exercising with friends is fun.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm trying out vegetarianism.", {"entities": [(14, 25, "LIFESTYLE")]}),
    ("Vegan lifestyle promotes sustainability.", {"entities": [(6, 12, "LIFESTYLE")]}),
    ("Say yes to a drug-free life.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Smoking is a difficult habit to break.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I enjoy a glass of wine occasionally.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("Exercising regularly improves health.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm considering going vegetarian.", {"entities": [(14, 24, "LIFESTYLE")]}),
    ("Veganism is my lifestyle choice.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I've never tried drugs.", {"entities": [(15, 20, "LIFESTYLE")]}),
    ("I hate the smell of smoke.", {"entities": [(19, 24, "LIFESTYLE")]}),
    ("I don't drink alcohol.", {"entities": [(11, 17, "LIFESTYLE")]}),
    ("Exercising outdoors is refreshing.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm considering going vegetarian.", {"entities": [(14, 24, "LIFESTYLE")]}),
    ("Being vegan is more than just a diet.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("Say no to drugs.", {"entities": [(7, 12, "LIFESTYLE")]}),
    ("Smoking is bad for your health.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I only drink water.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("I can't skip my daily exercise.", {"entities": [(16, 24, "LIFESTYLE")]}),
    ("I enjoy vegetarian cooking.", {"entities": [(9, 19, "LIFESTYLE")]}),
    ("Living vegan brings me joy.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("I've never touched drugs.", {"entities": [(17, 22, "LIFESTYLE")]}),
    ("I quit smoking last year.", {"entities": [(6, 12, "LIFESTYLE")]}),
    ("I rarely drink coffee.", {"entities": [(8, 13, "LIFESTYLE")]}),
    ("Exercising in the morning wakes me up.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm exploring vegetarian recipes.", {"entities": [(12, 22, "LIFESTYLE")]}),
    ("Going vegan is a big commitment.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("Drugs destroy lives.", {"entities": [(0, 5, "LIFESTYLE")]}),
    ("I hate the taste of smoke.", {"entities": [(18, 23, "LIFESTYLE")]}),
    ("I never drink soda.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Regular exercise improves mood.", {"entities": [(8, 16, "LIFESTYLE")]}),
    ("Vegetarianism is gaining popularity.", {"entities": [(0, 12, "LIFESTYLE")]}),
    ("I've been vegan for years.", {"entities": [(10, 14, "LIFESTYLE")]}),
    ("Stay away from drugs.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Cigarette smoke bothers me.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I only drink green tea.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("Exercising with friends is fun.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm trying out vegetarianism.", {"entities": [(14, 25, "LIFESTYLE")]}),
    ("Vegan lifestyle promotes sustainability.", {"entities": [(6, 12, "LIFESTYLE")]}),
    ("Say yes to a drug-free life.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Smoking is a difficult habit to break.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I enjoy a glass of wine occasionally.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("Exercising regularly improves health.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm considering going vegetarian.", {"entities": [(14, 24, "LIFESTYLE")]}),
    ("Veganism is my lifestyle choice.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I've never tried drugs.", {"entities": [(15, 20, "LIFESTYLE")]}),
    ("I hate the smell of smoke.", {"entities": [(19, 24, "LIFESTYLE")]}),
    ("I don't drink alcohol.", {"entities": [(11, 17, "LIFESTYLE")]}),
    ("Exercising outdoors is refreshing.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm considering going vegetarian.", {"entities": [(14, 24, "LIFESTYLE")]}),
    ("Being vegan is more than just a diet.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("Say no to drugs.", {"entities": [(7, 12, "LIFESTYLE")]}),
    ("Smoking is bad for your health.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I only drink water.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("I can't skip my daily exercise.", {"entities": [(16, 24, "LIFESTYLE")]}),
    ("I enjoy vegetarian cooking.", {"entities": [(9, 19, "LIFESTYLE")]}),
    ("Living vegan brings me joy.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("I've never touched drugs.", {"entities": [(17, 22, "LIFESTYLE")]}),
    ("I quit smoking last year.", {"entities": [(6, 12, "LIFESTYLE")]}),
    ("I rarely drink coffee.", {"entities": [(8, 13, "LIFESTYLE")]}),
    ("Exercising in the morning wakes me up.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm exploring vegetarian recipes.", {"entities": [(12, 22, "LIFESTYLE")]}),
    ("Going vegan is a big commitment.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("Drugs destroy lives.", {"entities": [(0, 5, "LIFESTYLE")]}),
    ("I hate the taste of smoke.", {"entities": [(18, 23, "LIFESTYLE")]}),
    ("I never drink soda.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Regular exercise improves mood.", {"entities": [(8, 16, "LIFESTYLE")]}),
    ("Vegetarianism is gaining popularity.", {"entities": [(0, 12, "LIFESTYLE")]}),
    ("I've been vegan for years.", {"entities": [(10, 14, "LIFESTYLE")]}),
    ("Stay away from drugs.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Cigarette smoke bothers me.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I only drink green tea.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("Exercising with friends is fun.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm trying out vegetarianism.", {"entities": [(14, 25, "LIFESTYLE")]}),
    ("Vegan lifestyle promotes sustainability.", {"entities": [(6, 12, "LIFESTYLE")]}),
    ("Say yes to a drug-free life.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Smoking is a difficult habit to break.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I enjoy a glass of wine occasionally.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("Exercising regularly improves health.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm considering going vegetarian.", {"entities": [(14, 24, "LIFESTYLE")]}),
    ("Veganism is my lifestyle choice.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I've never tried drugs.", {"entities": [(15, 20, "LIFESTYLE")]}),
    ("I hate the smell of smoke.", {"entities": [(19, 24, "LIFESTYLE")]}),
    ("I don't drink alcohol.", {"entities": [(11, 17, "LIFESTYLE")]}),
    ("Exercising outdoors is refreshing.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm considering going vegetarian.", {"entities": [(14, 24, "LIFESTYLE")]}),
    ("Being vegan is more than just a diet.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("Say no to drugs.", {"entities": [(7, 12, "LIFESTYLE")]}),
    ("Smoking is bad for your health.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I only drink water.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("I can't skip my daily exercise.", {"entities": [(16, 24, "LIFESTYLE")]}),
    ("I enjoy vegetarian cooking.", {"entities": [(9, 19, "LIFESTYLE")]}),
    ("Living vegan brings me joy.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("I've never touched drugs.", {"entities": [(17, 22, "LIFESTYLE")]}),
    ("I quit smoking last year.", {"entities": [(6, 12, "LIFESTYLE")]}),
    ("I rarely drink coffee.", {"entities": [(8, 13, "LIFESTYLE")]}),
    ("Exercising in the morning wakes me up.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm exploring vegetarian recipes.", {"entities": [(12, 22, "LIFESTYLE")]}),
    ("Going vegan is a big commitment.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("Drugs destroy lives.", {"entities": [(0, 5, "LIFESTYLE")]}),
    ("I hate the taste of smoke.", {"entities": [(18, 23, "LIFESTYLE")]}),
    ("I never drink soda.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Regular exercise improves mood.", {"entities": [(8, 16, "LIFESTYLE")]}),
    ("Vegetarianism is gaining popularity.", {"entities": [(0, 12, "LIFESTYLE")]}),
    ("I've been vegan for years.", {"entities": [(10, 14, "LIFESTYLE")]}),
    ("Stay away from drugs.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Cigarette smoke bothers me.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I only drink green tea.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("Exercising with friends is fun.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm trying out vegetarianism.", {"entities": [(14, 25, "LIFESTYLE")]}),
    ("Vegan lifestyle promotes sustainability.", {"entities": [(6, 12, "LIFESTYLE")]}),
    ("Say yes to a drug-free life.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Smoking is a difficult habit to break.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I enjoy a glass of wine occasionally.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("Exercising regularly improves health.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm considering going vegetarian.", {"entities": [(14, 24, "LIFESTYLE")]}),
    ("Veganism is my lifestyle choice.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I've never tried drugs.", {"entities": [(15, 20, "LIFESTYLE")]}),
    ("I hate the smell of smoke.", {"entities": [(19, 24, "LIFESTYLE")]}),
    ("I don't drink alcohol.", {"entities": [(11, 17, "LIFESTYLE")]}),
    ("Exercising outdoors is refreshing.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm considering going vegetarian.", {"entities": [(14, 24, "LIFESTYLE")]}),
    ("Being vegan is more than just a diet.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("Say no to drugs.", {"entities": [(7, 12, "LIFESTYLE")]}),
    ("Smoking is bad for your health.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I only drink water.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("I can't skip my daily exercise.", {"entities": [(16, 24, "LIFESTYLE")]}),
    ("I enjoy vegetarian cooking.", {"entities": [(9, 19, "LIFESTYLE")]}),
    ("Living vegan brings me joy.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("I've never touched drugs.", {"entities": [(17, 22, "LIFESTYLE")]}),
    ("I quit smoking last year.", {"entities": [(6, 12, "LIFESTYLE")]}),
    ("I rarely drink coffee.", {"entities": [(8, 13, "LIFESTYLE")]}),
    ("Exercising in the morning wakes me up.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm exploring vegetarian recipes.", {"entities": [(12, 22, "LIFESTYLE")]}),
    ("Going vegan is a big commitment.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("Drugs destroy lives.", {"entities": [(0, 5, "LIFESTYLE")]}),
    ("I hate the taste of smoke.", {"entities": [(18, 23, "LIFESTYLE")]}),
    ("I never drink soda.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Regular exercise improves mood.", {"entities": [(8, 16, "LIFESTYLE")]}),
    ("Vegetarianism is gaining popularity.", {"entities": [(0, 12, "LIFESTYLE")]}),
    ("I've been vegan for years.", {"entities": [(10, 14, "LIFESTYLE")]}),
    ("Stay away from drugs.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Cigarette smoke bothers me.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I only drink green tea.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("Exercising with friends is fun.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm trying out vegetarianism.", {"entities": [(14, 25, "LIFESTYLE")]}),
    ("Vegan lifestyle promotes sustainability.", {"entities": [(6, 12, "LIFESTYLE")]}),
    ("Say yes to a drug-free life.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Smoking is a difficult habit to break.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I enjoy a glass of wine occasionally.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("Exercising regularly improves health.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm considering going vegetarian.", {"entities": [(14, 24, "LIFESTYLE")]}),
    ("Veganism is my lifestyle choice.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I've never tried drugs.", {"entities": [(15, 20, "LIFESTYLE")]}),
    ("I hate the smell of smoke.", {"entities": [(19, 24, "LIFESTYLE")]}),
    ("I don't drink alcohol.", {"entities": [(11, 17, "LIFESTYLE")]}),
    ("Exercising outdoors is refreshing.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm considering going vegetarian.", {"entities": [(14, 24, "LIFESTYLE")]}),
    ("Being vegan is more than just a diet.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("Say no to drugs.", {"entities": [(7, 12, "LIFESTYLE")]}),
    ("Smoking is bad for your health.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I only drink water.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("I can't skip my daily exercise.", {"entities": [(16, 24, "LIFESTYLE")]}),
    ("I enjoy vegetarian cooking.", {"entities": [(9, 19, "LIFESTYLE")]}),
    ("Living vegan brings me joy.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("I've never touched drugs.", {"entities": [(17, 22, "LIFESTYLE")]}),
    ("I quit smoking last year.", {"entities": [(6, 12, "LIFESTYLE")]}),
    ("I rarely drink coffee.", {"entities": [(8, 13, "LIFESTYLE")]}),
    ("Exercising in the morning wakes me up.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm exploring vegetarian recipes.", {"entities": [(12, 22, "LIFESTYLE")]}),
    ("Going vegan is a big commitment.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("Drugs destroy lives.", {"entities": [(0, 5, "LIFESTYLE")]}),
    ("I hate the taste of smoke.", {"entities": [(18, 23, "LIFESTYLE")]}),
    ("I never drink soda.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Regular exercise improves mood.", {"entities": [(8, 16, "LIFESTYLE")]}),
    ("Vegetarianism is gaining popularity.", {"entities": [(0, 12, "LIFESTYLE")]}),
    ("I've been vegan for years.", {"entities": [(10, 14, "LIFESTYLE")]}),
    ("Stay away from drugs.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Cigarette smoke bothers me.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I only drink green tea.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("Exercising with friends is fun.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm trying out vegetarianism.", {"entities": [(14, 25, "LIFESTYLE")]}),
    ("Vegan lifestyle promotes sustainability.", {"entities": [(6, 12, "LIFESTYLE")]}),
    ("Say yes to a drug-free life.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Smoking is a difficult habit to break.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I enjoy a glass of wine occasionally.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("Exercising regularly improves health.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm considering going vegetarian.", {"entities": [(14, 24, "LIFESTYLE")]}),
    ("Veganism is my lifestyle choice.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I've never tried drugs.", {"entities": [(15, 20, "LIFESTYLE")]}),
    ("I hate the smell of smoke.", {"entities": [(19, 24, "LIFESTYLE")]}),
    ("I don't drink alcohol.", {"entities": [(11, 17, "LIFESTYLE")]}),
    ("Exercising outdoors is refreshing.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm considering going vegetarian.", {"entities": [(14, 24, "LIFESTYLE")]}),
    ("Being vegan is more than just a diet.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("Say no to drugs.", {"entities": [(7, 12, "LIFESTYLE")]}),
    ("Smoking is bad for your health.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I only drink water.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("I can't skip my daily exercise.", {"entities": [(16, 24, "LIFESTYLE")]}),
    ("I enjoy vegetarian cooking.", {"entities": [(9, 19, "LIFESTYLE")]}),
    ("Living vegan brings me joy.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("I've never touched drugs.", {"entities": [(17, 22, "LIFESTYLE")]}),
    ("I quit smoking last year.", {"entities": [(6, 12, "LIFESTYLE")]}),
    ("I rarely drink coffee.", {"entities": [(8, 13, "LIFESTYLE")]}),
    ("Exercising in the morning wakes me up.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm exploring vegetarian recipes.", {"entities": [(12, 22, "LIFESTYLE")]}),
    ("Going vegan is a big commitment.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("Drugs destroy lives.", {"entities": [(0, 5, "LIFESTYLE")]}),
    ("I hate the taste of smoke.", {"entities": [(18, 23, "LIFESTYLE")]}),
    ("I never drink soda.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Regular exercise improves mood.", {"entities": [(8, 16, "LIFESTYLE")]}),
    ("Vegetarianism is gaining popularity.", {"entities": [(0, 12, "LIFESTYLE")]}),
    ("I've been vegan for years.", {"entities": [(10, 14, "LIFESTYLE")]}),
    ("Stay away from drugs.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Cigarette smoke bothers me.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I only drink green tea.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("Exercising with friends is fun.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm trying out vegetarianism.", {"entities": [(14, 25, "LIFESTYLE")]}),
    ("Vegan lifestyle promotes sustainability.", {"entities": [(6, 12, "LIFESTYLE")]}),
    ("Say yes to a drug-free life.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Smoking is a difficult habit to break.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I enjoy a glass of wine occasionally.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("Exercising regularly improves health.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm considering going vegetarian.", {"entities": [(14, 24, "LIFESTYLE")]}),
    ("Veganism is my lifestyle choice.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I've never tried drugs.", {"entities": [(15, 20, "LIFESTYLE")]}),
    ("I hate the smell of smoke.", {"entities": [(19, 24, "LIFESTYLE")]}),
    ("I don't drink alcohol.", {"entities": [(11, 17, "LIFESTYLE")]}),
    ("Exercising outdoors is refreshing.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm considering going vegetarian.", {"entities": [(14, 24, "LIFESTYLE")]}),
    ("Being vegan is more than just a diet.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("Say no to drugs.", {"entities": [(7, 12, "LIFESTYLE")]}),
    ("Smoking is bad for your health.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I only drink water.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("I can't skip my daily exercise.", {"entities": [(16, 24, "LIFESTYLE")]}),
    ("I enjoy vegetarian cooking.", {"entities": [(9, 19, "LIFESTYLE")]}),
    ("Living vegan brings me joy.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("I've never touched drugs.", {"entities": [(17, 22, "LIFESTYLE")]}),
    ("I quit smoking last year.", {"entities": [(6, 12, "LIFESTYLE")]}),
    ("I rarely drink coffee.", {"entities": [(8, 13, "LIFESTYLE")]}),
    ("Exercising in the morning wakes me up.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm exploring vegetarian recipes.", {"entities": [(12, 22, "LIFESTYLE")]}),
    ("Going vegan is a big commitment.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("Drugs destroy lives.", {"entities": [(0, 5, "LIFESTYLE")]}),
    ("I hate the taste of smoke.", {"entities": [(18, 23, "LIFESTYLE")]}),
    ("I never drink soda.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Regular exercise improves mood.", {"entities": [(8, 16, "LIFESTYLE")]}),
    ("Vegetarianism is gaining popularity.", {"entities": [(0, 12, "LIFESTYLE")]}),
    ("I've been vegan for years.", {"entities": [(10, 14, "LIFESTYLE")]}),
    ("Stay away from drugs.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Cigarette smoke bothers me.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I only drink green tea.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("Exercising with friends is fun.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm trying out vegetarianism.", {"entities": [(14, 25, "LIFESTYLE")]}),
    ("Vegan lifestyle promotes sustainability.", {"entities": [(6, 12, "LIFESTYLE")]}),
    ("Say yes to a drug-free life.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Smoking is a difficult habit to break.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I enjoy a glass of wine occasionally.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("Exercising regularly improves health.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm considering going vegetarian.", {"entities": [(14, 24, "LIFESTYLE")]}),
    ("Veganism is my lifestyle choice.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I've never tried drugs.", {"entities": [(15, 20, "LIFESTYLE")]}),
    ("I hate the smell of smoke.", {"entities": [(19, 24, "LIFESTYLE")]}),
    ("I don't drink alcohol.", {"entities": [(11, 17, "LIFESTYLE")]}),
    ("Exercising outdoors is refreshing.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm considering going vegetarian.", {"entities": [(14, 24, "LIFESTYLE")]}),
    ("Being vegan is more than just a diet.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("Say no to drugs.", {"entities": [(7, 12, "LIFESTYLE")]}),
    ("Smoking is bad for your health.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I only drink water.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("I can't skip my daily exercise.", {"entities": [(16, 24, "LIFESTYLE")]}),
    ("I enjoy vegetarian cooking.", {"entities": [(9, 19, "LIFESTYLE")]}),
    ("Living vegan brings me joy.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("I've never touched drugs.", {"entities": [(17, 22, "LIFESTYLE")]}),
    ("I quit smoking last year.", {"entities": [(6, 12, "LIFESTYLE")]}),
    ("I rarely drink coffee.", {"entities": [(8, 13, "LIFESTYLE")]}),
    ("Exercising in the morning wakes me up.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm exploring vegetarian recipes.", {"entities": [(12, 22, "LIFESTYLE")]}),
    ("Going vegan is a big commitment.", {"entities": [(6, 10, "LIFESTYLE")]}),
    ("Drugs destroy lives.", {"entities": [(0, 5, "LIFESTYLE")]}),
    ("I hate the taste of smoke.", {"entities": [(18, 23, "LIFESTYLE")]}),
    ("I never drink soda.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Regular exercise improves mood.", {"entities": [(8, 16, "LIFESTYLE")]}),
    ("Vegetarianism is gaining popularity.", {"entities": [(0, 12, "LIFESTYLE")]}),
    ("I've been vegan for years.", {"entities": [(10, 14, "LIFESTYLE")]}),
    ("Stay away from drugs.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Cigarette smoke bothers me.", {"entities": [(11, 16, "LIFESTYLE")]}),
    ("I only drink green tea.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("Exercising with friends is fun.", {"entities": [(0, 10, "LIFESTYLE")]}),
    ("I'm trying out vegetarianism.", {"entities": [(14, 25, "LIFESTYLE")]}),
    ("Vegan lifestyle promotes sustainability.", {"entities": [(6, 12, "LIFESTYLE")]}),
    ("Say yes to a drug-free life.", {"entities": [(10, 15, "LIFESTYLE")]}),
    ("Smoking is a difficult habit to break.", {"entities": [(0, 7, "LIFESTYLE")]}),
    ("I enjoy a glass of wine occasionally.", {"entities": [(9, 14, "LIFESTYLE")]}),
    ("Exercising regularly improves health.", {"entities": [(0, 10, "LIFESTYLE")]}),
("The sky is blue.", {"entities": []}),
    ("I enjoy playing the guitar.", {"entities": []}),
    ("She runs every morning.", {"entities": []}),
    ("Cooking is an art form.", {"entities": []}),
    ("He likes to read science fiction novels.", {"entities": []}),
    ("The flowers bloom in spring.", {"entities": []}),
    ("Hiking in the mountains is exhilarating.", {"entities": []}),
    ("Music brings people together.", {"entities": []}),
    ("They celebrate birthdays with cake.", {"entities": []}),
    ("Learning new skills is challenging.", {"entities": []}),
    ("The train arrives at 9 AM.", {"entities": []}),
    ("I prefer tea over coffee.", {"entities": []}),
    ("The cat purrs when petted.", {"entities": []}),
    ("Driving in traffic can be stressful.", {"entities": []}),
    ("I like to watch documentaries.", {"entities": []}),
    ("The smell of freshly cut grass is pleasant.", {"entities": []}),
    ("She practices yoga for relaxation.", {"entities": []}),
    ("Artists express themselves through their work.", {"entities": []}),
    ("Reading under a cozy blanket is comforting.", {"entities": []}),
    ("He enjoys fishing by the lake.", {"entities": []}),
    ("Rainbows appear after a rainstorm.", {"entities": []}),
    ("The sound of laughter fills the room.", {"entities": []}),
    ("She bakes cookies for her friends.", {"entities": []}),
    ("The city lights shine brightly at night.", {"entities": []}),
    ("He takes photographs as a hobby.", {"entities": []}),
    ("Writing poetry is a creative outlet.", {"entities": []}),
    ("They take walks in the park.", {"entities": []}),
    ("Exploring new places is exciting.", {"entities": []}),
    ("The clock ticks rhythmically on the wall.", {"entities": []}),
    ("She practices meditation for inner peace.", {"entities": []}),
    ("Gardens are filled with colorful flowers.", {"entities": []}),
    ("The smell of coffee fills the kitchen.", {"entities": []}),
    ("They go swimming at the beach.", {"entities": []}),
    ("Drawing is a form of self-expression.", {"entities": []}),
    ("He enjoys watching sports on TV.", {"entities": []}),
    ("Birds chirp in the trees.", {"entities": []}),
    ("She volunteers at the local shelter.", {"entities": []}),
    ("The sun sets in the evening sky.", {"entities": []}),
    ("He practices martial arts for discipline.", {"entities": []}),
    ("Candles flicker in the dark room.", {"entities": []}),
    ("She enjoys picnics in the park.", {"entities": []}),
    ("The smell of rain is refreshing.", {"entities": []}),
    ("They go for bike rides on weekends.", {"entities": []}),
    ("Cooking with fresh herbs enhances flavor.", {"entities": []}),
    ("He plays the piano for relaxation.", {"entities": []}),
    ("The stars twinkle in the night sky.", {"entities": []}),
    ("She collects seashells on the beach.", {"entities": []}),
    ("The smell of cinnamon fills the air.", {"entities": []}),
    ("They watch the sunrise together.", {"entities": []}),
    ("Painting landscapes is a hobby.", {"entities": []}),
    ("He enjoys stargazing on clear nights.", {"entities": []}),
    ("The smell of roses is intoxicating.", {"entities": []}),
    ("She enjoys gardening in her spare time.", {"entities": []}),
    ("He listens to music while studying.", {"entities": []}),
    ("Watching the sunset is a peaceful experience.", {"entities": []}),
    ("They go camping in the mountains.", {"entities": []}),
    ("The sound of waves crashing is relaxing.", {"entities": []}),
    ("She practices mindfulness for mental clarity.", {"entities": []}),
    ("He enjoys building model airplanes.", {"entities": []}),
    ("The smell of pine trees fills the forest.", {"entities": []}),
    ("They go for long walks in nature.", {"entities": []}),
    ("She enjoys knitting as a hobby.", {"entities": []}),
    ("The sound of crickets fills the night.", {"entities": []}),
    ("He takes photographs of nature.", {"entities": []}),
    ("She enjoys collecting vintage records.", {"entities": []}),
    ("The smell of fresh laundry is comforting.", {"entities": []}),
    ("They enjoy picnics by the lake.", {"entities": []}),
    ("He practices calligraphy for relaxation.", {"entities": []}),
    ("Watching thunderstorms is exciting.", {"entities": []}),
    ("She enjoys birdwatching in the park.", {"entities": []}),
    ("The smell of barbecue fills the backyard.", {"entities": []}),
    ("They go on road trips to explore new places.", {"entities": []}),
    ("He enjoys sculpting as a creative outlet.", {"entities": []}),
    ("The sound of birdsong fills the morning.", {"entities": []}),
    ("She practices tai chi for balance.", {"entities": []}),
    ("They go for hikes in the wilderness.", {"entities": []}),
    ("He enjoys playing board games with friends.", {"entities": []}),
    ("The smell of fresh bread is irresistible.", {"entities": []}),
    ("They watch movies together on weekends.", {"entities": []}),
    ("She enjoys embroidery as a hobby.", {"entities": []}),
    ("The sound of rain tapping on the roof is calming.", {"entities": []}),
    ("He collects stamps as a hobby.", {"entities": []}),
    ("She enjoys horseback riding in the countryside.", {"entities": []}),
    ("The smell of chocolate chip cookies baking is heavenly.", {"entities": []}),
    ("They go kayaking on the river.", {"entities": []}),
    ("He practices photography as a hobby.", {"entities": []}),
    ("The sound of wind rustling through the trees is soothing.", {"entities": []}),
    ("She enjoys pottery as a creative outlet.", {"entities": []}),
    ("They go for walks in the snow.", {"entities": []}),
    ("He enjoys reading comic books in his free time.", {"entities": []}),
    ("The smell of freshly brewed coffee is invigorating.", {"entities": []}),
    ("They go ice skating at the rink.", {"entities": []}),
    ("She practices mindfulness for stress relief.", {"entities": []}),
    ("The sound of a crackling fire is comforting.", {"entities": []}),
    ("He enjoys playing video games as a hobby.", {"entities": []}),
    ("She enjoys knitting as a creative outlet.", {"entities": []}),
    ("They go for picnics in the countryside.", {"entities": []}),
    ("I love exploring new places and discovering.", {"entities": []}),
    ("I enjoy nature, trees, and fresh air.", {"entities": []}),
    ("I find joy in watching the sunset.", {"entities": []}),
    ("I'm passionate about photography and capturing moments.", {"entities": []}),
    ("I find solace in reading books.", {"entities": []}),
    ("I love cooking delicious meals.", {"entities": []}),
    ("I'm fascinated by stars and stargazing.", {"entities": []}),
    ("I'm drawn to the ocean and waves.", {"entities": []}),
    ("I'm a believer in mindfulness and meditation.", {"entities": []}),
    ("I find inspiration in art galleries.", {"entities": []}),
    ("I'm always curious and love learning.", {"entities": []}),
    ("I enjoy solving puzzles and brain teasers.", {"entities": []}),
    ("I find peace in nature's beauty.", {"entities": []}),
    ("I'm passionate about music and guitar.", {"entities": []}),
    ("I'm a keen observer and birdwatching.", {"entities": []}),
    ("I'm a collector and enjoy finding treasures.", {"entities": []}),
    ("I'm happiest when surrounded by loved ones.", {"entities": []}),
    ("I believe in self-care and relaxation.", {"entities": []}),
    ("I'm an adventurer and love exploring.", {"entities": []}),
    ("I'm passionate about conservation and sustainability.", {"entities": []}),
    ("I find joy in helping others.", {"entities": []}),
    ("I'm fascinated by history and museums.", {"entities": []}),
    ("I'm a dreamer and love creativity.", {"entities": []}),
    ("I'm a believer in positivity and kindness.", {"entities": []}),
    ("I find peace in life's simplicity.", {"entities": []}),
    ("I'm passionate about fitness and challenges.", {"entities": []}),
    ("I'm a lifelong learner and seek growth.", {"entities": []}),
    ("I find inspiration in nature and photography.", {"entities": []}),
    ("I'm an advocate for mental health awareness.", {"entities": []}),
    ("I'm an explorer and love adventures.", {"entities": []}),
    ("I find joy in the little things.", {"entities": []}),
    ("I'm passionate about creativity and expression.", {"entities": []}),
    ("I'm an animal lover and enjoy companionship.", {"entities": []}),
    ("I'm a believer in gratitude and thankfulness.", {"entities": []}),
    ("I'm a dreamer and imagine endless possibilities.", {"entities": []}),
    ("I'm a seeker of knowledge and understanding.", {"entities": []}),
    ("I enjoy painting and expressing my emotions.", {"entities": []}),
    ("I'm an early riser and love mornings.", {"entities": []}),
    ("I find comfort in a warm cup.", {"entities": []}),
    ("I'm passionate about helping others succeed.", {"entities": []}),
    ("I'm fascinated by science and discovery.", {"entities": []}),
    ("I find joy in spending time outdoors.", {"entities": []}),
    ("I'm a believer in lifelong learning.", {"entities": []}),
    ("I'm an explorer and crave new experiences.", {"entities": []}),
    ("I love the smell of fresh flowers.", {"entities": []}),
    ("I find solace in the sound of rain.", {"entities": []}),
    ("I'm a believer in the power of positivity.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about protecting the environment.", {"entities": []}),
    ("I find inspiration in the beauty of nature.", {"entities": []}),
    ("I'm a dreamer and love to imagine.", {"entities": []}),
    ("I'm an optimist and see the good.", {"entities": []}),
    ("I enjoy the taste of freshly brewed coffee.", {"entities": []}),
    ("I'm a believer in the importance of kindness.", {"entities": []}),
    ("I love the feeling of accomplishment after exercise.", {"entities": []}),
    ("I find happiness in the little things.", {"entities": []}),
    ("I'm passionate about making a difference.", {"entities": []}),
    ("I find peace in the sound of birdsong.", {"entities": []}),
    ("I'm a believer in the power of dreams.", {"entities": []}),
    ("I'm an adventurer and seek new horizons.", {"entities": []}),
    ("I enjoy the feeling of sunshine on my face.", {"entities": []}),
    ("I'm passionate about living life to the fullest.", {"entities": []}),
    ("I find comfort in the company of loved ones.", {"entities": []}),
    ("I'm fascinated by the wonders of the universe.", {"entities": []}),
    ("I find joy in the simple pleasures of life.", {"entities": []}),
    ("I'm a believer in the value of friendship.", {"entities": []}),
    ("I enjoy the feeling of grass beneath my feet.", {"entities": []}),
    ("I'm passionate about learning from others.", {"entities": []}),
    ("I find inspiration in the power of imagination.", {"entities": []}),
    ("I'm a dreamer and chase my aspirations.", {"entities": []}),
    ("I'm an explorer and seek adventure.", {"entities": []}),
    ("I enjoy the feeling of accomplishment after a workout.", {"entities": []}),
    ("I'm a believer in the beauty of simplicity.", {"entities": []}),
    ("I find happiness in the beauty of nature.", {"entities": []}),
    ("I'm passionate about making a positive impact.", {"entities": []}),
    ("I find comfort in the warmth of the sun.", {"entities": []}),
    ("I'm fascinated by the mysteries of the mind.", {"entities": []}),
    ("I find joy in the laughter of loved ones.", {"entities": []}),
    ("I'm a believer in the power of love.", {"entities": []}),
    ("I enjoy the feeling of rain on my skin.", {"entities": []}),
    ("I'm passionate about pursuing my dreams.", {"entities": []}),
    ("I find inspiration in the beauty of art.", {"entities": []}),
    ("I'm a dreamer and believe in possibilities.", {"entities": []}),
    ("I'm an adventurer and embrace uncertainty.", {"entities": []}),
    ("I enjoy the feeling of wind in my hair.", {"entities": []}),
    ("I'm a believer in the importance of gratitude.", {"entities": []}),
    ("I find happiness in the simplicity of life.", {"entities": []}),
    ("I'm passionate about spreading kindness.", {"entities": []}),
    ("I find comfort in the sound of waves.", {"entities": []}),
    ("I'm fascinated by the diversity of cultures.", {"entities": []}),
    ("I find joy in the beauty of a sunrise.", {"entities": []}),
    ("I'm a believer in the power of perseverance.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about living with purpose.", {"entities": []}),
    ("I find inspiration in the magic of storytelling.", {"entities": []}),
    ("I'm a dreamer and believe in magic.", {"entities": []}),
    ("I'm an explorer and seek new adventures.", {"entities": []}),
    ("I enjoy the feeling of a warm embrace.", {"entities": []}),
    ("I'm a believer in the beauty of diversity.", {"entities": []}),
    ("I find happiness in the company of friends.", {"entities": []}),
    ("I'm passionate about preserving natural habitats.", {"entities": []}),
    ("I find comfort in the sound of gentle rain.", {"entities": []}),
    ("I'm fascinated by the wonders of the natural world.", {"entities": []}),
    ("I find joy in the sound of children's laughter.", {"entities": []}),
    ("I'm a believer in the power of resilience.", {"entities": []}),
    ("I enjoy the feeling of accomplishment after a run.", {"entities": []}),
    ("I'm passionate about creating meaningful connections.", {"entities": []}),
    ("I find inspiration in the beauty of the night sky.", {"entities": []}),
    ("I'm a dreamer and chase after my dreams.", {"entities": []}),
    ("I'm an adventurer and seek new challenges.", {"entities": []}),
    ("I enjoy the feeling of a warm cup of tea.", {"entities": []}),
    ("I'm a believer in the importance of empathy.", {"entities": []}),
    ("I find happiness in the sound of music.", {"entities": []}),
    ("I'm passionate about fostering a sense of belonging.", {"entities": []}),
    ("I find comfort in the serenity of a quiet moment.", {"entities": []}),
    ("I'm fascinated by the mysteries of the human heart.", {"entities": []}),
    ("I find joy in the colors of a sunset.", {"entities": []}),
    ("I'm a believer in the power of positive thinking.", {"entities": []}),
    ("I enjoy the feeling of a cool breeze.", {"entities": []}),
    ("I'm passionate about making a positive difference.", {"entities": []}),
    ("I find inspiration in the resilience of nature.", {"entities": []}),
    ("I'm a dreamer and believe in infinite possibilities.", {"entities": []}),
    ("I'm an explorer and seek new opportunities.", {"entities": []}),
    ("I enjoy the feeling of laughter bubbling up.", {"entities": []}),
    ("I'm a believer in the importance of compassion.", {"entities": []}),
    ("I find happiness in the simple joys of life.", {"entities": []}),
    ("I'm passionate about protecting endangered species.", {"entities": []}),
    ("I find comfort in the sound of birds chirping.", {"entities": []}),
    ("I'm fascinated by the wonders of the cosmos.", {"entities": []}),
    ("I find joy in the beauty of a blooming flower.", {"entities": []}),
    ("I'm a believer in the power of self-discovery.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about creating a more sustainable future.", {"entities": []}),
    ("I find inspiration in the power of human potential.", {"entities": []}),
    ("I'm a dreamer and believe in following my heart.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm hug.", {"entities": []}),
    ("I'm a believer in the importance of diversity.", {"entities": []}),
    ("I find happiness in the beauty of a rainbow.", {"entities": []}),
    ("I'm passionate about promoting social justice.", {"entities": []}),
    ("I find comfort in the warmth of a cozy fire.", {"entities": []}),
    ("I'm fascinated by the intricacies of the human mind.", {"entities": []}),
    ("I find joy in the sound of waves crashing.", {"entities": []}),
    ("I'm a believer in the power of resilience and perseverance.", {"entities": []}),
    ("I enjoy the feeling of a gentle breeze.", {"entities": []}),
    ("I'm passionate about spreading love and kindness.", {"entities": []}),
    ("I find inspiration in the beauty of the natural world.", {"entities": []}),
    ("I'm a dreamer and believe in the beauty of dreams.", {"entities": []}),
    ("I'm an explorer and seek adventure wherever I go.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm a believer in the importance of mindfulness.", {"entities": []}),
    ("I find happiness in the company of good friends.", {"entities": []}),
    ("I'm passionate about making the world a better place.", {"entities": []}),
    ("I find comfort in the sound of rain falling softly.", {"entities": []}),
    ("I'm fascinated by the wonders of the natural world.", {"entities": []}),
    ("I find joy in the laughter of children at play.", {"entities": []}),
    ("I'm a believer in the power of resilience and strength.", {"entities": []}),
    ("I enjoy the feeling of accomplishment after a workout.", {"entities": []}),
    ("I'm passionate about fostering a sense of community.", {"entities": []}),
    ("I find inspiration in the beauty of the night sky.", {"entities": []}),
    ("I'm a dreamer and believe in the power of imagination.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm cup of tea.", {"entities": []}),
    ("I'm a believer in the importance of empathy and understanding.", {"entities": []}),
    ("I find happiness in the sound of music.", {"entities": []}),
    ("I'm passionate about fostering a sense of belonging.", {"entities": []}),
    ("I find comfort in the serenity of a quiet moment.", {"entities": []}),
    ("I'm fascinated by the mysteries of the human heart.", {"entities": []}),
    ("I find joy in the colors of a sunset.", {"entities": []}),
    ("I'm a believer in the power of positive thinking.", {"entities": []}),
    ("I enjoy the feeling of a cool breeze.", {"entities": []}),
    ("I'm passionate about making a positive difference.", {"entities": []}),
    ("I find inspiration in the resilience of nature.", {"entities": []}),
    ("I'm a dreamer and believe in infinite possibilities.", {"entities": []}),
    ("I'm an explorer and seek new opportunities.", {"entities": []}),
    ("I enjoy the feeling of laughter bubbling up.", {"entities": []}),
    ("I'm a believer in the importance of compassion.", {"entities": []}),
    ("I find happiness in the simple joys of life.", {"entities": []}),
    ("I'm passionate about protecting endangered species.", {"entities": []}),
    ("I find comfort in the sound of birds chirping.", {"entities": []}),
    ("I'm fascinated by the wonders of the cosmos.", {"entities": []}),
    ("I find joy in the beauty of a blooming flower.", {"entities": []}),
    ("I'm a believer in the power of self-discovery.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about creating a more sustainable future.", {"entities": []}),
    ("I find inspiration in the power of human potential.", {"entities": []}),
    ("I'm a dreamer and believe in following my heart.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm hug.", {"entities": []}),
    ("I'm a believer in the importance of diversity.", {"entities": []}),
    ("I find happiness in the beauty of a rainbow.", {"entities": []}),
    ("I'm passionate about promoting social justice.", {"entities": []}),
    ("I find comfort in the warmth of a cozy fire.", {"entities": []}),
    ("I'm fascinated by the intricacies of the human mind.", {"entities": []}),
    ("I find joy in the sound of waves crashing.", {"entities": []}),
    ("I'm a believer in the power of resilience and perseverance.", {"entities": []}),
    ("I enjoy the feeling of a gentle breeze.", {"entities": []}),
    ("I'm passionate about spreading love and kindness.", {"entities": []}),
    ("I find inspiration in the beauty of the natural world.", {"entities": []}),
    ("I'm a dreamer and believe in the beauty of dreams.", {"entities": []}),
    ("I'm an explorer and seek adventure wherever I go.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm a believer in the importance of mindfulness.", {"entities": []}),
    ("I find happiness in the company of good friends.", {"entities": []}),
    ("I'm passionate about making the world a better place.", {"entities": []}),
    ("I find comfort in the sound of rain falling softly.", {"entities": []}),
    ("I'm fascinated by the wonders of the natural world.", {"entities": []}),
    ("I find joy in the laughter of children at play.", {"entities": []}),
    ("I'm a believer in the power of resilience and strength.", {"entities": []}),
    ("I enjoy the feeling of accomplishment after a workout.", {"entities": []}),
    ("I'm passionate about fostering a sense of community.", {"entities": []}),
    ("I find inspiration in the beauty of the night sky.", {"entities": []}),
    ("I'm a dreamer and believe in the power of imagination.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm cup of tea.", {"entities": []}),
    ("I'm a believer in the importance of empathy and understanding.", {"entities": []}),
    ("I find happiness in the sound of music.", {"entities": []}),
    ("I'm passionate about fostering a sense of belonging.", {"entities": []}),
    ("I find comfort in the serenity of a quiet moment.", {"entities": []}),
    ("I'm fascinated by the mysteries of the human heart.", {"entities": []}),
    ("I find joy in the colors of a sunset.", {"entities": []}),
    ("I'm a believer in the power of positive thinking.", {"entities": []}),
    ("I enjoy the feeling of a cool breeze.", {"entities": []}),
    ("I'm passionate about making a positive difference.", {"entities": []}),
    ("I find inspiration in the resilience of nature.", {"entities": []}),
    ("I'm a dreamer and believe in infinite possibilities.", {"entities": []}),
    ("I'm an explorer and seek new opportunities.", {"entities": []}),
    ("I enjoy the feeling of laughter bubbling up.", {"entities": []}),
    ("I'm a believer in the importance of compassion.", {"entities": []}),
    ("I find happiness in the simple joys of life.", {"entities": []}),
    ("I'm passionate about protecting endangered species.", {"entities": []}),
    ("I find comfort in the sound of birds chirping.", {"entities": []}),
    ("I'm fascinated by the wonders of the cosmos.", {"entities": []}),
    ("I find joy in the beauty of a blooming flower.", {"entities": []}),
    ("I'm a believer in the power of self-discovery.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about creating a more sustainable future.", {"entities": []}),
    ("I find inspiration in the power of human potential.", {"entities": []}),
    ("I'm a dreamer and believe in following my heart.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm hug.", {"entities": []}),
    ("I'm a believer in the importance of diversity.", {"entities": []}),
    ("I find happiness in the beauty of a rainbow.", {"entities": []}),
    ("I'm passionate about promoting social justice.", {"entities": []}),
    ("I find comfort in the warmth of a cozy fire.", {"entities": []}),
    ("I'm fascinated by the intricacies of the human mind.", {"entities": []}),
    ("I find joy in the sound of waves crashing.", {"entities": []}),
    ("I'm a believer in the power of resilience and perseverance.", {"entities": []}),
    ("I enjoy the feeling of a gentle breeze.", {"entities": []}),
    ("I'm passionate about spreading love and kindness.", {"entities": []}),
    ("I find inspiration in the beauty of the natural world.", {"entities": []}),
    ("I'm a dreamer and believe in the beauty of dreams.", {"entities": []}),
    ("I'm an explorer and seek adventure wherever I go.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm a believer in the importance of mindfulness.", {"entities": []}),
    ("I find happiness in the company of good friends.", {"entities": []}),
    ("I'm passionate about making the world a better place.", {"entities": []}),
    ("I find comfort in the sound of rain falling softly.", {"entities": []}),
    ("I'm fascinated by the wonders of the natural world.", {"entities": []}),
    ("I find joy in the laughter of children at play.", {"entities": []}),
    ("I'm a believer in the power of resilience and strength.", {"entities": []}),
    ("I enjoy the feeling of accomplishment after a workout.", {"entities": []}),
    ("I'm passionate about fostering a sense of community.", {"entities": []}),
    ("I find inspiration in the beauty of the night sky.", {"entities": []}),
    ("I'm a dreamer and believe in the power of imagination.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm cup of tea.", {"entities": []}),
    ("I'm a believer in the importance of empathy and understanding.", {"entities": []}),
    ("I find happiness in the sound of music.", {"entities": []}),
    ("I'm passionate about fostering a sense of belonging.", {"entities": []}),
    ("I find comfort in the serenity of a quiet moment.", {"entities": []}),
    ("I'm fascinated by the mysteries of the human heart.", {"entities": []}),
    ("I find joy in the colors of a sunset.", {"entities": []}),
    ("I'm a believer in the power of positive thinking.", {"entities": []}),
    ("I enjoy the feeling of a cool breeze.", {"entities": []}),
    ("I'm passionate about making a positive difference.", {"entities": []}),
    ("I find inspiration in the resilience of nature.", {"entities": []}),
    ("I'm a dreamer and believe in infinite possibilities.", {"entities": []}),
    ("I'm an explorer and seek new opportunities.", {"entities": []}),
    ("I enjoy the feeling of laughter bubbling up.", {"entities": []}),
    ("I'm a believer in the importance of compassion.", {"entities": []}),
    ("I find happiness in the simple joys of life.", {"entities": []}),
    ("I'm passionate about protecting endangered species.", {"entities": []}),
    ("I find comfort in the sound of birds chirping.", {"entities": []}),
    ("I'm fascinated by the wonders of the cosmos.", {"entities": []}),
    ("I find joy in the beauty of a blooming flower.", {"entities": []}),
    ("I'm a believer in the power of self-discovery.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about creating a more sustainable future.", {"entities": []}),
    ("I find inspiration in the power of human potential.", {"entities": []}),
    ("I'm a dreamer and believe in following my heart.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm hug.", {"entities": []}),
    ("I'm a believer in the importance of diversity.", {"entities": []}),
    ("I find happiness in the beauty of a rainbow.", {"entities": []}),
    ("I'm passionate about promoting social justice.", {"entities": []}),
    ("I find comfort in the warmth of a cozy fire.", {"entities": []}),
    ("I'm fascinated by the intricacies of the human mind.", {"entities": []}),
    ("I find joy in the sound of waves crashing.", {"entities": []}),
    ("I'm a believer in the power of resilience and perseverance.", {"entities": []}),
    ("I enjoy the feeling of a gentle breeze.", {"entities": []}),
    ("I'm passionate about spreading love and kindness.", {"entities": []}),
    ("I find inspiration in the beauty of the natural world.", {"entities": []}),
    ("I'm a dreamer and believe in the beauty of dreams.", {"entities": []}),
    ("I'm an explorer and seek adventure wherever I go.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm a believer in the importance of mindfulness.", {"entities": []}),
    ("I find happiness in the company of good friends.", {"entities": []}),
    ("I'm passionate about making the world a better place.", {"entities": []}),
    ("I find comfort in the sound of rain falling softly.", {"entities": []}),
    ("I'm fascinated by the wonders of the natural world.", {"entities": []}),
    ("I find joy in the laughter of children at play.", {"entities": []}),
    ("I'm a believer in the power of resilience and strength.", {"entities": []}),
    ("I enjoy the feeling of accomplishment after a workout.", {"entities": []}),
    ("I'm passionate about fostering a sense of community.", {"entities": []}),
    ("I find inspiration in the beauty of the night sky.", {"entities": []}),
    ("I'm a dreamer and believe in the power of imagination.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm cup of tea.", {"entities": []}),
    ("I'm a believer in the importance of empathy and understanding.", {"entities": []}),
    ("I find happiness in the sound of music.", {"entities": []}),
    ("I'm passionate about fostering a sense of belonging.", {"entities": []}),
    ("I find comfort in the serenity of a quiet moment.", {"entities": []}),
    ("I'm fascinated by the mysteries of the human heart.", {"entities": []}),
    ("I find joy in the colors of a sunset.", {"entities": []}),
    ("I'm a believer in the power of positive thinking.", {"entities": []}),
    ("I enjoy the feeling of a cool breeze.", {"entities": []}),
    ("I'm passionate about making a positive difference.", {"entities": []}),
    ("I find inspiration in the resilience of nature.", {"entities": []}),
    ("I'm a dreamer and believe in infinite possibilities.", {"entities": []}),
    ("I'm an explorer and seek new opportunities.", {"entities": []}),
    ("I enjoy the feeling of laughter bubbling up.", {"entities": []}),
    ("I'm a believer in the importance of compassion.", {"entities": []}),
    ("I find happiness in the simple joys of life.", {"entities": []}),
    ("I'm passionate about protecting endangered species.", {"entities": []}),
    ("I find comfort in the sound of birds chirping.", {"entities": []}),
    ("I'm fascinated by the wonders of the cosmos.", {"entities": []}),
    ("I find joy in the beauty of a blooming flower.", {"entities": []}),
    ("I'm a believer in the power of self-discovery.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about creating a more sustainable future.", {"entities": []}),
    ("I find inspiration in the power of human potential.", {"entities": []}),
    ("I'm a dreamer and believe in following my heart.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm hug.", {"entities": []}),
    ("I'm a believer in the importance of diversity.", {"entities": []}),
    ("I find happiness in the beauty of a rainbow.", {"entities": []}),
    ("I'm passionate about promoting social justice.", {"entities": []}),
    ("I find comfort in the warmth of a cozy fire.", {"entities": []}),
    ("I'm fascinated by the intricacies of the human mind.", {"entities": []}),
    ("I find joy in the sound of waves crashing.", {"entities": []}),
    ("I'm a believer in the power of resilience and perseverance.", {"entities": []}),
    ("I enjoy the feeling of a gentle breeze.", {"entities": []}),
    ("I'm passionate about spreading love and kindness.", {"entities": []}),
    ("I find inspiration in the beauty of the natural world.", {"entities": []}),
    ("I'm a dreamer and believe in the beauty of dreams.", {"entities": []}),
    ("I'm an explorer and seek adventure wherever I go.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm a believer in the importance of mindfulness.", {"entities": []}),
    ("I find happiness in the company of good friends.", {"entities": []}),
    ("I'm passionate about making the world a better place.", {"entities": []}),
    ("I find comfort in the sound of rain falling softly.", {"entities": []}),
    ("I'm fascinated by the wonders of the natural world.", {"entities": []}),
    ("I find joy in the laughter of children at play.", {"entities": []}),
    ("I'm a believer in the power of resilience and strength.", {"entities": []}),
    ("I enjoy the feeling of accomplishment after a workout.", {"entities": []}),
    ("I'm passionate about fostering a sense of community.", {"entities": []}),
    ("I find inspiration in the beauty of the night sky.", {"entities": []}),
    ("I'm a dreamer and believe in the power of imagination.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm cup of tea.", {"entities": []}),
    ("I'm a believer in the importance of empathy and understanding.", {"entities": []}),
    ("I find happiness in the sound of music.", {"entities": []}),
    ("I'm passionate about fostering a sense of belonging.", {"entities": []}),
    ("I find comfort in the serenity of a quiet moment.", {"entities": []}),
    ("I'm fascinated by the mysteries of the human heart.", {"entities": []}),
    ("I find joy in the colors of a sunset.", {"entities": []}),
    ("I'm a believer in the power of positive thinking.", {"entities": []}),
    ("I enjoy the feeling of a cool breeze.", {"entities": []}),
    ("I'm passionate about making a positive difference.", {"entities": []}),
    ("I find inspiration in the resilience of nature.", {"entities": []}),
    ("I'm a dreamer and believe in infinite possibilities.", {"entities": []}),
    ("I'm an explorer and seek new opportunities.", {"entities": []}),
    ("I enjoy the feeling of laughter bubbling up.", {"entities": []}),
    ("I'm a believer in the importance of compassion.", {"entities": []}),
    ("I find happiness in the simple joys of life.", {"entities": []}),
    ("I'm passionate about protecting endangered species.", {"entities": []}),
    ("I find comfort in the sound of birds chirping.", {"entities": []}),
    ("I'm fascinated by the wonders of the cosmos.", {"entities": []}),
    ("I find joy in the beauty of a blooming flower.", {"entities": []}),
    ("I'm a believer in the power of self-discovery.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about creating a more sustainable future.", {"entities": []}),
    ("I find inspiration in the power of human potential.", {"entities": []}),
    ("I'm a dreamer and believe in following my heart.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm hug.", {"entities": []}),
    ("I'm a believer in the importance of diversity.", {"entities": []}),
    ("I find happiness in the beauty of a rainbow.", {"entities": []}),
    ("I'm passionate about promoting social justice.", {"entities": []}),
    ("I find comfort in the warmth of a cozy fire.", {"entities": []}),
    ("I'm fascinated by the intricacies of the human mind.", {"entities": []}),
    ("I find joy in the sound of waves crashing.", {"entities": []}),
    ("I'm a believer in the power of resilience and perseverance.", {"entities": []}),
    ("I enjoy the feeling of a gentle breeze.", {"entities": []}),
    ("I'm passionate about spreading love and kindness.", {"entities": []}),
    ("I find inspiration in the beauty of the natural world.", {"entities": []}),
    ("I'm a dreamer and believe in the beauty of dreams.", {"entities": []}),
    ("I'm an explorer and seek adventure wherever I go.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm a believer in the importance of mindfulness.", {"entities": []}),
    ("I find happiness in the company of good friends.", {"entities": []}),
    ("I'm passionate about making the world a better place.", {"entities": []}),
    ("I find comfort in the sound of rain falling softly.", {"entities": []}),
    ("I'm fascinated by the wonders of the natural world.", {"entities": []}),
    ("I find joy in the laughter of children at play.", {"entities": []}),
    ("I'm a believer in the power of resilience and strength.", {"entities": []}),
    ("I enjoy the feeling of accomplishment after a workout.", {"entities": []}),
    ("I'm passionate about fostering a sense of community.", {"entities": []}),
    ("I find inspiration in the beauty of the night sky.", {"entities": []}),
    ("I'm a dreamer and believe in the power of imagination.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm cup of tea.", {"entities": []}),
    ("I'm a believer in the importance of empathy and understanding.", {"entities": []}),
    ("I find happiness in the sound of music.", {"entities": []}),
    ("I'm passionate about fostering a sense of belonging.", {"entities": []}),
    ("I find comfort in the serenity of a quiet moment.", {"entities": []}),
    ("I'm fascinated by the mysteries of the human heart.", {"entities": []}),
    ("I find joy in the colors of a sunset.", {"entities": []}),
    ("I'm a believer in the power of positive thinking.", {"entities": []}),
    ("I enjoy the feeling of a cool breeze.", {"entities": []}),
    ("I'm passionate about making a positive difference.", {"entities": []}),
    ("I find inspiration in the resilience of nature.", {"entities": []}),
    ("I'm a dreamer and believe in infinite possibilities.", {"entities": []}),
    ("I'm an explorer and seek new opportunities.", {"entities": []}),
    ("I enjoy the feeling of laughter bubbling up.", {"entities": []}),
    ("I'm a believer in the importance of compassion.", {"entities": []}),
    ("I find happiness in the simple joys of life.", {"entities": []}),
    ("I'm passionate about protecting endangered species.", {"entities": []}),
    ("I find comfort in the sound of birds chirping.", {"entities": []}),
    ("I'm fascinated by the wonders of the cosmos.", {"entities": []}),
    ("I find joy in the beauty of a blooming flower.", {"entities": []}),
    ("I'm a believer in the power of self-discovery.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about creating a more sustainable future.", {"entities": []}),
    ("I find inspiration in the power of human potential.", {"entities": []}),
    ("I'm a dreamer and believe in following my heart.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm hug.", {"entities": []}),
    ("I'm a believer in the importance of diversity.", {"entities": []}),
    ("I find happiness in the beauty of a rainbow.", {"entities": []}),
    ("I'm passionate about promoting social justice.", {"entities": []}),
    ("I find comfort in the warmth of a cozy fire.", {"entities": []}),
    ("I'm fascinated by the intricacies of the human mind.", {"entities": []}),
    ("I find joy in the sound of waves crashing.", {"entities": []}),
    ("I'm a believer in the power of resilience and perseverance.", {"entities": []}),
    ("I enjoy the feeling of a gentle breeze.", {"entities": []}),
    ("I'm passionate about spreading love and kindness.", {"entities": []}),
    ("I find inspiration in the beauty of the natural world.", {"entities": []}),
    ("I'm a dreamer and believe in the beauty of dreams.", {"entities": []}),
    ("I'm an explorer and seek adventure wherever I go.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm a believer in the importance of mindfulness.", {"entities": []}),
    ("I find happiness in the company of good friends.", {"entities": []}),
    ("I'm passionate about making the world a better place.", {"entities": []}),
    ("I find comfort in the sound of rain falling softly.", {"entities": []}),
    ("I'm fascinated by the wonders of the natural world.", {"entities": []}),
    ("I find joy in the laughter of children at play.", {"entities": []}),
    ("I'm a believer in the power of resilience and strength.", {"entities": []}),
    ("I enjoy the feeling of accomplishment after a workout.", {"entities": []}),
    ("I'm passionate about fostering a sense of community.", {"entities": []}),
    ("I find inspiration in the beauty of the night sky.", {"entities": []}),
    ("I'm a dreamer and believe in the power of imagination.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm cup of tea.", {"entities": []}),
    ("I'm a believer in the importance of empathy and understanding.", {"entities": []}),
    ("I find happiness in the sound of music.", {"entities": []}),
    ("I'm passionate about fostering a sense of belonging.", {"entities": []}),
    ("I find comfort in the serenity of a quiet moment.", {"entities": []}),
    ("I'm fascinated by the mysteries of the human heart.", {"entities": []}),
    ("I find joy in the colors of a sunset.", {"entities": []}),
    ("I'm a believer in the power of positive thinking.", {"entities": []}),
    ("I enjoy the feeling of a cool breeze.", {"entities": []}),
    ("I'm passionate about making a positive difference.", {"entities": []}),
    ("I find inspiration in the resilience of nature.", {"entities": []}),
    ("I'm a dreamer and believe in infinite possibilities.", {"entities": []}),
    ("I'm an explorer and seek new opportunities.", {"entities": []}),
    ("I enjoy the feeling of laughter bubbling up.", {"entities": []}),
    ("I'm a believer in the importance of compassion.", {"entities": []}),
    ("I find happiness in the simple joys of life.", {"entities": []}),
    ("I'm passionate about protecting endangered species.", {"entities": []}),
    ("I find comfort in the sound of birds chirping.", {"entities": []}),
    ("I'm fascinated by the wonders of the cosmos.", {"entities": []}),
    ("I find joy in the beauty of a blooming flower.", {"entities": []}),
    ("I'm a believer in the power of self-discovery.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about creating a more sustainable future.", {"entities": []}),
    ("I find inspiration in the power of human potential.", {"entities": []}),
    ("I'm a dreamer and believe in following my heart.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm hug.", {"entities": []}),
    ("I'm a believer in the importance of diversity.", {"entities": []}),
    ("I find happiness in the beauty of a rainbow.", {"entities": []}),
    ("I'm passionate about promoting social justice.", {"entities": []}),
    ("I find comfort in the warmth of a cozy fire.", {"entities": []}),
    ("I'm fascinated by the intricacies of the human mind.", {"entities": []}),
    ("I find joy in the sound of waves crashing.", {"entities": []}),
    ("I'm a believer in the power of resilience and perseverance.", {"entities": []}),
    ("I enjoy the feeling of a gentle breeze.", {"entities": []}),
    ("I'm passionate about spreading love and kindness.", {"entities": []}),
    ("I find inspiration in the beauty of the natural world.", {"entities": []}),
    ("I'm a dreamer and believe in the beauty of dreams.", {"entities": []}),
    ("I'm an explorer and seek adventure wherever I go.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm a believer in the importance of mindfulness.", {"entities": []}),
    ("I find happiness in the company of good friends.", {"entities": []}),
    ("I'm passionate about making the world a better place.", {"entities": []}),
    ("I find comfort in the sound of rain falling softly.", {"entities": []}),
    ("I'm fascinated by the wonders of the natural world.", {"entities": []}),
    ("I find joy in the laughter of children at play.", {"entities": []}),
    ("I'm a believer in the power of resilience and strength.", {"entities": []}),
    ("I enjoy the feeling of accomplishment after a workout.", {"entities": []}),
    ("I'm passionate about fostering a sense of community.", {"entities": []}),
    ("I find inspiration in the beauty of the night sky.", {"entities": []}),
    ("I'm a dreamer and believe in the power of imagination.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm cup of tea.", {"entities": []}),
    ("I'm a believer in the importance of empathy and understanding.", {"entities": []}),
    ("I find happiness in the sound of music.", {"entities": []}),
    ("I'm passionate about fostering a sense of belonging.", {"entities": []}),
    ("I find comfort in the serenity of a quiet moment.", {"entities": []}),
    ("I'm fascinated by the mysteries of the human heart.", {"entities": []}),
    ("I find joy in the colors of a sunset.", {"entities": []}),
    ("I'm a believer in the power of positive thinking.", {"entities": []}),
    ("I enjoy the feeling of a cool breeze.", {"entities": []}),
    ("I'm passionate about making a positive difference.", {"entities": []}),
    ("I find inspiration in the resilience of nature.", {"entities": []}),
    ("I'm a dreamer and believe in infinite possibilities.", {"entities": []}),
    ("I'm an explorer and seek new opportunities.", {"entities": []}),
    ("I enjoy the feeling of laughter bubbling up.", {"entities": []}),
    ("I'm a believer in the importance of compassion.", {"entities": []}),
    ("I find happiness in the simple joys of life.", {"entities": []}),
    ("I'm passionate about protecting endangered species.", {"entities": []}),
    ("I find comfort in the sound of birds chirping.", {"entities": []}),
    ("I'm fascinated by the wonders of the cosmos.", {"entities": []}),
    ("I find joy in the beauty of a blooming flower.", {"entities": []}),
    ("I'm a believer in the power of self-discovery.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about creating a more sustainable future.", {"entities": []}),
    ("I find inspiration in the power of human potential.", {"entities": []}),
    ("I'm a dreamer and believe in following my heart.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm hug.", {"entities": []}),
    ("I'm a believer in the importance of diversity.", {"entities": []}),
    ("I find happiness in the beauty of a rainbow.", {"entities": []}),
    ("I'm passionate about promoting social justice.", {"entities": []}),
    ("I find comfort in the warmth of a cozy fire.", {"entities": []}),
    ("I'm fascinated by the intricacies of the human mind.", {"entities": []}),
    ("I find joy in the sound of waves crashing.", {"entities": []}),
    ("I'm a believer in the power of resilience and perseverance.", {"entities": []}),
    ("I enjoy the feeling of a gentle breeze.", {"entities": []}),
    ("I'm passionate about spreading love and kindness.", {"entities": []}),
    ("I find inspiration in the beauty of the natural world.", {"entities": []}),
    ("I'm a dreamer and believe in the beauty of dreams.", {"entities": []}),
    ("I'm an explorer and seek adventure wherever I go.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm a believer in the importance of mindfulness.", {"entities": []}),
    ("I find happiness in the company of good friends.", {"entities": []}),
    ("I'm passionate about making the world a better place.", {"entities": []}),
    ("I find comfort in the sound of rain falling softly.", {"entities": []}),
    ("I'm fascinated by the wonders of the natural world.", {"entities": []}),
    ("I find joy in the laughter of children at play.", {"entities": []}),
    ("I'm a believer in the power of resilience and strength.", {"entities": []}),
    ("I enjoy the feeling of accomplishment after a workout.", {"entities": []}),
    ("I'm passionate about fostering a sense of community.", {"entities": []}),
    ("I find inspiration in the beauty of the night sky.", {"entities": []}),
    ("I'm a dreamer and believe in the power of imagination.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm cup of tea.", {"entities": []}),
    ("I'm a believer in the importance of empathy and understanding.", {"entities": []}),
    ("I find happiness in the sound of music.", {"entities": []}),
    ("I'm passionate about fostering a sense of belonging.", {"entities": []}),
    ("I find comfort in the serenity of a quiet moment.", {"entities": []}),
    ("I'm fascinated by the mysteries of the human heart.", {"entities": []}),
    ("I find joy in the colors of a sunset.", {"entities": []}),
    ("I'm a believer in the power of positive thinking.", {"entities": []}),
    ("I enjoy the feeling of a cool breeze.", {"entities": []}),
    ("I'm passionate about making a positive difference.", {"entities": []}),
    ("I find inspiration in the resilience of nature.", {"entities": []}),
    ("I'm a dreamer and believe in infinite possibilities.", {"entities": []}),
    ("I'm an explorer and seek new opportunities.", {"entities": []}),
    ("I enjoy the feeling of laughter bubbling up.", {"entities": []}),
    ("I'm a believer in the importance of compassion.", {"entities": []}),
    ("I find happiness in the simple joys of life.", {"entities": []}),
    ("I'm passionate about protecting endangered species.", {"entities": []}),
    ("I find comfort in the sound of birds chirping.", {"entities": []}),
    ("I'm fascinated by the wonders of the cosmos.", {"entities": []}),
    ("I find joy in the beauty of a blooming flower.", {"entities": []}),
    ("I'm a believer in the power of self-discovery.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about creating a more sustainable future.", {"entities": []}),
    ("I find inspiration in the power of human potential.", {"entities": []}),
    ("I'm a dreamer and believe in following my heart.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm hug.", {"entities": []}),
    ("I'm a believer in the importance of diversity.", {"entities": []}),
    ("I find happiness in the beauty of a rainbow.", {"entities": []}),
    ("I'm passionate about promoting social justice.", {"entities": []}),
    ("I find comfort in the warmth of a cozy fire.", {"entities": []}),
    ("I'm fascinated by the intricacies of the human mind.", {"entities": []}),
    ("I find joy in the sound of waves crashing.", {"entities": []}),
    ("I'm a believer in the power of resilience and perseverance.", {"entities": []}),
    ("I enjoy the feeling of a gentle breeze.", {"entities": []}),
    ("I'm passionate about spreading love and kindness.", {"entities": []}),
    ("I find inspiration in the beauty of the natural world.", {"entities": []}),
    ("I'm a dreamer and believe in the beauty of dreams.", {"entities": []}),
    ("I'm an explorer and seek adventure wherever I go.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm a believer in the importance of mindfulness.", {"entities": []}),
    ("I find happiness in the company of good friends.", {"entities": []}),
    ("I'm passionate about making the world a better place.", {"entities": []}),
    ("I find comfort in the sound of rain falling softly.", {"entities": []}),
    ("I'm fascinated by the wonders of the natural world.", {"entities": []}),
    ("I find joy in the laughter of children at play.", {"entities": []}),
    ("I'm a believer in the power of resilience and strength.", {"entities": []}),
    ("I enjoy the feeling of accomplishment after a workout.", {"entities": []}),
    ("I'm passionate about fostering a sense of community.", {"entities": []}),
    ("I find inspiration in the beauty of the night sky.", {"entities": []}),
    ("I'm a dreamer and believe in the power of imagination.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm cup of tea.", {"entities": []}),
    ("I'm a believer in the importance of empathy and understanding.", {"entities": []}),
    ("I find happiness in the sound of music.", {"entities": []}),
    ("I'm passionate about fostering a sense of belonging.", {"entities": []}),
    ("I find comfort in the serenity of a quiet moment.", {"entities": []}),
    ("I'm fascinated by the mysteries of the human heart.", {"entities": []}),
    ("I find joy in the colors of a sunset.", {"entities": []}),
    ("I'm a believer in the power of positive thinking.", {"entities": []}),
    ("I enjoy the feeling of a cool breeze.", {"entities": []}),
    ("I'm passionate about making a positive difference.", {"entities": []}),
    ("I find inspiration in the resilience of nature.", {"entities": []}),
    ("I'm a dreamer and believe in infinite possibilities.", {"entities": []}),
    ("I'm an explorer and seek new opportunities.", {"entities": []}),
    ("I enjoy the feeling of laughter bubbling up.", {"entities": []}),
    ("I'm a believer in the importance of compassion.", {"entities": []}),
    ("I find happiness in the simple joys of life.", {"entities": []}),
    ("I'm passionate about protecting endangered species.", {"entities": []}),
    ("I find comfort in the sound of birds chirping.", {"entities": []}),
    ("I'm fascinated by the wonders of the cosmos.", {"entities": []}),
    ("I find joy in the beauty of a blooming flower.", {"entities": []}),
    ("I'm a believer in the power of self-discovery.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about creating a more sustainable future.", {"entities": []}),
    ("I find inspiration in the power of human potential.", {"entities": []}),
    ("I'm a dreamer and believe in following my heart.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm hug.", {"entities": []}),
    ("I'm a believer in the importance of diversity.", {"entities": []}),
    ("I find happiness in the beauty of a rainbow.", {"entities": []}),
    ("I'm passionate about promoting social justice.", {"entities": []}),
    ("I find comfort in the warmth of a cozy fire.", {"entities": []}),
    ("I'm fascinated by the intricacies of the human mind.", {"entities": []}),
    ("I find joy in the sound of waves crashing.", {"entities": []}),
    ("I'm a believer in the power of resilience and perseverance.", {"entities": []}),
    ("I enjoy the feeling of a gentle breeze.", {"entities": []}),
    ("I'm passionate about spreading love and kindness.", {"entities": []}),
    ("I find inspiration in the beauty of the natural world.", {"entities": []}),
    ("I'm a dreamer and believe in the beauty of dreams.", {"entities": []}),
    ("I'm an explorer and seek adventure wherever I go.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm a believer in the importance of mindfulness.", {"entities": []}),
    ("I find happiness in the company of good friends.", {"entities": []}),
    ("I'm passionate about making the world a better place.", {"entities": []}),
    ("I find comfort in the sound of rain falling softly.", {"entities": []}),
    ("I'm fascinated by the wonders of the natural world.", {"entities": []}),
    ("I find joy in the laughter of children at play.", {"entities": []}),
    ("I'm a believer in the power of resilience and strength.", {"entities": []}),
    ("I enjoy the feeling of accomplishment after a workout.", {"entities": []}),
    ("I'm passionate about fostering a sense of community.", {"entities": []}),
    ("I find inspiration in the beauty of the night sky.", {"entities": []}),
    ("I'm a dreamer and believe in the power of imagination.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm cup of tea.", {"entities": []}),
    ("I'm a believer in the importance of empathy and understanding.", {"entities": []}),
    ("I find happiness in the sound of music.", {"entities": []}),
    ("I'm passionate about fostering a sense of belonging.", {"entities": []}),
    ("I find comfort in the serenity of a quiet moment.", {"entities": []}),
    ("I'm fascinated by the mysteries of the human heart.", {"entities": []}),
    ("I find joy in the colors of a sunset.", {"entities": []}),
    ("I'm a believer in the power of positive thinking.", {"entities": []}),
    ("I enjoy the feeling of a cool breeze.", {"entities": []}),
    ("I'm passionate about making a positive difference.", {"entities": []}),
    ("I find inspiration in the resilience of nature.", {"entities": []}),
    ("I'm a dreamer and believe in infinite possibilities.", {"entities": []}),
    ("I'm an explorer and seek new opportunities.", {"entities": []}),
    ("I enjoy the feeling of laughter bubbling up.", {"entities": []}),
    ("I'm a believer in the importance of compassion.", {"entities": []}),
    ("I find happiness in the simple joys of life.", {"entities": []}),
    ("I'm passionate about protecting endangered species.", {"entities": []}),
    ("I find comfort in the sound of birds chirping.", {"entities": []}),
    ("I'm fascinated by the wonders of the cosmos.", {"entities": []}),
    ("I find joy in the beauty of a blooming flower.", {"entities": []}),
    ("I'm a believer in the power of self-discovery.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about creating a more sustainable future.", {"entities": []}),
    ("I find inspiration in the power of human potential.", {"entities": []}),
    ("I'm a dreamer and believe in following my heart.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm hug.", {"entities": []}),
    ("I'm a believer in the importance of diversity.", {"entities": []}),
    ("I find happiness in the beauty of a rainbow.", {"entities": []}),
    ("I'm passionate about promoting social justice.", {"entities": []}),
    ("I find comfort in the warmth of a cozy fire.", {"entities": []}),
    ("I'm fascinated by the intricacies of the human mind.", {"entities": []}),
    ("I find joy in the sound of waves crashing.", {"entities": []}),
    ("I'm a believer in the power of resilience and perseverance.", {"entities": []}),
    ("I enjoy the feeling of a gentle breeze.", {"entities": []}),
    ("I'm passionate about spreading love and kindness.", {"entities": []}),
    ("I find inspiration in the beauty of the natural world.", {"entities": []}),
    ("I'm a dreamer and believe in the beauty of dreams.", {"entities": []}),
    ("I'm an explorer and seek adventure wherever I go.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm a believer in the importance of mindfulness.", {"entities": []}),
    ("I find happiness in the company of good friends.", {"entities": []}),
    ("I'm passionate about making the world a better place.", {"entities": []}),
    ("I find comfort in the sound of rain falling softly.", {"entities": []}),
    ("I'm fascinated by the wonders of the natural world.", {"entities": []}),
    ("I find joy in the laughter of children at play.", {"entities": []}),
    ("I'm a believer in the power of resilience and strength.", {"entities": []}),
    ("I enjoy the feeling of accomplishment after a workout.", {"entities": []}),
    ("I'm passionate about fostering a sense of community.", {"entities": []}),
    ("I find inspiration in the beauty of the night sky.", {"entities": []}),
    ("I'm a dreamer and believe in the power of imagination.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm cup of tea.", {"entities": []}),
    ("I'm a believer in the importance of empathy and understanding.", {"entities": []}),
    ("I find happiness in the sound of music.", {"entities": []}),
    ("I'm passionate about fostering a sense of belonging.", {"entities": []}),
    ("I find comfort in the serenity of a quiet moment.", {"entities": []}),
    ("I'm fascinated by the mysteries of the human heart.", {"entities": []}),
    ("I find joy in the colors of a sunset.", {"entities": []}),
    ("I'm a believer in the power of positive thinking.", {"entities": []}),
    ("I enjoy the feeling of a cool breeze.", {"entities": []}),
    ("I'm passionate about making a positive difference.", {"entities": []}),
    ("I find inspiration in the resilience of nature.", {"entities": []}),
    ("I'm a dreamer and believe in infinite possibilities.", {"entities": []}),
    ("I'm an explorer and seek new opportunities.", {"entities": []}),
    ("I enjoy the feeling of laughter bubbling up.", {"entities": []}),
    ("I'm a believer in the importance of compassion.", {"entities": []}),
    ("I find happiness in the simple joys of life.", {"entities": []}),
    ("I'm passionate about protecting endangered species.", {"entities": []}),
    ("I find comfort in the sound of birds chirping.", {"entities": []}),
    ("I'm fascinated by the wonders of the cosmos.", {"entities": []}),
    ("I find joy in the beauty of a blooming flower.", {"entities": []}),
    ("I'm a believer in the power of self-discovery.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about creating a more sustainable future.", {"entities": []}),
    ("I find inspiration in the power of human potential.", {"entities": []}),
    ("I'm a dreamer and believe in following my heart.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm hug.", {"entities": []}),
    ("I'm a believer in the importance of diversity.", {"entities": []}),
    ("I find happiness in the beauty of a rainbow.", {"entities": []}),
    ("I'm passionate about promoting social justice.", {"entities": []}),
    ("I find comfort in the warmth of a cozy fire.", {"entities": []}),
    ("I'm fascinated by the intricacies of the human mind.", {"entities": []}),
    ("I find joy in the sound of waves crashing.", {"entities": []}),
    ("I'm a believer in the power of resilience and perseverance.", {"entities": []}),
    ("I enjoy the feeling of a gentle breeze.", {"entities": []}),
    ("I'm passionate about spreading love and kindness.", {"entities": []}),
    ("I find inspiration in the beauty of the natural world.", {"entities": []}),
    ("I'm a dreamer and believe in the beauty of dreams.", {"entities": []}),
    ("I'm an explorer and seek adventure wherever I go.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm a believer in the importance of mindfulness.", {"entities": []}),
    ("I find happiness in the company of good friends.", {"entities": []}),
    ("I'm passionate about making the world a better place.", {"entities": []}),
    ("I find comfort in the sound of rain falling softly.", {"entities": []}),
    ("I'm fascinated by the wonders of the natural world.", {"entities": []}),
    ("I find joy in the laughter of children at play.", {"entities": []}),
    ("I'm a believer in the power of resilience and strength.", {"entities": []}),
    ("I enjoy the feeling of accomplishment after a workout.", {"entities": []}),
    ("I'm passionate about fostering a sense of community.", {"entities": []}),
    ("I find inspiration in the beauty of the night sky.", {"entities": []}),
    ("I'm a dreamer and believe in the power of imagination.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm cup of tea.", {"entities": []}),
    ("I'm a believer in the importance of empathy and understanding.", {"entities": []}),
    ("I find happiness in the sound of music.", {"entities": []}),
    ("I'm passionate about fostering a sense of belonging.", {"entities": []}),
    ("I find comfort in the serenity of a quiet moment.", {"entities": []}),
    ("I'm fascinated by the mysteries of the human heart.", {"entities": []}),
    ("I find joy in the colors of a sunset.", {"entities": []}),
    ("I'm a believer in the power of positive thinking.", {"entities": []}),
    ("I enjoy the feeling of a cool breeze.", {"entities": []}),
    ("I'm passionate about making a positive difference.", {"entities": []}),
    ("I find inspiration in the resilience of nature.", {"entities": []}),
    ("I'm a dreamer and believe in infinite possibilities.", {"entities": []}),
    ("I'm an explorer and seek new opportunities.", {"entities": []}),
    ("I enjoy the feeling of laughter bubbling up.", {"entities": []}),
    ("I'm a believer in the importance of compassion.", {"entities": []}),
    ("I find happiness in the simple joys of life.", {"entities": []}),
    ("I'm passionate about protecting endangered species.", {"entities": []}),
    ("I find comfort in the sound of birds chirping.", {"entities": []}),
    ("I'm fascinated by the wonders of the cosmos.", {"entities": []}),
    ("I find joy in the beauty of a blooming flower.", {"entities": []}),
    ("I'm a believer in the power of self-discovery.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about creating a more sustainable future.", {"entities": []}),
    ("I find inspiration in the power of human potential.", {"entities": []}),
    ("I'm a dreamer and believe in following my heart.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm hug.", {"entities": []}),
    ("I'm a believer in the importance of diversity.", {"entities": []}),
    ("I find happiness in the beauty of a rainbow.", {"entities": []}),
    ("I'm passionate about promoting social justice.", {"entities": []}),
    ("I find comfort in the warmth of a cozy fire.", {"entities": []}),
    ("I'm fascinated by the intricacies of the human mind.", {"entities": []}),
    ("I find joy in the sound of waves crashing.", {"entities": []}),
    ("I'm a believer in the power of resilience and perseverance.", {"entities": []}),
    ("I enjoy the feeling of a gentle breeze.", {"entities": []}),
    ("I'm passionate about spreading love and kindness.", {"entities": []}),
    ("I find inspiration in the beauty of the natural world.", {"entities": []}),
    ("I'm a dreamer and believe in the beauty of dreams.", {"entities": []}),
    ("I'm an explorer and seek adventure wherever I go.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm a believer in the importance of mindfulness.", {"entities": []}),
    ("I find happiness in the company of good friends.", {"entities": []}),
    ("I'm passionate about making the world a better place.", {"entities": []}),
    ("I find comfort in the sound of rain falling softly.", {"entities": []}),
    ("I'm fascinated by the wonders of the natural world.", {"entities": []}),
    ("I find joy in the laughter of children at play.", {"entities": []}),
    ("I'm a believer in the power of resilience and strength.", {"entities": []}),
    ("I enjoy the feeling of accomplishment after a workout.", {"entities": []}),
    ("I'm passionate about fostering a sense of community.", {"entities": []}),
    ("I find inspiration in the beauty of the night sky.", {"entities": []}),
    ("I'm a dreamer and believe in the power of imagination.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm cup of tea.", {"entities": []}),
    ("I'm a believer in the importance of empathy and understanding.", {"entities": []}),
    ("I find happiness in the sound of music.", {"entities": []}),
    ("I'm passionate about fostering a sense of belonging.", {"entities": []}),
    ("I find comfort in the serenity of a quiet moment.", {"entities": []}),
    ("I'm fascinated by the mysteries of the human heart.", {"entities": []}),
    ("I find joy in the colors of a sunset.", {"entities": []}),
    ("I'm a believer in the power of positive thinking.", {"entities": []}),
    ("I enjoy the feeling of a cool breeze.", {"entities": []}),
    ("I'm passionate about making a positive difference.", {"entities": []}),
    ("I find inspiration in the resilience of nature.", {"entities": []}),
    ("I'm a dreamer and believe in infinite possibilities.", {"entities": []}),
    ("I'm an explorer and seek new opportunities.", {"entities": []}),
    ("I enjoy the feeling of laughter bubbling up.", {"entities": []}),
    ("I'm a believer in the importance of compassion.", {"entities": []}),
    ("I find happiness in the simple joys of life.", {"entities": []}),
    ("I'm passionate about protecting endangered species.", {"entities": []}),
    ("I find comfort in the sound of birds chirping.", {"entities": []}),
    ("I'm fascinated by the wonders of the cosmos.", {"entities": []}),
    ("I find joy in the beauty of a blooming flower.", {"entities": []}),
    ("I'm a believer in the power of self-discovery.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about creating a more sustainable future.", {"entities": []}),
    ("I find inspiration in the power of human potential.", {"entities": []}),
    ("I'm a dreamer and believe in following my heart.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm hug.", {"entities": []}),
    ("I'm a believer in the importance of diversity.", {"entities": []}),
    ("I find happiness in the beauty of a rainbow.", {"entities": []}),
    ("I'm passionate about promoting social justice.", {"entities": []}),
    ("I find comfort in the warmth of a cozy fire.", {"entities": []}),
    ("I'm fascinated by the intricacies of the human mind.", {"entities": []}),
    ("I find joy in the sound of waves crashing.", {"entities": []}),
    ("I'm a believer in the power of resilience and perseverance.", {"entities": []}),
    ("I enjoy the feeling of a gentle breeze.", {"entities": []}),
    ("I'm passionate about spreading love and kindness.", {"entities": []}),
    ("I find inspiration in the beauty of the natural world.", {"entities": []}),
    ("I'm a dreamer and believe in the beauty of dreams.", {"entities": []}),
    ("I'm an explorer and seek adventure wherever I go.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm a believer in the importance of mindfulness.", {"entities": []}),
    ("I find happiness in the company of good friends.", {"entities": []}),
    ("I'm passionate about making the world a better place.", {"entities": []}),
    ("I find comfort in the sound of rain falling softly.", {"entities": []}),
    ("I'm fascinated by the wonders of the natural world.", {"entities": []}),
    ("I find joy in the laughter of children at play.", {"entities": []}),
    ("I'm a believer in the power of resilience and strength.", {"entities": []}),
    ("I enjoy the feeling of accomplishment after a workout.", {"entities": []}),
    ("I'm passionate about fostering a sense of community.", {"entities": []}),
    ("I find inspiration in the beauty of the night sky.", {"entities": []}),
    ("I'm a dreamer and believe in the power of imagination.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm cup of tea.", {"entities": []}),
    ("I'm a believer in the importance of empathy and understanding.", {"entities": []}),
    ("I find happiness in the sound of music.", {"entities": []}),
    ("I'm passionate about fostering a sense of belonging.", {"entities": []}),
    ("I find comfort in the serenity of a quiet moment.", {"entities": []}),
    ("I'm fascinated by the mysteries of the human heart.", {"entities": []}),
    ("I find joy in the colors of a sunset.", {"entities": []}),
    ("I'm a believer in the power of positive thinking.", {"entities": []}),
    ("I enjoy the feeling of a cool breeze.", {"entities": []}),
    ("I'm passionate about making a positive difference.", {"entities": []}),
    ("I find inspiration in the resilience of nature.", {"entities": []}),
    ("I'm a dreamer and believe in infinite possibilities.", {"entities": []}),
    ("I'm an explorer and seek new opportunities.", {"entities": []}),
    ("I enjoy the feeling of laughter bubbling up.", {"entities": []}),
    ("I'm a believer in the importance of compassion.", {"entities": []}),
    ("I find happiness in the simple joys of life.", {"entities": []}),
    ("I'm passionate about protecting endangered species.", {"entities": []}),
    ("I find comfort in the sound of birds chirping.", {"entities": []}),
    ("I'm fascinated by the wonders of the cosmos.", {"entities": []}),
    ("I find joy in the beauty of a blooming flower.", {"entities": []}),
    ("I'm a believer in the power of self-discovery.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about creating a more sustainable future.", {"entities": []}),
    ("I find inspiration in the power of human potential.", {"entities": []}),
    ("I'm a dreamer and believe in following my heart.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm hug.", {"entities": []}),
    ("I'm a believer in the importance of diversity.", {"entities": []}),
    ("I find happiness in the beauty of a rainbow.", {"entities": []}),
    ("I'm passionate about promoting social justice.", {"entities": []}),
    ("I find comfort in the warmth of a cozy fire.", {"entities": []}),
    ("I'm fascinated by the intricacies of the human mind.", {"entities": []}),
    ("I find joy in the sound of waves crashing.", {"entities": []}),
    ("I'm a believer in the power of resilience and perseverance.", {"entities": []}),
    ("I enjoy the feeling of a gentle breeze.", {"entities": []}),
    ("I'm passionate about spreading love and kindness.", {"entities": []}),
    ("I find inspiration in the beauty of the natural world.", {"entities": []}),
    ("I'm a dreamer and believe in the beauty of dreams.", {"entities": []}),
    ("I'm an explorer and seek adventure wherever I go.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm a believer in the importance of mindfulness.", {"entities": []}),
    ("I find happiness in the company of good friends.", {"entities": []}),
    ("I'm passionate about making the world a better place.", {"entities": []}),
    ("I find comfort in the sound of rain falling softly.", {"entities": []}),
    ("I'm fascinated by the wonders of the natural world.", {"entities": []}),
    ("I find joy in the laughter of children at play.", {"entities": []}),
    ("I'm a believer in the power of resilience and strength.", {"entities": []}),
    ("I enjoy the feeling of accomplishment after a workout.", {"entities": []}),
    ("I'm passionate about fostering a sense of community.", {"entities": []}),
    ("I find inspiration in the beauty of the night sky.", {"entities": []}),
    ("I'm a dreamer and believe in the power of imagination.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm cup of tea.", {"entities": []}),
    ("I'm a believer in the importance of empathy and understanding.", {"entities": []}),
    ("I find happiness in the sound of music.", {"entities": []}),
    ("I'm passionate about fostering a sense of belonging.", {"entities": []}),
    ("I find comfort in the serenity of a quiet moment.", {"entities": []}),
    ("I'm fascinated by the mysteries of the human heart.", {"entities": []}),
    ("I find joy in the colors of a sunset.", {"entities": []}),
    ("I'm a believer in the power of positive thinking.", {"entities": []}),
    ("I enjoy the feeling of a cool breeze.", {"entities": []}),
    ("I'm passionate about making a positive difference.", {"entities": []}),
    ("I find inspiration in the resilience of nature.", {"entities": []}),
    ("I'm a dreamer and believe in infinite possibilities.", {"entities": []}),
    ("I'm an explorer and seek new opportunities.", {"entities": []}),
    ("I enjoy the feeling of laughter bubbling up.", {"entities": []}),
    ("I'm a believer in the importance of compassion.", {"entities": []}),
    ("I find happiness in the simple joys of life.", {"entities": []}),
    ("I'm passionate about protecting endangered species.", {"entities": []}),
    ("I find comfort in the sound of birds chirping.", {"entities": []}),
    ("I'm fascinated by the wonders of the cosmos.", {"entities": []}),
    ("I find joy in the beauty of a blooming flower.", {"entities": []}),
    ("I'm a believer in the power of self-discovery.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about creating a more sustainable future.", {"entities": []}),
    ("I find inspiration in the power of human potential.", {"entities": []}),
    ("I'm a dreamer and believe in following my heart.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm hug.", {"entities": []}),
    ("I'm a believer in the importance of diversity.", {"entities": []}),
    ("I find happiness in the beauty of a rainbow.", {"entities": []}),
    ("I'm passionate about promoting social justice.", {"entities": []}),
    ("I find comfort in the warmth of a cozy fire.", {"entities": []}),
    ("I'm fascinated by the intricacies of the human mind.", {"entities": []}),
    ("I find joy in the sound of waves crashing.", {"entities": []}),
    ("I'm a believer in the power of resilience and perseverance.", {"entities": []}),
    ("I enjoy the feeling of a gentle breeze.", {"entities": []}),
    ("I'm passionate about spreading love and kindness.", {"entities": []}),
    ("I find inspiration in the beauty of the natural world.", {"entities": []}),
    ("I'm a dreamer and believe in the beauty of dreams.", {"entities": []}),
    ("I'm an explorer and seek adventure wherever I go.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm a believer in the importance of mindfulness.", {"entities": []}),
    ("I find happiness in the company of good friends.", {"entities": []}),
    ("I'm passionate about making the world a better place.", {"entities": []}),
    ("I find comfort in the sound of rain falling softly.", {"entities": []}),
    ("I'm fascinated by the wonders of the natural world.", {"entities": []}),
    ("I find joy in the laughter of children at play.", {"entities": []}),
    ("I'm a believer in the power of resilience and strength.", {"entities": []}),
    ("I enjoy the feeling of accomplishment after a workout.", {"entities": []}),
    ("I'm passionate about fostering a sense of community.", {"entities": []}),
    ("I find inspiration in the beauty of the night sky.", {"entities": []}),
    ("I'm a dreamer and believe in the power of imagination.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm cup of tea.", {"entities": []}),
    ("I'm a believer in the importance of empathy and understanding.", {"entities": []}),
    ("I find happiness in the sound of music.", {"entities": []}),
    ("I'm passionate about fostering a sense of belonging.", {"entities": []}),
    ("I find comfort in the serenity of a quiet moment.", {"entities": []}),
    ("I'm fascinated by the mysteries of the human heart.", {"entities": []}),
    ("I find joy in the colors of a sunset.", {"entities": []}),
    ("I'm a believer in the power of positive thinking.", {"entities": []}),
    ("I enjoy the feeling of a cool breeze.", {"entities": []}),
    ("I'm passionate about making a positive difference.", {"entities": []}),
    ("I find inspiration in the resilience of nature.", {"entities": []}),
    ("I'm a dreamer and believe in infinite possibilities.", {"entities": []}),
    ("I'm an explorer and seek new opportunities.", {"entities": []}),
    ("I enjoy the feeling of laughter bubbling up.", {"entities": []}),
    ("I'm a believer in the importance of compassion.", {"entities": []}),
    ("I find happiness in the simple joys of life.", {"entities": []}),
    ("I'm passionate about protecting endangered species.", {"entities": []}),
    ("I find comfort in the sound of birds chirping.", {"entities": []}),
    ("I'm fascinated by the wonders of the cosmos.", {"entities": []}),
    ("I find joy in the beauty of a blooming flower.", {"entities": []}),
    ("I'm a believer in the power of self-discovery.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about creating a more sustainable future.", {"entities": []}),
    ("I find inspiration in the power of human potential.", {"entities": []}),
    ("I'm a dreamer and believe in following my heart.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm hug.", {"entities": []}),
    ("I'm a believer in the importance of diversity.", {"entities": []}),
    ("I find happiness in the beauty of a rainbow.", {"entities": []}),
    ("I'm passionate about promoting social justice.", {"entities": []}),
    ("I find comfort in the warmth of a cozy fire.", {"entities": []}),
    ("I'm fascinated by the intricacies of the human mind.", {"entities": []}),
    ("I find joy in the sound of waves crashing.", {"entities": []}),
    ("I'm a believer in the power of resilience and perseverance.", {"entities": []}),
    ("I enjoy the feeling of a gentle breeze.", {"entities": []}),
    ("I'm passionate about spreading love and kindness.", {"entities": []}),
    ("I find inspiration in the beauty of the natural world.", {"entities": []}),
    ("I'm a dreamer and believe in the beauty of dreams.", {"entities": []}),
    ("I'm an explorer and seek adventure wherever I go.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm a believer in the importance of mindfulness.", {"entities": []}),
    ("I find happiness in the company of good friends.", {"entities": []}),
    ("I'm passionate about making the world a better place.", {"entities": []}),
    ("I find comfort in the sound of rain falling softly.", {"entities": []}),
    ("I'm fascinated by the wonders of the natural world.", {"entities": []}),
    ("I find joy in the laughter of children at play.", {"entities": []}),
    ("I'm a believer in the power of resilience and strength.", {"entities": []}),
    ("I enjoy the feeling of accomplishment after a workout.", {"entities": []}),
    ("I'm passionate about fostering a sense of community.", {"entities": []}),
    ("I find inspiration in the beauty of the night sky.", {"entities": []}),
    ("I'm a dreamer and believe in the power of imagination.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm cup of tea.", {"entities": []}),
    ("I'm a believer in the importance of empathy and understanding.", {"entities": []}),
    ("I find happiness in the sound of music.", {"entities": []}),
    ("I'm passionate about fostering a sense of belonging.", {"entities": []}),
    ("I find comfort in the serenity of a quiet moment.", {"entities": []}),
    ("I'm fascinated by the mysteries of the human heart.", {"entities": []}),
    ("I find joy in the colors of a sunset.", {"entities": []}),
    ("I'm a believer in the power of positive thinking.", {"entities": []}),
    ("I enjoy the feeling of a cool breeze.", {"entities": []}),
    ("I'm passionate about making a positive difference.", {"entities": []}),
    ("I find inspiration in the resilience of nature.", {"entities": []}),
    ("I'm a dreamer and believe in infinite possibilities.", {"entities": []}),
    ("I'm an explorer and seek new opportunities.", {"entities": []}),
    ("I enjoy the feeling of laughter bubbling up.", {"entities": []}),
    ("I'm a believer in the importance of compassion.", {"entities": []}),
    ("I find happiness in the simple joys of life.", {"entities": []}),
    ("I'm passionate about protecting endangered species.", {"entities": []}),
    ("I find comfort in the sound of birds chirping.", {"entities": []}),
    ("I'm fascinated by the wonders of the cosmos.", {"entities": []}),
    ("I find joy in the beauty of a blooming flower.", {"entities": []}),
    ("I'm a believer in the power of self-discovery.", {"entities": []}),
    ("I enjoy the feeling of sand between my toes.", {"entities": []}),
    ("I'm passionate about creating a more sustainable future.", {"entities": []}),
    ("I find inspiration in the power of human potential.", {"entities": []}),
    ("I'm a dreamer and believe in following my heart.", {"entities": []}),
    ("I'm an adventurer and seek new experiences.", {"entities": []}),
    ("I enjoy the feeling of a warm hug.", {"entities": []}),
    ("I'm a believer in the importance of diversity.", {"entities": []}),
    ("I find happiness in the beauty of a rainbow.", {"entities": []}),
    ("I'm passionate about promoting social justice.", {"entities": []}),
    ("I find comfort in the warmth of a cozy fire.", {"entities": []}),
]

# %% [markdown]
# # Preprocessing Data

# %%
# !pip install transformers torch
from transformers import AutoTokenizer, AutoModelForTokenClassification, TrainingArguments, Trainer
import torch
import numpy as np

model_name = "bert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
label2id = {"O": 0, "B-LIFESTYLE": 1, "I-LIFESTYLE": 2}
id2label = {0: "O", 1: "B-LIFESTYLE", 2: "I-LIFESTYLE"}

# %%
def tokenize_and_align_labels(tokenizer, data, label2id):
    tokenized_inputs = tokenizer([text for text, _ in data], padding=True, truncation=True, return_tensors="pt")
    labels = []

    for i, (_, annotations) in enumerate(data):
        word_ids = tokenized_inputs.word_ids(batch_index=i)
        label_array = np.ones(len(word_ids), dtype=int) * label2id["O"]  # Initialize all labels to "O"

        entities = annotations['entities']
        for start_char, end_char, label in entities:
            entity_tokens_range = (tokenized_inputs.char_to_token(i, start_char), tokenized_inputs.char_to_token(i, end_char - 1))
            if None not in entity_tokens_range:
                start_token, end_token = entity_tokens_range
                label_array[start_token] = label2id[f"B-{label}"]  # Begin label
                for token_index in range(start_token + 1, end_token + 1):
                    label_array[token_index] = label2id[f"I-{label}"]  # Inside label

        labels.append(label_array.tolist())

    tokenized_inputs["labels"] = torch.tensor(labels)
    return tokenized_inputs

# %%
# Tokenize and align labels
tokenized_and_aligned_data = tokenize_and_align_labels(tokenizer, TRAIN_DATA, label2id)

# %%
from torch.utils.data import Dataset

class NERDataset(Dataset):
    def __init__(self, tokenized_data):
        self.input_ids = tokenized_data["input_ids"]
        self.attention_mask = tokenized_data["attention_mask"]
        self.labels = tokenized_data["labels"]

    def __len__(self):
        return self.labels.size(0)

    def __getitem__(self, idx):
        return {
            "input_ids": self.input_ids[idx],
            "attention_mask": self.attention_mask[idx],
            "labels": self.labels[idx]
        }

dataset = NERDataset(tokenized_and_aligned_data)

# %%
model = AutoModelForTokenClassification.from_pretrained(model_name, num_labels=len(label2id))
# Out:
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from transformers import get_linear_schedule_with_warmup
from transformers import TrainingArguments
from transformers import EarlyStoppingCallback

from transformers import TrainingArguments
from transformers import EarlyStoppingCallback

early_stopping = EarlyStoppingCallback(early_stopping_patience=2)

training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=15,
    per_device_train_batch_size=16,
    warmup_steps=500,
    weight_decay=0.01,
    logging_dir='./logs',
    logging_steps=10,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=TRAIN_DATA,
    callbacks=[early_stopping],
)

# %%
from transformers import Trainer

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset,
)

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='5100' max='5100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5100/5100 2:31:19, Epoch 15/15]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>1.168900</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.068200</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.874300</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.582100</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.340300</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.245700</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.227800</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.191600</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.188700</td>
#     </tr>
#     <tr>
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
model_path = r"/content/drive/My Drive/Team_Project_Lifestyle"
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)
# Out:
# ('/content/drive/My Drive/Team_Project_Lifestyle/tokenizer_config.json',
#  '/content/drive/My Drive/Team_Project_Lifestyle/special_tokens_map.json',
#  '/content/drive/My Drive/Team_Project_Lifestyle/vocab.txt',
#  '/content/drive/My Drive/Team_Project_Lifestyle/added_tokens.json',
#  '/content/drive/My Drive/Team_Project_Lifestyle/tokenizer.json')

# %%
# To reload later
#from transformers import AutoModelForTokenClassification, AutoTokenizer

#model_path = "/content/drive/My Drive/Team Project"
#model = AutoModelForTokenClassification.from_pretrained(model_path)
#tokenizer = AutoTokenizer.from_pretrained(model_path)

# %%
# Example text
text = "I eat halal food, i eat kosher food"

inputs = tokenizer(text, return_tensors="pt")

with torch.no_grad():
    outputs = model(**inputs)

logits = outputs.logits
predictions = logits.argmax(-1).squeeze().tolist()

predicted_labels = [id2label[label] for label in predictions]

# Combine tokens with labels
tokens = tokenizer.convert_ids_to_tokens(inputs["input_ids"].squeeze().tolist())
labeled_tokens = list(zip(tokens, predicted_labels))

def aggregate_entities(tokens, predicted_labels):
    entities = []
    current_entity = []
    current_label = None

    for token, label in zip(tokens, predicted_labels):
        # Skip special tokens
        if token in ["[CLS]", "[SEP]"]:
            continue

        # Handle subword tokens
        if token.startswith("##"):
            if current_entity:
                current_entity[-1] += token[2:]  # Merge with the previous
            continue

        # Process BIO tags
        if label.startswith("B-"):
            if current_entity:  # Save the previous 
                entities.append((current_label, " ".join(current_entity)))
            current_entity = [token]
            current_label = label[2:]  # Remove the BIO prefix
        elif label.startswith("I-") and current_label == label[2:]:
            current_entity.append(token)
        else:  # O or different entity
            if current_entity:  # Save the previous 
                entities.append((current_label, " ".join(current_entity)))
                current_entity = []
                current_label = None

    if current_entity:
        entities.append((current_label, " ".join(current_entity)))

    return entities

entities = aggregate_entities(tokens, predicted_labels)

def extract_entities(entities, label_to_extract):
    extracted_entities = []
    for label, entity in entities:
        if label == label_to_extract:
            extracted_entities.append(entity)
    return extracted_entities

def remove_additional_words(entities, additional_words):
    cleaned_entities = []
    for entity in entities:
        words = entity.split()
        cleaned_entity = ' '.join(word for word in words if word.lower() not in additional_words)
        if cleaned_entity: 
            cleaned_entities.append(cleaned_entity)
    return cleaned_entities

lifestyle_entities = extract_entities(entities, 'LIFESTYLE')

additional_words_to_remove = ["and", "eat"]  # Add more words as needed
cleaned_lifestyle_entities = remove_additional_words(lifestyle_entities, additional_words_to_remove)

for entity in cleaned_lifestyle_entities:
    print(entity)
# Out:
# halal
# kosher

# %% [markdown]
# # Check in stages

# %%
# Example text
text = "I exercise daily"

inputs = tokenizer(text, return_tensors="pt")

with torch.no_grad():
    outputs = model(**inputs)

logits = outputs.logits
predictions = logits.argmax(-1).squeeze().tolist()

predicted_labels = [id2label[label] for label in predictions]

tokens = tokenizer.convert_ids_to_tokens(inputs["input_ids"].squeeze().tolist())
labeled_tokens = list(zip(tokens, predicted_labels))

def aggregate_entities(tokens, predicted_labels):
    entities = []
    current_entity = []
    current_label = None

    for token, label in zip(tokens, predicted_labels):
        # Skip special tokens
        if token in ["[CLS]", "[SEP]"]:
            continue

        # Handle subword tokens
        if token.startswith("##"):
            if current_entity:
                current_entity[-1] += token[2:]  # Merge with the previous
            continue

        # Process BIO tags
        if label.startswith("B-"):
            if current_entity:  # Save the previous 
                entities.append((current_label, " ".join(current_entity)))
            current_entity = [token]
            current_label = label[2:]  # Remove the BIO prefix
        elif label.startswith("I-") and current_label == label[2:]:
            current_entity.append(token)
        else: 
            if current_entity:  # Save the previous 
                entities.append((current_label, " ".join(current_entity)))
                current_entity = []
                current_label = None

    if current_entity:
        entities.append((current_label, " ".join(current_entity)))

    return entities

entities = aggregate_entities(tokens, predicted_labels)
for label, entity in entities:
    print(f"{label}: {entity}")
# Out:
# LIFESTYLE: exercise

# %%
print(predicted_labels)
# Out:
# ['O', 'O', 'B-LIFESTYLE', 'O', 'O']

# %%
for token, label in zip(tokens, predicted_labels):
    print(f"{token}: {label}")
# Out:
# [CLS]: O
# i: O
# exercise: B-LIFESTYLE
# daily: O
# [SEP]: O

# %%
def extract_entities(entities, label_to_extract):
    extracted_entities = []
    for label, entity in entities:
        if label == label_to_extract:
            extracted_entities.append(entity)
    return extracted_entities

def remove_additional_words(entities, additional_words):
    cleaned_entities = []
    for entity in entities:
        words = entity.split()
        cleaned_entity = ' '.join(word for word in words if word.lower() not in additional_words)
        if cleaned_entity:  
            cleaned_entities.append(cleaned_entity)
    return cleaned_entities

entities = aggregate_entities(tokens, predicted_labels)

lifestyle_entities = extract_entities(entities, 'LIFESTYLE')

additional_words_to_remove = ["and", "eat"]  # Add more words as needed
cleaned_lifestyle_entities = remove_additional_words(lifestyle_entities, additional_words_to_remove)

for entity in cleaned_lifestyle_entities:
    print(entity)
# Out:
# exercise
